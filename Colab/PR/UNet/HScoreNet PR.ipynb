# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
# !pip install -U keras
# !pip install tensorflow-gpu==2.1.0rc0
# Out:
# Requirement already up-to-date: keras in /usr/local/lib/python3.6/dist-packages (2.3.1)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras) (1.0.8)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras) (1.1.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.18.4)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.10.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.4.1)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras) (1.12.0)
# Collecting tensorflow-gpu==2.1.0rc0
#   Downloading https://files.pythonhosted.org/packages/f3/24/f94a1b8f779471f53b814a96c5109994ccf65b0103b771ff208c8a937d37/tensorflow_gpu-2.1.0rc0-cp36-cp36m-manylinux2010_x86_64.whl (402.3MB)
#      |████████████████████████████████| 402.3MB 35kB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.9.0)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.29.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (3.2.1)
# Collecting tensorboard<2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/76/54/99b9d5d52d5cb732f099baaaf7740403e83fe6b0cedde940fabd2b13d75a/tensorboard-2.0.2-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 51.8MB/s
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.12.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.34.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.12.0)
# Collecting tensorflow-estimator<2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/fc/08/8b927337b7019c374719145d1dceba21a8bb909b93b1ad6f8fb7d22c1ca1/tensorflow_estimator-2.0.1-py2.py3-none-any.whl (449kB)
#      |████████████████████████████████| 450kB 42.4MB/s
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.0.8)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.8.1)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (3.10.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.18.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.7.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.2.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.4.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (46.4.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==2.1.0rc0) (2.10.0)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.2.8)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (4.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.6.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2020.4.5.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=f1494fb7196c0447395673337f127214962d223f0c872797285cdbe30ca79ed5
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 2.2.0 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.2.0 has requirement tensorboard<2.3.0,>=2.2.0, but you'll have tensorboard 2.0.2 which is incompatible.
# ERROR: tensorflow 2.2.0 has requirement tensorflow-estimator<2.3.0,>=2.2.0, but you'll have tensorflow-estimator 2.0.1 which is incompatible.
# ERROR: tensorflow-probability 0.10.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# Installing collected packages: gast, tensorboard, tensorflow-estimator, tensorflow-gpu
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorboard 2.2.1
#     Uninstalling tensorboard-2.2.1:
#       Successfully uninstalled tensorboard-2.2.1
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
# Successfully installed gast-0.2.2 tensorboard-2.0.2 tensorflow-estimator-2.0.1 tensorflow-gpu-2.1.0rc0

# %%
import math
import random
import keras
from keras.layers import *
from keras.models import Sequential
from keras import Model
# Out:
# Using TensorFlow backend.

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/4 Class PR"

Train = ['230','242','239','232']
Test  = ['221', '229', '246', '252','263']

# Train set patients: 230 232 242 263 
TrainX_1 = np.load(PATH + '/PR IHC 230 Images.npy')
TrainY_1 = np.load(PATH + '/PR IHC 230 Masks.npy')
TrainX_2 = np.load(PATH + '/PR IHC 242 Images.npy')
TrainY_2 = np.load(PATH + '/PR IHC 242 Masks.npy')
TrainX_3 = np.load(PATH + '/PR IHC 239 Images.npy')
TrainY_3 = np.load(PATH + '/PR IHC 239 Masks.npy')
TrainX_4 = np.load(PATH + '/PR IHC 232 Images.npy')
TrainY_4 = np.load(PATH + '/PR IHC 232 Masks.npy')

# Test set patients: 221 229 239 246 252
TestX_1 = np.load(PATH + '/PR IHC 221 Images.npy')
TestY_1 = np.load(PATH + '/PR IHC 221 Masks.npy')
TestX_2 = np.load(PATH + '/PR IHC 229 Images.npy')
TestY_2 = np.load(PATH + '/PR IHC 229 Masks.npy')
TestX_3 = np.load(PATH + '/PR IHC 246 Images.npy')
TestY_3 = np.load(PATH + '/PR IHC 246 Masks.npy')
TestX_4 = np.load(PATH + '/PR IHC 252 Images.npy')
TestY_4 = np.load(PATH + '/PR IHC 252 Masks.npy')
TestX_5 = np.load(PATH + '/PR IHC 263 Images.npy')
TestY_5 = np.load(PATH + '/PR IHC 263 Masks.npy')

# %%
def convertToLabels(data):
  data[data==85]=1
  data[data==170]=2
  data[data==255]=3

def convertFromLabels(data):
  data[data==1]=85
  data[data==2]=170
  data[data==3]=255

# %%
TrainX = np.concatenate((TrainX_1, TrainX_2, TrainX_3, TrainX_4), axis=0)
TrainGT = np.concatenate((TrainY_1, TrainY_2, TrainY_3, TrainY_4), axis=0)
TrainY = np.copy(TrainGT)
convertToLabels(TrainY)
TrainY = keras.utils.to_categorical(TrainY,num_classes=4,dtype='int16')

# Train = list(zip(TrainX,TrainY))
# random.shuffle(Train)
# TrainX,TrainY = zip(*Train)
# TrainX = np.asarray(list(TrainX))
# TrainY = np.asarray(list(TrainY))

TestX = np.concatenate((TestX_1, TestX_2, TestX_3,TestX_4,TestX_5), axis=0)
TestGT = np.concatenate((TestY_1, TestY_2, TestY_3,TestY_4,TestY_5), axis=0)
TestY = np.copy(TestGT)
convertToLabels(TestY)
TestY = keras.utils.to_categorical(TestY,num_classes=4, dtype='int16')

ValidX = TrainX[1800:, : ]
ValidY = TrainY[1800:, : ]

TrainX = TrainX[0:1800, : ]
TrainY = TrainY[0:1800, : ]

# %%
TrainX = TrainX.astype('float32')/255
TestX = TestX.astype('float32')/255
ValidX = ValidX.astype('float32')/255

# %%
print(TrainX.shape)
print(TrainY.shape)

print(TestX.shape)
print(TestY.shape)

print(ValidX.shape)
print(ValidY.shape)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 4)
# (2400, 240, 240, 3)
# (2400, 240, 240, 4)
# (312, 240, 240, 3)
# (312, 240, 240, 4)

# %%
def get_conv_block1(input_layer,nFilters,size):
    conv1 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(input_layer)
    conv2 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    bn1 = BatchNormalization()(conv2)
    return bn1

def get_conv_block2(input_layer,nFilters,size):
    conv1 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(input_layer)
    conv2 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv3 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    bn1 = BatchNormalization()(conv3)
    return bn1

def get_model():    
    input_layer = Input(shape=(240,240,3))
    block1 = get_conv_block1(input_layer,64,2)
    dr1 = Dropout(0.1)(block1)
    mp1 = MaxPooling2D(pool_size=(2, 2))(dr1)
    
    block2 = get_conv_block2(mp1,64,2)
    dr2 = Dropout(0.1)(block2)
    mp2 = MaxPooling2D(pool_size=(2, 2))(dr2)
    
    block3 = get_conv_block2(mp2,64,2)
    dr3 = Dropout(0.1)(block3)
    mp3 = MaxPooling2D(pool_size=(2, 2))(dr3)
    
    block4 = get_conv_block1(mp3,64,2)
    dr4 = Dropout(0.1)(block4)
    mp4 = MaxPooling2D(pool_size=(2, 2))(dr4)

    block5 = get_conv_block1(mp4,64,2)
    dr5 = Dropout(0.1)(block5)
       
    up1 = Conv2DTranspose(32,(2,2),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(dr5)
    cat1 = concatenate([block4,up1])
    dr1 = Dropout(0.1)(cat1)
    block5 = get_conv_block2(dr1,64,2)

    up2 = Conv2DTranspose(32,(2,2),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block5)
    cat2 = concatenate([block3,up2])
    dr2 = Dropout(0.1)(cat2)
    block6 = get_conv_block2(dr2,64,2)
    
    up3 = Conv2DTranspose(32,(2,2),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block6)
    cat3 = concatenate([block2,up3])
    dr3 = Dropout(0.1)(cat3)
    block7 = get_conv_block2(dr3,64,2)
    
    up4 = Conv2DTranspose(32,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block7)
    cat4 = concatenate([block1,up4])
    dr4 = Dropout(0.1)(cat4)
    block8 = get_conv_block1(dr4,64,3)

    conv10 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(block8)
    conv11 = Conv2D(4, (1,1), activation='softmax', padding = 'same')(conv10)

    model = Model(input_layer,conv11)
    return model

# %%
model = get_model()
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 240, 240, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 240, 240, 64) 832         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 240, 240, 64) 16448       conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 240, 240, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 240, 240, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 120, 120, 64) 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 120, 120, 64) 16448       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 120, 120, 64) 16448       conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 120, 120, 64) 16448       conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 120, 120, 64) 256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 120, 120, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 60, 60, 64)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 60, 60, 64)   16448       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 60, 60, 64)   16448       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 60, 60, 64)   16448       conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 60, 60, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 60, 60, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 30, 30, 64)   0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 30, 30, 64)   16448       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 30, 30, 64)   16448       conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 30, 30, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 30, 30, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 15, 15, 64)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 15, 15, 64)   16448       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 15, 15, 64)   16448       conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 15, 15, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 15, 15, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 30, 30, 32)   8224        dropout_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 30, 30, 96)   0           batch_normalization_4[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 30, 30, 96)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 30, 30, 64)   24640       dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 30, 30, 64)   16448       conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 30, 30, 64)   16448       conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 30, 30, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 60, 60, 32)   8224        batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 60, 60, 96)   0           batch_normalization_3[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 60, 60, 96)   0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 60, 60, 64)   24640       dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 60, 60, 64)   16448       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 60, 60, 64)   16448       conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 60, 60, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 120, 120, 32) 8224        batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 120, 120, 96) 0           batch_normalization_2[0][0]
#                                                                  conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 120, 120, 96) 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 120, 120, 64) 24640       dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 120, 120, 64) 16448       conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 120, 120, 64) 16448       conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 120, 120, 64) 256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 240, 240, 32) 18464       batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 240, 240, 96) 0           batch_normalization_1[0][0]
#                                                                  conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 240, 240, 96) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 240, 240, 64) 55360       dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 240, 240, 64) 36928       conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 240, 240, 64) 256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 240, 240, 2)  1154        batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 240, 240, 4)  12          conv2d_24[0][0]
# ==================================================================================================
# Total params: 493,262
# Trainable params: 492,110
# Non-trainable params: 1,152
# __________________________________________________________________________________________________

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
from keras.callbacks import EarlyStopping,ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
mc = ModelCheckpoint('Checkpoint.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=0.001, decay=0.0, amsgrad=True)

# %%
def tversky_loss(y_true, y_pred):
    alpha = 0.45
    beta  = 0.55
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def combined_loss(y_true, y_pred):
  return (0.5*K.categorical_crossentropy(y_true, y_pred))+(1*tversky_loss(y_true, y_pred))

# %%
batch_size = 16
def get_batch(batch_size, X_train, Y_train): 
    size_batch = batch_size
    last_index = len(X_train) - 1
    x_train = X_train
    y_train = Y_train 
    while True:
        batch_data = [[],[]]
        for i in range(0, size_batch):
            random_index = random.randint(0, last_index)
            batch_data[0].append(x_train[random_index])
            batch_data[1].append(y_train[random_index])

        yield (np.array(batch_data[0]), np.array(batch_data[1]))

# %%
from keras import backend as K      
model.compile(loss=combined_loss, optimizer= optimizer , metrics=[dice_coef,'accuracy'])

# %%
num_epoch = 100
datagen = get_batch(batch_size, TrainX, TrainY)
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/PR"
n_points = len(TrainX)
history = model.fit(datagen, 
                validation_data = (ValidX, ValidY),
                epochs=num_epoch,steps_per_epoch = math.ceil(n_points / batch_size), callbacks =[es,mc],  shuffle =True)
model.save(MODELS_PATH + '/HScoreNet_PR.h5')
# Out:
# Epoch 1/100
# 113/113 [==============================] - 43s 384ms/step - loss: 4.0332 - dice_coef: 0.2832 - accuracy: 0.8537 - val_loss: 4.1600 - val_dice_coef: 0.2933 - val_accuracy: 0.9886
#
# Epoch 00001: val_loss improved from inf to 4.15996, saving model to Checkpoint.h5
# Epoch 2/100
# 113/113 [==============================] - 39s 348ms/step - loss: 3.8436 - dice_coef: 0.3346 - accuracy: 0.9618 - val_loss: 4.0279 - val_dice_coef: 0.3411 - val_accuracy: 0.9895
#
# Epoch 00002: val_loss improved from 4.15996 to 4.02790, saving model to Checkpoint.h5
# Epoch 3/100
# 113/113 [==============================] - 39s 347ms/step - loss: 3.6997 - dice_coef: 0.3818 - accuracy: 0.9637 - val_loss: 3.9027 - val_dice_coef: 0.3918 - val_accuracy: 0.9896
#
# Epoch 00003: val_loss improved from 4.02790 to 3.90273, saving model to Checkpoint.h5
# Epoch 4/100
# 113/113 [==============================] - 39s 347ms/step - loss: 3.5881 - dice_coef: 0.4279 - accuracy: 0.9652 - val_loss: 3.7867 - val_dice_coef: 0.4438 - val_accuracy: 0.9897
#
# Epoch 00004: val_loss improved from 3.90273 to 3.78668, saving model to Checkpoint.h5
# Epoch 5/100
# 113/113 [==============================] - 39s 347ms/step - loss: 3.4213 - dice_coef: 0.4783 - accuracy: 0.9608 - val_loss: 3.6781 - val_dice_coef: 0.4962 - val_accuracy: 0.9897
#
# Epoch 00005: val_loss improved from 3.78668 to 3.67810, saving model to Checkpoint.h5
# Epoch 6/100
# 113/113 [==============================] - 39s 347ms/step - loss: 3.3082 - dice_coef: 0.5271 - accuracy: 0.9623 - val_loss: 3.5870 - val_dice_coef: 0.5462 - val_accuracy: 0.9879
#
# Epoch 00006: val_loss improved from 3.67810 to 3.58696, saving model to Checkpoint.h5
# Epoch 7/100
# 113/113 [==============================] - 39s 348ms/step - loss: 3.1838 - dice_coef: 0.5734 - accuracy: 0.9610 - val_loss: 3.5160 - val_dice_coef: 0.5919 - val_accuracy: 0.9831
#
# Epoch 00007: val_loss improved from 3.58696 to 3.51599, saving model to Checkpoint.h5
# Epoch 8/100
# 113/113 [==============================] - 39s 348ms/step - loss: 3.0839 - dice_coef: 0.6179 - accuracy: 0.9635 - val_loss: 3.4214 - val_dice_coef: 0.6412 - val_accuracy: 0.9898
#
# Epoch 00008: val_loss improved from 3.51599 to 3.42141, saving model to Checkpoint.h5
# Epoch 9/100
# 113/113 [==============================] - 39s 348ms/step - loss: 2.9651 - dice_coef: 0.6587 - accuracy: 0.9621 - val_loss: 3.3572 - val_dice_coef: 0.6823 - val_accuracy: 0.9893
#
# Epoch 00009: val_loss improved from 3.42141 to 3.35717, saving model to Checkpoint.h5
# Epoch 10/100
# 113/113 [==============================] - 39s 347ms/step - loss: 2.8551 - dice_coef: 0.6948 - accuracy: 0.9605 - val_loss: 3.3077 - val_dice_coef: 0.7164 - val_accuracy: 0.9863
#
# Epoch 00010: val_loss improved from 3.35717 to 3.30771, saving model to Checkpoint.h5
# Epoch 11/100
# 113/113 [==============================] - 39s 348ms/step - loss: 2.8428 - dice_coef: 0.7295 - accuracy: 0.9667 - val_loss: 3.2444 - val_dice_coef: 0.7530 - val_accuracy: 0.9892
#
# Epoch 00011: val_loss improved from 3.30771 to 3.24438, saving model to Checkpoint.h5
# Epoch 12/100
# 113/113 [==============================] - 39s 348ms/step - loss: 2.7098 - dice_coef: 0.7572 - accuracy: 0.9631 - val_loss: 3.2053 - val_dice_coef: 0.7825 - val_accuracy: 0.9887
#
# Epoch 00012: val_loss improved from 3.24438 to 3.20529, saving model to Checkpoint.h5
# Epoch 13/100
# 113/113 [==============================] - 39s 347ms/step - loss: 2.6507 - dice_coef: 0.7829 - accuracy: 0.9633 - val_loss: 3.1685 - val_dice_coef: 0.8062 - val_accuracy: 0.9861
#
# Epoch 00013: val_loss improved from 3.20529 to 3.16848, saving model to Checkpoint.h5
# Epoch 14/100
# 113/113 [==============================] - 39s 347ms/step - loss: 2.5589 - dice_coef: 0.8047 - accuracy: 0.9622 - val_loss: 3.1271 - val_dice_coef: 0.8291 - val_accuracy: 0.9868
#
# Epoch 00014: val_loss improved from 3.16848 to 3.12708, saving model to Checkpoint.h5
# Epoch 15/100
# 113/113 [==============================] - 39s 347ms/step - loss: 2.5441 - dice_coef: 0.8259 - accuracy: 0.9655 - val_loss: 3.0868 - val_dice_coef: 0.8489 - val_accuracy: 0.9879
#
# Epoch 00015: val_loss improved from 3.12708 to 3.08680, saving model to Checkpoint.h5
# Epoch 16/100
# 113/113 [==============================] - 39s 347ms/step - loss: 2.4582 - dice_coef: 0.8424 - accuracy: 0.9649 - val_loss: 3.0900 - val_dice_coef: 0.8592 - val_accuracy: 0.9820
#
# Epoch 00016: val_loss did not improve from 3.08680
# Epoch 17/100
# 113/113 [==============================] - 39s 347ms/step - loss: 2.4239 - dice_coef: 0.8577 - accuracy: 0.9668 - val_loss: 3.0444 - val_dice_coef: 0.8787 - val_accuracy: 0.9866
#
# Epoch 00017: val_loss improved from 3.08680 to 3.04441, saving model to Checkpoint.h5
# Epoch 18/100
# 113/113 [==============================] - 39s 347ms/step - loss: 2.3813 - dice_coef: 0.8708 - accuracy: 0.9679 - val_loss: 3.0084 - val_dice_coef: 0.8906 - val_accuracy: 0.9868
#
# Epoch 00018: val_loss improved from 3.04441 to 3.00837, saving model to Checkpoint.h5
# Epoch 19/100
# 113/113 [==============================] - 39s 347ms/step - loss: 2.2878 - dice_coef: 0.8806 - accuracy: 0.9668 - val_loss: 2.9934 - val_dice_coef: 0.9041 - val_accuracy: 0.9893
#
# Epoch 00019: val_loss improved from 3.00837 to 2.99337, saving model to Checkpoint.h5
# Epoch 20/100
# 113/113 [==============================] - 39s 347ms/step - loss: 2.2291 - dice_coef: 0.8896 - accuracy: 0.9669 - val_loss: 2.9564 - val_dice_coef: 0.9101 - val_accuracy: 0.9862
#
# Epoch 00020: val_loss improved from 2.99337 to 2.95644, saving model to Checkpoint.h5
# Epoch 21/100
# 113/113 [==============================] - 39s 347ms/step - loss: 2.2277 - dice_coef: 0.8958 - accuracy: 0.9653 - val_loss: 2.9287 - val_dice_coef: 0.9213 - val_accuracy: 0.9894
#
# Epoch 00021: val_loss improved from 2.95644 to 2.92873, saving model to Checkpoint.h5
# Epoch 22/100
# 113/113 [==============================] - 39s 347ms/step - loss: 2.1462 - dice_coef: 0.9046 - accuracy: 0.9664 - val_loss: 2.8887 - val_dice_coef: 0.9165 - val_accuracy: 0.9812
#
# Epoch 00022: val_loss improved from 2.92873 to 2.88868, saving model to Checkpoint.h5
# Epoch 23/100
# 113/113 [==============================] - 39s 347ms/step - loss: 2.1131 - dice_coef: 0.9094 - accuracy: 0.9642 - val_loss: 2.9445 - val_dice_coef: 0.9346 - val_accuracy: 0.9884
#
# Epoch 00023: val_loss did not improve from 2.88868
# Epoch 24/100
# 113/113 [==============================] - 39s 347ms/step - loss: 2.0849 - dice_coef: 0.9143 - accuracy: 0.9628 - val_loss: 2.8308 - val_dice_coef: 0.9390 - val_accuracy: 0.9878
#
# Epoch 00024: val_loss improved from 2.88868 to 2.83075, saving model to Checkpoint.h5
# Epoch 25/100
# 113/113 [==============================] - 39s 347ms/step - loss: 2.0841 - dice_coef: 0.9220 - accuracy: 0.9654 - val_loss: 2.8232 - val_dice_coef: 0.9362 - val_accuracy: 0.9840
#
# Epoch 00025: val_loss improved from 2.83075 to 2.82315, saving model to Checkpoint.h5
# Epoch 26/100
# 113/113 [==============================] - 39s 347ms/step - loss: 2.0088 - dice_coef: 0.9231 - accuracy: 0.9621 - val_loss: 2.8384 - val_dice_coef: 0.9510 - val_accuracy: 0.9897
#
# Epoch 00026: val_loss did not improve from 2.82315
# Epoch 27/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.9811 - dice_coef: 0.9287 - accuracy: 0.9640 - val_loss: 2.8601 - val_dice_coef: 0.9477 - val_accuracy: 0.9871
#
# Epoch 00027: val_loss did not improve from 2.82315
# Epoch 28/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.9422 - dice_coef: 0.9340 - accuracy: 0.9660 - val_loss: 2.8176 - val_dice_coef: 0.9577 - val_accuracy: 0.9896
#
# Epoch 00028: val_loss improved from 2.82315 to 2.81762, saving model to Checkpoint.h5
# Epoch 29/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.9608 - dice_coef: 0.9362 - accuracy: 0.9655 - val_loss: 2.8950 - val_dice_coef: 0.9597 - val_accuracy: 0.9884
#
# Epoch 00029: val_loss did not improve from 2.81762
# Epoch 30/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.8910 - dice_coef: 0.9399 - accuracy: 0.9663 - val_loss: 2.7605 - val_dice_coef: 0.9546 - val_accuracy: 0.9823
#
# Epoch 00030: val_loss improved from 2.81762 to 2.76050, saving model to Checkpoint.h5
# Epoch 31/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.9301 - dice_coef: 0.9427 - accuracy: 0.9667 - val_loss: 2.8443 - val_dice_coef: 0.9657 - val_accuracy: 0.9894
#
# Epoch 00031: val_loss did not improve from 2.76050
# Epoch 32/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.8356 - dice_coef: 0.9445 - accuracy: 0.9664 - val_loss: 2.7672 - val_dice_coef: 0.9688 - val_accuracy: 0.9904
#
# Epoch 00032: val_loss did not improve from 2.76050
# Epoch 33/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.8449 - dice_coef: 0.9464 - accuracy: 0.9666 - val_loss: 2.7087 - val_dice_coef: 0.9688 - val_accuracy: 0.9887
#
# Epoch 00033: val_loss improved from 2.76050 to 2.70874, saving model to Checkpoint.h5
# Epoch 34/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.8530 - dice_coef: 0.9470 - accuracy: 0.9655 - val_loss: 2.7874 - val_dice_coef: 0.9686 - val_accuracy: 0.9876
#
# Epoch 00034: val_loss did not improve from 2.70874
# Epoch 35/100
# 113/113 [==============================] - 39s 348ms/step - loss: 1.8475 - dice_coef: 0.9498 - accuracy: 0.9670 - val_loss: 2.6662 - val_dice_coef: 0.9713 - val_accuracy: 0.9885
#
# Epoch 00035: val_loss improved from 2.70874 to 2.66618, saving model to Checkpoint.h5
# Epoch 36/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.8280 - dice_coef: 0.9520 - accuracy: 0.9680 - val_loss: 2.7124 - val_dice_coef: 0.9745 - val_accuracy: 0.9903
#
# Epoch 00036: val_loss did not improve from 2.66618
# Epoch 37/100
# 113/113 [==============================] - 39s 348ms/step - loss: 1.8194 - dice_coef: 0.9524 - accuracy: 0.9672 - val_loss: 2.8484 - val_dice_coef: 0.9372 - val_accuracy: 0.9641
#
# Epoch 00037: val_loss did not improve from 2.66618
# Epoch 38/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.8030 - dice_coef: 0.9539 - accuracy: 0.9678 - val_loss: 2.7762 - val_dice_coef: 0.9751 - val_accuracy: 0.9889
#
# Epoch 00038: val_loss did not improve from 2.66618
# Epoch 39/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.7861 - dice_coef: 0.9558 - accuracy: 0.9689 - val_loss: 2.7397 - val_dice_coef: 0.9738 - val_accuracy: 0.9882
#
# Epoch 00039: val_loss did not improve from 2.66618
# Epoch 40/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.7570 - dice_coef: 0.9572 - accuracy: 0.9693 - val_loss: 2.6796 - val_dice_coef: 0.9751 - val_accuracy: 0.9879
#
# Epoch 00040: val_loss did not improve from 2.66618
# Epoch 41/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.7623 - dice_coef: 0.9569 - accuracy: 0.9683 - val_loss: 2.6416 - val_dice_coef: 0.9776 - val_accuracy: 0.9889
#
# Epoch 00041: val_loss improved from 2.66618 to 2.64164, saving model to Checkpoint.h5
# Epoch 42/100
# 113/113 [==============================] - 39s 348ms/step - loss: 1.7302 - dice_coef: 0.9579 - accuracy: 0.9687 - val_loss: 2.6821 - val_dice_coef: 0.9785 - val_accuracy: 0.9892
#
# Epoch 00042: val_loss did not improve from 2.64164
# Epoch 43/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.7380 - dice_coef: 0.9585 - accuracy: 0.9687 - val_loss: 2.7526 - val_dice_coef: 0.9798 - val_accuracy: 0.9899
#
# Epoch 00043: val_loss did not improve from 2.64164
# Epoch 44/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.7031 - dice_coef: 0.9579 - accuracy: 0.9675 - val_loss: 2.7454 - val_dice_coef: 0.9600 - val_accuracy: 0.9774
#
# Epoch 00044: val_loss did not improve from 2.64164
# Epoch 45/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.7398 - dice_coef: 0.9586 - accuracy: 0.9678 - val_loss: 2.7957 - val_dice_coef: 0.9810 - val_accuracy: 0.9899
#
# Epoch 00045: val_loss did not improve from 2.64164
# Epoch 46/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.7501 - dice_coef: 0.9603 - accuracy: 0.9690 - val_loss: 2.6989 - val_dice_coef: 0.9790 - val_accuracy: 0.9876
#
# Epoch 00046: val_loss did not improve from 2.64164
# Epoch 47/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.6994 - dice_coef: 0.9613 - accuracy: 0.9696 - val_loss: 2.8712 - val_dice_coef: 0.9231 - val_accuracy: 0.9457
#
# Epoch 00047: val_loss did not improve from 2.64164
# Epoch 48/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.6976 - dice_coef: 0.9611 - accuracy: 0.9690 - val_loss: 2.7186 - val_dice_coef: 0.9717 - val_accuracy: 0.9807
#
# Epoch 00048: val_loss did not improve from 2.64164
# Epoch 49/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.6862 - dice_coef: 0.9607 - accuracy: 0.9683 - val_loss: 2.7336 - val_dice_coef: 0.9695 - val_accuracy: 0.9813
#
# Epoch 00049: val_loss did not improve from 2.64164
# Epoch 50/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.6704 - dice_coef: 0.9627 - accuracy: 0.9699 - val_loss: 2.6962 - val_dice_coef: 0.9806 - val_accuracy: 0.9878
#
# Epoch 00050: val_loss did not improve from 2.64164
# Epoch 51/100
# 113/113 [==============================] - 39s 347ms/step - loss: 1.6670 - dice_coef: 0.9638 - accuracy: 0.9706 - val_loss: 2.6778 - val_dice_coef: 0.9806 - val_accuracy: 0.9873
#
# Epoch 00051: val_loss did not improve from 2.64164
# Epoch 00051: early stopping

# %%
train_loss = history.history['loss']
train_acc = history.history['accuracy']
val_loss = history.history['val_loss']
val_acc = history.history['val_accuracy']
xc=range(len(train_loss))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_loss)
plt.plot(xc, val_loss)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(['train','val'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_acc)
plt.plot(xc, val_acc)
plt.xlabel("Epoch")
plt.ylabel("Acc")
plt.legend(['train','val'])

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/PR/"
model = keras.models.load_model(MODELS_PATH +'/HScoreNet_PR.h5',custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

# %%
trainResult = model.predict(TrainX, batch_size=16)
validResult = model.predict(ValidX,batch_size=16)
testResult = model.predict(TestX,batch_size=16)

# %%
trainResult = np.argmax(trainResult,axis=-1)
validResult = np.argmax(validResult,axis=-1)
testResult = np.argmax(testResult,axis=-1)

convertFromLabels(trainResult)
convertFromLabels(validResult)
convertFromLabels(testResult)

# %%
from sklearn import metrics
trial1 = np.reshape(TrainY,(-1, TrainY.shape[3]))
trial2 = np.reshape(trainResult,(-1, trainResult.shape[3]))

print("TRAIN")
print(metrics.classification_report(trial1.argmax(axis = 1), trial2.argmax(axis = 1)))
train_JC = metrics.jaccard_score(trial1.argmax(axis=1),trial2.argmax(axis=1),average='weighted')
print("JACCARD COEFFICIENT:  ",train_JC)

trial1 = np.reshape(TestY,(-1, TestY.shape[3]))
trial2 = np.reshape(testResult,(-1, testResult.shape[3]))

print("\n\nTEST")
print(metrics.classification_report(trial1.argmax(axis = 1), trial2.argmax(axis = 1)))
test_JC = metrics.jaccard_score(trial1.argmax(axis=1),trial2.argmax(axis=1),average='weighted')
print("JACCARD COEFFICIENT:  ",test_JC)
# Out:
# TRAIN
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98  97581720
#            1       0.19      0.60      0.29    390675
#            2       0.37      0.65      0.47   1562840
#            3       0.85      0.81      0.83   4144765
#
#     accuracy                           0.96 103680000
#    macro avg       0.60      0.76      0.64 103680000
# weighted avg       0.98      0.96      0.97 103680000
#
# JACCARD COEFFICIENT:   0.9465703350259772
#
#
# TEST
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99 134676107
#            1       0.13      0.06      0.08   1113039
#            2       0.25      0.76      0.38   1725484
#            3       0.48      0.33      0.39    725370
#
#     accuracy                           0.96 138240000
#    macro avg       0.46      0.53      0.46 138240000
# weighted avg       0.98      0.96      0.97 138240000
#
# JACCARD COEFFICIENT:   0.9521041333493958

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask, Patient_array, title):
  num = mask.shape[0]/480
  print(num)
  for id in range(int(num)):
    temp = []
    for i in range(id*10, id*10+10):
      idx = i * 48
      final_output = mask[idx:idx+48]
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save("/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/PR/HScoreNet/" + title + Patient_array[id], final_output)

# %%
# saving predicted outputs as numpy arrays for test images
trainResult = np.append(trainResult, validResult, axis=0)
saveNumpyOutput(trainResult, Train,"Train/")
saveNumpyOutput(testResult, Test, "Test/")

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 25  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]

Mask_input = TrainY[id:id+48]

Mask_input = np.argmax(Mask_input, axis = 3)
convertFromLabels(Mask_input)
print(Mask_input.shape)
print(final_input.shape)
final_output = trainResult[id:id+48]
convertFromLabels(final_output)
final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240)
# (48, 240, 240, 3)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0.  85. 170. 255.]

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 45  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]

Mask_input = TestY[id:id+48]

Mask_input = np.argmax(Mask_input, axis = 3)
convertFromLabels(Mask_input)
print(Mask_input.shape)
print(final_input.shape)
final_output = testResult[id:id+48]
convertFromLabels(final_output)
final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240)
# (48, 240, 240, 3)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0.  85. 170. 255.]
