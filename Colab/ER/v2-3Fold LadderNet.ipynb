# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import cv2
import numpy as np
# !pip install -U keras
# !pip install tensorflow-gpu==2.1.0rc0
# Out:
# Requirement already up-to-date: keras in /usr/local/lib/python3.6/dist-packages (2.3.1)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras) (1.0.8)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras) (1.1.2)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.10.0)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras) (1.12.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.18.5)
# Requirement already satisfied, skipping upgrade: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.4.1)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)
# Requirement already satisfied: tensorflow-gpu==2.1.0rc0 in /usr/local/lib/python3.6/dist-packages (2.1.0rc0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.12.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (3.2.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.1.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (3.10.0)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.2.2)
# Requirement already satisfied: tensorboard<2.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (2.0.2)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.8.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.12.1)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.0.8)
# Requirement already satisfied: tensorflow-estimator<2.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (2.0.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.9.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.18.5)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.34.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.29.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorflow-gpu==2.1.0rc0) (47.1.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.2.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.7.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==2.1.0rc0) (2.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.24.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.6.0)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.2.8)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.0)

# %%
import math
import random
import keras
from keras.layers import *
from keras.models import Sequential
from keras import Model
from keras import backend as K  
from keras.regularizers import l2
from keras.callbacks import EarlyStopping,ModelCheckpoint

from sklearn.model_selection import LeaveOneOut
from sklearn import metrics
# Out:
# Using TensorFlow backend.

# %%
def get_conv_block(input_layer,nFilters,size):
    conv1 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(input_layer)
    bn1 = BatchNormalization()(conv1)
    conv2 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(bn1)
    bn2 = BatchNormalization()(conv2)
    return bn2
    
def get_UNET(input_layer,nFilters,flag): 

    block1 = get_conv_block(input_layer[0],nFilters,3)
    mp1 = MaxPooling2D(pool_size=(2, 2))(block1)
    dr1 = Dropout(0.1)(mp1)
   
    if(flag==1):
      dr1 = concatenate([dr1,input_layer[1]])

    block2 = get_conv_block(dr1,nFilters*2,3)
    mp2 = MaxPooling2D(pool_size=(2, 2))(block2)
    dr2 = Dropout(0.1)(mp2)

    if(flag==1):
      dr2 = concatenate([dr2,input_layer[2]])
   
    block3 = get_conv_block(dr2,nFilters*4,3)
    mp3 = MaxPooling2D(pool_size=(2, 2))(block3)
    dr3 = Dropout(0.1)(mp3)

    if(flag==1):
      dr3 = concatenate([dr3,input_layer[3]])
       
    block4 = get_conv_block(dr3,nFilters*8,3)
    mp4 = MaxPooling2D(pool_size=(2, 2))(block4)
    dr4 = Dropout(0.1)(mp4)

    conv5 = Conv2D(nFilters*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(dr4)
    conv5 = Conv2D(nFilters*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(conv5)

    up1 = Conv2DTranspose(nFilters*8,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(conv5)
    cat1 = concatenate([block4, up1, mp3])
    dr1 = Dropout(0.1)(cat1)
    block5 = get_conv_block(dr1,nFilters*8,3)

    up2 = Conv2DTranspose(nFilters*4,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block5)
    b4_upsample = Conv2DTranspose(nFilters*4,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block4)
    cat2 = concatenate([block3, up2, b4_upsample, mp2])
    dr2 = Dropout(0.1)(cat2)
    block6 = get_conv_block(dr2,nFilters*4,3)
    
    up3 = Conv2DTranspose(nFilters*2,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block6)
    b3_upsample = Conv2DTranspose(nFilters*2,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block3)
    cat3 = concatenate([block2, up3, mp1, b3_upsample])
    dr3 = Dropout(0.1)(cat3)
    block7 = get_conv_block(dr3,nFilters*2,3)
    
    up4 = Conv2DTranspose(nFilters,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block7)
    b2_upsample = Conv2DTranspose(nFilters,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block2)
    cat4 = concatenate([block1, up4, b2_upsample])
    dr4 = Dropout(0.1)(cat4)
    block8 = get_conv_block(dr4,nFilters,3)

    conv10 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(block8)
    conv11 = Conv2D(4,(1,1), activation='softmax', padding = 'same',kernel_regularizer=l2(1e-4))(conv10)

    return (conv11, block7, block6, block5)

def get_model(input_shape,nFilters1,nFilters2):

    input_layer = Input(shape=input_shape)
    out1,out2,out3,out4 = get_UNET([input_layer],nFilters1,0)

    out1,out2,out3,out4 = get_UNET([out1,out2,out3,out4],nFilters2,1)

    model = Model(input_layer,out1)
    return model

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/4 Class ER"

# Loading the data patient wise
X1 = np.load(PATH + '/ER IHC 230 Images.npy')
Y1 = np.load(PATH + '/ER IHC 230 Masks.npy')

X2 = np.load(PATH + '/ER IHC 232 Images.npy')
Y2 = np.load(PATH + '/ER IHC 232 Masks.npy')

X3 = np.load(PATH + '/ER IHC 242 Images.npy')
Y3 = np.load(PATH + '/ER IHC 242 Masks.npy')

X4 = np.load(PATH + '/ER IHC 263 Images.npy')
Y4 = np.load(PATH + '/ER IHC 263 Masks.npy')

X5 = np.load(PATH + '/ER IHC 221 Images.npy')
Y5 = np.load(PATH + '/ER IHC 221 Masks.npy')

X6 = np.load(PATH + '/ER IHC 229 Images.npy')
Y6 = np.load(PATH + '/ER IHC 229 Masks.npy')

X7 = np.load(PATH + '/ER IHC 239 Images.npy')
Y7 = np.load(PATH + '/ER IHC 239 Masks.npy')

X8 = np.load(PATH + '/ER IHC 246 Images.npy')
Y8 = np.load(PATH + '/ER IHC 246 Masks.npy')

X9 = np.load(PATH + '/ER IHC 252 Images.npy')
Y9 = np.load(PATH + '/ER IHC 252 Masks.npy')

# %%
X = [X1, X2, X3, X4, X5, X6, X7, X8, X9]
Y = [Y1, Y2, Y3, Y4, Y5, Y6, Y7, Y8, Y9]
patient_no = ['230','232','242','263','221','229','239','246','252']
size = [10,10,10,10,10,10,10,10,10]

# %%
fold_split = []

#test patient = 230, 232 
fold_split.append(([2,3,4,5,6,7,8],[0,1]))

# #test_patient = 239, 242
# fold_split.append(([0,1,3,4,5,7,8],[2,6]))

# #test_patient = 252,263
# fold_split.append(([0,1,2,4,5,6,7],[3,8]))

# %%
def convertToLabels(data):
  data[data==85]=1
  data[data==170]=2
  data[data==255]=3

def convertFromLabels(data):
  data[data==1]=85
  data[data==2]=170
  data[data==3]=255

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
# def tversky_loss(y_true, y_pred):
#     alpha = 0.5
#     beta  = 0.5
    
#     ones = K.ones(K.shape(y_true))
#     p0 = y_pred      # proba that voxels are class i
#     p1 = ones-y_pred # proba that voxels are not class i
#     g0 = y_true
#     g1 = ones-y_true
    
#     num = K.sum(p0*g0, (0,1,2))
#     den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
#     # 
#     T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
#     Ncl = K.cast(K.shape(y_true)[-1], 'float32')
#     return Ncl-T

# def combined_loss(y_true, y_pred):
#   return (0.2*K.categorical_crossentropy(y_true, y_pred))+(0.8*tversky_loss(y_true, y_pred))

# %%
def tversky_loss(y_true, y_pred):
    alpha = 0.3
    beta  = 0.7
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    # 
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def focal_tversky_loss(y_true, y_pred, gamma=0.75):
    tversky_index = tversky_loss(y_true, y_pred)
    return K.pow((tversky_index), gamma)

def combined_loss(y_true, y_pred):
  return (0.2*K.categorical_crossentropy(y_true, y_pred))+(0.8*focal_tversky_loss(y_true, y_pred))

# %%
batch_size = 8
def get_batch(batch_size, X_train, Y_train): 
    size_batch = batch_size
    last_index = len(X_train) - 1
    x_train = X_train
    y_train = Y_train 
    while True:
        batch_data = [[],[]]
        for i in range(0, size_batch):
            random_index = random.randint(0, last_index)
            batch_data[0].append(x_train[random_index])
            batch_data[1].append(y_train[random_index])

        yield (np.array(batch_data[0]), np.array(batch_data[1]))

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER/3Fold LadderNet"

fold=0

for train_index, test_index in fold_split:
  print("TRAIN:", train_index, "TEST:", test_index)
  
  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  Train = list(zip(TrainX,TrainY))
  random.shuffle(Train)
  TrainX,TrainY = zip(*Train)
  TrainX = np.asarray(list(TrainX))
  TrainY = np.asarray(list(TrainY))

  Test = list(zip(TestX,TestY))
  random.shuffle(Test)
  TestX,TestY = zip(*Test)
  TestX = np.asarray(list(TestX))
  TestY = np.asarray(list(TestY))

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255
  convertToLabels(TrainY)
  TrainY = keras.utils.to_categorical(TrainY,num_classes=4,dtype='int16')
  convertToLabels(TestY)
  TestY = keras.utils.to_categorical(TestY,num_classes=4,dtype='int16')
  ValX = TrainX[(int)(0.8*TrainX.shape[0]):]
  ValY = TrainY[(int)(0.8*TrainY.shape[0]):]
  model = get_model((240,240,3),32,64)

  #es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
  mc = ModelCheckpoint('Checkpoint.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

  optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=0.001, decay=0.0, amsgrad=True)

  model.compile(loss=combined_loss, optimizer= optimizer , metrics=[dice_coef,'accuracy']) 
  num_epoch = 100
  datagen = get_batch(batch_size, TrainX, TrainY)
  n_points = len(TrainX)
  print('-----------fold {}--------------'.format(fold))
  history = model.fit(datagen, validation_data = [ValX, ValY],
                  epochs=num_epoch,steps_per_epoch = math.ceil(n_points / batch_size), callbacks =[mc],  shuffle =True)
  model.save(MODELS_PATH + '/FoC_TVCombined_LadderNet_ER_v3_'+ str(fold) +'.h5')
  fold = fold + 1
# Out:
# TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1]
# -----------fold 0--------------
# Epoch 1/100
# 420/420 [==============================] - 328s 780ms/step - loss: 3.9027 - dice_coef: 0.3412 - accuracy: 0.8693 - val_loss: 3.8085 - val_dice_coef: 0.4110 - val_accuracy: 0.9231
#
# Epoch 00001: val_loss improved from inf to 3.80850, saving model to Checkpoint.h5
# Epoch 2/100
# 420/420 [==============================] - 311s 741ms/step - loss: 3.5285 - dice_coef: 0.5242 - accuracy: 0.9551 - val_loss: 3.3417 - val_dice_coef: 0.6113 - val_accuracy: 0.9583
#
# Epoch 00002: val_loss improved from 3.80850 to 3.34170, saving model to Checkpoint.h5
# Epoch 3/100
# 420/420 [==============================] - 311s 741ms/step - loss: 3.1931 - dice_coef: 0.6761 - accuracy: 0.9568 - val_loss: 3.0327 - val_dice_coef: 0.7366 - val_accuracy: 0.9576
#
# Epoch 00003: val_loss improved from 3.34170 to 3.03274, saving model to Checkpoint.h5
# Epoch 4/100
# 420/420 [==============================] - 311s 741ms/step - loss: 2.9072 - dice_coef: 0.7754 - accuracy: 0.9565 - val_loss: 2.8151 - val_dice_coef: 0.8037 - val_accuracy: 0.9430
#
# Epoch 00004: val_loss improved from 3.03274 to 2.81512, saving model to Checkpoint.h5
# Epoch 5/100
# 420/420 [==============================] - 311s 740ms/step - loss: 2.5941 - dice_coef: 0.8448 - accuracy: 0.9565 - val_loss: 2.4970 - val_dice_coef: 0.8636 - val_accuracy: 0.9486
#
# Epoch 00005: val_loss improved from 2.81512 to 2.49702, saving model to Checkpoint.h5
# Epoch 6/100
# 420/420 [==============================] - 311s 740ms/step - loss: 2.3971 - dice_coef: 0.8849 - accuracy: 0.9572 - val_loss: 2.2974 - val_dice_coef: 0.8983 - val_accuracy: 0.9575
#
# Epoch 00006: val_loss improved from 2.49702 to 2.29737, saving model to Checkpoint.h5
# Epoch 7/100
# 420/420 [==============================] - 311s 740ms/step - loss: 2.2161 - dice_coef: 0.9108 - accuracy: 0.9622 - val_loss: 2.1728 - val_dice_coef: 0.9181 - val_accuracy: 0.9618
#
# Epoch 00007: val_loss improved from 2.29737 to 2.17281, saving model to Checkpoint.h5
# Epoch 8/100
# 420/420 [==============================] - 311s 740ms/step - loss: 2.0804 - dice_coef: 0.9216 - accuracy: 0.9604 - val_loss: 2.0389 - val_dice_coef: 0.9246 - val_accuracy: 0.9587
#
# Epoch 00008: val_loss improved from 2.17281 to 2.03892, saving model to Checkpoint.h5
# Epoch 9/100
# 420/420 [==============================] - 311s 740ms/step - loss: 1.9547 - dice_coef: 0.9280 - accuracy: 0.9592 - val_loss: 1.9811 - val_dice_coef: 0.9155 - val_accuracy: 0.9460
#
# Epoch 00009: val_loss improved from 2.03892 to 1.98109, saving model to Checkpoint.h5
# Epoch 10/100
# 420/420 [==============================] - 311s 740ms/step - loss: 1.8776 - dice_coef: 0.9315 - accuracy: 0.9581 - val_loss: 1.8225 - val_dice_coef: 0.9356 - val_accuracy: 0.9588
#
# Epoch 00010: val_loss improved from 1.98109 to 1.82251, saving model to Checkpoint.h5
# Epoch 11/100
# 420/420 [==============================] - 311s 740ms/step - loss: 1.8127 - dice_coef: 0.9361 - accuracy: 0.9588 - val_loss: 1.7395 - val_dice_coef: 0.9410 - val_accuracy: 0.9636
#
# Epoch 00011: val_loss improved from 1.82251 to 1.73947, saving model to Checkpoint.h5
# Epoch 12/100
# 420/420 [==============================] - 311s 740ms/step - loss: 1.7190 - dice_coef: 0.9363 - accuracy: 0.9563 - val_loss: 1.6825 - val_dice_coef: 0.9480 - val_accuracy: 0.9655
#
# Epoch 00012: val_loss improved from 1.73947 to 1.68254, saving model to Checkpoint.h5
# Epoch 13/100
# 420/420 [==============================] - 311s 740ms/step - loss: 1.6775 - dice_coef: 0.9420 - accuracy: 0.9598 - val_loss: 1.6586 - val_dice_coef: 0.9413 - val_accuracy: 0.9563
#
# Epoch 00013: val_loss improved from 1.68254 to 1.65859, saving model to Checkpoint.h5
# Epoch 14/100
# 420/420 [==============================] - 311s 740ms/step - loss: 1.6064 - dice_coef: 0.9416 - accuracy: 0.9574 - val_loss: 1.5983 - val_dice_coef: 0.9446 - val_accuracy: 0.9585
#
# Epoch 00014: val_loss improved from 1.65859 to 1.59826, saving model to Checkpoint.h5
# Epoch 15/100
# 420/420 [==============================] - 311s 740ms/step - loss: 1.5875 - dice_coef: 0.9407 - accuracy: 0.9541 - val_loss: 1.5563 - val_dice_coef: 0.9505 - val_accuracy: 0.9626
#
# Epoch 00015: val_loss improved from 1.59826 to 1.55634, saving model to Checkpoint.h5
# Epoch 16/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.5299 - dice_coef: 0.9453 - accuracy: 0.9568 - val_loss: 1.5195 - val_dice_coef: 0.9340 - val_accuracy: 0.9459
#
# Epoch 00016: val_loss improved from 1.55634 to 1.51951, saving model to Checkpoint.h5
# Epoch 17/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.5025 - dice_coef: 0.9445 - accuracy: 0.9544 - val_loss: 1.7321 - val_dice_coef: 0.8458 - val_accuracy: 0.8522
#
# Epoch 00017: val_loss did not improve from 1.51951
# Epoch 18/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.4369 - dice_coef: 0.9462 - accuracy: 0.9550 - val_loss: 1.4833 - val_dice_coef: 0.9521 - val_accuracy: 0.9601
#
# Epoch 00018: val_loss improved from 1.51951 to 1.48333, saving model to Checkpoint.h5
# Epoch 19/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.4769 - dice_coef: 0.9435 - accuracy: 0.9513 - val_loss: 1.4266 - val_dice_coef: 0.9488 - val_accuracy: 0.9559
#
# Epoch 00019: val_loss improved from 1.48333 to 1.42655, saving model to Checkpoint.h5
# Epoch 20/100
# 420/420 [==============================] - 311s 740ms/step - loss: 1.4333 - dice_coef: 0.9464 - accuracy: 0.9537 - val_loss: 1.5105 - val_dice_coef: 0.9107 - val_accuracy: 0.9173
#
# Epoch 00020: val_loss did not improve from 1.42655
# Epoch 21/100
# 420/420 [==============================] - 311s 740ms/step - loss: 1.3926 - dice_coef: 0.9462 - accuracy: 0.9528 - val_loss: 1.4256 - val_dice_coef: 0.9487 - val_accuracy: 0.9553
#
# Epoch 00021: val_loss improved from 1.42655 to 1.42555, saving model to Checkpoint.h5
# Epoch 22/100
# 420/420 [==============================] - 311s 740ms/step - loss: 1.3902 - dice_coef: 0.9491 - accuracy: 0.9551 - val_loss: 1.3907 - val_dice_coef: 0.9452 - val_accuracy: 0.9520
#
# Epoch 00022: val_loss improved from 1.42555 to 1.39072, saving model to Checkpoint.h5
# Epoch 23/100
# 420/420 [==============================] - 311s 740ms/step - loss: 1.3517 - dice_coef: 0.9488 - accuracy: 0.9544 - val_loss: 1.4287 - val_dice_coef: 0.9403 - val_accuracy: 0.9449
#
# Epoch 00023: val_loss did not improve from 1.39072
# Epoch 24/100
# 420/420 [==============================] - 311s 740ms/step - loss: 1.3680 - dice_coef: 0.9511 - accuracy: 0.9561 - val_loss: 1.3712 - val_dice_coef: 0.9474 - val_accuracy: 0.9520
#
# Epoch 00024: val_loss improved from 1.39072 to 1.37123, saving model to Checkpoint.h5
# Epoch 25/100
# 420/420 [==============================] - 311s 739ms/step - loss: 1.3643 - dice_coef: 0.9500 - accuracy: 0.9548 - val_loss: 1.5500 - val_dice_coef: 0.9350 - val_accuracy: 0.9384
#
# Epoch 00025: val_loss did not improve from 1.37123
# Epoch 26/100
# 420/420 [==============================] - 311s 740ms/step - loss: 1.3345 - dice_coef: 0.9517 - accuracy: 0.9561 - val_loss: 1.3540 - val_dice_coef: 0.9452 - val_accuracy: 0.9493
#
# Epoch 00026: val_loss improved from 1.37123 to 1.35397, saving model to Checkpoint.h5
# Epoch 27/100
# 420/420 [==============================] - 311s 740ms/step - loss: 1.3882 - dice_coef: 0.9473 - accuracy: 0.9519 - val_loss: 1.4703 - val_dice_coef: 0.9002 - val_accuracy: 0.9182
#
# Epoch 00027: val_loss did not improve from 1.35397
# Epoch 28/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.4079 - dice_coef: 0.9489 - accuracy: 0.9531 - val_loss: 1.3864 - val_dice_coef: 0.9471 - val_accuracy: 0.9508
#
# Epoch 00028: val_loss did not improve from 1.35397
# Epoch 29/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.3911 - dice_coef: 0.9516 - accuracy: 0.9558 - val_loss: 1.3549 - val_dice_coef: 0.9502 - val_accuracy: 0.9542
#
# Epoch 00029: val_loss did not improve from 1.35397
# Epoch 30/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.3432 - dice_coef: 0.9498 - accuracy: 0.9535 - val_loss: 1.3444 - val_dice_coef: 0.9575 - val_accuracy: 0.9612
#
# Epoch 00030: val_loss improved from 1.35397 to 1.34437, saving model to Checkpoint.h5
# Epoch 31/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.3545 - dice_coef: 0.9496 - accuracy: 0.9533 - val_loss: 1.3378 - val_dice_coef: 0.9553 - val_accuracy: 0.9586
#
# Epoch 00031: val_loss improved from 1.34437 to 1.33785, saving model to Checkpoint.h5
# Epoch 32/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.3142 - dice_coef: 0.9498 - accuracy: 0.9534 - val_loss: 1.3212 - val_dice_coef: 0.9481 - val_accuracy: 0.9515
#
# Epoch 00032: val_loss improved from 1.33785 to 1.32124, saving model to Checkpoint.h5
# Epoch 33/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.3364 - dice_coef: 0.9524 - accuracy: 0.9558 - val_loss: 1.3162 - val_dice_coef: 0.9501 - val_accuracy: 0.9547
#
# Epoch 00033: val_loss improved from 1.32124 to 1.31616, saving model to Checkpoint.h5
# Epoch 34/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.3099 - dice_coef: 0.9531 - accuracy: 0.9563 - val_loss: 1.3854 - val_dice_coef: 0.9494 - val_accuracy: 0.9540
#
# Epoch 00034: val_loss did not improve from 1.31616
# Epoch 35/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.3102 - dice_coef: 0.9523 - accuracy: 0.9553 - val_loss: 1.6780 - val_dice_coef: 0.7261 - val_accuracy: 0.7237
#
# Epoch 00035: val_loss did not improve from 1.31616
# Epoch 36/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.3032 - dice_coef: 0.9525 - accuracy: 0.9555 - val_loss: 1.2991 - val_dice_coef: 0.9533 - val_accuracy: 0.9559
#
# Epoch 00036: val_loss improved from 1.31616 to 1.29905, saving model to Checkpoint.h5
# Epoch 37/100
# 420/420 [==============================] - 311s 739ms/step - loss: 1.2975 - dice_coef: 0.9513 - accuracy: 0.9542 - val_loss: 1.3688 - val_dice_coef: 0.9271 - val_accuracy: 0.9322
#
# Epoch 00037: val_loss did not improve from 1.29905
# Epoch 38/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2853 - dice_coef: 0.9503 - accuracy: 0.9531 - val_loss: 1.2832 - val_dice_coef: 0.9589 - val_accuracy: 0.9617
#
# Epoch 00038: val_loss improved from 1.29905 to 1.28324, saving model to Checkpoint.h5
# Epoch 39/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.3090 - dice_coef: 0.9553 - accuracy: 0.9579 - val_loss: 1.2820 - val_dice_coef: 0.9542 - val_accuracy: 0.9573
#
# Epoch 00039: val_loss improved from 1.28324 to 1.28202, saving model to Checkpoint.h5
# Epoch 40/100
# 420/420 [==============================] - 311s 739ms/step - loss: 1.2861 - dice_coef: 0.9572 - accuracy: 0.9598 - val_loss: 1.3588 - val_dice_coef: 0.9516 - val_accuracy: 0.9537
#
# Epoch 00040: val_loss did not improve from 1.28202
# Epoch 41/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2930 - dice_coef: 0.9549 - accuracy: 0.9575 - val_loss: 1.3281 - val_dice_coef: 0.9497 - val_accuracy: 0.9525
#
# Epoch 00041: val_loss did not improve from 1.28202
# Epoch 42/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2924 - dice_coef: 0.9569 - accuracy: 0.9594 - val_loss: 1.2860 - val_dice_coef: 0.9570 - val_accuracy: 0.9593
#
# Epoch 00042: val_loss did not improve from 1.28202
# Epoch 43/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2758 - dice_coef: 0.9554 - accuracy: 0.9578 - val_loss: 1.2978 - val_dice_coef: 0.9490 - val_accuracy: 0.9508
#
# Epoch 00043: val_loss did not improve from 1.28202
# Epoch 44/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.2735 - dice_coef: 0.9545 - accuracy: 0.9568 - val_loss: 1.2553 - val_dice_coef: 0.9544 - val_accuracy: 0.9567
#
# Epoch 00044: val_loss improved from 1.28202 to 1.25532, saving model to Checkpoint.h5
# Epoch 45/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.3059 - dice_coef: 0.9600 - accuracy: 0.9623 - val_loss: 1.3018 - val_dice_coef: 0.9577 - val_accuracy: 0.9598
#
# Epoch 00045: val_loss did not improve from 1.25532
# Epoch 46/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2974 - dice_coef: 0.9539 - accuracy: 0.9563 - val_loss: 1.2992 - val_dice_coef: 0.9594 - val_accuracy: 0.9617
#
# Epoch 00046: val_loss did not improve from 1.25532
# Epoch 47/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2857 - dice_coef: 0.9555 - accuracy: 0.9576 - val_loss: 1.2859 - val_dice_coef: 0.9568 - val_accuracy: 0.9589
#
# Epoch 00047: val_loss did not improve from 1.25532
# Epoch 48/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.2821 - dice_coef: 0.9532 - accuracy: 0.9553 - val_loss: 1.3101 - val_dice_coef: 0.9584 - val_accuracy: 0.9604
#
# Epoch 00048: val_loss did not improve from 1.25532
# Epoch 49/100
# 420/420 [==============================] - 311s 739ms/step - loss: 1.2642 - dice_coef: 0.9569 - accuracy: 0.9590 - val_loss: 1.2560 - val_dice_coef: 0.9606 - val_accuracy: 0.9625
#
# Epoch 00049: val_loss did not improve from 1.25532
# Epoch 50/100
# 420/420 [==============================] - 311s 740ms/step - loss: 1.2656 - dice_coef: 0.9570 - accuracy: 0.9592 - val_loss: 1.2797 - val_dice_coef: 0.9544 - val_accuracy: 0.9568
#
# Epoch 00050: val_loss did not improve from 1.25532
# Epoch 51/100
# 420/420 [==============================] - 311s 740ms/step - loss: 1.2701 - dice_coef: 0.9586 - accuracy: 0.9606 - val_loss: 1.2803 - val_dice_coef: 0.9528 - val_accuracy: 0.9553
#
# Epoch 00051: val_loss did not improve from 1.25532
# Epoch 52/100
# 420/420 [==============================] - 311s 739ms/step - loss: 1.2748 - dice_coef: 0.9563 - accuracy: 0.9583 - val_loss: 1.3274 - val_dice_coef: 0.9601 - val_accuracy: 0.9622
#
# Epoch 00052: val_loss did not improve from 1.25532
# Epoch 53/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2793 - dice_coef: 0.9548 - accuracy: 0.9569 - val_loss: 1.2880 - val_dice_coef: 0.9605 - val_accuracy: 0.9624
#
# Epoch 00053: val_loss did not improve from 1.25532
# Epoch 54/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2601 - dice_coef: 0.9570 - accuracy: 0.9589 - val_loss: 1.2951 - val_dice_coef: 0.9535 - val_accuracy: 0.9553
#
# Epoch 00054: val_loss did not improve from 1.25532
# Epoch 55/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2611 - dice_coef: 0.9566 - accuracy: 0.9585 - val_loss: 1.2861 - val_dice_coef: 0.9489 - val_accuracy: 0.9508
#
# Epoch 00055: val_loss did not improve from 1.25532
# Epoch 56/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.3058 - dice_coef: 0.9576 - accuracy: 0.9595 - val_loss: 1.2853 - val_dice_coef: 0.9586 - val_accuracy: 0.9602
#
# Epoch 00056: val_loss did not improve from 1.25532
# Epoch 57/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.3111 - dice_coef: 0.9594 - accuracy: 0.9612 - val_loss: 1.2686 - val_dice_coef: 0.9546 - val_accuracy: 0.9563
#
# Epoch 00057: val_loss did not improve from 1.25532
# Epoch 58/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.2631 - dice_coef: 0.9533 - accuracy: 0.9552 - val_loss: 1.2907 - val_dice_coef: 0.9596 - val_accuracy: 0.9617
#
# Epoch 00058: val_loss did not improve from 1.25532
# Epoch 59/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.3151 - dice_coef: 0.9546 - accuracy: 0.9563 - val_loss: 1.3166 - val_dice_coef: 0.9517 - val_accuracy: 0.9532
#
# Epoch 00059: val_loss did not improve from 1.25532
# Epoch 60/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2837 - dice_coef: 0.9519 - accuracy: 0.9537 - val_loss: 1.4147 - val_dice_coef: 0.9508 - val_accuracy: 0.9522
#
# Epoch 00060: val_loss did not improve from 1.25532
# Epoch 61/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2590 - dice_coef: 0.9559 - accuracy: 0.9577 - val_loss: 1.2420 - val_dice_coef: 0.9553 - val_accuracy: 0.9566
#
# Epoch 00061: val_loss improved from 1.25532 to 1.24196, saving model to Checkpoint.h5
# Epoch 62/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2446 - dice_coef: 0.9548 - accuracy: 0.9565 - val_loss: 1.3445 - val_dice_coef: 0.9518 - val_accuracy: 0.9531
#
# Epoch 00062: val_loss did not improve from 1.24196
# Epoch 63/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2881 - dice_coef: 0.9553 - accuracy: 0.9571 - val_loss: 1.2667 - val_dice_coef: 0.9611 - val_accuracy: 0.9626
#
# Epoch 00063: val_loss did not improve from 1.24196
# Epoch 64/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2986 - dice_coef: 0.9579 - accuracy: 0.9595 - val_loss: 1.2911 - val_dice_coef: 0.9581 - val_accuracy: 0.9604
#
# Epoch 00064: val_loss did not improve from 1.24196
# Epoch 65/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2743 - dice_coef: 0.9548 - accuracy: 0.9566 - val_loss: 1.3076 - val_dice_coef: 0.9581 - val_accuracy: 0.9595
#
# Epoch 00065: val_loss did not improve from 1.24196
# Epoch 66/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2580 - dice_coef: 0.9540 - accuracy: 0.9557 - val_loss: 1.3084 - val_dice_coef: 0.9507 - val_accuracy: 0.9520
#
# Epoch 00066: val_loss did not improve from 1.24196
# Epoch 67/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2502 - dice_coef: 0.9547 - accuracy: 0.9563 - val_loss: 1.3423 - val_dice_coef: 0.9622 - val_accuracy: 0.9646
#
# Epoch 00067: val_loss did not improve from 1.24196
# Epoch 68/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2875 - dice_coef: 0.9545 - accuracy: 0.9562 - val_loss: 1.3179 - val_dice_coef: 0.9512 - val_accuracy: 0.9525
#
# Epoch 00068: val_loss did not improve from 1.24196
# Epoch 69/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2881 - dice_coef: 0.9553 - accuracy: 0.9569 - val_loss: 1.3147 - val_dice_coef: 0.9458 - val_accuracy: 0.9475
#
# Epoch 00069: val_loss did not improve from 1.24196
# Epoch 70/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2939 - dice_coef: 0.9586 - accuracy: 0.9601 - val_loss: 1.3449 - val_dice_coef: 0.9529 - val_accuracy: 0.9542
#
# Epoch 00070: val_loss did not improve from 1.24196
# Epoch 71/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.2538 - dice_coef: 0.9572 - accuracy: 0.9588 - val_loss: 1.3271 - val_dice_coef: 0.9597 - val_accuracy: 0.9612
#
# Epoch 00071: val_loss did not improve from 1.24196
# Epoch 72/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2847 - dice_coef: 0.9532 - accuracy: 0.9548 - val_loss: 1.3627 - val_dice_coef: 0.9506 - val_accuracy: 0.9520
#
# Epoch 00072: val_loss did not improve from 1.24196
# Epoch 73/100
# 420/420 [==============================] - 311s 740ms/step - loss: 1.2778 - dice_coef: 0.9565 - accuracy: 0.9581 - val_loss: 1.2824 - val_dice_coef: 0.9573 - val_accuracy: 0.9590
#
# Epoch 00073: val_loss did not improve from 1.24196
# Epoch 74/100
# 420/420 [==============================] - 311s 740ms/step - loss: 1.3156 - dice_coef: 0.9517 - accuracy: 0.9534 - val_loss: 1.3077 - val_dice_coef: 0.9549 - val_accuracy: 0.9564
#
# Epoch 00074: val_loss did not improve from 1.24196
# Epoch 75/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.3135 - dice_coef: 0.9553 - accuracy: 0.9570 - val_loss: 1.2747 - val_dice_coef: 0.9535 - val_accuracy: 0.9558
#
# Epoch 00075: val_loss did not improve from 1.24196
# Epoch 76/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2848 - dice_coef: 0.9544 - accuracy: 0.9559 - val_loss: 1.3367 - val_dice_coef: 0.9475 - val_accuracy: 0.9507
#
# Epoch 00076: val_loss did not improve from 1.24196
# Epoch 77/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.3230 - dice_coef: 0.9540 - accuracy: 0.9558 - val_loss: 1.3443 - val_dice_coef: 0.9563 - val_accuracy: 0.9574
#
# Epoch 00077: val_loss did not improve from 1.24196
# Epoch 78/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.2766 - dice_coef: 0.9574 - accuracy: 0.9591 - val_loss: 1.6514 - val_dice_coef: 0.9365 - val_accuracy: 0.9376
#
# Epoch 00078: val_loss did not improve from 1.24196
# Epoch 79/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.2680 - dice_coef: 0.9549 - accuracy: 0.9564 - val_loss: 1.3308 - val_dice_coef: 0.9601 - val_accuracy: 0.9618
#
# Epoch 00079: val_loss did not improve from 1.24196
# Epoch 80/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.2870 - dice_coef: 0.9527 - accuracy: 0.9542 - val_loss: 1.2785 - val_dice_coef: 0.9570 - val_accuracy: 0.9588
#
# Epoch 00080: val_loss did not improve from 1.24196
# Epoch 81/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.2885 - dice_coef: 0.9580 - accuracy: 0.9596 - val_loss: 1.2557 - val_dice_coef: 0.9585 - val_accuracy: 0.9599
#
# Epoch 00081: val_loss did not improve from 1.24196
# Epoch 82/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.2602 - dice_coef: 0.9552 - accuracy: 0.9569 - val_loss: 1.3054 - val_dice_coef: 0.9604 - val_accuracy: 0.9617
#
# Epoch 00082: val_loss did not improve from 1.24196
# Epoch 83/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.2950 - dice_coef: 0.9556 - accuracy: 0.9571 - val_loss: 1.3865 - val_dice_coef: 0.9571 - val_accuracy: 0.9585
#
# Epoch 00083: val_loss did not improve from 1.24196
# Epoch 84/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.3168 - dice_coef: 0.9547 - accuracy: 0.9562 - val_loss: 1.3166 - val_dice_coef: 0.9600 - val_accuracy: 0.9614
#
# Epoch 00084: val_loss did not improve from 1.24196
# Epoch 85/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.2949 - dice_coef: 0.9559 - accuracy: 0.9574 - val_loss: 1.3508 - val_dice_coef: 0.9604 - val_accuracy: 0.9617
#
# Epoch 00085: val_loss did not improve from 1.24196
# Epoch 86/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.2756 - dice_coef: 0.9586 - accuracy: 0.9600 - val_loss: 1.3210 - val_dice_coef: 0.9484 - val_accuracy: 0.9496
#
# Epoch 00086: val_loss did not improve from 1.24196
# Epoch 87/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.2827 - dice_coef: 0.9552 - accuracy: 0.9567 - val_loss: 1.2986 - val_dice_coef: 0.9521 - val_accuracy: 0.9537
#
# Epoch 00087: val_loss did not improve from 1.24196
# Epoch 88/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.3088 - dice_coef: 0.9535 - accuracy: 0.9550 - val_loss: 1.4735 - val_dice_coef: 0.9394 - val_accuracy: 0.9405
#
# Epoch 00088: val_loss did not improve from 1.24196
# Epoch 89/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.2904 - dice_coef: 0.9528 - accuracy: 0.9543 - val_loss: 1.2651 - val_dice_coef: 0.9613 - val_accuracy: 0.9624
#
# Epoch 00089: val_loss did not improve from 1.24196
# Epoch 90/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.3026 - dice_coef: 0.9546 - accuracy: 0.9561 - val_loss: 1.3034 - val_dice_coef: 0.9556 - val_accuracy: 0.9571
#
# Epoch 00090: val_loss did not improve from 1.24196
# Epoch 91/100
# 420/420 [==============================] - 311s 739ms/step - loss: 1.3147 - dice_coef: 0.9545 - accuracy: 0.9561 - val_loss: 1.3037 - val_dice_coef: 0.9490 - val_accuracy: 0.9502
#
# Epoch 00091: val_loss did not improve from 1.24196
# Epoch 92/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.3458 - dice_coef: 0.9559 - accuracy: 0.9572 - val_loss: 1.2844 - val_dice_coef: 0.9550 - val_accuracy: 0.9563
#
# Epoch 00092: val_loss did not improve from 1.24196
# Epoch 93/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2760 - dice_coef: 0.9549 - accuracy: 0.9563 - val_loss: 1.3269 - val_dice_coef: 0.9537 - val_accuracy: 0.9548
#
# Epoch 00093: val_loss did not improve from 1.24196
# Epoch 94/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2910 - dice_coef: 0.9548 - accuracy: 0.9560 - val_loss: 1.2702 - val_dice_coef: 0.9571 - val_accuracy: 0.9583
#
# Epoch 00094: val_loss did not improve from 1.24196
# Epoch 95/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2472 - dice_coef: 0.9557 - accuracy: 0.9571 - val_loss: 1.2803 - val_dice_coef: 0.9605 - val_accuracy: 0.9616
#
# Epoch 00095: val_loss did not improve from 1.24196
# Epoch 96/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.2722 - dice_coef: 0.9549 - accuracy: 0.9563 - val_loss: 1.2834 - val_dice_coef: 0.9565 - val_accuracy: 0.9576
#
# Epoch 00096: val_loss did not improve from 1.24196
# Epoch 97/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.2984 - dice_coef: 0.9571 - accuracy: 0.9585 - val_loss: 1.3087 - val_dice_coef: 0.9492 - val_accuracy: 0.9505
#
# Epoch 00097: val_loss did not improve from 1.24196
# Epoch 98/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.2874 - dice_coef: 0.9537 - accuracy: 0.9550 - val_loss: 1.2675 - val_dice_coef: 0.9572 - val_accuracy: 0.9584
#
# Epoch 00098: val_loss did not improve from 1.24196
# Epoch 99/100
# 420/420 [==============================] - 310s 738ms/step - loss: 1.2697 - dice_coef: 0.9560 - accuracy: 0.9574 - val_loss: 1.2610 - val_dice_coef: 0.9608 - val_accuracy: 0.9622
#
# Epoch 00099: val_loss did not improve from 1.24196
# Epoch 100/100
# 420/420 [==============================] - 310s 739ms/step - loss: 1.2731 - dice_coef: 0.9548 - accuracy: 0.9562 - val_loss: 1.2785 - val_dice_coef: 0.9632 - val_accuracy: 0.9643
#
# Epoch 00100: val_loss did not improve from 1.24196

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask, Patient_array,Patient_length,title,folder):
  idx = 0
  for i in range(len(Patient_length)):
    temp = []
    for j in range(Patient_length[i]):
      final_output = mask[idx:idx+48]
      idx = idx + 48
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save(folder + title + Patient_array[i], final_output)

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER/Combined FTL/"
model_names = os.listdir(MODELS_PATH)
print(model_names)
# Out:
# ['FoC_TVCombined_LadderNet_ER_v3_0.h5']

# %%
SAVE_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/ER/3Fold LadderNet/Combined FTLv2"

# %%
# !ls "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/ER/3Fold LadderNet/Combined FTLv2"
# Out:
# Checkpoint.h5

# %%
# !ls "/content"
# Out:
# Checkpoint.h5  drive  sample_data

# %%
# !mv "Checkpoint.h5" "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/ER/3Fold LadderNet/Combined FTLv2"

# %%
# Axis 0 = Folds
# Axis 1 = Class (Strong Intermediate,Weak,Background)
# Axis 2 = Evaluation Technique (Precision, Recall, Dice coefficient)
pixEvaluationTrain = np.empty((0,4,3))
pixEvaluationTest = np.empty((0,4,3))
score = np.zeros((1,4,3))

# %%
fold = 0

for train_index, test_index in fold_split:
  print("FOLD:",fold,"\tTRAIN:", train_index, "TEST:", test_index)
  # Splitting Train and Test data
  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  train_no = [patient_no[i] for i in train_index]
  train_size = [size[i] for i in train_index]

  test_no = [patient_no[i] for i in test_index]
  test_size = [size[i] for i in test_index]

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255

  convertToLabels(TrainY)
  convertToLabels(TestY)

  # TrainY = keras.utils.to_categorical(TrainY,num_classes=4,dtype='int16')
  # TestY = keras.utils.to_categorical(TestY,num_classes=4,dtype='int16')
  
  # Loading corrosponding fold of model
  model = keras.models.load_model(MODELS_PATH + model_names[fold],custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

  # Predicting results using model
  trainResult = model.predict(TrainX, batch_size=8)
  testResult = model.predict(TestX,batch_size=8)

  trainResult = np.argmax(trainResult,axis=-1)
  testResult = np.argmax(testResult,axis=-1)

  # trainOneHot = keras.utils.to_categorical(trainResult,num_classes=4,dtype='int16')
  # testOneHot = keras.utils.to_categorical(testResult,num_classes=4,dtype='int16')

  # Obtaining pixel-wise results: Precision recall and dice coefficient
  # For TRAIN
  y_true = np.reshape(TrainY,(-1))
  y_pred = np.reshape(trainResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  print('TRAIN')
  print(prec)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  print(recall)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(4):
    score[0][i][0] = prec[3-i]
    score[0][i][1] = recall[3-i]
    score[0][i][2] = dice[3-i]
  print(score)
  pixEvaluationTrain = np.append(pixEvaluationTrain,score,axis=0)
 
  # For TEST
  y_true = np.reshape(TestY,(-1))
  y_pred = np.reshape(testResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  print('TEST')
  print(prec)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  print(recall)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(4):
    score[0][i][0] = prec[3-i]
    score[0][i][1] = recall[3-i]
    score[0][i][2] = dice[3-i]
  print(score)
  pixEvaluationTest = np.append(pixEvaluationTest,score,axis=0)

  # Converting predicted labels to required output format
  convertFromLabels(trainResult)
  convertFromLabels(testResult)

  # Saving numpy arrays
  path = os.path.join(SAVE_PATH,"Fold " + str(fold))
  os.mkdir(path)
  os.mkdir(path + '/Train')
  os.mkdir(path + '/Test')

  saveNumpyOutput(trainResult, train_no, train_size,"/Train/",path)
  saveNumpyOutput(testResult, test_no, test_size,"/Test/",path)

  fold +=1
# Out:
# FOLD: 0 	TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1]
# TRAIN
# [0.99128247 0.35550955 0.5102027  0.77348306]
# [0.98266966 0.33067253 0.65844757 0.80605675]
# [[[0.77348306 0.80605675 0.78943403]
#   [0.5102027  0.65844757 0.5749226 ]
#   [0.35550955 0.33067253 0.34264154]
#   [0.99128247 0.98266966 0.98695728]]]
# TEST
# [0.96788415 0.30431192 0.37780781 0.90925674]
# [0.98915652 0.25230572 0.55879303 0.2414232 ]
# [[[0.90925674 0.2414232  0.38154079]
#   [0.37780781 0.55879303 0.45081397]
#   [0.30431192 0.25230572 0.27587928]
#   [0.96788415 0.98915652 0.97840472]]]
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-47-2bc82661691c> in <module>()
#      82   # Saving numpy arrays
#      83   path = os.path.join(SAVE_PATH,"Fold " + str(fold))
# ---> 84   os.mkdir(path)
#      85   os.mkdir(path + '/Train')
#      86   os.mkdir(path + '/Test')
#
# FileExistsError: [Errno 17] File exists: '/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/ER/3Fold LadderNet/Combined FTLv2/Fold 0'

# %%
prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)

# %%
metrics.classification_report(y_true,y_pred,label)

# %%
print(y_true.shape)
# Out:
# (55296000,)

# %%
prec
# Out:
# array([0.96788415, 1.        , 1.        , 1.        ])

# %%
recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)

# %%
recall

# %%
score
# Out:
# array([[[0.90925674, 0.2414232 , 0.38154079],
#         [0.37780781, 0.55879303, 0.45081397],
#         [0.30431192, 0.25230572, 0.27587928],
#         [0.96788415, 0.98915652, 0.97840472]]])

# %%
print(pixEvaluationTrain.shape)
print(pixEvaluationTest.shape)
print(pixEvaluationTest)
# Out:
# (1, 4, 3)
# (1, 4, 3)
# [[[0.90925674 0.2414232  0.38154079]
#   [0.37780781 0.55879303 0.45081397]
#   [0.30431192 0.25230572 0.27587928]
#   [0.96788415 0.98915652 0.97840472]]]

# %%
np.save(SAVE_PATH + "Pixel-wise Metrics Train.npy", pixEvaluationTrain)
np.save(SAVE_PATH + "Pixel-wise Metrics Test.npy", pixEvaluationTest)

# %% [markdown]
# # **DISPLAY**

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 48   # enter between 0- 50 since there are 5 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]
Mask_input = TestGT[id:id+48]
final_output = testResult[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 25  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]
Mask_input = TrainGT[id:id+48]
final_output = trainResult[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
