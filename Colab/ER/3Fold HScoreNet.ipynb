# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
# !pip install -U keras
# !pip install tensorflow-gpu==2.1.0rc0
# Out:
# Requirement already up-to-date: keras in /usr/local/lib/python3.6/dist-packages (2.3.1)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras) (1.12.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.4.1)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras) (1.0.8)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.18.5)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras) (1.1.2)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.10.0)
# Collecting tensorflow-gpu==2.1.0rc0
#   Downloading https://files.pythonhosted.org/packages/f3/24/f94a1b8f779471f53b814a96c5109994ccf65b0103b771ff208c8a937d37/tensorflow_gpu-2.1.0rc0-cp36-cp36m-manylinux2010_x86_64.whl (402.3MB)
#      |████████████████████████████████| 402.3MB 33kB/s
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.2.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.0.8)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.12.0)
# Collecting tensorflow-estimator<2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/fc/08/8b927337b7019c374719145d1dceba21a8bb909b93b1ad6f8fb7d22c1ca1/tensorflow_estimator-2.0.1-py2.py3-none-any.whl (449kB)
#      |████████████████████████████████| 450kB 65.7MB/s
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.18.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (3.2.1)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.12.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.29.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (3.10.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.34.2)
# Collecting tensorboard<2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/76/54/99b9d5d52d5cb732f099baaaf7740403e83fe6b0cedde940fabd2b13d75a/tensorboard-2.0.2-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 46.3MB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.9.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.8.1)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.1.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==2.1.0rc0) (2.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorflow-gpu==2.1.0rc0) (47.1.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.7.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.4.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2.9)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.1)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.6.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=f36324354a91bd41af85feb94f66e30f9567a83562c2bff80a7785150b0d112f
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 2.2.0 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.2.0 has requirement tensorboard<2.3.0,>=2.2.0, but you'll have tensorboard 2.0.2 which is incompatible.
# ERROR: tensorflow 2.2.0 has requirement tensorflow-estimator<2.3.0,>=2.2.0, but you'll have tensorflow-estimator 2.0.1 which is incompatible.
# ERROR: tensorflow-probability 0.10.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# Installing collected packages: tensorflow-estimator, gast, tensorboard, tensorflow-gpu
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
# Successfully installed gast-0.2.2 tensorboard-2.0.2 tensorflow-estimator-2.0.1 tensorflow-gpu-2.1.0rc0

# %%
import math
import random
import keras
from keras.layers import *
from keras.models import Sequential
from keras import Model
from keras import backend as K  
from keras.regularizers import l2
from keras.callbacks import EarlyStopping,ModelCheckpoint

from sklearn.model_selection import LeaveOneOut
from sklearn import metrics
# Out:
# Using TensorFlow backend.

# %%
def get_conv_block1(input_layer,nFilters,size):
    conv1 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(input_layer)
    conv2 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    bn1 = BatchNormalization()(conv2)
    return bn1

def get_conv_block2(input_layer,nFilters,size):
    conv1 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(input_layer)
    conv2 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv3 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    bn1 = BatchNormalization()(conv3)
    return bn1

def get_model():    
    input_layer = Input(shape=(240,240,3))
    block1 = get_conv_block1(input_layer,64,2)
    dr1 = Dropout(0.1)(block1)
    mp1 = MaxPooling2D(pool_size=(2, 2))(dr1)
    
    block2 = get_conv_block2(mp1,64,2)
    dr2 = Dropout(0.1)(block2)
    mp2 = MaxPooling2D(pool_size=(2, 2))(dr2)
    
    block3 = get_conv_block2(mp2,64,2)
    dr3 = Dropout(0.1)(block3)
    mp3 = MaxPooling2D(pool_size=(2, 2))(dr3)
    
    block4 = get_conv_block1(mp3,64,2)
    dr4 = Dropout(0.1)(block4)
    mp4 = MaxPooling2D(pool_size=(2, 2))(dr4)

    block5 = get_conv_block1(mp4,64,2)
    dr5 = Dropout(0.1)(block5)
       
    up1 = Conv2DTranspose(32,(2,2),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(dr5)
    cat1 = concatenate([block4,up1])
    dr1 = Dropout(0.1)(cat1)
    block5 = get_conv_block2(dr1,64,2)

    up2 = Conv2DTranspose(32,(2,2),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block5)
    cat2 = concatenate([block3,up2])
    dr2 = Dropout(0.1)(cat2)
    block6 = get_conv_block2(dr2,64,2)
    
    up3 = Conv2DTranspose(32,(2,2),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block6)
    cat3 = concatenate([block2,up3])
    dr3 = Dropout(0.1)(cat3)
    block7 = get_conv_block2(dr3,64,2)
    
    up4 = Conv2DTranspose(32,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block7)
    cat4 = concatenate([block1,up4])
    dr4 = Dropout(0.1)(cat4)
    block8 = get_conv_block1(dr4,64,3)

    conv10 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(block8)
    conv11 = Conv2D(4,(1,1), activation='softmax', padding = 'same')(conv10)

    model = Model(input_layer,conv11)
    return model

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/4 Class ER"

# Loading the data patient wise
X1 = np.load(PATH + '/ER IHC 230 Images.npy')
Y1 = np.load(PATH + '/ER IHC 230 Masks.npy')

X2 = np.load(PATH + '/ER IHC 232 Images.npy')
Y2 = np.load(PATH + '/ER IHC 232 Masks.npy')

X3 = np.load(PATH + '/ER IHC 242 Images.npy')
Y3 = np.load(PATH + '/ER IHC 242 Masks.npy')

X4 = np.load(PATH + '/ER IHC 263 Images.npy')
Y4 = np.load(PATH + '/ER IHC 263 Masks.npy')

X5 = np.load(PATH + '/ER IHC 221 Images.npy')
Y5 = np.load(PATH + '/ER IHC 221 Masks.npy')

X6 = np.load(PATH + '/ER IHC 229 Images.npy')
Y6 = np.load(PATH + '/ER IHC 229 Masks.npy')

X7 = np.load(PATH + '/ER IHC 239 Images.npy')
Y7 = np.load(PATH + '/ER IHC 239 Masks.npy')

X8 = np.load(PATH + '/ER IHC 246 Images.npy')
Y8 = np.load(PATH + '/ER IHC 246 Masks.npy')

X9 = np.load(PATH + '/ER IHC 252 Images.npy')
Y9 = np.load(PATH + '/ER IHC 252 Masks.npy')

# %%
X = [X1, X2, X3, X4, X5, X6, X7, X8, X9]
Y = [Y1, Y2, Y3, Y4, Y5, Y6, Y7, Y8, Y9]
patient_no = ['230','232','242','263','221','229','239','246','252']
size = [10,10,10,10,10,10,10,10,10]

# %%
fold_split = []

#test patient = 230, 232 
fold_split.append(([2,3,4,5,6,7,8],[0,1]))

#test_patient = 239, 242
fold_split.append(([0,1,3,4,5,7,8],[2,6]))

#test_patient = 252,263
fold_split.append(([0,1,2,4,5,6,7],[3,8]))

# %%
def convertToLabels(data):
  data[data==85]=1
  data[data==170]=2
  data[data==255]=3

def convertFromLabels(data):
  data[data==1]=85
  data[data==2]=170
  data[data==3]=255

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def combined_loss(y_true, y_pred):
  return (0.2*K.categorical_crossentropy(y_true, y_pred))+(0.8*tversky_loss(y_true, y_pred))

# %%
batch_size = 16
def get_batch(batch_size, X_train, Y_train): 
    size_batch = batch_size
    last_index = len(X_train) - 1
    x_train = X_train
    y_train = Y_train 
    while True:
        batch_data = [[],[]]
        for i in range(0, size_batch):
            random_index = random.randint(0, last_index)
            batch_data[0].append(x_train[random_index])
            batch_data[1].append(y_train[random_index])

        yield (np.array(batch_data[0]), np.array(batch_data[1]))

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER/3Fold HScoreNet"
fold=0

for train_index, test_index in fold_split:
  print("TRAIN:", train_index, "TEST:", test_index)
  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  Train = list(zip(TrainX,TrainY))
  random.shuffle(Train)
  TrainX,TrainY = zip(*Train)
  TrainX = np.asarray(list(TrainX))
  TrainY = np.asarray(list(TrainY))

  Test = list(zip(TestX,TestY))
  random.shuffle(Test)
  TestX,TestY = zip(*Test)
  TestX = np.asarray(list(TestX))
  TestY = np.asarray(list(TestY))

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255
  
  convertToLabels(TrainY)
  TrainY = keras.utils.to_categorical(TrainY,num_classes=4,dtype='int16')
  convertToLabels(TestY)
  TestY = keras.utils.to_categorical(TestY,num_classes=4,dtype='int16')
  ValX = TrainX[(int)(0.8*TrainX.shape[0]):]
  ValY = TrainY[(int)(0.8*TrainY.shape[0]):]
  model = get_model()

  es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
  mc = ModelCheckpoint('Checkpoint.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

  optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=0.001, decay=0.0, amsgrad=True)

  model.compile(loss=combined_loss, optimizer= optimizer , metrics=[dice_coef,'accuracy']) 
  num_epoch = 100
  datagen = get_batch(batch_size, TrainX, TrainY)
  n_points = len(TrainX)
  print('-----------fold {}--------------'.format(fold))
  history = model.fit(datagen, validation_data = [ValX, ValY],
                  epochs=num_epoch,steps_per_epoch = math.ceil(n_points / batch_size), callbacks =[es,mc],  shuffle =True)
  model.save(MODELS_PATH + '/HScoreNet_ER_'+ str(fold) +'.h5')
  fold = fold + 1
# Out:
# TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1]
# -----------fold 0--------------
# Epoch 1/100
# 210/210 [==============================] - 85s 403ms/step - loss: 2.9044 - dice_coef: 0.3039 - accuracy: 0.8631 - val_loss: 2.8593 - val_dice_coef: 0.3387 - val_accuracy: 0.9547
#
# Epoch 00001: val_loss improved from inf to 2.85933, saving model to Checkpoint.h5
# Epoch 2/100
# 210/210 [==============================] - 74s 352ms/step - loss: 2.7283 - dice_coef: 0.3926 - accuracy: 0.9490 - val_loss: 2.8375 - val_dice_coef: 0.3703 - val_accuracy: 0.7741
#
# Epoch 00002: val_loss improved from 2.85933 to 2.83745, saving model to Checkpoint.h5
# Epoch 3/100
# 210/210 [==============================] - 74s 352ms/step - loss: 2.1972 - dice_coef: 0.7004 - accuracy: 0.9496 - val_loss: 1.8494 - val_dice_coef: 0.9370 - val_accuracy: 0.9558
#
# Epoch 00003: val_loss improved from 2.83745 to 1.84942, saving model to Checkpoint.h5
# Epoch 4/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.6210 - dice_coef: 0.9404 - accuracy: 0.9549 - val_loss: 1.5909 - val_dice_coef: 0.9502 - val_accuracy: 0.9572
#
# Epoch 00004: val_loss improved from 1.84942 to 1.59092, saving model to Checkpoint.h5
# Epoch 5/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.5597 - dice_coef: 0.9467 - accuracy: 0.9555 - val_loss: 1.5678 - val_dice_coef: 0.9435 - val_accuracy: 0.9537
#
# Epoch 00005: val_loss improved from 1.59092 to 1.56782, saving model to Checkpoint.h5
# Epoch 6/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.5252 - dice_coef: 0.9527 - accuracy: 0.9575 - val_loss: 1.5319 - val_dice_coef: 0.9557 - val_accuracy: 0.9576
#
# Epoch 00006: val_loss improved from 1.56782 to 1.53191, saving model to Checkpoint.h5
# Epoch 7/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.4903 - dice_coef: 0.9539 - accuracy: 0.9566 - val_loss: 1.5169 - val_dice_coef: 0.9580 - val_accuracy: 0.9597
#
# Epoch 00007: val_loss improved from 1.53191 to 1.51691, saving model to Checkpoint.h5
# Epoch 8/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.5111 - dice_coef: 0.9550 - accuracy: 0.9573 - val_loss: 1.4694 - val_dice_coef: 0.9579 - val_accuracy: 0.9592
#
# Epoch 00008: val_loss improved from 1.51691 to 1.46942, saving model to Checkpoint.h5
# Epoch 9/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.4632 - dice_coef: 0.9551 - accuracy: 0.9571 - val_loss: 1.5253 - val_dice_coef: 0.9529 - val_accuracy: 0.9545
#
# Epoch 00009: val_loss did not improve from 1.46942
# Epoch 10/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.4823 - dice_coef: 0.9550 - accuracy: 0.9568 - val_loss: 1.4567 - val_dice_coef: 0.9562 - val_accuracy: 0.9574
#
# Epoch 00010: val_loss improved from 1.46942 to 1.45668, saving model to Checkpoint.h5
# Epoch 11/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.4545 - dice_coef: 0.9512 - accuracy: 0.9528 - val_loss: 1.4303 - val_dice_coef: 0.9547 - val_accuracy: 0.9561
#
# Epoch 00011: val_loss improved from 1.45668 to 1.43032, saving model to Checkpoint.h5
# Epoch 12/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.4501 - dice_coef: 0.9588 - accuracy: 0.9602 - val_loss: 1.4983 - val_dice_coef: 0.9565 - val_accuracy: 0.9569
#
# Epoch 00012: val_loss did not improve from 1.43032
# Epoch 13/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.4539 - dice_coef: 0.9569 - accuracy: 0.9581 - val_loss: 1.4341 - val_dice_coef: 0.9563 - val_accuracy: 0.9568
#
# Epoch 00013: val_loss did not improve from 1.43032
# Epoch 14/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.4141 - dice_coef: 0.9553 - accuracy: 0.9565 - val_loss: 1.4515 - val_dice_coef: 0.9499 - val_accuracy: 0.9511
#
# Epoch 00014: val_loss did not improve from 1.43032
# Epoch 15/100
# 210/210 [==============================] - 74s 351ms/step - loss: 1.4442 - dice_coef: 0.9568 - accuracy: 0.9578 - val_loss: 1.4018 - val_dice_coef: 0.9569 - val_accuracy: 0.9572
#
# Epoch 00015: val_loss improved from 1.43032 to 1.40185, saving model to Checkpoint.h5
# Epoch 16/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.4308 - dice_coef: 0.9521 - accuracy: 0.9533 - val_loss: 1.4208 - val_dice_coef: 0.9603 - val_accuracy: 0.9609
#
# Epoch 00016: val_loss did not improve from 1.40185
# Epoch 17/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.3858 - dice_coef: 0.9578 - accuracy: 0.9589 - val_loss: 1.3713 - val_dice_coef: 0.9592 - val_accuracy: 0.9599
#
# Epoch 00017: val_loss improved from 1.40185 to 1.37128, saving model to Checkpoint.h5
# Epoch 18/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.4137 - dice_coef: 0.9571 - accuracy: 0.9582 - val_loss: 1.3770 - val_dice_coef: 0.9578 - val_accuracy: 0.9586
#
# Epoch 00018: val_loss did not improve from 1.37128
# Epoch 19/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.3776 - dice_coef: 0.9580 - accuracy: 0.9590 - val_loss: 1.3993 - val_dice_coef: 0.9597 - val_accuracy: 0.9601
#
# Epoch 00019: val_loss did not improve from 1.37128
# Epoch 20/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.3984 - dice_coef: 0.9564 - accuracy: 0.9575 - val_loss: 1.4752 - val_dice_coef: 0.9606 - val_accuracy: 0.9614
#
# Epoch 00020: val_loss did not improve from 1.37128
# Epoch 21/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.4121 - dice_coef: 0.9594 - accuracy: 0.9605 - val_loss: 1.3506 - val_dice_coef: 0.9581 - val_accuracy: 0.9588
#
# Epoch 00021: val_loss improved from 1.37128 to 1.35060, saving model to Checkpoint.h5
# Epoch 22/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.4007 - dice_coef: 0.9559 - accuracy: 0.9572 - val_loss: 1.3667 - val_dice_coef: 0.9616 - val_accuracy: 0.9625
#
# Epoch 00022: val_loss did not improve from 1.35060
# Epoch 23/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.3600 - dice_coef: 0.9573 - accuracy: 0.9585 - val_loss: 1.3802 - val_dice_coef: 0.9593 - val_accuracy: 0.9598
#
# Epoch 00023: val_loss did not improve from 1.35060
# Epoch 24/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.3617 - dice_coef: 0.9589 - accuracy: 0.9600 - val_loss: 1.5230 - val_dice_coef: 0.9515 - val_accuracy: 0.9521
#
# Epoch 00024: val_loss did not improve from 1.35060
# Epoch 25/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.3467 - dice_coef: 0.9555 - accuracy: 0.9568 - val_loss: 1.3636 - val_dice_coef: 0.9600 - val_accuracy: 0.9610
#
# Epoch 00025: val_loss did not improve from 1.35060
# Epoch 26/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.3345 - dice_coef: 0.9572 - accuracy: 0.9584 - val_loss: 1.3682 - val_dice_coef: 0.9568 - val_accuracy: 0.9575
#
# Epoch 00026: val_loss did not improve from 1.35060
# Epoch 27/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.3299 - dice_coef: 0.9588 - accuracy: 0.9600 - val_loss: 1.3332 - val_dice_coef: 0.9616 - val_accuracy: 0.9623
#
# Epoch 00027: val_loss improved from 1.35060 to 1.33323, saving model to Checkpoint.h5
# Epoch 28/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.3334 - dice_coef: 0.9582 - accuracy: 0.9594 - val_loss: 1.5023 - val_dice_coef: 0.9508 - val_accuracy: 0.9514
#
# Epoch 00028: val_loss did not improve from 1.33323
# Epoch 29/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.3511 - dice_coef: 0.9591 - accuracy: 0.9601 - val_loss: 1.3289 - val_dice_coef: 0.9614 - val_accuracy: 0.9624
#
# Epoch 00029: val_loss improved from 1.33323 to 1.32892, saving model to Checkpoint.h5
# Epoch 30/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.3348 - dice_coef: 0.9600 - accuracy: 0.9611 - val_loss: 1.4080 - val_dice_coef: 0.9546 - val_accuracy: 0.9554
#
# Epoch 00030: val_loss did not improve from 1.32892
# Epoch 31/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.3529 - dice_coef: 0.9564 - accuracy: 0.9576 - val_loss: 1.4444 - val_dice_coef: 0.9489 - val_accuracy: 0.9502
#
# Epoch 00031: val_loss did not improve from 1.32892
# Epoch 32/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.3817 - dice_coef: 0.9588 - accuracy: 0.9600 - val_loss: 1.3131 - val_dice_coef: 0.9598 - val_accuracy: 0.9606
#
# Epoch 00032: val_loss improved from 1.32892 to 1.31309, saving model to Checkpoint.h5
# Epoch 33/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.3404 - dice_coef: 0.9593 - accuracy: 0.9604 - val_loss: 1.2880 - val_dice_coef: 0.9601 - val_accuracy: 0.9608
#
# Epoch 00033: val_loss improved from 1.31309 to 1.28805, saving model to Checkpoint.h5
# Epoch 34/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.3550 - dice_coef: 0.9604 - accuracy: 0.9615 - val_loss: 1.3022 - val_dice_coef: 0.9608 - val_accuracy: 0.9615
#
# Epoch 00034: val_loss did not improve from 1.28805
# Epoch 35/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.3131 - dice_coef: 0.9604 - accuracy: 0.9615 - val_loss: 1.4361 - val_dice_coef: 0.9504 - val_accuracy: 0.9512
#
# Epoch 00035: val_loss did not improve from 1.28805
# Epoch 36/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.2871 - dice_coef: 0.9586 - accuracy: 0.9598 - val_loss: 1.2990 - val_dice_coef: 0.9613 - val_accuracy: 0.9621
#
# Epoch 00036: val_loss did not improve from 1.28805
# Epoch 37/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.3188 - dice_coef: 0.9582 - accuracy: 0.9593 - val_loss: 1.3000 - val_dice_coef: 0.9629 - val_accuracy: 0.9636
#
# Epoch 00037: val_loss did not improve from 1.28805
# Epoch 38/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.3575 - dice_coef: 0.9598 - accuracy: 0.9610 - val_loss: 1.3354 - val_dice_coef: 0.9613 - val_accuracy: 0.9619
#
# Epoch 00038: val_loss did not improve from 1.28805
# Epoch 39/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.3110 - dice_coef: 0.9600 - accuracy: 0.9611 - val_loss: 1.2971 - val_dice_coef: 0.9586 - val_accuracy: 0.9592
#
# Epoch 00039: val_loss did not improve from 1.28805
# Epoch 40/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.3217 - dice_coef: 0.9597 - accuracy: 0.9608 - val_loss: 1.3019 - val_dice_coef: 0.9596 - val_accuracy: 0.9607
#
# Epoch 00040: val_loss did not improve from 1.28805
# Epoch 41/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.3133 - dice_coef: 0.9584 - accuracy: 0.9596 - val_loss: 1.3404 - val_dice_coef: 0.9555 - val_accuracy: 0.9568
#
# Epoch 00041: val_loss did not improve from 1.28805
# Epoch 42/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.2866 - dice_coef: 0.9595 - accuracy: 0.9606 - val_loss: 1.3883 - val_dice_coef: 0.9595 - val_accuracy: 0.9615
#
# Epoch 00042: val_loss did not improve from 1.28805
# Epoch 43/100
# 210/210 [==============================] - 74s 352ms/step - loss: 1.3296 - dice_coef: 0.9601 - accuracy: 0.9611 - val_loss: 1.3145 - val_dice_coef: 0.9601 - val_accuracy: 0.9609
#
# Epoch 00043: val_loss did not improve from 1.28805
# Epoch 00043: early stopping
# TRAIN: [0, 1, 3, 4, 5, 7, 8] TEST: [2, 6]
# -----------fold 1--------------
# Epoch 1/100
# 210/210 [==============================] - 78s 373ms/step - loss: 2.6058 - dice_coef: 0.4782 - accuracy: 0.6252 - val_loss: 2.0440 - val_dice_coef: 0.8355 - val_accuracy: 0.9513
#
# Epoch 00001: val_loss improved from inf to 2.04404, saving model to Checkpoint.h5
# Epoch 2/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.7078 - dice_coef: 0.9271 - accuracy: 0.9541 - val_loss: 1.8456 - val_dice_coef: 0.9035 - val_accuracy: 0.9354
#
# Epoch 00002: val_loss improved from 2.04404 to 1.84558, saving model to Checkpoint.h5
# Epoch 3/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.5171 - dice_coef: 0.9514 - accuracy: 0.9552 - val_loss: 1.6282 - val_dice_coef: 0.9492 - val_accuracy: 0.9506
#
# Epoch 00003: val_loss improved from 1.84558 to 1.62821, saving model to Checkpoint.h5
# Epoch 4/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.5163 - dice_coef: 0.9528 - accuracy: 0.9557 - val_loss: 1.5751 - val_dice_coef: 0.9466 - val_accuracy: 0.9494
#
# Epoch 00004: val_loss improved from 1.62821 to 1.57515, saving model to Checkpoint.h5
# Epoch 5/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.4958 - dice_coef: 0.9567 - accuracy: 0.9592 - val_loss: 1.4964 - val_dice_coef: 0.9604 - val_accuracy: 0.9616
#
# Epoch 00005: val_loss improved from 1.57515 to 1.49643, saving model to Checkpoint.h5
# Epoch 6/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.4898 - dice_coef: 0.9591 - accuracy: 0.9610 - val_loss: 2.0197 - val_dice_coef: 0.8175 - val_accuracy: 0.8124
#
# Epoch 00006: val_loss did not improve from 1.49643
# Epoch 7/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.4322 - dice_coef: 0.9578 - accuracy: 0.9590 - val_loss: 1.5845 - val_dice_coef: 0.9597 - val_accuracy: 0.9603
#
# Epoch 00007: val_loss did not improve from 1.49643
# Epoch 8/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.4271 - dice_coef: 0.9580 - accuracy: 0.9593 - val_loss: 1.5328 - val_dice_coef: 0.9520 - val_accuracy: 0.9528
#
# Epoch 00008: val_loss did not improve from 1.49643
# Epoch 9/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.4132 - dice_coef: 0.9563 - accuracy: 0.9573 - val_loss: 1.4382 - val_dice_coef: 0.9593 - val_accuracy: 0.9602
#
# Epoch 00009: val_loss improved from 1.49643 to 1.43819, saving model to Checkpoint.h5
# Epoch 10/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.3930 - dice_coef: 0.9608 - accuracy: 0.9618 - val_loss: 1.4259 - val_dice_coef: 0.9613 - val_accuracy: 0.9619
#
# Epoch 00010: val_loss improved from 1.43819 to 1.42588, saving model to Checkpoint.h5
# Epoch 11/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.4091 - dice_coef: 0.9603 - accuracy: 0.9612 - val_loss: 1.4345 - val_dice_coef: 0.9617 - val_accuracy: 0.9621
#
# Epoch 00011: val_loss did not improve from 1.42588
# Epoch 12/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.3696 - dice_coef: 0.9589 - accuracy: 0.9596 - val_loss: 1.4001 - val_dice_coef: 0.9635 - val_accuracy: 0.9639
#
# Epoch 00012: val_loss improved from 1.42588 to 1.40010, saving model to Checkpoint.h5
# Epoch 13/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.3476 - dice_coef: 0.9572 - accuracy: 0.9580 - val_loss: 1.3898 - val_dice_coef: 0.9609 - val_accuracy: 0.9614
#
# Epoch 00013: val_loss improved from 1.40010 to 1.38984, saving model to Checkpoint.h5
# Epoch 14/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.3714 - dice_coef: 0.9580 - accuracy: 0.9588 - val_loss: 1.3705 - val_dice_coef: 0.9618 - val_accuracy: 0.9624
#
# Epoch 00014: val_loss improved from 1.38984 to 1.37051, saving model to Checkpoint.h5
# Epoch 15/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.3251 - dice_coef: 0.9604 - accuracy: 0.9613 - val_loss: 1.4018 - val_dice_coef: 0.9611 - val_accuracy: 0.9619
#
# Epoch 00015: val_loss did not improve from 1.37051
# Epoch 16/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.3378 - dice_coef: 0.9602 - accuracy: 0.9611 - val_loss: 1.3328 - val_dice_coef: 0.9639 - val_accuracy: 0.9643
#
# Epoch 00016: val_loss improved from 1.37051 to 1.33276, saving model to Checkpoint.h5
# Epoch 17/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.3337 - dice_coef: 0.9602 - accuracy: 0.9610 - val_loss: 1.3380 - val_dice_coef: 0.9631 - val_accuracy: 0.9635
#
# Epoch 00017: val_loss did not improve from 1.33276
# Epoch 18/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2962 - dice_coef: 0.9596 - accuracy: 0.9604 - val_loss: 1.3600 - val_dice_coef: 0.9588 - val_accuracy: 0.9594
#
# Epoch 00018: val_loss did not improve from 1.33276
# Epoch 19/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.2810 - dice_coef: 0.9632 - accuracy: 0.9639 - val_loss: 1.6733 - val_dice_coef: 0.9205 - val_accuracy: 0.9194
#
# Epoch 00019: val_loss did not improve from 1.33276
# Epoch 20/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.3080 - dice_coef: 0.9618 - accuracy: 0.9626 - val_loss: 1.5279 - val_dice_coef: 0.9188 - val_accuracy: 0.9178
#
# Epoch 00020: val_loss did not improve from 1.33276
# Epoch 21/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2908 - dice_coef: 0.9613 - accuracy: 0.9623 - val_loss: 1.3288 - val_dice_coef: 0.9564 - val_accuracy: 0.9577
#
# Epoch 00021: val_loss improved from 1.33276 to 1.32883, saving model to Checkpoint.h5
# Epoch 22/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.3052 - dice_coef: 0.9637 - accuracy: 0.9644 - val_loss: 1.3159 - val_dice_coef: 0.9629 - val_accuracy: 0.9632
#
# Epoch 00022: val_loss improved from 1.32883 to 1.31595, saving model to Checkpoint.h5
# Epoch 23/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.3008 - dice_coef: 0.9629 - accuracy: 0.9636 - val_loss: 1.3420 - val_dice_coef: 0.9630 - val_accuracy: 0.9631
#
# Epoch 00023: val_loss did not improve from 1.31595
# Epoch 24/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2873 - dice_coef: 0.9612 - accuracy: 0.9619 - val_loss: 1.3037 - val_dice_coef: 0.9649 - val_accuracy: 0.9653
#
# Epoch 00024: val_loss improved from 1.31595 to 1.30369, saving model to Checkpoint.h5
# Epoch 25/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.3073 - dice_coef: 0.9617 - accuracy: 0.9624 - val_loss: 1.3755 - val_dice_coef: 0.9641 - val_accuracy: 0.9645
#
# Epoch 00025: val_loss did not improve from 1.30369
# Epoch 26/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2614 - dice_coef: 0.9621 - accuracy: 0.9628 - val_loss: 1.3657 - val_dice_coef: 0.9580 - val_accuracy: 0.9586
#
# Epoch 00026: val_loss did not improve from 1.30369
# Epoch 27/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2717 - dice_coef: 0.9616 - accuracy: 0.9625 - val_loss: 1.3986 - val_dice_coef: 0.9434 - val_accuracy: 0.9444
#
# Epoch 00027: val_loss did not improve from 1.30369
# Epoch 28/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2541 - dice_coef: 0.9612 - accuracy: 0.9620 - val_loss: 1.3484 - val_dice_coef: 0.9630 - val_accuracy: 0.9635
#
# Epoch 00028: val_loss did not improve from 1.30369
# Epoch 29/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2511 - dice_coef: 0.9600 - accuracy: 0.9609 - val_loss: 1.3510 - val_dice_coef: 0.9582 - val_accuracy: 0.9588
#
# Epoch 00029: val_loss did not improve from 1.30369
# Epoch 30/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.2198 - dice_coef: 0.9639 - accuracy: 0.9647 - val_loss: 1.2376 - val_dice_coef: 0.9664 - val_accuracy: 0.9669
#
# Epoch 00030: val_loss improved from 1.30369 to 1.23764, saving model to Checkpoint.h5
# Epoch 31/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2523 - dice_coef: 0.9613 - accuracy: 0.9622 - val_loss: 1.3498 - val_dice_coef: 0.9498 - val_accuracy: 0.9504
#
# Epoch 00031: val_loss did not improve from 1.23764
# Epoch 32/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2428 - dice_coef: 0.9647 - accuracy: 0.9655 - val_loss: 1.2942 - val_dice_coef: 0.9625 - val_accuracy: 0.9630
#
# Epoch 00032: val_loss did not improve from 1.23764
# Epoch 33/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2615 - dice_coef: 0.9635 - accuracy: 0.9642 - val_loss: 1.2607 - val_dice_coef: 0.9630 - val_accuracy: 0.9636
#
# Epoch 00033: val_loss did not improve from 1.23764
# Epoch 34/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2614 - dice_coef: 0.9619 - accuracy: 0.9628 - val_loss: 1.3434 - val_dice_coef: 0.9542 - val_accuracy: 0.9547
#
# Epoch 00034: val_loss did not improve from 1.23764
# Epoch 35/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2207 - dice_coef: 0.9612 - accuracy: 0.9620 - val_loss: 1.2690 - val_dice_coef: 0.9652 - val_accuracy: 0.9656
#
# Epoch 00035: val_loss did not improve from 1.23764
# Epoch 36/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2412 - dice_coef: 0.9636 - accuracy: 0.9644 - val_loss: 1.2068 - val_dice_coef: 0.9650 - val_accuracy: 0.9656
#
# Epoch 00036: val_loss improved from 1.23764 to 1.20681, saving model to Checkpoint.h5
# Epoch 37/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2348 - dice_coef: 0.9633 - accuracy: 0.9641 - val_loss: 1.2867 - val_dice_coef: 0.9593 - val_accuracy: 0.9597
#
# Epoch 00037: val_loss did not improve from 1.20681
# Epoch 38/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2173 - dice_coef: 0.9632 - accuracy: 0.9640 - val_loss: 1.2978 - val_dice_coef: 0.9658 - val_accuracy: 0.9662
#
# Epoch 00038: val_loss did not improve from 1.20681
# Epoch 39/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2351 - dice_coef: 0.9622 - accuracy: 0.9630 - val_loss: 1.3033 - val_dice_coef: 0.9600 - val_accuracy: 0.9604
#
# Epoch 00039: val_loss did not improve from 1.20681
# Epoch 40/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2033 - dice_coef: 0.9627 - accuracy: 0.9635 - val_loss: 1.2825 - val_dice_coef: 0.9631 - val_accuracy: 0.9637
#
# Epoch 00040: val_loss did not improve from 1.20681
# Epoch 41/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2319 - dice_coef: 0.9620 - accuracy: 0.9628 - val_loss: 1.3135 - val_dice_coef: 0.9662 - val_accuracy: 0.9666
#
# Epoch 00041: val_loss did not improve from 1.20681
# Epoch 42/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.1914 - dice_coef: 0.9655 - accuracy: 0.9663 - val_loss: 1.3156 - val_dice_coef: 0.9543 - val_accuracy: 0.9546
#
# Epoch 00042: val_loss did not improve from 1.20681
# Epoch 43/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.1996 - dice_coef: 0.9632 - accuracy: 0.9640 - val_loss: 1.2506 - val_dice_coef: 0.9622 - val_accuracy: 0.9626
#
# Epoch 00043: val_loss did not improve from 1.20681
# Epoch 44/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.1824 - dice_coef: 0.9656 - accuracy: 0.9664 - val_loss: 1.3414 - val_dice_coef: 0.9481 - val_accuracy: 0.9483
#
# Epoch 00044: val_loss did not improve from 1.20681
# Epoch 45/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.1746 - dice_coef: 0.9635 - accuracy: 0.9643 - val_loss: 1.2623 - val_dice_coef: 0.9564 - val_accuracy: 0.9571
#
# Epoch 00045: val_loss did not improve from 1.20681
# Epoch 46/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.1651 - dice_coef: 0.9647 - accuracy: 0.9655 - val_loss: 1.2548 - val_dice_coef: 0.9663 - val_accuracy: 0.9669
#
# Epoch 00046: val_loss did not improve from 1.20681
# Epoch 00046: early stopping
# TRAIN: [0, 1, 2, 4, 5, 6, 7] TEST: [3, 8]
# -----------fold 2--------------
# Epoch 1/100
# 210/210 [==============================] - 78s 373ms/step - loss: 2.9514 - dice_coef: 0.2917 - accuracy: 0.8547 - val_loss: 2.9027 - val_dice_coef: 0.3326 - val_accuracy: 0.9543
#
# Epoch 00001: val_loss improved from inf to 2.90266, saving model to Checkpoint.h5
# Epoch 2/100
# 210/210 [==============================] - 74s 353ms/step - loss: 2.7690 - dice_coef: 0.3858 - accuracy: 0.9499 - val_loss: 2.7414 - val_dice_coef: 0.4033 - val_accuracy: 0.8513
#
# Epoch 00002: val_loss improved from 2.90266 to 2.74139, saving model to Checkpoint.h5
# Epoch 3/100
# 210/210 [==============================] - 74s 353ms/step - loss: 2.5979 - dice_coef: 0.4764 - accuracy: 0.9453 - val_loss: 2.5458 - val_dice_coef: 0.5217 - val_accuracy: 0.9525
#
# Epoch 00003: val_loss improved from 2.74139 to 2.54584, saving model to Checkpoint.h5
# Epoch 4/100
# 210/210 [==============================] - 74s 354ms/step - loss: 2.4478 - dice_coef: 0.5690 - accuracy: 0.9539 - val_loss: 2.3854 - val_dice_coef: 0.6101 - val_accuracy: 0.9496
#
# Epoch 00004: val_loss improved from 2.54584 to 2.38542, saving model to Checkpoint.h5
# Epoch 5/100
# 210/210 [==============================] - 74s 354ms/step - loss: 2.2902 - dice_coef: 0.6552 - accuracy: 0.9562 - val_loss: 2.2765 - val_dice_coef: 0.6476 - val_accuracy: 0.9165
#
# Epoch 00005: val_loss improved from 2.38542 to 2.27653, saving model to Checkpoint.h5
# Epoch 6/100
# 210/210 [==============================] - 74s 353ms/step - loss: 2.1483 - dice_coef: 0.7244 - accuracy: 0.9527 - val_loss: 2.1187 - val_dice_coef: 0.7573 - val_accuracy: 0.9537
#
# Epoch 00006: val_loss improved from 2.27653 to 2.11871, saving model to Checkpoint.h5
# Epoch 7/100
# 210/210 [==============================] - 74s 353ms/step - loss: 2.0318 - dice_coef: 0.7839 - accuracy: 0.9569 - val_loss: 2.0400 - val_dice_coef: 0.7930 - val_accuracy: 0.9426
#
# Epoch 00007: val_loss improved from 2.11871 to 2.04004, saving model to Checkpoint.h5
# Epoch 8/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.8895 - dice_coef: 0.8255 - accuracy: 0.9535 - val_loss: 2.0425 - val_dice_coef: 0.7918 - val_accuracy: 0.9032
#
# Epoch 00008: val_loss did not improve from 2.04004
# Epoch 9/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.7709 - dice_coef: 0.8606 - accuracy: 0.9560 - val_loss: 1.7954 - val_dice_coef: 0.8579 - val_accuracy: 0.9426
#
# Epoch 00009: val_loss improved from 2.04004 to 1.79540, saving model to Checkpoint.h5
# Epoch 10/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.7073 - dice_coef: 0.8842 - accuracy: 0.9554 - val_loss: 1.7408 - val_dice_coef: 0.8823 - val_accuracy: 0.9442
#
# Epoch 00010: val_loss improved from 1.79540 to 1.74079, saving model to Checkpoint.h5
# Epoch 11/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.6500 - dice_coef: 0.9023 - accuracy: 0.9568 - val_loss: 1.6703 - val_dice_coef: 0.8981 - val_accuracy: 0.9475
#
# Epoch 00011: val_loss improved from 1.74079 to 1.67034, saving model to Checkpoint.h5
# Epoch 12/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.5565 - dice_coef: 0.9132 - accuracy: 0.9550 - val_loss: 1.6310 - val_dice_coef: 0.8950 - val_accuracy: 0.9333
#
# Epoch 00012: val_loss improved from 1.67034 to 1.63103, saving model to Checkpoint.h5
# Epoch 13/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.4945 - dice_coef: 0.9269 - accuracy: 0.9600 - val_loss: 1.5639 - val_dice_coef: 0.9121 - val_accuracy: 0.9447
#
# Epoch 00013: val_loss improved from 1.63103 to 1.56394, saving model to Checkpoint.h5
# Epoch 14/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.4398 - dice_coef: 0.9321 - accuracy: 0.9582 - val_loss: 1.5519 - val_dice_coef: 0.9385 - val_accuracy: 0.9621
#
# Epoch 00014: val_loss improved from 1.56394 to 1.55193, saving model to Checkpoint.h5
# Epoch 15/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.4284 - dice_coef: 0.9380 - accuracy: 0.9595 - val_loss: 1.5537 - val_dice_coef: 0.9445 - val_accuracy: 0.9639
#
# Epoch 00015: val_loss did not improve from 1.55193
# Epoch 16/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.3828 - dice_coef: 0.9419 - accuracy: 0.9598 - val_loss: 1.5147 - val_dice_coef: 0.9435 - val_accuracy: 0.9597
#
# Epoch 00016: val_loss improved from 1.55193 to 1.51469, saving model to Checkpoint.h5
# Epoch 17/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.3578 - dice_coef: 0.9436 - accuracy: 0.9588 - val_loss: 1.4839 - val_dice_coef: 0.9520 - val_accuracy: 0.9658
#
# Epoch 00017: val_loss improved from 1.51469 to 1.48389, saving model to Checkpoint.h5
# Epoch 18/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.3273 - dice_coef: 0.9503 - accuracy: 0.9634 - val_loss: 1.4992 - val_dice_coef: 0.9526 - val_accuracy: 0.9644
#
# Epoch 00018: val_loss did not improve from 1.48389
# Epoch 19/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.3222 - dice_coef: 0.9495 - accuracy: 0.9609 - val_loss: 1.3869 - val_dice_coef: 0.9519 - val_accuracy: 0.9625
#
# Epoch 00019: val_loss improved from 1.48389 to 1.38690, saving model to Checkpoint.h5
# Epoch 20/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.3344 - dice_coef: 0.9509 - accuracy: 0.9611 - val_loss: 1.3671 - val_dice_coef: 0.9544 - val_accuracy: 0.9639
#
# Epoch 00020: val_loss improved from 1.38690 to 1.36712, saving model to Checkpoint.h5
# Epoch 21/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.3035 - dice_coef: 0.9538 - accuracy: 0.9628 - val_loss: 1.6586 - val_dice_coef: 0.8651 - val_accuracy: 0.8878
#
# Epoch 00021: val_loss did not improve from 1.36712
# Epoch 22/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.2771 - dice_coef: 0.9525 - accuracy: 0.9607 - val_loss: 1.4484 - val_dice_coef: 0.9510 - val_accuracy: 0.9596
#
# Epoch 00022: val_loss did not improve from 1.36712
# Epoch 23/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.2811 - dice_coef: 0.9542 - accuracy: 0.9617 - val_loss: 1.3716 - val_dice_coef: 0.9593 - val_accuracy: 0.9663
#
# Epoch 00023: val_loss did not improve from 1.36712
# Epoch 24/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2254 - dice_coef: 0.9537 - accuracy: 0.9606 - val_loss: 1.3187 - val_dice_coef: 0.9540 - val_accuracy: 0.9611
#
# Epoch 00024: val_loss improved from 1.36712 to 1.31869, saving model to Checkpoint.h5
# Epoch 25/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.2541 - dice_coef: 0.9549 - accuracy: 0.9613 - val_loss: 1.2920 - val_dice_coef: 0.9605 - val_accuracy: 0.9664
#
# Epoch 00025: val_loss improved from 1.31869 to 1.29201, saving model to Checkpoint.h5
# Epoch 26/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.2580 - dice_coef: 0.9562 - accuracy: 0.9621 - val_loss: 1.4243 - val_dice_coef: 0.9601 - val_accuracy: 0.9655
#
# Epoch 00026: val_loss did not improve from 1.29201
# Epoch 27/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.2475 - dice_coef: 0.9584 - accuracy: 0.9639 - val_loss: 1.2875 - val_dice_coef: 0.9622 - val_accuracy: 0.9674
#
# Epoch 00027: val_loss improved from 1.29201 to 1.28745, saving model to Checkpoint.h5
# Epoch 28/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.2326 - dice_coef: 0.9584 - accuracy: 0.9636 - val_loss: 1.2895 - val_dice_coef: 0.9529 - val_accuracy: 0.9584
#
# Epoch 00028: val_loss did not improve from 1.28745
# Epoch 29/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.2108 - dice_coef: 0.9602 - accuracy: 0.9651 - val_loss: 1.2493 - val_dice_coef: 0.9589 - val_accuracy: 0.9634
#
# Epoch 00029: val_loss improved from 1.28745 to 1.24927, saving model to Checkpoint.h5
# Epoch 30/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.1905 - dice_coef: 0.9590 - accuracy: 0.9636 - val_loss: 1.2142 - val_dice_coef: 0.9609 - val_accuracy: 0.9654
#
# Epoch 00030: val_loss improved from 1.24927 to 1.21420, saving model to Checkpoint.h5
# Epoch 31/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.2082 - dice_coef: 0.9579 - accuracy: 0.9622 - val_loss: 1.2826 - val_dice_coef: 0.9565 - val_accuracy: 0.9605
#
# Epoch 00031: val_loss did not improve from 1.21420
# Epoch 32/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.2011 - dice_coef: 0.9612 - accuracy: 0.9653 - val_loss: 1.4467 - val_dice_coef: 0.9529 - val_accuracy: 0.9569
#
# Epoch 00032: val_loss did not improve from 1.21420
# Epoch 33/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.1996 - dice_coef: 0.9597 - accuracy: 0.9636 - val_loss: 1.3170 - val_dice_coef: 0.9587 - val_accuracy: 0.9624
#
# Epoch 00033: val_loss did not improve from 1.21420
# Epoch 34/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.2290 - dice_coef: 0.9614 - accuracy: 0.9651 - val_loss: 1.2982 - val_dice_coef: 0.9609 - val_accuracy: 0.9645
#
# Epoch 00034: val_loss did not improve from 1.21420
# Epoch 35/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.2118 - dice_coef: 0.9624 - accuracy: 0.9660 - val_loss: 1.3937 - val_dice_coef: 0.9629 - val_accuracy: 0.9662
#
# Epoch 00035: val_loss did not improve from 1.21420
# Epoch 36/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.1942 - dice_coef: 0.9651 - accuracy: 0.9684 - val_loss: 1.3232 - val_dice_coef: 0.9581 - val_accuracy: 0.9613
#
# Epoch 00036: val_loss did not improve from 1.21420
# Epoch 37/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.1580 - dice_coef: 0.9617 - accuracy: 0.9650 - val_loss: 1.3272 - val_dice_coef: 0.9616 - val_accuracy: 0.9647
#
# Epoch 00037: val_loss did not improve from 1.21420
# Epoch 38/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.1933 - dice_coef: 0.9627 - accuracy: 0.9658 - val_loss: 1.2054 - val_dice_coef: 0.9621 - val_accuracy: 0.9654
#
# Epoch 00038: val_loss improved from 1.21420 to 1.20543, saving model to Checkpoint.h5
# Epoch 39/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.1794 - dice_coef: 0.9618 - accuracy: 0.9648 - val_loss: 1.2508 - val_dice_coef: 0.9558 - val_accuracy: 0.9595
#
# Epoch 00039: val_loss did not improve from 1.20543
# Epoch 40/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.1746 - dice_coef: 0.9623 - accuracy: 0.9653 - val_loss: 1.1919 - val_dice_coef: 0.9651 - val_accuracy: 0.9681
#
# Epoch 00040: val_loss improved from 1.20543 to 1.19190, saving model to Checkpoint.h5
# Epoch 41/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.1977 - dice_coef: 0.9606 - accuracy: 0.9635 - val_loss: 1.1833 - val_dice_coef: 0.9643 - val_accuracy: 0.9669
#
# Epoch 00041: val_loss improved from 1.19190 to 1.18330, saving model to Checkpoint.h5
# Epoch 42/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.1654 - dice_coef: 0.9621 - accuracy: 0.9648 - val_loss: 1.2339 - val_dice_coef: 0.9637 - val_accuracy: 0.9668
#
# Epoch 00042: val_loss did not improve from 1.18330
# Epoch 43/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.1648 - dice_coef: 0.9613 - accuracy: 0.9640 - val_loss: 1.4692 - val_dice_coef: 0.9434 - val_accuracy: 0.9476
#
# Epoch 00043: val_loss did not improve from 1.18330
# Epoch 44/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.1081 - dice_coef: 0.9632 - accuracy: 0.9658 - val_loss: 1.1710 - val_dice_coef: 0.9648 - val_accuracy: 0.9672
#
# Epoch 00044: val_loss improved from 1.18330 to 1.17102, saving model to Checkpoint.h5
# Epoch 45/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.1066 - dice_coef: 0.9622 - accuracy: 0.9647 - val_loss: 1.2687 - val_dice_coef: 0.9627 - val_accuracy: 0.9656
#
# Epoch 00045: val_loss did not improve from 1.17102
# Epoch 46/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.1408 - dice_coef: 0.9630 - accuracy: 0.9655 - val_loss: 1.1715 - val_dice_coef: 0.9648 - val_accuracy: 0.9673
#
# Epoch 00046: val_loss did not improve from 1.17102
# Epoch 47/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.1384 - dice_coef: 0.9621 - accuracy: 0.9645 - val_loss: 1.4589 - val_dice_coef: 0.9515 - val_accuracy: 0.9536
#
# Epoch 00047: val_loss did not improve from 1.17102
# Epoch 48/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.1199 - dice_coef: 0.9626 - accuracy: 0.9649 - val_loss: 1.1572 - val_dice_coef: 0.9651 - val_accuracy: 0.9673
#
# Epoch 00048: val_loss improved from 1.17102 to 1.15719, saving model to Checkpoint.h5
# Epoch 49/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.1275 - dice_coef: 0.9618 - accuracy: 0.9640 - val_loss: 1.2121 - val_dice_coef: 0.9637 - val_accuracy: 0.9662
#
# Epoch 00049: val_loss did not improve from 1.15719
# Epoch 50/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.1131 - dice_coef: 0.9643 - accuracy: 0.9665 - val_loss: 1.2250 - val_dice_coef: 0.9575 - val_accuracy: 0.9600
#
# Epoch 00050: val_loss did not improve from 1.15719
# Epoch 51/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.1280 - dice_coef: 0.9623 - accuracy: 0.9645 - val_loss: 1.2870 - val_dice_coef: 0.9659 - val_accuracy: 0.9679
#
# Epoch 00051: val_loss did not improve from 1.15719
# Epoch 52/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.0729 - dice_coef: 0.9629 - accuracy: 0.9650 - val_loss: 1.2303 - val_dice_coef: 0.9617 - val_accuracy: 0.9637
#
# Epoch 00052: val_loss did not improve from 1.15719
# Epoch 53/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.1394 - dice_coef: 0.9633 - accuracy: 0.9654 - val_loss: 1.4283 - val_dice_coef: 0.9534 - val_accuracy: 0.9552
#
# Epoch 00053: val_loss did not improve from 1.15719
# Epoch 54/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.1191 - dice_coef: 0.9652 - accuracy: 0.9672 - val_loss: 1.2071 - val_dice_coef: 0.9626 - val_accuracy: 0.9646
#
# Epoch 00054: val_loss did not improve from 1.15719
# Epoch 55/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.0949 - dice_coef: 0.9633 - accuracy: 0.9653 - val_loss: 1.3082 - val_dice_coef: 0.9599 - val_accuracy: 0.9624
#
# Epoch 00055: val_loss did not improve from 1.15719
# Epoch 56/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.0847 - dice_coef: 0.9664 - accuracy: 0.9683 - val_loss: 1.1199 - val_dice_coef: 0.9673 - val_accuracy: 0.9690
#
# Epoch 00056: val_loss improved from 1.15719 to 1.11990, saving model to Checkpoint.h5
# Epoch 57/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.0901 - dice_coef: 0.9663 - accuracy: 0.9682 - val_loss: 1.1973 - val_dice_coef: 0.9643 - val_accuracy: 0.9660
#
# Epoch 00057: val_loss did not improve from 1.11990
# Epoch 58/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.1173 - dice_coef: 0.9666 - accuracy: 0.9684 - val_loss: 1.2370 - val_dice_coef: 0.9650 - val_accuracy: 0.9667
#
# Epoch 00058: val_loss did not improve from 1.11990
# Epoch 59/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.1074 - dice_coef: 0.9629 - accuracy: 0.9648 - val_loss: 1.2132 - val_dice_coef: 0.9590 - val_accuracy: 0.9607
#
# Epoch 00059: val_loss did not improve from 1.11990
# Epoch 60/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.0990 - dice_coef: 0.9645 - accuracy: 0.9663 - val_loss: 1.2811 - val_dice_coef: 0.9571 - val_accuracy: 0.9592
#
# Epoch 00060: val_loss did not improve from 1.11990
# Epoch 61/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.1046 - dice_coef: 0.9636 - accuracy: 0.9655 - val_loss: 1.1527 - val_dice_coef: 0.9656 - val_accuracy: 0.9673
#
# Epoch 00061: val_loss did not improve from 1.11990
# Epoch 62/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.0956 - dice_coef: 0.9635 - accuracy: 0.9653 - val_loss: 1.3894 - val_dice_coef: 0.9615 - val_accuracy: 0.9631
#
# Epoch 00062: val_loss did not improve from 1.11990
# Epoch 63/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.0664 - dice_coef: 0.9645 - accuracy: 0.9663 - val_loss: 1.2240 - val_dice_coef: 0.9594 - val_accuracy: 0.9613
#
# Epoch 00063: val_loss did not improve from 1.11990
# Epoch 64/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.0487 - dice_coef: 0.9646 - accuracy: 0.9663 - val_loss: 1.1914 - val_dice_coef: 0.9642 - val_accuracy: 0.9657
#
# Epoch 00064: val_loss did not improve from 1.11990
# Epoch 65/100
# 210/210 [==============================] - 74s 353ms/step - loss: 1.0452 - dice_coef: 0.9646 - accuracy: 0.9664 - val_loss: 1.1656 - val_dice_coef: 0.9650 - val_accuracy: 0.9666
#
# Epoch 00065: val_loss did not improve from 1.11990
# Epoch 66/100
# 210/210 [==============================] - 74s 354ms/step - loss: 1.0905 - dice_coef: 0.9648 - accuracy: 0.9664 - val_loss: 1.2173 - val_dice_coef: 0.9614 - val_accuracy: 0.9629
#
# Epoch 00066: val_loss did not improve from 1.11990
# Epoch 00066: early stopping

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask, Patient_array,Patient_length,title,folder):
  idx = 0
  for i in range(len(Patient_length)):
    temp = []
    for j in range(Patient_length[i]):
      final_output = mask[idx:idx+48]
      idx = idx + 48
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save(folder + title + Patient_array[i], final_output)

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER/3Fold HScoreNet/"
model_names = os.listdir(MODELS_PATH)
print(model_names)
# Out:
# ['HScoreNet_ER_0.h5', 'HScoreNet_ER_1.h5', 'HScoreNet_ER_2.h5']

# %%
SAVE_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/ER/3Fold HScoreNet/"

# %%
# Axis 0 = Folds
# Axis 1 = Class (Strong Intermediate,Weak,Background)
# Axis 2 = Evaluation Technique (Precision, Recall, Dice coefficient)
pixEvaluationTrain = np.empty((0,4,3))
pixEvaluationTest = np.empty((0,4,3))
score = np.zeros((1,4,3))

# %%
fold = 0

for train_index, test_index in fold_split:
  print("FOLD:",fold,"\tTRAIN:", train_index, "TEST:", test_index)
  # Splitting Train and Test data
  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  train_no = [patient_no[i] for i in train_index]
  train_size = [size[i] for i in train_index]

  test_no = [patient_no[i] for i in test_index]
  test_size = [size[i] for i in test_index]

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255

  convertToLabels(TrainY)
  convertToLabels(TestY)

  # TrainY = keras.utils.to_categorical(TrainY,num_classes=4,dtype='int16')
  # TestY = keras.utils.to_categorical(TestY,num_classes=4,dtype='int16')
  
  # Loading corrosponding fold of model
  model = keras.models.load_model(MODELS_PATH + model_names[fold],custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

  # Predicting results using model
  trainResult = model.predict(TrainX, batch_size=8)
  testResult = model.predict(TestX,batch_size=8)

  trainResult = np.argmax(trainResult,axis=-1)
  testResult = np.argmax(testResult,axis=-1)

  # trainOneHot = keras.utils.to_categorical(trainResult,num_classes=4,dtype='int16')
  # testOneHot = keras.utils.to_categorical(testResult,num_classes=4,dtype='int16')

  # Obtaining pixel-wise results: Precision recall and dice coefficient
  # For TRAIN
  y_true = np.reshape(TrainY,(-1))
  y_pred = np.reshape(trainResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(4):
    score[0][i][0] = prec[3-i]
    score[0][i][1] = recall[3-i]
    score[0][i][2] = dice[3-i]

  pixEvaluationTrain = np.append(pixEvaluationTrain,score,axis=0)
 
  # For TEST
  y_true = np.reshape(TestY,(-1))
  y_pred = np.reshape(testResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(4):
    score[0][i][0] = prec[3-i]
    score[0][i][1] = recall[3-i]
    score[0][i][2] = dice[3-i]

  pixEvaluationTest = np.append(pixEvaluationTest,score,axis=0)

  # Converting predicted labels to required output format
  convertFromLabels(trainResult)
  convertFromLabels(testResult)

  # Saving numpy arrays
  path = os.path.join(SAVE_PATH,"Fold " + str(fold))
  os.mkdir(path)
  os.mkdir(path + '/Train')
  os.mkdir(path + '/Test')

  saveNumpyOutput(trainResult, train_no, train_size,"/Train/",path)
  saveNumpyOutput(testResult, test_no, test_size,"/Test/",path)

  fold +=1
# Out:
# FOLD: 0 	TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1]
# FOLD: 1 	TRAIN: [0, 1, 3, 4, 5, 7, 8] TEST: [2, 6]
# FOLD: 2 	TRAIN: [0, 1, 2, 4, 5, 6, 7] TEST: [3, 8]

# %%
print(pixEvaluationTrain.shape)
print(pixEvaluationTest.shape)
# Out:
# (3, 4, 3)
# (3, 4, 3)

# %%
print(pixEvaluationTest)
# Out:
# [[[0.89593336 0.23160105 0.36805814]
#   [0.28727179 0.28225524 0.28474142]
#   [0.18615404 0.21973742 0.20155639]
#   [0.95161094 0.99316899 0.97194594]]
#
#  [[0.66845317 0.85047459 0.74855757]
#   [0.50009331 0.28539459 0.36340197]
#   [0.12893335 0.22647124 0.16431806]
#   [0.97388375 0.95679856 0.96526556]]
#
#  [[0.47812307 0.98749005 0.6442925 ]
#   [0.06166588 0.0791578  0.06932549]
#   [0.05741099 0.08648431 0.06901059]
#   [0.99905039 0.8785541  0.93493579]]]

# %%
np.save(SAVE_PATH + "Pixel-wise Metrics Train.npy", pixEvaluationTrain)
np.save(SAVE_PATH + "Pixel-wise Metrics Test.npy", pixEvaluationTest)

# %% [markdown]
# # **DISPLAY**

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 48   # enter between 0- 50 since there are 5 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]
Mask_input = TestGT[id:id+48]
final_output = testResult[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 25  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]
Mask_input = TrainGT[id:id+48]
final_output = trainResult[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
