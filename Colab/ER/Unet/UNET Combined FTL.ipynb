# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
# !pip install -U keras
# !pip install tensorflow-gpu==2.1.0rc0

# %%
import math
import random
import keras
from keras.layers import *
from keras.models import Sequential
from keras import Model
from keras import backend as K  
from keras.regularizers import l2
from keras.callbacks import EarlyStopping,ModelCheckpoint

from sklearn.model_selection import LeaveOneOut
from sklearn import metrics
# Out:
# Using TensorFlow backend.

# %%
def get_conv_block(input_layer,nFilters,size):
    conv1 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(input_layer)
    bn1 = BatchNormalization()(conv1)
    conv2 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(bn1)
    bn2 = BatchNormalization()(conv2)
    return bn2
    
def get_UNET(input_layer,nFilters): 

    block1 = get_conv_block(input_layer,nFilters,3)
    mp1 = MaxPooling2D(pool_size=(2, 2))(block1)
    dr1 = Dropout(0.1)(mp1)
   
    block2 = get_conv_block(dr1,nFilters*2,3)
    mp2 = MaxPooling2D(pool_size=(2, 2))(block2)
    dr2 = Dropout(0.1)(mp2)

    block3 = get_conv_block(dr2,nFilters*4,3)
    mp3 = MaxPooling2D(pool_size=(2, 2))(block3)
    dr3 = Dropout(0.1)(mp3)

    block4 = get_conv_block(dr3,nFilters*8,3)
    mp4 = MaxPooling2D(pool_size=(2, 2))(block4)
    dr4 = Dropout(0.1)(mp4)

    conv5 = Conv2D(nFilters*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(dr4)
    conv5 = Conv2D(nFilters*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(conv5)

    up1 = Conv2DTranspose(nFilters*8,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(conv5)
    cat1 = concatenate([block4, up1])
    dr1 = Dropout(0.1)(cat1)
    block5 = get_conv_block(dr1,nFilters*8,3)

    up2 = Conv2DTranspose(nFilters*4,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block5)
    cat2 = concatenate([block3, up2])
    dr2 = Dropout(0.1)(cat2)
    block6 = get_conv_block(dr2,nFilters*4,3)
    
    up3 = Conv2DTranspose(nFilters*2,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block6)
    cat3 = concatenate([block2, up3])
    dr3 = Dropout(0.1)(cat3)
    block7 = get_conv_block(dr3,nFilters*2,3)
    
    up4 = Conv2DTranspose(nFilters,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block7)
    cat4 = concatenate([block1, up4])
    dr4 = Dropout(0.1)(cat4)
    block8 = get_conv_block(dr4,nFilters,3)

    conv10 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(block8)
    out = Conv2D(4,(1,1), activation='softmax', padding = 'same',kernel_regularizer=l2(1e-4))(conv10)

    return out

def get_model(input_shape,nFilters):

    input_layer = Input(shape=input_shape)
    out = get_UNET(input_layer,nFilters)
    model = Model(input_layer,out)
    return model

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/4 Class ER"

# Loading the data patient wise
X1 = np.load(PATH + '/ER IHC 230 Images.npy')
Y1 = np.load(PATH + '/ER IHC 230 Masks.npy')

X2 = np.load(PATH + '/ER IHC 232 Images.npy')
Y2 = np.load(PATH + '/ER IHC 232 Masks.npy')

X3 = np.load(PATH + '/ER IHC 242 Images.npy')
Y3 = np.load(PATH + '/ER IHC 242 Masks.npy')

X4 = np.load(PATH + '/ER IHC 263 Images.npy')
Y4 = np.load(PATH + '/ER IHC 263 Masks.npy')

X5 = np.load(PATH + '/ER IHC 221 Images.npy')
Y5 = np.load(PATH + '/ER IHC 221 Masks.npy')

X6 = np.load(PATH + '/ER IHC 229 Images.npy')
Y6 = np.load(PATH + '/ER IHC 229 Masks.npy')

X7 = np.load(PATH + '/ER IHC 239 Images.npy')
Y7 = np.load(PATH + '/ER IHC 239 Masks.npy')

X8 = np.load(PATH + '/ER IHC 246 Images.npy')
Y8 = np.load(PATH + '/ER IHC 246 Masks.npy')

X9 = np.load(PATH + '/ER IHC 252 Images.npy')
Y9 = np.load(PATH + '/ER IHC 252 Masks.npy')

# %%
X = [X1, X2, X3, X4, X5, X6, X7, X8, X9]
Y = [Y1, Y2, Y3, Y4, Y5, Y6, Y7, Y8, Y9]
patient_no = ['230','232','242','263','221','229','239','246','252']
size = [10,10,10,10,10,10,10,10,10]

# %%
fold_split = []

#test patient = 230, 232 
fold_split.append(([2,3,4,5,6,7,8],[0,1]))

# #test_patient = 239, 242
# fold_split.append(([0,1,3,4,5,7,8],[2,6]))

# #test_patient = 252,263
# fold_split.append(([0,1,2,4,5,6,7],[3,8]))

# %%
def convertToLabels(data):
  data[data==85]=1
  data[data==170]=2
  data[data==255]=3

def convertFromLabels(data):
  data[data==1]=85
  data[data==2]=170
  data[data==3]=255

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
def tversky_loss_1(y_true, y_pred):
    alpha = 0.7
    beta  = 0.3
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
  
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    # 
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def tversky_loss_2(y_true, y_pred):
    alpha = 0.3
    beta  = 0.7
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    # 
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def focal_tversky_loss_1(y_true, y_pred, gamma=0.75):
    tversky_index = tversky_loss_1(y_true, y_pred)
    return K.pow((tversky_index), gamma)
  
def focal_tversky_loss_2(y_true, y_pred, gamma=0.75):
    tversky_index = tversky_loss_2(y_true, y_pred)
    return K.pow((tversky_index), gamma)

def combined_loss(y_true, y_pred):
  return (0.2*K.categorical_crossentropy(y_true, y_pred))+(0.8*focal_tversky_loss_1(y_true, y_pred)+(0.8*focal_tversky_loss_2(y_true, y_pred)))

# %%
batch_size = 8
def get_batch(batch_size, X_train, Y_train): 
    size_batch = batch_size
    last_index = len(X_train) - 1
    x_train = X_train
    y_train = Y_train 
    while True:
        batch_data = [[],[]]
        for i in range(0, size_batch):
            random_index = random.randint(0, last_index)
            batch_data[0].append(x_train[random_index])
            batch_data[1].append(y_train[random_index])

        yield (np.array(batch_data[0]), np.array(batch_data[1]))

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER/UNET"

fold=0

for train_index, test_index in fold_split:
  print("TRAIN:", train_index, "TEST:", test_index, "FOLD:", fold)

  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  Train = list(zip(TrainX,TrainY))
  random.shuffle(Train)
  TrainX,TrainY = zip(*Train)
  TrainX = np.asarray(list(TrainX))
  TrainY = np.asarray(list(TrainY))

  Test = list(zip(TestX,TestY))
  random.shuffle(Test)
  TestX,TestY = zip(*Test)
  TestX = np.asarray(list(TestX))
  TestY = np.asarray(list(TestY))

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255
  convertToLabels(TrainY)
  TrainY = keras.utils.to_categorical(TrainY,num_classes=4,dtype='int16')
  convertToLabels(TestY)
  TestY = keras.utils.to_categorical(TestY,num_classes=4,dtype='int16')
  ValX = TrainX[(int)(0.8*TrainX.shape[0]):]
  ValY = TrainY[(int)(0.8*TrainY.shape[0]):]
  model = get_model((240,240,3),64)

  #es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
  mc = ModelCheckpoint('Checkpoint.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

  optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=0.001, decay=0.0, amsgrad=True)

  model.compile(loss=combined_loss, optimizer= optimizer , metrics=[dice_coef,'accuracy']) 
  num_epoch = 100
  datagen = get_batch(batch_size, TrainX, TrainY)
  n_points = len(TrainX)
  print('-----------fold {}--------------'.format(fold))
  history = model.fit(datagen, validation_data = [ValX, ValY],
                  epochs=num_epoch,steps_per_epoch = math.ceil(n_points / batch_size), callbacks =[mc],  shuffle =True)
  model.save(MODELS_PATH + '/UNET_ER_'+ str(fold) +'.h5')
  fold = fold + 1
# Out:
# TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1] FOLD: 0
# -----------fold 0--------------
# Epoch 1/100
# 420/420 [==============================] - 193s 459ms/step - loss: 4.3357 - dice_coef: 0.8616 - accuracy: 0.8971 - val_loss: 4.0433 - val_dice_coef: 0.9429 - val_accuracy: 0.9470
#
# Epoch 00001: val_loss improved from inf to 4.04327, saving model to Checkpoint.h5
# Epoch 2/100
# 420/420 [==============================] - 179s 427ms/step - loss: 3.9148 - dice_coef: 0.9415 - accuracy: 0.9460 - val_loss: 3.8549 - val_dice_coef: 0.9492 - val_accuracy: 0.9534
#
# Epoch 00002: val_loss improved from 4.04327 to 3.85485, saving model to Checkpoint.h5
# Epoch 3/100
# 420/420 [==============================] - 179s 427ms/step - loss: 3.6973 - dice_coef: 0.9514 - accuracy: 0.9562 - val_loss: 3.6530 - val_dice_coef: 0.9529 - val_accuracy: 0.9571
#
# Epoch 00003: val_loss improved from 3.85485 to 3.65300, saving model to Checkpoint.h5
# Epoch 4/100
# 420/420 [==============================] - 179s 427ms/step - loss: 3.5631 - dice_coef: 0.9554 - accuracy: 0.9595 - val_loss: 3.4831 - val_dice_coef: 0.9509 - val_accuracy: 0.9555
#
# Epoch 00004: val_loss improved from 3.65300 to 3.48311, saving model to Checkpoint.h5
# Epoch 5/100
# 420/420 [==============================] - 179s 427ms/step - loss: 3.3858 - dice_coef: 0.9529 - accuracy: 0.9573 - val_loss: 3.5644 - val_dice_coef: 0.9476 - val_accuracy: 0.9501
#
# Epoch 00005: val_loss did not improve from 3.48311
# Epoch 6/100
# 420/420 [==============================] - 179s 427ms/step - loss: 3.2878 - dice_coef: 0.9524 - accuracy: 0.9566 - val_loss: 3.3112 - val_dice_coef: 0.9445 - val_accuracy: 0.9506
#
# Epoch 00006: val_loss improved from 3.48311 to 3.31123, saving model to Checkpoint.h5
# Epoch 7/100
# 420/420 [==============================] - 179s 427ms/step - loss: 3.2375 - dice_coef: 0.9561 - accuracy: 0.9599 - val_loss: 3.1997 - val_dice_coef: 0.9473 - val_accuracy: 0.9522
#
# Epoch 00007: val_loss improved from 3.31123 to 3.19972, saving model to Checkpoint.h5
# Epoch 8/100
# 420/420 [==============================] - 179s 427ms/step - loss: 3.1141 - dice_coef: 0.9566 - accuracy: 0.9614 - val_loss: 3.0889 - val_dice_coef: 0.9523 - val_accuracy: 0.9572
#
# Epoch 00008: val_loss improved from 3.19972 to 3.08892, saving model to Checkpoint.h5
# Epoch 9/100
# 420/420 [==============================] - 179s 427ms/step - loss: 3.0407 - dice_coef: 0.9553 - accuracy: 0.9603 - val_loss: 3.0625 - val_dice_coef: 0.9541 - val_accuracy: 0.9583
#
# Epoch 00009: val_loss improved from 3.08892 to 3.06249, saving model to Checkpoint.h5
# Epoch 10/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.9753 - dice_coef: 0.9549 - accuracy: 0.9593 - val_loss: 2.9756 - val_dice_coef: 0.9545 - val_accuracy: 0.9577
#
# Epoch 00010: val_loss improved from 3.06249 to 2.97559, saving model to Checkpoint.h5
# Epoch 11/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.9455 - dice_coef: 0.9534 - accuracy: 0.9576 - val_loss: 2.9486 - val_dice_coef: 0.9548 - val_accuracy: 0.9590
#
# Epoch 00011: val_loss improved from 2.97559 to 2.94856, saving model to Checkpoint.h5
# Epoch 12/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.8987 - dice_coef: 0.9548 - accuracy: 0.9589 - val_loss: 3.0249 - val_dice_coef: 0.9399 - val_accuracy: 0.9458
#
# Epoch 00012: val_loss did not improve from 2.94856
# Epoch 13/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.8498 - dice_coef: 0.9564 - accuracy: 0.9599 - val_loss: 2.8653 - val_dice_coef: 0.9565 - val_accuracy: 0.9592
#
# Epoch 00013: val_loss improved from 2.94856 to 2.86527, saving model to Checkpoint.h5
# Epoch 14/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.8564 - dice_coef: 0.9541 - accuracy: 0.9561 - val_loss: 2.8265 - val_dice_coef: 0.9472 - val_accuracy: 0.9486
#
# Epoch 00014: val_loss improved from 2.86527 to 2.82645, saving model to Checkpoint.h5
# Epoch 15/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.7720 - dice_coef: 0.9538 - accuracy: 0.9553 - val_loss: 2.7916 - val_dice_coef: 0.9398 - val_accuracy: 0.9391
#
# Epoch 00015: val_loss improved from 2.82645 to 2.79158, saving model to Checkpoint.h5
# Epoch 16/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.7331 - dice_coef: 0.9556 - accuracy: 0.9562 - val_loss: 2.8177 - val_dice_coef: 0.9510 - val_accuracy: 0.9515
#
# Epoch 00016: val_loss did not improve from 2.79158
# Epoch 17/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.6976 - dice_coef: 0.9536 - accuracy: 0.9543 - val_loss: 2.8946 - val_dice_coef: 0.9381 - val_accuracy: 0.9387
#
# Epoch 00017: val_loss did not improve from 2.79158
# Epoch 18/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.6639 - dice_coef: 0.9533 - accuracy: 0.9542 - val_loss: 2.7654 - val_dice_coef: 0.9542 - val_accuracy: 0.9544
#
# Epoch 00018: val_loss improved from 2.79158 to 2.76541, saving model to Checkpoint.h5
# Epoch 19/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.7252 - dice_coef: 0.9544 - accuracy: 0.9551 - val_loss: 2.7386 - val_dice_coef: 0.9523 - val_accuracy: 0.9535
#
# Epoch 00019: val_loss improved from 2.76541 to 2.73865, saving model to Checkpoint.h5
# Epoch 20/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.6550 - dice_coef: 0.9545 - accuracy: 0.9553 - val_loss: 2.7097 - val_dice_coef: 0.9536 - val_accuracy: 0.9547
#
# Epoch 00020: val_loss improved from 2.73865 to 2.70972, saving model to Checkpoint.h5
# Epoch 21/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.6389 - dice_coef: 0.9556 - accuracy: 0.9566 - val_loss: 2.6705 - val_dice_coef: 0.9514 - val_accuracy: 0.9526
#
# Epoch 00021: val_loss improved from 2.70972 to 2.67054, saving model to Checkpoint.h5
# Epoch 22/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.6579 - dice_coef: 0.9587 - accuracy: 0.9598 - val_loss: 3.0845 - val_dice_coef: 0.9503 - val_accuracy: 0.9505
#
# Epoch 00022: val_loss did not improve from 2.67054
# Epoch 23/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.6909 - dice_coef: 0.9550 - accuracy: 0.9561 - val_loss: 2.6429 - val_dice_coef: 0.9566 - val_accuracy: 0.9577
#
# Epoch 00023: val_loss improved from 2.67054 to 2.64293, saving model to Checkpoint.h5
# Epoch 24/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.6220 - dice_coef: 0.9532 - accuracy: 0.9545 - val_loss: 2.6280 - val_dice_coef: 0.9573 - val_accuracy: 0.9584
#
# Epoch 00024: val_loss improved from 2.64293 to 2.62803, saving model to Checkpoint.h5
# Epoch 25/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.6076 - dice_coef: 0.9593 - accuracy: 0.9603 - val_loss: 2.5986 - val_dice_coef: 0.9556 - val_accuracy: 0.9565
#
# Epoch 00025: val_loss improved from 2.62803 to 2.59858, saving model to Checkpoint.h5
# Epoch 26/100
# 420/420 [==============================] - 180s 427ms/step - loss: 2.6999 - dice_coef: 0.9579 - accuracy: 0.9588 - val_loss: 2.6297 - val_dice_coef: 0.9574 - val_accuracy: 0.9584
#
# Epoch 00026: val_loss did not improve from 2.59858
# Epoch 27/100
# 420/420 [==============================] - 180s 427ms/step - loss: 2.5910 - dice_coef: 0.9579 - accuracy: 0.9588 - val_loss: 2.6697 - val_dice_coef: 0.9575 - val_accuracy: 0.9581
#
# Epoch 00027: val_loss did not improve from 2.59858
# Epoch 28/100
# 420/420 [==============================] - 180s 427ms/step - loss: 2.5411 - dice_coef: 0.9587 - accuracy: 0.9597 - val_loss: 2.6035 - val_dice_coef: 0.9566 - val_accuracy: 0.9573
#
# Epoch 00028: val_loss did not improve from 2.59858
# Epoch 29/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5123 - dice_coef: 0.9596 - accuracy: 0.9604 - val_loss: 2.6311 - val_dice_coef: 0.9553 - val_accuracy: 0.9561
#
# Epoch 00029: val_loss did not improve from 2.59858
# Epoch 30/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5997 - dice_coef: 0.9597 - accuracy: 0.9606 - val_loss: 2.6437 - val_dice_coef: 0.9360 - val_accuracy: 0.9368
#
# Epoch 00030: val_loss did not improve from 2.59858
# Epoch 31/100
# 420/420 [==============================] - 180s 428ms/step - loss: 2.5680 - dice_coef: 0.9559 - accuracy: 0.9567 - val_loss: 2.6017 - val_dice_coef: 0.9572 - val_accuracy: 0.9578
#
# Epoch 00031: val_loss did not improve from 2.59858
# Epoch 32/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5827 - dice_coef: 0.9579 - accuracy: 0.9587 - val_loss: 2.6221 - val_dice_coef: 0.9583 - val_accuracy: 0.9588
#
# Epoch 00032: val_loss did not improve from 2.59858
# Epoch 33/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5524 - dice_coef: 0.9596 - accuracy: 0.9603 - val_loss: 2.6280 - val_dice_coef: 0.9504 - val_accuracy: 0.9512
#
# Epoch 00033: val_loss did not improve from 2.59858
# Epoch 34/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5927 - dice_coef: 0.9567 - accuracy: 0.9575 - val_loss: 2.5705 - val_dice_coef: 0.9529 - val_accuracy: 0.9533
#
# Epoch 00034: val_loss improved from 2.59858 to 2.57050, saving model to Checkpoint.h5
# Epoch 35/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5567 - dice_coef: 0.9584 - accuracy: 0.9591 - val_loss: 2.5317 - val_dice_coef: 0.9590 - val_accuracy: 0.9596
#
# Epoch 00035: val_loss improved from 2.57050 to 2.53173, saving model to Checkpoint.h5
# Epoch 36/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5339 - dice_coef: 0.9561 - accuracy: 0.9569 - val_loss: 2.6431 - val_dice_coef: 0.9504 - val_accuracy: 0.9514
#
# Epoch 00036: val_loss did not improve from 2.53173
# Epoch 37/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5556 - dice_coef: 0.9600 - accuracy: 0.9607 - val_loss: 2.5691 - val_dice_coef: 0.9516 - val_accuracy: 0.9527
#
# Epoch 00037: val_loss did not improve from 2.53173
# Epoch 38/100
# 420/420 [==============================] - 180s 428ms/step - loss: 2.5014 - dice_coef: 0.9566 - accuracy: 0.9574 - val_loss: 2.6030 - val_dice_coef: 0.9540 - val_accuracy: 0.9549
#
# Epoch 00038: val_loss did not improve from 2.53173
# Epoch 39/100
# 420/420 [==============================] - 180s 428ms/step - loss: 2.4678 - dice_coef: 0.9568 - accuracy: 0.9577 - val_loss: 2.7585 - val_dice_coef: 0.9527 - val_accuracy: 0.9532
#
# Epoch 00039: val_loss did not improve from 2.53173
# Epoch 40/100
# 420/420 [==============================] - 180s 427ms/step - loss: 2.5485 - dice_coef: 0.9559 - accuracy: 0.9567 - val_loss: 2.5548 - val_dice_coef: 0.9571 - val_accuracy: 0.9578
#
# Epoch 00040: val_loss did not improve from 2.53173
# Epoch 41/100
# 420/420 [==============================] - 180s 427ms/step - loss: 2.5648 - dice_coef: 0.9603 - accuracy: 0.9610 - val_loss: 2.9619 - val_dice_coef: 0.9440 - val_accuracy: 0.9445
#
# Epoch 00041: val_loss did not improve from 2.53173
# Epoch 42/100
# 420/420 [==============================] - 180s 428ms/step - loss: 2.5184 - dice_coef: 0.9588 - accuracy: 0.9595 - val_loss: 2.5776 - val_dice_coef: 0.9571 - val_accuracy: 0.9577
#
# Epoch 00042: val_loss did not improve from 2.53173
# Epoch 43/100
# 420/420 [==============================] - 180s 428ms/step - loss: 2.5350 - dice_coef: 0.9596 - accuracy: 0.9603 - val_loss: 2.7794 - val_dice_coef: 0.9363 - val_accuracy: 0.9371
#
# Epoch 00043: val_loss did not improve from 2.53173
# Epoch 44/100
# 420/420 [==============================] - 180s 428ms/step - loss: 2.5129 - dice_coef: 0.9587 - accuracy: 0.9594 - val_loss: 2.5353 - val_dice_coef: 0.9577 - val_accuracy: 0.9583
#
# Epoch 00044: val_loss did not improve from 2.53173
# Epoch 45/100
# 420/420 [==============================] - 180s 429ms/step - loss: 2.4746 - dice_coef: 0.9591 - accuracy: 0.9599 - val_loss: 2.5367 - val_dice_coef: 0.9524 - val_accuracy: 0.9532
#
# Epoch 00045: val_loss did not improve from 2.53173
# Epoch 46/100
# 420/420 [==============================] - 180s 429ms/step - loss: 2.5434 - dice_coef: 0.9596 - accuracy: 0.9603 - val_loss: 2.5791 - val_dice_coef: 0.9593 - val_accuracy: 0.9597
#
# Epoch 00046: val_loss did not improve from 2.53173
# Epoch 47/100
# 420/420 [==============================] - 180s 429ms/step - loss: 2.5649 - dice_coef: 0.9582 - accuracy: 0.9590 - val_loss: 2.6003 - val_dice_coef: 0.9516 - val_accuracy: 0.9525
#
# Epoch 00047: val_loss did not improve from 2.53173
# Epoch 48/100
# 420/420 [==============================] - 180s 429ms/step - loss: 2.4794 - dice_coef: 0.9594 - accuracy: 0.9601 - val_loss: 2.5599 - val_dice_coef: 0.9577 - val_accuracy: 0.9584
#
# Epoch 00048: val_loss did not improve from 2.53173
# Epoch 49/100
# 420/420 [==============================] - 180s 428ms/step - loss: 2.4981 - dice_coef: 0.9584 - accuracy: 0.9591 - val_loss: 2.5121 - val_dice_coef: 0.9573 - val_accuracy: 0.9579
#
# Epoch 00049: val_loss improved from 2.53173 to 2.51211, saving model to Checkpoint.h5
# Epoch 50/100
# 420/420 [==============================] - 180s 429ms/step - loss: 2.5768 - dice_coef: 0.9596 - accuracy: 0.9603 - val_loss: 2.5188 - val_dice_coef: 0.9594 - val_accuracy: 0.9601
#
# Epoch 00050: val_loss did not improve from 2.51211
# Epoch 51/100
# 420/420 [==============================] - 180s 429ms/step - loss: 2.5489 - dice_coef: 0.9601 - accuracy: 0.9608 - val_loss: 2.5710 - val_dice_coef: 0.9565 - val_accuracy: 0.9570
#
# Epoch 00051: val_loss did not improve from 2.51211
# Epoch 52/100
# 420/420 [==============================] - 180s 427ms/step - loss: 2.5501 - dice_coef: 0.9594 - accuracy: 0.9601 - val_loss: 2.5897 - val_dice_coef: 0.9523 - val_accuracy: 0.9531
#
# Epoch 00052: val_loss did not improve from 2.51211
# Epoch 53/100
# 420/420 [==============================] - 180s 428ms/step - loss: 2.5146 - dice_coef: 0.9585 - accuracy: 0.9592 - val_loss: 2.5217 - val_dice_coef: 0.9600 - val_accuracy: 0.9605
#
# Epoch 00053: val_loss did not improve from 2.51211
# Epoch 54/100
# 420/420 [==============================] - 180s 429ms/step - loss: 2.5318 - dice_coef: 0.9590 - accuracy: 0.9597 - val_loss: 2.5687 - val_dice_coef: 0.9568 - val_accuracy: 0.9573
#
# Epoch 00054: val_loss did not improve from 2.51211
# Epoch 55/100
# 420/420 [==============================] - 180s 429ms/step - loss: 2.4964 - dice_coef: 0.9609 - accuracy: 0.9616 - val_loss: 2.5160 - val_dice_coef: 0.9572 - val_accuracy: 0.9577
#
# Epoch 00055: val_loss did not improve from 2.51211
# Epoch 56/100
# 420/420 [==============================] - 180s 429ms/step - loss: 2.5310 - dice_coef: 0.9619 - accuracy: 0.9626 - val_loss: 2.5150 - val_dice_coef: 0.9568 - val_accuracy: 0.9573
#
# Epoch 00056: val_loss did not improve from 2.51211
# Epoch 57/100
# 420/420 [==============================] - 180s 429ms/step - loss: 2.5280 - dice_coef: 0.9599 - accuracy: 0.9605 - val_loss: 2.7835 - val_dice_coef: 0.9547 - val_accuracy: 0.9551
#
# Epoch 00057: val_loss did not improve from 2.51211
# Epoch 58/100
# 420/420 [==============================] - 180s 429ms/step - loss: 2.5429 - dice_coef: 0.9593 - accuracy: 0.9599 - val_loss: 2.5722 - val_dice_coef: 0.9576 - val_accuracy: 0.9586
#
# Epoch 00058: val_loss did not improve from 2.51211
# Epoch 59/100
# 420/420 [==============================] - 180s 429ms/step - loss: 2.5033 - dice_coef: 0.9592 - accuracy: 0.9599 - val_loss: 2.5845 - val_dice_coef: 0.9548 - val_accuracy: 0.9552
#
# Epoch 00059: val_loss did not improve from 2.51211
# Epoch 60/100
# 420/420 [==============================] - 180s 429ms/step - loss: 2.5412 - dice_coef: 0.9590 - accuracy: 0.9596 - val_loss: 2.5781 - val_dice_coef: 0.9539 - val_accuracy: 0.9545
#
# Epoch 00060: val_loss did not improve from 2.51211
# Epoch 61/100
# 420/420 [==============================] - 180s 428ms/step - loss: 2.4905 - dice_coef: 0.9600 - accuracy: 0.9606 - val_loss: 2.5561 - val_dice_coef: 0.9529 - val_accuracy: 0.9535
#
# Epoch 00061: val_loss did not improve from 2.51211
# Epoch 62/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5042 - dice_coef: 0.9611 - accuracy: 0.9617 - val_loss: 2.5212 - val_dice_coef: 0.9573 - val_accuracy: 0.9579
#
# Epoch 00062: val_loss did not improve from 2.51211
# Epoch 63/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5109 - dice_coef: 0.9594 - accuracy: 0.9601 - val_loss: 2.7563 - val_dice_coef: 0.9601 - val_accuracy: 0.9604
#
# Epoch 00063: val_loss did not improve from 2.51211
# Epoch 64/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5337 - dice_coef: 0.9593 - accuracy: 0.9599 - val_loss: 2.6978 - val_dice_coef: 0.9501 - val_accuracy: 0.9510
#
# Epoch 00064: val_loss did not improve from 2.51211
# Epoch 65/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4889 - dice_coef: 0.9612 - accuracy: 0.9618 - val_loss: 2.6346 - val_dice_coef: 0.9590 - val_accuracy: 0.9594
#
# Epoch 00065: val_loss did not improve from 2.51211
# Epoch 66/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4398 - dice_coef: 0.9610 - accuracy: 0.9616 - val_loss: 2.6614 - val_dice_coef: 0.9453 - val_accuracy: 0.9461
#
# Epoch 00066: val_loss did not improve from 2.51211
# Epoch 67/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5309 - dice_coef: 0.9591 - accuracy: 0.9597 - val_loss: 2.5547 - val_dice_coef: 0.9591 - val_accuracy: 0.9596
#
# Epoch 00067: val_loss did not improve from 2.51211
# Epoch 68/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4973 - dice_coef: 0.9578 - accuracy: 0.9585 - val_loss: 2.5090 - val_dice_coef: 0.9559 - val_accuracy: 0.9574
#
# Epoch 00068: val_loss improved from 2.51211 to 2.50898, saving model to Checkpoint.h5
# Epoch 69/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5059 - dice_coef: 0.9585 - accuracy: 0.9591 - val_loss: 2.5462 - val_dice_coef: 0.9544 - val_accuracy: 0.9550
#
# Epoch 00069: val_loss did not improve from 2.50898
# Epoch 70/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4661 - dice_coef: 0.9620 - accuracy: 0.9626 - val_loss: 2.4585 - val_dice_coef: 0.9578 - val_accuracy: 0.9584
#
# Epoch 00070: val_loss improved from 2.50898 to 2.45845, saving model to Checkpoint.h5
# Epoch 71/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4844 - dice_coef: 0.9604 - accuracy: 0.9610 - val_loss: 2.6109 - val_dice_coef: 0.9571 - val_accuracy: 0.9575
#
# Epoch 00071: val_loss did not improve from 2.45845
# Epoch 72/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4921 - dice_coef: 0.9598 - accuracy: 0.9604 - val_loss: 2.9331 - val_dice_coef: 0.9355 - val_accuracy: 0.9361
#
# Epoch 00072: val_loss did not improve from 2.45845
# Epoch 73/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5508 - dice_coef: 0.9595 - accuracy: 0.9601 - val_loss: 2.6066 - val_dice_coef: 0.9567 - val_accuracy: 0.9572
#
# Epoch 00073: val_loss did not improve from 2.45845
# Epoch 74/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5105 - dice_coef: 0.9588 - accuracy: 0.9595 - val_loss: 2.6830 - val_dice_coef: 0.9507 - val_accuracy: 0.9513
#
# Epoch 00074: val_loss did not improve from 2.45845
# Epoch 75/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4960 - dice_coef: 0.9625 - accuracy: 0.9631 - val_loss: 2.7632 - val_dice_coef: 0.9471 - val_accuracy: 0.9476
#
# Epoch 00075: val_loss did not improve from 2.45845
# Epoch 76/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5344 - dice_coef: 0.9604 - accuracy: 0.9610 - val_loss: 2.6008 - val_dice_coef: 0.9577 - val_accuracy: 0.9581
#
# Epoch 00076: val_loss did not improve from 2.45845
# Epoch 77/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4676 - dice_coef: 0.9567 - accuracy: 0.9574 - val_loss: 2.6218 - val_dice_coef: 0.9582 - val_accuracy: 0.9589
#
# Epoch 00077: val_loss did not improve from 2.45845
# Epoch 78/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5016 - dice_coef: 0.9600 - accuracy: 0.9606 - val_loss: 2.5766 - val_dice_coef: 0.9595 - val_accuracy: 0.9599
#
# Epoch 00078: val_loss did not improve from 2.45845
# Epoch 79/100
# 420/420 [==============================] - 180s 427ms/step - loss: 2.4775 - dice_coef: 0.9593 - accuracy: 0.9599 - val_loss: 2.7710 - val_dice_coef: 0.9459 - val_accuracy: 0.9462
#
# Epoch 00079: val_loss did not improve from 2.45845
# Epoch 80/100
# 420/420 [==============================] - 180s 427ms/step - loss: 2.5320 - dice_coef: 0.9598 - accuracy: 0.9604 - val_loss: 2.5260 - val_dice_coef: 0.9586 - val_accuracy: 0.9590
#
# Epoch 00080: val_loss did not improve from 2.45845
# Epoch 81/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4665 - dice_coef: 0.9598 - accuracy: 0.9605 - val_loss: 2.5301 - val_dice_coef: 0.9598 - val_accuracy: 0.9602
#
# Epoch 00081: val_loss did not improve from 2.45845
# Epoch 82/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4659 - dice_coef: 0.9610 - accuracy: 0.9617 - val_loss: 2.5328 - val_dice_coef: 0.9591 - val_accuracy: 0.9596
#
# Epoch 00082: val_loss did not improve from 2.45845
# Epoch 83/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4524 - dice_coef: 0.9613 - accuracy: 0.9619 - val_loss: 2.6708 - val_dice_coef: 0.9457 - val_accuracy: 0.9462
#
# Epoch 00083: val_loss did not improve from 2.45845
# Epoch 84/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4733 - dice_coef: 0.9600 - accuracy: 0.9607 - val_loss: 2.7090 - val_dice_coef: 0.9446 - val_accuracy: 0.9452
#
# Epoch 00084: val_loss did not improve from 2.45845
# Epoch 85/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5244 - dice_coef: 0.9598 - accuracy: 0.9605 - val_loss: 2.5887 - val_dice_coef: 0.9594 - val_accuracy: 0.9600
#
# Epoch 00085: val_loss did not improve from 2.45845
# Epoch 86/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4872 - dice_coef: 0.9607 - accuracy: 0.9613 - val_loss: 2.6490 - val_dice_coef: 0.9595 - val_accuracy: 0.9599
#
# Epoch 00086: val_loss did not improve from 2.45845
# Epoch 87/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5356 - dice_coef: 0.9608 - accuracy: 0.9613 - val_loss: 2.4917 - val_dice_coef: 0.9556 - val_accuracy: 0.9562
#
# Epoch 00087: val_loss did not improve from 2.45845
# Epoch 88/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5311 - dice_coef: 0.9608 - accuracy: 0.9614 - val_loss: 2.5869 - val_dice_coef: 0.9541 - val_accuracy: 0.9545
#
# Epoch 00088: val_loss did not improve from 2.45845
# Epoch 89/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5102 - dice_coef: 0.9596 - accuracy: 0.9601 - val_loss: 2.5733 - val_dice_coef: 0.9575 - val_accuracy: 0.9580
#
# Epoch 00089: val_loss did not improve from 2.45845
# Epoch 90/100
# 420/420 [==============================] - 180s 428ms/step - loss: 2.5299 - dice_coef: 0.9589 - accuracy: 0.9596 - val_loss: 2.5220 - val_dice_coef: 0.9583 - val_accuracy: 0.9588
#
# Epoch 00090: val_loss did not improve from 2.45845
# Epoch 91/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4980 - dice_coef: 0.9630 - accuracy: 0.9636 - val_loss: 2.5384 - val_dice_coef: 0.9566 - val_accuracy: 0.9573
#
# Epoch 00091: val_loss did not improve from 2.45845
# Epoch 92/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4430 - dice_coef: 0.9619 - accuracy: 0.9625 - val_loss: 2.5167 - val_dice_coef: 0.9539 - val_accuracy: 0.9546
#
# Epoch 00092: val_loss did not improve from 2.45845
# Epoch 93/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4396 - dice_coef: 0.9615 - accuracy: 0.9621 - val_loss: 2.7243 - val_dice_coef: 0.8957 - val_accuracy: 0.8966
#
# Epoch 00093: val_loss did not improve from 2.45845
# Epoch 94/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4426 - dice_coef: 0.9621 - accuracy: 0.9627 - val_loss: 2.5413 - val_dice_coef: 0.9587 - val_accuracy: 0.9591
#
# Epoch 00094: val_loss did not improve from 2.45845
# Epoch 95/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4966 - dice_coef: 0.9625 - accuracy: 0.9631 - val_loss: 2.5507 - val_dice_coef: 0.9590 - val_accuracy: 0.9594
#
# Epoch 00095: val_loss did not improve from 2.45845
# Epoch 96/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4804 - dice_coef: 0.9584 - accuracy: 0.9591 - val_loss: 2.5297 - val_dice_coef: 0.9611 - val_accuracy: 0.9616
#
# Epoch 00096: val_loss did not improve from 2.45845
# Epoch 97/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4715 - dice_coef: 0.9596 - accuracy: 0.9602 - val_loss: 2.5322 - val_dice_coef: 0.9551 - val_accuracy: 0.9555
#
# Epoch 00097: val_loss did not improve from 2.45845
# Epoch 98/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.4852 - dice_coef: 0.9598 - accuracy: 0.9604 - val_loss: 2.6474 - val_dice_coef: 0.9585 - val_accuracy: 0.9590
#
# Epoch 00098: val_loss did not improve from 2.45845
# Epoch 99/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5115 - dice_coef: 0.9597 - accuracy: 0.9603 - val_loss: 2.5503 - val_dice_coef: 0.9565 - val_accuracy: 0.9569
#
# Epoch 00099: val_loss did not improve from 2.45845
# Epoch 100/100
# 420/420 [==============================] - 179s 427ms/step - loss: 2.5286 - dice_coef: 0.9598 - accuracy: 0.9604 - val_loss: 2.5332 - val_dice_coef: 0.9472 - val_accuracy: 0.9479
#
# Epoch 00100: val_loss did not improve from 2.45845

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask, Patient_array,Patient_length,title,folder):
  idx = 0
  for i in range(len(Patient_length)):
    temp = []
    for j in range(Patient_length[i]):
      final_output = mask[idx:idx+48]
      idx = idx + 48
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save(folder + title + Patient_array[i], final_output)

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER/UNET/"
model_names = os.listdir(MODELS_PATH)
print(model_names)
# Out:
# ['UNET_ER_0.h5']

# %%
SAVE_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/ER/UNET/"

# %%
# Axis 0 = Folds
# Axis 1 = Class (Strong Intermediate,Weak,Background)
# Axis 2 = Evaluation Technique (Precision, Recall, Dice coefficient)
pixEvaluationTrain = np.empty((0,4,3))
pixEvaluationTest = np.empty((0,4,3))
score = np.zeros((1,4,3))

# %%
fold = 0

for train_index, test_index in fold_split:
  print("FOLD:",fold,"\tTRAIN:", train_index, "TEST:", test_index)
  # Splitting Train and Test data
  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  train_no = [patient_no[i] for i in train_index]
  train_size = [size[i] for i in train_index]

  test_no = [patient_no[i] for i in test_index]
  test_size = [size[i] for i in test_index]

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255

  convertToLabels(TrainY)
  convertToLabels(TestY)

  # Loading corrosponding fold of model
  model = keras.models.load_model(MODELS_PATH + model_names[fold],custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

  # Predicting results using model
  trainResult = model.predict(TrainX, batch_size=8)
  testResult = model.predict(TestX,batch_size=8)

  trainResult = np.argmax(trainResult,axis=-1)
  testResult = np.argmax(testResult,axis=-1)

  # Obtaining pixel-wise results: Precision recall and dice coefficient
  # For TRAIN
  y_true = np.reshape(TrainY,(-1))
  y_pred = np.reshape(trainResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(4):
    score[0][i][0] = prec[3-i]
    score[0][i][1] = recall[3-i]
    score[0][i][2] = dice[3-i]

  pixEvaluationTrain = np.append(pixEvaluationTrain,score,axis=0)
 
  # For TEST
  y_true = np.reshape(TestY,(-1))
  y_pred = np.reshape(testResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(4):
    score[0][i][0] = prec[3-i]
    score[0][i][1] = recall[3-i]
    score[0][i][2] = dice[3-i]

  pixEvaluationTest = np.append(pixEvaluationTest,score,axis=0)

  # Converting predicted labels to required output format
  
  convertFromLabels(trainResult)
  convertFromLabels(testResult)

  # Saving numpy arrays
  path = os.path.join(SAVE_PATH,"Fold " + str(fold))
  os.mkdir(path)
  os.mkdir(path + '/Train')
  os.mkdir(path + '/Test')

  saveNumpyOutput(trainResult, train_no, train_size,"/Train/",path)
  saveNumpyOutput(testResult, test_no, test_size,"/Test/",path)

  fold +=1
# Out:
# FOLD: 0 	TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1]

# %%
print(pixEvaluationTrain.shape)
print(pixEvaluationTest.shape)
print(pixEvaluationTest)
# Out:
# (1, 4, 3)
# (1, 4, 3)
# [[[0.89726281 0.29532795 0.44438846]
#   [0.39303243 0.59722515 0.47407635]
#   [0.31631779 0.43318254 0.36563918]
#   [0.97582288 0.98184625 0.9788253 ]]]

# %%
np.save(SAVE_PATH + "Pixel-wise Metrics Train.npy", pixEvaluationTrain)
np.save(SAVE_PATH + "Pixel-wise Metrics Test.npy", pixEvaluationTest)

# %% [markdown]
# # **DISPLAY**

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 48   # enter between 0- 50 since there are 5 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]
Mask_input = TestGT[id:id+48]
final_output = testResult[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 25  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]
Mask_input = TrainGT[id:id+48]
final_output = trainResult[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
