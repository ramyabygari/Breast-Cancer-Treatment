# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
# !pip install -U keras
# !pip install tensorflow-gpu==2.1.0rc0
import tensorflow as tf
# Out:
# Collecting keras
#   Downloading https://files.pythonhosted.org/packages/ad/fd/6bfe87920d7f4fd475acd28500a42482b6b84479832bdc0fe9e589a60ceb/Keras-2.3.1-py2.py3-none-any.whl (377kB)
#      |████████████████████████████████| 378kB 4.2MB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.18.2)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras) (1.1.0)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.10.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.4.1)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras) (1.12.0)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras) (1.0.8)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)
# Installing collected packages: keras
#   Found existing installation: Keras 2.2.5
#     Uninstalling Keras-2.2.5:
#       Successfully uninstalled Keras-2.2.5
# Successfully installed keras-2.3.1
# Collecting tensorflow-gpu==2.1.0rc0
#   Downloading https://files.pythonhosted.org/packages/f3/24/f94a1b8f779471f53b814a96c5109994ccf65b0103b771ff208c8a937d37/tensorflow_gpu-2.1.0rc0-cp36-cp36m-manylinux2010_x86_64.whl (402.3MB)
#      |████████████████████████████████| 402.3MB 34kB/s
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.12.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (3.2.0)
# Collecting tensorflow-estimator<2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/fc/08/8b927337b7019c374719145d1dceba21a8bb909b93b1ad6f8fb7d22c1ca1/tensorflow_estimator-2.0.1-py2.py3-none-any.whl (449kB)
#      |████████████████████████████████| 450kB 42.4MB/s
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.34.2)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.0.8)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.9.0)
# Collecting tensorboard<2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/76/54/99b9d5d52d5cb732f099baaaf7740403e83fe6b0cedde940fabd2b13d75a/tensorboard-2.0.2-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 34.4MB/s
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.12.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (3.10.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.27.2)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.18.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==2.1.0rc0) (2.10.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.4.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.2.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2.21.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.7.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (46.1.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.0.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.3.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.24.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.2.8)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (4.0)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.4.8)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=d51a998fc0c155da7576fdbc2408e37c64df30e16434d4990a5c2ae54375f5ff
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 2.2.0rc2 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.2.0rc2 has requirement tensorboard<2.3.0,>=2.2.0, but you'll have tensorboard 2.0.2 which is incompatible.
# ERROR: tensorflow 2.2.0rc2 has requirement tensorflow-estimator<2.3.0,>=2.2.0rc0, but you'll have tensorflow-estimator 2.0.1 which is incompatible.
# Installing collected packages: gast, tensorflow-estimator, tensorboard, tensorflow-gpu
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorflow-estimator 2.2.0rc0
#     Uninstalling tensorflow-estimator-2.2.0rc0:
#       Successfully uninstalled tensorflow-estimator-2.2.0rc0
#   Found existing installation: tensorboard 2.2.0
#     Uninstalling tensorboard-2.2.0:
#       Successfully uninstalled tensorboard-2.2.0
# Successfully installed gast-0.2.2 tensorboard-2.0.2 tensorflow-estimator-2.0.1 tensorflow-gpu-2.1.0rc0

# %%
# Function to convert image from greyscale to one hot (i.e. 3 channels)
def convertToOneHot(image):
    num_classes = 3
    shape = image.shape[:2]+(num_classes,)
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c]==0:
          encoded_image[r][c][0] = 1
        elif image[r][c]==128:
          encoded_image[r][c][1] = 1
        else:
          encoded_image[r][c][2] = 1
    return encoded_image

# %%
# Function to convert back from one hot image to greyscale
def convertFromOneHot(image):
    shape = image.shape[:2]
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c][0] == 1:
          encoded_image[r][c] = 0
        elif image[r][c][1] == 1:
          encoded_image[r][c] = 128
        else:
          encoded_image[r][c] = 255
    return encoded_image

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/3 Class ER"

# Train set patients: 230 232 239 242 
TrainX_1 = np.load(PATH + '/ER IHC 263 Images.npy')
TrainY_1 = np.load(PATH + '/ER IHC 263 Masks.npy')
TrainX_2 = np.load(PATH + '/ER IHC 232 Images.npy')
TrainY_2 = np.load(PATH + '/ER IHC 232 Masks.npy')
TrainX_3 = np.load(PATH + '/ER IHC 242 Images.npy')
TrainY_3 = np.load(PATH + '/ER IHC 242 Masks.npy')
TrainX_4 = np.load(PATH + '/ER IHC 230 Images.npy')
TrainY_4 = np.load(PATH + '/ER IHC 230 Masks.npy')

# Test set patients: 221 246 239
TestX_1 = np.load(PATH + '/ER IHC 221 Images.npy')
TestY_1 = np.load(PATH + '/ER IHC 221 Masks.npy')
TestX_2 = np.load(PATH + '/ER IHC 246 Images.npy')
TestY_2 = np.load(PATH + '/ER IHC 246 Masks.npy')
TestX_3 = np.load(PATH + '/ER IHC 239 Images.npy')
TestY_3 = np.load(PATH + '/ER IHC 239 Masks.npy')

# %%
TestX_3.shape
# Out:
# (480, 240, 240, 3)

# %%
TrainX = np.concatenate((TrainX_1, TrainX_2, TrainX_3, TrainX_4), axis=0)
TrainGroundTruth = np.concatenate((TrainY_1, TrainY_2, TrainY_3, TrainY_4), axis=0)
TrainY = []

for img in TrainGroundTruth:
  encoded_img = convertToOneHot(img)
  TrainY.append(encoded_img)

TrainY = np.asarray(TrainY)

TestX = np.concatenate((TestX_1, TestX_2, TestX_3), axis=0)
TestGroundTruth = np.concatenate((TestY_1, TestY_2, TestY_3), axis=0)
TestY = []

for img in TestGroundTruth:
  encoded_img = convertToOneHot(img)
  TestY.append(encoded_img)

TestY = np.asarray(TestY)

ValidX = TrainX[1800:, : ]
ValidY = TrainY[1800:, : ]

TrainX = TrainX[0:1800, : ]
TrainY = TrainY[0:1800, : ]

print(TrainX.shape)
print(TrainY.shape)
print(TestX.shape)
print(TestY.shape)
print(ValidX.shape)
print(ValidY.shape)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 3)
# (1440, 240, 240, 3)
# (1440, 240, 240, 3)
# (120, 240, 240, 3)
# (120, 240, 240, 3)

# %%
TrainX = np.reshape(TrainX,(-1,240, 240,3))
TrainY = np.reshape(TrainY,(-1,240, 240,3))

TrainX = TrainX.astype('float32')/255

TestX = np.reshape(TestX,(-1,240, 240,3))
TestY = np.reshape(TestY,(-1,240, 240,3))

TestX = TestX.astype('float32')/255

ValidX = np.reshape(ValidX,(-1,240, 240,3))
ValidY = np.reshape(ValidY,(-1,240, 240,3))

ValidX = ValidX.astype('float32')/255

# %%
print(TrainX.shape)
print(TrainY.shape)

print(TestX.shape)
print(TestY.shape)

print(ValidX.shape)
print(ValidY.shape)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 3)
# (1440, 240, 240, 3)
# (1440, 240, 240, 3)
# (120, 240, 240, 3)
# (120, 240, 240, 3)

# %%
# !pip install medpy
from keras.layers import *
import keras
from keras.models import Sequential
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from medpy.metric import dc, precision, recall
from keras import Model
# Out:
# Collecting medpy
#   Downloading https://files.pythonhosted.org/packages/3b/70/c1fd5dd60242eee81774696ea7ba4caafac2bad8f028bba94b1af83777d7/MedPy-0.4.0.tar.gz (151kB)
#      |████████████████████████████████| 153kB 5.0MB/s
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.18.2)
# Collecting SimpleITK>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/f8/d8/53338c34f71020725ffb3557846c80af96c29c03bc883551a2565aa68a7c/SimpleITK-1.2.4-cp36-cp36m-manylinux1_x86_64.whl (42.5MB)
#      |████████████████████████████████| 42.5MB 72kB/s
# Building wheels for collected packages: medpy
#   Building wheel for medpy (setup.py) ... done
#   Created wheel for medpy: filename=MedPy-0.4.0-cp36-cp36m-linux_x86_64.whl size=753438 sha256=ac8d37989435f9c61ca3b819c06d38fdde2ec236c94732a962e06c4626b14a9e
#   Stored in directory: /root/.cache/pip/wheels/8c/c9/9c/2c6281c7a72b9fb1570862a4f028af7ce38405008354fbf870
# Successfully built medpy
# Installing collected packages: SimpleITK, medpy
# Successfully installed SimpleITK-1.2.4 medpy-0.4.0
# Using TensorFlow backend.

# %%
def get_conv_block(input_layer,nFilters,size):
    conv1 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(input_layer)
    bn1 = BatchNormalization()(conv1)
    conv2 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(bn1)
    bn2 = BatchNormalization()(conv2)
    return bn2
    
def get_model():    
    input_layer = Input(shape=(240,240,3))
    block1 = get_conv_block(input_layer,32,3)
    mp1 = MaxPooling2D(pool_size=(2, 2))(block1)
    dr1 = Dropout(0.1)(mp1)
    
    block2 = get_conv_block(dr1,64,3)
    mp2 = MaxPooling2D(pool_size=(2, 2))(block2)
    dr2 = Dropout(0.1)(mp2)
    
    block3 = get_conv_block(dr2,128,3)
    mp3 = MaxPooling2D(pool_size=(2, 2))(block3)
    dr3 = Dropout(0.1)(mp3)
    
    block4 = get_conv_block(dr3,256,3)
    mp4 = MaxPooling2D(pool_size=(2, 2))(block4)
    dr4 = Dropout(0.1)(mp4)

    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(dr4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)

    up1 = Conv2DTranspose(256,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(conv5)
    cat1 = concatenate([block4,up1])
    dr1 = Dropout(0.1)(cat1)
    block5 = get_conv_block(dr1,256,3)

    up2 = Conv2DTranspose(128,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block5)
    cat2 = concatenate([block3,up2])
    dr2 = Dropout(0.1)(cat2)
    block6 = get_conv_block(dr2,128,3)
    
    up3 = Conv2DTranspose(64,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block6)
    cat3 = concatenate([block2,up3])
    dr3 = Dropout(0.1)(cat3)
    block7 = get_conv_block(dr3,64,3)
    
    up4 = Conv2DTranspose(32,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block7)
    cat4 = concatenate([block1,up4])
    dr4 = Dropout(0.1)(cat4)
    block8 = get_conv_block(dr4,64,3)

    # conv10 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(block8)
    conv11 = Conv2D(3,(1,1), activation='softmax', padding = 'same')(block8)

    model = Model(input_layer,conv11)
    return model

# %%
model = get_model()
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 240, 240, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 240, 240, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 240, 240, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 240, 240, 32) 9248        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 240, 240, 32) 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 120, 120, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 120, 120, 32) 0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 120, 120, 64) 18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 120, 120, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 120, 120, 64) 36928       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 120, 120, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 60, 60, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 60, 60, 64)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 60, 60, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 60, 60, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 60, 60, 128)  147584      batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 60, 60, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 30, 30, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 30, 30, 128)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 30, 30, 256)  295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 30, 30, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 30, 30, 256)  590080      batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 30, 30, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 15, 15, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 15, 15, 256)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 15, 15, 512)  1180160     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 15, 15, 512)  2359808     conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 30, 30, 256)  1179904     conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 30, 30, 512)  0           batch_normalization_8[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 30, 30, 512)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 30, 30, 256)  1179904     dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 30, 30, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 30, 30, 256)  590080      batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 30, 30, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 60, 60, 128)  295040      batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 60, 60, 256)  0           batch_normalization_6[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 60, 60, 256)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 60, 60, 128)  295040      dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 60, 60, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 60, 60, 128)  147584      batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 60, 60, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 120, 120, 64) 73792       batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 120, 120, 128 0           batch_normalization_4[0][0]
#                                                                  conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 120, 120, 128 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 120, 120, 64) 73792       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 120, 120, 64) 256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 120, 120, 64) 36928       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 120, 120, 64) 256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 240, 240, 32) 18464       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 240, 240, 64) 0           batch_normalization_2[0][0]
#                                                                  conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 240, 240, 64) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 240, 240, 64) 36928       dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 240, 240, 64) 256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 240, 240, 64) 36928       batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 240, 240, 64) 256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 240, 240, 3)  195         batch_normalization_16[0][0]
# ==================================================================================================
# Total params: 8,684,739
# Trainable params: 8,680,771
# Non-trainable params: 3,968
# __________________________________________________________________________________________________

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def combined_loss(y_true, y_pred):
  return (1*K.categorical_crossentropy(y_true, y_pred))+(0.5*tversky_loss(y_true, y_pred))

# %%
import math
from keras.callbacks import EarlyStopping,ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
mc = ModelCheckpoint('Checkpoint.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=True)

# %%
import random
batch_size = 16
def get_batch(batch_size, X_train, Y_train): 
    size_batch = batch_size
    last_index = len(X_train) - 1
    x_train = X_train
    y_train = Y_train

    
    while True:
        batch_data = [[],[]]
        for i in range(0, size_batch):
            random_index = random.randint(0, last_index)
            batch_data[0].append(x_train[random_index])
            batch_data[1].append(y_train[random_index])

        yield (np.array(batch_data[0]), np.array(batch_data[1]))     
        
datagen = get_batch(batch_size, TrainX, TrainY)

# %%
from keras import backend as K      
model.compile(loss=combined_loss, optimizer = "adam", metrics=[dice_coef,'accuracy',combined_loss])

# %%
from math import ceil
num_epoch = 100
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/3 Class/ER"
n_points = len(TrainX)
history = model.fit(datagen, 
                validation_data = (ValidX, ValidY),
                epochs=num_epoch,steps_per_epoch = ceil(n_points / batch_size), callbacks =[es,mc],  shuffle =True)
model.save(MODELS_PATH + '/3 Class_UNET_ER_08_04_2020.h5')
# Out:
# Epoch 1/100
# 113/113 [==============================] - 54s 481ms/step - loss: 0.9718 - dice_coef: 0.8262 - accuracy: 0.9040 - combined_loss: 0.9718 - val_loss: 1.0379 - val_dice_coef: 0.9633 - val_accuracy: 0.9826 - val_combined_loss: 1.0379
#
# Epoch 00001: val_loss improved from inf to 1.03788, saving model to Checkpoint.h5
# Epoch 2/100
# 113/113 [==============================] - 42s 374ms/step - loss: 0.6653 - dice_coef: 0.9113 - accuracy: 0.9349 - combined_loss: 0.6653 - val_loss: 1.2261 - val_dice_coef: 0.8511 - val_accuracy: 0.9359 - val_combined_loss: 1.2261
#
# Epoch 00002: val_loss did not improve from 1.03788
# Epoch 3/100
# 113/113 [==============================] - 42s 374ms/step - loss: 0.5994 - dice_coef: 0.9241 - accuracy: 0.9370 - combined_loss: 0.5994 - val_loss: 0.9397 - val_dice_coef: 0.9864 - val_accuracy: 0.9902 - val_combined_loss: 0.9397
#
# Epoch 00003: val_loss improved from 1.03788 to 0.93973, saving model to Checkpoint.h5
# Epoch 4/100
# 113/113 [==============================] - 42s 374ms/step - loss: 0.5648 - dice_coef: 0.9278 - accuracy: 0.9385 - combined_loss: 0.5648 - val_loss: 0.7893 - val_dice_coef: 0.9877 - val_accuracy: 0.9896 - val_combined_loss: 0.7893
#
# Epoch 00004: val_loss improved from 0.93973 to 0.78930, saving model to Checkpoint.h5
# Epoch 5/100
# 113/113 [==============================] - 42s 374ms/step - loss: 0.5334 - dice_coef: 0.9291 - accuracy: 0.9388 - combined_loss: 0.5334 - val_loss: 0.9772 - val_dice_coef: 0.9874 - val_accuracy: 0.9895 - val_combined_loss: 0.9772
#
# Epoch 00005: val_loss did not improve from 0.78930
# Epoch 6/100
# 113/113 [==============================] - 42s 374ms/step - loss: 0.5248 - dice_coef: 0.9334 - accuracy: 0.9432 - combined_loss: 0.5248 - val_loss: 0.9718 - val_dice_coef: 0.9897 - val_accuracy: 0.9900 - val_combined_loss: 0.9718
#
# Epoch 00006: val_loss did not improve from 0.78930
# Epoch 7/100
# 113/113 [==============================] - 42s 374ms/step - loss: 0.5072 - dice_coef: 0.9373 - accuracy: 0.9456 - combined_loss: 0.5072 - val_loss: 0.9657 - val_dice_coef: 0.9875 - val_accuracy: 0.9897 - val_combined_loss: 0.9657
#
# Epoch 00007: val_loss did not improve from 0.78930
# Epoch 8/100
# 113/113 [==============================] - 42s 374ms/step - loss: 0.4989 - dice_coef: 0.9365 - accuracy: 0.9451 - combined_loss: 0.4989 - val_loss: 0.8422 - val_dice_coef: 0.9849 - val_accuracy: 0.9899 - val_combined_loss: 0.8422
#
# Epoch 00008: val_loss did not improve from 0.78930
# Epoch 9/100
# 113/113 [==============================] - 42s 374ms/step - loss: 0.4985 - dice_coef: 0.9356 - accuracy: 0.9439 - combined_loss: 0.4985 - val_loss: 0.8388 - val_dice_coef: 0.9893 - val_accuracy: 0.9909 - val_combined_loss: 0.8388
#
# Epoch 00009: val_loss did not improve from 0.78930
# Epoch 10/100
# 113/113 [==============================] - 42s 374ms/step - loss: 0.4893 - dice_coef: 0.9371 - accuracy: 0.9453 - combined_loss: 0.4893 - val_loss: 0.9032 - val_dice_coef: 0.9891 - val_accuracy: 0.9903 - val_combined_loss: 0.9032
#
# Epoch 00010: val_loss did not improve from 0.78930
# Epoch 11/100
# 113/113 [==============================] - 42s 374ms/step - loss: 0.4904 - dice_coef: 0.9396 - accuracy: 0.9473 - combined_loss: 0.4904 - val_loss: 0.9171 - val_dice_coef: 0.9896 - val_accuracy: 0.9902 - val_combined_loss: 0.9171
#
# Epoch 00011: val_loss did not improve from 0.78930
# Epoch 12/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.5048 - dice_coef: 0.9376 - accuracy: 0.9458 - combined_loss: 0.5048 - val_loss: 0.8007 - val_dice_coef: 0.9906 - val_accuracy: 0.9910 - val_combined_loss: 0.8007
#
# Epoch 00012: val_loss did not improve from 0.78930
# Epoch 13/100
# 113/113 [==============================] - 42s 374ms/step - loss: 0.4753 - dice_coef: 0.9384 - accuracy: 0.9465 - combined_loss: 0.4753 - val_loss: 0.8173 - val_dice_coef: 0.9892 - val_accuracy: 0.9909 - val_combined_loss: 0.8173
#
# Epoch 00013: val_loss did not improve from 0.78930
# Epoch 14/100
# 113/113 [==============================] - 42s 374ms/step - loss: 0.5084 - dice_coef: 0.9338 - accuracy: 0.9425 - combined_loss: 0.5084 - val_loss: 0.9651 - val_dice_coef: 0.9881 - val_accuracy: 0.9892 - val_combined_loss: 0.9651
#
# Epoch 00014: val_loss did not improve from 0.78930
# Epoch 15/100
# 113/113 [==============================] - 42s 374ms/step - loss: 0.4869 - dice_coef: 0.9365 - accuracy: 0.9448 - combined_loss: 0.4869 - val_loss: 0.7943 - val_dice_coef: 0.9888 - val_accuracy: 0.9907 - val_combined_loss: 0.7943
#
# Epoch 00015: val_loss did not improve from 0.78930
# Epoch 16/100
# 113/113 [==============================] - 42s 374ms/step - loss: 0.4615 - dice_coef: 0.9396 - accuracy: 0.9474 - combined_loss: 0.4615 - val_loss: 0.8067 - val_dice_coef: 0.9886 - val_accuracy: 0.9909 - val_combined_loss: 0.8067
#
# Epoch 00016: val_loss did not improve from 0.78930
# Epoch 17/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.4668 - dice_coef: 0.9394 - accuracy: 0.9473 - combined_loss: 0.4668 - val_loss: 0.7942 - val_dice_coef: 0.9884 - val_accuracy: 0.9908 - val_combined_loss: 0.7942
#
# Epoch 00017: val_loss did not improve from 0.78930
# Epoch 18/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.4599 - dice_coef: 0.9413 - accuracy: 0.9489 - combined_loss: 0.4599 - val_loss: 0.7839 - val_dice_coef: 0.9894 - val_accuracy: 0.9906 - val_combined_loss: 0.7839
#
# Epoch 00018: val_loss improved from 0.78930 to 0.78394, saving model to Checkpoint.h5
# Epoch 19/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.4586 - dice_coef: 0.9435 - accuracy: 0.9503 - combined_loss: 0.4586 - val_loss: 0.8268 - val_dice_coef: 0.9892 - val_accuracy: 0.9907 - val_combined_loss: 0.8268
#
# Epoch 00019: val_loss did not improve from 0.78394
# Epoch 20/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.4660 - dice_coef: 0.9409 - accuracy: 0.9485 - combined_loss: 0.4660 - val_loss: 0.9269 - val_dice_coef: 0.9904 - val_accuracy: 0.9904 - val_combined_loss: 0.9269
#
# Epoch 00020: val_loss did not improve from 0.78394
# Epoch 21/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.4666 - dice_coef: 0.9432 - accuracy: 0.9500 - combined_loss: 0.4666 - val_loss: 0.8240 - val_dice_coef: 0.9860 - val_accuracy: 0.9885 - val_combined_loss: 0.8240
#
# Epoch 00021: val_loss did not improve from 0.78394
# Epoch 22/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.4602 - dice_coef: 0.9427 - accuracy: 0.9500 - combined_loss: 0.4602 - val_loss: 0.8163 - val_dice_coef: 0.9893 - val_accuracy: 0.9911 - val_combined_loss: 0.8163
#
# Epoch 00022: val_loss did not improve from 0.78394
# Epoch 23/100
# 113/113 [==============================] - 42s 374ms/step - loss: 0.4600 - dice_coef: 0.9414 - accuracy: 0.9489 - combined_loss: 0.4600 - val_loss: 0.7873 - val_dice_coef: 0.9896 - val_accuracy: 0.9908 - val_combined_loss: 0.7873
#
# Epoch 00023: val_loss did not improve from 0.78394
# Epoch 24/100
# 113/113 [==============================] - 42s 374ms/step - loss: 0.4566 - dice_coef: 0.9417 - accuracy: 0.9491 - combined_loss: 0.4566 - val_loss: 0.8105 - val_dice_coef: 0.9900 - val_accuracy: 0.9904 - val_combined_loss: 0.8105
#
# Epoch 00024: val_loss did not improve from 0.78394
# Epoch 25/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.4368 - dice_coef: 0.9455 - accuracy: 0.9523 - combined_loss: 0.4368 - val_loss: 1.0303 - val_dice_coef: 0.9889 - val_accuracy: 0.9888 - val_combined_loss: 1.0303
#
# Epoch 00025: val_loss did not improve from 0.78394
# Epoch 26/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.4496 - dice_coef: 0.9422 - accuracy: 0.9499 - combined_loss: 0.4496 - val_loss: 0.8867 - val_dice_coef: 0.9882 - val_accuracy: 0.9903 - val_combined_loss: 0.8867
#
# Epoch 00026: val_loss did not improve from 0.78394
# Epoch 27/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.4402 - dice_coef: 0.9449 - accuracy: 0.9518 - combined_loss: 0.4402 - val_loss: 0.9536 - val_dice_coef: 0.9886 - val_accuracy: 0.9896 - val_combined_loss: 0.9536
#
# Epoch 00027: val_loss did not improve from 0.78394
# Epoch 28/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.4430 - dice_coef: 0.9442 - accuracy: 0.9514 - combined_loss: 0.4430 - val_loss: 0.7880 - val_dice_coef: 0.9888 - val_accuracy: 0.9901 - val_combined_loss: 0.7880
#
# Epoch 00028: val_loss did not improve from 0.78394
# Epoch 29/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.4457 - dice_coef: 0.9426 - accuracy: 0.9500 - combined_loss: 0.4457 - val_loss: 0.7991 - val_dice_coef: 0.9874 - val_accuracy: 0.9894 - val_combined_loss: 0.7991
#
# Epoch 00029: val_loss did not improve from 0.78394
# Epoch 30/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.4255 - dice_coef: 0.9441 - accuracy: 0.9514 - combined_loss: 0.4255 - val_loss: 0.7833 - val_dice_coef: 0.9881 - val_accuracy: 0.9899 - val_combined_loss: 0.7833
#
# Epoch 00030: val_loss improved from 0.78394 to 0.78331, saving model to Checkpoint.h5
# Epoch 31/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.4209 - dice_coef: 0.9487 - accuracy: 0.9552 - combined_loss: 0.4209 - val_loss: 0.8259 - val_dice_coef: 0.9906 - val_accuracy: 0.9906 - val_combined_loss: 0.8259
#
# Epoch 00031: val_loss did not improve from 0.78331
# Epoch 32/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.4224 - dice_coef: 0.9471 - accuracy: 0.9539 - combined_loss: 0.4224 - val_loss: 0.9271 - val_dice_coef: 0.9904 - val_accuracy: 0.9901 - val_combined_loss: 0.9271
#
# Epoch 00032: val_loss did not improve from 0.78331
# Epoch 33/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.3949 - dice_coef: 0.9504 - accuracy: 0.9569 - combined_loss: 0.3949 - val_loss: 0.8367 - val_dice_coef: 0.9907 - val_accuracy: 0.9911 - val_combined_loss: 0.8367
#
# Epoch 00033: val_loss did not improve from 0.78331
# Epoch 34/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.3917 - dice_coef: 0.9501 - accuracy: 0.9566 - combined_loss: 0.3917 - val_loss: 0.8085 - val_dice_coef: 0.9899 - val_accuracy: 0.9907 - val_combined_loss: 0.8085
#
# Epoch 00034: val_loss did not improve from 0.78331
# Epoch 35/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.4138 - dice_coef: 0.9489 - accuracy: 0.9554 - combined_loss: 0.4138 - val_loss: 0.9094 - val_dice_coef: 0.9855 - val_accuracy: 0.9904 - val_combined_loss: 0.9094
#
# Epoch 00035: val_loss did not improve from 0.78331
# Epoch 36/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.4053 - dice_coef: 0.9495 - accuracy: 0.9558 - combined_loss: 0.4053 - val_loss: 0.9027 - val_dice_coef: 0.9893 - val_accuracy: 0.9901 - val_combined_loss: 0.9027
#
# Epoch 00036: val_loss did not improve from 0.78331
# Epoch 37/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.3869 - dice_coef: 0.9502 - accuracy: 0.9570 - combined_loss: 0.3869 - val_loss: 0.7762 - val_dice_coef: 0.9888 - val_accuracy: 0.9891 - val_combined_loss: 0.7762
#
# Epoch 00037: val_loss improved from 0.78331 to 0.77624, saving model to Checkpoint.h5
# Epoch 38/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.3811 - dice_coef: 0.9527 - accuracy: 0.9586 - combined_loss: 0.3811 - val_loss: 0.9776 - val_dice_coef: 0.9856 - val_accuracy: 0.9895 - val_combined_loss: 0.9776
#
# Epoch 00038: val_loss did not improve from 0.77624
# Epoch 39/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.3799 - dice_coef: 0.9527 - accuracy: 0.9588 - combined_loss: 0.3799 - val_loss: 0.7847 - val_dice_coef: 0.9900 - val_accuracy: 0.9911 - val_combined_loss: 0.7847
#
# Epoch 00039: val_loss did not improve from 0.77624
# Epoch 40/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.3465 - dice_coef: 0.9555 - accuracy: 0.9614 - combined_loss: 0.3465 - val_loss: 0.8351 - val_dice_coef: 0.9876 - val_accuracy: 0.9899 - val_combined_loss: 0.8351
#
# Epoch 00040: val_loss did not improve from 0.77624
# Epoch 41/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.3688 - dice_coef: 0.9524 - accuracy: 0.9586 - combined_loss: 0.3688 - val_loss: 0.8018 - val_dice_coef: 0.9870 - val_accuracy: 0.9889 - val_combined_loss: 0.8018
#
# Epoch 00041: val_loss did not improve from 0.77624
# Epoch 42/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.3641 - dice_coef: 0.9555 - accuracy: 0.9610 - combined_loss: 0.3641 - val_loss: 0.8708 - val_dice_coef: 0.9903 - val_accuracy: 0.9905 - val_combined_loss: 0.8708
#
# Epoch 00042: val_loss did not improve from 0.77624
# Epoch 43/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.3516 - dice_coef: 0.9552 - accuracy: 0.9610 - combined_loss: 0.3516 - val_loss: 0.7991 - val_dice_coef: 0.9905 - val_accuracy: 0.9908 - val_combined_loss: 0.7991
#
# Epoch 00043: val_loss did not improve from 0.77624
# Epoch 44/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.3487 - dice_coef: 0.9553 - accuracy: 0.9611 - combined_loss: 0.3487 - val_loss: 0.8109 - val_dice_coef: 0.9902 - val_accuracy: 0.9903 - val_combined_loss: 0.8109
#
# Epoch 00044: val_loss did not improve from 0.77624
# Epoch 45/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.3187 - dice_coef: 0.9581 - accuracy: 0.9637 - combined_loss: 0.3187 - val_loss: 0.8124 - val_dice_coef: 0.9889 - val_accuracy: 0.9907 - val_combined_loss: 0.8124
#
# Epoch 00045: val_loss did not improve from 0.77624
# Epoch 46/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.3207 - dice_coef: 0.9583 - accuracy: 0.9638 - combined_loss: 0.3207 - val_loss: 0.7889 - val_dice_coef: 0.9900 - val_accuracy: 0.9907 - val_combined_loss: 0.7889
#
# Epoch 00046: val_loss did not improve from 0.77624
# Epoch 47/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.3059 - dice_coef: 0.9604 - accuracy: 0.9656 - combined_loss: 0.3059 - val_loss: 0.7829 - val_dice_coef: 0.9900 - val_accuracy: 0.9905 - val_combined_loss: 0.7829
#
# Epoch 00047: val_loss did not improve from 0.77624
# Epoch 48/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.2953 - dice_coef: 0.9597 - accuracy: 0.9651 - combined_loss: 0.2953 - val_loss: 0.8025 - val_dice_coef: 0.9897 - val_accuracy: 0.9899 - val_combined_loss: 0.8025
#
# Epoch 00048: val_loss did not improve from 0.77624
# Epoch 49/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.2932 - dice_coef: 0.9635 - accuracy: 0.9682 - combined_loss: 0.2932 - val_loss: 0.8846 - val_dice_coef: 0.9885 - val_accuracy: 0.9901 - val_combined_loss: 0.8846
#
# Epoch 00049: val_loss did not improve from 0.77624
# Epoch 50/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.2935 - dice_coef: 0.9618 - accuracy: 0.9668 - combined_loss: 0.2935 - val_loss: 0.7716 - val_dice_coef: 0.9904 - val_accuracy: 0.9907 - val_combined_loss: 0.7716
#
# Epoch 00050: val_loss improved from 0.77624 to 0.77161, saving model to Checkpoint.h5
# Epoch 51/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.2806 - dice_coef: 0.9639 - accuracy: 0.9686 - combined_loss: 0.2806 - val_loss: 0.7943 - val_dice_coef: 0.9887 - val_accuracy: 0.9888 - val_combined_loss: 0.7943
#
# Epoch 00051: val_loss did not improve from 0.77161
# Epoch 52/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.2699 - dice_coef: 0.9636 - accuracy: 0.9685 - combined_loss: 0.2699 - val_loss: 0.8336 - val_dice_coef: 0.9912 - val_accuracy: 0.9911 - val_combined_loss: 0.8336
#
# Epoch 00052: val_loss did not improve from 0.77161
# Epoch 53/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.2635 - dice_coef: 0.9657 - accuracy: 0.9702 - combined_loss: 0.2635 - val_loss: 0.8047 - val_dice_coef: 0.9907 - val_accuracy: 0.9908 - val_combined_loss: 0.8047
#
# Epoch 00053: val_loss did not improve from 0.77161
# Epoch 54/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.2688 - dice_coef: 0.9637 - accuracy: 0.9685 - combined_loss: 0.2688 - val_loss: 0.8922 - val_dice_coef: 0.9873 - val_accuracy: 0.9890 - val_combined_loss: 0.8922
#
# Epoch 00054: val_loss did not improve from 0.77161
# Epoch 55/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.2555 - dice_coef: 0.9644 - accuracy: 0.9693 - combined_loss: 0.2555 - val_loss: 0.7934 - val_dice_coef: 0.9904 - val_accuracy: 0.9904 - val_combined_loss: 0.7934
#
# Epoch 00055: val_loss did not improve from 0.77161
# Epoch 56/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.2381 - dice_coef: 0.9688 - accuracy: 0.9729 - combined_loss: 0.2381 - val_loss: 0.7920 - val_dice_coef: 0.9908 - val_accuracy: 0.9910 - val_combined_loss: 0.7920
#
# Epoch 00056: val_loss did not improve from 0.77161
# Epoch 57/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.2337 - dice_coef: 0.9680 - accuracy: 0.9724 - combined_loss: 0.2337 - val_loss: 0.7769 - val_dice_coef: 0.9902 - val_accuracy: 0.9907 - val_combined_loss: 0.7769
#
# Epoch 00057: val_loss did not improve from 0.77161
# Epoch 58/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.2186 - dice_coef: 0.9702 - accuracy: 0.9742 - combined_loss: 0.2186 - val_loss: 0.8350 - val_dice_coef: 0.9909 - val_accuracy: 0.9910 - val_combined_loss: 0.8350
#
# Epoch 00058: val_loss did not improve from 0.77161
# Epoch 59/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.2194 - dice_coef: 0.9677 - accuracy: 0.9723 - combined_loss: 0.2194 - val_loss: 0.7924 - val_dice_coef: 0.9883 - val_accuracy: 0.9892 - val_combined_loss: 0.7924
#
# Epoch 00059: val_loss did not improve from 0.77161
# Epoch 60/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.2130 - dice_coef: 0.9712 - accuracy: 0.9750 - combined_loss: 0.2130 - val_loss: 0.8265 - val_dice_coef: 0.9867 - val_accuracy: 0.9879 - val_combined_loss: 0.8265
#
# Epoch 00060: val_loss did not improve from 0.77161
# Epoch 61/100
# 113/113 [==============================] - 42s 372ms/step - loss: 0.2116 - dice_coef: 0.9706 - accuracy: 0.9746 - combined_loss: 0.2116 - val_loss: 0.9171 - val_dice_coef: 0.9900 - val_accuracy: 0.9899 - val_combined_loss: 0.9171
#
# Epoch 00061: val_loss did not improve from 0.77161
# Epoch 62/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.1949 - dice_coef: 0.9732 - accuracy: 0.9768 - combined_loss: 0.1949 - val_loss: 0.8104 - val_dice_coef: 0.9892 - val_accuracy: 0.9891 - val_combined_loss: 0.8104
#
# Epoch 00062: val_loss did not improve from 0.77161
# Epoch 63/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.1926 - dice_coef: 0.9737 - accuracy: 0.9773 - combined_loss: 0.1926 - val_loss: 0.8262 - val_dice_coef: 0.9899 - val_accuracy: 0.9899 - val_combined_loss: 0.8262
#
# Epoch 00063: val_loss did not improve from 0.77161
# Epoch 64/100
# 113/113 [==============================] - 42s 372ms/step - loss: 0.2020 - dice_coef: 0.9728 - accuracy: 0.9763 - combined_loss: 0.2020 - val_loss: 0.7997 - val_dice_coef: 0.9871 - val_accuracy: 0.9871 - val_combined_loss: 0.7997
#
# Epoch 00064: val_loss did not improve from 0.77161
# Epoch 65/100
# 113/113 [==============================] - 42s 372ms/step - loss: 0.1799 - dice_coef: 0.9739 - accuracy: 0.9775 - combined_loss: 0.1799 - val_loss: 0.8015 - val_dice_coef: 0.9896 - val_accuracy: 0.9894 - val_combined_loss: 0.8015
#
# Epoch 00065: val_loss did not improve from 0.77161
# Epoch 66/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.1681 - dice_coef: 0.9763 - accuracy: 0.9795 - combined_loss: 0.1681 - val_loss: 0.8108 - val_dice_coef: 0.9905 - val_accuracy: 0.9903 - val_combined_loss: 0.8108
#
# Epoch 00066: val_loss did not improve from 0.77161
# Epoch 67/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.1717 - dice_coef: 0.9765 - accuracy: 0.9795 - combined_loss: 0.1717 - val_loss: 0.8397 - val_dice_coef: 0.9903 - val_accuracy: 0.9902 - val_combined_loss: 0.8397
#
# Epoch 00067: val_loss did not improve from 0.77161
# Epoch 68/100
# 113/113 [==============================] - 42s 372ms/step - loss: 0.1847 - dice_coef: 0.9741 - accuracy: 0.9775 - combined_loss: 0.1847 - val_loss: 0.9218 - val_dice_coef: 0.9906 - val_accuracy: 0.9902 - val_combined_loss: 0.9218
#
# Epoch 00068: val_loss did not improve from 0.77161
# Epoch 69/100
# 113/113 [==============================] - 42s 372ms/step - loss: 0.1696 - dice_coef: 0.9757 - accuracy: 0.9790 - combined_loss: 0.1696 - val_loss: 0.8401 - val_dice_coef: 0.9852 - val_accuracy: 0.9854 - val_combined_loss: 0.8401
#
# Epoch 00069: val_loss did not improve from 0.77161
# Epoch 70/100
# 113/113 [==============================] - 42s 372ms/step - loss: 0.1579 - dice_coef: 0.9775 - accuracy: 0.9806 - combined_loss: 0.1579 - val_loss: 0.8042 - val_dice_coef: 0.9907 - val_accuracy: 0.9906 - val_combined_loss: 0.8042
#
# Epoch 00070: val_loss did not improve from 0.77161
# Epoch 71/100
# 113/113 [==============================] - 42s 372ms/step - loss: 0.1557 - dice_coef: 0.9790 - accuracy: 0.9818 - combined_loss: 0.1557 - val_loss: 0.8188 - val_dice_coef: 0.9899 - val_accuracy: 0.9899 - val_combined_loss: 0.8188
#
# Epoch 00071: val_loss did not improve from 0.77161
# Epoch 72/100
# 113/113 [==============================] - 42s 372ms/step - loss: 0.1469 - dice_coef: 0.9791 - accuracy: 0.9820 - combined_loss: 0.1469 - val_loss: 0.7978 - val_dice_coef: 0.9890 - val_accuracy: 0.9888 - val_combined_loss: 0.7978
#
# Epoch 00072: val_loss did not improve from 0.77161
# Epoch 73/100
# 113/113 [==============================] - 42s 372ms/step - loss: 0.1502 - dice_coef: 0.9789 - accuracy: 0.9817 - combined_loss: 0.1502 - val_loss: 0.7841 - val_dice_coef: 0.9903 - val_accuracy: 0.9903 - val_combined_loss: 0.7841
#
# Epoch 00073: val_loss did not improve from 0.77161
# Epoch 74/100
# 113/113 [==============================] - 42s 372ms/step - loss: 0.1386 - dice_coef: 0.9798 - accuracy: 0.9825 - combined_loss: 0.1386 - val_loss: 0.8714 - val_dice_coef: 0.9890 - val_accuracy: 0.9889 - val_combined_loss: 0.8714
#
# Epoch 00074: val_loss did not improve from 0.77161
# Epoch 75/100
# 113/113 [==============================] - 42s 374ms/step - loss: 0.1419 - dice_coef: 0.9798 - accuracy: 0.9825 - combined_loss: 0.1419 - val_loss: 0.8041 - val_dice_coef: 0.9898 - val_accuracy: 0.9895 - val_combined_loss: 0.8041
#
# Epoch 00075: val_loss did not improve from 0.77161
# Epoch 76/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.1312 - dice_coef: 0.9810 - accuracy: 0.9836 - combined_loss: 0.1312 - val_loss: 0.8215 - val_dice_coef: 0.9909 - val_accuracy: 0.9907 - val_combined_loss: 0.8215
#
# Epoch 00076: val_loss did not improve from 0.77161
# Epoch 77/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.1630 - dice_coef: 0.9776 - accuracy: 0.9805 - combined_loss: 0.1630 - val_loss: 0.8383 - val_dice_coef: 0.9892 - val_accuracy: 0.9889 - val_combined_loss: 0.8383
#
# Epoch 00077: val_loss did not improve from 0.77161
# Epoch 78/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.1519 - dice_coef: 0.9787 - accuracy: 0.9814 - combined_loss: 0.1519 - val_loss: 0.9035 - val_dice_coef: 0.9900 - val_accuracy: 0.9896 - val_combined_loss: 0.9035
#
# Epoch 00078: val_loss did not improve from 0.77161
# Epoch 79/100
# 113/113 [==============================] - 42s 373ms/step - loss: 0.1366 - dice_coef: 0.9798 - accuracy: 0.9826 - combined_loss: 0.1366 - val_loss: 0.8143 - val_dice_coef: 0.9905 - val_accuracy: 0.9903 - val_combined_loss: 0.8143
#
# Epoch 00079: val_loss did not improve from 0.77161
# Epoch 80/100
# 113/113 [==============================] - 42s 372ms/step - loss: 0.1349 - dice_coef: 0.9803 - accuracy: 0.9830 - combined_loss: 0.1349 - val_loss: 0.8185 - val_dice_coef: 0.9906 - val_accuracy: 0.9903 - val_combined_loss: 0.8185
#
# Epoch 00080: val_loss did not improve from 0.77161
# Epoch 00080: early stopping

# %%
train_loss = history.history['loss']
train_acc = history.history['accuracy']
val_loss = history.history['val_loss']
val_acc = history.history['val_accuracy']
xc=range(len(train_loss))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_loss)
plt.plot(xc, val_loss)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(['train','val'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_acc)
plt.plot(xc, val_acc)
plt.xlabel("Epoch")
plt.ylabel("Acc")
plt.legend(['train','val'])

# %%
# MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models"
# model = keras.models.load_model(MODELS_PATH+'/UNET_ER_20_03_03_v5.h5',custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

# %%
# Function to find the most probable class of an image pixel by pixel
def ClassFinder(img):
  result = np.zeros(img.shape, dtype=np.uint8)
  for r in range(len(img)):
    for c in range(len(img[0])):
      idx = np.argmax(img[r][c])
      result[r][c][idx]=1
      
  return result

# %%
TrainX = np.concatenate((TrainX,ValidX))
TrainY = np.concatenate((TrainY,ValidY))
train_result = model.predict(TrainX, batch_size=16)
print(np.shape(train_result))
Train_predict = [ ]
for img in train_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_predict.append(encoded_img)

Predicted_images = np.asarray(Train_predict)
print(Predicted_images.shape)
np.unique(Predicted_images)
# dice = dc(train_result, TrainY)
# pre  = precision(train_result,TrainY)
# re   = recall(train_result,TrainY)
# print('Train dc: '  + str(dice))
# print('Train pre: ' + str(pre))
# print('Train re: '  + str(re))
# Out:
# (1920, 240, 240, 3)
# (1920, 240, 240)
# array([  0, 128, 255], dtype=uint8)

# %%
test_result = model.predict(TestX, batch_size=16)
print(np.shape(test_result))

Test_predict = [ ]
for img in test_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_predict.append(encoded_img)

Predicted_images_test = np.asarray(Test_predict)
print(Predicted_images_test.shape)
np.unique(Predicted_images_test)
# dice = dc(test_result, TestY)
# pre  = precision(test_result,TestY)
# re   = recall(test_result,TestY)
# print('Test dc: '  + str(dice))
# print('Test pre: ' + str(pre))
# print('Test re: '  + str(re))
# Out:
# (1440, 240, 240, 3)
# (1440, 240, 240)
# array([  0, 128, 255], dtype=uint8)

# %%
from sklearn.metrics import confusion_matrix
def get_confusion_matrix(Actual, Predicted):
  ActualY = np.reshape(Actual,(-1, Actual.shape[3]))
  PredY = np.reshape(Predicted,(-1, Predicted.shape[3]))
  matrix = confusion_matrix(ActualY.argmax(axis = 1), PredY.argmax(axis = 1))
  return matrix

def get_precision(confusion_matrix):
  precision = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 0)
  nan_indices = np.isnan(precision)
  precision[nan_indices] = 0
  return precision

def get_recall(confusion_matrix):
  recall = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 1)
  nan_indices = np.isnan(recall)
  recall[nan_indices] = 0
  return recall

# %%
test_matrix = get_confusion_matrix(TestY, test_result)
train_matrix = get_confusion_matrix(TrainY, train_result)
print(test_matrix)
print(train_matrix)
# TestY.shape[3]
# test_result.shape
# Out:
# [[74918091   196537   675065]
#  [ 1195684   760875   729191]
#  [  975685    61438  3431434]]
# [[95990897   285647   298205]
#  [ 1062297  5394592    21062]
#  [  530132    20482  6988686]]

# %%
np.unique(Predicted_images_test)
# Out:
# array([  0, 128, 255], dtype=uint8)

# %%
test_precision = get_precision(test_matrix)
print('Test Precision')
print(test_precision)
test_recall = get_recall(test_matrix)
print('Test Recall')
print(test_recall)
train_precision = get_precision(train_matrix)
print('Train Precision')
print(train_precision)
train_recall = get_recall(train_matrix)
print('Train Recall')
print(train_recall)
# Out:
# Test Precision
# [0.97183313 0.74679786 0.70960587]
# Test Recall
# [0.98849973 0.28330075 0.76790651]
# Train Precision
# [0.98368134 0.94629995 0.95631239]
# Train Recall
# [0.9939544  0.83276209 0.92696749]

# %%
# weight_matrix = np.zeros((3,1))
# weight_matrix[0] = 0.6
# weight_matrix[1] = 0.2
# weight_matrix[2] = 0.2
# print(weight_matrix.shape)

# %%
weight_matrix = np.zeros((3,1))
weight_matrix[0] = 1/3
weight_matrix[1] = 1/3
weight_matrix[2] = 1/3
print(weight_matrix.shape)
# Out:
# (3, 1)

# %%
def get_overall_precision(precision, weights):
  final_precision = np.dot(precision,weights)
  return final_precision

def get_overall_recall(recall, weights):
  final_recall = np.dot(recall ,weights)
  return final_recall

# %%
final_test_precision  = get_overall_precision(test_precision, weight_matrix)
final_test_recall     = get_overall_recall(test_recall, weight_matrix)
final_train_precision = get_overall_precision(train_precision, weight_matrix)
final_train_recall    = get_overall_recall(train_recall, weight_matrix)
print('Final Test Precision')
print(final_test_precision)
print('Final Test Recall')
print(final_test_recall)
print('Final Train Precision')
print(final_train_precision)
print('Final Train Recall')
print(final_train_recall)
# Out:
# Final Test Precision
# [0.80941229]
# Final Test Recall
# [0.67990233]
# Final Train Precision
# [0.96209789]
# Final Train Recall
# [0.91789466]

# %%
from scipy.stats import hmean

def dice_coefficient(precision, recall):
  return hmean(np.asarray([precision , recall]))

# %%
test_dice_coeff = dice_coefficient(final_test_precision, final_test_recall)
print('Test Dice coeff')
print(test_dice_coeff)

train_dice_coeff = dice_coefficient(final_train_precision, final_train_recall)
print('Train Dice coeff')
print(train_dice_coeff)
# Out:
# Test Dice coeff
# [0.73902625]
# Train Dice coeff
# [0.93947661]

# %%
copy1  = np.copy(TestX [250])
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
copy3 = np.reshape(copy2,(240, 240,3))
Img = cv2.cvtColor(copy3,cv2.COLOR_BGR2RGB)

Mask = TestGroundTruth[250]

Predicted_Mask = Predicted_images_test[250] 

plt.subplot(131).imshow(Img)
plt.subplot(132).imshow(Mask,'gray')
plt.subplot(133).imshow(Predicted_Mask,'gray')

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask, folder):
  num = mask.shape[0]/480
  for id in range(int(num)):
    temp = []
    for i in range(id, id+10):
      idx = i * 48
      final_output = mask[idx:idx+48]
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save("/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/ER/UNET/3 Class" + folder+ "/ER1 Patient " + str(id), final_output)

# %%
# saving predicted outputs as numpy arrays for test images
saveNumpyOutput(Predicted_images,'/Train')
saveNumpyOutput(Predicted_images_test,'/Test')

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 25   # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]

Mask_input = TestY[id:id+48]
Test_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Test_Actual)
print(Mask_input.shape)

final_output = Predicted_images_test[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# (48, 240, 240, 3)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0. 128. 255.]

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 2  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]

Mask_input = TrainY[id:id+48]
Train_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Train_Actual)
print(Mask_input.shape)

final_output = Predicted_images[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 3)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0. 128. 255.]

# %%
SAVE_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Predicted Images/ER/UNET/3 Class/8-04-2020"
def saveImageOutput(patients, GroundTruth, Predicted, folder):
  totalimages = patients * 10
  for id in range(totalimages):
    index = id * 48
    Mask_input = GroundTruth[index:index+48]
    GroundTruth_Actual = [ ]
    for img in Mask_input:
      img = ClassFinder(img)
      encoded_img = convertFromOneHot(img)
      GroundTruth_Actual.append(encoded_img)
    Mask_input = np.asarray(GroundTruth_Actual)
    final_output = Predicted[index:index+48]
    Mask_input   = stitchMaskPatches(Mask_input)
    final_output = stitchMaskPatches(final_output)
    cv2.imwrite(SAVE_PATH + '/Ground Truth' + folder + '/Image '+ str(id) + '.png', Mask_input)
    cv2.imwrite(SAVE_PATH +  '/Predicted Mask'+ folder + '/Image '+ str(id) + '.png', final_output)

# %%
saveImageOutput(3, TestY, Predicted_images_test, '/Test' )
saveImageOutput(4, TrainY, Predicted_images, '/Train' )
