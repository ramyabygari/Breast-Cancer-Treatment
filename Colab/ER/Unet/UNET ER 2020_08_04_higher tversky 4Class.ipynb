# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
# !pip install -U keras
# !pip install tensorflow-gpu==2.1.0rc0
# Out:
# Collecting keras
#   Downloading https://files.pythonhosted.org/packages/ad/fd/6bfe87920d7f4fd475acd28500a42482b6b84479832bdc0fe9e589a60ceb/Keras-2.3.1-py2.py3-none-any.whl (377kB)
#      |████████████████████████████████| 378kB 3.0MB/s
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.10.0)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras) (1.0.8)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras) (1.1.0)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras) (1.12.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.18.2)
# Installing collected packages: keras
#   Found existing installation: Keras 2.2.5
#     Uninstalling Keras-2.2.5:
#       Successfully uninstalled Keras-2.2.5
# Successfully installed keras-2.3.1
# Collecting tensorflow-gpu==2.1.0rc0
#   Downloading https://files.pythonhosted.org/packages/f3/24/f94a1b8f779471f53b814a96c5109994ccf65b0103b771ff208c8a937d37/tensorflow_gpu-2.1.0rc0-cp36-cp36m-manylinux2010_x86_64.whl (402.3MB)
#      |████████████████████████████████| 402.3MB 35kB/s
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.18.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.12.1)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.0.8)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (3.10.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.12.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.27.2)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (3.2.0)
# Collecting tensorboard<2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/76/54/99b9d5d52d5cb732f099baaaf7740403e83fe6b0cedde940fabd2b13d75a/tensorboard-2.0.2-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 45.7MB/s
# Collecting tensorflow-estimator<2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/fc/08/8b927337b7019c374719145d1dceba21a8bb909b93b1ad6f8fb7d22c1ca1/tensorflow_estimator-2.0.1-py2.py3-none-any.whl (449kB)
#      |████████████████████████████████| 450kB 51.8MB/s
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.34.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.9.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.8.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==2.1.0rc0) (2.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorflow-gpu==2.1.0rc0) (46.1.3)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.7.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2.21.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.2.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.4.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.0.1)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (4.0)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2019.11.28)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=1864c1ff4b6aeeb99849ed645fe00b3562445f693ca24bd78a4863e5c34fbde3
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 2.2.0rc2 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.2.0rc2 has requirement tensorboard<2.3.0,>=2.2.0, but you'll have tensorboard 2.0.2 which is incompatible.
# ERROR: tensorflow 2.2.0rc2 has requirement tensorflow-estimator<2.3.0,>=2.2.0rc0, but you'll have tensorflow-estimator 2.0.1 which is incompatible.
# Installing collected packages: gast, tensorboard, tensorflow-estimator, tensorflow-gpu
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorboard 2.2.0
#     Uninstalling tensorboard-2.2.0:
#       Successfully uninstalled tensorboard-2.2.0
#   Found existing installation: tensorflow-estimator 2.2.0rc0
#     Uninstalling tensorflow-estimator-2.2.0rc0:
#       Successfully uninstalled tensorflow-estimator-2.2.0rc0
# Successfully installed gast-0.2.2 tensorboard-2.0.2 tensorflow-estimator-2.0.1 tensorflow-gpu-2.1.0rc0

# %%
# Function to convert image from greyscale to one hot (i.e. 3 channels)
def convertToOneHot(image):
    num_classes = 4
    shape = image.shape[:2]+(num_classes,)
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c]==0:
          encoded_image[r][c][0] = 1
        elif image[r][c]==85:
          encoded_image[r][c][1] = 1
        elif image[r][c]==170:
          encoded_image[r][c][2] = 1
        else:
          encoded_image[r][c][3] = 1
    return encoded_image

# %%
# Function to convert back from one hot image to greyscale
def convertFromOneHot(image):
    shape = image.shape[:2]
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c][0] == 1:
          encoded_image[r][c] = 0
        elif image[r][c][1] == 1:
          encoded_image[r][c] = 85
        elif image[r][c][2] == 1:
          encoded_image[r][c] = 170
        else:
          encoded_image[r][c] = 255
    return encoded_image

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/4 Class ER"

# Train set patients: 230 232 239 242 
TrainX_1 = np.load(PATH + '/ER IHC 263 Images.npy')
TrainY_1 = np.load(PATH + '/ER IHC 263 Masks.npy')
TrainX_2 = np.load(PATH + '/ER IHC 232 Images.npy')
TrainY_2 = np.load(PATH + '/ER IHC 232 Masks.npy')
TrainX_3 = np.load(PATH + '/ER IHC 242 Images.npy')
TrainY_3 = np.load(PATH + '/ER IHC 242 Masks.npy')
TrainX_4 = np.load(PATH + '/ER IHC 230 Images.npy')
TrainY_4 = np.load(PATH + '/ER IHC 230 Masks.npy')

# Test set patients: 221 246 263
TestX_1 = np.load(PATH + '/ER IHC 221 Images.npy')
TestY_1 = np.load(PATH + '/ER IHC 221 Masks.npy')
TestX_2 = np.load(PATH + '/ER IHC 246 Images.npy')
TestY_2 = np.load(PATH + '/ER IHC 246 Masks.npy')
TestX_3 = np.load(PATH + '/ER IHC 239 Images.npy')
TestY_3 = np.load(PATH + '/ER IHC 239 Masks.npy')

# %%
TrainX = np.concatenate((TrainX_1, TrainX_2, TrainX_3, TrainX_4), axis=0)
TrainGroundTruth = np.concatenate((TrainY_1, TrainY_2, TrainY_3, TrainY_4), axis=0)
TrainY = []

for img in TrainGroundTruth:
  encoded_img = convertToOneHot(img)
  TrainY.append(encoded_img)

TrainY = np.asarray(TrainY)

TestX = np.concatenate((TestX_1, TestX_2, TestX_3), axis=0)
TestGroundTruth = np.concatenate((TestY_1, TestY_2, TestY_3), axis=0)
TestY = []

for img in TestGroundTruth:
  encoded_img = convertToOneHot(img)
  TestY.append(encoded_img)

TestY = np.asarray(TestY)

ValidX = TrainX[1800:, : ]
ValidY = TrainY[1800:, : ]

TrainX = TrainX[0:1800, : ]
TrainY = TrainY[0:1800, : ]

print(TrainX.shape)
print(TrainY.shape)
print(TestX.shape)
print(TestY.shape)
print(ValidX.shape)
print(ValidY.shape)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 4)
# (1440, 240, 240, 3)
# (1440, 240, 240, 4)
# (120, 240, 240, 3)
# (120, 240, 240, 4)

# %%
TrainX = np.reshape(TrainX,(-1,240, 240,3))
TrainY = np.reshape(TrainY,(-1,240, 240,4))

TrainX = TrainX.astype('float32')/255

TestX = np.reshape(TestX,(-1,240, 240,3))
TestY = np.reshape(TestY,(-1,240, 240,4))

TestX = TestX.astype('float32')/255

ValidX = np.reshape(ValidX,(-1,240, 240,3))
ValidY = np.reshape(ValidY,(-1,240, 240,4))

ValidX = ValidX.astype('float32')/255

# %%
print(TrainX.shape)
print(TrainY.shape)

print(TestX.shape)
print(TestY.shape)

print(ValidX.shape)
print(ValidY.shape)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 4)
# (1440, 240, 240, 3)
# (1440, 240, 240, 4)
# (120, 240, 240, 3)
# (120, 240, 240, 4)

# %%
# !pip install medpy
from keras.layers import *
import keras
from keras.models import Sequential
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from medpy.metric import dc, precision, recall
from keras import Model
# Out:
# Collecting medpy
#   Downloading https://files.pythonhosted.org/packages/3b/70/c1fd5dd60242eee81774696ea7ba4caafac2bad8f028bba94b1af83777d7/MedPy-0.4.0.tar.gz (151kB)
#      |████████████████████████████████| 153kB 3.4MB/s
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.18.2)
# Collecting SimpleITK>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/f8/d8/53338c34f71020725ffb3557846c80af96c29c03bc883551a2565aa68a7c/SimpleITK-1.2.4-cp36-cp36m-manylinux1_x86_64.whl (42.5MB)
#      |████████████████████████████████| 42.5MB 72kB/s
# Building wheels for collected packages: medpy
#   Building wheel for medpy (setup.py) ... done
#   Created wheel for medpy: filename=MedPy-0.4.0-cp36-cp36m-linux_x86_64.whl size=753428 sha256=d730ead0048315e7a3fba5cc44d0593e2745fc241a43c30760931dd678cfd57f
#   Stored in directory: /root/.cache/pip/wheels/8c/c9/9c/2c6281c7a72b9fb1570862a4f028af7ce38405008354fbf870
# Successfully built medpy
# Installing collected packages: SimpleITK, medpy
# Successfully installed SimpleITK-1.2.4 medpy-0.4.0
# Using TensorFlow backend.

# %%
def get_conv_block(input_layer,nFilters,size):
    conv1 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(input_layer)
    bn1 = BatchNormalization()(conv1)
    conv2 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(bn1)
    bn2 = BatchNormalization()(conv2)
    return bn2
    
def get_model():    
    input_layer = Input(shape=(240,240,3))
    block1 = get_conv_block(input_layer,32,3)
    mp1 = MaxPooling2D(pool_size=(2, 2))(block1)
    dr1 = Dropout(0.1)(mp1)
    
    block2 = get_conv_block(dr1,64,3)
    mp2 = MaxPooling2D(pool_size=(2, 2))(block2)
    dr2 = Dropout(0.1)(mp2)
    
    block3 = get_conv_block(dr2,128,3)
    mp3 = MaxPooling2D(pool_size=(2, 2))(block3)
    dr3 = Dropout(0.1)(mp3)
    
    block4 = get_conv_block(dr3,256,3)
    mp4 = MaxPooling2D(pool_size=(2, 2))(block4)
    dr4 = Dropout(0.1)(mp4)

    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(dr4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)

    up1 = Conv2DTranspose(256,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(conv5)
    cat1 = concatenate([block4,up1])
    dr1 = Dropout(0.1)(cat1)
    block5 = get_conv_block(dr1,256,3)

    up2 = Conv2DTranspose(128,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block5)
    cat2 = concatenate([block3,up2])
    dr2 = Dropout(0.1)(cat2)
    block6 = get_conv_block(dr2,128,3)
    
    up3 = Conv2DTranspose(64,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block6)
    cat3 = concatenate([block2,up3])
    dr3 = Dropout(0.1)(cat3)
    block7 = get_conv_block(dr3,64,3)
    
    up4 = Conv2DTranspose(32,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block7)
    cat4 = concatenate([block1,up4])
    dr4 = Dropout(0.1)(cat4)
    block8 = get_conv_block(dr4,64,3)

    conv10 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(block8)
    conv11 = Conv2D(4,(1,1), activation='softmax', padding = 'same')(conv10)

    model = Model(input_layer,conv11)
    return model

# %%
model = get_model()
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 240, 240, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 240, 240, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 240, 240, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 240, 240, 32) 9248        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 240, 240, 32) 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 120, 120, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 120, 120, 32) 0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 120, 120, 64) 18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 120, 120, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 120, 120, 64) 36928       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 120, 120, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 60, 60, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 60, 60, 64)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 60, 60, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 60, 60, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 60, 60, 128)  147584      batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 60, 60, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 30, 30, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 30, 30, 128)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 30, 30, 256)  295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 30, 30, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 30, 30, 256)  590080      batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 30, 30, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 15, 15, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 15, 15, 256)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 15, 15, 512)  1180160     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 15, 15, 512)  2359808     conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 30, 30, 256)  1179904     conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 30, 30, 512)  0           batch_normalization_8[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 30, 30, 512)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 30, 30, 256)  1179904     dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 30, 30, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 30, 30, 256)  590080      batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 30, 30, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 60, 60, 128)  295040      batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 60, 60, 256)  0           batch_normalization_6[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 60, 60, 256)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 60, 60, 128)  295040      dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 60, 60, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 60, 60, 128)  147584      batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 60, 60, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 120, 120, 64) 73792       batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 120, 120, 128 0           batch_normalization_4[0][0]
#                                                                  conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 120, 120, 128 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 120, 120, 64) 73792       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 120, 120, 64) 256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 120, 120, 64) 36928       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 120, 120, 64) 256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 240, 240, 32) 18464       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 240, 240, 64) 0           batch_normalization_2[0][0]
#                                                                  conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 240, 240, 64) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 240, 240, 64) 36928       dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 240, 240, 64) 256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 240, 240, 64) 36928       batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 240, 240, 64) 256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 240, 240, 2)  1154        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 240, 240, 4)  12          conv2d_19[0][0]
# ==================================================================================================
# Total params: 8,685,710
# Trainable params: 8,681,742
# Non-trainable params: 3,968
# __________________________________________________________________________________________________

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
import math
from keras.callbacks import EarlyStopping,ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
mc = ModelCheckpoint('Checkpoint.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=True)

# %%
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def combined_loss(y_true, y_pred):
  return (1*K.categorical_crossentropy(y_true, y_pred))+(0.75*tversky_loss(y_true, y_pred))

# %%
import random
batch_size = 16
def get_batch(batch_size, X_train, Y_train): 
    size_batch = batch_size
    last_index = len(X_train) - 1
    x_train = X_train
    y_train = Y_train 
    while True:
        batch_data = [[],[]]
        for i in range(0, size_batch):
            random_index = random.randint(0, last_index)
            batch_data[0].append(x_train[random_index])
            batch_data[1].append(y_train[random_index])

        yield (np.array(batch_data[0]), np.array(batch_data[1]))     
        
datagen = get_batch(batch_size, TrainX, TrainY)

# %%
from keras import backend as K      
model.compile(loss=combined_loss, optimizer="adam", metrics=[dice_coef,'accuracy'])

# %%
from math import ceil
num_epoch = 100
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER"
n_points = len(TrainX)
history = model.fit(datagen, 
                validation_data = (ValidX, ValidY),
                epochs=num_epoch,steps_per_epoch = ceil(n_points / batch_size), callbacks =[es,mc],  shuffle =True)
model.save(MODELS_PATH + '/4 Class_UNET_ER_08_04_2020v2.h5')
# Out:
# Epoch 1/100
# 113/113 [==============================] - 55s 489ms/step - loss: 3.7433 - dice_coef: 0.2949 - accuracy: 0.8529 - val_loss: 4.9348 - val_dice_coef: 0.1618 - val_accuracy: 0.3145
#
# Epoch 00001: val_loss improved from inf to 4.93485, saving model to Checkpoint.h5
# Epoch 2/100
# 113/113 [==============================] - 43s 383ms/step - loss: 3.5134 - dice_coef: 0.3375 - accuracy: 0.9155 - val_loss: 3.6852 - val_dice_coef: 0.3396 - val_accuracy: 0.9860
#
# Epoch 00002: val_loss improved from 4.93485 to 3.68520, saving model to Checkpoint.h5
# Epoch 3/100
# 113/113 [==============================] - 43s 383ms/step - loss: 3.3073 - dice_coef: 0.3847 - accuracy: 0.9207 - val_loss: 3.5100 - val_dice_coef: 0.3890 - val_accuracy: 0.9885
#
# Epoch 00003: val_loss improved from 3.68520 to 3.51004, saving model to Checkpoint.h5
# Epoch 4/100
# 113/113 [==============================] - 43s 383ms/step - loss: 3.1476 - dice_coef: 0.4270 - accuracy: 0.9194 - val_loss: 3.3886 - val_dice_coef: 0.4290 - val_accuracy: 0.9597
#
# Epoch 00004: val_loss improved from 3.51004 to 3.38864, saving model to Checkpoint.h5
# Epoch 5/100
# 113/113 [==============================] - 43s 383ms/step - loss: 3.0069 - dice_coef: 0.4688 - accuracy: 0.9205 - val_loss: 3.2173 - val_dice_coef: 0.4868 - val_accuracy: 0.9885
#
# Epoch 00005: val_loss improved from 3.38864 to 3.21730, saving model to Checkpoint.h5
# Epoch 6/100
# 113/113 [==============================] - 43s 383ms/step - loss: 2.8726 - dice_coef: 0.5096 - accuracy: 0.9193 - val_loss: 3.0960 - val_dice_coef: 0.5338 - val_accuracy: 0.9885
#
# Epoch 00006: val_loss improved from 3.21730 to 3.09603, saving model to Checkpoint.h5
# Epoch 7/100
# 113/113 [==============================] - 43s 383ms/step - loss: 2.7549 - dice_coef: 0.5478 - accuracy: 0.9189 - val_loss: 2.9899 - val_dice_coef: 0.5784 - val_accuracy: 0.9885
#
# Epoch 00007: val_loss improved from 3.09603 to 2.98986, saving model to Checkpoint.h5
# Epoch 8/100
# 113/113 [==============================] - 43s 383ms/step - loss: 2.6561 - dice_coef: 0.5840 - accuracy: 0.9188 - val_loss: 2.8968 - val_dice_coef: 0.6203 - val_accuracy: 0.9885
#
# Epoch 00008: val_loss improved from 2.98986 to 2.89683, saving model to Checkpoint.h5
# Epoch 9/100
# 113/113 [==============================] - 43s 383ms/step - loss: 2.5414 - dice_coef: 0.6179 - accuracy: 0.9156 - val_loss: 2.8172 - val_dice_coef: 0.6587 - val_accuracy: 0.9885
#
# Epoch 00009: val_loss improved from 2.89683 to 2.81723, saving model to Checkpoint.h5
# Epoch 10/100
# 113/113 [==============================] - 43s 383ms/step - loss: 2.4550 - dice_coef: 0.6512 - accuracy: 0.9183 - val_loss: 2.7481 - val_dice_coef: 0.6938 - val_accuracy: 0.9885
#
# Epoch 00010: val_loss improved from 2.81723 to 2.74806, saving model to Checkpoint.h5
# Epoch 11/100
# 113/113 [==============================] - 43s 383ms/step - loss: 2.3303 - dice_coef: 0.6856 - accuracy: 0.9326 - val_loss: 2.6853 - val_dice_coef: 0.7272 - val_accuracy: 0.9883
#
# Epoch 00011: val_loss improved from 2.74806 to 2.68528, saving model to Checkpoint.h5
# Epoch 12/100
# 113/113 [==============================] - 43s 383ms/step - loss: 2.2156 - dice_coef: 0.7149 - accuracy: 0.9309 - val_loss: 2.6331 - val_dice_coef: 0.7569 - val_accuracy: 0.9871
#
# Epoch 00012: val_loss improved from 2.68528 to 2.63311, saving model to Checkpoint.h5
# Epoch 13/100
# 113/113 [==============================] - 43s 383ms/step - loss: 2.1211 - dice_coef: 0.7441 - accuracy: 0.9358 - val_loss: 2.5836 - val_dice_coef: 0.7856 - val_accuracy: 0.9885
#
# Epoch 00013: val_loss improved from 2.63311 to 2.58360, saving model to Checkpoint.h5
# Epoch 14/100
# 113/113 [==============================] - 43s 383ms/step - loss: 2.0396 - dice_coef: 0.7680 - accuracy: 0.9370 - val_loss: 2.5438 - val_dice_coef: 0.8096 - val_accuracy: 0.9885
#
# Epoch 00014: val_loss improved from 2.58360 to 2.54381, saving model to Checkpoint.h5
# Epoch 15/100
# 113/113 [==============================] - 43s 383ms/step - loss: 2.0037 - dice_coef: 0.7841 - accuracy: 0.9345 - val_loss: 2.5108 - val_dice_coef: 0.8301 - val_accuracy: 0.9885
#
# Epoch 00015: val_loss improved from 2.54381 to 2.51084, saving model to Checkpoint.h5
# Epoch 16/100
# 113/113 [==============================] - 43s 384ms/step - loss: 1.8947 - dice_coef: 0.8057 - accuracy: 0.9393 - val_loss: 2.6198 - val_dice_coef: 0.7782 - val_accuracy: 0.9721
#
# Epoch 00016: val_loss did not improve from 2.51084
# Epoch 17/100
# 113/113 [==============================] - 43s 383ms/step - loss: 1.8547 - dice_coef: 0.8176 - accuracy: 0.9367 - val_loss: 2.4590 - val_dice_coef: 0.8639 - val_accuracy: 0.9885
#
# Epoch 00017: val_loss improved from 2.51084 to 2.45898, saving model to Checkpoint.h5
# Epoch 18/100
# 113/113 [==============================] - 43s 383ms/step - loss: 1.7829 - dice_coef: 0.8351 - accuracy: 0.9423 - val_loss: 3.3411 - val_dice_coef: 0.5984 - val_accuracy: 0.6929
#
# Epoch 00018: val_loss did not improve from 2.45898
# Epoch 19/100
# 113/113 [==============================] - 43s 383ms/step - loss: 1.7594 - dice_coef: 0.8462 - accuracy: 0.9424 - val_loss: 2.4165 - val_dice_coef: 0.8877 - val_accuracy: 0.9885
#
# Epoch 00019: val_loss improved from 2.45898 to 2.41653, saving model to Checkpoint.h5
# Epoch 20/100
# 113/113 [==============================] - 43s 383ms/step - loss: 1.7119 - dice_coef: 0.8520 - accuracy: 0.9386 - val_loss: 2.4007 - val_dice_coef: 0.9001 - val_accuracy: 0.9885
#
# Epoch 00020: val_loss improved from 2.41653 to 2.40068, saving model to Checkpoint.h5
# Epoch 21/100
# 113/113 [==============================] - 43s 383ms/step - loss: 1.6704 - dice_coef: 0.8627 - accuracy: 0.9414 - val_loss: 2.3886 - val_dice_coef: 0.9091 - val_accuracy: 0.9885
#
# Epoch 00021: val_loss improved from 2.40068 to 2.38858, saving model to Checkpoint.h5
# Epoch 22/100
# 113/113 [==============================] - 43s 383ms/step - loss: 1.6496 - dice_coef: 0.8667 - accuracy: 0.9383 - val_loss: 2.3780 - val_dice_coef: 0.9167 - val_accuracy: 0.9885
#
# Epoch 00022: val_loss improved from 2.38858 to 2.37801, saving model to Checkpoint.h5
# Epoch 23/100
# 113/113 [==============================] - 43s 383ms/step - loss: 1.6329 - dice_coef: 0.8785 - accuracy: 0.9445 - val_loss: 2.3693 - val_dice_coef: 0.9239 - val_accuracy: 0.9885
#
# Epoch 00023: val_loss improved from 2.37801 to 2.36935, saving model to Checkpoint.h5
# Epoch 24/100
# 113/113 [==============================] - 43s 383ms/step - loss: 1.6245 - dice_coef: 0.8799 - accuracy: 0.9404 - val_loss: 2.3480 - val_dice_coef: 0.9295 - val_accuracy: 0.9883
#
# Epoch 00024: val_loss improved from 2.36935 to 2.34803, saving model to Checkpoint.h5
# Epoch 25/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.6000 - dice_coef: 0.8838 - accuracy: 0.9394 - val_loss: 2.3525 - val_dice_coef: 0.9353 - val_accuracy: 0.9885
#
# Epoch 00025: val_loss did not improve from 2.34803
# Epoch 26/100
# 113/113 [==============================] - 43s 383ms/step - loss: 1.5715 - dice_coef: 0.8889 - accuracy: 0.9405 - val_loss: 2.3484 - val_dice_coef: 0.9402 - val_accuracy: 0.9885
#
# Epoch 00026: val_loss did not improve from 2.34803
# Epoch 27/100
# 113/113 [==============================] - 43s 383ms/step - loss: 1.5371 - dice_coef: 0.8917 - accuracy: 0.9397 - val_loss: 2.3222 - val_dice_coef: 0.9446 - val_accuracy: 0.9885
#
# Epoch 00027: val_loss improved from 2.34803 to 2.32216, saving model to Checkpoint.h5
# Epoch 28/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.5184 - dice_coef: 0.8946 - accuracy: 0.9397 - val_loss: 2.3299 - val_dice_coef: 0.9488 - val_accuracy: 0.9886
#
# Epoch 00028: val_loss did not improve from 2.32216
# Epoch 29/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.4616 - dice_coef: 0.9021 - accuracy: 0.9427 - val_loss: 2.3200 - val_dice_coef: 0.9528 - val_accuracy: 0.9889
#
# Epoch 00029: val_loss improved from 2.32216 to 2.31998, saving model to Checkpoint.h5
# Epoch 30/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.4118 - dice_coef: 0.9063 - accuracy: 0.9433 - val_loss: 2.3230 - val_dice_coef: 0.9565 - val_accuracy: 0.9887
#
# Epoch 00030: val_loss did not improve from 2.31998
# Epoch 31/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.4083 - dice_coef: 0.9073 - accuracy: 0.9403 - val_loss: 2.2677 - val_dice_coef: 0.9607 - val_accuracy: 0.9897
#
# Epoch 00031: val_loss improved from 2.31998 to 2.26771, saving model to Checkpoint.h5
# Epoch 32/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.4310 - dice_coef: 0.9052 - accuracy: 0.9357 - val_loss: 2.2460 - val_dice_coef: 0.9314 - val_accuracy: 0.9813
#
# Epoch 00032: val_loss improved from 2.26771 to 2.24601, saving model to Checkpoint.h5
# Epoch 33/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.3827 - dice_coef: 0.9092 - accuracy: 0.9364 - val_loss: 2.2213 - val_dice_coef: 0.9666 - val_accuracy: 0.9899
#
# Epoch 00033: val_loss improved from 2.24601 to 2.22126, saving model to Checkpoint.h5
# Epoch 34/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.3095 - dice_coef: 0.9185 - accuracy: 0.9428 - val_loss: 2.1013 - val_dice_coef: 0.9698 - val_accuracy: 0.9910
#
# Epoch 00034: val_loss improved from 2.22126 to 2.10130, saving model to Checkpoint.h5
# Epoch 35/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.3238 - dice_coef: 0.9158 - accuracy: 0.9384 - val_loss: 2.2574 - val_dice_coef: 0.9703 - val_accuracy: 0.9892
#
# Epoch 00035: val_loss did not improve from 2.10130
# Epoch 36/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.2814 - dice_coef: 0.9234 - accuracy: 0.9440 - val_loss: 2.1093 - val_dice_coef: 0.9734 - val_accuracy: 0.9908
#
# Epoch 00036: val_loss did not improve from 2.10130
# Epoch 37/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.2575 - dice_coef: 0.9237 - accuracy: 0.9430 - val_loss: 2.1500 - val_dice_coef: 0.9749 - val_accuracy: 0.9901
#
# Epoch 00037: val_loss did not improve from 2.10130
# Epoch 38/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.2902 - dice_coef: 0.9228 - accuracy: 0.9410 - val_loss: 2.0309 - val_dice_coef: 0.9762 - val_accuracy: 0.9908
#
# Epoch 00038: val_loss improved from 2.10130 to 2.03093, saving model to Checkpoint.h5
# Epoch 39/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.2083 - dice_coef: 0.9275 - accuracy: 0.9443 - val_loss: 2.1893 - val_dice_coef: 0.9734 - val_accuracy: 0.9878
#
# Epoch 00039: val_loss did not improve from 2.03093
# Epoch 40/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.2081 - dice_coef: 0.9284 - accuracy: 0.9438 - val_loss: 1.9913 - val_dice_coef: 0.9767 - val_accuracy: 0.9896
#
# Epoch 00040: val_loss improved from 2.03093 to 1.99127, saving model to Checkpoint.h5
# Epoch 41/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.1420 - dice_coef: 0.9330 - accuracy: 0.9471 - val_loss: 2.0872 - val_dice_coef: 0.9772 - val_accuracy: 0.9895
#
# Epoch 00041: val_loss did not improve from 1.99127
# Epoch 42/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.1823 - dice_coef: 0.9329 - accuracy: 0.9467 - val_loss: 1.9987 - val_dice_coef: 0.9812 - val_accuracy: 0.9911
#
# Epoch 00042: val_loss did not improve from 1.99127
# Epoch 43/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.1910 - dice_coef: 0.9323 - accuracy: 0.9452 - val_loss: 2.1587 - val_dice_coef: 0.9811 - val_accuracy: 0.9901
#
# Epoch 00043: val_loss did not improve from 1.99127
# Epoch 44/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.1458 - dice_coef: 0.9347 - accuracy: 0.9471 - val_loss: 2.0016 - val_dice_coef: 0.9805 - val_accuracy: 0.9897
#
# Epoch 00044: val_loss did not improve from 1.99127
# Epoch 45/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.1231 - dice_coef: 0.9355 - accuracy: 0.9471 - val_loss: 1.9921 - val_dice_coef: 0.9813 - val_accuracy: 0.9894
#
# Epoch 00045: val_loss did not improve from 1.99127
# Epoch 46/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.0409 - dice_coef: 0.9389 - accuracy: 0.9499 - val_loss: 1.9935 - val_dice_coef: 0.9821 - val_accuracy: 0.9898
#
# Epoch 00046: val_loss did not improve from 1.99127
# Epoch 47/100
# 113/113 [==============================] - 43s 381ms/step - loss: 1.0768 - dice_coef: 0.9386 - accuracy: 0.9489 - val_loss: 1.9823 - val_dice_coef: 0.9843 - val_accuracy: 0.9911
#
# Epoch 00047: val_loss improved from 1.99127 to 1.98229, saving model to Checkpoint.h5
# Epoch 48/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.0776 - dice_coef: 0.9415 - accuracy: 0.9514 - val_loss: 2.2625 - val_dice_coef: 0.9822 - val_accuracy: 0.9887
#
# Epoch 00048: val_loss did not improve from 1.98229
# Epoch 49/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.0759 - dice_coef: 0.9415 - accuracy: 0.9510 - val_loss: 2.1411 - val_dice_coef: 0.9843 - val_accuracy: 0.9903
#
# Epoch 00049: val_loss did not improve from 1.98229
# Epoch 50/100
# 113/113 [==============================] - 43s 381ms/step - loss: 0.9994 - dice_coef: 0.9429 - accuracy: 0.9520 - val_loss: 2.0462 - val_dice_coef: 0.9851 - val_accuracy: 0.9906
#
# Epoch 00050: val_loss did not improve from 1.98229
# Epoch 51/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.0229 - dice_coef: 0.9436 - accuracy: 0.9523 - val_loss: 2.0618 - val_dice_coef: 0.9717 - val_accuracy: 0.9775
#
# Epoch 00051: val_loss did not improve from 1.98229
# Epoch 52/100
# 113/113 [==============================] - 43s 382ms/step - loss: 1.0200 - dice_coef: 0.9447 - accuracy: 0.9531 - val_loss: 2.5765 - val_dice_coef: 0.8764 - val_accuracy: 0.8827
#
# Epoch 00052: val_loss did not improve from 1.98229
# Epoch 53/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.9215 - dice_coef: 0.9458 - accuracy: 0.9541 - val_loss: 1.9153 - val_dice_coef: 0.9858 - val_accuracy: 0.9901
#
# Epoch 00053: val_loss improved from 1.98229 to 1.91531, saving model to Checkpoint.h5
# Epoch 54/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.9389 - dice_coef: 0.9462 - accuracy: 0.9541 - val_loss: 1.9475 - val_dice_coef: 0.9823 - val_accuracy: 0.9873
#
# Epoch 00054: val_loss did not improve from 1.91531
# Epoch 55/100
# 113/113 [==============================] - 43s 381ms/step - loss: 0.8607 - dice_coef: 0.9520 - accuracy: 0.9592 - val_loss: 1.9906 - val_dice_coef: 0.9871 - val_accuracy: 0.9910
#
# Epoch 00055: val_loss did not improve from 1.91531
# Epoch 56/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.9194 - dice_coef: 0.9481 - accuracy: 0.9555 - val_loss: 2.0369 - val_dice_coef: 0.9872 - val_accuracy: 0.9906
#
# Epoch 00056: val_loss did not improve from 1.91531
# Epoch 57/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.8841 - dice_coef: 0.9492 - accuracy: 0.9560 - val_loss: 1.9915 - val_dice_coef: 0.9835 - val_accuracy: 0.9876
#
# Epoch 00057: val_loss did not improve from 1.91531
# Epoch 58/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.8611 - dice_coef: 0.9484 - accuracy: 0.9553 - val_loss: 2.3910 - val_dice_coef: 0.9342 - val_accuracy: 0.9381
#
# Epoch 00058: val_loss did not improve from 1.91531
# Epoch 59/100
# 113/113 [==============================] - 43s 383ms/step - loss: 0.8469 - dice_coef: 0.9515 - accuracy: 0.9581 - val_loss: 1.9431 - val_dice_coef: 0.9872 - val_accuracy: 0.9902
#
# Epoch 00059: val_loss did not improve from 1.91531
# Epoch 60/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.8392 - dice_coef: 0.9493 - accuracy: 0.9561 - val_loss: 1.9253 - val_dice_coef: 0.9882 - val_accuracy: 0.9911
#
# Epoch 00060: val_loss did not improve from 1.91531
# Epoch 61/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.8476 - dice_coef: 0.9513 - accuracy: 0.9575 - val_loss: 1.9538 - val_dice_coef: 0.9884 - val_accuracy: 0.9910
#
# Epoch 00061: val_loss did not improve from 1.91531
# Epoch 62/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.7749 - dice_coef: 0.9524 - accuracy: 0.9586 - val_loss: 2.0142 - val_dice_coef: 0.9880 - val_accuracy: 0.9908
#
# Epoch 00062: val_loss did not improve from 1.91531
# Epoch 63/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.7531 - dice_coef: 0.9570 - accuracy: 0.9627 - val_loss: 1.9891 - val_dice_coef: 0.9834 - val_accuracy: 0.9859
#
# Epoch 00063: val_loss did not improve from 1.91531
# Epoch 64/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.7523 - dice_coef: 0.9568 - accuracy: 0.9622 - val_loss: 1.9465 - val_dice_coef: 0.9856 - val_accuracy: 0.9877
#
# Epoch 00064: val_loss did not improve from 1.91531
# Epoch 65/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.7115 - dice_coef: 0.9584 - accuracy: 0.9637 - val_loss: 2.0340 - val_dice_coef: 0.9883 - val_accuracy: 0.9904
#
# Epoch 00065: val_loss did not improve from 1.91531
# Epoch 66/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.6672 - dice_coef: 0.9585 - accuracy: 0.9638 - val_loss: 1.9066 - val_dice_coef: 0.9887 - val_accuracy: 0.9906
#
# Epoch 00066: val_loss improved from 1.91531 to 1.90659, saving model to Checkpoint.h5
# Epoch 67/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.6950 - dice_coef: 0.9584 - accuracy: 0.9637 - val_loss: 1.9688 - val_dice_coef: 0.9890 - val_accuracy: 0.9910
#
# Epoch 00067: val_loss did not improve from 1.90659
# Epoch 68/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.6915 - dice_coef: 0.9593 - accuracy: 0.9642 - val_loss: 1.9576 - val_dice_coef: 0.9885 - val_accuracy: 0.9903
#
# Epoch 00068: val_loss did not improve from 1.90659
# Epoch 69/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.7022 - dice_coef: 0.9592 - accuracy: 0.9640 - val_loss: 2.0255 - val_dice_coef: 0.9875 - val_accuracy: 0.9896
#
# Epoch 00069: val_loss did not improve from 1.90659
# Epoch 70/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.7137 - dice_coef: 0.9601 - accuracy: 0.9648 - val_loss: 2.0298 - val_dice_coef: 0.9891 - val_accuracy: 0.9905
#
# Epoch 00070: val_loss did not improve from 1.90659
# Epoch 71/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.6632 - dice_coef: 0.9600 - accuracy: 0.9648 - val_loss: 1.9824 - val_dice_coef: 0.9895 - val_accuracy: 0.9908
#
# Epoch 00071: val_loss did not improve from 1.90659
# Epoch 72/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.6503 - dice_coef: 0.9638 - accuracy: 0.9680 - val_loss: 1.9005 - val_dice_coef: 0.9894 - val_accuracy: 0.9906
#
# Epoch 00072: val_loss improved from 1.90659 to 1.90049, saving model to Checkpoint.h5
# Epoch 73/100
# 113/113 [==============================] - 43s 383ms/step - loss: 0.5926 - dice_coef: 0.9640 - accuracy: 0.9682 - val_loss: 1.9502 - val_dice_coef: 0.9895 - val_accuracy: 0.9905
#
# Epoch 00073: val_loss did not improve from 1.90049
# Epoch 74/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.6071 - dice_coef: 0.9629 - accuracy: 0.9672 - val_loss: 1.9850 - val_dice_coef: 0.9896 - val_accuracy: 0.9907
#
# Epoch 00074: val_loss did not improve from 1.90049
# Epoch 75/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.5820 - dice_coef: 0.9649 - accuracy: 0.9689 - val_loss: 1.9936 - val_dice_coef: 0.9897 - val_accuracy: 0.9906
#
# Epoch 00075: val_loss did not improve from 1.90049
# Epoch 76/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.5565 - dice_coef: 0.9646 - accuracy: 0.9686 - val_loss: 2.0256 - val_dice_coef: 0.9892 - val_accuracy: 0.9905
#
# Epoch 00076: val_loss did not improve from 1.90049
# Epoch 77/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.5635 - dice_coef: 0.9645 - accuracy: 0.9686 - val_loss: 1.9695 - val_dice_coef: 0.9871 - val_accuracy: 0.9879
#
# Epoch 00077: val_loss did not improve from 1.90049
# Epoch 78/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.5587 - dice_coef: 0.9654 - accuracy: 0.9694 - val_loss: 2.0140 - val_dice_coef: 0.9897 - val_accuracy: 0.9904
#
# Epoch 00078: val_loss did not improve from 1.90049
# Epoch 79/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.5426 - dice_coef: 0.9668 - accuracy: 0.9705 - val_loss: 1.9766 - val_dice_coef: 0.9901 - val_accuracy: 0.9906
#
# Epoch 00079: val_loss did not improve from 1.90049
# Epoch 80/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.5683 - dice_coef: 0.9671 - accuracy: 0.9708 - val_loss: 2.0231 - val_dice_coef: 0.9899 - val_accuracy: 0.9906
#
# Epoch 00080: val_loss did not improve from 1.90049
# Epoch 81/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.5192 - dice_coef: 0.9679 - accuracy: 0.9715 - val_loss: 1.9207 - val_dice_coef: 0.9897 - val_accuracy: 0.9903
#
# Epoch 00081: val_loss did not improve from 1.90049
# Epoch 82/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.5925 - dice_coef: 0.9631 - accuracy: 0.9670 - val_loss: 2.0612 - val_dice_coef: 0.9822 - val_accuracy: 0.9828
#
# Epoch 00082: val_loss did not improve from 1.90049
# Epoch 83/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.5259 - dice_coef: 0.9663 - accuracy: 0.9700 - val_loss: 2.0294 - val_dice_coef: 0.9890 - val_accuracy: 0.9898
#
# Epoch 00083: val_loss did not improve from 1.90049
# Epoch 84/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.5473 - dice_coef: 0.9670 - accuracy: 0.9706 - val_loss: 2.2013 - val_dice_coef: 0.9890 - val_accuracy: 0.9897
#
# Epoch 00084: val_loss did not improve from 1.90049
# Epoch 85/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.5288 - dice_coef: 0.9665 - accuracy: 0.9701 - val_loss: 1.9709 - val_dice_coef: 0.9887 - val_accuracy: 0.9893
#
# Epoch 00085: val_loss did not improve from 1.90049
# Epoch 86/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.5347 - dice_coef: 0.9688 - accuracy: 0.9723 - val_loss: 1.9764 - val_dice_coef: 0.9894 - val_accuracy: 0.9899
#
# Epoch 00086: val_loss did not improve from 1.90049
# Epoch 87/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.4822 - dice_coef: 0.9700 - accuracy: 0.9732 - val_loss: 2.0044 - val_dice_coef: 0.9903 - val_accuracy: 0.9906
#
# Epoch 00087: val_loss did not improve from 1.90049
# Epoch 88/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.5091 - dice_coef: 0.9671 - accuracy: 0.9707 - val_loss: 2.0230 - val_dice_coef: 0.9900 - val_accuracy: 0.9902
#
# Epoch 00088: val_loss did not improve from 1.90049
# Epoch 89/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.4496 - dice_coef: 0.9720 - accuracy: 0.9751 - val_loss: 2.0220 - val_dice_coef: 0.9869 - val_accuracy: 0.9876
#
# Epoch 00089: val_loss did not improve from 1.90049
# Epoch 90/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.4165 - dice_coef: 0.9712 - accuracy: 0.9744 - val_loss: 2.0171 - val_dice_coef: 0.9906 - val_accuracy: 0.9909
#
# Epoch 00090: val_loss did not improve from 1.90049
# Epoch 91/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.4551 - dice_coef: 0.9704 - accuracy: 0.9736 - val_loss: 1.9582 - val_dice_coef: 0.9894 - val_accuracy: 0.9897
#
# Epoch 00091: val_loss did not improve from 1.90049
# Epoch 92/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.4109 - dice_coef: 0.9731 - accuracy: 0.9760 - val_loss: 1.9427 - val_dice_coef: 0.9899 - val_accuracy: 0.9902
#
# Epoch 00092: val_loss did not improve from 1.90049
# Epoch 93/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.4241 - dice_coef: 0.9722 - accuracy: 0.9752 - val_loss: 2.0439 - val_dice_coef: 0.9899 - val_accuracy: 0.9902
#
# Epoch 00093: val_loss did not improve from 1.90049
# Epoch 94/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.3969 - dice_coef: 0.9747 - accuracy: 0.9775 - val_loss: 2.0804 - val_dice_coef: 0.9901 - val_accuracy: 0.9903
#
# Epoch 00094: val_loss did not improve from 1.90049
# Epoch 95/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.4567 - dice_coef: 0.9708 - accuracy: 0.9740 - val_loss: 1.9786 - val_dice_coef: 0.9879 - val_accuracy: 0.9881
#
# Epoch 00095: val_loss did not improve from 1.90049
# Epoch 96/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.4550 - dice_coef: 0.9719 - accuracy: 0.9748 - val_loss: 1.9661 - val_dice_coef: 0.9882 - val_accuracy: 0.9883
#
# Epoch 00096: val_loss did not improve from 1.90049
# Epoch 97/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.4461 - dice_coef: 0.9719 - accuracy: 0.9749 - val_loss: 2.0564 - val_dice_coef: 0.9882 - val_accuracy: 0.9886
#
# Epoch 00097: val_loss did not improve from 1.90049
# Epoch 98/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.3874 - dice_coef: 0.9749 - accuracy: 0.9775 - val_loss: 2.0259 - val_dice_coef: 0.9897 - val_accuracy: 0.9897
#
# Epoch 00098: val_loss did not improve from 1.90049
# Epoch 99/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.3961 - dice_coef: 0.9759 - accuracy: 0.9785 - val_loss: 1.9735 - val_dice_coef: 0.9897 - val_accuracy: 0.9899
#
# Epoch 00099: val_loss did not improve from 1.90049
# Epoch 100/100
# 113/113 [==============================] - 43s 382ms/step - loss: 0.4146 - dice_coef: 0.9753 - accuracy: 0.9778 - val_loss: 2.0939 - val_dice_coef: 0.9902 - val_accuracy: 0.9904
#
# Epoch 00100: val_loss did not improve from 1.90049

# %%
train_loss = history.history['loss']
train_acc = history.history['accuracy']
val_loss = history.history['val_loss']
val_acc = history.history['val_accuracy']
xc=range(len(train_loss))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_loss)
plt.plot(xc, val_loss)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(['train','val'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_acc)
plt.plot(xc, val_acc)
plt.xlabel("Epoch")
plt.ylabel("Acc")
plt.legend(['train','val'])

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER"
model = keras.models.load_model(MODELS_PATH+'/4 Class_UNET_ER_08_04_2020v2.h5',custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

# %%
# Function to find the most probable class of an image pixel by pixel
def ClassFinder(img):
  result = np.zeros(img.shape, dtype=np.uint8)
  for r in range(len(img)):
    for c in range(len(img[0])):
      idx = np.argmax(img[r][c])
      result[r][c][idx]=1
      
  return result

# %%
TrainX = np.concatenate((TrainX,ValidX))
TrainY = np.concatenate((TrainY,ValidY))
train_result = model.predict(TrainX, batch_size=16)
print(np.shape(train_result))
Train_predict = [ ]
for img in train_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_predict.append(encoded_img)

Predicted_images = np.asarray(Train_predict)
print(Predicted_images.shape)
np.unique(Predicted_images)
# dice = dc(train_result, TrainY)
# pre  = precision(train_result,TrainY)
# re   = recall(train_result,TrainY)
# print('Train dc: '  + str(dice))
# print('Train pre: ' + str(pre))
# print('Train re: '  + str(re))
# Out:
# (1920, 240, 240, 4)
# (1920, 240, 240)
# array([  0,  85, 170, 255], dtype=uint8)

# %%
test_result = model.predict(TestX, batch_size=16)
print(np.shape(test_result))

Test_predict = [ ]
for img in test_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_predict.append(encoded_img)

Predicted_images_test = np.asarray(Test_predict)
print(Predicted_images_test.shape)
np.unique(Predicted_images_test)
# dice = dc(test_result, TestY)
# pre  = precision(test_result,TestY)
# re   = recall(test_result,TestY)
# print('Test dc: '  + str(dice))
# print('Test pre: ' + str(pre))
# print('Test re: '  + str(re))
# Out:
# (1440, 240, 240, 4)
# (1440, 240, 240)
# array([  0,  85, 170, 255], dtype=uint8)

# %%
from sklearn.metrics import confusion_matrix
def get_confusion_matrix(Actual, Predicted):
  ActualY = np.reshape(Actual,(-1, Actual.shape[3]))
  PredY = np.reshape(Predicted,(-1, Predicted.shape[3]))
  matrix = confusion_matrix(ActualY.argmax(axis = 1), PredY.argmax(axis = 1))
  return matrix

def get_precision(confusion_matrix):
  precision = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 0)
  nan_indices = np.isnan(precision)
  precision[nan_indices] = 0
  return precision

def get_recall(confusion_matrix):
  recall = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 1)
  nan_indices = np.isnan(recall)
  recall[nan_indices] = 0
  return recall

# %%
test_matrix = get_confusion_matrix(TestY, test_result)
train_matrix = get_confusion_matrix(TrainY, train_result)
print(test_matrix)
print(train_matrix)
# TestY.shape[3]
# test_result.shape
# Out:
# [[74613986   196722   280145   698792]
#  [  250342   212986   166465    46476]
#  [  657167   146015   725306   480993]
#  [  884110    13725   175076  3395694]]
# [[95498453    59059   514440   501967]
#  [  280017  1128801    30730      461]
#  [  288460    12200  4714981    22301]
#  [  565576      363   101567  6872624]]

# %%
test_precision = get_precision(test_matrix)
print('Test Precision')
print(test_precision)
test_recall = get_recall(test_matrix)
print('Test Recall')
print(test_recall)
train_precision = get_precision(train_matrix)
print('Train Precision')
print(train_precision)
train_recall = get_recall(train_matrix)
print('Train Recall')
print(train_recall)
# Out:
# Test Precision
# [0.97655121 0.37402186 0.53846348 0.73468781]
# Test Recall
# [0.98448787 0.31494272 0.36094195 0.75990024]
# Train Precision
# [0.98826427 0.94033603 0.87937877 0.9290653 ]
# Train Recall
# [0.9888638  0.78388468 0.93589426 0.91147288]

# %%
weight_matrix = np.zeros((4,1))
weight_matrix[0] = 1/3
weight_matrix[1] = 1/3
weight_matrix[2] = 1/3
weight_matrix[3] = 1/3
print(weight_matrix.shape)
# Out:
# (4, 1)

# %%
def get_overall_precision(precision, weights):
  final_precision = np.dot(precision,weights)
  return final_precision

def get_overall_recall(recall, weights):
  final_recall = np.dot(recall ,weights)
  return final_recall

# %%
final_test_precision  = get_overall_precision(test_precision, weight_matrix)
final_test_recall     = get_overall_recall(test_recall, weight_matrix)
final_train_precision = get_overall_precision(train_precision, weight_matrix)
final_train_recall    = get_overall_recall(train_recall, weight_matrix)
print('Final Test Precision')
print(final_test_precision)
print('Final Test Recall')
print(final_test_recall)
print('Final Train Precision')
print(final_train_precision)
print('Final Train Recall')
print(final_train_recall)
# Out:
# Final Test Precision
# [0.87457479]
# Final Test Recall
# [0.80675759]
# Final Train Precision
# [1.24568146]
# Final Train Recall
# [1.20670521]

# %%
from scipy.stats import hmean

def dice_coefficient(precision, recall):
  return hmean(np.asarray([precision , recall]))

# %%
test_dice_coeff = dice_coefficient(final_test_precision, final_test_recall)
print('Test Dice coeff')
print(test_dice_coeff)

train_dice_coeff = dice_coefficient(final_train_precision, final_train_recall)
print('Train Dice coeff')
print(train_dice_coeff)
# Out:
# Test Dice coeff
# [0.83929847]
# Train Dice coeff
# [1.22588361]

# %%
copy1  = np.copy(TestX [250])
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
copy3 = np.reshape(copy2,(240, 240,3))
Img = cv2.cvtColor(copy3,cv2.COLOR_BGR2RGB)

Mask = TestGroundTruth[250]

Predicted_Mask = Predicted_images_test[250] 

plt.subplot(131).imshow(Img)
plt.subplot(132).imshow(Mask,'gray')
plt.subplot(133).imshow(Predicted_Mask,'gray')

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask):
  num = mask.shape[0]/480
  for id in range(int(num)):
    temp = []
    for i in range(id, id+10):
      idx = i * 48
      final_output = mask[idx:idx+48]
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save("/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/Combined_Loss/UNet 4 Class/ER1 Patient " + str(id), final_output)

# %%
# saving predicted outputs as numpy arrays for test images
saveNumpyOutput(Predicted_images)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 22   # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]

Mask_input = TestY[id:id+48]
Test_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Test_Actual)
print(Mask_input.shape)

final_output = Predicted_images_test[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# (48, 240, 240, 4)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0.  85. 170. 255.]

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 2  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]

Mask_input = TrainY[id:id+48]
Train_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Train_Actual)
print(Mask_input.shape)

final_output = Predicted_images[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 4)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0.  85. 170. 255.]

# %%
SAVE_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Predicted Images/ER/UNET/4 Class/8-04-2020"
def saveImageOutput(patients, GroundTruth, Predicted, folder):
  totalimages = patients * 10
  for id in range(totalimages):
    index = id * 48
    Mask_input = GroundTruth[index:index+48]
    GroundTruth_Actual = [ ]
    for img in Mask_input:
      img = ClassFinder(img)
      encoded_img = convertFromOneHot(img)
      GroundTruth_Actual.append(encoded_img)
    Mask_input = np.asarray(GroundTruth_Actual)
    final_output = Predicted[index:index+48]
    Mask_input   = stitchMaskPatches(Mask_input)
    final_output = stitchMaskPatches(final_output)
    cv2.imwrite(SAVE_PATH + '/Ground Truth' + folder + '/Image '+ str(id) + '.png', Mask_input)
    cv2.imwrite(SAVE_PATH +  '/Predicted Mask'+ folder + '/Image '+ str(id) + '.png', final_output)

# %%
saveImageOutput(3, TestY, Predicted_images_test, '/Test' )
saveImageOutput(4, TrainY, Predicted_images, '/Train' )
