# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np

# %%
# Function to convert image from greyscale to one hot (i.e. 3 channels)
def convertToOneHot(image):
    num_classes = 3
    shape = image.shape[:2]+(num_classes,)
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c]==0:
          encoded_image[r][c][0] = 1
        elif image[r][c]==128:
          encoded_image[r][c][1] = 1
        else:
          encoded_image[r][c][2] = 1
    return encoded_image

# %%
# Function to convert back from one hot image to greyscale
def convertFromOneHot(image):
    shape = image.shape[:2]
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c][0] == 1:
          encoded_image[r][c] = 0
        elif image[r][c][1] == 1:
          encoded_image[r][c] = 128
        else:
          encoded_image[r][c] = 255
    return encoded_image

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays"

# Train set paitients: 230 232
TrainX_1 = np.load(PATH + '/ER IHC 239 Images.npy')
TrainY_1 = np.load(PATH + '/ER IHC 239 Masks.npy')
TrainX_2 = np.load(PATH + '/ER IHC 232 Images.npy')
TrainY_2 = np.load(PATH + '/ER IHC 232 Masks.npy')
TrainX_3 = np.load(PATH + '/ER IHC 242 Images.npy')
TrainY_3 = np.load(PATH + '/ER IHC 242 Masks.npy')
TrainX_4 = np.load(PATH + '/ER IHC 230 Images.npy')
TrainY_4 = np.load(PATH + '/ER IHC 230 Masks.npy')

# Test set paitients: 221 239 242 246
TestX_1 = np.load(PATH + '/ER IHC 221 Images.npy')
TestY_1 = np.load(PATH + '/ER IHC 221 Masks.npy')
TestX_2 = np.load(PATH + '/ER IHC 246 Images.npy')
TestY_2 = np.load(PATH + '/ER IHC 246 Masks.npy')

# %%
TrainX = np.concatenate((TrainX_1, TrainX_2, TrainX_3, TrainX_4), axis=0)
TrainGroundTruth = np.concatenate((TrainY_1, TrainY_2, TrainY_3, TrainY_4), axis=0)
TrainY = []

for img in TrainGroundTruth:
  encoded_img = convertToOneHot(img)
  TrainY.append(encoded_img)

TrainY = np.asarray(TrainY)

TestX = np.concatenate((TestX_1, TestX_2), axis=0)
TestGroundTruth = np.concatenate((TestY_1, TestY_2), axis=0)
TestY = []

for img in TestGroundTruth:
  encoded_img = convertToOneHot(img)
  TestY.append(encoded_img)

TestY = np.asarray(TestY)

ValidX = TrainX[1800:, : ]
ValidY = TrainY[1800:, : ]

TrainX = TrainX[0:1800, : ]
TrainY = TrainY[0:1800, : ]

print(TrainX.shape)
print(TrainY.shape)
print(TestX.shape)
print(TestY.shape)
print(ValidX.shape)
print(ValidY.shape)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 3)
# (960, 240, 240, 3)
# (960, 240, 240, 3)
# (120, 240, 240, 3)
# (120, 240, 240, 3)

# %%
TrainX = np.reshape(TrainX,(-1,240, 240,3))
TrainY = np.reshape(TrainY,(-1,240, 240,3))

TrainX = TrainX.astype('float32')/255

TestX = np.reshape(TestX,(-1,240, 240,3))
TestY = np.reshape(TestY,(-1,240, 240,3))

TestX = TestX.astype('float32')/255

ValidX = np.reshape(ValidX,(-1,240, 240,3))
ValidY = np.reshape(ValidY,(-1,240, 240,3))

ValidX = ValidX.astype('float32')/255

# %%
print(TrainX.shape)
print(TrainY.shape)

print(TestX.shape)
print(TestY.shape)

print(ValidX.shape)
print(ValidY.shape)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 3)
# (960, 240, 240, 3)
# (960, 240, 240, 3)
# (120, 240, 240, 3)
# (120, 240, 240, 3)

# %%
# !pip install medpy
from keras.layers import *
import keras
from keras.models import Sequential
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from medpy.metric import dc, precision, recall
from keras import Model
import tensorflow as tf
# Out:
# Collecting medpy
#   Downloading https://files.pythonhosted.org/packages/3b/70/c1fd5dd60242eee81774696ea7ba4caafac2bad8f028bba94b1af83777d7/MedPy-0.4.0.tar.gz (151kB)
#      |████████████████████████████████| 153kB 4.6MB/s
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.17.5)
# Collecting SimpleITK>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/f8/d8/53338c34f71020725ffb3557846c80af96c29c03bc883551a2565aa68a7c/SimpleITK-1.2.4-cp36-cp36m-manylinux1_x86_64.whl (42.5MB)
#      |████████████████████████████████| 42.5MB 71kB/s
# Building wheels for collected packages: medpy
#   Building wheel for medpy (setup.py) ... done
#   Created wheel for medpy: filename=MedPy-0.4.0-cp36-cp36m-linux_x86_64.whl size=753425 sha256=8550b7d21c84d7f35143fc7975a4f8eb693415ce6259a137921efe1838afbe47
#   Stored in directory: /root/.cache/pip/wheels/8c/c9/9c/2c6281c7a72b9fb1570862a4f028af7ce38405008354fbf870
# Successfully built medpy
# Installing collected packages: SimpleITK, medpy
# Successfully installed SimpleITK-1.2.4 medpy-0.4.0

# %%
def get_conv_block(input_layer,nFilters,size):
    conv1 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(input_layer)
    bn1 = BatchNormalization()(conv1)
    conv2 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(bn1)
    bn2 = BatchNormalization()(conv2)
    return bn2
    
def get_model():    
    input_layer = Input(shape=(240,240,3))
    block1 = get_conv_block(input_layer,32,3)
    mp1 = MaxPooling2D(pool_size=(2, 2))(block1)
    dr1 = Dropout(0.1)(mp1)
    
    block2 = get_conv_block(dr1,64,3)
    mp2 = MaxPooling2D(pool_size=(2, 2))(block2)
    dr2 = Dropout(0.1)(mp2)
    
    block3 = get_conv_block(dr2,128,3)
    mp3 = MaxPooling2D(pool_size=(2, 2))(block3)
    dr3 = Dropout(0.1)(mp3)
    
    block4 = get_conv_block(dr3,256,3)
    mp4 = MaxPooling2D(pool_size=(2, 2))(block4)
    dr4 = Dropout(0.1)(mp4)

    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(dr4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)

    up1 = Conv2DTranspose(256,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(conv5)
    cat1 = concatenate([block4,up1])
    dr1 = Dropout(0.1)(cat1)
    block5 = get_conv_block(dr1,256,3)

    up2 = Conv2DTranspose(128,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block5)
    cat2 = concatenate([block3,up2])
    dr2 = Dropout(0.1)(cat2)
    block6 = get_conv_block(dr2,128,3)
    
    up3 = Conv2DTranspose(64,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block6)
    cat3 = concatenate([block2,up3])
    dr3 = Dropout(0.1)(cat3)
    block7 = get_conv_block(dr3,64,3)
    
    up4 = Conv2DTranspose(32,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block7)
    cat4 = concatenate([block1,up4])
    dr4 = Dropout(0.1)(cat4)
    block8 = get_conv_block(dr4,64,3)

    conv10 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(block8)
    conv11 = Conv2D(3,(1,1), activation='softmax', padding = 'same')(conv10)

    model = Model(input_layer,conv11)
    return model

# %%
model = get_model()
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 240, 240, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 240, 240, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 240, 240, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 240, 240, 32) 9248        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 240, 240, 32) 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 120, 120, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 120, 120, 32) 0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 120, 120, 64) 18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 120, 120, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 120, 120, 64) 36928       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 120, 120, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 60, 60, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 60, 60, 64)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 60, 60, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 60, 60, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 60, 60, 128)  147584      batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 60, 60, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 30, 30, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 30, 30, 128)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 30, 30, 256)  295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 30, 30, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 30, 30, 256)  590080      batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 30, 30, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 15, 15, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 15, 15, 256)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 15, 15, 512)  1180160     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 15, 15, 512)  2359808     conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 30, 30, 256)  1179904     conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 30, 30, 512)  0           batch_normalization_8[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 30, 30, 512)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 30, 30, 256)  1179904     dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 30, 30, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 30, 30, 256)  590080      batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 30, 30, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 60, 60, 128)  295040      batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 60, 60, 256)  0           batch_normalization_6[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 60, 60, 256)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 60, 60, 128)  295040      dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 60, 60, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 60, 60, 128)  147584      batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 60, 60, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 120, 120, 64) 73792       batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 120, 120, 128 0           batch_normalization_4[0][0]
#                                                                  conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 120, 120, 128 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 120, 120, 64) 73792       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 120, 120, 64) 256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 120, 120, 64) 36928       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 120, 120, 64) 256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 240, 240, 32) 18464       batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 240, 240, 64) 0           batch_normalization_2[0][0]
#                                                                  conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 240, 240, 64) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 240, 240, 64) 36928       dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 240, 240, 64) 256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 240, 240, 64) 36928       batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 240, 240, 64) 256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 240, 240, 2)  1154        batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 240, 240, 3)  9           conv2d_19[0][0]
# ==================================================================================================
# Total params: 8,685,707
# Trainable params: 8,681,739
# Non-trainable params: 3,968
# __________________________________________________________________________________________________

# %%
smooth = 1.
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

# %%
import math
from keras.callbacks import EarlyStopping,ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
mc = ModelCheckpoint('Checkpoint.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
optimizer=keras.optimizers.Adam(lr=1e-5, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=True)
class_wt = [1,5,5]

# %%
from keras import backend as K      
model.compile(loss=tversky_loss, optimizer=optimizer, metrics=[dice_coef,'accuracy'])

# %%
TrainX.shape
# Out:
# (1800, 240, 240, 3)

# %%
num_epoch = 100;
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models"
history = model.fit(TrainX, TrainY, epochs=num_epoch, validation_data=(ValidX, ValidY), shuffle=True,batch_size=16,callbacks=[es,mc])
model.save(MODELS_PATH + '/UNET_ER_20_01_20_v3.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 1800 samples, validate on 120 samples
# Epoch 1/100
# 1800/1800 [==============================] - 40s 22ms/step - loss: 2.2599 - dice_coef: 0.3266 - acc: 0.6390 - val_loss: 2.4961 - val_dice_coef: 0.3189 - val_acc: 0.7575
#
# Epoch 00001: val_loss improved from inf to 2.49605, saving model to Checkpoint.h5
# Epoch 2/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 2.1467 - dice_coef: 0.3829 - acc: 0.7752 - val_loss: 2.4577 - val_dice_coef: 0.3513 - val_acc: 0.8648
#
# Epoch 00002: val_loss improved from 2.49605 to 2.45766, saving model to Checkpoint.h5
# Epoch 3/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 2.0554 - dice_coef: 0.4338 - acc: 0.8352 - val_loss: 2.4152 - val_dice_coef: 0.3887 - val_acc: 0.9069
#
# Epoch 00003: val_loss improved from 2.45766 to 2.41520, saving model to Checkpoint.h5
# Epoch 4/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.9703 - dice_coef: 0.4848 - acc: 0.8547 - val_loss: 2.3792 - val_dice_coef: 0.4215 - val_acc: 0.8659
#
# Epoch 00004: val_loss improved from 2.41520 to 2.37922, saving model to Checkpoint.h5
# Epoch 5/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.8862 - dice_coef: 0.5338 - acc: 0.8714 - val_loss: 2.3325 - val_dice_coef: 0.4674 - val_acc: 0.9589
#
# Epoch 00005: val_loss improved from 2.37922 to 2.33249, saving model to Checkpoint.h5
# Epoch 6/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.8231 - dice_coef: 0.5716 - acc: 0.8840 - val_loss: 2.3084 - val_dice_coef: 0.4919 - val_acc: 0.9476
#
# Epoch 00006: val_loss improved from 2.33249 to 2.30840, saving model to Checkpoint.h5
# Epoch 7/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.7725 - dice_coef: 0.6003 - acc: 0.8858 - val_loss: 2.2816 - val_dice_coef: 0.5198 - val_acc: 0.9860
#
# Epoch 00007: val_loss improved from 2.30840 to 2.28156, saving model to Checkpoint.h5
# Epoch 8/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.7334 - dice_coef: 0.6245 - acc: 0.8916 - val_loss: 2.2554 - val_dice_coef: 0.5474 - val_acc: 0.9822
#
# Epoch 00008: val_loss improved from 2.28156 to 2.25543, saving model to Checkpoint.h5
# Epoch 9/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.6937 - dice_coef: 0.6455 - acc: 0.8901 - val_loss: 2.2179 - val_dice_coef: 0.5871 - val_acc: 0.9871
#
# Epoch 00009: val_loss improved from 2.25543 to 2.21792, saving model to Checkpoint.h5
# Epoch 10/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.6524 - dice_coef: 0.6657 - acc: 0.8941 - val_loss: 2.1875 - val_dice_coef: 0.6202 - val_acc: 0.9868
#
# Epoch 00010: val_loss improved from 2.21792 to 2.18745, saving model to Checkpoint.h5
# Epoch 11/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.6247 - dice_coef: 0.6824 - acc: 0.8918 - val_loss: 2.1595 - val_dice_coef: 0.6484 - val_acc: 0.9873
#
# Epoch 00011: val_loss improved from 2.18745 to 2.15950, saving model to Checkpoint.h5
# Epoch 12/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.5856 - dice_coef: 0.6990 - acc: 0.8961 - val_loss: 2.0980 - val_dice_coef: 0.7074 - val_acc: 0.9875
#
# Epoch 00012: val_loss improved from 2.15950 to 2.09804, saving model to Checkpoint.h5
# Epoch 13/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.5556 - dice_coef: 0.7136 - acc: 0.8941 - val_loss: 2.0534 - val_dice_coef: 0.7471 - val_acc: 0.9879
#
# Epoch 00013: val_loss improved from 2.09804 to 2.05338, saving model to Checkpoint.h5
# Epoch 14/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.5287 - dice_coef: 0.7269 - acc: 0.8953 - val_loss: 1.9911 - val_dice_coef: 0.8004 - val_acc: 0.9879
#
# Epoch 00014: val_loss improved from 2.05338 to 1.99106, saving model to Checkpoint.h5
# Epoch 15/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.4971 - dice_coef: 0.7397 - acc: 0.8962 - val_loss: 1.9778 - val_dice_coef: 0.8119 - val_acc: 0.9879
#
# Epoch 00015: val_loss improved from 1.99106 to 1.97780, saving model to Checkpoint.h5
# Epoch 16/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.4677 - dice_coef: 0.7520 - acc: 0.8969 - val_loss: 1.9032 - val_dice_coef: 0.8698 - val_acc: 0.9882
#
# Epoch 00016: val_loss improved from 1.97780 to 1.90317, saving model to Checkpoint.h5
# Epoch 17/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.4535 - dice_coef: 0.7619 - acc: 0.8984 - val_loss: 1.8836 - val_dice_coef: 0.8804 - val_acc: 0.9883
#
# Epoch 00017: val_loss improved from 1.90317 to 1.88356, saving model to Checkpoint.h5
# Epoch 18/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.4174 - dice_coef: 0.7734 - acc: 0.9007 - val_loss: 1.8595 - val_dice_coef: 0.8935 - val_acc: 0.9883
#
# Epoch 00018: val_loss improved from 1.88356 to 1.85948, saving model to Checkpoint.h5
# Epoch 19/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.3934 - dice_coef: 0.7832 - acc: 0.9012 - val_loss: 1.8508 - val_dice_coef: 0.8984 - val_acc: 0.9883
#
# Epoch 00019: val_loss improved from 1.85948 to 1.85081, saving model to Checkpoint.h5
# Epoch 20/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.3667 - dice_coef: 0.7926 - acc: 0.9018 - val_loss: 1.8287 - val_dice_coef: 0.9092 - val_acc: 0.9884
#
# Epoch 00020: val_loss improved from 1.85081 to 1.82865, saving model to Checkpoint.h5
# Epoch 21/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.3510 - dice_coef: 0.8004 - acc: 0.9029 - val_loss: 1.8497 - val_dice_coef: 0.8977 - val_acc: 0.9881
#
# Epoch 00021: val_loss did not improve from 1.82865
# Epoch 22/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.3257 - dice_coef: 0.8088 - acc: 0.9036 - val_loss: 1.8196 - val_dice_coef: 0.9135 - val_acc: 0.9884
#
# Epoch 00022: val_loss improved from 1.82865 to 1.81958, saving model to Checkpoint.h5
# Epoch 23/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.3021 - dice_coef: 0.8167 - acc: 0.9051 - val_loss: 1.8004 - val_dice_coef: 0.9221 - val_acc: 0.9884
#
# Epoch 00023: val_loss improved from 1.81958 to 1.80044, saving model to Checkpoint.h5
# Epoch 24/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.2842 - dice_coef: 0.8232 - acc: 0.9055 - val_loss: 1.7865 - val_dice_coef: 0.9274 - val_acc: 0.9885
#
# Epoch 00024: val_loss improved from 1.80044 to 1.78652, saving model to Checkpoint.h5
# Epoch 25/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.2789 - dice_coef: 0.8286 - acc: 0.9049 - val_loss: 1.7845 - val_dice_coef: 0.9284 - val_acc: 0.9885
#
# Epoch 00025: val_loss improved from 1.78652 to 1.78450, saving model to Checkpoint.h5
# Epoch 26/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.2610 - dice_coef: 0.8341 - acc: 0.9059 - val_loss: 1.7777 - val_dice_coef: 0.9312 - val_acc: 0.9885
#
# Epoch 00026: val_loss improved from 1.78450 to 1.77766, saving model to Checkpoint.h5
# Epoch 27/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.2387 - dice_coef: 0.8408 - acc: 0.9081 - val_loss: 1.7810 - val_dice_coef: 0.9299 - val_acc: 0.9885
#
# Epoch 00027: val_loss did not improve from 1.77766
# Epoch 28/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.2214 - dice_coef: 0.8458 - acc: 0.9054 - val_loss: 1.7668 - val_dice_coef: 0.9361 - val_acc: 0.9798
#
# Epoch 00028: val_loss improved from 1.77766 to 1.76683, saving model to Checkpoint.h5
# Epoch 29/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.2009 - dice_coef: 0.8515 - acc: 0.8961 - val_loss: 1.7643 - val_dice_coef: 0.9384 - val_acc: 0.9819
#
# Epoch 00029: val_loss improved from 1.76683 to 1.76431, saving model to Checkpoint.h5
# Epoch 30/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.1899 - dice_coef: 0.8563 - acc: 0.8999 - val_loss: 1.7577 - val_dice_coef: 0.9407 - val_acc: 0.9834
#
# Epoch 00030: val_loss improved from 1.76431 to 1.75769, saving model to Checkpoint.h5
# Epoch 31/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.1716 - dice_coef: 0.8605 - acc: 0.9016 - val_loss: 1.7508 - val_dice_coef: 0.9449 - val_acc: 0.9852
#
# Epoch 00031: val_loss improved from 1.75769 to 1.75083, saving model to Checkpoint.h5
# Epoch 32/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.1702 - dice_coef: 0.8637 - acc: 0.9037 - val_loss: 1.7465 - val_dice_coef: 0.9473 - val_acc: 0.9832
#
# Epoch 00032: val_loss improved from 1.75083 to 1.74652, saving model to Checkpoint.h5
# Epoch 33/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.1488 - dice_coef: 0.8683 - acc: 0.9061 - val_loss: 1.7578 - val_dice_coef: 0.9523 - val_acc: 0.9888
#
# Epoch 00033: val_loss did not improve from 1.74652
# Epoch 34/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.1345 - dice_coef: 0.8716 - acc: 0.9079 - val_loss: 1.7358 - val_dice_coef: 0.9508 - val_acc: 0.9861
#
# Epoch 00034: val_loss improved from 1.74652 to 1.73585, saving model to Checkpoint.h5
# Epoch 35/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.1452 - dice_coef: 0.8726 - acc: 0.9096 - val_loss: 1.7446 - val_dice_coef: 0.9552 - val_acc: 0.9877
#
# Epoch 00035: val_loss did not improve from 1.73585
# Epoch 36/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.1283 - dice_coef: 0.8762 - acc: 0.9106 - val_loss: 1.7501 - val_dice_coef: 0.9571 - val_acc: 0.9891
#
# Epoch 00036: val_loss did not improve from 1.73585
# Epoch 37/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.1104 - dice_coef: 0.8800 - acc: 0.9118 - val_loss: 1.7499 - val_dice_coef: 0.9590 - val_acc: 0.9894
#
# Epoch 00037: val_loss did not improve from 1.73585
# Epoch 38/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.0986 - dice_coef: 0.8828 - acc: 0.9154 - val_loss: 1.7254 - val_dice_coef: 0.9568 - val_acc: 0.9840
#
# Epoch 00038: val_loss improved from 1.73585 to 1.72542, saving model to Checkpoint.h5
# Epoch 39/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.0875 - dice_coef: 0.8853 - acc: 0.9175 - val_loss: 1.7195 - val_dice_coef: 0.9593 - val_acc: 0.9853
#
# Epoch 00039: val_loss improved from 1.72542 to 1.71954, saving model to Checkpoint.h5
# Epoch 40/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.0738 - dice_coef: 0.8885 - acc: 0.9189 - val_loss: 1.7177 - val_dice_coef: 0.9606 - val_acc: 0.9848
#
# Epoch 00040: val_loss improved from 1.71954 to 1.71768, saving model to Checkpoint.h5
# Epoch 41/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.0611 - dice_coef: 0.8909 - acc: 0.9205 - val_loss: 1.7407 - val_dice_coef: 0.9645 - val_acc: 0.9895
#
# Epoch 00041: val_loss did not improve from 1.71768
# Epoch 42/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.0459 - dice_coef: 0.8933 - acc: 0.9228 - val_loss: 1.7303 - val_dice_coef: 0.9658 - val_acc: 0.9894
#
# Epoch 00042: val_loss did not improve from 1.71768
# Epoch 43/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.0541 - dice_coef: 0.8940 - acc: 0.9224 - val_loss: 1.7073 - val_dice_coef: 0.9646 - val_acc: 0.9866
#
# Epoch 00043: val_loss improved from 1.71768 to 1.70729, saving model to Checkpoint.h5
# Epoch 44/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.0425 - dice_coef: 0.8957 - acc: 0.9229 - val_loss: 1.7403 - val_dice_coef: 0.9689 - val_acc: 0.9901
#
# Epoch 00044: val_loss did not improve from 1.70729
# Epoch 45/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.0291 - dice_coef: 0.8983 - acc: 0.9254 - val_loss: 1.7623 - val_dice_coef: 0.9700 - val_acc: 0.9902
#
# Epoch 00045: val_loss did not improve from 1.70729
# Epoch 46/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.0264 - dice_coef: 0.8993 - acc: 0.9245 - val_loss: 1.7201 - val_dice_coef: 0.9698 - val_acc: 0.9896
#
# Epoch 00046: val_loss did not improve from 1.70729
# Epoch 47/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.0128 - dice_coef: 0.9013 - acc: 0.9262 - val_loss: 1.7099 - val_dice_coef: 0.9695 - val_acc: 0.9883
#
# Epoch 00047: val_loss did not improve from 1.70729
# Epoch 48/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.0207 - dice_coef: 0.9010 - acc: 0.9259 - val_loss: 1.7161 - val_dice_coef: 0.9722 - val_acc: 0.9898
#
# Epoch 00048: val_loss did not improve from 1.70729
# Epoch 49/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.0148 - dice_coef: 0.9030 - acc: 0.9276 - val_loss: 1.7553 - val_dice_coef: 0.9736 - val_acc: 0.9905
#
# Epoch 00049: val_loss did not improve from 1.70729
# Epoch 50/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 1.0116 - dice_coef: 0.9042 - acc: 0.9299 - val_loss: 1.7775 - val_dice_coef: 0.9742 - val_acc: 0.9905
#
# Epoch 00050: val_loss did not improve from 1.70729
# Epoch 51/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 0.9931 - dice_coef: 0.9062 - acc: 0.9285 - val_loss: 1.7499 - val_dice_coef: 0.9751 - val_acc: 0.9904
#
# Epoch 00051: val_loss did not improve from 1.70729
# Epoch 52/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 0.9928 - dice_coef: 0.9067 - acc: 0.9296 - val_loss: 1.7814 - val_dice_coef: 0.9758 - val_acc: 0.9905
#
# Epoch 00052: val_loss did not improve from 1.70729
# Epoch 53/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 0.9846 - dice_coef: 0.9084 - acc: 0.9316 - val_loss: 1.7348 - val_dice_coef: 0.9760 - val_acc: 0.9904
#
# Epoch 00053: val_loss did not improve from 1.70729
# Epoch 00053: early stopping

# %%
from keras.models import load_model

MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models"
model.load_weights(MODELS_PATH + '/UNET_ER_20_01_20_v3.h5')

# %%
train_loss = history.history['loss']
train_acc = history.history['acc']
val_loss = history.history['val_loss']
val_acc = history.history['val_acc']
xc=range(len(train_loss))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_loss)
plt.plot(xc, val_loss)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(['train','val'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-58b846d4c3f1> in <module>()
# ----> 1 train_loss = history.history['loss']
#       2 train_acc = history.history['acc']
#       3 val_loss = history.history['val_loss']
#       4 val_acc = history.history['val_acc']
#       5 xc=range(len(train_loss))
#
# NameError: name 'history' is not defined

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_acc)
plt.plot(xc, val_acc)
plt.xlabel("Epoch")
plt.ylabel("Acc")
plt.legend(['train','val'])

# %%
# Function to find the most probable class of an image pixel by pixel
def ClassFinder(img):
  result = np.zeros(img.shape, dtype=np.uint8)
  for r in range(len(img)):
    for c in range(len(img[0])):
      idx = np.argmax(img[r][c])
      result[r][c][idx]=1
      
  return result

# %%
train_result = model.predict(TrainX, batch_size=16)
print(np.shape(train_result))
Train_predict = [ ]
for img in train_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_predict.append(encoded_img)

Predicted_images = np.asarray(Train_predict)
print(Predicted_images.shape)
np.unique(Predicted_images)
# dice = dc(train_result, TrainY)
# pre  = precision(train_result,TrainY)
# re   = recall(train_result,TrainY)
# print('Train dc: '  + str(dice))
# print('Train pre: ' + str(pre))
# print('Train re: '  + str(re))
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240)
# array([  0, 128, 255], dtype=uint8)

# %%
test_result = model.predict(TestX, batch_size=16)
print(np.shape(test_result))

Test_predict = [ ]
for img in test_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_predict.append(encoded_img)

Predicted_images_test = np.asarray(Test_predict)
print(Predicted_images_test.shape)
np.unique(Predicted_images_test)
# dice = dc(test_result, TestY)
# pre  = precision(test_result,TestY)
# re   = recall(test_result,TestY)
# print('Test dc: '  + str(dice))
# print('Test pre: ' + str(pre))
# print('Test re: '  + str(re))
# Out:
# (960, 240, 240, 3)
# (960, 240, 240)
# array([  0, 128, 255], dtype=uint8)

# %%
from sklearn.metrics import confusion_matrix
def get_confusion_matrix(Actual, Predicted):
  ActualY = np.reshape(Actual,(-1, Actual.shape[3]))
  PredY = np.reshape(Predicted,(-1, Predicted.shape[3]))
  matrix = confusion_matrix(ActualY.argmax(axis = 1), PredY.argmax(axis = 1))
  return matrix

def get_precision(confusion_matrix):
  precision = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 0)
  nan_indices = np.isnan(precision)
  precision[nan_indices] = 0
  return precision

def get_recall(confusion_matrix):
  recall = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 1)
  nan_indices = np.isnan(recall)
  recall[nan_indices] = 0
  return recall

# %%
test_matrix = get_confusion_matrix(TestY, test_result)
train_matrix = get_confusion_matrix(TrainY, train_result)
print(test_matrix)
print(train_matrix)
# TestY.shape[3]
# test_result.shape
# Out:
# [[55211941    52017     4734]
#  [   11050    16217       41]
#  [       0        0        0]]
# [[86952374  2118667   978402]
#  [  708972  5011366   425477]
#  [  348903  1489121  5646718]]

# %%
np.unique(Predicted_images_test)
# Out:
# array([  0, 128, 255], dtype=uint8)

# %%
test_precision = get_precision(test_matrix)
print('Test Precision')
print(test_precision)
test_recall = get_recall(test_matrix)
print('Test Recall')
print(test_recall)
train_precision = get_precision(train_matrix)
print('Train Precision')
print(train_precision)
train_recall = get_recall(train_matrix)
print('Train Recall')
print(train_recall)
# Out:
# Test Precision
# [0.9997999  0.23766744 0.        ]
# Test Recall
# [0.99897318 0.59385528 0.        ]
# Train Precision
# [0.98798009 0.58142203 0.80088509]
# Train Recall
# [0.96560702 0.81541114 0.75443055]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in true_divide
#   from ipykernel import kernelapp as app

# %%
weight_matrix = np.zeros((3,1))
weight_matrix[0] = 1/3
weight_matrix[1] = 1/3
weight_matrix[2] = 1/3
print(weight_matrix.shape)
# Out:
# (3, 1)

# %%
# weight_matrix = np.zeros((3,1))
# weight_matrix[0] = 1/3
# weight_matrix[1] = 1/3
# weight_matrix[2] = 1/3
# print(weight_matrix.shape)

# %%
def get_overall_precision(precision, weights):
  final_precision = np.dot(precision,weights)
  return final_precision

def get_overall_recall(recall, weights):
  final_recall = np.dot(recall ,weights)
  return final_recall

# %%
final_test_precision  = get_overall_precision(test_precision, weight_matrix)
final_test_recall     = get_overall_recall(test_recall, weight_matrix)
final_train_precision = get_overall_precision(train_precision, weight_matrix)
final_train_recall    = get_overall_recall(train_recall, weight_matrix)
print('Final Test Precision')
print(final_test_precision)
print('Final Test Recall')
print(final_test_recall)
print('Final Train Precision')
print(final_train_precision)
print('Final Train Recall')
print(final_train_recall)
# Out:
# Final Test Precision
# [0.43521049]
# Final Test Recall
# [0.33367592]
# Final Train Precision
# [0.65612709]
# Final Train Recall
# [0.59711733]

# %%
from scipy.stats import hmean

def dice_coefficient(precision, recall):
  return hmean(np.asarray([precision , recall]))

# %%
test_dice_coeff = dice_coefficient(final_test_precision, final_test_recall)
print('Test Dice coeff')
print(test_dice_coeff)

train_dice_coeff = dice_coefficient(final_train_precision, final_train_recall)
print('Train Dice coeff')
print(train_dice_coeff)
# Out:
# Test Dice coeff
# [0.37773918]
# Train Dice coeff
# [0.62523295]

# %%
copy1  = np.copy(TestX [250])
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
copy3 = np.reshape(copy2,(240, 240,3))
Img = cv2.cvtColor(copy3,cv2.COLOR_BGR2RGB)

Mask = TestGroundTruth[250]

Predicted_Mask = Predicted_images_test[250] 

plt.subplot(131).imshow(Img)
plt.subplot(132).imshow(Mask,'gray')
plt.subplot(133).imshow(Predicted_Mask,'gray')

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask):
  num = mask.shape[0]/480
  for id in range(int(num)):
    temp = []
    for i in range(id, id+10):
      idx = i * 48
      final_output = mask[idx:idx+48]
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save("/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/Tversky/ER Patient " + str(id), final_output)

# %%
# saving predicted outputs as numpy arrays for test images
saveNumpyOutput(Predicted_images)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 12   # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]

Mask_input = TestY[id:id+48]
Test_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Test_Actual)
print(Mask_input.shape)

final_output = Predicted_images_test[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 3)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0. 128. 255.]

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 14 # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]

Mask_input = TrainY[id:id+48]
Train_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Train_Actual)
print(Mask_input.shape)

final_output = Predicted_images[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 3)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0. 128. 255.]
