# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
# !pip install -U keras
# !pip install tensorflow-gpu==2.1.0rc0

# %%
import math
import random
import keras
from keras.layers import *
from keras.models import Sequential
from keras import Model
from keras import backend as K  
from keras.regularizers import l2
from keras.callbacks import EarlyStopping,ModelCheckpoint

from sklearn.model_selection import LeaveOneOut
from sklearn import metrics
# Out:
# Using TensorFlow backend.

# %%
def get_conv_block(input_layer,nFilters,size):
    conv1 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(input_layer)
    bn1 = BatchNormalization()(conv1)
    conv2 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(bn1)
    bn2 = BatchNormalization()(conv2)
    return bn2
    
def get_UNET(input_layer,nFilters,flag): 

    block1 = get_conv_block(input_layer[0],nFilters,3)
    mp1 = MaxPooling2D(pool_size=(2, 2))(block1)
    dr1 = Dropout(0.1)(mp1)
   
    if(flag==1):
      dr1 = concatenate([dr1,input_layer[1]])

    block2 = get_conv_block(dr1,nFilters*2,3)
    mp2 = MaxPooling2D(pool_size=(2, 2))(block2)
    dr2 = Dropout(0.1)(mp2)

    if(flag==1):
      dr2 = concatenate([dr2,input_layer[2]])
   
    block3 = get_conv_block(dr2,nFilters*4,3)
    mp3 = MaxPooling2D(pool_size=(2, 2))(block3)
    dr3 = Dropout(0.1)(mp3)

    if(flag==1):
      dr3 = concatenate([dr3,input_layer[3]])
       
    block4 = get_conv_block(dr3,nFilters*8,3)
    mp4 = MaxPooling2D(pool_size=(2, 2))(block4)
    dr4 = Dropout(0.1)(mp4)

    conv5 = Conv2D(nFilters*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(dr4)
    conv5 = Conv2D(nFilters*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(conv5)

    up1 = Conv2DTranspose(nFilters*8,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(conv5)
    cat1 = concatenate([block4, up1, mp3])
    dr1 = Dropout(0.1)(cat1)
    block5 = get_conv_block(dr1,nFilters*8,3)

    up2 = Conv2DTranspose(nFilters*4,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block5)
    b4_upsample = Conv2DTranspose(nFilters*4,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block4)
    cat2 = concatenate([block3, up2, b4_upsample, mp2])
    dr2 = Dropout(0.1)(cat2)
    block6 = get_conv_block(dr2,nFilters*4,3)
    
    up3 = Conv2DTranspose(nFilters*2,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block6)
    b3_upsample = Conv2DTranspose(nFilters*2,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block3)
    cat3 = concatenate([block2, up3, mp1, b3_upsample])
    dr3 = Dropout(0.1)(cat3)
    block7 = get_conv_block(dr3,nFilters*2,3)
    
    up4 = Conv2DTranspose(nFilters,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block7)
    b2_upsample = Conv2DTranspose(nFilters,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block2)
    cat4 = concatenate([block1, up4, b2_upsample])
    dr4 = Dropout(0.1)(cat4)
    block8 = get_conv_block(dr4,nFilters,3)

    conv10 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(block8)
    conv11 = Conv2D(4,(1,1), activation='softmax', padding = 'same',kernel_regularizer=l2(1e-4))(conv10)

    return (conv11, block7, block6, block5)

def get_model(input_shape,nFilters1,nFilters2):

    input_layer = Input(shape=input_shape)
    out1,out2,out3,out4 = get_UNET([input_layer],nFilters1,0)

    out1,out2,out3,out4 = get_UNET([out1,out2,out3,out4],nFilters2,1)

    model = Model(input_layer,out1)
    return model

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/4 Class ER"

# Loading the data patient wise
X1 = np.load(PATH + '/ER IHC 230 Images.npy')
Y1 = np.load(PATH + '/ER IHC 230 Masks.npy')

X2 = np.load(PATH + '/ER IHC 232 Images.npy')
Y2 = np.load(PATH + '/ER IHC 232 Masks.npy')

X3 = np.load(PATH + '/ER IHC 242 Images.npy')
Y3 = np.load(PATH + '/ER IHC 242 Masks.npy')

X4 = np.load(PATH + '/ER IHC 263 Images.npy')
Y4 = np.load(PATH + '/ER IHC 263 Masks.npy')

X5 = np.load(PATH + '/ER IHC 221 Images.npy')
Y5 = np.load(PATH + '/ER IHC 221 Masks.npy')

X6 = np.load(PATH + '/ER IHC 229 Images.npy')
Y6 = np.load(PATH + '/ER IHC 229 Masks.npy')

X7 = np.load(PATH + '/ER IHC 239 Images.npy')
Y7 = np.load(PATH + '/ER IHC 239 Masks.npy')

X8 = np.load(PATH + '/ER IHC 246 Images.npy')
Y8 = np.load(PATH + '/ER IHC 246 Masks.npy')

X9 = np.load(PATH + '/ER IHC 252 Images.npy')
Y9 = np.load(PATH + '/ER IHC 252 Masks.npy')

# %%
X = [X1, X2, X3, X4, X5, X6, X7, X8, X9]
Y = [Y1, Y2, Y3, Y4, Y5, Y6, Y7, Y8, Y9]
patient_no = ['230','232','242','263','221','229','239','246','252']
size = [10,10,10,10,10,10,10,10,10]

# %%
fold_split = []

#test patient = 230, 232 
fold_split.append(([2,3,4,5,6,7,8],[0,1]))

#test_patient = 239, 242
# fold_split.append(([0,1,3,4,5,7,8],[2,6]))

# #test_patient = 252,263
# fold_split.append(([0,1,2,4,5,6,7],[3,8]))

# %%
def convertToLabels(data):
  data[data==85]=1
  data[data==170]=2
  data[data==255]=3

def convertFromLabels(data):
  data[data==1]=85
  data[data==2]=170
  data[data==3]=255

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
# def tversky_loss(y_true, y_pred):
#     alpha = 0.5
#     beta  = 0.5
    
#     ones = K.ones(K.shape(y_true))
#     p0 = y_pred      # proba that voxels are class i
#     p1 = ones-y_pred # proba that voxels are not class i
#     g0 = y_true
#     g1 = ones-y_true
    
#     num = K.sum(p0*g0, (0,1,2))
#     den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
#     # 
#     T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
#     Ncl = K.cast(K.shape(y_true)[-1], 'float32')
#     return Ncl-T

# def combined_loss(y_true, y_pred):
#   return (0.2*K.categorical_crossentropy(y_true, y_pred))+(0.8*tversky_loss(y_true, y_pred))

# %%
def tversky_loss(y_true, y_pred):
    alpha = 0.7
    beta  = 0.3
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    # 
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def focal_tversky_loss(y_true, y_pred, gamma=0.75):
    tversky_index = tversky_loss(y_true, y_pred)
    return K.pow((tversky_index), gamma)

def combined_loss(y_true, y_pred):
  return (0.2*K.categorical_crossentropy(y_true, y_pred))+(0.8*focal_tversky_loss(y_true, y_pred))

# %%
batch_size = 16
def get_batch(batch_size, X_train, Y_train): 
    size_batch = batch_size
    last_index = len(X_train) - 1
    x_train = X_train
    y_train = Y_train 
    while True:
        batch_data = [[],[]]
        for i in range(0, size_batch):
            random_index = random.randint(0, last_index)
            batch_data[0].append(x_train[random_index])
            batch_data[1].append(y_train[random_index])

        yield (np.array(batch_data[0]), np.array(batch_data[1]))

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER/FTL"

fold=0

for train_index, test_index in fold_split:
  print("TRAIN:", train_index, "TEST:", test_index)
  
  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  Train = list(zip(TrainX,TrainY))
  random.shuffle(Train)
  TrainX,TrainY = zip(*Train)
  TrainX = np.asarray(list(TrainX))
  TrainY = np.asarray(list(TrainY))

  Test = list(zip(TestX,TestY))
  random.shuffle(Test)
  TestX,TestY = zip(*Test)
  TestX = np.asarray(list(TestX))
  TestY = np.asarray(list(TestY))

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255
  convertToLabels(TrainY)
  TrainY = keras.utils.to_categorical(TrainY,num_classes=4,dtype='int16')
  convertToLabels(TestY)
  TestY = keras.utils.to_categorical(TestY,num_classes=4,dtype='int16')
  ValX = TrainX[(int)(0.8*TrainX.shape[0]):]
  ValY = TrainY[(int)(0.8*TrainY.shape[0]):]
  model = get_model((240,240,3),32,32)

  # es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
  mc = ModelCheckpoint('Checkpoint.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

  optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=0.001, decay=0.0, amsgrad=True)

  model.compile(loss=focal_tversky_loss, optimizer= optimizer , metrics=[dice_coef,'accuracy']) 
  num_epoch = 100
  datagen = get_batch(batch_size, TrainX, TrainY)
  n_points = len(TrainX)
  print('-----------fold {}--------------'.format(fold))
  history = model.fit(datagen, validation_data = [ValX, ValY],
                  epochs=num_epoch,steps_per_epoch = math.ceil(n_points / batch_size), callbacks =[mc],  shuffle =True)
  model.save(MODELS_PATH + '/LadderNet_ER'+ str(fold) +'.h5')
  fold = fold + 1
# Out:
# TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1]
# -----------fold 0--------------
# Epoch 1/100
# 210/210 [==============================] - 187s 889ms/step - loss: 3.2521 - dice_coef: 0.6472 - accuracy: 0.8507 - val_loss: 2.9693 - val_dice_coef: 0.9373 - val_accuracy: 0.9472
#
# Epoch 00001: val_loss improved from inf to 2.96925, saving model to Checkpoint.h5
# Epoch 2/100
# 210/210 [==============================] - 168s 799ms/step - loss: 2.8212 - dice_coef: 0.9475 - accuracy: 0.9547 - val_loss: 2.7971 - val_dice_coef: 0.9406 - val_accuracy: 0.9412
#
# Epoch 00002: val_loss improved from 2.96925 to 2.79711, saving model to Checkpoint.h5
# Epoch 3/100
# 210/210 [==============================] - 168s 799ms/step - loss: 2.7006 - dice_coef: 0.9567 - accuracy: 0.9604 - val_loss: 2.7606 - val_dice_coef: 0.9480 - val_accuracy: 0.9492
#
# Epoch 00003: val_loss improved from 2.79711 to 2.76065, saving model to Checkpoint.h5
# Epoch 4/100
# 210/210 [==============================] - 168s 799ms/step - loss: 2.6249 - dice_coef: 0.9561 - accuracy: 0.9597 - val_loss: 2.5749 - val_dice_coef: 0.9529 - val_accuracy: 0.9557
#
# Epoch 00004: val_loss improved from 2.76065 to 2.57487, saving model to Checkpoint.h5
# Epoch 5/100
# 210/210 [==============================] - 168s 800ms/step - loss: 2.5295 - dice_coef: 0.9577 - accuracy: 0.9605 - val_loss: 2.6686 - val_dice_coef: 0.9537 - val_accuracy: 0.9545
#
# Epoch 00005: val_loss did not improve from 2.57487
# Epoch 6/100
# 210/210 [==============================] - 168s 799ms/step - loss: 2.4857 - dice_coef: 0.9589 - accuracy: 0.9619 - val_loss: 2.4162 - val_dice_coef: 0.9563 - val_accuracy: 0.9594
#
# Epoch 00006: val_loss improved from 2.57487 to 2.41622, saving model to Checkpoint.h5
# Epoch 7/100
# 210/210 [==============================] - 168s 800ms/step - loss: 2.3904 - dice_coef: 0.9579 - accuracy: 0.9603 - val_loss: 2.4396 - val_dice_coef: 0.9561 - val_accuracy: 0.9578
#
# Epoch 00007: val_loss did not improve from 2.41622
# Epoch 8/100
# 210/210 [==============================] - 168s 800ms/step - loss: 2.3172 - dice_coef: 0.9578 - accuracy: 0.9600 - val_loss: 2.5258 - val_dice_coef: 0.9300 - val_accuracy: 0.9342
#
# Epoch 00008: val_loss did not improve from 2.41622
# Epoch 9/100
# 210/210 [==============================] - 168s 799ms/step - loss: 2.2799 - dice_coef: 0.9577 - accuracy: 0.9596 - val_loss: 2.2578 - val_dice_coef: 0.9561 - val_accuracy: 0.9573
#
# Epoch 00009: val_loss improved from 2.41622 to 2.25783, saving model to Checkpoint.h5
# Epoch 10/100
# 210/210 [==============================] - 168s 799ms/step - loss: 2.2338 - dice_coef: 0.9606 - accuracy: 0.9619 - val_loss: 2.2931 - val_dice_coef: 0.9559 - val_accuracy: 0.9565
#
# Epoch 00010: val_loss did not improve from 2.25783
# Epoch 11/100
# 210/210 [==============================] - 168s 799ms/step - loss: 2.1667 - dice_coef: 0.9588 - accuracy: 0.9600 - val_loss: 2.3722 - val_dice_coef: 0.9539 - val_accuracy: 0.9544
#
# Epoch 00011: val_loss did not improve from 2.25783
# Epoch 12/100
# 210/210 [==============================] - 168s 799ms/step - loss: 2.0905 - dice_coef: 0.9600 - accuracy: 0.9605 - val_loss: 2.0547 - val_dice_coef: 0.9575 - val_accuracy: 0.9582
#
# Epoch 00012: val_loss improved from 2.25783 to 2.05472, saving model to Checkpoint.h5
# Epoch 13/100
# 210/210 [==============================] - 168s 799ms/step - loss: 2.0838 - dice_coef: 0.9609 - accuracy: 0.9611 - val_loss: 2.3209 - val_dice_coef: 0.9395 - val_accuracy: 0.9388
#
# Epoch 00013: val_loss did not improve from 2.05472
# Epoch 14/100
# 210/210 [==============================] - 168s 799ms/step - loss: 2.0057 - dice_coef: 0.9590 - accuracy: 0.9593 - val_loss: 2.2005 - val_dice_coef: 0.8925 - val_accuracy: 0.8895
#
# Epoch 00014: val_loss did not improve from 2.05472
# Epoch 15/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.9704 - dice_coef: 0.9603 - accuracy: 0.9609 - val_loss: 1.9990 - val_dice_coef: 0.9526 - val_accuracy: 0.9522
#
# Epoch 00015: val_loss improved from 2.05472 to 1.99899, saving model to Checkpoint.h5
# Epoch 16/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.9311 - dice_coef: 0.9609 - accuracy: 0.9614 - val_loss: 2.1573 - val_dice_coef: 0.9369 - val_accuracy: 0.9342
#
# Epoch 00016: val_loss did not improve from 1.99899
# Epoch 17/100
# 210/210 [==============================] - 168s 800ms/step - loss: 1.9078 - dice_coef: 0.9598 - accuracy: 0.9601 - val_loss: 1.8851 - val_dice_coef: 0.9570 - val_accuracy: 0.9579
#
# Epoch 00017: val_loss improved from 1.99899 to 1.88510, saving model to Checkpoint.h5
# Epoch 18/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.8638 - dice_coef: 0.9612 - accuracy: 0.9617 - val_loss: 1.8609 - val_dice_coef: 0.9595 - val_accuracy: 0.9604
#
# Epoch 00018: val_loss improved from 1.88510 to 1.86087, saving model to Checkpoint.h5
# Epoch 19/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.8273 - dice_coef: 0.9579 - accuracy: 0.9585 - val_loss: 1.8035 - val_dice_coef: 0.9572 - val_accuracy: 0.9571
#
# Epoch 00019: val_loss improved from 1.86087 to 1.80347, saving model to Checkpoint.h5
# Epoch 20/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.8123 - dice_coef: 0.9606 - accuracy: 0.9610 - val_loss: 1.7878 - val_dice_coef: 0.9570 - val_accuracy: 0.9579
#
# Epoch 00020: val_loss improved from 1.80347 to 1.78776, saving model to Checkpoint.h5
# Epoch 21/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.7980 - dice_coef: 0.9626 - accuracy: 0.9631 - val_loss: 1.8049 - val_dice_coef: 0.9552 - val_accuracy: 0.9552
#
# Epoch 00021: val_loss did not improve from 1.78776
# Epoch 22/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.7680 - dice_coef: 0.9618 - accuracy: 0.9622 - val_loss: 1.8323 - val_dice_coef: 0.9499 - val_accuracy: 0.9500
#
# Epoch 00022: val_loss did not improve from 1.78776
# Epoch 23/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.7320 - dice_coef: 0.9635 - accuracy: 0.9641 - val_loss: 1.7129 - val_dice_coef: 0.9594 - val_accuracy: 0.9600
#
# Epoch 00023: val_loss improved from 1.78776 to 1.71290, saving model to Checkpoint.h5
# Epoch 24/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.7449 - dice_coef: 0.9619 - accuracy: 0.9623 - val_loss: 1.6818 - val_dice_coef: 0.9601 - val_accuracy: 0.9607
#
# Epoch 00024: val_loss improved from 1.71290 to 1.68176, saving model to Checkpoint.h5
# Epoch 25/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.7013 - dice_coef: 0.9623 - accuracy: 0.9627 - val_loss: 1.6751 - val_dice_coef: 0.9570 - val_accuracy: 0.9574
#
# Epoch 00025: val_loss improved from 1.68176 to 1.67509, saving model to Checkpoint.h5
# Epoch 26/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.6781 - dice_coef: 0.9620 - accuracy: 0.9623 - val_loss: 1.8878 - val_dice_coef: 0.9382 - val_accuracy: 0.9379
#
# Epoch 00026: val_loss did not improve from 1.67509
# Epoch 27/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.6522 - dice_coef: 0.9616 - accuracy: 0.9620 - val_loss: 1.6863 - val_dice_coef: 0.9588 - val_accuracy: 0.9595
#
# Epoch 00027: val_loss did not improve from 1.67509
# Epoch 28/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.6292 - dice_coef: 0.9624 - accuracy: 0.9628 - val_loss: 1.7668 - val_dice_coef: 0.9379 - val_accuracy: 0.9375
#
# Epoch 00028: val_loss did not improve from 1.67509
# Epoch 29/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.6311 - dice_coef: 0.9642 - accuracy: 0.9646 - val_loss: 1.6521 - val_dice_coef: 0.9561 - val_accuracy: 0.9564
#
# Epoch 00029: val_loss improved from 1.67509 to 1.65210, saving model to Checkpoint.h5
# Epoch 30/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.6187 - dice_coef: 0.9615 - accuracy: 0.9619 - val_loss: 1.6881 - val_dice_coef: 0.9554 - val_accuracy: 0.9551
#
# Epoch 00030: val_loss did not improve from 1.65210
# Epoch 31/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.5904 - dice_coef: 0.9575 - accuracy: 0.9578 - val_loss: 1.6239 - val_dice_coef: 0.9544 - val_accuracy: 0.9557
#
# Epoch 00031: val_loss improved from 1.65210 to 1.62390, saving model to Checkpoint.h5
# Epoch 32/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.5780 - dice_coef: 0.9639 - accuracy: 0.9642 - val_loss: 1.6095 - val_dice_coef: 0.9542 - val_accuracy: 0.9543
#
# Epoch 00032: val_loss improved from 1.62390 to 1.60955, saving model to Checkpoint.h5
# Epoch 33/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.5919 - dice_coef: 0.9616 - accuracy: 0.9617 - val_loss: 1.5978 - val_dice_coef: 0.9608 - val_accuracy: 0.9609
#
# Epoch 00033: val_loss improved from 1.60955 to 1.59779, saving model to Checkpoint.h5
# Epoch 34/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.5575 - dice_coef: 0.9638 - accuracy: 0.9639 - val_loss: 1.5597 - val_dice_coef: 0.9586 - val_accuracy: 0.9587
#
# Epoch 00034: val_loss improved from 1.59779 to 1.55972, saving model to Checkpoint.h5
# Epoch 35/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.5889 - dice_coef: 0.9604 - accuracy: 0.9605 - val_loss: 1.6338 - val_dice_coef: 0.9491 - val_accuracy: 0.9492
#
# Epoch 00035: val_loss did not improve from 1.55972
# Epoch 36/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.5461 - dice_coef: 0.9616 - accuracy: 0.9617 - val_loss: 1.6130 - val_dice_coef: 0.9605 - val_accuracy: 0.9606
#
# Epoch 00036: val_loss did not improve from 1.55972
# Epoch 37/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.5562 - dice_coef: 0.9582 - accuracy: 0.9582 - val_loss: 1.6702 - val_dice_coef: 0.9545 - val_accuracy: 0.9545
#
# Epoch 00037: val_loss did not improve from 1.55972
# Epoch 38/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.5694 - dice_coef: 0.9608 - accuracy: 0.9607 - val_loss: 1.6856 - val_dice_coef: 0.9568 - val_accuracy: 0.9587
#
# Epoch 00038: val_loss did not improve from 1.55972
# Epoch 39/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.5746 - dice_coef: 0.9610 - accuracy: 0.9610 - val_loss: 1.5910 - val_dice_coef: 0.9598 - val_accuracy: 0.9599
#
# Epoch 00039: val_loss did not improve from 1.55972
# Epoch 40/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.5645 - dice_coef: 0.9614 - accuracy: 0.9614 - val_loss: 1.6219 - val_dice_coef: 0.9489 - val_accuracy: 0.9488
#
# Epoch 00040: val_loss did not improve from 1.55972
# Epoch 41/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.4743 - dice_coef: 0.9624 - accuracy: 0.9624 - val_loss: 1.5351 - val_dice_coef: 0.9563 - val_accuracy: 0.9563
#
# Epoch 00041: val_loss improved from 1.55972 to 1.53508, saving model to Checkpoint.h5
# Epoch 42/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.5002 - dice_coef: 0.9601 - accuracy: 0.9601 - val_loss: 1.5239 - val_dice_coef: 0.9563 - val_accuracy: 0.9563
#
# Epoch 00042: val_loss improved from 1.53508 to 1.52385, saving model to Checkpoint.h5
# Epoch 43/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.5206 - dice_coef: 0.9624 - accuracy: 0.9624 - val_loss: 1.5042 - val_dice_coef: 0.9597 - val_accuracy: 0.9598
#
# Epoch 00043: val_loss improved from 1.52385 to 1.50424, saving model to Checkpoint.h5
# Epoch 44/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.5385 - dice_coef: 0.9620 - accuracy: 0.9621 - val_loss: 1.5168 - val_dice_coef: 0.9579 - val_accuracy: 0.9579
#
# Epoch 00044: val_loss did not improve from 1.50424
# Epoch 45/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.4785 - dice_coef: 0.9626 - accuracy: 0.9627 - val_loss: 1.5330 - val_dice_coef: 0.9620 - val_accuracy: 0.9620
#
# Epoch 00045: val_loss did not improve from 1.50424
# Epoch 46/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4916 - dice_coef: 0.9643 - accuracy: 0.9643 - val_loss: 1.7027 - val_dice_coef: 0.9528 - val_accuracy: 0.9528
#
# Epoch 00046: val_loss did not improve from 1.50424
# Epoch 47/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.5735 - dice_coef: 0.9586 - accuracy: 0.9586 - val_loss: 2.1632 - val_dice_coef: 0.8741 - val_accuracy: 0.8736
#
# Epoch 00047: val_loss did not improve from 1.50424
# Epoch 48/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.5111 - dice_coef: 0.9602 - accuracy: 0.9602 - val_loss: 1.6124 - val_dice_coef: 0.9562 - val_accuracy: 0.9561
#
# Epoch 00048: val_loss did not improve from 1.50424
# Epoch 49/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4946 - dice_coef: 0.9607 - accuracy: 0.9607 - val_loss: 1.4537 - val_dice_coef: 0.9591 - val_accuracy: 0.9592
#
# Epoch 00049: val_loss improved from 1.50424 to 1.45372, saving model to Checkpoint.h5
# Epoch 50/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.5030 - dice_coef: 0.9610 - accuracy: 0.9611 - val_loss: 1.5437 - val_dice_coef: 0.9560 - val_accuracy: 0.9560
#
# Epoch 00050: val_loss did not improve from 1.45372
# Epoch 51/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4752 - dice_coef: 0.9619 - accuracy: 0.9620 - val_loss: 1.6526 - val_dice_coef: 0.9548 - val_accuracy: 0.9548
#
# Epoch 00051: val_loss did not improve from 1.45372
# Epoch 52/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4728 - dice_coef: 0.9623 - accuracy: 0.9624 - val_loss: 1.5515 - val_dice_coef: 0.9609 - val_accuracy: 0.9610
#
# Epoch 00052: val_loss did not improve from 1.45372
# Epoch 53/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4722 - dice_coef: 0.9631 - accuracy: 0.9632 - val_loss: 1.4636 - val_dice_coef: 0.9557 - val_accuracy: 0.9557
#
# Epoch 00053: val_loss did not improve from 1.45372
# Epoch 54/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4702 - dice_coef: 0.9625 - accuracy: 0.9626 - val_loss: 1.4837 - val_dice_coef: 0.9591 - val_accuracy: 0.9592
#
# Epoch 00054: val_loss did not improve from 1.45372
# Epoch 55/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4592 - dice_coef: 0.9630 - accuracy: 0.9631 - val_loss: 1.4533 - val_dice_coef: 0.9569 - val_accuracy: 0.9569
#
# Epoch 00055: val_loss improved from 1.45372 to 1.45331, saving model to Checkpoint.h5
# Epoch 56/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4331 - dice_coef: 0.9642 - accuracy: 0.9642 - val_loss: 1.5216 - val_dice_coef: 0.9531 - val_accuracy: 0.9531
#
# Epoch 00056: val_loss did not improve from 1.45331
# Epoch 57/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4908 - dice_coef: 0.9618 - accuracy: 0.9618 - val_loss: 1.6323 - val_dice_coef: 0.9471 - val_accuracy: 0.9471
#
# Epoch 00057: val_loss did not improve from 1.45331
# Epoch 58/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4703 - dice_coef: 0.9628 - accuracy: 0.9629 - val_loss: 1.4838 - val_dice_coef: 0.9547 - val_accuracy: 0.9548
#
# Epoch 00058: val_loss did not improve from 1.45331
# Epoch 59/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4578 - dice_coef: 0.9604 - accuracy: 0.9604 - val_loss: 1.4382 - val_dice_coef: 0.9613 - val_accuracy: 0.9614
#
# Epoch 00059: val_loss improved from 1.45331 to 1.43820, saving model to Checkpoint.h5
# Epoch 60/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4794 - dice_coef: 0.9635 - accuracy: 0.9635 - val_loss: 1.4490 - val_dice_coef: 0.9574 - val_accuracy: 0.9574
#
# Epoch 00060: val_loss did not improve from 1.43820
# Epoch 61/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4230 - dice_coef: 0.9623 - accuracy: 0.9623 - val_loss: 1.5787 - val_dice_coef: 0.9588 - val_accuracy: 0.9588
#
# Epoch 00061: val_loss did not improve from 1.43820
# Epoch 62/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4463 - dice_coef: 0.9644 - accuracy: 0.9644 - val_loss: 1.5394 - val_dice_coef: 0.9585 - val_accuracy: 0.9586
#
# Epoch 00062: val_loss did not improve from 1.43820
# Epoch 63/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4369 - dice_coef: 0.9605 - accuracy: 0.9606 - val_loss: 1.5336 - val_dice_coef: 0.9562 - val_accuracy: 0.9562
#
# Epoch 00063: val_loss did not improve from 1.43820
# Epoch 64/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4570 - dice_coef: 0.9585 - accuracy: 0.9585 - val_loss: 1.5158 - val_dice_coef: 0.9599 - val_accuracy: 0.9599
#
# Epoch 00064: val_loss did not improve from 1.43820
# Epoch 65/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4606 - dice_coef: 0.9601 - accuracy: 0.9601 - val_loss: 1.5075 - val_dice_coef: 0.9623 - val_accuracy: 0.9623
#
# Epoch 00065: val_loss did not improve from 1.43820
# Epoch 66/100
# 210/210 [==============================] - 167s 798ms/step - loss: 1.4703 - dice_coef: 0.9612 - accuracy: 0.9612 - val_loss: 1.5221 - val_dice_coef: 0.9574 - val_accuracy: 0.9575
#
# Epoch 00066: val_loss did not improve from 1.43820
# Epoch 67/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4160 - dice_coef: 0.9628 - accuracy: 0.9629 - val_loss: 1.4383 - val_dice_coef: 0.9586 - val_accuracy: 0.9586
#
# Epoch 00067: val_loss did not improve from 1.43820
# Epoch 68/100
# 210/210 [==============================] - 167s 798ms/step - loss: 1.4407 - dice_coef: 0.9611 - accuracy: 0.9611 - val_loss: 1.5560 - val_dice_coef: 0.9530 - val_accuracy: 0.9530
#
# Epoch 00068: val_loss did not improve from 1.43820
# Epoch 69/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4076 - dice_coef: 0.9620 - accuracy: 0.9621 - val_loss: 1.4106 - val_dice_coef: 0.9586 - val_accuracy: 0.9586
#
# Epoch 00069: val_loss improved from 1.43820 to 1.41057, saving model to Checkpoint.h5
# Epoch 70/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4579 - dice_coef: 0.9620 - accuracy: 0.9620 - val_loss: 1.5290 - val_dice_coef: 0.9573 - val_accuracy: 0.9576
#
# Epoch 00070: val_loss did not improve from 1.41057
# Epoch 71/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4500 - dice_coef: 0.9643 - accuracy: 0.9643 - val_loss: 1.4332 - val_dice_coef: 0.9559 - val_accuracy: 0.9560
#
# Epoch 00071: val_loss did not improve from 1.41057
# Epoch 72/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4063 - dice_coef: 0.9643 - accuracy: 0.9643 - val_loss: 1.4349 - val_dice_coef: 0.9598 - val_accuracy: 0.9598
#
# Epoch 00072: val_loss did not improve from 1.41057
# Epoch 73/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4077 - dice_coef: 0.9626 - accuracy: 0.9626 - val_loss: 2.0455 - val_dice_coef: 0.7292 - val_accuracy: 0.7480
#
# Epoch 00073: val_loss did not improve from 1.41057
# Epoch 74/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4342 - dice_coef: 0.9624 - accuracy: 0.9625 - val_loss: 1.5173 - val_dice_coef: 0.9338 - val_accuracy: 0.9337
#
# Epoch 00074: val_loss did not improve from 1.41057
# Epoch 75/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.3970 - dice_coef: 0.9641 - accuracy: 0.9642 - val_loss: 1.6194 - val_dice_coef: 0.9494 - val_accuracy: 0.9494
#
# Epoch 00075: val_loss did not improve from 1.41057
# Epoch 76/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4239 - dice_coef: 0.9629 - accuracy: 0.9630 - val_loss: 1.4574 - val_dice_coef: 0.9606 - val_accuracy: 0.9606
#
# Epoch 00076: val_loss did not improve from 1.41057
# Epoch 77/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4011 - dice_coef: 0.9621 - accuracy: 0.9621 - val_loss: 1.4460 - val_dice_coef: 0.9589 - val_accuracy: 0.9592
#
# Epoch 00077: val_loss did not improve from 1.41057
# Epoch 78/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.3636 - dice_coef: 0.9631 - accuracy: 0.9632 - val_loss: 1.6861 - val_dice_coef: 0.9420 - val_accuracy: 0.9421
#
# Epoch 00078: val_loss did not improve from 1.41057
# Epoch 79/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.3998 - dice_coef: 0.9626 - accuracy: 0.9627 - val_loss: 1.4214 - val_dice_coef: 0.9612 - val_accuracy: 0.9612
#
# Epoch 00079: val_loss did not improve from 1.41057
# Epoch 80/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4310 - dice_coef: 0.9632 - accuracy: 0.9632 - val_loss: 1.6044 - val_dice_coef: 0.9449 - val_accuracy: 0.9573
#
# Epoch 00080: val_loss did not improve from 1.41057
# Epoch 81/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4711 - dice_coef: 0.9605 - accuracy: 0.9606 - val_loss: 1.4664 - val_dice_coef: 0.9601 - val_accuracy: 0.9602
#
# Epoch 00081: val_loss did not improve from 1.41057
# Epoch 82/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4313 - dice_coef: 0.9632 - accuracy: 0.9633 - val_loss: 1.5095 - val_dice_coef: 0.9457 - val_accuracy: 0.9457
#
# Epoch 00082: val_loss did not improve from 1.41057
# Epoch 83/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4304 - dice_coef: 0.9620 - accuracy: 0.9621 - val_loss: 1.4422 - val_dice_coef: 0.9574 - val_accuracy: 0.9575
#
# Epoch 00083: val_loss did not improve from 1.41057
# Epoch 84/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.3949 - dice_coef: 0.9631 - accuracy: 0.9631 - val_loss: 1.4605 - val_dice_coef: 0.9589 - val_accuracy: 0.9589
#
# Epoch 00084: val_loss did not improve from 1.41057
# Epoch 85/100
# 210/210 [==============================] - 168s 799ms/step - loss: 1.3667 - dice_coef: 0.9630 - accuracy: 0.9630 - val_loss: 1.4161 - val_dice_coef: 0.9586 - val_accuracy: 0.9586
#
# Epoch 00085: val_loss did not improve from 1.41057
# Epoch 86/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4281 - dice_coef: 0.9631 - accuracy: 0.9631 - val_loss: 1.4151 - val_dice_coef: 0.9587 - val_accuracy: 0.9589
#
# Epoch 00086: val_loss did not improve from 1.41057
# Epoch 87/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4435 - dice_coef: 0.9623 - accuracy: 0.9623 - val_loss: 1.5418 - val_dice_coef: 0.9583 - val_accuracy: 0.9583
#
# Epoch 00087: val_loss did not improve from 1.41057
# Epoch 88/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4059 - dice_coef: 0.9635 - accuracy: 0.9635 - val_loss: 1.4707 - val_dice_coef: 0.9607 - val_accuracy: 0.9608
#
# Epoch 00088: val_loss did not improve from 1.41057
# Epoch 89/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.3839 - dice_coef: 0.9651 - accuracy: 0.9651 - val_loss: 1.4398 - val_dice_coef: 0.9601 - val_accuracy: 0.9601
#
# Epoch 00089: val_loss did not improve from 1.41057
# Epoch 90/100
# 210/210 [==============================] - 167s 798ms/step - loss: 1.4001 - dice_coef: 0.9632 - accuracy: 0.9633 - val_loss: 1.5542 - val_dice_coef: 0.9533 - val_accuracy: 0.9533
#
# Epoch 00090: val_loss did not improve from 1.41057
# Epoch 91/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4013 - dice_coef: 0.9627 - accuracy: 0.9628 - val_loss: 1.4255 - val_dice_coef: 0.9560 - val_accuracy: 0.9560
#
# Epoch 00091: val_loss did not improve from 1.41057
# Epoch 92/100
# 210/210 [==============================] - 167s 798ms/step - loss: 1.3705 - dice_coef: 0.9630 - accuracy: 0.9630 - val_loss: 1.4894 - val_dice_coef: 0.9600 - val_accuracy: 0.9601
#
# Epoch 00092: val_loss did not improve from 1.41057
# Epoch 93/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4229 - dice_coef: 0.9621 - accuracy: 0.9622 - val_loss: 1.4374 - val_dice_coef: 0.9553 - val_accuracy: 0.9554
#
# Epoch 00093: val_loss did not improve from 1.41057
# Epoch 94/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.4229 - dice_coef: 0.9622 - accuracy: 0.9622 - val_loss: 1.5319 - val_dice_coef: 0.9561 - val_accuracy: 0.9562
#
# Epoch 00094: val_loss did not improve from 1.41057
# Epoch 95/100
# 210/210 [==============================] - 168s 798ms/step - loss: 1.3924 - dice_coef: 0.9625 - accuracy: 0.9625 - val_loss: 1.4254 - val_dice_coef: 0.9621 - val_accuracy: 0.9621
#
# Epoch 00095: val_loss did not improve from 1.41057
# Epoch 96/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4175 - dice_coef: 0.9641 - accuracy: 0.9641 - val_loss: 1.4051 - val_dice_coef: 0.9611 - val_accuracy: 0.9611
#
# Epoch 00096: val_loss improved from 1.41057 to 1.40513, saving model to Checkpoint.h5
# Epoch 97/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.4159 - dice_coef: 0.9637 - accuracy: 0.9637 - val_loss: 1.4432 - val_dice_coef: 0.9539 - val_accuracy: 0.9541
#
# Epoch 00097: val_loss did not improve from 1.40513
# Epoch 98/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.3877 - dice_coef: 0.9616 - accuracy: 0.9616 - val_loss: 1.4183 - val_dice_coef: 0.9617 - val_accuracy: 0.9617
#
# Epoch 00098: val_loss did not improve from 1.40513
# Epoch 99/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.3670 - dice_coef: 0.9597 - accuracy: 0.9597 - val_loss: 1.5641 - val_dice_coef: 0.9586 - val_accuracy: 0.9587
#
# Epoch 00099: val_loss did not improve from 1.40513
# Epoch 100/100
# 210/210 [==============================] - 167s 797ms/step - loss: 1.3986 - dice_coef: 0.9630 - accuracy: 0.9630 - val_loss: 1.4727 - val_dice_coef: 0.9563 - val_accuracy: 0.9564
#
# Epoch 00100: val_loss did not improve from 1.40513

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask, Patient_array,Patient_length,title,folder):
  idx = 0
  for i in range(len(Patient_length)):
    temp = []
    for j in range(Patient_length[i]):
      final_output = mask[idx:idx+48]
      idx = idx + 48
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save(folder + title + Patient_array[i], final_output)

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER/FTL/"
model_names = os.listdir(MODELS_PATH)
print(model_names)
# Out:
# ['LadderNet_ER0.h5']

# %%
SAVE_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/ER/FTL/"

# %%
# Axis 0 = Folds
# Axis 1 = Class (Strong Intermediate,Weak,Background)
# Axis 2 = Evaluation Technique (Precision, Recall, Dice coefficient)
pixEvaluationTrain = np.empty((0,4,3))
pixEvaluationTest = np.empty((0,4,3))
score = np.zeros((1,4,3))

# %%
fold = 0

for train_index, test_index in fold_split:
  print("FOLD:",fold,"\tTRAIN:", train_index, "TEST:", test_index)
  # Splitting Train and Test data
  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  train_no = [patient_no[i] for i in train_index]
  train_size = [size[i] for i in train_index]

  test_no = [patient_no[i] for i in test_index]
  test_size = [size[i] for i in test_index]

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255

  convertToLabels(TrainY)
  convertToLabels(TestY)
  
  # Loading corrosponding fold of model
  model = keras.models.load_model(MODELS_PATH + model_names[fold],custom_objects={ 'focal_tversky_loss': focal_tversky_loss, 'dice_coef': dice_coef })

  # Predicting results using model
  trainResult = model.predict(TrainX, batch_size=8)
  testResult = model.predict(TestX,batch_size=8)

  trainResult = np.argmax(trainResult,axis=-1)
  testResult = np.argmax(testResult,axis=-1)

  # Obtaining pixel-wise results: Precision recall and dice coefficient
  # For TRAIN
  y_true = np.reshape(TrainY,(-1))
  y_pred = np.reshape(trainResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(4):
    score[0][i][0] = prec[3-i]
    score[0][i][1] = recall[3-i]
    score[0][i][2] = dice[3-i]

  pixEvaluationTrain = np.append(pixEvaluationTrain,score,axis=0)
 
  # For TEST
  y_true = np.reshape(TestY,(-1))
  y_pred = np.reshape(testResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(4):
    score[0][i][0] = prec[3-i]
    score[0][i][1] = recall[3-i]
    score[0][i][2] = dice[3-i]

  pixEvaluationTest = np.append(pixEvaluationTest,score,axis=0)

  # Converting predicted labels to required output format
  convertFromLabels(trainResult)
  convertFromLabels(testResult)

  # Saving numpy arrays
  path = os.path.join(SAVE_PATH,"Fold " + str(fold))
  os.mkdir(path)
  os.mkdir(path + '/Train')
  os.mkdir(path + '/Test')

  saveNumpyOutput(trainResult, train_no, train_size,"/Train/",path)
  saveNumpyOutput(testResult, test_no, test_size,"/Test/",path)

  fold +=1
# Out:
# FOLD: 0 	TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1]

# %%
print(pixEvaluationTrain.shape)
print(pixEvaluationTest.shape)
print(pixEvaluationTest)
# Out:
# (1, 4, 3)
# (1, 4, 3)
# [[[0.78615809 0.47361435 0.59111589]
#   [0.47005241 0.42802952 0.4480578 ]
#   [0.21642334 0.18720371 0.20075589]
#   [0.95521313 0.98575745 0.97024496]]]

# %%
np.save(SAVE_PATH + "Pixel-wise Metrics Train.npy", pixEvaluationTrain)
np.save(SAVE_PATH + "Pixel-wise Metrics Test.npy", pixEvaluationTest)

# %% [markdown]
# # **DISPLAY**

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 48   # enter between 0- 50 since there are 5 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]
Mask_input = TestGT[id:id+48]
final_output = testResult[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 25  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]
Mask_input = TrainGT[id:id+48]
final_output = trainResult[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
