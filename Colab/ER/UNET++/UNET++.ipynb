# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import tensorflow as tf

# %%
import os
import cv2
import numpy as np
import math
import random
import keras
from keras.layers import *
from keras.models import Sequential
from keras import Model
from keras import backend as K  
from keras.regularizers import l2
from keras.callbacks import EarlyStopping,ModelCheckpoint
from sklearn import metrics
# Out:
# Using TensorFlow backend.

# %%
def get_conv_block(input_layer,nFilters,size):
    conv1 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(input_layer)
    bn1 = BatchNormalization()(conv1)
    conv2 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(bn1)
    bn2 = BatchNormalization()(conv2)
    return bn2
    
def get_UNETplusplus(input_layer,nFilters): 

    block00 = get_conv_block(input_layer,nFilters,3)
    mp1 = MaxPooling2D(pool_size=(2, 2))(block00)
    dr1 = Dropout(0.1)(mp1)

    block10 = get_conv_block(dr1,nFilters*2,3)
    mp2 = MaxPooling2D(pool_size=(2, 2))(block10)
    dr2 = Dropout(0.1)(mp2)
  
    block20 = get_conv_block(dr2,nFilters*4,3)
    mp3 = MaxPooling2D(pool_size=(2, 2))(block20)
    dr3 = Dropout(0.1)(mp3)

    block30 = get_conv_block(dr3,nFilters*8,3)
    mp4 = MaxPooling2D(pool_size=(2, 2))(block30)
    dr4 = Dropout(0.1)(mp4)

    conv5 = Conv2D(nFilters*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(dr4)
    block40 = Conv2D(nFilters*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(conv5)

    block01 = Conv2DTranspose(nFilters,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block10)
    block01 = Add()([block01,block00])
    block11 = Conv2DTranspose(nFilters*2,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block20)
    block11 = Add()([block11,block10])
    block21 = Conv2DTranspose(nFilters*4,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block30)
    block21 = Add()([block21,block20])

    block02 = Conv2DTranspose(nFilters,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block11)
    block02 = Add()([block02,block01,block00])
    block12 = Conv2DTranspose(nFilters*2,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block21)
    block12 = Add()([block12,block11,block10])

    block03 = Conv2DTranspose(nFilters,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block12)
    block03 = Add()([block03,block02,block01,block00])

    up1 = Conv2DTranspose(nFilters*8,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block40)
    cat1 = concatenate([block30, up1])
    dr1 = Dropout(0.1)(cat1)
    block31 = get_conv_block(dr1,nFilters*8,3)

    up2 = Conv2DTranspose(nFilters*4,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block31)
    add2 = Add()([block20, block21])
    cat2 = concatenate([add2,up2])
    dr2 = Dropout(0.1)(cat2)
    block22 = get_conv_block(dr2,nFilters*4,3)
    
    up3 = Conv2DTranspose(nFilters*2,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block22)
    add3 = Add()([block10, block11, block12])
    cat3 = concatenate([add3, up3])
    dr3 = Dropout(0.1)(cat3)
    block13 = get_conv_block(dr3,nFilters*2,3)
    
    up4 = Conv2DTranspose(nFilters,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block13)
    add4 = Add()([block00, block01, block02, block03])
    cat4 = concatenate([add4, up4])
    dr4 = Dropout(0.1)(cat4)
    block04 = get_conv_block(dr4,nFilters,3)

    conv10 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(block04)
    out = Conv2D(4,(1,1), activation='softmax', padding = 'same',kernel_regularizer=l2(1e-4))(conv10)

    return out

def get_model(input_shape,nFilters):

    input_layer = Input(shape=input_shape)
    out = get_UNETplusplus(input_layer,nFilters)
    model = Model(input_layer,out)
    return model

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/4 Class ER"

# Loading the data patient wise
X1 = np.load(PATH + '/ER IHC 230 Images.npy')
Y1 = np.load(PATH + '/ER IHC 230 Masks.npy')

X2 = np.load(PATH + '/ER IHC 232 Images.npy')
Y2 = np.load(PATH + '/ER IHC 232 Masks.npy')

X3 = np.load(PATH + '/ER IHC 242 Images.npy')
Y3 = np.load(PATH + '/ER IHC 242 Masks.npy')

X4 = np.load(PATH + '/ER IHC 263 Images.npy')
Y4 = np.load(PATH + '/ER IHC 263 Masks.npy')

X5 = np.load(PATH + '/ER IHC 221 Images.npy')
Y5 = np.load(PATH + '/ER IHC 221 Masks.npy')

X6 = np.load(PATH + '/ER IHC 229 Images.npy')
Y6 = np.load(PATH + '/ER IHC 229 Masks.npy')

X7 = np.load(PATH + '/ER IHC 239 Images.npy')
Y7 = np.load(PATH + '/ER IHC 239 Masks.npy')

X8 = np.load(PATH + '/ER IHC 246 Images.npy')
Y8 = np.load(PATH + '/ER IHC 246 Masks.npy')

X9 = np.load(PATH + '/ER IHC 252 Images.npy')
Y9 = np.load(PATH + '/ER IHC 252 Masks.npy')

# %%
X = [X1, X2, X3, X4, X5, X6, X7, X8, X9]
Y = [Y1, Y2, Y3, Y4, Y5, Y6, Y7, Y8, Y9]
patient_no = ['230','232','242','263','221','229','239','246','252']
size = [10,10,10,10,10,10,10,10,10]

# %%
fold_split = []

#test patient = 230, 232 
fold_split.append(([2,3,4,5,6,7,8],[0,1]))

#test_patient = 239, 242
# fold_split.append(([0,1,3,4,5,7,8],[2,6]))

# #test_patient = 252,263
# fold_split.append(([0,1,2,4,5,6,7],[3,8]))

# %%
def convertToLabels(data):
  data[data==85]=1
  data[data==170]=2
  data[data==255]=3

def convertFromLabels(data):
  data[data==1]=85
  data[data==2]=170
  data[data==3]=255

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
def tversky_loss_1(y_true, y_pred):
    alpha = 0.7
    beta  = 0.3
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
  
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    # 
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def tversky_loss_2(y_true, y_pred):
    alpha = 0.3
    beta  = 0.7
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    # 
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def focal_tversky_loss_1(y_true, y_pred, gamma=0.75):
    tversky_index = tversky_loss_1(y_true, y_pred)
    return K.pow((tversky_index), gamma)
  
def focal_tversky_loss_2(y_true, y_pred, gamma=0.75):
    tversky_index = tversky_loss_2(y_true, y_pred)
    return K.pow((tversky_index), gamma)

def combined_loss(y_true, y_pred):
  return (0.2*K.categorical_crossentropy(y_true, y_pred))+(0.8*focal_tversky_loss_1(y_true, y_pred)+(0.8*focal_tversky_loss_2(y_true, y_pred)))

# %%
batch_size = 8
def get_batch(batch_size, X_train, Y_train): 
    size_batch = batch_size
    last_index = len(X_train) - 1
    x_train = X_train
    y_train = Y_train 
    while True:
        batch_data = [[],[]]
        for i in range(0, size_batch):
            random_index = random.randint(0, last_index)
            batch_data[0].append(x_train[random_index])
            batch_data[1].append(y_train[random_index])

        yield (np.array(batch_data[0]), np.array(batch_data[1]))

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER/UNET++"

fold=0

for train_index, test_index in fold_split:
  print("TRAIN:", train_index, "TEST:", test_index, "FOLD:", fold)

  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  Train = list(zip(TrainX,TrainY))
  random.shuffle(Train)
  TrainX,TrainY = zip(*Train)
  TrainX = np.asarray(list(TrainX))
  TrainY = np.asarray(list(TrainY))

  Test = list(zip(TestX,TestY))
  random.shuffle(Test)
  TestX,TestY = zip(*Test)
  TestX = np.asarray(list(TestX))
  TestY = np.asarray(list(TestY))

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255
  convertToLabels(TrainY)
  TrainY = keras.utils.to_categorical(TrainY,num_classes=4,dtype='int16')
  convertToLabels(TestY)
  TestY = keras.utils.to_categorical(TestY,num_classes=4,dtype='int16')
  ValX = TrainX[(int)(0.8*TrainX.shape[0]):]
  ValY = TrainY[(int)(0.8*TrainY.shape[0]):]
  model = get_model((240,240,3),64)

  #es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
  mc = ModelCheckpoint('Checkpoint.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

  optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=0.001, decay=0.0, amsgrad=True)

  model.compile(loss=combined_loss, optimizer= optimizer , metrics=[dice_coef,'accuracy']) 
  num_epoch = 100
  datagen = get_batch(batch_size, TrainX, TrainY)
  n_points = len(TrainX)
  print('-----------fold {}--------------'.format(fold))
  history = model.fit(datagen, validation_data = [ValX, ValY],
                  epochs=num_epoch,steps_per_epoch = math.ceil(n_points / batch_size), callbacks =[mc],  shuffle =True)
  model.save(MODELS_PATH + '/UNET++_ER_'+ str(fold) +'.h5')
  fold = fold + 1
# Out:
# TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1] FOLD: 0
# -----------fold 0--------------
# Epoch 1/100
# 420/420 [==============================] - 235s 560ms/step - loss: 4.3807 - dice_coef: 0.8270 - accuracy: 0.9000 - val_loss: 4.3574 - val_dice_coef: 0.9122 - val_accuracy: 0.9112
#
# Epoch 00001: val_loss improved from inf to 4.35736, saving model to Checkpoint.h5
# Epoch 2/100
# 420/420 [==============================] - 222s 529ms/step - loss: 3.9145 - dice_coef: 0.9427 - accuracy: 0.9472 - val_loss: 3.7417 - val_dice_coef: 0.9523 - val_accuracy: 0.9567
#
# Epoch 00002: val_loss improved from 4.35736 to 3.74173, saving model to Checkpoint.h5
# Epoch 3/100
# 420/420 [==============================] - 222s 528ms/step - loss: 3.7243 - dice_coef: 0.9516 - accuracy: 0.9561 - val_loss: 3.5079 - val_dice_coef: 0.9498 - val_accuracy: 0.9546
#
# Epoch 00003: val_loss improved from 3.74173 to 3.50792, saving model to Checkpoint.h5
# Epoch 4/100
# 420/420 [==============================] - 222s 528ms/step - loss: 3.5304 - dice_coef: 0.9523 - accuracy: 0.9564 - val_loss: 3.5468 - val_dice_coef: 0.9184 - val_accuracy: 0.9183
#
# Epoch 00004: val_loss did not improve from 3.50792
# Epoch 5/100
# 420/420 [==============================] - 222s 528ms/step - loss: 3.4065 - dice_coef: 0.9574 - accuracy: 0.9613 - val_loss: 3.4699 - val_dice_coef: 0.9529 - val_accuracy: 0.9542
#
# Epoch 00005: val_loss improved from 3.50792 to 3.46987, saving model to Checkpoint.h5
# Epoch 6/100
# 420/420 [==============================] - 222s 528ms/step - loss: 3.2770 - dice_coef: 0.9527 - accuracy: 0.9568 - val_loss: 3.2391 - val_dice_coef: 0.9554 - val_accuracy: 0.9580
#
# Epoch 00006: val_loss improved from 3.46987 to 3.23911, saving model to Checkpoint.h5
# Epoch 7/100
# 420/420 [==============================] - 222s 528ms/step - loss: 3.1758 - dice_coef: 0.9526 - accuracy: 0.9567 - val_loss: 3.0640 - val_dice_coef: 0.9528 - val_accuracy: 0.9556
#
# Epoch 00007: val_loss improved from 3.23911 to 3.06403, saving model to Checkpoint.h5
# Epoch 8/100
# 420/420 [==============================] - 222s 528ms/step - loss: 3.1263 - dice_coef: 0.9547 - accuracy: 0.9587 - val_loss: 2.9802 - val_dice_coef: 0.9558 - val_accuracy: 0.9589
#
# Epoch 00008: val_loss improved from 3.06403 to 2.98025, saving model to Checkpoint.h5
# Epoch 9/100
# 420/420 [==============================] - 222s 528ms/step - loss: 3.0080 - dice_coef: 0.9541 - accuracy: 0.9589 - val_loss: 2.8763 - val_dice_coef: 0.9501 - val_accuracy: 0.9556
#
# Epoch 00009: val_loss improved from 2.98025 to 2.87627, saving model to Checkpoint.h5
# Epoch 10/100
# 420/420 [==============================] - 222s 527ms/step - loss: 2.9230 - dice_coef: 0.9511 - accuracy: 0.9539 - val_loss: 2.7992 - val_dice_coef: 0.9493 - val_accuracy: 0.9519
#
# Epoch 00010: val_loss improved from 2.87627 to 2.79920, saving model to Checkpoint.h5
# Epoch 11/100
# 420/420 [==============================] - 222s 527ms/step - loss: 2.8868 - dice_coef: 0.9496 - accuracy: 0.9520 - val_loss: 2.9815 - val_dice_coef: 0.9347 - val_accuracy: 0.9366
#
# Epoch 00011: val_loss did not improve from 2.79920
# Epoch 12/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.8498 - dice_coef: 0.9548 - accuracy: 0.9567 - val_loss: 2.7945 - val_dice_coef: 0.9539 - val_accuracy: 0.9550
#
# Epoch 00012: val_loss improved from 2.79920 to 2.79446, saving model to Checkpoint.h5
# Epoch 13/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.7959 - dice_coef: 0.9546 - accuracy: 0.9562 - val_loss: 2.7861 - val_dice_coef: 0.9480 - val_accuracy: 0.9494
#
# Epoch 00013: val_loss improved from 2.79446 to 2.78610, saving model to Checkpoint.h5
# Epoch 14/100
# 420/420 [==============================] - 222s 529ms/step - loss: 2.7442 - dice_coef: 0.9577 - accuracy: 0.9590 - val_loss: 2.5651 - val_dice_coef: 0.9526 - val_accuracy: 0.9539
#
# Epoch 00014: val_loss improved from 2.78610 to 2.56514, saving model to Checkpoint.h5
# Epoch 15/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.7374 - dice_coef: 0.9568 - accuracy: 0.9581 - val_loss: 2.5511 - val_dice_coef: 0.9552 - val_accuracy: 0.9562
#
# Epoch 00015: val_loss improved from 2.56514 to 2.55108, saving model to Checkpoint.h5
# Epoch 16/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.6902 - dice_coef: 0.9567 - accuracy: 0.9579 - val_loss: 2.6852 - val_dice_coef: 0.9440 - val_accuracy: 0.9448
#
# Epoch 00016: val_loss did not improve from 2.55108
# Epoch 17/100
# 420/420 [==============================] - 222s 529ms/step - loss: 2.6175 - dice_coef: 0.9552 - accuracy: 0.9564 - val_loss: 2.5315 - val_dice_coef: 0.9494 - val_accuracy: 0.9506
#
# Epoch 00017: val_loss improved from 2.55108 to 2.53151, saving model to Checkpoint.h5
# Epoch 18/100
# 420/420 [==============================] - 222s 529ms/step - loss: 2.6145 - dice_coef: 0.9595 - accuracy: 0.9605 - val_loss: 2.8558 - val_dice_coef: 0.9359 - val_accuracy: 0.9369
#
# Epoch 00018: val_loss did not improve from 2.53151
# Epoch 19/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.6510 - dice_coef: 0.9591 - accuracy: 0.9601 - val_loss: 2.8182 - val_dice_coef: 0.8801 - val_accuracy: 0.8824
#
# Epoch 00019: val_loss did not improve from 2.53151
# Epoch 20/100
# 420/420 [==============================] - 222s 527ms/step - loss: 2.5526 - dice_coef: 0.9575 - accuracy: 0.9585 - val_loss: 2.7400 - val_dice_coef: 0.9440 - val_accuracy: 0.9449
#
# Epoch 00020: val_loss did not improve from 2.53151
# Epoch 21/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.5782 - dice_coef: 0.9564 - accuracy: 0.9574 - val_loss: 2.5794 - val_dice_coef: 0.9567 - val_accuracy: 0.9574
#
# Epoch 00021: val_loss did not improve from 2.53151
# Epoch 22/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.5561 - dice_coef: 0.9581 - accuracy: 0.9590 - val_loss: 2.4223 - val_dice_coef: 0.9574 - val_accuracy: 0.9582
#
# Epoch 00022: val_loss improved from 2.53151 to 2.42229, saving model to Checkpoint.h5
# Epoch 23/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.5926 - dice_coef: 0.9595 - accuracy: 0.9603 - val_loss: 2.4730 - val_dice_coef: 0.9470 - val_accuracy: 0.9480
#
# Epoch 00023: val_loss did not improve from 2.42229
# Epoch 24/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.5649 - dice_coef: 0.9576 - accuracy: 0.9584 - val_loss: 2.5132 - val_dice_coef: 0.9508 - val_accuracy: 0.9513
#
# Epoch 00024: val_loss did not improve from 2.42229
# Epoch 25/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.5723 - dice_coef: 0.9612 - accuracy: 0.9619 - val_loss: 2.4944 - val_dice_coef: 0.9566 - val_accuracy: 0.9572
#
# Epoch 00025: val_loss did not improve from 2.42229
# Epoch 26/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5326 - dice_coef: 0.9595 - accuracy: 0.9604 - val_loss: 2.7701 - val_dice_coef: 0.9462 - val_accuracy: 0.9469
#
# Epoch 00026: val_loss did not improve from 2.42229
# Epoch 27/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5537 - dice_coef: 0.9594 - accuracy: 0.9602 - val_loss: 2.4734 - val_dice_coef: 0.9503 - val_accuracy: 0.9510
#
# Epoch 00027: val_loss did not improve from 2.42229
# Epoch 28/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5374 - dice_coef: 0.9611 - accuracy: 0.9618 - val_loss: 2.5186 - val_dice_coef: 0.9496 - val_accuracy: 0.9502
#
# Epoch 00028: val_loss did not improve from 2.42229
# Epoch 29/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5768 - dice_coef: 0.9586 - accuracy: 0.9594 - val_loss: 2.7479 - val_dice_coef: 0.9289 - val_accuracy: 0.9301
#
# Epoch 00029: val_loss did not improve from 2.42229
# Epoch 30/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5225 - dice_coef: 0.9587 - accuracy: 0.9595 - val_loss: 2.4450 - val_dice_coef: 0.9556 - val_accuracy: 0.9562
#
# Epoch 00030: val_loss did not improve from 2.42229
# Epoch 31/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.6187 - dice_coef: 0.9579 - accuracy: 0.9587 - val_loss: 2.4524 - val_dice_coef: 0.9565 - val_accuracy: 0.9574
#
# Epoch 00031: val_loss did not improve from 2.42229
# Epoch 32/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.5042 - dice_coef: 0.9590 - accuracy: 0.9599 - val_loss: 2.4374 - val_dice_coef: 0.9561 - val_accuracy: 0.9568
#
# Epoch 00032: val_loss did not improve from 2.42229
# Epoch 33/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.5401 - dice_coef: 0.9597 - accuracy: 0.9605 - val_loss: 2.4348 - val_dice_coef: 0.9582 - val_accuracy: 0.9587
#
# Epoch 00033: val_loss did not improve from 2.42229
# Epoch 34/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.5075 - dice_coef: 0.9578 - accuracy: 0.9585 - val_loss: 2.5496 - val_dice_coef: 0.9417 - val_accuracy: 0.9426
#
# Epoch 00034: val_loss did not improve from 2.42229
# Epoch 35/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.5302 - dice_coef: 0.9593 - accuracy: 0.9600 - val_loss: 2.4317 - val_dice_coef: 0.9542 - val_accuracy: 0.9548
#
# Epoch 00035: val_loss did not improve from 2.42229
# Epoch 36/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.5263 - dice_coef: 0.9570 - accuracy: 0.9578 - val_loss: 2.4671 - val_dice_coef: 0.9565 - val_accuracy: 0.9571
#
# Epoch 00036: val_loss did not improve from 2.42229
# Epoch 37/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.4931 - dice_coef: 0.9577 - accuracy: 0.9585 - val_loss: 2.3838 - val_dice_coef: 0.9515 - val_accuracy: 0.9522
#
# Epoch 00037: val_loss improved from 2.42229 to 2.38384, saving model to Checkpoint.h5
# Epoch 38/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.5052 - dice_coef: 0.9605 - accuracy: 0.9612 - val_loss: 2.4784 - val_dice_coef: 0.9540 - val_accuracy: 0.9545
#
# Epoch 00038: val_loss did not improve from 2.38384
# Epoch 39/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5185 - dice_coef: 0.9605 - accuracy: 0.9612 - val_loss: 2.5213 - val_dice_coef: 0.9417 - val_accuracy: 0.9427
#
# Epoch 00039: val_loss did not improve from 2.38384
# Epoch 40/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.5395 - dice_coef: 0.9587 - accuracy: 0.9594 - val_loss: 2.3611 - val_dice_coef: 0.9535 - val_accuracy: 0.9540
#
# Epoch 00040: val_loss improved from 2.38384 to 2.36107, saving model to Checkpoint.h5
# Epoch 41/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.5043 - dice_coef: 0.9603 - accuracy: 0.9610 - val_loss: 2.4080 - val_dice_coef: 0.9589 - val_accuracy: 0.9594
#
# Epoch 00041: val_loss did not improve from 2.36107
# Epoch 42/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.5263 - dice_coef: 0.9593 - accuracy: 0.9601 - val_loss: 2.4235 - val_dice_coef: 0.9521 - val_accuracy: 0.9525
#
# Epoch 00042: val_loss did not improve from 2.36107
# Epoch 43/100
# 420/420 [==============================] - 222s 527ms/step - loss: 2.5263 - dice_coef: 0.9602 - accuracy: 0.9608 - val_loss: 2.4797 - val_dice_coef: 0.9577 - val_accuracy: 0.9581
#
# Epoch 00043: val_loss did not improve from 2.36107
# Epoch 44/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.4586 - dice_coef: 0.9616 - accuracy: 0.9623 - val_loss: 2.4532 - val_dice_coef: 0.9572 - val_accuracy: 0.9576
#
# Epoch 00044: val_loss did not improve from 2.36107
# Epoch 45/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.4923 - dice_coef: 0.9625 - accuracy: 0.9631 - val_loss: 2.5204 - val_dice_coef: 0.9591 - val_accuracy: 0.9594
#
# Epoch 00045: val_loss did not improve from 2.36107
# Epoch 46/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4933 - dice_coef: 0.9619 - accuracy: 0.9625 - val_loss: 2.3919 - val_dice_coef: 0.9574 - val_accuracy: 0.9579
#
# Epoch 00046: val_loss did not improve from 2.36107
# Epoch 47/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.5023 - dice_coef: 0.9590 - accuracy: 0.9597 - val_loss: 2.4962 - val_dice_coef: 0.9478 - val_accuracy: 0.9484
#
# Epoch 00047: val_loss did not improve from 2.36107
# Epoch 48/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.4894 - dice_coef: 0.9617 - accuracy: 0.9623 - val_loss: 2.4806 - val_dice_coef: 0.9527 - val_accuracy: 0.9532
#
# Epoch 00048: val_loss did not improve from 2.36107
# Epoch 49/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.4433 - dice_coef: 0.9603 - accuracy: 0.9610 - val_loss: 2.6332 - val_dice_coef: 0.9541 - val_accuracy: 0.9544
#
# Epoch 00049: val_loss did not improve from 2.36107
# Epoch 50/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.4545 - dice_coef: 0.9595 - accuracy: 0.9602 - val_loss: 2.3478 - val_dice_coef: 0.9566 - val_accuracy: 0.9572
#
# Epoch 00050: val_loss improved from 2.36107 to 2.34777, saving model to Checkpoint.h5
# Epoch 51/100
# 420/420 [==============================] - 222s 527ms/step - loss: 2.4879 - dice_coef: 0.9585 - accuracy: 0.9592 - val_loss: 2.4598 - val_dice_coef: 0.9584 - val_accuracy: 0.9588
#
# Epoch 00051: val_loss did not improve from 2.34777
# Epoch 52/100
# 420/420 [==============================] - 222s 527ms/step - loss: 2.5013 - dice_coef: 0.9633 - accuracy: 0.9638 - val_loss: 2.4027 - val_dice_coef: 0.9581 - val_accuracy: 0.9585
#
# Epoch 00052: val_loss did not improve from 2.34777
# Epoch 53/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4806 - dice_coef: 0.9582 - accuracy: 0.9588 - val_loss: 2.5096 - val_dice_coef: 0.9509 - val_accuracy: 0.9515
#
# Epoch 00053: val_loss did not improve from 2.34777
# Epoch 54/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5164 - dice_coef: 0.9609 - accuracy: 0.9615 - val_loss: 2.4682 - val_dice_coef: 0.9518 - val_accuracy: 0.9524
#
# Epoch 00054: val_loss did not improve from 2.34777
# Epoch 55/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5469 - dice_coef: 0.9619 - accuracy: 0.9626 - val_loss: 2.3957 - val_dice_coef: 0.9569 - val_accuracy: 0.9575
#
# Epoch 00055: val_loss did not improve from 2.34777
# Epoch 56/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4347 - dice_coef: 0.9598 - accuracy: 0.9604 - val_loss: 2.3160 - val_dice_coef: 0.9584 - val_accuracy: 0.9588
#
# Epoch 00056: val_loss improved from 2.34777 to 2.31598, saving model to Checkpoint.h5
# Epoch 57/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5106 - dice_coef: 0.9597 - accuracy: 0.9603 - val_loss: 2.4931 - val_dice_coef: 0.9460 - val_accuracy: 0.9467
#
# Epoch 00057: val_loss did not improve from 2.31598
# Epoch 58/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5513 - dice_coef: 0.9598 - accuracy: 0.9605 - val_loss: 2.4747 - val_dice_coef: 0.9542 - val_accuracy: 0.9545
#
# Epoch 00058: val_loss did not improve from 2.31598
# Epoch 59/100
# 420/420 [==============================] - 222s 527ms/step - loss: 2.5350 - dice_coef: 0.9626 - accuracy: 0.9631 - val_loss: 2.5468 - val_dice_coef: 0.9467 - val_accuracy: 0.9470
#
# Epoch 00059: val_loss did not improve from 2.31598
# Epoch 60/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4496 - dice_coef: 0.9610 - accuracy: 0.9617 - val_loss: 2.3715 - val_dice_coef: 0.9604 - val_accuracy: 0.9608
#
# Epoch 00060: val_loss did not improve from 2.31598
# Epoch 61/100
# 420/420 [==============================] - 222s 529ms/step - loss: 2.4466 - dice_coef: 0.9600 - accuracy: 0.9607 - val_loss: 2.4744 - val_dice_coef: 0.9583 - val_accuracy: 0.9587
#
# Epoch 00061: val_loss did not improve from 2.31598
# Epoch 62/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4592 - dice_coef: 0.9599 - accuracy: 0.9606 - val_loss: 2.4493 - val_dice_coef: 0.9560 - val_accuracy: 0.9565
#
# Epoch 00062: val_loss did not improve from 2.31598
# Epoch 63/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4242 - dice_coef: 0.9601 - accuracy: 0.9607 - val_loss: 2.4740 - val_dice_coef: 0.9567 - val_accuracy: 0.9571
#
# Epoch 00063: val_loss did not improve from 2.31598
# Epoch 64/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4700 - dice_coef: 0.9591 - accuracy: 0.9598 - val_loss: 2.4308 - val_dice_coef: 0.9563 - val_accuracy: 0.9568
#
# Epoch 00064: val_loss did not improve from 2.31598
# Epoch 65/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4414 - dice_coef: 0.9601 - accuracy: 0.9608 - val_loss: 2.4129 - val_dice_coef: 0.9545 - val_accuracy: 0.9549
#
# Epoch 00065: val_loss did not improve from 2.31598
# Epoch 66/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4939 - dice_coef: 0.9610 - accuracy: 0.9617 - val_loss: 2.3597 - val_dice_coef: 0.9562 - val_accuracy: 0.9566
#
# Epoch 00066: val_loss did not improve from 2.31598
# Epoch 67/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4825 - dice_coef: 0.9609 - accuracy: 0.9616 - val_loss: 2.4726 - val_dice_coef: 0.9493 - val_accuracy: 0.9501
#
# Epoch 00067: val_loss did not improve from 2.31598
# Epoch 68/100
# 420/420 [==============================] - 222s 529ms/step - loss: 2.5416 - dice_coef: 0.9606 - accuracy: 0.9612 - val_loss: 2.3685 - val_dice_coef: 0.9535 - val_accuracy: 0.9542
#
# Epoch 00068: val_loss did not improve from 2.31598
# Epoch 69/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4953 - dice_coef: 0.9593 - accuracy: 0.9599 - val_loss: 2.6755 - val_dice_coef: 0.9588 - val_accuracy: 0.9591
#
# Epoch 00069: val_loss did not improve from 2.31598
# Epoch 70/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5410 - dice_coef: 0.9588 - accuracy: 0.9595 - val_loss: 2.4146 - val_dice_coef: 0.9557 - val_accuracy: 0.9563
#
# Epoch 00070: val_loss did not improve from 2.31598
# Epoch 71/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4747 - dice_coef: 0.9614 - accuracy: 0.9620 - val_loss: 2.4765 - val_dice_coef: 0.9592 - val_accuracy: 0.9596
#
# Epoch 00071: val_loss did not improve from 2.31598
# Epoch 72/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4873 - dice_coef: 0.9603 - accuracy: 0.9610 - val_loss: 2.3556 - val_dice_coef: 0.9598 - val_accuracy: 0.9602
#
# Epoch 00072: val_loss did not improve from 2.31598
# Epoch 73/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4406 - dice_coef: 0.9621 - accuracy: 0.9627 - val_loss: 2.3936 - val_dice_coef: 0.9589 - val_accuracy: 0.9593
#
# Epoch 00073: val_loss did not improve from 2.31598
# Epoch 74/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5223 - dice_coef: 0.9609 - accuracy: 0.9615 - val_loss: 2.6712 - val_dice_coef: 0.9016 - val_accuracy: 0.9036
#
# Epoch 00074: val_loss did not improve from 2.31598
# Epoch 75/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4785 - dice_coef: 0.9630 - accuracy: 0.9636 - val_loss: 2.3787 - val_dice_coef: 0.9555 - val_accuracy: 0.9560
#
# Epoch 00075: val_loss did not improve from 2.31598
# Epoch 76/100
# 420/420 [==============================] - 222s 527ms/step - loss: 2.4937 - dice_coef: 0.9611 - accuracy: 0.9617 - val_loss: 2.4956 - val_dice_coef: 0.9446 - val_accuracy: 0.9453
#
# Epoch 00076: val_loss did not improve from 2.31598
# Epoch 77/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.4306 - dice_coef: 0.9639 - accuracy: 0.9645 - val_loss: 2.7336 - val_dice_coef: 0.9490 - val_accuracy: 0.9499
#
# Epoch 00077: val_loss did not improve from 2.31598
# Epoch 78/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.4560 - dice_coef: 0.9615 - accuracy: 0.9621 - val_loss: 2.3775 - val_dice_coef: 0.9535 - val_accuracy: 0.9543
#
# Epoch 00078: val_loss did not improve from 2.31598
# Epoch 79/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.5289 - dice_coef: 0.9623 - accuracy: 0.9629 - val_loss: 2.3949 - val_dice_coef: 0.9595 - val_accuracy: 0.9600
#
# Epoch 00079: val_loss did not improve from 2.31598
# Epoch 80/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.4507 - dice_coef: 0.9604 - accuracy: 0.9611 - val_loss: 2.4794 - val_dice_coef: 0.9566 - val_accuracy: 0.9571
#
# Epoch 00080: val_loss did not improve from 2.31598
# Epoch 81/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.5208 - dice_coef: 0.9590 - accuracy: 0.9597 - val_loss: 2.4581 - val_dice_coef: 0.9553 - val_accuracy: 0.9557
#
# Epoch 00081: val_loss did not improve from 2.31598
# Epoch 82/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.4901 - dice_coef: 0.9598 - accuracy: 0.9604 - val_loss: 2.4009 - val_dice_coef: 0.9550 - val_accuracy: 0.9555
#
# Epoch 00082: val_loss did not improve from 2.31598
# Epoch 83/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.5101 - dice_coef: 0.9622 - accuracy: 0.9628 - val_loss: 2.5172 - val_dice_coef: 0.9482 - val_accuracy: 0.9487
#
# Epoch 00083: val_loss did not improve from 2.31598
# Epoch 84/100
# 420/420 [==============================] - 221s 527ms/step - loss: 2.4362 - dice_coef: 0.9614 - accuracy: 0.9620 - val_loss: 2.3327 - val_dice_coef: 0.9557 - val_accuracy: 0.9564
#
# Epoch 00084: val_loss did not improve from 2.31598
# Epoch 85/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4936 - dice_coef: 0.9638 - accuracy: 0.9643 - val_loss: 2.4465 - val_dice_coef: 0.9584 - val_accuracy: 0.9587
#
# Epoch 00085: val_loss did not improve from 2.31598
# Epoch 86/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5439 - dice_coef: 0.9619 - accuracy: 0.9624 - val_loss: 2.3631 - val_dice_coef: 0.9580 - val_accuracy: 0.9585
#
# Epoch 00086: val_loss did not improve from 2.31598
# Epoch 87/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4829 - dice_coef: 0.9592 - accuracy: 0.9598 - val_loss: 2.5319 - val_dice_coef: 0.9541 - val_accuracy: 0.9544
#
# Epoch 00087: val_loss did not improve from 2.31598
# Epoch 88/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4373 - dice_coef: 0.9616 - accuracy: 0.9621 - val_loss: 2.8081 - val_dice_coef: 0.9373 - val_accuracy: 0.9376
#
# Epoch 00088: val_loss did not improve from 2.31598
# Epoch 89/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5006 - dice_coef: 0.9619 - accuracy: 0.9625 - val_loss: 2.3864 - val_dice_coef: 0.9599 - val_accuracy: 0.9606
#
# Epoch 00089: val_loss did not improve from 2.31598
# Epoch 90/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4458 - dice_coef: 0.9602 - accuracy: 0.9608 - val_loss: 2.4676 - val_dice_coef: 0.9603 - val_accuracy: 0.9607
#
# Epoch 00090: val_loss did not improve from 2.31598
# Epoch 91/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5145 - dice_coef: 0.9584 - accuracy: 0.9590 - val_loss: 2.3230 - val_dice_coef: 0.9577 - val_accuracy: 0.9585
#
# Epoch 00091: val_loss did not improve from 2.31598
# Epoch 92/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4485 - dice_coef: 0.9602 - accuracy: 0.9609 - val_loss: 2.3962 - val_dice_coef: 0.9542 - val_accuracy: 0.9547
#
# Epoch 00092: val_loss did not improve from 2.31598
# Epoch 93/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4712 - dice_coef: 0.9605 - accuracy: 0.9612 - val_loss: 2.5105 - val_dice_coef: 0.9539 - val_accuracy: 0.9544
#
# Epoch 00093: val_loss did not improve from 2.31598
# Epoch 94/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5778 - dice_coef: 0.9591 - accuracy: 0.9598 - val_loss: 2.5330 - val_dice_coef: 0.9597 - val_accuracy: 0.9602
#
# Epoch 00094: val_loss did not improve from 2.31598
# Epoch 95/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5165 - dice_coef: 0.9607 - accuracy: 0.9614 - val_loss: 2.4175 - val_dice_coef: 0.9594 - val_accuracy: 0.9598
#
# Epoch 00095: val_loss did not improve from 2.31598
# Epoch 96/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4499 - dice_coef: 0.9631 - accuracy: 0.9637 - val_loss: 2.5089 - val_dice_coef: 0.9546 - val_accuracy: 0.9550
#
# Epoch 00096: val_loss did not improve from 2.31598
# Epoch 97/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5080 - dice_coef: 0.9616 - accuracy: 0.9622 - val_loss: 2.4014 - val_dice_coef: 0.9565 - val_accuracy: 0.9569
#
# Epoch 00097: val_loss did not improve from 2.31598
# Epoch 98/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.4528 - dice_coef: 0.9623 - accuracy: 0.9629 - val_loss: 2.3608 - val_dice_coef: 0.9575 - val_accuracy: 0.9579
#
# Epoch 00098: val_loss did not improve from 2.31598
# Epoch 99/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5117 - dice_coef: 0.9612 - accuracy: 0.9618 - val_loss: 2.3701 - val_dice_coef: 0.9578 - val_accuracy: 0.9582
#
# Epoch 00099: val_loss did not improve from 2.31598
# Epoch 100/100
# 420/420 [==============================] - 222s 528ms/step - loss: 2.5409 - dice_coef: 0.9621 - accuracy: 0.9628 - val_loss: 2.3542 - val_dice_coef: 0.9597 - val_accuracy: 0.9602
#
# Epoch 00100: val_loss did not improve from 2.31598

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask, Patient_array,Patient_length,title,folder):
  idx = 0
  for i in range(len(Patient_length)):
    temp = []
    for j in range(Patient_length[i]):
      final_output = mask[idx:idx+48]
      idx = idx + 48
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save(folder + title + Patient_array[i], final_output)

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER/UNET++/"
model_names = os.listdir(MODELS_PATH)
print(model_names)
# Out:
# ['UNET++_ER_0.h5']

# %%
SAVE_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/ER/UNET++/"

# %%
# Axis 0 = Folds
# Axis 1 = Class (Strong Intermediate,Weak,Background)
# Axis 2 = Evaluation Technique (Precision, Recall, Dice coefficient)
pixEvaluationTrain = np.empty((0,4,3))
pixEvaluationTest = np.empty((0,4,3))
score = np.zeros((1,4,3))

# %%
fold = 0

for train_index, test_index in fold_split:
  print("FOLD:",fold,"\tTRAIN:", train_index, "TEST:", test_index)
  # Splitting Train and Test data
  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  train_no = [patient_no[i] for i in train_index]
  train_size = [size[i] for i in train_index]

  test_no = [patient_no[i] for i in test_index]
  test_size = [size[i] for i in test_index]

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255

  convertToLabels(TrainY)
  convertToLabels(TestY)

  # Loading corrosponding fold of model
  model = keras.models.load_model(MODELS_PATH + model_names[fold],custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

  # Predicting results using model
  trainResult = model.predict(TrainX, batch_size=8)
  testResult = model.predict(TestX,batch_size=8)

  trainResult = np.argmax(trainResult,axis=-1)
  testResult = np.argmax(testResult,axis=-1)

  # Obtaining pixel-wise results: Precision recall and dice coefficient
  # For TRAIN
  y_true = np.reshape(TrainY,(-1))
  y_pred = np.reshape(trainResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(4):
    score[0][i][0] = prec[3-i]
    score[0][i][1] = recall[3-i]
    score[0][i][2] = dice[3-i]

  pixEvaluationTrain = np.append(pixEvaluationTrain,score,axis=0)
 
  # For TEST
  y_true = np.reshape(TestY,(-1))
  y_pred = np.reshape(testResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(4):
    score[0][i][0] = prec[3-i]
    score[0][i][1] = recall[3-i]
    score[0][i][2] = dice[3-i]

  pixEvaluationTest = np.append(pixEvaluationTest,score,axis=0)

  # Converting predicted labels to required output format
  convertFromLabels(trainResult)
  convertFromLabels(testResult)

  # Saving numpy arrays
  path = os.path.join(SAVE_PATH,"Fold " + str(fold))
  os.mkdir(path)
  os.mkdir(path + '/Train')
  os.mkdir(path + '/Test')

  saveNumpyOutput(trainResult, train_no, train_size,"/Train/",path)
  saveNumpyOutput(testResult, test_no, test_size,"/Test/",path)

  fold +=1
# Out:
# FOLD: 0 	TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1]

# %%
print(pixEvaluationTrain.shape)
print(pixEvaluationTest.shape)
print(pixEvaluationTest)
# Out:
# (1, 4, 3)
# (1, 4, 3)
# [[[0.80979871 0.33734091 0.47627722]
#   [0.40263024 0.50130971 0.44658375]
#   [0.35263255 0.18278711 0.2407707 ]
#   [0.96079627 0.99069864 0.97551836]]]

# %%
np.save(SAVE_PATH + "Pixel-wise Metrics Train.npy", pixEvaluationTrain)
np.save(SAVE_PATH + "Pixel-wise Metrics Test.npy", pixEvaluationTest)

# %% [markdown]
# # **DISPLAY**

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 48   # enter between 0- 50 since there are 5 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]
Mask_input = TestGT[id:id+48]
final_output = testResult[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 25  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]
Mask_input = TrainGT[id:id+48]
final_output = trainResult[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
