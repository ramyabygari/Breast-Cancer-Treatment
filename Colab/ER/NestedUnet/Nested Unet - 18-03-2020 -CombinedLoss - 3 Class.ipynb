# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from keras.layers import Activation,Conv2D,MaxPooling2D,UpSampling2D,Dense,BatchNormalization,Input,Reshape,multiply,add,Dropout,AveragePooling2D,GlobalAveragePooling2D,concatenate
from keras.layers.convolutional import Conv2DTranspose
from keras.models import Model														  
import keras.backend as K
from keras.regularizers import l2
from keras.engine import Layer,InputSpec
from keras.utils import conv_utils
from keras.layers import Activation,Conv2D,MaxPooling2D,UpSampling2D,Dense,BatchNormalization,Input,Reshape,multiply,add,Dropout,AveragePooling2D,GlobalAveragePooling2D,concatenate
from keras.layers.convolutional import Conv2DTranspose
from keras.models import Model														  
import keras.backend as K
from keras.regularizers import l2
from keras.engine import Layer,InputSpec
from keras.utils import conv_utils
# !pip install medpy
from keras.layers import *
from keras.models import Sequential
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from medpy.metric import dc, precision, recall
import keras
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Requirement already satisfied: medpy in /usr/local/lib/python3.6/dist-packages (0.4.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.4.1)
# Requirement already satisfied: SimpleITK>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.2.4)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.18.1)

# %%
smooth = 1.
dropout_rate = 0.5
def standard_unit(input_tensor, stage, nb_filter, kernel_size=3):

    act = 'elu'

    x = Conv2D(nb_filter, (kernel_size, kernel_size), activation=act, name='conv'+stage+'_1', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(input_tensor)
    x = Dropout(dropout_rate, name='dp'+stage+'_1')(x)
    x = Conv2D(nb_filter, (kernel_size, kernel_size), activation=act, name='conv'+stage+'_2', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(x)
    x = Dropout(dropout_rate, name='dp'+stage+'_2')(x)

    return x

# %%
def Nest_Net(img_rows, img_cols, color_type=3, num_class=3, deep_supervision=False):

    nb_filter = [8,16,32,64,128]
    act = 'elu'
  
    bn_axis = 3
    
    
    img_input = Input(shape=(img_rows, img_cols, color_type), name='main_input')
    conv1_1 = standard_unit(img_input, stage='11', nb_filter=nb_filter[0])
    pool1 = MaxPooling2D((2, 2), strides=(2, 2), name='pool1')(conv1_1)

    conv2_1 = standard_unit(pool1, stage='21', nb_filter=nb_filter[1])
    pool2 = MaxPooling2D((2, 2), strides=(2, 2), name='pool2')(conv2_1)

    up1_2 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up12', padding='same')(conv2_1)
    conv1_2 = concatenate([up1_2, conv1_1], name='merge12', axis=bn_axis)
    conv1_2 = standard_unit(conv1_2, stage='12', nb_filter=nb_filter[0])

    conv3_1 = standard_unit(pool2, stage='31', nb_filter=nb_filter[2])
    pool3 = MaxPooling2D((2, 2), strides=(2, 2), name='pool3')(conv3_1)

    up2_2 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up22', padding='same')(conv3_1)
    conv2_2 = concatenate([up2_2, conv2_1], name='merge22', axis=bn_axis)
    conv2_2 = standard_unit(conv2_2, stage='22', nb_filter=nb_filter[1])

    up1_3 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up13', padding='same')(conv2_2)
    conv1_3 = concatenate([up1_3, conv1_1, conv1_2], name='merge13', axis=bn_axis)
    conv1_3 = standard_unit(conv1_3, stage='13', nb_filter=nb_filter[0])

    conv4_1 = standard_unit(pool3, stage='41', nb_filter=nb_filter[3])
    pool4 = MaxPooling2D((2, 2), strides=(2, 2), name='pool4')(conv4_1)

    up3_2 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up32', padding='same')(conv4_1)
    conv3_2 = concatenate([up3_2, conv3_1], name='merge32', axis=bn_axis)
    conv3_2 = standard_unit(conv3_2, stage='32', nb_filter=nb_filter[2])

    up2_3 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up23', padding='same')(conv3_2)
    conv2_3 = concatenate([up2_3, conv2_1, conv2_2], name='merge23', axis=bn_axis)
    conv2_3 = standard_unit(conv2_3, stage='23', nb_filter=nb_filter[1])

    up1_4 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up14', padding='same')(conv2_3)
    conv1_4 = concatenate([up1_4, conv1_1, conv1_2, conv1_3], name='merge14', axis=bn_axis)
    conv1_4 = standard_unit(conv1_4, stage='14', nb_filter=nb_filter[0])

    conv5_1 = standard_unit(pool4, stage='51', nb_filter=nb_filter[4])

    up4_2 = Conv2DTranspose(nb_filter[3], (2, 2), strides=(2, 2), name='up42', padding='same')(conv5_1)
    conv4_2 = concatenate([up4_2, conv4_1], name='merge42', axis=bn_axis)
    conv4_2 = standard_unit(conv4_2, stage='42', nb_filter=nb_filter[3])

    up3_3 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up33', padding='same')(conv4_2)
    conv3_3 = concatenate([up3_3, conv3_1, conv3_2], name='merge33', axis=bn_axis)
    conv3_3 = standard_unit(conv3_3, stage='33', nb_filter=nb_filter[2])

    up2_4 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up24', padding='same')(conv3_3)
    conv2_4 = concatenate([up2_4, conv2_1, conv2_2, conv2_3], name='merge24', axis=bn_axis)
    conv2_4 = standard_unit(conv2_4, stage='24', nb_filter=nb_filter[1])

    up1_5 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up15', padding='same')(conv2_4)
    conv1_5 = concatenate([up1_5, conv1_1, conv1_2, conv1_3, conv1_4], name='merge15', axis=bn_axis)
    conv1_5 = standard_unit(conv1_5, stage='15', nb_filter=nb_filter[0])

    nestnet_output_1 = Conv2D(num_class, (1, 1), activation='softmax', name='output_1', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_2)
    nestnet_output_2 = Conv2D(num_class, (1, 1), activation='softmax', name='output_2', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_3)
    nestnet_output_3 = Conv2D(num_class, (1, 1), activation='softmax', name='output_3', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_4)
    nestnet_output_4 = Conv2D(num_class, (1, 1), activation='softmax', name='output_4', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_5)

    if deep_supervision:
        model = Model(input=img_input, output=[nestnet_output_1,
                                               nestnet_output_2,
                                               nestnet_output_3,
                                               nestnet_output_4])
    else:
        model = Model(input=img_input, output=[nestnet_output_4])

    return model

# %%
model = Nest_Net(240,240,3)
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 240, 240, 3)  0
# __________________________________________________________________________________________________
# conv11_1 (Conv2D)               (None, 240, 240, 8)  224         main_input[0][0]
# __________________________________________________________________________________________________
# dp11_1 (Dropout)                (None, 240, 240, 8)  0           conv11_1[0][0]
# __________________________________________________________________________________________________
# conv11_2 (Conv2D)               (None, 240, 240, 8)  584         dp11_1[0][0]
# __________________________________________________________________________________________________
# dp11_2 (Dropout)                (None, 240, 240, 8)  0           conv11_2[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 120, 120, 8)  0           dp11_2[0][0]
# __________________________________________________________________________________________________
# conv21_1 (Conv2D)               (None, 120, 120, 16) 1168        pool1[0][0]
# __________________________________________________________________________________________________
# dp21_1 (Dropout)                (None, 120, 120, 16) 0           conv21_1[0][0]
# __________________________________________________________________________________________________
# conv21_2 (Conv2D)               (None, 120, 120, 16) 2320        dp21_1[0][0]
# __________________________________________________________________________________________________
# dp21_2 (Dropout)                (None, 120, 120, 16) 0           conv21_2[0][0]
# __________________________________________________________________________________________________
# pool2 (MaxPooling2D)            (None, 60, 60, 16)   0           dp21_2[0][0]
# __________________________________________________________________________________________________
# conv31_1 (Conv2D)               (None, 60, 60, 32)   4640        pool2[0][0]
# __________________________________________________________________________________________________
# dp31_1 (Dropout)                (None, 60, 60, 32)   0           conv31_1[0][0]
# __________________________________________________________________________________________________
# conv31_2 (Conv2D)               (None, 60, 60, 32)   9248        dp31_1[0][0]
# __________________________________________________________________________________________________
# dp31_2 (Dropout)                (None, 60, 60, 32)   0           conv31_2[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 30, 30, 32)   0           dp31_2[0][0]
# __________________________________________________________________________________________________
# conv41_1 (Conv2D)               (None, 30, 30, 64)   18496       pool3[0][0]
# __________________________________________________________________________________________________
# dp41_1 (Dropout)                (None, 30, 30, 64)   0           conv41_1[0][0]
# __________________________________________________________________________________________________
# conv41_2 (Conv2D)               (None, 30, 30, 64)   36928       dp41_1[0][0]
# __________________________________________________________________________________________________
# dp41_2 (Dropout)                (None, 30, 30, 64)   0           conv41_2[0][0]
# __________________________________________________________________________________________________
# pool4 (MaxPooling2D)            (None, 15, 15, 64)   0           dp41_2[0][0]
# __________________________________________________________________________________________________
# conv51_1 (Conv2D)               (None, 15, 15, 128)  73856       pool4[0][0]
# __________________________________________________________________________________________________
# dp51_1 (Dropout)                (None, 15, 15, 128)  0           conv51_1[0][0]
# __________________________________________________________________________________________________
# conv51_2 (Conv2D)               (None, 15, 15, 128)  147584      dp51_1[0][0]
# __________________________________________________________________________________________________
# dp51_2 (Dropout)                (None, 15, 15, 128)  0           conv51_2[0][0]
# __________________________________________________________________________________________________
# up42 (Conv2DTranspose)          (None, 30, 30, 64)   32832       dp51_2[0][0]
# __________________________________________________________________________________________________
# merge42 (Concatenate)           (None, 30, 30, 128)  0           up42[0][0]
#                                                                  dp41_2[0][0]
# __________________________________________________________________________________________________
# up32 (Conv2DTranspose)          (None, 60, 60, 32)   8224        dp41_2[0][0]
# __________________________________________________________________________________________________
# conv42_1 (Conv2D)               (None, 30, 30, 64)   73792       merge42[0][0]
# __________________________________________________________________________________________________
# merge32 (Concatenate)           (None, 60, 60, 64)   0           up32[0][0]
#                                                                  dp31_2[0][0]
# __________________________________________________________________________________________________
# up22 (Conv2DTranspose)          (None, 120, 120, 16) 2064        dp31_2[0][0]
# __________________________________________________________________________________________________
# dp42_1 (Dropout)                (None, 30, 30, 64)   0           conv42_1[0][0]
# __________________________________________________________________________________________________
# conv32_1 (Conv2D)               (None, 60, 60, 32)   18464       merge32[0][0]
# __________________________________________________________________________________________________
# merge22 (Concatenate)           (None, 120, 120, 32) 0           up22[0][0]
#                                                                  dp21_2[0][0]
# __________________________________________________________________________________________________
# up12 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp21_2[0][0]
# __________________________________________________________________________________________________
# conv42_2 (Conv2D)               (None, 30, 30, 64)   36928       dp42_1[0][0]
# __________________________________________________________________________________________________
# dp32_1 (Dropout)                (None, 60, 60, 32)   0           conv32_1[0][0]
# __________________________________________________________________________________________________
# conv22_1 (Conv2D)               (None, 120, 120, 16) 4624        merge22[0][0]
# __________________________________________________________________________________________________
# merge12 (Concatenate)           (None, 240, 240, 16) 0           up12[0][0]
#                                                                  dp11_2[0][0]
# __________________________________________________________________________________________________
# dp42_2 (Dropout)                (None, 30, 30, 64)   0           conv42_2[0][0]
# __________________________________________________________________________________________________
# conv32_2 (Conv2D)               (None, 60, 60, 32)   9248        dp32_1[0][0]
# __________________________________________________________________________________________________
# dp22_1 (Dropout)                (None, 120, 120, 16) 0           conv22_1[0][0]
# __________________________________________________________________________________________________
# conv12_1 (Conv2D)               (None, 240, 240, 8)  1160        merge12[0][0]
# __________________________________________________________________________________________________
# up33 (Conv2DTranspose)          (None, 60, 60, 32)   8224        dp42_2[0][0]
# __________________________________________________________________________________________________
# dp32_2 (Dropout)                (None, 60, 60, 32)   0           conv32_2[0][0]
# __________________________________________________________________________________________________
# conv22_2 (Conv2D)               (None, 120, 120, 16) 2320        dp22_1[0][0]
# __________________________________________________________________________________________________
# dp12_1 (Dropout)                (None, 240, 240, 8)  0           conv12_1[0][0]
# __________________________________________________________________________________________________
# merge33 (Concatenate)           (None, 60, 60, 96)   0           up33[0][0]
#                                                                  dp31_2[0][0]
#                                                                  dp32_2[0][0]
# __________________________________________________________________________________________________
# dp22_2 (Dropout)                (None, 120, 120, 16) 0           conv22_2[0][0]
# __________________________________________________________________________________________________
# up23 (Conv2DTranspose)          (None, 120, 120, 16) 2064        dp32_2[0][0]
# __________________________________________________________________________________________________
# conv12_2 (Conv2D)               (None, 240, 240, 8)  584         dp12_1[0][0]
# __________________________________________________________________________________________________
# conv33_1 (Conv2D)               (None, 60, 60, 32)   27680       merge33[0][0]
# __________________________________________________________________________________________________
# merge23 (Concatenate)           (None, 120, 120, 48) 0           up23[0][0]
#                                                                  dp21_2[0][0]
#                                                                  dp22_2[0][0]
# __________________________________________________________________________________________________
# dp12_2 (Dropout)                (None, 240, 240, 8)  0           conv12_2[0][0]
# __________________________________________________________________________________________________
# up13 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp22_2[0][0]
# __________________________________________________________________________________________________
# dp33_1 (Dropout)                (None, 60, 60, 32)   0           conv33_1[0][0]
# __________________________________________________________________________________________________
# conv23_1 (Conv2D)               (None, 120, 120, 16) 6928        merge23[0][0]
# __________________________________________________________________________________________________
# merge13 (Concatenate)           (None, 240, 240, 24) 0           up13[0][0]
#                                                                  dp11_2[0][0]
#                                                                  dp12_2[0][0]
# __________________________________________________________________________________________________
# conv33_2 (Conv2D)               (None, 60, 60, 32)   9248        dp33_1[0][0]
# __________________________________________________________________________________________________
# dp23_1 (Dropout)                (None, 120, 120, 16) 0           conv23_1[0][0]
# __________________________________________________________________________________________________
# conv13_1 (Conv2D)               (None, 240, 240, 8)  1736        merge13[0][0]
# __________________________________________________________________________________________________
# dp33_2 (Dropout)                (None, 60, 60, 32)   0           conv33_2[0][0]
# __________________________________________________________________________________________________
# conv23_2 (Conv2D)               (None, 120, 120, 16) 2320        dp23_1[0][0]
# __________________________________________________________________________________________________
# dp13_1 (Dropout)                (None, 240, 240, 8)  0           conv13_1[0][0]
# __________________________________________________________________________________________________
# up24 (Conv2DTranspose)          (None, 120, 120, 16) 2064        dp33_2[0][0]
# __________________________________________________________________________________________________
# dp23_2 (Dropout)                (None, 120, 120, 16) 0           conv23_2[0][0]
# __________________________________________________________________________________________________
# conv13_2 (Conv2D)               (None, 240, 240, 8)  584         dp13_1[0][0]
# __________________________________________________________________________________________________
# merge24 (Concatenate)           (None, 120, 120, 64) 0           up24[0][0]
#                                                                  dp21_2[0][0]
#                                                                  dp22_2[0][0]
#                                                                  dp23_2[0][0]
# __________________________________________________________________________________________________
# dp13_2 (Dropout)                (None, 240, 240, 8)  0           conv13_2[0][0]
# __________________________________________________________________________________________________
# up14 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp23_2[0][0]
# __________________________________________________________________________________________________
# conv24_1 (Conv2D)               (None, 120, 120, 16) 9232        merge24[0][0]
# __________________________________________________________________________________________________
# merge14 (Concatenate)           (None, 240, 240, 32) 0           up14[0][0]
#                                                                  dp11_2[0][0]
#                                                                  dp12_2[0][0]
#                                                                  dp13_2[0][0]
# __________________________________________________________________________________________________
# dp24_1 (Dropout)                (None, 120, 120, 16) 0           conv24_1[0][0]
# __________________________________________________________________________________________________
# conv14_1 (Conv2D)               (None, 240, 240, 8)  2312        merge14[0][0]
# __________________________________________________________________________________________________
# conv24_2 (Conv2D)               (None, 120, 120, 16) 2320        dp24_1[0][0]
# __________________________________________________________________________________________________
# dp14_1 (Dropout)                (None, 240, 240, 8)  0           conv14_1[0][0]
# __________________________________________________________________________________________________
# dp24_2 (Dropout)                (None, 120, 120, 16) 0           conv24_2[0][0]
# __________________________________________________________________________________________________
# conv14_2 (Conv2D)               (None, 240, 240, 8)  584         dp14_1[0][0]
# __________________________________________________________________________________________________
# up15 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp24_2[0][0]
# __________________________________________________________________________________________________
# dp14_2 (Dropout)                (None, 240, 240, 8)  0           conv14_2[0][0]
# __________________________________________________________________________________________________
# merge15 (Concatenate)           (None, 240, 240, 40) 0           up15[0][0]
#                                                                  dp11_2[0][0]
#                                                                  dp12_2[0][0]
#                                                                  dp13_2[0][0]
#                                                                  dp14_2[0][0]
# __________________________________________________________________________________________________
# conv15_1 (Conv2D)               (None, 240, 240, 8)  2888        merge15[0][0]
# __________________________________________________________________________________________________
# dp15_1 (Dropout)                (None, 240, 240, 8)  0           conv15_1[0][0]
# __________________________________________________________________________________________________
# conv15_2 (Conv2D)               (None, 240, 240, 8)  584         dp15_1[0][0]
# __________________________________________________________________________________________________
# dp15_2 (Dropout)                (None, 240, 240, 8)  0           conv15_2[0][0]
# __________________________________________________________________________________________________
# output_4 (Conv2D)               (None, 240, 240, 3)  27          dp15_2[0][0]
# ==================================================================================================
# Total params: 566,163
# Trainable params: 566,163
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:75: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("ma..., outputs=[<tf.Tenso...)`

# %%
import os
import cv2
import numpy as np

# %%
# Function to convert image from greyscale to one hot (i.e. 3 channels)
def convertToOneHot(image):
    num_classes = 3
    shape = image.shape[:2]+(num_classes,)
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c]==0:
          encoded_image[r][c][0] = 1
        elif image[r][c]==128:
          encoded_image[r][c][1] = 1
        else:
          encoded_image[r][c][2] = 1
    return encoded_image

# %%
# Function to convert back from one hot image to greyscale
def convertFromOneHot(image):
    shape = image.shape[:2]
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c][0] == 1:
          encoded_image[r][c] = 0
        elif image[r][c][1] == 1:
          encoded_image[r][c] = 128
        else:
          encoded_image[r][c] = 255
    return encoded_image

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/3 Class"

# Train set patients: 230 263 239 242 
TrainX_1 = np.load(PATH + '/ER IHC 239 Images.npy')
TrainY_1 = np.load(PATH + '/ER IHC 239 Masks.npy')
TrainX_2 = np.load(PATH + '/ER IHC 232 Images.npy')
TrainY_2 = np.load(PATH + '/ER IHC 232 Masks.npy')
TrainX_3 = np.load(PATH + '/ER IHC 242 Images.npy')
TrainY_3 = np.load(PATH + '/ER IHC 242 Masks.npy')
TrainX_4 = np.load(PATH + '/ER IHC 230 Images.npy')
TrainY_4 = np.load(PATH + '/ER IHC 230 Masks.npy')

# Test set patients: 221 246 232
TestX_1 = np.load(PATH + '/ER IHC 221 Images.npy')
TestY_1 = np.load(PATH + '/ER IHC 221 Masks.npy')
TestX_2 = np.load(PATH + '/ER IHC 246 Images.npy')
TestY_2 = np.load(PATH + '/ER IHC 246 Masks.npy')
TestX_3 = np.load(PATH + '/ER IHC 263 Images.npy')
TestY_3 = np.load(PATH + '/ER IHC 263 Masks.npy')

# %%
np.unique(TestY_3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-53d0366974ee> in <module>()
# ----> 1 print(TrainX_1.shape)
#       2 print(TrainX_2.shape)
#       3 print(TrainX_3.shape)
#       4 print(TrainX_4.shape)
#
# NameError: name 'TrainX_1' is not defined

# %%
TrainX = np.concatenate((TrainX_1, TrainX_2, TrainX_3, TrainX_4), axis=0)
TrainGroundTruth = np.concatenate((TrainY_1, TrainY_2, TrainY_3, TrainY_4), axis=0)
TrainY = []

for img in TrainGroundTruth:
  encoded_img = convertToOneHot(img)
  TrainY.append(encoded_img)

TrainY = np.asarray(TrainY)

TestX = np.concatenate((TestX_1, TestX_2, TestX_3), axis=0)
TestGroundTruth = np.concatenate((TestY_1, TestY_2, TestY_3), axis=0)
TestY = []

for img in TestGroundTruth:
  encoded_img = convertToOneHot(img)
  TestY.append(encoded_img)

TestY = np.asarray(TestY)

ValidX = TrainX[1800:, : ]
ValidY = TrainY[1800:, : ]

TrainX = TrainX[0:1800, : ]
TrainY = TrainY[0:1800, : ]

print(TrainX.shape)
print(TrainY.shape)
print(TestX.shape)
print(TestY.shape)
print(ValidX.shape)
print(ValidY.shape)
np.unique(TestY)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 3)
# (1440, 240, 240, 3)
# (1440, 240, 240, 3)
# (120, 240, 240, 3)
# (120, 240, 240, 3)
# array([0, 1], dtype=uint8)

# %%
TrainX = np.reshape(TrainX,(-1,240, 240,3))
TrainY = np.reshape(TrainY,(-1,240, 240,3))

TrainX = TrainX.astype('float32')/255

TestX = np.reshape(TestX,(-1,240, 240,3))
TestY = np.reshape(TestY,(-1,240, 240,3))

TestX = TestX.astype('float32')/255

ValidX = np.reshape(ValidX,(-1,240, 240,3))
ValidY = np.reshape(ValidY,(-1,240, 240,3))

ValidX = ValidX.astype('float32')/255

# %%
print(TrainX.shape)
print(TrainY.shape)

print(TestX.shape)
print(TestY.shape)

print(ValidX.shape)
print(ValidY.shape)

np.unique(TestY)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 3)
# (1440, 240, 240, 3)
# (1440, 240, 240, 3)
# (120, 240, 240, 3)
# (120, 240, 240, 3)
# array([0, 1], dtype=uint8)

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
import math
from keras.callbacks import EarlyStopping,ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
mc = ModelCheckpoint('Checkpoint.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def combined_loss(y_true, y_pred):
  return (1*K.categorical_crossentropy(y_true, y_pred))+(0.5*tversky_loss(y_true, y_pred))

def loss(y_true, y_pred):
  return (1*K.categorical_crossentropy(y_true, y_pred))

# %%
optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=True)

# %%
model.compile(loss=tversky_loss, optimizer=optimizer, metrics=[dice_coef,'accuracy',tversky_loss, loss, combined_loss])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
TrainY.shape
# Out:
# (1800, 240, 240, 3)

# %%
num_epoch = 100;
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models"
history = model.fit(TrainX, TrainY, epochs=num_epoch, validation_data=(ValidX, ValidY), shuffle=True,batch_size=16,callbacks=[es,mc])
model.save(MODELS_PATH + '/NestedUNET_ER_20_03_18.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1800 samples, validate on 120 samples
# Epoch 1/100
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1800/1800 [==============================] - 25s 14ms/step - loss: 1.9059 - dice_coef: 0.7120 - acc: 0.7168 - tversky_loss: 1.7538 - loss_1: 2.8303 - combined_loss: 3.7071 - val_loss: 2.1041 - val_dice_coef: 0.9885 - val_acc: 0.9885 - val_tversky_loss: 1.9850 - val_loss_1: 0.1699 - val_combined_loss: 1.1624
#
# Epoch 00001: val_loss improved from inf to 2.10413, saving model to Checkpoint.h5
# Epoch 2/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.3861 - dice_coef: 0.8122 - acc: 0.8206 - tversky_loss: 1.2904 - loss_1: 2.1264 - combined_loss: 2.7716 - val_loss: 1.9753 - val_dice_coef: 0.9109 - val_acc: 0.9109 - val_tversky_loss: 1.8988 - val_loss_1: 1.1130 - val_combined_loss: 2.0624
#
# Epoch 00002: val_loss improved from 2.10413 to 1.97532, saving model to Checkpoint.h5
# Epoch 3/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.2429 - dice_coef: 0.8197 - acc: 0.8286 - tversky_loss: 1.1786 - loss_1: 2.3123 - combined_loss: 2.9016 - val_loss: 2.4525 - val_dice_coef: 0.4121 - val_acc: 0.4121 - val_tversky_loss: 2.3986 - val_loss_1: 8.9515 - val_combined_loss: 10.1507
#
# Epoch 00003: val_loss did not improve from 1.97532
# Epoch 4/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.1792 - dice_coef: 0.8348 - acc: 0.8470 - tversky_loss: 1.1317 - loss_1: 2.0824 - combined_loss: 2.6483 - val_loss: 2.1750 - val_dice_coef: 0.6911 - val_acc: 0.6909 - val_tversky_loss: 2.1324 - val_loss_1: 4.3607 - val_combined_loss: 5.4269
#
# Epoch 00004: val_loss did not improve from 1.97532
# Epoch 5/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.0983 - dice_coef: 0.8570 - acc: 0.8710 - tversky_loss: 1.0578 - loss_1: 1.7959 - combined_loss: 2.3248 - val_loss: 2.4165 - val_dice_coef: 0.4309 - val_acc: 0.4309 - val_tversky_loss: 2.3770 - val_loss_1: 9.0145 - val_combined_loss: 10.2031
#
# Epoch 00005: val_loss did not improve from 1.97532
# Epoch 6/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.9693 - dice_coef: 0.8833 - acc: 0.8943 - tversky_loss: 0.9295 - loss_1: 1.3961 - combined_loss: 1.8608 - val_loss: 1.6199 - val_dice_coef: 0.9843 - val_acc: 0.9843 - val_tversky_loss: 1.5800 - val_loss_1: 0.2504 - val_combined_loss: 1.0404
#
# Epoch 00006: val_loss improved from 1.97532 to 1.61992, saving model to Checkpoint.h5
# Epoch 7/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.8355 - dice_coef: 0.9185 - acc: 0.9284 - tversky_loss: 0.7953 - loss_1: 0.8938 - combined_loss: 1.2914 - val_loss: 1.9473 - val_dice_coef: 0.8561 - val_acc: 0.8561 - val_tversky_loss: 1.9076 - val_loss_1: 2.2989 - val_combined_loss: 3.2527
#
# Epoch 00007: val_loss did not improve from 1.61992
# Epoch 8/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.8055 - dice_coef: 0.9240 - acc: 0.9316 - tversky_loss: 0.7663 - loss_1: 0.8883 - combined_loss: 1.2715 - val_loss: 1.8156 - val_dice_coef: 0.9320 - val_acc: 0.9320 - val_tversky_loss: 1.7769 - val_loss_1: 1.0909 - val_combined_loss: 1.9794
#
# Epoch 00008: val_loss did not improve from 1.61992
# Epoch 9/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.7542 - dice_coef: 0.9286 - acc: 0.9342 - tversky_loss: 0.7152 - loss_1: 0.8491 - combined_loss: 1.2067 - val_loss: 1.5031 - val_dice_coef: 0.9898 - val_acc: 0.9898 - val_tversky_loss: 1.4636 - val_loss_1: 0.1642 - val_combined_loss: 0.8960
#
# Epoch 00009: val_loss improved from 1.61992 to 1.50314, saving model to Checkpoint.h5
# Epoch 10/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.8106 - dice_coef: 0.9251 - acc: 0.9299 - tversky_loss: 0.7699 - loss_1: 0.9195 - combined_loss: 1.3045 - val_loss: 1.7682 - val_dice_coef: 0.9371 - val_acc: 0.9371 - val_tversky_loss: 1.7283 - val_loss_1: 1.0106 - val_combined_loss: 1.8747
#
# Epoch 00010: val_loss did not improve from 1.50314
# Epoch 11/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.7440 - dice_coef: 0.9305 - acc: 0.9349 - tversky_loss: 0.7038 - loss_1: 0.8532 - combined_loss: 1.2051 - val_loss: 2.3584 - val_dice_coef: 0.4890 - val_acc: 0.4890 - val_tversky_loss: 2.3188 - val_loss_1: 8.2250 - val_combined_loss: 9.3844
#
# Epoch 00011: val_loss did not improve from 1.50314
# Epoch 12/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.7356 - dice_coef: 0.9315 - acc: 0.9358 - tversky_loss: 0.6964 - loss_1: 0.8488 - combined_loss: 1.1970 - val_loss: 1.5116 - val_dice_coef: 0.9913 - val_acc: 0.9913 - val_tversky_loss: 1.4723 - val_loss_1: 0.1403 - val_combined_loss: 0.8765
#
# Epoch 00012: val_loss did not improve from 1.50314
# Epoch 13/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.7223 - dice_coef: 0.9324 - acc: 0.9365 - tversky_loss: 0.6830 - loss_1: 0.8419 - combined_loss: 1.1834 - val_loss: 1.8967 - val_dice_coef: 0.9069 - val_acc: 0.9069 - val_tversky_loss: 1.8584 - val_loss_1: 1.4959 - val_combined_loss: 2.4251
#
# Epoch 00013: val_loss did not improve from 1.50314
# Epoch 14/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.7320 - dice_coef: 0.9318 - acc: 0.9358 - tversky_loss: 0.6945 - loss_1: 0.8574 - combined_loss: 1.2046 - val_loss: 1.7668 - val_dice_coef: 0.9565 - val_acc: 0.9565 - val_tversky_loss: 1.7295 - val_loss_1: 0.6993 - val_combined_loss: 1.5640
#
# Epoch 00014: val_loss did not improve from 1.50314
# Epoch 15/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.7425 - dice_coef: 0.9329 - acc: 0.9370 - tversky_loss: 0.7057 - loss_1: 0.8484 - combined_loss: 1.2012 - val_loss: 1.5539 - val_dice_coef: 0.9855 - val_acc: 0.9855 - val_tversky_loss: 1.5177 - val_loss_1: 0.2334 - val_combined_loss: 0.9923
#
# Epoch 00015: val_loss did not improve from 1.50314
# Epoch 16/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.7021 - dice_coef: 0.9339 - acc: 0.9377 - tversky_loss: 0.6653 - loss_1: 0.8371 - combined_loss: 1.1698 - val_loss: 2.0265 - val_dice_coef: 0.7793 - val_acc: 0.7793 - val_tversky_loss: 1.9895 - val_loss_1: 3.5509 - val_combined_loss: 4.5456
#
# Epoch 00016: val_loss did not improve from 1.50314
# Epoch 17/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6985 - dice_coef: 0.9343 - acc: 0.9379 - tversky_loss: 0.6617 - loss_1: 0.8355 - combined_loss: 1.1664 - val_loss: 1.5476 - val_dice_coef: 0.9842 - val_acc: 0.9842 - val_tversky_loss: 1.5113 - val_loss_1: 0.2546 - val_combined_loss: 1.0103
#
# Epoch 00017: val_loss did not improve from 1.50314
# Epoch 18/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.7018 - dice_coef: 0.9344 - acc: 0.9377 - tversky_loss: 0.6651 - loss_1: 0.8418 - combined_loss: 1.1743 - val_loss: 1.7344 - val_dice_coef: 0.9467 - val_acc: 0.9467 - val_tversky_loss: 1.6979 - val_loss_1: 0.8561 - val_combined_loss: 1.7050
#
# Epoch 00018: val_loss did not improve from 1.50314
# Epoch 19/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.7040 - dice_coef: 0.9346 - acc: 0.9377 - tversky_loss: 0.6676 - loss_1: 0.8422 - combined_loss: 1.1761 - val_loss: 1.8128 - val_dice_coef: 0.9201 - val_acc: 0.9201 - val_tversky_loss: 1.7767 - val_loss_1: 1.2849 - val_combined_loss: 2.1732
#
# Epoch 00019: val_loss did not improve from 1.50314
# Epoch 20/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6877 - dice_coef: 0.9353 - acc: 0.9383 - tversky_loss: 0.6518 - loss_1: 0.8352 - combined_loss: 1.1611 - val_loss: 1.7161 - val_dice_coef: 0.9905 - val_acc: 0.9905 - val_tversky_loss: 1.6802 - val_loss_1: 0.1530 - val_combined_loss: 0.9931
#
# Epoch 00020: val_loss did not improve from 1.50314
# Epoch 21/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6778 - dice_coef: 0.9362 - acc: 0.9390 - tversky_loss: 0.6413 - loss_1: 0.8234 - combined_loss: 1.1441 - val_loss: 1.6755 - val_dice_coef: 0.9649 - val_acc: 0.9649 - val_tversky_loss: 1.6383 - val_loss_1: 0.5635 - val_combined_loss: 1.3827
#
# Epoch 00021: val_loss did not improve from 1.50314
# Epoch 22/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6851 - dice_coef: 0.9368 - acc: 0.9395 - tversky_loss: 0.6476 - loss_1: 0.8173 - combined_loss: 1.1411 - val_loss: 1.5954 - val_dice_coef: 0.9769 - val_acc: 0.9769 - val_tversky_loss: 1.5584 - val_loss_1: 0.3714 - val_combined_loss: 1.1506
#
# Epoch 00022: val_loss did not improve from 1.50314
# Epoch 23/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6863 - dice_coef: 0.9362 - acc: 0.9387 - tversky_loss: 0.6495 - loss_1: 0.8303 - combined_loss: 1.1550 - val_loss: 1.4978 - val_dice_coef: 0.9873 - val_acc: 0.9873 - val_tversky_loss: 1.4609 - val_loss_1: 0.2036 - val_combined_loss: 0.9340
#
# Epoch 00023: val_loss improved from 1.50314 to 1.49781, saving model to Checkpoint.h5
# Epoch 24/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6726 - dice_coef: 0.9374 - acc: 0.9398 - tversky_loss: 0.6351 - loss_1: 0.8155 - combined_loss: 1.1330 - val_loss: 1.7684 - val_dice_coef: 0.9905 - val_acc: 0.9905 - val_tversky_loss: 1.7312 - val_loss_1: 0.1535 - val_combined_loss: 1.0191
#
# Epoch 00024: val_loss did not improve from 1.49781
# Epoch 25/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.7052 - dice_coef: 0.9349 - acc: 0.9373 - tversky_loss: 0.6678 - loss_1: 0.8540 - combined_loss: 1.1879 - val_loss: 2.0045 - val_dice_coef: 0.8013 - val_acc: 0.8013 - val_tversky_loss: 1.9674 - val_loss_1: 3.1930 - val_combined_loss: 4.1767
#
# Epoch 00025: val_loss did not improve from 1.49781
# Epoch 26/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6773 - dice_coef: 0.9367 - acc: 0.9390 - tversky_loss: 0.6405 - loss_1: 0.8290 - combined_loss: 1.1492 - val_loss: 1.4697 - val_dice_coef: 0.9907 - val_acc: 0.9907 - val_tversky_loss: 1.4325 - val_loss_1: 0.1500 - val_combined_loss: 0.8663
#
# Epoch 00026: val_loss improved from 1.49781 to 1.46973, saving model to Checkpoint.h5
# Epoch 27/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6689 - dice_coef: 0.9370 - acc: 0.9392 - tversky_loss: 0.6319 - loss_1: 0.8263 - combined_loss: 1.1422 - val_loss: 1.4680 - val_dice_coef: 0.9903 - val_acc: 0.9903 - val_tversky_loss: 1.4310 - val_loss_1: 0.1566 - val_combined_loss: 0.8721
#
# Epoch 00027: val_loss improved from 1.46973 to 1.46800, saving model to Checkpoint.h5
# Epoch 28/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6785 - dice_coef: 0.9373 - acc: 0.9394 - tversky_loss: 0.6412 - loss_1: 0.8230 - combined_loss: 1.1436 - val_loss: 1.8152 - val_dice_coef: 0.9215 - val_acc: 0.9215 - val_tversky_loss: 1.7768 - val_loss_1: 1.2604 - val_combined_loss: 2.1488
#
# Epoch 00028: val_loss did not improve from 1.46800
# Epoch 29/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6754 - dice_coef: 0.9367 - acc: 0.9387 - tversky_loss: 0.6362 - loss_1: 0.8346 - combined_loss: 1.1527 - val_loss: 1.6786 - val_dice_coef: 0.9906 - val_acc: 0.9906 - val_tversky_loss: 1.6396 - val_loss_1: 0.1507 - val_combined_loss: 0.9705
#
# Epoch 00029: val_loss did not improve from 1.46800
# Epoch 30/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6656 - dice_coef: 0.9375 - acc: 0.9394 - tversky_loss: 0.6268 - loss_1: 0.8240 - combined_loss: 1.1374 - val_loss: 1.4953 - val_dice_coef: 0.9889 - val_acc: 0.9889 - val_tversky_loss: 1.4568 - val_loss_1: 0.1782 - val_combined_loss: 0.9066
#
# Epoch 00030: val_loss did not improve from 1.46800
# Epoch 31/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6567 - dice_coef: 0.9385 - acc: 0.9404 - tversky_loss: 0.6177 - loss_1: 0.8093 - combined_loss: 1.1181 - val_loss: 1.6079 - val_dice_coef: 0.9756 - val_acc: 0.9756 - val_tversky_loss: 1.5678 - val_loss_1: 0.3924 - val_combined_loss: 1.1763
#
# Epoch 00031: val_loss did not improve from 1.46800
# Epoch 32/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6755 - dice_coef: 0.9382 - acc: 0.9400 - tversky_loss: 0.6346 - loss_1: 0.8165 - combined_loss: 1.1337 - val_loss: 1.7456 - val_dice_coef: 0.9445 - val_acc: 0.9445 - val_tversky_loss: 1.7051 - val_loss_1: 0.8908 - val_combined_loss: 1.7433
#
# Epoch 00032: val_loss did not improve from 1.46800
# Epoch 33/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6640 - dice_coef: 0.9388 - acc: 0.9406 - tversky_loss: 0.6235 - loss_1: 0.8084 - combined_loss: 1.1201 - val_loss: 1.5384 - val_dice_coef: 0.9844 - val_acc: 0.9844 - val_tversky_loss: 1.4976 - val_loss_1: 0.2512 - val_combined_loss: 1.0000
#
# Epoch 00033: val_loss did not improve from 1.46800
# Epoch 34/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6682 - dice_coef: 0.9380 - acc: 0.9398 - tversky_loss: 0.6278 - loss_1: 0.8227 - combined_loss: 1.1367 - val_loss: 1.5321 - val_dice_coef: 0.9911 - val_acc: 0.9911 - val_tversky_loss: 1.4920 - val_loss_1: 0.1428 - val_combined_loss: 0.8888
#
# Epoch 00034: val_loss did not improve from 1.46800
# Epoch 35/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6875 - dice_coef: 0.9362 - acc: 0.9380 - tversky_loss: 0.6470 - loss_1: 0.8525 - combined_loss: 1.1760 - val_loss: 1.5561 - val_dice_coef: 0.9812 - val_acc: 0.9812 - val_tversky_loss: 1.5156 - val_loss_1: 0.3019 - val_combined_loss: 1.0597
#
# Epoch 00035: val_loss did not improve from 1.46800
# Epoch 36/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6634 - dice_coef: 0.9383 - acc: 0.9400 - tversky_loss: 0.6229 - loss_1: 0.8196 - combined_loss: 1.1311 - val_loss: 1.6414 - val_dice_coef: 0.9695 - val_acc: 0.9695 - val_tversky_loss: 1.6013 - val_loss_1: 0.4898 - val_combined_loss: 1.2904
#
# Epoch 00036: val_loss did not improve from 1.46800
# Epoch 37/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6829 - dice_coef: 0.9379 - acc: 0.9396 - tversky_loss: 0.6431 - loss_1: 0.8283 - combined_loss: 1.1498 - val_loss: 1.9442 - val_dice_coef: 0.8446 - val_acc: 0.8446 - val_tversky_loss: 1.9036 - val_loss_1: 2.4999 - val_combined_loss: 3.4517
#
# Epoch 00037: val_loss did not improve from 1.46800
# Epoch 38/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6721 - dice_coef: 0.9373 - acc: 0.9390 - tversky_loss: 0.6310 - loss_1: 0.8374 - combined_loss: 1.1528 - val_loss: 1.4598 - val_dice_coef: 0.9907 - val_acc: 0.9907 - val_tversky_loss: 1.4184 - val_loss_1: 0.1488 - val_combined_loss: 0.8580
#
# Epoch 00038: val_loss improved from 1.46800 to 1.45981, saving model to Checkpoint.h5
# Epoch 39/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6471 - dice_coef: 0.9402 - acc: 0.9419 - tversky_loss: 0.6056 - loss_1: 0.7942 - combined_loss: 1.0971 - val_loss: 1.6974 - val_dice_coef: 0.9599 - val_acc: 0.9599 - val_tversky_loss: 1.6561 - val_loss_1: 0.6442 - val_combined_loss: 1.4723
#
# Epoch 00039: val_loss did not improve from 1.45981
# Epoch 40/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6583 - dice_coef: 0.9386 - acc: 0.9403 - tversky_loss: 0.6168 - loss_1: 0.8187 - combined_loss: 1.1271 - val_loss: 1.4694 - val_dice_coef: 0.9895 - val_acc: 0.9895 - val_tversky_loss: 1.4283 - val_loss_1: 0.1681 - val_combined_loss: 0.8823
#
# Epoch 00040: val_loss did not improve from 1.45981
# Epoch 41/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6537 - dice_coef: 0.9396 - acc: 0.9413 - tversky_loss: 0.6130 - loss_1: 0.8044 - combined_loss: 1.1109 - val_loss: 1.5383 - val_dice_coef: 0.9909 - val_acc: 0.9909 - val_tversky_loss: 1.4978 - val_loss_1: 0.1462 - val_combined_loss: 0.8951
#
# Epoch 00041: val_loss did not improve from 1.45981
# Epoch 42/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6502 - dice_coef: 0.9392 - acc: 0.9409 - tversky_loss: 0.6098 - loss_1: 0.8094 - combined_loss: 1.1143 - val_loss: 1.5552 - val_dice_coef: 0.9907 - val_acc: 0.9907 - val_tversky_loss: 1.5147 - val_loss_1: 0.1490 - val_combined_loss: 0.9064
#
# Epoch 00042: val_loss did not improve from 1.45981
# Epoch 43/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6573 - dice_coef: 0.9397 - acc: 0.9413 - tversky_loss: 0.6169 - loss_1: 0.8040 - combined_loss: 1.1125 - val_loss: 1.6434 - val_dice_coef: 0.9709 - val_acc: 0.9709 - val_tversky_loss: 1.6033 - val_loss_1: 0.4662 - val_combined_loss: 1.2678
#
# Epoch 00043: val_loss did not improve from 1.45981
# Epoch 44/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6499 - dice_coef: 0.9398 - acc: 0.9414 - tversky_loss: 0.6099 - loss_1: 0.8031 - combined_loss: 1.1080 - val_loss: 1.5510 - val_dice_coef: 0.9908 - val_acc: 0.9908 - val_tversky_loss: 1.5112 - val_loss_1: 0.1478 - val_combined_loss: 0.9034
#
# Epoch 00044: val_loss did not improve from 1.45981
# Epoch 45/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6509 - dice_coef: 0.9389 - acc: 0.9404 - tversky_loss: 0.6112 - loss_1: 0.8176 - combined_loss: 1.1232 - val_loss: 1.6221 - val_dice_coef: 0.9903 - val_acc: 0.9903 - val_tversky_loss: 1.5820 - val_loss_1: 0.1566 - val_combined_loss: 0.9477
#
# Epoch 00045: val_loss did not improve from 1.45981
# Epoch 46/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6470 - dice_coef: 0.9399 - acc: 0.9414 - tversky_loss: 0.6069 - loss_1: 0.8030 - combined_loss: 1.1064 - val_loss: 1.5427 - val_dice_coef: 0.9847 - val_acc: 0.9847 - val_tversky_loss: 1.5027 - val_loss_1: 0.2452 - val_combined_loss: 0.9966
#
# Epoch 00046: val_loss did not improve from 1.45981
# Epoch 47/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6712 - dice_coef: 0.9388 - acc: 0.9402 - tversky_loss: 0.6300 - loss_1: 0.8217 - combined_loss: 1.1367 - val_loss: 1.4832 - val_dice_coef: 0.9908 - val_acc: 0.9908 - val_tversky_loss: 1.4418 - val_loss_1: 0.1479 - val_combined_loss: 0.8688
#
# Epoch 00047: val_loss did not improve from 1.45981
# Epoch 48/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6528 - dice_coef: 0.9392 - acc: 0.9406 - tversky_loss: 0.6122 - loss_1: 0.8159 - combined_loss: 1.1219 - val_loss: 1.7748 - val_dice_coef: 0.9902 - val_acc: 0.9902 - val_tversky_loss: 1.7340 - val_loss_1: 0.1583 - val_combined_loss: 1.0254
#
# Epoch 00048: val_loss did not improve from 1.45981
# Epoch 49/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6615 - dice_coef: 0.9390 - acc: 0.9403 - tversky_loss: 0.6214 - loss_1: 0.8188 - combined_loss: 1.1295 - val_loss: 1.6642 - val_dice_coef: 0.9671 - val_acc: 0.9671 - val_tversky_loss: 1.6239 - val_loss_1: 0.5275 - val_combined_loss: 1.3395
#
# Epoch 00049: val_loss did not improve from 1.45981
# Epoch 50/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6572 - dice_coef: 0.9390 - acc: 0.9404 - tversky_loss: 0.6167 - loss_1: 0.8181 - combined_loss: 1.1264 - val_loss: 1.4782 - val_dice_coef: 0.9889 - val_acc: 0.9889 - val_tversky_loss: 1.4380 - val_loss_1: 0.1784 - val_combined_loss: 0.8974
#
# Epoch 00050: val_loss did not improve from 1.45981
# Epoch 51/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6552 - dice_coef: 0.9395 - acc: 0.9408 - tversky_loss: 0.6148 - loss_1: 0.8141 - combined_loss: 1.1215 - val_loss: 1.5036 - val_dice_coef: 0.9901 - val_acc: 0.9901 - val_tversky_loss: 1.4626 - val_loss_1: 0.1591 - val_combined_loss: 0.8904
#
# Epoch 00051: val_loss did not improve from 1.45981
# Epoch 52/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6617 - dice_coef: 0.9389 - acc: 0.9402 - tversky_loss: 0.6201 - loss_1: 0.8231 - combined_loss: 1.1331 - val_loss: 1.6444 - val_dice_coef: 0.9902 - val_acc: 0.9902 - val_tversky_loss: 1.6025 - val_loss_1: 0.1573 - val_combined_loss: 0.9586
#
# Epoch 00052: val_loss did not improve from 1.45981
# Epoch 53/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6518 - dice_coef: 0.9398 - acc: 0.9410 - tversky_loss: 0.6093 - loss_1: 0.8110 - combined_loss: 1.1157 - val_loss: 1.4841 - val_dice_coef: 0.9879 - val_acc: 0.9879 - val_tversky_loss: 1.4418 - val_loss_1: 0.1946 - val_combined_loss: 0.9156
#
# Epoch 00053: val_loss did not improve from 1.45981
# Epoch 54/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6339 - dice_coef: 0.9407 - acc: 0.9420 - tversky_loss: 0.5923 - loss_1: 0.7959 - combined_loss: 1.0921 - val_loss: 1.7454 - val_dice_coef: 0.9524 - val_acc: 0.9524 - val_tversky_loss: 1.7044 - val_loss_1: 0.7607 - val_combined_loss: 1.6129
#
# Epoch 00054: val_loss did not improve from 1.45981
# Epoch 55/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6545 - dice_coef: 0.9395 - acc: 0.9408 - tversky_loss: 0.6133 - loss_1: 0.8140 - combined_loss: 1.1206 - val_loss: 1.6608 - val_dice_coef: 0.9666 - val_acc: 0.9666 - val_tversky_loss: 1.6195 - val_loss_1: 0.5336 - val_combined_loss: 1.3434
#
# Epoch 00055: val_loss did not improve from 1.45981
# Epoch 56/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6392 - dice_coef: 0.9399 - acc: 0.9411 - tversky_loss: 0.5980 - loss_1: 0.8090 - combined_loss: 1.1080 - val_loss: 1.4818 - val_dice_coef: 0.9903 - val_acc: 0.9903 - val_tversky_loss: 1.4402 - val_loss_1: 0.1560 - val_combined_loss: 0.8761
#
# Epoch 00056: val_loss did not improve from 1.45981
# Epoch 57/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6503 - dice_coef: 0.9398 - acc: 0.9410 - tversky_loss: 0.6085 - loss_1: 0.8129 - combined_loss: 1.1172 - val_loss: 1.6363 - val_dice_coef: 0.9719 - val_acc: 0.9719 - val_tversky_loss: 1.5949 - val_loss_1: 0.4517 - val_combined_loss: 1.2492
#
# Epoch 00057: val_loss did not improve from 1.45981
# Epoch 58/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6333 - dice_coef: 0.9412 - acc: 0.9423 - tversky_loss: 0.5916 - loss_1: 0.7909 - combined_loss: 1.0867 - val_loss: 1.5469 - val_dice_coef: 0.9836 - val_acc: 0.9836 - val_tversky_loss: 1.5052 - val_loss_1: 0.2627 - val_combined_loss: 1.0153
#
# Epoch 00058: val_loss did not improve from 1.45981
# Epoch 59/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6400 - dice_coef: 0.9407 - acc: 0.9418 - tversky_loss: 0.5987 - loss_1: 0.7983 - combined_loss: 1.0976 - val_loss: 1.5241 - val_dice_coef: 0.9866 - val_acc: 0.9866 - val_tversky_loss: 1.4827 - val_loss_1: 0.2155 - val_combined_loss: 0.9568
#
# Epoch 00059: val_loss did not improve from 1.45981
# Epoch 60/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6542 - dice_coef: 0.9399 - acc: 0.9410 - tversky_loss: 0.6128 - loss_1: 0.8111 - combined_loss: 1.1175 - val_loss: 1.4674 - val_dice_coef: 0.9901 - val_acc: 0.9901 - val_tversky_loss: 1.4259 - val_loss_1: 0.1586 - val_combined_loss: 0.8715
#
# Epoch 00060: val_loss did not improve from 1.45981
# Epoch 61/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6401 - dice_coef: 0.9409 - acc: 0.9420 - tversky_loss: 0.5990 - loss_1: 0.7962 - combined_loss: 1.0956 - val_loss: 1.4868 - val_dice_coef: 0.9901 - val_acc: 0.9901 - val_tversky_loss: 1.4459 - val_loss_1: 0.1591 - val_combined_loss: 0.8820
#
# Epoch 00061: val_loss did not improve from 1.45981
# Epoch 62/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6470 - dice_coef: 0.9403 - acc: 0.9413 - tversky_loss: 0.6064 - loss_1: 0.8062 - combined_loss: 1.1094 - val_loss: 1.4729 - val_dice_coef: 0.9891 - val_acc: 0.9891 - val_tversky_loss: 1.4321 - val_loss_1: 0.1745 - val_combined_loss: 0.8906
#
# Epoch 00062: val_loss did not improve from 1.45981
# Epoch 63/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6356 - dice_coef: 0.9401 - acc: 0.9411 - tversky_loss: 0.5945 - loss_1: 0.8104 - combined_loss: 1.1077 - val_loss: 1.6742 - val_dice_coef: 0.9704 - val_acc: 0.9704 - val_tversky_loss: 1.6327 - val_loss_1: 0.4734 - val_combined_loss: 1.2897
#
# Epoch 00063: val_loss did not improve from 1.45981
# Epoch 64/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6479 - dice_coef: 0.9403 - acc: 0.9413 - tversky_loss: 0.6061 - loss_1: 0.8075 - combined_loss: 1.1106 - val_loss: 1.5012 - val_dice_coef: 0.9900 - val_acc: 0.9900 - val_tversky_loss: 1.4597 - val_loss_1: 0.1599 - val_combined_loss: 0.8897
#
# Epoch 00064: val_loss did not improve from 1.45981
# Epoch 65/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6376 - dice_coef: 0.9411 - acc: 0.9421 - tversky_loss: 0.5963 - loss_1: 0.7928 - combined_loss: 1.0910 - val_loss: 1.4880 - val_dice_coef: 0.9879 - val_acc: 0.9879 - val_tversky_loss: 1.4471 - val_loss_1: 0.1942 - val_combined_loss: 0.9177
#
# Epoch 00065: val_loss did not improve from 1.45981
# Epoch 66/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6293 - dice_coef: 0.9408 - acc: 0.9419 - tversky_loss: 0.5884 - loss_1: 0.7992 - combined_loss: 1.0934 - val_loss: 1.4976 - val_dice_coef: 0.9884 - val_acc: 0.9884 - val_tversky_loss: 1.4560 - val_loss_1: 0.1856 - val_combined_loss: 0.9136
#
# Epoch 00066: val_loss did not improve from 1.45981
# Epoch 67/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6287 - dice_coef: 0.9415 - acc: 0.9425 - tversky_loss: 0.5860 - loss_1: 0.7876 - combined_loss: 1.0806 - val_loss: 1.5268 - val_dice_coef: 0.9901 - val_acc: 0.9901 - val_tversky_loss: 1.4838 - val_loss_1: 0.1594 - val_combined_loss: 0.9013
#
# Epoch 00067: val_loss did not improve from 1.45981
# Epoch 68/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6380 - dice_coef: 0.9409 - acc: 0.9419 - tversky_loss: 0.5953 - loss_1: 0.7975 - combined_loss: 1.0951 - val_loss: 1.4921 - val_dice_coef: 0.9883 - val_acc: 0.9883 - val_tversky_loss: 1.4494 - val_loss_1: 0.1874 - val_combined_loss: 0.9121
#
# Epoch 00068: val_loss did not improve from 1.45981
# Epoch 00068: early stopping

# %%
train_loss = history.history['loss']
train_acc = history.history['acc']
val_loss = history.history['val_loss']
val_acc = history.history['val_acc']
xc=range(len(train_loss))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_loss)
plt.plot(xc, val_loss)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(['train','val'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_acc)
plt.plot(xc, val_acc)
plt.xlabel("Epoch")
plt.ylabel("Acc")
plt.legend(['train','val'])

# %%
# MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models"
# model = keras.models.load_model(MODELS_PATH+'/UNET_ER_20_03_03_v5.h5',custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

# %%
# Function to find the most probable class of an image pixel by pixel
def ClassFinder(img):
  result = np.zeros(img.shape, dtype=np.uint8)
  for r in range(len(img)):
    for c in range(len(img[0])):
      idx = np.argmax(img[r][c])
      result[r][c][idx]=1
      
  return result

# %%
train_result = model.predict(TrainX, batch_size=16)
print(np.shape(train_result))
Train_predict = [ ]
for img in train_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_predict.append(encoded_img)

Predicted_images = np.asarray(Train_predict)
print(Predicted_images.shape)
np.unique(Predicted_images)
# dice = dc(train_result, TrainY)
# pre  = precision(train_result,TrainY)
# re   = recall(train_result,TrainY)
# print('Train dc: '  + str(dice))
# print('Train pre: ' + str(pre))
# print('Train re: '  + str(re))
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240)
# array([  0, 128, 255], dtype=uint8)

# %%
test_result = model.predict(TestX, batch_size=16)
print(np.shape(test_result))

Test_predict = [ ]
for img in test_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_predict.append(encoded_img)

Predicted_images_test = np.asarray(Test_predict)
print(Predicted_images_test.shape)
np.unique(Predicted_images_test)
# dice = dc(test_result, TestY)
# pre  = precision(test_result,TestY)
# re   = recall(test_result,TestY)
# print('Test dc: '  + str(dice))
# print('Test pre: ' + str(pre))
# print('Test re: '  + str(re))
# Out:
# (1440, 240, 240, 3)
# (1440, 240, 240)
# array([  0, 128, 255], dtype=uint8)

# %%
from sklearn.metrics import confusion_matrix
def get_confusion_matrix(Actual, Predicted):
  ActualY = np.reshape(Actual,(-1, Actual.shape[3]))
  PredY = np.reshape(Predicted,(-1, Predicted.shape[3]))
  matrix = confusion_matrix(ActualY.argmax(axis = 1), PredY.argmax(axis = 1))
  return matrix

def get_precision(confusion_matrix):
  precision = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 0)
  nan_indices = np.isnan(precision)
  precision[nan_indices] = 0
  return precision

def get_recall(confusion_matrix):
  recall = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 1)
  nan_indices = np.isnan(recall)
  recall[nan_indices] = 0
  return recall

# %%
test_matrix = get_confusion_matrix(TestY, test_result)
train_matrix = get_confusion_matrix(TrainY, train_result)
print(test_matrix)
print(train_matrix)
# TestY.shape[3]
# test_result.shape
# Out:
# [[69565678  4108101  1808716]
#  [   31624   822905  2083861]
#  [   24126    77984  4421005]]
# [[85141824  3940774   966845]
#  [  452133  5237831   455851]
#  [  621832  1125209  5737701]]

# %%
np.unique(Predicted_images_test)
# Out:
# array([  0, 128, 255], dtype=uint8)

# %%
test_precision = get_precision(test_matrix)
print('Test Precision')
print(test_precision)
test_recall = get_recall(test_matrix)
print('Test Recall')
print(test_recall)
train_precision = get_precision(train_matrix)
print('Train Precision')
print(train_precision)
train_recall = get_recall(train_matrix)
print('Train Recall')
print(train_recall)
# Out:
# Test Precision
# [0.99919924 0.16428561 0.53178101]
# Test Recall
# [0.92161339 0.28005302 0.97742485]
# Train Precision
# [0.98754329 0.50833905 0.80131046]
# Train Recall
# [0.94550084 0.85225979 0.76658634]

# %%
# weight_matrix = np.zeros((3,1))
# weight_matrix[0] = 0.6
# weight_matrix[1] = 0.2
# weight_matrix[2] = 0.2
# print(weight_matrix.shape)

# %%
weight_matrix = np.zeros((3,1))
weight_matrix[0] = 1/3
weight_matrix[1] = 1/3
weight_matrix[2] = 1/3
print(weight_matrix.shape)
# Out:
# (3, 1)

# %%
def get_overall_precision(precision, weights):
  final_precision = np.dot(precision,weights)
  return final_precision

def get_overall_recall(recall, weights):
  final_recall = np.dot(recall ,weights)
  return final_recall

# %%
final_test_precision  = get_overall_precision(test_precision, weight_matrix)
final_test_recall     = get_overall_recall(test_recall, weight_matrix)
final_train_precision = get_overall_precision(train_precision, weight_matrix)
final_train_recall    = get_overall_recall(train_recall, weight_matrix)
print('Final Test Precision')
print(final_test_precision)
print('Final Test Recall')
print(final_test_recall)
print('Final Train Precision')
print(final_train_precision)
print('Final Train Recall')
print(final_train_recall)
# Out:
# Final Test Precision
# [0.56508862]
# Final Test Recall
# [0.72636375]
# Final Train Precision
# [0.76573093]
# Final Train Recall
# [0.85478232]

# %%
from scipy.stats import hmean

def dice_coefficient(precision, recall):
  return hmean(np.asarray([precision , recall]))

# %%
test_dice_coeff = dice_coefficient(final_test_precision, final_test_recall)
print('Test Dice coeff')
print(test_dice_coeff)

train_dice_coeff = dice_coefficient(final_train_precision, final_train_recall)
print('Train Dice coeff')
print(train_dice_coeff)
# Out:
# Test Dice coeff
# [0.63565626]
# Train Dice coeff
# [0.80780983]

# %%
copy1  = np.copy(TestX [250])
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
copy3 = np.reshape(copy2,(240, 240,3))
Img = cv2.cvtColor(copy3,cv2.COLOR_BGR2RGB)

Mask = TestGroundTruth[250]

Predicted_Mask = Predicted_images_test[250] 

plt.subplot(131).imshow(Img)
plt.subplot(132).imshow(Mask,'gray')
plt.subplot(133).imshow(Predicted_Mask,'gray')

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask):
  num = mask.shape[0]/480
  for id in range(int(num)):
    temp = []
    for i in range(id, id+10):
      idx = i * 48
      final_output = mask[idx:idx+48]
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save("/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/Combined_Loss/ER1 Patient " + str(id), final_output)

# %%
# saving predicted outputs as numpy arrays for test images
saveNumpyOutput(Predicted_images)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 20   # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]

Mask_input = TestY[id:id+48]
Test_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Test_Actual)
print(Mask_input.shape)

final_output = Predicted_images_test[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cb353051c9d0> in <module>()
#      12
#      13 id = id * 48
# ---> 14 final_input = TestX[id:id+48]
#      15
#      16 Mask_input = TestY[id:id+48]
#
# NameError: name 'TestX' is not defined

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 14  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]

Mask_input = TrainY[id:id+48]
Train_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Train_Actual)
print(Mask_input.shape)

final_output = Predicted_images[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 3)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0. 128. 255.]
