# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from keras.layers import Activation,Conv2D,MaxPooling2D,UpSampling2D,Dense,BatchNormalization,Input,Reshape,multiply,add,Dropout,AveragePooling2D,GlobalAveragePooling2D,concatenate
from keras.layers.convolutional import Conv2DTranspose
from keras.models import Model														  
import keras.backend as K
from keras.regularizers import l2
from keras.engine import Layer,InputSpec
from keras.utils import conv_utils
from keras.layers import Activation,Conv2D,MaxPooling2D,UpSampling2D,Dense,BatchNormalization,Input,Reshape,multiply,add,Dropout,AveragePooling2D,GlobalAveragePooling2D,concatenate
from keras.layers.convolutional import Conv2DTranspose
from keras.models import Model														  
import keras.backend as K
from keras.regularizers import l2
from keras.engine import Layer,InputSpec
from keras.utils import conv_utils
# !pip install medpy
from keras.layers import *
from keras.models import Sequential
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from medpy.metric import dc, precision, recall
import keras
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Collecting medpy
#   Downloading https://files.pythonhosted.org/packages/3b/70/c1fd5dd60242eee81774696ea7ba4caafac2bad8f028bba94b1af83777d7/MedPy-0.4.0.tar.gz (151kB)
#      |████████████████████████████████| 153kB 2.7MB/s
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.18.2)
# Collecting SimpleITK>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/f8/d8/53338c34f71020725ffb3557846c80af96c29c03bc883551a2565aa68a7c/SimpleITK-1.2.4-cp36-cp36m-manylinux1_x86_64.whl (42.5MB)
#      |████████████████████████████████| 42.5MB 98kB/s
# Building wheels for collected packages: medpy
#   Building wheel for medpy (setup.py) ... done
#   Created wheel for medpy: filename=MedPy-0.4.0-cp36-cp36m-linux_x86_64.whl size=753436 sha256=f74282e920879d3aa417cde5680d66fe2fc9c780c67a5ea63db52a7343ac058d
#   Stored in directory: /root/.cache/pip/wheels/8c/c9/9c/2c6281c7a72b9fb1570862a4f028af7ce38405008354fbf870
# Successfully built medpy
# Installing collected packages: SimpleITK, medpy
# Successfully installed SimpleITK-1.2.4 medpy-0.4.0

# %%
smooth = 1.
dropout_rate = 0.5
def standard_unit(input_tensor, stage, nb_filter, kernel_size=3):

    act = 'elu'

    x = Conv2D(nb_filter, (kernel_size, kernel_size), activation=act, name='conv'+stage+'_1', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(input_tensor)
    x = Dropout(dropout_rate, name='dp'+stage+'_1')(x)
    x = Conv2D(nb_filter, (kernel_size, kernel_size), activation=act, name='conv'+stage+'_2', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(x)
    x = Dropout(dropout_rate, name='dp'+stage+'_2')(x)

    return x

# %%
def Nest_Net(img_rows, img_cols, color_type=3, num_class=4, deep_supervision=False):

    nb_filter = [8,16,32,64,128]
    act = 'elu'
  
    bn_axis = 3
    
    
    img_input = Input(shape=(img_rows, img_cols, color_type), name='main_input')
    conv1_1 = standard_unit(img_input, stage='11', nb_filter=nb_filter[0])
    pool1 = MaxPooling2D((2, 2), strides=(2, 2), name='pool1')(conv1_1)

    conv2_1 = standard_unit(pool1, stage='21', nb_filter=nb_filter[1])
    pool2 = MaxPooling2D((2, 2), strides=(2, 2), name='pool2')(conv2_1)

    up1_2 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up12', padding='same')(conv2_1)
    conv1_2 = concatenate([up1_2, conv1_1], name='merge12', axis=bn_axis)
    conv1_2 = standard_unit(conv1_2, stage='12', nb_filter=nb_filter[0])

    conv3_1 = standard_unit(pool2, stage='31', nb_filter=nb_filter[2])
    pool3 = MaxPooling2D((2, 2), strides=(2, 2), name='pool3')(conv3_1)

    up2_2 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up22', padding='same')(conv3_1)
    conv2_2 = concatenate([up2_2, conv2_1], name='merge22', axis=bn_axis)
    conv2_2 = standard_unit(conv2_2, stage='22', nb_filter=nb_filter[1])

    up1_3 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up13', padding='same')(conv2_2)
    conv1_3 = concatenate([up1_3, conv1_1, conv1_2], name='merge13', axis=bn_axis)
    conv1_3 = standard_unit(conv1_3, stage='13', nb_filter=nb_filter[0])

    conv4_1 = standard_unit(pool3, stage='41', nb_filter=nb_filter[3])
    pool4 = MaxPooling2D((2, 2), strides=(2, 2), name='pool4')(conv4_1)

    up3_2 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up32', padding='same')(conv4_1)
    conv3_2 = concatenate([up3_2, conv3_1], name='merge32', axis=bn_axis)
    conv3_2 = standard_unit(conv3_2, stage='32', nb_filter=nb_filter[2])

    up2_3 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up23', padding='same')(conv3_2)
    conv2_3 = concatenate([up2_3, conv2_1, conv2_2], name='merge23', axis=bn_axis)
    conv2_3 = standard_unit(conv2_3, stage='23', nb_filter=nb_filter[1])

    up1_4 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up14', padding='same')(conv2_3)
    conv1_4 = concatenate([up1_4, conv1_1, conv1_2, conv1_3], name='merge14', axis=bn_axis)
    conv1_4 = standard_unit(conv1_4, stage='14', nb_filter=nb_filter[0])

    conv5_1 = standard_unit(pool4, stage='51', nb_filter=nb_filter[4])

    up4_2 = Conv2DTranspose(nb_filter[3], (2, 2), strides=(2, 2), name='up42', padding='same')(conv5_1)
    conv4_2 = concatenate([up4_2, conv4_1], name='merge42', axis=bn_axis)
    conv4_2 = standard_unit(conv4_2, stage='42', nb_filter=nb_filter[3])

    up3_3 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up33', padding='same')(conv4_2)
    conv3_3 = concatenate([up3_3, conv3_1, conv3_2], name='merge33', axis=bn_axis)
    conv3_3 = standard_unit(conv3_3, stage='33', nb_filter=nb_filter[2])

    up2_4 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up24', padding='same')(conv3_3)
    conv2_4 = concatenate([up2_4, conv2_1, conv2_2, conv2_3], name='merge24', axis=bn_axis)
    conv2_4 = standard_unit(conv2_4, stage='24', nb_filter=nb_filter[1])

    up1_5 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up15', padding='same')(conv2_4)
    conv1_5 = concatenate([up1_5, conv1_1, conv1_2, conv1_3, conv1_4], name='merge15', axis=bn_axis)
    conv1_5 = standard_unit(conv1_5, stage='15', nb_filter=nb_filter[0])

    nestnet_output_1 = Conv2D(num_class, (1, 1), activation='softmax', name='output_1', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_2)
    nestnet_output_2 = Conv2D(num_class, (1, 1), activation='softmax', name='output_2', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_3)
    nestnet_output_3 = Conv2D(num_class, (1, 1), activation='softmax', name='output_3', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_4)
    nestnet_output_4 = Conv2D(num_class, (1, 1), activation='softmax', name='output_4', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_5)

    if deep_supervision:
        model = Model(input=img_input, output=[nestnet_output_1,
                                               nestnet_output_2,
                                               nestnet_output_3,
                                               nestnet_output_4])
    else:
        model = Model(input=img_input, output=[nestnet_output_4])

    return model

# %%
model = Nest_Net(240,240,3)
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 240, 240, 3)  0
# __________________________________________________________________________________________________
# conv11_1 (Conv2D)               (None, 240, 240, 8)  224         main_input[0][0]
# __________________________________________________________________________________________________
# dp11_1 (Dropout)                (None, 240, 240, 8)  0           conv11_1[0][0]
# __________________________________________________________________________________________________
# conv11_2 (Conv2D)               (None, 240, 240, 8)  584         dp11_1[0][0]
# __________________________________________________________________________________________________
# dp11_2 (Dropout)                (None, 240, 240, 8)  0           conv11_2[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 120, 120, 8)  0           dp11_2[0][0]
# __________________________________________________________________________________________________
# conv21_1 (Conv2D)               (None, 120, 120, 16) 1168        pool1[0][0]
# __________________________________________________________________________________________________
# dp21_1 (Dropout)                (None, 120, 120, 16) 0           conv21_1[0][0]
# __________________________________________________________________________________________________
# conv21_2 (Conv2D)               (None, 120, 120, 16) 2320        dp21_1[0][0]
# __________________________________________________________________________________________________
# dp21_2 (Dropout)                (None, 120, 120, 16) 0           conv21_2[0][0]
# __________________________________________________________________________________________________
# pool2 (MaxPooling2D)            (None, 60, 60, 16)   0           dp21_2[0][0]
# __________________________________________________________________________________________________
# conv31_1 (Conv2D)               (None, 60, 60, 32)   4640        pool2[0][0]
# __________________________________________________________________________________________________
# dp31_1 (Dropout)                (None, 60, 60, 32)   0           conv31_1[0][0]
# __________________________________________________________________________________________________
# conv31_2 (Conv2D)               (None, 60, 60, 32)   9248        dp31_1[0][0]
# __________________________________________________________________________________________________
# dp31_2 (Dropout)                (None, 60, 60, 32)   0           conv31_2[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 30, 30, 32)   0           dp31_2[0][0]
# __________________________________________________________________________________________________
# conv41_1 (Conv2D)               (None, 30, 30, 64)   18496       pool3[0][0]
# __________________________________________________________________________________________________
# dp41_1 (Dropout)                (None, 30, 30, 64)   0           conv41_1[0][0]
# __________________________________________________________________________________________________
# conv41_2 (Conv2D)               (None, 30, 30, 64)   36928       dp41_1[0][0]
# __________________________________________________________________________________________________
# dp41_2 (Dropout)                (None, 30, 30, 64)   0           conv41_2[0][0]
# __________________________________________________________________________________________________
# pool4 (MaxPooling2D)            (None, 15, 15, 64)   0           dp41_2[0][0]
# __________________________________________________________________________________________________
# conv51_1 (Conv2D)               (None, 15, 15, 128)  73856       pool4[0][0]
# __________________________________________________________________________________________________
# dp51_1 (Dropout)                (None, 15, 15, 128)  0           conv51_1[0][0]
# __________________________________________________________________________________________________
# conv51_2 (Conv2D)               (None, 15, 15, 128)  147584      dp51_1[0][0]
# __________________________________________________________________________________________________
# dp51_2 (Dropout)                (None, 15, 15, 128)  0           conv51_2[0][0]
# __________________________________________________________________________________________________
# up42 (Conv2DTranspose)          (None, 30, 30, 64)   32832       dp51_2[0][0]
# __________________________________________________________________________________________________
# merge42 (Concatenate)           (None, 30, 30, 128)  0           up42[0][0]
#                                                                  dp41_2[0][0]
# __________________________________________________________________________________________________
# up32 (Conv2DTranspose)          (None, 60, 60, 32)   8224        dp41_2[0][0]
# __________________________________________________________________________________________________
# conv42_1 (Conv2D)               (None, 30, 30, 64)   73792       merge42[0][0]
# __________________________________________________________________________________________________
# merge32 (Concatenate)           (None, 60, 60, 64)   0           up32[0][0]
#                                                                  dp31_2[0][0]
# __________________________________________________________________________________________________
# up22 (Conv2DTranspose)          (None, 120, 120, 16) 2064        dp31_2[0][0]
# __________________________________________________________________________________________________
# dp42_1 (Dropout)                (None, 30, 30, 64)   0           conv42_1[0][0]
# __________________________________________________________________________________________________
# conv32_1 (Conv2D)               (None, 60, 60, 32)   18464       merge32[0][0]
# __________________________________________________________________________________________________
# merge22 (Concatenate)           (None, 120, 120, 32) 0           up22[0][0]
#                                                                  dp21_2[0][0]
# __________________________________________________________________________________________________
# up12 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp21_2[0][0]
# __________________________________________________________________________________________________
# conv42_2 (Conv2D)               (None, 30, 30, 64)   36928       dp42_1[0][0]
# __________________________________________________________________________________________________
# dp32_1 (Dropout)                (None, 60, 60, 32)   0           conv32_1[0][0]
# __________________________________________________________________________________________________
# conv22_1 (Conv2D)               (None, 120, 120, 16) 4624        merge22[0][0]
# __________________________________________________________________________________________________
# merge12 (Concatenate)           (None, 240, 240, 16) 0           up12[0][0]
#                                                                  dp11_2[0][0]
# __________________________________________________________________________________________________
# dp42_2 (Dropout)                (None, 30, 30, 64)   0           conv42_2[0][0]
# __________________________________________________________________________________________________
# conv32_2 (Conv2D)               (None, 60, 60, 32)   9248        dp32_1[0][0]
# __________________________________________________________________________________________________
# dp22_1 (Dropout)                (None, 120, 120, 16) 0           conv22_1[0][0]
# __________________________________________________________________________________________________
# conv12_1 (Conv2D)               (None, 240, 240, 8)  1160        merge12[0][0]
# __________________________________________________________________________________________________
# up33 (Conv2DTranspose)          (None, 60, 60, 32)   8224        dp42_2[0][0]
# __________________________________________________________________________________________________
# dp32_2 (Dropout)                (None, 60, 60, 32)   0           conv32_2[0][0]
# __________________________________________________________________________________________________
# conv22_2 (Conv2D)               (None, 120, 120, 16) 2320        dp22_1[0][0]
# __________________________________________________________________________________________________
# dp12_1 (Dropout)                (None, 240, 240, 8)  0           conv12_1[0][0]
# __________________________________________________________________________________________________
# merge33 (Concatenate)           (None, 60, 60, 96)   0           up33[0][0]
#                                                                  dp31_2[0][0]
#                                                                  dp32_2[0][0]
# __________________________________________________________________________________________________
# dp22_2 (Dropout)                (None, 120, 120, 16) 0           conv22_2[0][0]
# __________________________________________________________________________________________________
# up23 (Conv2DTranspose)          (None, 120, 120, 16) 2064        dp32_2[0][0]
# __________________________________________________________________________________________________
# conv12_2 (Conv2D)               (None, 240, 240, 8)  584         dp12_1[0][0]
# __________________________________________________________________________________________________
# conv33_1 (Conv2D)               (None, 60, 60, 32)   27680       merge33[0][0]
# __________________________________________________________________________________________________
# merge23 (Concatenate)           (None, 120, 120, 48) 0           up23[0][0]
#                                                                  dp21_2[0][0]
#                                                                  dp22_2[0][0]
# __________________________________________________________________________________________________
# dp12_2 (Dropout)                (None, 240, 240, 8)  0           conv12_2[0][0]
# __________________________________________________________________________________________________
# up13 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp22_2[0][0]
# __________________________________________________________________________________________________
# dp33_1 (Dropout)                (None, 60, 60, 32)   0           conv33_1[0][0]
# __________________________________________________________________________________________________
# conv23_1 (Conv2D)               (None, 120, 120, 16) 6928        merge23[0][0]
# __________________________________________________________________________________________________
# merge13 (Concatenate)           (None, 240, 240, 24) 0           up13[0][0]
#                                                                  dp11_2[0][0]
#                                                                  dp12_2[0][0]
# __________________________________________________________________________________________________
# conv33_2 (Conv2D)               (None, 60, 60, 32)   9248        dp33_1[0][0]
# __________________________________________________________________________________________________
# dp23_1 (Dropout)                (None, 120, 120, 16) 0           conv23_1[0][0]
# __________________________________________________________________________________________________
# conv13_1 (Conv2D)               (None, 240, 240, 8)  1736        merge13[0][0]
# __________________________________________________________________________________________________
# dp33_2 (Dropout)                (None, 60, 60, 32)   0           conv33_2[0][0]
# __________________________________________________________________________________________________
# conv23_2 (Conv2D)               (None, 120, 120, 16) 2320        dp23_1[0][0]
# __________________________________________________________________________________________________
# dp13_1 (Dropout)                (None, 240, 240, 8)  0           conv13_1[0][0]
# __________________________________________________________________________________________________
# up24 (Conv2DTranspose)          (None, 120, 120, 16) 2064        dp33_2[0][0]
# __________________________________________________________________________________________________
# dp23_2 (Dropout)                (None, 120, 120, 16) 0           conv23_2[0][0]
# __________________________________________________________________________________________________
# conv13_2 (Conv2D)               (None, 240, 240, 8)  584         dp13_1[0][0]
# __________________________________________________________________________________________________
# merge24 (Concatenate)           (None, 120, 120, 64) 0           up24[0][0]
#                                                                  dp21_2[0][0]
#                                                                  dp22_2[0][0]
#                                                                  dp23_2[0][0]
# __________________________________________________________________________________________________
# dp13_2 (Dropout)                (None, 240, 240, 8)  0           conv13_2[0][0]
# __________________________________________________________________________________________________
# up14 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp23_2[0][0]
# __________________________________________________________________________________________________
# conv24_1 (Conv2D)               (None, 120, 120, 16) 9232        merge24[0][0]
# __________________________________________________________________________________________________
# merge14 (Concatenate)           (None, 240, 240, 32) 0           up14[0][0]
#                                                                  dp11_2[0][0]
#                                                                  dp12_2[0][0]
#                                                                  dp13_2[0][0]
# __________________________________________________________________________________________________
# dp24_1 (Dropout)                (None, 120, 120, 16) 0           conv24_1[0][0]
# __________________________________________________________________________________________________
# conv14_1 (Conv2D)               (None, 240, 240, 8)  2312        merge14[0][0]
# __________________________________________________________________________________________________
# conv24_2 (Conv2D)               (None, 120, 120, 16) 2320        dp24_1[0][0]
# __________________________________________________________________________________________________
# dp14_1 (Dropout)                (None, 240, 240, 8)  0           conv14_1[0][0]
# __________________________________________________________________________________________________
# dp24_2 (Dropout)                (None, 120, 120, 16) 0           conv24_2[0][0]
# __________________________________________________________________________________________________
# conv14_2 (Conv2D)               (None, 240, 240, 8)  584         dp14_1[0][0]
# __________________________________________________________________________________________________
# up15 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp24_2[0][0]
# __________________________________________________________________________________________________
# dp14_2 (Dropout)                (None, 240, 240, 8)  0           conv14_2[0][0]
# __________________________________________________________________________________________________
# merge15 (Concatenate)           (None, 240, 240, 40) 0           up15[0][0]
#                                                                  dp11_2[0][0]
#                                                                  dp12_2[0][0]
#                                                                  dp13_2[0][0]
#                                                                  dp14_2[0][0]
# __________________________________________________________________________________________________
# conv15_1 (Conv2D)               (None, 240, 240, 8)  2888        merge15[0][0]
# __________________________________________________________________________________________________
# dp15_1 (Dropout)                (None, 240, 240, 8)  0           conv15_1[0][0]
# __________________________________________________________________________________________________
# conv15_2 (Conv2D)               (None, 240, 240, 8)  584         dp15_1[0][0]
# __________________________________________________________________________________________________
# dp15_2 (Dropout)                (None, 240, 240, 8)  0           conv15_2[0][0]
# __________________________________________________________________________________________________
# output_4 (Conv2D)               (None, 240, 240, 4)  36          dp15_2[0][0]
# ==================================================================================================
# Total params: 566,172
# Trainable params: 566,172
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:75: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("ma..., outputs=[<tf.Tenso...)`

# %%
import os
import cv2
import numpy as np

# %%
# Function to convert image from greyscale to one hot (i.e. 4 channels)
def convertToOneHot(image):
    num_classes = 4
    shape = image.shape[:2]+(num_classes,)
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c]==0:
          encoded_image[r][c][0] = 1
        elif image[r][c]==85:
          encoded_image[r][c][1] = 1
        elif image[r][c]==170:
          encoded_image[r][c][2] = 1
        else:
          encoded_image[r][c][3] = 1
    return encoded_image

# %%
# Function to convert back from one hot image to greyscale
def convertFromOneHot(image):
    shape = image.shape[:2]
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c][0] == 1:
          encoded_image[r][c] = 0
        elif image[r][c][1] == 1:
          encoded_image[r][c] = 85
        elif image[r][c][2] == 1:
          encoded_image[r][c] = 170
        else:
          encoded_image[r][c] = 255
    return encoded_image

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/4 Class ER"

# Train set patients: 230 263 239 242 
TrainX_1 = np.load(PATH + '/ER IHC 239 Images.npy')
TrainY_1 = np.load(PATH + '/ER IHC 239 Masks.npy')
TrainX_2 = np.load(PATH + '/ER IHC 263 Images.npy')
TrainY_2 = np.load(PATH + '/ER IHC 263 Masks.npy')
TrainX_3 = np.load(PATH + '/ER IHC 242 Images.npy')
TrainY_3 = np.load(PATH + '/ER IHC 242 Masks.npy')
TrainX_4 = np.load(PATH + '/ER IHC 230 Images.npy')
TrainY_4 = np.load(PATH + '/ER IHC 230 Masks.npy')

# Test set patients: 221 246 232
TestX_1 = np.load(PATH + '/ER IHC 221 Images.npy')
TestY_1 = np.load(PATH + '/ER IHC 221 Masks.npy')
TestX_2 = np.load(PATH + '/ER IHC 246 Images.npy')
TestY_2 = np.load(PATH + '/ER IHC 246 Masks.npy')
TestX_3 = np.load(PATH + '/ER IHC 232 Images.npy')
TestY_3 = np.load(PATH + '/ER IHC 232 Masks.npy')

# %%
np.unique(TestY_3)
# Out:
# array([  0.,  85., 170., 255.])

# %%
TrainX = np.concatenate((TrainX_1, TrainX_2, TrainX_3, TrainX_4), axis=0)
TrainGroundTruth = np.concatenate((TrainY_1, TrainY_2, TrainY_3, TrainY_4), axis=0)
TrainY = []

for img in TrainGroundTruth:
  encoded_img = convertToOneHot(img)
  TrainY.append(encoded_img)

TrainY = np.asarray(TrainY)

TestX = np.concatenate((TestX_1, TestX_2, TestX_3), axis=0)
TestGroundTruth = np.concatenate((TestY_1, TestY_2, TestY_3), axis=0)
TestY = []

for img in TestGroundTruth:
  encoded_img = convertToOneHot(img)
  TestY.append(encoded_img)

TestY = np.asarray(TestY)

ValidX = TrainX[1800:, : ]
ValidY = TrainY[1800:, : ]

TrainX = TrainX[0:1800, : ]
TrainY = TrainY[0:1800, : ]

print(TrainX.shape)
print(TrainY.shape)
print(TestX.shape)
print(TestY.shape)
print(ValidX.shape)
print(ValidY.shape)
np.unique(TestY)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 4)
# (1440, 240, 240, 3)
# (1440, 240, 240, 4)
# (120, 240, 240, 3)
# (120, 240, 240, 4)
# array([0, 1], dtype=uint8)

# %%
TrainX = np.reshape(TrainX,(-1,240, 240,3))
TrainY = np.reshape(TrainY,(-1,240, 240,4))

TrainX = TrainX.astype('float32')/255

TestX = np.reshape(TestX,(-1,240, 240,3))
TestY = np.reshape(TestY,(-1,240, 240,4))

TestX = TestX.astype('float32')/255

ValidX = np.reshape(ValidX,(-1,240, 240,3))
ValidY = np.reshape(ValidY,(-1,240, 240,4))

ValidX = ValidX.astype('float32')/255

# %%
print(TrainX.shape)
print(TrainY.shape)

print(TestX.shape)
print(TestY.shape)

print(ValidX.shape)
print(ValidY.shape)

np.unique(TestY)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 4)
# (1440, 240, 240, 3)
# (1440, 240, 240, 4)
# (120, 240, 240, 3)
# (120, 240, 240, 4)
# array([0, 1], dtype=uint8)

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

def dice_loss(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)
    return 1 - score

# %%
import math
from keras.callbacks import EarlyStopping,ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='auto', verbose=1, patience=30)
mc = ModelCheckpoint('Checkpoint.h5', monitor='val_loss', mode='auto', verbose=1, save_best_only=True)

# %%
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def combined_loss(y_true, y_pred):
  return (1*K.categorical_crossentropy(y_true, y_pred))+(1*dice_loss(y_true, y_pred))

def loss(y_true, y_pred):
  return (1*K.categorical_crossentropy(y_true, y_pred))

# %%
optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=True)

# %%
model.compile(loss= combined_loss, optimizer=optimizer, metrics=[dice_coef,'accuracy',tversky_loss, loss, combined_loss])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-1b873c568326> in <module>()
# ----> 1 model.compile(loss= combined_loss, optimizer=optimizer, metrics=[dice_coef,'accuracy',tversky_loss, loss, combined_loss])
#
# NameError: name 'combined_loss' is not defined

# %%
TrainY.shape

# %%
num_epoch = 100;
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER"
history = model.fit(TrainX, TrainY, epochs=num_epoch, validation_data=(ValidX, ValidY), shuffle=True,batch_size=16,callbacks=[es,mc])
model.save(MODELS_PATH + '/NestedUNET_ER_20_03_21_CombinedLossv2.h5')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1800 samples, validate on 120 samples
# Epoch 1/100
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1800/1800 [==============================] - 35s 19ms/step - loss: 1.5572 - dice_coef: 0.7535 - acc: 0.7697 - tversky_loss: 2.6948 - loss_1: 1.1446 - combined_loss: 1.3911 - val_loss: 0.3441 - val_dice_coef: 0.9885 - val_acc: 0.9885 - val_tversky_loss: 3.0058 - val_loss_1: 0.1853 - val_combined_loss: 0.1968
#
# Epoch 00001: val_loss improved from inf to 0.34414, saving model to Checkpoint.h5
# Epoch 2/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.7523 - dice_coef: 0.8416 - acc: 0.8614 - tversky_loss: 2.3781 - loss_1: 0.4628 - combined_loss: 0.6212 - val_loss: 0.3119 - val_dice_coef: 0.9885 - val_acc: 0.9885 - val_tversky_loss: 3.0058 - val_loss_1: 0.1843 - val_combined_loss: 0.1958
#
# Epoch 00002: val_loss improved from 0.34414 to 0.31188, saving model to Checkpoint.h5
# Epoch 3/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.6275 - dice_coef: 0.8539 - acc: 0.8800 - tversky_loss: 2.3271 - loss_1: 0.3771 - combined_loss: 0.5233 - val_loss: 0.2698 - val_dice_coef: 0.9886 - val_acc: 0.9885 - val_tversky_loss: 2.9897 - val_loss_1: 0.1650 - val_combined_loss: 0.1764
#
# Epoch 00003: val_loss improved from 0.31188 to 0.26983, saving model to Checkpoint.h5
# Epoch 4/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.5681 - dice_coef: 0.8588 - acc: 0.8888 - tversky_loss: 2.3128 - loss_1: 0.3419 - combined_loss: 0.4831 - val_loss: 0.1675 - val_dice_coef: 0.9877 - val_acc: 0.9877 - val_tversky_loss: 2.9277 - val_loss_1: 0.0781 - val_combined_loss: 0.0904
#
# Epoch 00004: val_loss improved from 0.26983 to 0.16753, saving model to Checkpoint.h5
# Epoch 5/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.5317 - dice_coef: 0.8615 - acc: 0.8950 - tversky_loss: 2.2984 - loss_1: 0.3222 - combined_loss: 0.4607 - val_loss: 0.1557 - val_dice_coef: 0.9871 - val_acc: 0.9874 - val_tversky_loss: 2.9172 - val_loss_1: 0.0774 - val_combined_loss: 0.0903
#
# Epoch 00005: val_loss improved from 0.16753 to 0.15567, saving model to Checkpoint.h5
# Epoch 6/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.4922 - dice_coef: 0.8661 - acc: 0.9016 - tversky_loss: 2.2820 - loss_1: 0.2976 - combined_loss: 0.4314 - val_loss: 0.1384 - val_dice_coef: 0.9876 - val_acc: 0.9879 - val_tversky_loss: 2.9115 - val_loss_1: 0.0695 - val_combined_loss: 0.0819
#
# Epoch 00006: val_loss improved from 0.15567 to 0.13843, saving model to Checkpoint.h5
# Epoch 7/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.4671 - dice_coef: 0.8698 - acc: 0.9072 - tversky_loss: 2.2660 - loss_1: 0.2838 - combined_loss: 0.4140 - val_loss: 0.1222 - val_dice_coef: 0.9876 - val_acc: 0.9881 - val_tversky_loss: 2.8607 - val_loss_1: 0.0600 - val_combined_loss: 0.0725
#
# Epoch 00007: val_loss improved from 0.13843 to 0.12224, saving model to Checkpoint.h5
# Epoch 8/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.4537 - dice_coef: 0.8715 - acc: 0.9101 - tversky_loss: 2.2509 - loss_1: 0.2780 - combined_loss: 0.4065 - val_loss: 0.1229 - val_dice_coef: 0.9880 - val_acc: 0.9882 - val_tversky_loss: 2.8940 - val_loss_1: 0.0662 - val_combined_loss: 0.0782
#
# Epoch 00008: val_loss did not improve from 0.12224
# Epoch 9/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.4350 - dice_coef: 0.8754 - acc: 0.9124 - tversky_loss: 2.2249 - loss_1: 0.2678 - combined_loss: 0.3924 - val_loss: 0.1035 - val_dice_coef: 0.9799 - val_acc: 0.9882 - val_tversky_loss: 2.8856 - val_loss_1: 0.0427 - val_combined_loss: 0.0628
#
# Epoch 00009: val_loss improved from 0.12224 to 0.10347, saving model to Checkpoint.h5
# Epoch 10/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.4275 - dice_coef: 0.8760 - acc: 0.9139 - tversky_loss: 2.2167 - loss_1: 0.2645 - combined_loss: 0.3885 - val_loss: 0.0928 - val_dice_coef: 0.9872 - val_acc: 0.9884 - val_tversky_loss: 2.8717 - val_loss_1: 0.0426 - val_combined_loss: 0.0554
#
# Epoch 00010: val_loss improved from 0.10347 to 0.09278, saving model to Checkpoint.h5
# Epoch 11/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.4158 - dice_coef: 0.8788 - acc: 0.9156 - tversky_loss: 2.1888 - loss_1: 0.2584 - combined_loss: 0.3796 - val_loss: 0.1020 - val_dice_coef: 0.9877 - val_acc: 0.9883 - val_tversky_loss: 2.8977 - val_loss_1: 0.0547 - val_combined_loss: 0.0670
#
# Epoch 00011: val_loss did not improve from 0.09278
# Epoch 12/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.4068 - dice_coef: 0.8811 - acc: 0.9165 - tversky_loss: 2.1756 - loss_1: 0.2539 - combined_loss: 0.3728 - val_loss: 0.0916 - val_dice_coef: 0.9821 - val_acc: 0.9869 - val_tversky_loss: 2.8416 - val_loss_1: 0.0408 - val_combined_loss: 0.0587
#
# Epoch 00012: val_loss improved from 0.09278 to 0.09156, saving model to Checkpoint.h5
# Epoch 13/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3952 - dice_coef: 0.8839 - acc: 0.9190 - tversky_loss: 2.1292 - loss_1: 0.2469 - combined_loss: 0.3631 - val_loss: 0.0858 - val_dice_coef: 0.9866 - val_acc: 0.9884 - val_tversky_loss: 2.8618 - val_loss_1: 0.0409 - val_combined_loss: 0.0543
#
# Epoch 00013: val_loss improved from 0.09156 to 0.08576, saving model to Checkpoint.h5
# Epoch 14/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3877 - dice_coef: 0.8863 - acc: 0.9207 - tversky_loss: 2.1035 - loss_1: 0.2429 - combined_loss: 0.3566 - val_loss: 0.1025 - val_dice_coef: 0.9763 - val_acc: 0.9884 - val_tversky_loss: 2.9336 - val_loss_1: 0.0484 - val_combined_loss: 0.0720
#
# Epoch 00014: val_loss did not improve from 0.08576
# Epoch 15/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3842 - dice_coef: 0.8876 - acc: 0.9211 - tversky_loss: 2.0858 - loss_1: 0.2416 - combined_loss: 0.3541 - val_loss: 0.1515 - val_dice_coef: 0.9526 - val_acc: 0.9856 - val_tversky_loss: 2.9234 - val_loss_1: 0.0746 - val_combined_loss: 0.1220
#
# Epoch 00015: val_loss did not improve from 0.08576
# Epoch 16/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3832 - dice_coef: 0.8881 - acc: 0.9213 - tversky_loss: 2.0877 - loss_1: 0.2423 - combined_loss: 0.3542 - val_loss: 0.1068 - val_dice_coef: 0.9711 - val_acc: 0.9874 - val_tversky_loss: 2.9111 - val_loss_1: 0.0495 - val_combined_loss: 0.0784
#
# Epoch 00016: val_loss did not improve from 0.08576
# Epoch 17/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3759 - dice_coef: 0.8900 - acc: 0.9219 - tversky_loss: 2.0663 - loss_1: 0.2379 - combined_loss: 0.3478 - val_loss: 0.1110 - val_dice_coef: 0.9698 - val_acc: 0.9883 - val_tversky_loss: 2.9408 - val_loss_1: 0.0532 - val_combined_loss: 0.0834
#
# Epoch 00017: val_loss did not improve from 0.08576
# Epoch 18/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3680 - dice_coef: 0.8914 - acc: 0.9226 - tversky_loss: 2.0501 - loss_1: 0.2325 - combined_loss: 0.3411 - val_loss: 0.1449 - val_dice_coef: 0.9508 - val_acc: 0.9883 - val_tversky_loss: 2.9611 - val_loss_1: 0.0694 - val_combined_loss: 0.1187
#
# Epoch 00018: val_loss did not improve from 0.08576
# Epoch 19/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3702 - dice_coef: 0.8912 - acc: 0.9221 - tversky_loss: 2.0623 - loss_1: 0.2353 - combined_loss: 0.3441 - val_loss: 0.1850 - val_dice_coef: 0.9314 - val_acc: 0.9875 - val_tversky_loss: 2.9790 - val_loss_1: 0.0904 - val_combined_loss: 0.1590
#
# Epoch 00019: val_loss did not improve from 0.08576
# Epoch 20/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3691 - dice_coef: 0.8913 - acc: 0.9215 - tversky_loss: 2.0666 - loss_1: 0.2349 - combined_loss: 0.3436 - val_loss: 0.1596 - val_dice_coef: 0.9426 - val_acc: 0.9878 - val_tversky_loss: 2.9645 - val_loss_1: 0.0773 - val_combined_loss: 0.1346
#
# Epoch 00020: val_loss did not improve from 0.08576
# Epoch 21/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3654 - dice_coef: 0.8924 - acc: 0.9229 - tversky_loss: 2.0405 - loss_1: 0.2331 - combined_loss: 0.3408 - val_loss: 0.3854 - val_dice_coef: 0.8426 - val_acc: 0.9768 - val_tversky_loss: 3.0402 - val_loss_1: 0.2038 - val_combined_loss: 0.3612
#
# Epoch 00021: val_loss did not improve from 0.08576
# Epoch 22/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3624 - dice_coef: 0.8928 - acc: 0.9227 - tversky_loss: 2.0402 - loss_1: 0.2312 - combined_loss: 0.3383 - val_loss: 0.1227 - val_dice_coef: 0.9614 - val_acc: 0.9881 - val_tversky_loss: 2.9527 - val_loss_1: 0.0604 - val_combined_loss: 0.0991
#
# Epoch 00022: val_loss did not improve from 0.08576
# Epoch 23/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3596 - dice_coef: 0.8934 - acc: 0.9231 - tversky_loss: 2.0417 - loss_1: 0.2296 - combined_loss: 0.3362 - val_loss: 0.1342 - val_dice_coef: 0.9550 - val_acc: 0.9882 - val_tversky_loss: 2.9622 - val_loss_1: 0.0660 - val_combined_loss: 0.1110
#
# Epoch 00023: val_loss did not improve from 0.08576
# Epoch 24/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3601 - dice_coef: 0.8934 - acc: 0.9226 - tversky_loss: 2.0460 - loss_1: 0.2305 - combined_loss: 0.3371 - val_loss: 0.2244 - val_dice_coef: 0.9103 - val_acc: 0.9881 - val_tversky_loss: 2.9994 - val_loss_1: 0.1119 - val_combined_loss: 0.2016
#
# Epoch 00024: val_loss did not improve from 0.08576
# Epoch 25/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3586 - dice_coef: 0.8938 - acc: 0.9230 - tversky_loss: 2.0360 - loss_1: 0.2297 - combined_loss: 0.3359 - val_loss: 0.1893 - val_dice_coef: 0.9270 - val_acc: 0.9876 - val_tversky_loss: 2.9812 - val_loss_1: 0.0939 - val_combined_loss: 0.1669
#
# Epoch 00025: val_loss did not improve from 0.08576
# Epoch 26/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3555 - dice_coef: 0.8949 - acc: 0.9234 - tversky_loss: 2.0314 - loss_1: 0.2284 - combined_loss: 0.3334 - val_loss: 0.1282 - val_dice_coef: 0.9569 - val_acc: 0.9882 - val_tversky_loss: 2.9515 - val_loss_1: 0.0634 - val_combined_loss: 0.1064
#
# Epoch 00026: val_loss did not improve from 0.08576
# Epoch 27/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3535 - dice_coef: 0.8949 - acc: 0.9235 - tversky_loss: 2.0243 - loss_1: 0.2267 - combined_loss: 0.3318 - val_loss: 0.1878 - val_dice_coef: 0.9277 - val_acc: 0.9876 - val_tversky_loss: 2.9813 - val_loss_1: 0.0942 - val_combined_loss: 0.1664
#
# Epoch 00027: val_loss did not improve from 0.08576
# Epoch 28/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3560 - dice_coef: 0.8942 - acc: 0.9229 - tversky_loss: 2.0377 - loss_1: 0.2288 - combined_loss: 0.3345 - val_loss: 0.3475 - val_dice_coef: 0.8526 - val_acc: 0.9860 - val_tversky_loss: 3.0378 - val_loss_1: 0.1788 - val_combined_loss: 0.3262
#
# Epoch 00028: val_loss did not improve from 0.08576
# Epoch 29/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3579 - dice_coef: 0.8944 - acc: 0.9234 - tversky_loss: 2.0288 - loss_1: 0.2313 - combined_loss: 0.3369 - val_loss: 0.0818 - val_dice_coef: 0.9840 - val_acc: 0.9885 - val_tversky_loss: 2.9374 - val_loss_1: 0.0451 - val_combined_loss: 0.0611
#
# Epoch 00029: val_loss improved from 0.08576 to 0.08184, saving model to Checkpoint.h5
# Epoch 30/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3574 - dice_coef: 0.8943 - acc: 0.9228 - tversky_loss: 2.0409 - loss_1: 0.2310 - combined_loss: 0.3367 - val_loss: 0.1892 - val_dice_coef: 0.9265 - val_acc: 0.9880 - val_tversky_loss: 2.9845 - val_loss_1: 0.0951 - val_combined_loss: 0.1686
#
# Epoch 00030: val_loss did not improve from 0.08184
# Epoch 31/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3486 - dice_coef: 0.8965 - acc: 0.9240 - tversky_loss: 2.0137 - loss_1: 0.2247 - combined_loss: 0.3282 - val_loss: 0.1773 - val_dice_coef: 0.9322 - val_acc: 0.9882 - val_tversky_loss: 2.9840 - val_loss_1: 0.0893 - val_combined_loss: 0.1571
#
# Epoch 00031: val_loss did not improve from 0.08184
# Epoch 32/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3501 - dice_coef: 0.8955 - acc: 0.9234 - tversky_loss: 2.0235 - loss_1: 0.2255 - combined_loss: 0.3300 - val_loss: 0.1882 - val_dice_coef: 0.9264 - val_acc: 0.9873 - val_tversky_loss: 2.9817 - val_loss_1: 0.0945 - val_combined_loss: 0.1681
#
# Epoch 00032: val_loss did not improve from 0.08184
# Epoch 33/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3481 - dice_coef: 0.8963 - acc: 0.9242 - tversky_loss: 2.0114 - loss_1: 0.2245 - combined_loss: 0.3282 - val_loss: 0.2594 - val_dice_coef: 0.8929 - val_acc: 0.9866 - val_tversky_loss: 3.0086 - val_loss_1: 0.1326 - val_combined_loss: 0.2397
#
# Epoch 00033: val_loss did not improve from 0.08184
# Epoch 34/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3461 - dice_coef: 0.8969 - acc: 0.9244 - tversky_loss: 2.0041 - loss_1: 0.2234 - combined_loss: 0.3265 - val_loss: 0.1274 - val_dice_coef: 0.9578 - val_acc: 0.9885 - val_tversky_loss: 2.9752 - val_loss_1: 0.0657 - val_combined_loss: 0.1079
#
# Epoch 00034: val_loss did not improve from 0.08184
# Epoch 35/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3498 - dice_coef: 0.8963 - acc: 0.9237 - tversky_loss: 2.0152 - loss_1: 0.2268 - combined_loss: 0.3305 - val_loss: 0.1238 - val_dice_coef: 0.9581 - val_acc: 0.9883 - val_tversky_loss: 2.9592 - val_loss_1: 0.0627 - val_combined_loss: 0.1046
#
# Epoch 00035: val_loss did not improve from 0.08184
# Epoch 36/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3477 - dice_coef: 0.8962 - acc: 0.9239 - tversky_loss: 2.0188 - loss_1: 0.2248 - combined_loss: 0.3286 - val_loss: 0.2096 - val_dice_coef: 0.9168 - val_acc: 0.9884 - val_tversky_loss: 3.0012 - val_loss_1: 0.1074 - val_combined_loss: 0.1906
#
# Epoch 00036: val_loss did not improve from 0.08184
# Epoch 37/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3447 - dice_coef: 0.8972 - acc: 0.9245 - tversky_loss: 1.9979 - loss_1: 0.2230 - combined_loss: 0.3258 - val_loss: 0.3915 - val_dice_coef: 0.8343 - val_acc: 0.9791 - val_tversky_loss: 3.0449 - val_loss_1: 0.2070 - val_combined_loss: 0.3727
#
# Epoch 00037: val_loss did not improve from 0.08184
# Epoch 38/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3460 - dice_coef: 0.8968 - acc: 0.9238 - tversky_loss: 2.0184 - loss_1: 0.2241 - combined_loss: 0.3273 - val_loss: 0.2403 - val_dice_coef: 0.9022 - val_acc: 0.9882 - val_tversky_loss: 3.0120 - val_loss_1: 0.1238 - val_combined_loss: 0.2217
#
# Epoch 00038: val_loss did not improve from 0.08184
# Epoch 39/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3430 - dice_coef: 0.8973 - acc: 0.9244 - tversky_loss: 2.0084 - loss_1: 0.2218 - combined_loss: 0.3244 - val_loss: 0.2033 - val_dice_coef: 0.9188 - val_acc: 0.9877 - val_tversky_loss: 2.9903 - val_loss_1: 0.1035 - val_combined_loss: 0.1847
#
# Epoch 00039: val_loss did not improve from 0.08184
# Epoch 40/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3425 - dice_coef: 0.8972 - acc: 0.9244 - tversky_loss: 2.0103 - loss_1: 0.2212 - combined_loss: 0.3240 - val_loss: 0.2009 - val_dice_coef: 0.9199 - val_acc: 0.9876 - val_tversky_loss: 2.9892 - val_loss_1: 0.1023 - val_combined_loss: 0.1825
#
# Epoch 00040: val_loss did not improve from 0.08184
# Epoch 41/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3473 - dice_coef: 0.8970 - acc: 0.9239 - tversky_loss: 2.0113 - loss_1: 0.2260 - combined_loss: 0.3289 - val_loss: 0.2137 - val_dice_coef: 0.9143 - val_acc: 0.9879 - val_tversky_loss: 2.9966 - val_loss_1: 0.1096 - val_combined_loss: 0.1954
#
# Epoch 00041: val_loss did not improve from 0.08184
# Epoch 42/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3435 - dice_coef: 0.8972 - acc: 0.9239 - tversky_loss: 2.0158 - loss_1: 0.2223 - combined_loss: 0.3252 - val_loss: 0.1481 - val_dice_coef: 0.9467 - val_acc: 0.9884 - val_tversky_loss: 2.9789 - val_loss_1: 0.0764 - val_combined_loss: 0.1297
#
# Epoch 00042: val_loss did not improve from 0.08184
# Epoch 43/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3429 - dice_coef: 0.8974 - acc: 0.9243 - tversky_loss: 2.0085 - loss_1: 0.2220 - combined_loss: 0.3246 - val_loss: 0.4580 - val_dice_coef: 0.8030 - val_acc: 0.9844 - val_tversky_loss: 3.0715 - val_loss_1: 0.2427 - val_combined_loss: 0.4397
#
# Epoch 00043: val_loss did not improve from 0.08184
# Epoch 44/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3427 - dice_coef: 0.8975 - acc: 0.9241 - tversky_loss: 2.0121 - loss_1: 0.2221 - combined_loss: 0.3246 - val_loss: 0.2261 - val_dice_coef: 0.9073 - val_acc: 0.9883 - val_tversky_loss: 3.0047 - val_loss_1: 0.1153 - val_combined_loss: 0.2080
#
# Epoch 00044: val_loss did not improve from 0.08184
# Epoch 45/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3420 - dice_coef: 0.8980 - acc: 0.9246 - tversky_loss: 2.0033 - loss_1: 0.2221 - combined_loss: 0.3241 - val_loss: 0.2162 - val_dice_coef: 0.9131 - val_acc: 0.9882 - val_tversky_loss: 3.0001 - val_loss_1: 0.1113 - val_combined_loss: 0.1982
#
# Epoch 00045: val_loss did not improve from 0.08184
# Epoch 46/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3420 - dice_coef: 0.8980 - acc: 0.9246 - tversky_loss: 2.0019 - loss_1: 0.2221 - combined_loss: 0.3240 - val_loss: 0.2785 - val_dice_coef: 0.8836 - val_acc: 0.9858 - val_tversky_loss: 3.0145 - val_loss_1: 0.1441 - val_combined_loss: 0.2605
#
# Epoch 00046: val_loss did not improve from 0.08184
# Epoch 47/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3420 - dice_coef: 0.8980 - acc: 0.9244 - tversky_loss: 2.0018 - loss_1: 0.2221 - combined_loss: 0.3241 - val_loss: 0.2777 - val_dice_coef: 0.8828 - val_acc: 0.9869 - val_tversky_loss: 3.0140 - val_loss_1: 0.1427 - val_combined_loss: 0.2599
#
# Epoch 00047: val_loss did not improve from 0.08184
# Epoch 48/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3401 - dice_coef: 0.8985 - acc: 0.9252 - tversky_loss: 1.9920 - loss_1: 0.2209 - combined_loss: 0.3224 - val_loss: 0.2593 - val_dice_coef: 0.8927 - val_acc: 0.9870 - val_tversky_loss: 3.0141 - val_loss_1: 0.1342 - val_combined_loss: 0.2415
#
# Epoch 00048: val_loss did not improve from 0.08184
# Epoch 49/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3416 - dice_coef: 0.8983 - acc: 0.9250 - tversky_loss: 1.9964 - loss_1: 0.2222 - combined_loss: 0.3239 - val_loss: 0.1849 - val_dice_coef: 0.9274 - val_acc: 0.9885 - val_tversky_loss: 2.9969 - val_loss_1: 0.0949 - val_combined_loss: 0.1674
#
# Epoch 00049: val_loss did not improve from 0.08184
# Epoch 50/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3384 - dice_coef: 0.8988 - acc: 0.9250 - tversky_loss: 1.9878 - loss_1: 0.2197 - combined_loss: 0.3209 - val_loss: 0.3018 - val_dice_coef: 0.8715 - val_acc: 0.9882 - val_tversky_loss: 3.0319 - val_loss_1: 0.1559 - val_combined_loss: 0.2844
#
# Epoch 00050: val_loss did not improve from 0.08184
# Epoch 51/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3409 - dice_coef: 0.8982 - acc: 0.9250 - tversky_loss: 1.9939 - loss_1: 0.2216 - combined_loss: 0.3234 - val_loss: 0.1960 - val_dice_coef: 0.9214 - val_acc: 0.9883 - val_tversky_loss: 2.9920 - val_loss_1: 0.0997 - val_combined_loss: 0.1784
#
# Epoch 00051: val_loss did not improve from 0.08184
# Epoch 52/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3400 - dice_coef: 0.8986 - acc: 0.9251 - tversky_loss: 1.9903 - loss_1: 0.2212 - combined_loss: 0.3225 - val_loss: 0.1683 - val_dice_coef: 0.9348 - val_acc: 0.9885 - val_tversky_loss: 2.9871 - val_loss_1: 0.0858 - val_combined_loss: 0.1509
#
# Epoch 00052: val_loss did not improve from 0.08184
# Epoch 53/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3399 - dice_coef: 0.8989 - acc: 0.9251 - tversky_loss: 1.9950 - loss_1: 0.2215 - combined_loss: 0.3226 - val_loss: 0.1399 - val_dice_coef: 0.9499 - val_acc: 0.9882 - val_tversky_loss: 2.9693 - val_loss_1: 0.0725 - val_combined_loss: 0.1226
#
# Epoch 00053: val_loss did not improve from 0.08184
# Epoch 54/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3388 - dice_coef: 0.8985 - acc: 0.9249 - tversky_loss: 1.9975 - loss_1: 0.2200 - combined_loss: 0.3215 - val_loss: 0.2284 - val_dice_coef: 0.9078 - val_acc: 0.9878 - val_tversky_loss: 3.0083 - val_loss_1: 0.1190 - val_combined_loss: 0.2112
#
# Epoch 00054: val_loss did not improve from 0.08184
# Epoch 55/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3373 - dice_coef: 0.8990 - acc: 0.9252 - tversky_loss: 1.9935 - loss_1: 0.2191 - combined_loss: 0.3201 - val_loss: 0.2558 - val_dice_coef: 0.8932 - val_acc: 0.9871 - val_tversky_loss: 3.0104 - val_loss_1: 0.1319 - val_combined_loss: 0.2387
#
# Epoch 00055: val_loss did not improve from 0.08184
# Epoch 56/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3398 - dice_coef: 0.8982 - acc: 0.9242 - tversky_loss: 2.0058 - loss_1: 0.2208 - combined_loss: 0.3227 - val_loss: 0.1805 - val_dice_coef: 0.9289 - val_acc: 0.9883 - val_tversky_loss: 2.9901 - val_loss_1: 0.0923 - val_combined_loss: 0.1634
#
# Epoch 00056: val_loss did not improve from 0.08184
# Epoch 57/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3333 - dice_coef: 0.8999 - acc: 0.9261 - tversky_loss: 1.9688 - loss_1: 0.2163 - combined_loss: 0.3163 - val_loss: 0.3005 - val_dice_coef: 0.8715 - val_acc: 0.9877 - val_tversky_loss: 3.0252 - val_loss_1: 0.1551 - val_combined_loss: 0.2836
#
# Epoch 00057: val_loss did not improve from 0.08184
# Epoch 58/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3365 - dice_coef: 0.8997 - acc: 0.9257 - tversky_loss: 1.9796 - loss_1: 0.2193 - combined_loss: 0.3196 - val_loss: 0.2677 - val_dice_coef: 0.8876 - val_acc: 0.9870 - val_tversky_loss: 3.0145 - val_loss_1: 0.1383 - val_combined_loss: 0.2508
#
# Epoch 00058: val_loss did not improve from 0.08184
# Epoch 59/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 0.3373 - dice_coef: 0.8987 - acc: 0.9252 - tversky_loss: 1.9932 - loss_1: 0.2191 - combined_loss: 0.3204 - val_loss: 0.5116 - val_dice_coef: 0.7824 - val_acc: 0.9727 - val_tversky_loss: 3.0819 - val_loss_1: 0.2771 - val_combined_loss: 0.4947
#
# Epoch 00059: val_loss did not improve from 0.08184
# Epoch 00059: early stopping

# %%
train_loss = history.history['loss']
train_acc = history.history['acc']
val_loss = history.history['val_loss']
val_acc = history.history['val_acc']
xc=range(len(train_loss))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_loss)
plt.plot(xc, val_loss)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(['train','val'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_acc)
plt.plot(xc, val_acc)
plt.xlabel("Epoch")
plt.ylabel("Acc")
plt.legend(['train','val'])

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER"
model = keras.models.load_model(MODELS_PATH+'/NestedUNET_ER_20_03_21_CombinedLossv2.h5',custom_objects={ 'loss' : loss , 'tversky_loss' : tversky_loss,'combined_loss': combined_loss, 'dice_coef': dice_coef })
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.

# %%
# Function to find the most probable class of an image pixel by pixel
def ClassFinder(img):
  result = np.zeros(img.shape, dtype=np.uint8)
  for r in range(len(img)):
    for c in range(len(img[0])):
      idx = np.argmax(img[r][c])
      result[r][c][idx]=1
      
  return result

# %%
train_result = model.predict(TrainX, batch_size=16)
print(np.shape(train_result))
Train_predict = [ ]
for img in train_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_predict.append(encoded_img)

Predicted_images = np.asarray(Train_predict)
print(Predicted_images.shape)
np.unique(Predicted_images)
# dice = dc(train_result, TrainY)
# pre  = precision(train_result,TrainY)
# re   = recall(train_result,TrainY)
# print('Train dc: '  + str(dice))
# print('Train pre: ' + str(pre))
# print('Train re: '  + str(re))
# Out:
# (1800, 240, 240, 4)
# (1800, 240, 240)
# array([  0, 170, 255], dtype=uint8)

# %%
test_result = model.predict(TestX, batch_size=16)
print(np.shape(test_result))

Test_predict = [ ]
for img in test_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_predict.append(encoded_img)

Predicted_images_test = np.asarray(Test_predict)
print(Predicted_images_test.shape)
np.unique(Predicted_images_test)
# dice = dc(test_result, TestY)
# pre  = precision(test_result,TestY)
# re   = recall(test_result,TestY)
# print('Test dc: '  + str(dice))
# print('Test pre: ' + str(pre))
# print('Test re: '  + str(re))
# Out:
# (1440, 240, 240, 4)
# (1440, 240, 240)
# array([  0, 170, 255], dtype=uint8)

# %%
from sklearn.metrics import confusion_matrix
def get_confusion_matrix(Actual, Predicted):
  ActualY = np.reshape(Actual,(-1, Actual.shape[3]))
  PredY = np.reshape(Predicted,(-1, Predicted.shape[3]))
  matrix = confusion_matrix(ActualY.argmax(axis = 1), PredY.argmax(axis = 1))
  return matrix

def get_precision(confusion_matrix):
  precision = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 0)
  nan_indices = np.isnan(precision)
  precision[nan_indices] = 0
  return precision

def get_recall(confusion_matrix):
  recall = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 1)
  nan_indices = np.isnan(recall)
  recall[nan_indices] = 0
  return recall

# %%
test_matrix = get_confusion_matrix(TestY, test_result)
train_matrix = get_confusion_matrix(TrainY, train_result)
print(test_matrix)
print(train_matrix)
# TestY.shape[3]
# test_result.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5734c1d7d1c9> in <module>()
# ----> 1 test_matrix = get_confusion_matrix(TestY, test_result)
#       2 train_matrix = get_confusion_matrix(TrainY, train_result)
#       3 print(test_matrix)
#       4 print(train_matrix)
#       5 # TestY.shape[3]
#
# NameError: name 'TestY' is not defined

# %%
np.unique(Predicted_images_test)
# Out:
# array([  0, 170, 255], dtype=uint8)

# %%
test_precision = get_precision(test_matrix)
print('Test Precision')
print(test_precision)
test_recall = get_recall(test_matrix)
print('Test Recall')
print(test_recall)
train_precision = get_precision(train_matrix)
print('Train Precision')
print(train_precision)
train_recall = get_recall(train_matrix)
print('Train Recall')
print(train_recall)

# %%
# weight_matrix = np.zeros((3,1))
# weight_matrix[0] = 0.6
# weight_matrix[1] = 0.2
# weight_matrix[2] = 0.2
# print(weight_matrix.shape)

# %%
weight_matrix = np.zeros((4,1))
weight_matrix[0] = 1/3
weight_matrix[1] = 1/3
weight_matrix[2] = 1/3
weight_matrix[3] = 1/3
print(weight_matrix.shape)

# %%
def get_overall_precision(precision, weights):
  final_precision = np.dot(precision,weights)
  return final_precision

def get_overall_recall(recall, weights):
  final_recall = np.dot(recall ,weights)
  return final_recall

# %%
final_test_precision  = get_overall_precision(test_precision, weight_matrix)
final_test_recall     = get_overall_recall(test_recall, weight_matrix)
final_train_precision = get_overall_precision(train_precision, weight_matrix)
final_train_recall    = get_overall_recall(train_recall, weight_matrix)
print('Final Test Precision')
print(final_test_precision)
print('Final Test Recall')
print(final_test_recall)
print('Final Train Precision')
print(final_train_precision)
print('Final Train Recall')
print(final_train_recall)

# %%
from scipy.stats import hmean

def dice_coefficient(precision, recall):
  return hmean(np.asarray([precision , recall]))

# %%
test_dice_coeff = dice_coefficient(final_test_precision, final_test_recall)
print('Test Dice coeff')
print(test_dice_coeff)

train_dice_coeff = dice_coefficient(final_train_precision, final_train_recall)
print('Train Dice coeff')
print(train_dice_coeff)

# %%
copy1  = np.copy(TestX [250])
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
copy3 = np.reshape(copy2,(240, 240,3))
Img = cv2.cvtColor(copy3,cv2.COLOR_BGR2RGB)

Mask = TestGroundTruth[250]

Predicted_Mask = Predicted_images_test[250] 

plt.subplot(131).imshow(Img)
plt.subplot(132).imshow(Mask,'gray')
plt.subplot(133).imshow(Predicted_Mask,'gray')

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask):
  num = mask.shape[0]/480
  for id in range(int(num)):
    temp = []
    for i in range(id, id+10):
      idx = i * 48
      final_output = mask[idx:idx+48]
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save("/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/Combined_Loss/ER1 Patient " + str(id), final_output)

# %%
# saving predicted outputs as numpy arrays for test images
saveNumpyOutput(Predicted_images)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 20   # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]

Mask_input = TestY[id:id+48]
Test_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Test_Actual)
print(Mask_input.shape)

final_output = Predicted_images_test[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 4)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0. 170. 255.]

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 19  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]

Mask_input = TrainY[id:id+48]
Train_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Train_Actual)
print(Mask_input.shape)

final_output = Predicted_images[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 4)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0. 170. 255.]
