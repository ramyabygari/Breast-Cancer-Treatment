# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from keras.layers import Activation,Conv2D,MaxPooling2D,UpSampling2D,Dense,BatchNormalization,Input,Reshape,multiply,add,Dropout,AveragePooling2D,GlobalAveragePooling2D,concatenate
from keras.layers.convolutional import Conv2DTranspose
from keras.models import Model														  
import keras.backend as K
from keras.regularizers import l2
from keras.engine import Layer,InputSpec
from keras.utils import conv_utils
from keras.layers import Activation,Conv2D,MaxPooling2D,UpSampling2D,Dense,BatchNormalization,Input,Reshape,multiply,add,Dropout,AveragePooling2D,GlobalAveragePooling2D,concatenate
from keras.layers.convolutional import Conv2DTranspose
from keras.models import Model														  
import keras.backend as K
from keras.regularizers import l2
from keras.engine import Layer,InputSpec
from keras.utils import conv_utils
# !pip install medpy
from keras.layers import *
from keras.models import Sequential
from statistics import mean 
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from medpy.metric import dc, precision, recall
import keras
# Out:
# Requirement already satisfied: medpy in /usr/local/lib/python3.6/dist-packages (0.4.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.18.2)
# Requirement already satisfied: SimpleITK>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.2.4)

# %%
smooth = 1.
dropout_rate = 0.5
def standard_unit(input_tensor, stage, nb_filter, kernel_size=3):

    act = 'elu'

    x = Conv2D(nb_filter, (kernel_size, kernel_size), activation=act, name='conv'+stage+'_1', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(input_tensor)
    x = Dropout(dropout_rate, name='dp'+stage+'_1')(x)
    x = Conv2D(nb_filter, (kernel_size, kernel_size), activation=act, name='conv'+stage+'_2', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(x)
    x = Dropout(dropout_rate, name='dp'+stage+'_2')(x)

    return x

# %%
def Nest_Net(img_rows, img_cols, color_type=3, num_class=4, deep_supervision=False):

    nb_filter = [8,16,32,64,128]
    act = 'elu'
  
    bn_axis = 3
    
    
    img_input = Input(shape=(img_rows, img_cols, color_type), name='main_input')
    conv1_1 = standard_unit(img_input, stage='11', nb_filter=nb_filter[0])
    pool1 = MaxPooling2D((2, 2), strides=(2, 2), name='pool1')(conv1_1)

    conv2_1 = standard_unit(pool1, stage='21', nb_filter=nb_filter[1])
    pool2 = MaxPooling2D((2, 2), strides=(2, 2), name='pool2')(conv2_1)

    up1_2 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up12', padding='same')(conv2_1)
    conv1_2 = concatenate([up1_2, conv1_1], name='merge12', axis=bn_axis)
    conv1_2 = standard_unit(conv1_2, stage='12', nb_filter=nb_filter[0])

    conv3_1 = standard_unit(pool2, stage='31', nb_filter=nb_filter[2])
    pool3 = MaxPooling2D((2, 2), strides=(2, 2), name='pool3')(conv3_1)

    up2_2 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up22', padding='same')(conv3_1)
    conv2_2 = concatenate([up2_2, conv2_1], name='merge22', axis=bn_axis)
    conv2_2 = standard_unit(conv2_2, stage='22', nb_filter=nb_filter[1])

    up1_3 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up13', padding='same')(conv2_2)
    conv1_3 = concatenate([up1_3, conv1_1, conv1_2], name='merge13', axis=bn_axis)
    conv1_3 = standard_unit(conv1_3, stage='13', nb_filter=nb_filter[0])

    conv4_1 = standard_unit(pool3, stage='41', nb_filter=nb_filter[3])
    pool4 = MaxPooling2D((2, 2), strides=(2, 2), name='pool4')(conv4_1)

    up3_2 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up32', padding='same')(conv4_1)
    conv3_2 = concatenate([up3_2, conv3_1], name='merge32', axis=bn_axis)
    conv3_2 = standard_unit(conv3_2, stage='32', nb_filter=nb_filter[2])

    up2_3 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up23', padding='same')(conv3_2)
    conv2_3 = concatenate([up2_3, conv2_1, conv2_2], name='merge23', axis=bn_axis)
    conv2_3 = standard_unit(conv2_3, stage='23', nb_filter=nb_filter[1])

    up1_4 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up14', padding='same')(conv2_3)
    conv1_4 = concatenate([up1_4, conv1_1, conv1_2, conv1_3], name='merge14', axis=bn_axis)
    conv1_4 = standard_unit(conv1_4, stage='14', nb_filter=nb_filter[0])

    conv5_1 = standard_unit(pool4, stage='51', nb_filter=nb_filter[4])

    up4_2 = Conv2DTranspose(nb_filter[3], (2, 2), strides=(2, 2), name='up42', padding='same')(conv5_1)
    conv4_2 = concatenate([up4_2, conv4_1], name='merge42', axis=bn_axis)
    conv4_2 = standard_unit(conv4_2, stage='42', nb_filter=nb_filter[3])

    up3_3 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up33', padding='same')(conv4_2)
    conv3_3 = concatenate([up3_3, conv3_1, conv3_2], name='merge33', axis=bn_axis)
    conv3_3 = standard_unit(conv3_3, stage='33', nb_filter=nb_filter[2])

    up2_4 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up24', padding='same')(conv3_3)
    conv2_4 = concatenate([up2_4, conv2_1, conv2_2, conv2_3], name='merge24', axis=bn_axis)
    conv2_4 = standard_unit(conv2_4, stage='24', nb_filter=nb_filter[1])

    up1_5 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up15', padding='same')(conv2_4)
    conv1_5 = concatenate([up1_5, conv1_1, conv1_2, conv1_3, conv1_4], name='merge15', axis=bn_axis)
    conv1_5 = standard_unit(conv1_5, stage='15', nb_filter=nb_filter[0])

    nestnet_output_1 = Conv2D(num_class, (1, 1), activation='softmax', name='output_1', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_2)
    nestnet_output_2 = Conv2D(num_class, (1, 1), activation='softmax', name='output_2', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_3)
    nestnet_output_3 = Conv2D(num_class, (1, 1), activation='softmax', name='output_3', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_4)
    nestnet_output_4 = Conv2D(num_class, (1, 1), activation='softmax', name='output_4', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_5)

    if deep_supervision:
        model = Model(input=img_input, output=[nestnet_output_1,
                                               nestnet_output_2,
                                               nestnet_output_3,
                                               nestnet_output_4])
    else:
        model = Model(input=img_input, output=[nestnet_output_4])

    return model

# %%
model = Nest_Net(240,240,3)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 240, 240, 3)  0
# __________________________________________________________________________________________________
# conv11_1 (Conv2D)               (None, 240, 240, 8)  224         main_input[0][0]
# __________________________________________________________________________________________________
# dp11_1 (Dropout)                (None, 240, 240, 8)  0           conv11_1[0][0]
# __________________________________________________________________________________________________
# conv11_2 (Conv2D)               (None, 240, 240, 8)  584         dp11_1[0][0]
# __________________________________________________________________________________________________
# dp11_2 (Dropout)                (None, 240, 240, 8)  0           conv11_2[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 120, 120, 8)  0           dp11_2[0][0]
# __________________________________________________________________________________________________
# conv21_1 (Conv2D)               (None, 120, 120, 16) 1168        pool1[0][0]
# __________________________________________________________________________________________________
# dp21_1 (Dropout)                (None, 120, 120, 16) 0           conv21_1[0][0]
# __________________________________________________________________________________________________
# conv21_2 (Conv2D)               (None, 120, 120, 16) 2320        dp21_1[0][0]
# __________________________________________________________________________________________________
# dp21_2 (Dropout)                (None, 120, 120, 16) 0           conv21_2[0][0]
# __________________________________________________________________________________________________
# pool2 (MaxPooling2D)            (None, 60, 60, 16)   0           dp21_2[0][0]
# __________________________________________________________________________________________________
# conv31_1 (Conv2D)               (None, 60, 60, 32)   4640        pool2[0][0]
# __________________________________________________________________________________________________
# dp31_1 (Dropout)                (None, 60, 60, 32)   0           conv31_1[0][0]
# __________________________________________________________________________________________________
# conv31_2 (Conv2D)               (None, 60, 60, 32)   9248        dp31_1[0][0]
# __________________________________________________________________________________________________
# dp31_2 (Dropout)                (None, 60, 60, 32)   0           conv31_2[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 30, 30, 32)   0           dp31_2[0][0]
# __________________________________________________________________________________________________
# conv41_1 (Conv2D)               (None, 30, 30, 64)   18496       pool3[0][0]
# __________________________________________________________________________________________________
# dp41_1 (Dropout)                (None, 30, 30, 64)   0           conv41_1[0][0]
# __________________________________________________________________________________________________
# conv41_2 (Conv2D)               (None, 30, 30, 64)   36928       dp41_1[0][0]
# __________________________________________________________________________________________________
# dp41_2 (Dropout)                (None, 30, 30, 64)   0           conv41_2[0][0]
# __________________________________________________________________________________________________
# pool4 (MaxPooling2D)            (None, 15, 15, 64)   0           dp41_2[0][0]
# __________________________________________________________________________________________________
# conv51_1 (Conv2D)               (None, 15, 15, 128)  73856       pool4[0][0]
# __________________________________________________________________________________________________
# dp51_1 (Dropout)                (None, 15, 15, 128)  0           conv51_1[0][0]
# __________________________________________________________________________________________________
# conv51_2 (Conv2D)               (None, 15, 15, 128)  147584      dp51_1[0][0]
# __________________________________________________________________________________________________
# dp51_2 (Dropout)                (None, 15, 15, 128)  0           conv51_2[0][0]
# __________________________________________________________________________________________________
# up42 (Conv2DTranspose)          (None, 30, 30, 64)   32832       dp51_2[0][0]
# __________________________________________________________________________________________________
# merge42 (Concatenate)           (None, 30, 30, 128)  0           up42[0][0]
#                                                                  dp41_2[0][0]
# __________________________________________________________________________________________________
# up32 (Conv2DTranspose)          (None, 60, 60, 32)   8224        dp41_2[0][0]
# __________________________________________________________________________________________________
# conv42_1 (Conv2D)               (None, 30, 30, 64)   73792       merge42[0][0]
# __________________________________________________________________________________________________
# merge32 (Concatenate)           (None, 60, 60, 64)   0           up32[0][0]
#                                                                  dp31_2[0][0]
# __________________________________________________________________________________________________
# up22 (Conv2DTranspose)          (None, 120, 120, 16) 2064        dp31_2[0][0]
# __________________________________________________________________________________________________
# dp42_1 (Dropout)                (None, 30, 30, 64)   0           conv42_1[0][0]
# __________________________________________________________________________________________________
# conv32_1 (Conv2D)               (None, 60, 60, 32)   18464       merge32[0][0]
# __________________________________________________________________________________________________
# merge22 (Concatenate)           (None, 120, 120, 32) 0           up22[0][0]
#                                                                  dp21_2[0][0]
# __________________________________________________________________________________________________
# up12 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp21_2[0][0]
# __________________________________________________________________________________________________
# conv42_2 (Conv2D)               (None, 30, 30, 64)   36928       dp42_1[0][0]
# __________________________________________________________________________________________________
# dp32_1 (Dropout)                (None, 60, 60, 32)   0           conv32_1[0][0]
# __________________________________________________________________________________________________
# conv22_1 (Conv2D)               (None, 120, 120, 16) 4624        merge22[0][0]
# __________________________________________________________________________________________________
# merge12 (Concatenate)           (None, 240, 240, 16) 0           up12[0][0]
#                                                                  dp11_2[0][0]
# __________________________________________________________________________________________________
# dp42_2 (Dropout)                (None, 30, 30, 64)   0           conv42_2[0][0]
# __________________________________________________________________________________________________
# conv32_2 (Conv2D)               (None, 60, 60, 32)   9248        dp32_1[0][0]
# __________________________________________________________________________________________________
# dp22_1 (Dropout)                (None, 120, 120, 16) 0           conv22_1[0][0]
# __________________________________________________________________________________________________
# conv12_1 (Conv2D)               (None, 240, 240, 8)  1160        merge12[0][0]
# __________________________________________________________________________________________________
# up33 (Conv2DTranspose)          (None, 60, 60, 32)   8224        dp42_2[0][0]
# __________________________________________________________________________________________________
# dp32_2 (Dropout)                (None, 60, 60, 32)   0           conv32_2[0][0]
# __________________________________________________________________________________________________
# conv22_2 (Conv2D)               (None, 120, 120, 16) 2320        dp22_1[0][0]
# __________________________________________________________________________________________________
# dp12_1 (Dropout)                (None, 240, 240, 8)  0           conv12_1[0][0]
# __________________________________________________________________________________________________
# merge33 (Concatenate)           (None, 60, 60, 96)   0           up33[0][0]
#                                                                  dp31_2[0][0]
#                                                                  dp32_2[0][0]
# __________________________________________________________________________________________________
# dp22_2 (Dropout)                (None, 120, 120, 16) 0           conv22_2[0][0]
# __________________________________________________________________________________________________
# up23 (Conv2DTranspose)          (None, 120, 120, 16) 2064        dp32_2[0][0]
# __________________________________________________________________________________________________
# conv12_2 (Conv2D)               (None, 240, 240, 8)  584         dp12_1[0][0]
# __________________________________________________________________________________________________
# conv33_1 (Conv2D)               (None, 60, 60, 32)   27680       merge33[0][0]
# __________________________________________________________________________________________________
# merge23 (Concatenate)           (None, 120, 120, 48) 0           up23[0][0]
#                                                                  dp21_2[0][0]
#                                                                  dp22_2[0][0]
# __________________________________________________________________________________________________
# dp12_2 (Dropout)                (None, 240, 240, 8)  0           conv12_2[0][0]
# __________________________________________________________________________________________________
# up13 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp22_2[0][0]
# __________________________________________________________________________________________________
# dp33_1 (Dropout)                (None, 60, 60, 32)   0           conv33_1[0][0]
# __________________________________________________________________________________________________
# conv23_1 (Conv2D)               (None, 120, 120, 16) 6928        merge23[0][0]
# __________________________________________________________________________________________________
# merge13 (Concatenate)           (None, 240, 240, 24) 0           up13[0][0]
#                                                                  dp11_2[0][0]
#                                                                  dp12_2[0][0]
# __________________________________________________________________________________________________
# conv33_2 (Conv2D)               (None, 60, 60, 32)   9248        dp33_1[0][0]
# __________________________________________________________________________________________________
# dp23_1 (Dropout)                (None, 120, 120, 16) 0           conv23_1[0][0]
# __________________________________________________________________________________________________
# conv13_1 (Conv2D)               (None, 240, 240, 8)  1736        merge13[0][0]
# __________________________________________________________________________________________________
# dp33_2 (Dropout)                (None, 60, 60, 32)   0           conv33_2[0][0]
# __________________________________________________________________________________________________
# conv23_2 (Conv2D)               (None, 120, 120, 16) 2320        dp23_1[0][0]
# __________________________________________________________________________________________________
# dp13_1 (Dropout)                (None, 240, 240, 8)  0           conv13_1[0][0]
# __________________________________________________________________________________________________
# up24 (Conv2DTranspose)          (None, 120, 120, 16) 2064        dp33_2[0][0]
# __________________________________________________________________________________________________
# dp23_2 (Dropout)                (None, 120, 120, 16) 0           conv23_2[0][0]
# __________________________________________________________________________________________________
# conv13_2 (Conv2D)               (None, 240, 240, 8)  584         dp13_1[0][0]
# __________________________________________________________________________________________________
# merge24 (Concatenate)           (None, 120, 120, 64) 0           up24[0][0]
#                                                                  dp21_2[0][0]
#                                                                  dp22_2[0][0]
#                                                                  dp23_2[0][0]
# __________________________________________________________________________________________________
# dp13_2 (Dropout)                (None, 240, 240, 8)  0           conv13_2[0][0]
# __________________________________________________________________________________________________
# up14 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp23_2[0][0]
# __________________________________________________________________________________________________
# conv24_1 (Conv2D)               (None, 120, 120, 16) 9232        merge24[0][0]
# __________________________________________________________________________________________________
# merge14 (Concatenate)           (None, 240, 240, 32) 0           up14[0][0]
#                                                                  dp11_2[0][0]
#                                                                  dp12_2[0][0]
#                                                                  dp13_2[0][0]
# __________________________________________________________________________________________________
# dp24_1 (Dropout)                (None, 120, 120, 16) 0           conv24_1[0][0]
# __________________________________________________________________________________________________
# conv14_1 (Conv2D)               (None, 240, 240, 8)  2312        merge14[0][0]
# __________________________________________________________________________________________________
# conv24_2 (Conv2D)               (None, 120, 120, 16) 2320        dp24_1[0][0]
# __________________________________________________________________________________________________
# dp14_1 (Dropout)                (None, 240, 240, 8)  0           conv14_1[0][0]
# __________________________________________________________________________________________________
# dp24_2 (Dropout)                (None, 120, 120, 16) 0           conv24_2[0][0]
# __________________________________________________________________________________________________
# conv14_2 (Conv2D)               (None, 240, 240, 8)  584         dp14_1[0][0]
# __________________________________________________________________________________________________
# up15 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp24_2[0][0]
# __________________________________________________________________________________________________
# dp14_2 (Dropout)                (None, 240, 240, 8)  0           conv14_2[0][0]
# __________________________________________________________________________________________________
# merge15 (Concatenate)           (None, 240, 240, 40) 0           up15[0][0]
#                                                                  dp11_2[0][0]
#                                                                  dp12_2[0][0]
#                                                                  dp13_2[0][0]
#                                                                  dp14_2[0][0]
# __________________________________________________________________________________________________
# conv15_1 (Conv2D)               (None, 240, 240, 8)  2888        merge15[0][0]
# __________________________________________________________________________________________________
# dp15_1 (Dropout)                (None, 240, 240, 8)  0           conv15_1[0][0]
# __________________________________________________________________________________________________
# conv15_2 (Conv2D)               (None, 240, 240, 8)  584         dp15_1[0][0]
# __________________________________________________________________________________________________
# dp15_2 (Dropout)                (None, 240, 240, 8)  0           conv15_2[0][0]
# __________________________________________________________________________________________________
# output_4 (Conv2D)               (None, 240, 240, 4)  36          dp15_2[0][0]
# ==================================================================================================
# Total params: 566,172
# Trainable params: 566,172
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:75: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("ma..., outputs=[<tf.Tenso...)`

# %%
import os
import cv2
import numpy as np

# %%
# Function to convert image from greyscale to one hot (i.e. 4 channels)
def convertToOneHot(image):
    num_classes = 4
    shape = image.shape[:2]+(num_classes,)
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c]==0:
          encoded_image[r][c][0] = 1
        elif image[r][c]==85:
          encoded_image[r][c][1] = 1
        elif image[r][c]==170:
          encoded_image[r][c][2] = 1
        else:
          encoded_image[r][c][3] = 1
    return encoded_image

# %%
# Function to convert back from one hot image to greyscale
def convertFromOneHot(image):
    shape = image.shape[:2]
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c][0] == 1:
          encoded_image[r][c] = 0
        elif image[r][c][1] == 1:
          encoded_image[r][c] = 85
        elif image[r][c][2] == 1:
          encoded_image[r][c] = 170
        else:
          encoded_image[r][c] = 255
    return encoded_image

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/4 Class ER"

# Train set patients: 230 263 239 242 
TrainX_1 = np.load(PATH + '/ER IHC 239 Images.npy')
TrainY_1 = np.load(PATH + '/ER IHC 239 Masks.npy')
TrainX_2 = np.load(PATH + '/ER IHC 263 Images.npy')
TrainY_2 = np.load(PATH + '/ER IHC 263 Masks.npy')
TrainX_3 = np.load(PATH + '/ER IHC 242 Images.npy')
TrainY_3 = np.load(PATH + '/ER IHC 242 Masks.npy')
TrainX_4 = np.load(PATH + '/ER IHC 230 Images.npy')
TrainY_4 = np.load(PATH + '/ER IHC 230 Masks.npy')

# Test set patients: 221 246 232
TestX_1 = np.load(PATH + '/ER IHC 221 Images.npy')
TestY_1 = np.load(PATH + '/ER IHC 221 Masks.npy')
TestX_2 = np.load(PATH + '/ER IHC 246 Images.npy')
TestY_2 = np.load(PATH + '/ER IHC 246 Masks.npy')
TestX_3 = np.load(PATH + '/ER IHC 232 Images.npy')
TestY_3 = np.load(PATH + '/ER IHC 232 Masks.npy')

# %%
np.unique(TestY_3)
# Out:
# array([  0.,  85., 170., 255.])

# %%
TrainX = np.concatenate((TrainX_1, TrainX_2, TrainX_3, TrainX_4), axis=0)
TrainGroundTruth = np.concatenate((TrainY_1, TrainY_2, TrainY_3, TrainY_4), axis=0)
TrainY = []

for img in TrainGroundTruth:
  encoded_img = convertToOneHot(img)
  TrainY.append(encoded_img)

TrainY = np.asarray(TrainY)

TestX = np.concatenate((TestX_1, TestX_2, TestX_3), axis=0)
TestGroundTruth = np.concatenate((TestY_1, TestY_2, TestY_3), axis=0)
TestY = []

for img in TestGroundTruth:
  encoded_img = convertToOneHot(img)
  TestY.append(encoded_img)

TestY = np.asarray(TestY)

ValidX = TrainX[1800:, : ]
ValidY = TrainY[1800:, : ]

TrainX = TrainX[0:1800, : ]
TrainY = TrainY[0:1800, : ]

print(TrainX.shape)
print(TrainY.shape)
print(TestX.shape)
print(TestY.shape)
print(ValidX.shape)
print(ValidY.shape)
np.unique(TestY)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 4)
# (1440, 240, 240, 3)
# (1440, 240, 240, 4)
# (120, 240, 240, 3)
# (120, 240, 240, 4)
# array([0, 1], dtype=uint8)

# %%
TrainX = np.reshape(TrainX,(-1,240, 240,3))
TrainY = np.reshape(TrainY,(-1,240, 240,4))

TrainX = TrainX.astype('float32')/255

TestX = np.reshape(TestX,(-1,240, 240,3))
TestY = np.reshape(TestY,(-1,240, 240,4))

TestX = TestX.astype('float32')/255

ValidX = np.reshape(ValidX,(-1,240, 240,3))
ValidY = np.reshape(ValidY,(-1,240, 240,4))

ValidX = ValidX.astype('float32')/255

# %%
print(TrainX.shape)
print(TrainY.shape)

print(TestX.shape)
print(TestY.shape)

print(ValidX.shape)
print(ValidY.shape)

np.unique(TestY)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 4)
# (1440, 240, 240, 3)
# (1440, 240, 240, 4)
# (120, 240, 240, 3)
# (120, 240, 240, 4)
# array([0, 1], dtype=uint8)

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
import math
from keras.callbacks import EarlyStopping,ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='auto', verbose=1, patience=30)
mc = ModelCheckpoint('Checkpoint.h5', monitor='val_loss', mode='auto', verbose=1, save_best_only=True)

# %%
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def combined_loss(y_true, y_pred):
  return (1*K.categorical_crossentropy(y_true, y_pred))+(0.5*tversky_loss(y_true, y_pred))

def loss(y_true, y_pred):
  return (1*K.categorical_crossentropy(y_true, y_pred))

# %%
optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=True)

# %%
model.compile(loss= tversky_loss, optimizer=optimizer, metrics=[dice_coef,'accuracy',tversky_loss, loss, combined_loss])

# %%
num_epoch = 100;
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER"
history = model.fit(TrainX, TrainY, epochs=num_epoch, validation_data=(ValidX, ValidY), shuffle=True,batch_size=16,callbacks=[es,mc])
model.save(MODELS_PATH + '/NestedUNET_ER_20_03_21_TverskyLoss.h5')
# Out:
# Train on 1800 samples, validate on 120 samples
# Epoch 1/100
# 1800/1800 [==============================] - 31s 17ms/step - loss: 2.8005 - dice_coef: 0.7014 - acc: 0.6949 - tversky_loss: 2.6436 - loss_1: 2.6217 - combined_loss: 3.9435 - val_loss: 3.1521 - val_dice_coef: 0.9457 - val_acc: 0.9457 - val_tversky_loss: 3.0236 - val_loss_1: 0.4869 - val_combined_loss: 1.9987
#
# Epoch 00001: val_loss improved from inf to 3.15213, saving model to Checkpoint.h5
# Epoch 2/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 2.2524 - dice_coef: 0.8219 - acc: 0.8235 - tversky_loss: 2.1446 - loss_1: 1.3096 - combined_loss: 2.3819 - val_loss: 3.0957 - val_dice_coef: 0.9885 - val_acc: 0.9885 - val_tversky_loss: 3.0056 - val_loss_1: 0.1850 - val_combined_loss: 1.6878
#
# Epoch 00002: val_loss improved from 3.15213 to 3.09568, saving model to Checkpoint.h5
# Epoch 3/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 2.1534 - dice_coef: 0.8422 - acc: 0.8544 - tversky_loss: 2.0752 - loss_1: 1.2803 - combined_loss: 2.3180 - val_loss: 3.0736 - val_dice_coef: 0.9862 - val_acc: 0.9862 - val_tversky_loss: 3.0058 - val_loss_1: 0.2113 - val_combined_loss: 1.7142
#
# Epoch 00003: val_loss improved from 3.09568 to 3.07364, saving model to Checkpoint.h5
# Epoch 4/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 2.0939 - dice_coef: 0.8624 - acc: 0.8666 - tversky_loss: 2.0328 - loss_1: 1.2060 - combined_loss: 2.2224 - val_loss: 3.0619 - val_dice_coef: 0.9885 - val_acc: 0.9885 - val_tversky_loss: 3.0054 - val_loss_1: 0.1848 - val_combined_loss: 1.6875
#
# Epoch 00004: val_loss improved from 3.07364 to 3.06189, saving model to Checkpoint.h5
# Epoch 5/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.9819 - dice_coef: 0.8842 - acc: 0.8944 - tversky_loss: 1.9277 - loss_1: 1.1695 - combined_loss: 2.1334 - val_loss: 3.0703 - val_dice_coef: 0.9593 - val_acc: 0.9593 - val_tversky_loss: 3.0186 - val_loss_1: 0.5793 - val_combined_loss: 2.0886
#
# Epoch 00005: val_loss did not improve from 3.06189
# Epoch 6/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.8886 - dice_coef: 0.8983 - acc: 0.9104 - tversky_loss: 1.8375 - loss_1: 1.0587 - combined_loss: 1.9775 - val_loss: 3.0505 - val_dice_coef: 0.9880 - val_acc: 0.9880 - val_tversky_loss: 3.0001 - val_loss_1: 0.1858 - val_combined_loss: 1.6859
#
# Epoch 00006: val_loss improved from 3.06189 to 3.05050, saving model to Checkpoint.h5
# Epoch 7/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.8640 - dice_coef: 0.8996 - acc: 0.9114 - tversky_loss: 1.8112 - loss_1: 1.0434 - combined_loss: 1.9490 - val_loss: 2.8647 - val_dice_coef: 0.9890 - val_acc: 0.9890 - val_tversky_loss: 2.8078 - val_loss_1: 0.1662 - val_combined_loss: 1.5701
#
# Epoch 00007: val_loss improved from 3.05050 to 2.86474, saving model to Checkpoint.h5
# Epoch 8/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.8172 - dice_coef: 0.9003 - acc: 0.9071 - tversky_loss: 1.7617 - loss_1: 1.1212 - combined_loss: 2.0021 - val_loss: 2.9208 - val_dice_coef: 0.9817 - val_acc: 0.9817 - val_tversky_loss: 2.8661 - val_loss_1: 0.2286 - val_combined_loss: 1.6617
#
# Epoch 00008: val_loss did not improve from 2.86474
# Epoch 9/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7738 - dice_coef: 0.9060 - acc: 0.9125 - tversky_loss: 1.7201 - loss_1: 1.1278 - combined_loss: 1.9879 - val_loss: 2.9863 - val_dice_coef: 0.9554 - val_acc: 0.9553 - val_tversky_loss: 2.9330 - val_loss_1: 0.5114 - val_combined_loss: 1.9779
#
# Epoch 00009: val_loss did not improve from 2.86474
# Epoch 10/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7775 - dice_coef: 0.9065 - acc: 0.9116 - tversky_loss: 1.7236 - loss_1: 1.1755 - combined_loss: 2.0373 - val_loss: 2.7384 - val_dice_coef: 0.9857 - val_acc: 0.9857 - val_tversky_loss: 2.6836 - val_loss_1: 0.1971 - val_combined_loss: 1.5389
#
# Epoch 00010: val_loss improved from 2.86474 to 2.73844, saving model to Checkpoint.h5
# Epoch 11/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7689 - dice_coef: 0.9098 - acc: 0.9143 - tversky_loss: 1.7127 - loss_1: 1.1611 - combined_loss: 2.0175 - val_loss: 2.7483 - val_dice_coef: 0.9826 - val_acc: 0.9826 - val_tversky_loss: 2.6923 - val_loss_1: 0.2258 - val_combined_loss: 1.5719
#
# Epoch 00011: val_loss did not improve from 2.73844
# Epoch 12/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7369 - dice_coef: 0.9113 - acc: 0.9154 - tversky_loss: 1.6807 - loss_1: 1.1547 - combined_loss: 1.9950 - val_loss: 2.9674 - val_dice_coef: 0.9888 - val_acc: 0.9888 - val_tversky_loss: 2.9103 - val_loss_1: 0.1778 - val_combined_loss: 1.6330
#
# Epoch 00012: val_loss did not improve from 2.73844
# Epoch 13/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7594 - dice_coef: 0.9109 - acc: 0.9144 - tversky_loss: 1.7023 - loss_1: 1.1824 - combined_loss: 2.0335 - val_loss: 2.7716 - val_dice_coef: 0.9868 - val_acc: 0.9868 - val_tversky_loss: 2.7143 - val_loss_1: 0.1952 - val_combined_loss: 1.5524
#
# Epoch 00013: val_loss did not improve from 2.73844
# Epoch 14/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7353 - dice_coef: 0.9128 - acc: 0.9159 - tversky_loss: 1.6779 - loss_1: 1.1682 - combined_loss: 2.0072 - val_loss: 2.6951 - val_dice_coef: 0.9885 - val_acc: 0.9885 - val_tversky_loss: 2.6382 - val_loss_1: 0.1697 - val_combined_loss: 1.4888
#
# Epoch 00014: val_loss improved from 2.73844 to 2.69512, saving model to Checkpoint.h5
# Epoch 15/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7367 - dice_coef: 0.9138 - acc: 0.9168 - tversky_loss: 1.6785 - loss_1: 1.1596 - combined_loss: 1.9989 - val_loss: 2.8925 - val_dice_coef: 0.9796 - val_acc: 0.9796 - val_tversky_loss: 2.8329 - val_loss_1: 0.2788 - val_combined_loss: 1.6953
#
# Epoch 00015: val_loss did not improve from 2.69512
# Epoch 16/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7526 - dice_coef: 0.9123 - acc: 0.9151 - tversky_loss: 1.6928 - loss_1: 1.1934 - combined_loss: 2.0398 - val_loss: 2.7228 - val_dice_coef: 0.9861 - val_acc: 0.9861 - val_tversky_loss: 2.6626 - val_loss_1: 0.1998 - val_combined_loss: 1.5310
#
# Epoch 00016: val_loss did not improve from 2.69512
# Epoch 17/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7376 - dice_coef: 0.9136 - acc: 0.9162 - tversky_loss: 1.6736 - loss_1: 1.1803 - combined_loss: 2.0172 - val_loss: 2.9402 - val_dice_coef: 0.9890 - val_acc: 0.9890 - val_tversky_loss: 2.8749 - val_loss_1: 0.1750 - val_combined_loss: 1.6124
#
# Epoch 00017: val_loss did not improve from 2.69512
# Epoch 18/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.6921 - dice_coef: 0.9158 - acc: 0.9183 - tversky_loss: 1.6280 - loss_1: 1.1519 - combined_loss: 1.9659 - val_loss: 2.9187 - val_dice_coef: 0.9885 - val_acc: 0.9885 - val_tversky_loss: 2.8554 - val_loss_1: 0.1792 - val_combined_loss: 1.6069
#
# Epoch 00018: val_loss did not improve from 2.69512
# Epoch 19/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.6918 - dice_coef: 0.9177 - acc: 0.9203 - tversky_loss: 1.6289 - loss_1: 1.1318 - combined_loss: 1.9462 - val_loss: 2.8881 - val_dice_coef: 0.9419 - val_acc: 0.9419 - val_tversky_loss: 2.8248 - val_loss_1: 0.8830 - val_combined_loss: 2.2954
#
# Epoch 00019: val_loss did not improve from 2.69512
# Epoch 20/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7360 - dice_coef: 0.9131 - acc: 0.9155 - tversky_loss: 1.6723 - loss_1: 1.1998 - combined_loss: 2.0360 - val_loss: 3.1804 - val_dice_coef: 0.7918 - val_acc: 0.7918 - val_tversky_loss: 3.1162 - val_loss_1: 3.2722 - val_combined_loss: 4.8303
#
# Epoch 00020: val_loss did not improve from 2.69512
# Epoch 21/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7709 - dice_coef: 0.9062 - acc: 0.9084 - tversky_loss: 1.7063 - loss_1: 1.3058 - combined_loss: 2.1589 - val_loss: nan - val_dice_coef: 0.9884 - val_acc: 0.9884 - val_tversky_loss: nan - val_loss_1: 0.1873 - val_combined_loss: nan
#
# Epoch 00021: val_loss did not improve from 2.69512
# Epoch 22/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.8021 - dice_coef: 0.9110 - acc: 0.9130 - tversky_loss: 1.7354 - loss_1: 1.2101 - combined_loss: 2.0778 - val_loss: 2.9893 - val_dice_coef: 0.9887 - val_acc: 0.9887 - val_tversky_loss: 2.9227 - val_loss_1: 0.1787 - val_combined_loss: 1.6401
#
# Epoch 00022: val_loss did not improve from 2.69512
# Epoch 23/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7776 - dice_coef: 0.9117 - acc: 0.9138 - tversky_loss: 1.7105 - loss_1: 1.2233 - combined_loss: 2.0786 - val_loss: nan - val_dice_coef: 0.9885 - val_acc: 0.9885 - val_tversky_loss: nan - val_loss_1: 0.1846 - val_combined_loss: nan
#
# Epoch 00023: val_loss did not improve from 2.69512
# Epoch 24/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7518 - dice_coef: 0.9148 - acc: 0.9168 - tversky_loss: 1.6814 - loss_1: 1.1717 - combined_loss: 2.0123 - val_loss: 2.9730 - val_dice_coef: 0.9261 - val_acc: 0.9261 - val_tversky_loss: 2.9031 - val_loss_1: 1.1498 - val_combined_loss: 2.6014
#
# Epoch 00024: val_loss did not improve from 2.69512
# Epoch 25/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7298 - dice_coef: 0.9171 - acc: 0.9190 - tversky_loss: 1.6598 - loss_1: 1.1499 - combined_loss: 1.9798 - val_loss: nan - val_dice_coef: 0.9885 - val_acc: 0.9885 - val_tversky_loss: nan - val_loss_1: 0.1848 - val_combined_loss: nan
#
# Epoch 00025: val_loss did not improve from 2.69512
# Epoch 26/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.6865 - dice_coef: 0.9188 - acc: 0.9207 - tversky_loss: 1.6173 - loss_1: 1.1309 - combined_loss: 1.9396 - val_loss: 3.0724 - val_dice_coef: 0.9870 - val_acc: 0.9870 - val_tversky_loss: 3.0027 - val_loss_1: 0.2073 - val_combined_loss: 1.7087
#
# Epoch 00026: val_loss did not improve from 2.69512
# Epoch 27/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.6934 - dice_coef: 0.9161 - acc: 0.9179 - tversky_loss: 1.6239 - loss_1: 1.1795 - combined_loss: 1.9914 - val_loss: 3.0736 - val_dice_coef: 0.9883 - val_acc: 0.9883 - val_tversky_loss: 3.0042 - val_loss_1: 0.1881 - val_combined_loss: 1.6902
#
# Epoch 00027: val_loss did not improve from 2.69512
# Epoch 28/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7954 - dice_coef: 0.9143 - acc: 0.9160 - tversky_loss: 1.7248 - loss_1: 1.2006 - combined_loss: 2.0630 - val_loss: 2.9634 - val_dice_coef: 0.9802 - val_acc: 0.9802 - val_tversky_loss: 2.8917 - val_loss_1: 0.3007 - val_combined_loss: 1.7465
#
# Epoch 00028: val_loss did not improve from 2.69512
# Epoch 29/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7353 - dice_coef: 0.9170 - acc: 0.9186 - tversky_loss: 1.6636 - loss_1: 1.1648 - combined_loss: 1.9966 - val_loss: 2.7747 - val_dice_coef: 0.9894 - val_acc: 0.9894 - val_tversky_loss: 2.7022 - val_loss_1: 0.1659 - val_combined_loss: 1.5170
#
# Epoch 00029: val_loss did not improve from 2.69512
# Epoch 30/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.6941 - dice_coef: 0.9168 - acc: 0.9184 - tversky_loss: 1.6211 - loss_1: 1.1740 - combined_loss: 1.9845 - val_loss: 3.0737 - val_dice_coef: 0.9842 - val_acc: 0.9842 - val_tversky_loss: 3.0008 - val_loss_1: 0.2463 - val_combined_loss: 1.7467
#
# Epoch 00030: val_loss did not improve from 2.69512
# Epoch 31/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7868 - dice_coef: 0.9144 - acc: 0.9159 - tversky_loss: 1.7142 - loss_1: 1.2061 - combined_loss: 2.0632 - val_loss: 3.0291 - val_dice_coef: 0.9873 - val_acc: 0.9873 - val_tversky_loss: 2.9561 - val_loss_1: 0.2002 - val_combined_loss: 1.6782
#
# Epoch 00031: val_loss did not improve from 2.69512
# Epoch 32/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.6741 - dice_coef: 0.9195 - acc: 0.9210 - tversky_loss: 1.6012 - loss_1: 1.1346 - combined_loss: 1.9352 - val_loss: nan - val_dice_coef: 0.9888 - val_acc: 0.9888 - val_tversky_loss: nan - val_loss_1: 0.1790 - val_combined_loss: nan
#
# Epoch 00032: val_loss did not improve from 2.69512
# Epoch 33/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.6990 - dice_coef: 0.9178 - acc: 0.9192 - tversky_loss: 1.6264 - loss_1: 1.1657 - combined_loss: 1.9789 - val_loss: 3.0689 - val_dice_coef: 0.9863 - val_acc: 0.9863 - val_tversky_loss: 2.9974 - val_loss_1: 0.2167 - val_combined_loss: 1.7153
#
# Epoch 00033: val_loss did not improve from 2.69512
# Epoch 34/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.6574 - dice_coef: 0.9198 - acc: 0.9212 - tversky_loss: 1.5864 - loss_1: 1.1350 - combined_loss: 1.9282 - val_loss: 3.0228 - val_dice_coef: 0.9885 - val_acc: 0.9885 - val_tversky_loss: 2.9519 - val_loss_1: 0.1838 - val_combined_loss: 1.6597
#
# Epoch 00034: val_loss did not improve from 2.69512
# Epoch 35/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.6884 - dice_coef: 0.9196 - acc: 0.9210 - tversky_loss: 1.6170 - loss_1: 1.1356 - combined_loss: 1.9441 - val_loss: 3.0674 - val_dice_coef: 0.9885 - val_acc: 0.9885 - val_tversky_loss: 2.9953 - val_loss_1: 0.1845 - val_combined_loss: 1.6822
#
# Epoch 00035: val_loss did not improve from 2.69512
# Epoch 36/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.6532 - dice_coef: 0.9214 - acc: 0.9227 - tversky_loss: 1.5813 - loss_1: 1.1136 - combined_loss: 1.9043 - val_loss: 3.0480 - val_dice_coef: 0.9811 - val_acc: 0.9811 - val_tversky_loss: 2.9762 - val_loss_1: 0.2970 - val_combined_loss: 1.7851
#
# Epoch 00036: val_loss did not improve from 2.69512
# Epoch 37/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.6571 - dice_coef: 0.9188 - acc: 0.9201 - tversky_loss: 1.5847 - loss_1: 1.1545 - combined_loss: 1.9468 - val_loss: 3.0720 - val_dice_coef: 0.9884 - val_acc: 0.9884 - val_tversky_loss: 2.9979 - val_loss_1: 0.1861 - val_combined_loss: 1.6850
#
# Epoch 00037: val_loss did not improve from 2.69512
# Epoch 38/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7511 - dice_coef: 0.9179 - acc: 0.9191 - tversky_loss: 1.6746 - loss_1: 1.1696 - combined_loss: 2.0069 - val_loss: 2.8183 - val_dice_coef: 0.9892 - val_acc: 0.9892 - val_tversky_loss: 2.7408 - val_loss_1: 0.1699 - val_combined_loss: 1.5403
#
# Epoch 00038: val_loss did not improve from 2.69512
# Epoch 39/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7307 - dice_coef: 0.9161 - acc: 0.9173 - tversky_loss: 1.6531 - loss_1: 1.1951 - combined_loss: 2.0216 - val_loss: 2.7939 - val_dice_coef: 0.9897 - val_acc: 0.9897 - val_tversky_loss: 2.7167 - val_loss_1: 0.1632 - val_combined_loss: 1.5215
#
# Epoch 00039: val_loss did not improve from 2.69512
# Epoch 40/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7095 - dice_coef: 0.9197 - acc: 0.9209 - tversky_loss: 1.6321 - loss_1: 1.1383 - combined_loss: 1.9543 - val_loss: 3.0143 - val_dice_coef: 0.9888 - val_acc: 0.9888 - val_tversky_loss: 2.9373 - val_loss_1: 0.1802 - val_combined_loss: 1.6488
#
# Epoch 00040: val_loss did not improve from 2.69512
# Epoch 41/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.6311 - dice_coef: 0.9208 - acc: 0.9219 - tversky_loss: 1.5541 - loss_1: 1.1279 - combined_loss: 1.9049 - val_loss: 2.9729 - val_dice_coef: 0.9880 - val_acc: 0.9880 - val_tversky_loss: 2.8961 - val_loss_1: 0.1896 - val_combined_loss: 1.6377
#
# Epoch 00041: val_loss did not improve from 2.69512
# Epoch 42/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.6237 - dice_coef: 0.9210 - acc: 0.9222 - tversky_loss: 1.5473 - loss_1: 1.1259 - combined_loss: 1.8996 - val_loss: 3.0770 - val_dice_coef: 0.9885 - val_acc: 0.9885 - val_tversky_loss: 3.0010 - val_loss_1: 0.1850 - val_combined_loss: 1.6856
#
# Epoch 00042: val_loss did not improve from 2.69512
# Epoch 43/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.6353 - dice_coef: 0.9209 - acc: 0.9220 - tversky_loss: 1.5593 - loss_1: 1.1307 - combined_loss: 1.9104 - val_loss: 3.0804 - val_dice_coef: 0.9869 - val_acc: 0.9869 - val_tversky_loss: 3.0049 - val_loss_1: 0.2091 - val_combined_loss: 1.7115
#
# Epoch 00043: val_loss did not improve from 2.69512
# Epoch 44/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.6956 - dice_coef: 0.9135 - acc: 0.9146 - tversky_loss: 1.6199 - loss_1: 1.2470 - combined_loss: 2.0569 - val_loss: 3.0806 - val_dice_coef: 0.9883 - val_acc: 0.9883 - val_tversky_loss: 3.0049 - val_loss_1: 0.1880 - val_combined_loss: 1.6905
#
# Epoch 00044: val_loss did not improve from 2.69512
# Epoch 00044: early stopping

# %%
train_loss = history.history['loss']
train_acc = history.history['acc']
val_loss = history.history['val_loss']
val_acc = history.history['val_acc']
xc=range(len(train_loss))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_loss)
plt.plot(xc, val_loss)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(['train','val'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_acc)
plt.plot(xc, val_acc)
plt.xlabel("Epoch")
plt.ylabel("Acc")
plt.legend(['train','val'])

# %%
# MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER"
# model = keras.models.load_model(MODELS_PATH+'/UNET_ER_20_03_03_v5.h5',custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

# %%
# Function to find the most probable class of an image pixel by pixel
def ClassFinder(img):
  result = np.zeros(img.shape, dtype=np.uint8)
  for r in range(len(img)):
    for c in range(len(img[0])):
      idx = np.argmax(img[r][c])
      result[r][c][idx]=1
      
  return result

# %%
train_result = model.predict(TrainX, batch_size=16)
print(np.shape(train_result))
Train_predict = [ ]
for img in train_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_predict.append(encoded_img)

Predicted_images = np.asarray(Train_predict)
print(Predicted_images.shape)
np.unique(Predicted_images)
# dice = dc(train_result, TrainY)
# pre  = precision(train_result,TrainY)
# re   = recall(train_result,TrainY)
# print('Train dc: '  + str(dice))
# print('Train pre: ' + str(pre))
# print('Train re: '  + str(re))
# Out:
# (1800, 240, 240, 4)
# (1800, 240, 240)
# array([  0,  85, 170, 255], dtype=uint8)

# %%
test_result = model.predict(TestX, batch_size=16)
print(np.shape(test_result))

Test_predict = [ ]
for img in test_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_predict.append(encoded_img)

Predicted_images_test = np.asarray(Test_predict)
print(Predicted_images_test.shape)
np.unique(Predicted_images_test)
# dice = dc(test_result, TestY)
# pre  = precision(test_result,TestY)
# re   = recall(test_result,TestY)
# print('Test dc: '  + str(dice))
# print('Test pre: ' + str(pre))
# print('Test re: '  + str(re))
# Out:
# (1440, 240, 240, 4)
# (1440, 240, 240)
# array([  0,  85, 170, 255], dtype=uint8)

# %%
from sklearn.metrics import confusion_matrix
def get_confusion_matrix(Actual, Predicted):
  ActualY = np.reshape(Actual,(-1, Actual.shape[3]))
  PredY = np.reshape(Predicted,(-1, Predicted.shape[3]))
  matrix = confusion_matrix(ActualY.argmax(axis = 1), PredY.argmax(axis = 1))
  return matrix

def get_precision(confusion_matrix):
  precision = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 0)
  nan_indices = np.isnan(precision)
  precision[nan_indices] = 0
  return precision

def get_recall(confusion_matrix):
  recall = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 1)
  nan_indices = np.isnan(recall)
  recall[nan_indices] = 0
  return recall

# %%
test_matrix = get_confusion_matrix(TestY, test_result)
train_matrix = get_confusion_matrix(TrainY, train_result)
print(test_matrix)
print(train_matrix)
# TestY.shape[3]
# test_result.shape
# Out:
# [[75465352     6766  1048283    45859]
#  [  212208      151   449385       85]
#  [  487771    12263  2167951    31476]
#  [ 1198773    23982  1537016   256679]]
# [[82850076    97476  5471324   545924]
#  [  374650     4422   988624     7257]
#  [ 1519488    42331  2656807   129336]
#  [ 4132460    30484  2774025  2055316]]

# %%
test_precision = get_precision(test_matrix)
print('Test Precision')
print(test_precision)
test_recall = get_recall(test_matrix)
print('Test Recall')
print(test_recall)
train_precision = get_precision(train_matrix)
print('Train Precision')
print(train_precision)
train_recall = get_recall(train_matrix)
print('Train Recall')
print(train_recall)
# Out:
# Test Precision
# [0.97545694 0.00349845 0.4167025  0.76827228]
# Test Recall
# [9.85621500e-01 2.28155611e-04 8.03105138e-01 8.50930730e-02]
# Train Precision
# [0.93219145 0.02531008 0.22343421 0.75070905]
# Train Recall
# [0.93126805 0.00321611 0.61104651 0.22856437]

# %%
# weight_matrix = np.zeros((3,1))
# weight_matrix[0] = 0.6
# weight_matrix[1] = 0.2
# weight_matrix[2] = 0.2
# print(weight_matrix.shape)

# %%
weight_matrix = np.zeros((4,1))
weight_matrix[0] = 1/3
weight_matrix[1] = 1/3
weight_matrix[2] = 1/3
weight_matrix[3] = 1/3
print(weight_matrix.shape)
# Out:
# (4, 1)

# %%
def get_overall_precision(precision, weights):
  final_precision = np.dot(precision,weights)
  return final_precision

def get_overall_recall(recall, weights):
  final_recall = np.dot(recall ,weights)
  return final_recall

# %%
final_test_precision  = get_overall_precision(test_precision, weight_matrix)
final_test_recall     = get_overall_recall(test_recall, weight_matrix)
final_train_precision = get_overall_precision(train_precision, weight_matrix)
final_train_recall    = get_overall_recall(train_recall, weight_matrix)
print('Final Test Precision')
print(final_test_precision)
print('Final Test Recall')
print(final_test_recall)
print('Final Train Precision')
print(final_train_precision)
print('Final Train Recall')
print(final_train_recall)
# Out:
# Final Test Precision
# [0.72131005]
# Final Test Recall
# [0.62468262]
# Final Train Precision
# [0.6438816]
# Final Train Recall
# [0.59136502]

# %%
from scipy.stats import hmean

def dice_coefficient(precision, recall):
  return hmean(np.asarray([precision , recall]))

# %%
test_dice_coeff = dice_coefficient(final_test_precision, final_test_recall)
print('Test Dice coeff')
print(test_dice_coeff)

train_dice_coeff = dice_coefficient(final_train_precision, final_train_recall)
print('Train Dice coeff')
print(train_dice_coeff)
# Out:
# Test Dice coeff
# [0.66952795]
# Train Dice coeff
# [0.61650693]

# %%
copy1  = np.copy(TestX [250])
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
copy3 = np.reshape(copy2,(240, 240,3))
Img = cv2.cvtColor(copy3,cv2.COLOR_BGR2RGB)

Mask = TestGroundTruth[250]

Predicted_Mask = Predicted_images_test[250] 

plt.subplot(131).imshow(Img)
plt.subplot(132).imshow(Mask,'gray')
plt.subplot(133).imshow(Predicted_Mask,'gray')

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask):
  num = mask.shape[0]/480
  for id in range(int(num)):
    temp = []
    for i in range(id, id+10):
      idx = i * 48
      final_output = mask[idx:idx+48]
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save("/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/Combined_Loss/ER1 Patient " + str(id), final_output)

# %%
# saving predicted outputs as numpy arrays for test images
saveNumpyOutput(Predicted_images)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 20   # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]

Mask_input = TestY[id:id+48]
Test_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Test_Actual)
print(Mask_input.shape)

final_output = Predicted_images_test[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 4)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0.  85. 170. 255.]

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 14  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]

Mask_input = TrainY[id:id+48]
Train_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Train_Actual)
print(Mask_input.shape)

final_output = Predicted_images[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 4)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0.  85. 170. 255.]
