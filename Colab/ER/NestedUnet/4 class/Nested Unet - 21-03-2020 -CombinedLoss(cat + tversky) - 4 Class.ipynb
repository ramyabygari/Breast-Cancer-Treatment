# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from keras.layers import Activation,Conv2D,MaxPooling2D,UpSampling2D,Dense,BatchNormalization,Input,Reshape,multiply,add,Dropout,AveragePooling2D,GlobalAveragePooling2D,concatenate
from keras.layers.convolutional import Conv2DTranspose
from keras.models import Model														  
import keras.backend as K
from keras.regularizers import l2
from keras.engine import Layer,InputSpec
from keras.utils import conv_utils
from keras.layers import Activation,Conv2D,MaxPooling2D,UpSampling2D,Dense,BatchNormalization,Input,Reshape,multiply,add,Dropout,AveragePooling2D,GlobalAveragePooling2D,concatenate
from keras.layers.convolutional import Conv2DTranspose
from keras.models import Model														  
import keras.backend as K
from keras.regularizers import l2
from keras.engine import Layer,InputSpec
from keras.utils import conv_utils
# !pip install medpy
from keras.layers import *
from keras.models import Sequential
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from medpy.metric import dc, precision, recall
import keras
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Requirement already satisfied: medpy in /usr/local/lib/python3.6/dist-packages (0.4.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.18.2)
# Requirement already satisfied: SimpleITK>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.2.4)

# %%
smooth = 1.
dropout_rate = 0.5
def standard_unit(input_tensor, stage, nb_filter, kernel_size=3):

    act = 'elu'

    x = Conv2D(nb_filter, (kernel_size, kernel_size), activation=act, name='conv'+stage+'_1', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(input_tensor)
    x = Dropout(dropout_rate, name='dp'+stage+'_1')(x)
    x = Conv2D(nb_filter, (kernel_size, kernel_size), activation=act, name='conv'+stage+'_2', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(x)
    x = Dropout(dropout_rate, name='dp'+stage+'_2')(x)

    return x

# %%
def Nest_Net(img_rows, img_cols, color_type=3, num_class=4, deep_supervision=False):

    nb_filter = [8,16,32,64,128]
    act = 'elu'
  
    bn_axis = 3
    
    
    img_input = Input(shape=(img_rows, img_cols, color_type), name='main_input')
    conv1_1 = standard_unit(img_input, stage='11', nb_filter=nb_filter[0])
    pool1 = MaxPooling2D((2, 2), strides=(2, 2), name='pool1')(conv1_1)

    conv2_1 = standard_unit(pool1, stage='21', nb_filter=nb_filter[1])
    pool2 = MaxPooling2D((2, 2), strides=(2, 2), name='pool2')(conv2_1)

    up1_2 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up12', padding='same')(conv2_1)
    conv1_2 = concatenate([up1_2, conv1_1], name='merge12', axis=bn_axis)
    conv1_2 = standard_unit(conv1_2, stage='12', nb_filter=nb_filter[0])

    conv3_1 = standard_unit(pool2, stage='31', nb_filter=nb_filter[2])
    pool3 = MaxPooling2D((2, 2), strides=(2, 2), name='pool3')(conv3_1)

    up2_2 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up22', padding='same')(conv3_1)
    conv2_2 = concatenate([up2_2, conv2_1], name='merge22', axis=bn_axis)
    conv2_2 = standard_unit(conv2_2, stage='22', nb_filter=nb_filter[1])

    up1_3 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up13', padding='same')(conv2_2)
    conv1_3 = concatenate([up1_3, conv1_1, conv1_2], name='merge13', axis=bn_axis)
    conv1_3 = standard_unit(conv1_3, stage='13', nb_filter=nb_filter[0])

    conv4_1 = standard_unit(pool3, stage='41', nb_filter=nb_filter[3])
    pool4 = MaxPooling2D((2, 2), strides=(2, 2), name='pool4')(conv4_1)

    up3_2 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up32', padding='same')(conv4_1)
    conv3_2 = concatenate([up3_2, conv3_1], name='merge32', axis=bn_axis)
    conv3_2 = standard_unit(conv3_2, stage='32', nb_filter=nb_filter[2])

    up2_3 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up23', padding='same')(conv3_2)
    conv2_3 = concatenate([up2_3, conv2_1, conv2_2], name='merge23', axis=bn_axis)
    conv2_3 = standard_unit(conv2_3, stage='23', nb_filter=nb_filter[1])

    up1_4 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up14', padding='same')(conv2_3)
    conv1_4 = concatenate([up1_4, conv1_1, conv1_2, conv1_3], name='merge14', axis=bn_axis)
    conv1_4 = standard_unit(conv1_4, stage='14', nb_filter=nb_filter[0])

    conv5_1 = standard_unit(pool4, stage='51', nb_filter=nb_filter[4])

    up4_2 = Conv2DTranspose(nb_filter[3], (2, 2), strides=(2, 2), name='up42', padding='same')(conv5_1)
    conv4_2 = concatenate([up4_2, conv4_1], name='merge42', axis=bn_axis)
    conv4_2 = standard_unit(conv4_2, stage='42', nb_filter=nb_filter[3])

    up3_3 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up33', padding='same')(conv4_2)
    conv3_3 = concatenate([up3_3, conv3_1, conv3_2], name='merge33', axis=bn_axis)
    conv3_3 = standard_unit(conv3_3, stage='33', nb_filter=nb_filter[2])

    up2_4 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up24', padding='same')(conv3_3)
    conv2_4 = concatenate([up2_4, conv2_1, conv2_2, conv2_3], name='merge24', axis=bn_axis)
    conv2_4 = standard_unit(conv2_4, stage='24', nb_filter=nb_filter[1])

    up1_5 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up15', padding='same')(conv2_4)
    conv1_5 = concatenate([up1_5, conv1_1, conv1_2, conv1_3, conv1_4], name='merge15', axis=bn_axis)
    conv1_5 = standard_unit(conv1_5, stage='15', nb_filter=nb_filter[0])

    nestnet_output_1 = Conv2D(num_class, (1, 1), activation='softmax', name='output_1', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_2)
    nestnet_output_2 = Conv2D(num_class, (1, 1), activation='softmax', name='output_2', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_3)
    nestnet_output_3 = Conv2D(num_class, (1, 1), activation='softmax', name='output_3', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_4)
    nestnet_output_4 = Conv2D(num_class, (1, 1), activation='softmax', name='output_4', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_5)

    if deep_supervision:
        model = Model(input=img_input, output=[nestnet_output_1,
                                               nestnet_output_2,
                                               nestnet_output_3,
                                               nestnet_output_4])
    else:
        model = Model(input=img_input, output=[nestnet_output_4])

    return model

# %%
model = Nest_Net(240,240,3)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 240, 240, 3)  0
# __________________________________________________________________________________________________
# conv11_1 (Conv2D)               (None, 240, 240, 8)  224         main_input[0][0]
# __________________________________________________________________________________________________
# dp11_1 (Dropout)                (None, 240, 240, 8)  0           conv11_1[0][0]
# __________________________________________________________________________________________________
# conv11_2 (Conv2D)               (None, 240, 240, 8)  584         dp11_1[0][0]
# __________________________________________________________________________________________________
# dp11_2 (Dropout)                (None, 240, 240, 8)  0           conv11_2[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 120, 120, 8)  0           dp11_2[0][0]
# __________________________________________________________________________________________________
# conv21_1 (Conv2D)               (None, 120, 120, 16) 1168        pool1[0][0]
# __________________________________________________________________________________________________
# dp21_1 (Dropout)                (None, 120, 120, 16) 0           conv21_1[0][0]
# __________________________________________________________________________________________________
# conv21_2 (Conv2D)               (None, 120, 120, 16) 2320        dp21_1[0][0]
# __________________________________________________________________________________________________
# dp21_2 (Dropout)                (None, 120, 120, 16) 0           conv21_2[0][0]
# __________________________________________________________________________________________________
# pool2 (MaxPooling2D)            (None, 60, 60, 16)   0           dp21_2[0][0]
# __________________________________________________________________________________________________
# conv31_1 (Conv2D)               (None, 60, 60, 32)   4640        pool2[0][0]
# __________________________________________________________________________________________________
# dp31_1 (Dropout)                (None, 60, 60, 32)   0           conv31_1[0][0]
# __________________________________________________________________________________________________
# conv31_2 (Conv2D)               (None, 60, 60, 32)   9248        dp31_1[0][0]
# __________________________________________________________________________________________________
# dp31_2 (Dropout)                (None, 60, 60, 32)   0           conv31_2[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 30, 30, 32)   0           dp31_2[0][0]
# __________________________________________________________________________________________________
# conv41_1 (Conv2D)               (None, 30, 30, 64)   18496       pool3[0][0]
# __________________________________________________________________________________________________
# dp41_1 (Dropout)                (None, 30, 30, 64)   0           conv41_1[0][0]
# __________________________________________________________________________________________________
# conv41_2 (Conv2D)               (None, 30, 30, 64)   36928       dp41_1[0][0]
# __________________________________________________________________________________________________
# dp41_2 (Dropout)                (None, 30, 30, 64)   0           conv41_2[0][0]
# __________________________________________________________________________________________________
# pool4 (MaxPooling2D)            (None, 15, 15, 64)   0           dp41_2[0][0]
# __________________________________________________________________________________________________
# conv51_1 (Conv2D)               (None, 15, 15, 128)  73856       pool4[0][0]
# __________________________________________________________________________________________________
# dp51_1 (Dropout)                (None, 15, 15, 128)  0           conv51_1[0][0]
# __________________________________________________________________________________________________
# conv51_2 (Conv2D)               (None, 15, 15, 128)  147584      dp51_1[0][0]
# __________________________________________________________________________________________________
# dp51_2 (Dropout)                (None, 15, 15, 128)  0           conv51_2[0][0]
# __________________________________________________________________________________________________
# up42 (Conv2DTranspose)          (None, 30, 30, 64)   32832       dp51_2[0][0]
# __________________________________________________________________________________________________
# merge42 (Concatenate)           (None, 30, 30, 128)  0           up42[0][0]
#                                                                  dp41_2[0][0]
# __________________________________________________________________________________________________
# up32 (Conv2DTranspose)          (None, 60, 60, 32)   8224        dp41_2[0][0]
# __________________________________________________________________________________________________
# conv42_1 (Conv2D)               (None, 30, 30, 64)   73792       merge42[0][0]
# __________________________________________________________________________________________________
# merge32 (Concatenate)           (None, 60, 60, 64)   0           up32[0][0]
#                                                                  dp31_2[0][0]
# __________________________________________________________________________________________________
# up22 (Conv2DTranspose)          (None, 120, 120, 16) 2064        dp31_2[0][0]
# __________________________________________________________________________________________________
# dp42_1 (Dropout)                (None, 30, 30, 64)   0           conv42_1[0][0]
# __________________________________________________________________________________________________
# conv32_1 (Conv2D)               (None, 60, 60, 32)   18464       merge32[0][0]
# __________________________________________________________________________________________________
# merge22 (Concatenate)           (None, 120, 120, 32) 0           up22[0][0]
#                                                                  dp21_2[0][0]
# __________________________________________________________________________________________________
# up12 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp21_2[0][0]
# __________________________________________________________________________________________________
# conv42_2 (Conv2D)               (None, 30, 30, 64)   36928       dp42_1[0][0]
# __________________________________________________________________________________________________
# dp32_1 (Dropout)                (None, 60, 60, 32)   0           conv32_1[0][0]
# __________________________________________________________________________________________________
# conv22_1 (Conv2D)               (None, 120, 120, 16) 4624        merge22[0][0]
# __________________________________________________________________________________________________
# merge12 (Concatenate)           (None, 240, 240, 16) 0           up12[0][0]
#                                                                  dp11_2[0][0]
# __________________________________________________________________________________________________
# dp42_2 (Dropout)                (None, 30, 30, 64)   0           conv42_2[0][0]
# __________________________________________________________________________________________________
# conv32_2 (Conv2D)               (None, 60, 60, 32)   9248        dp32_1[0][0]
# __________________________________________________________________________________________________
# dp22_1 (Dropout)                (None, 120, 120, 16) 0           conv22_1[0][0]
# __________________________________________________________________________________________________
# conv12_1 (Conv2D)               (None, 240, 240, 8)  1160        merge12[0][0]
# __________________________________________________________________________________________________
# up33 (Conv2DTranspose)          (None, 60, 60, 32)   8224        dp42_2[0][0]
# __________________________________________________________________________________________________
# dp32_2 (Dropout)                (None, 60, 60, 32)   0           conv32_2[0][0]
# __________________________________________________________________________________________________
# conv22_2 (Conv2D)               (None, 120, 120, 16) 2320        dp22_1[0][0]
# __________________________________________________________________________________________________
# dp12_1 (Dropout)                (None, 240, 240, 8)  0           conv12_1[0][0]
# __________________________________________________________________________________________________
# merge33 (Concatenate)           (None, 60, 60, 96)   0           up33[0][0]
#                                                                  dp31_2[0][0]
#                                                                  dp32_2[0][0]
# __________________________________________________________________________________________________
# dp22_2 (Dropout)                (None, 120, 120, 16) 0           conv22_2[0][0]
# __________________________________________________________________________________________________
# up23 (Conv2DTranspose)          (None, 120, 120, 16) 2064        dp32_2[0][0]
# __________________________________________________________________________________________________
# conv12_2 (Conv2D)               (None, 240, 240, 8)  584         dp12_1[0][0]
# __________________________________________________________________________________________________
# conv33_1 (Conv2D)               (None, 60, 60, 32)   27680       merge33[0][0]
# __________________________________________________________________________________________________
# merge23 (Concatenate)           (None, 120, 120, 48) 0           up23[0][0]
#                                                                  dp21_2[0][0]
#                                                                  dp22_2[0][0]
# __________________________________________________________________________________________________
# dp12_2 (Dropout)                (None, 240, 240, 8)  0           conv12_2[0][0]
# __________________________________________________________________________________________________
# up13 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp22_2[0][0]
# __________________________________________________________________________________________________
# dp33_1 (Dropout)                (None, 60, 60, 32)   0           conv33_1[0][0]
# __________________________________________________________________________________________________
# conv23_1 (Conv2D)               (None, 120, 120, 16) 6928        merge23[0][0]
# __________________________________________________________________________________________________
# merge13 (Concatenate)           (None, 240, 240, 24) 0           up13[0][0]
#                                                                  dp11_2[0][0]
#                                                                  dp12_2[0][0]
# __________________________________________________________________________________________________
# conv33_2 (Conv2D)               (None, 60, 60, 32)   9248        dp33_1[0][0]
# __________________________________________________________________________________________________
# dp23_1 (Dropout)                (None, 120, 120, 16) 0           conv23_1[0][0]
# __________________________________________________________________________________________________
# conv13_1 (Conv2D)               (None, 240, 240, 8)  1736        merge13[0][0]
# __________________________________________________________________________________________________
# dp33_2 (Dropout)                (None, 60, 60, 32)   0           conv33_2[0][0]
# __________________________________________________________________________________________________
# conv23_2 (Conv2D)               (None, 120, 120, 16) 2320        dp23_1[0][0]
# __________________________________________________________________________________________________
# dp13_1 (Dropout)                (None, 240, 240, 8)  0           conv13_1[0][0]
# __________________________________________________________________________________________________
# up24 (Conv2DTranspose)          (None, 120, 120, 16) 2064        dp33_2[0][0]
# __________________________________________________________________________________________________
# dp23_2 (Dropout)                (None, 120, 120, 16) 0           conv23_2[0][0]
# __________________________________________________________________________________________________
# conv13_2 (Conv2D)               (None, 240, 240, 8)  584         dp13_1[0][0]
# __________________________________________________________________________________________________
# merge24 (Concatenate)           (None, 120, 120, 64) 0           up24[0][0]
#                                                                  dp21_2[0][0]
#                                                                  dp22_2[0][0]
#                                                                  dp23_2[0][0]
# __________________________________________________________________________________________________
# dp13_2 (Dropout)                (None, 240, 240, 8)  0           conv13_2[0][0]
# __________________________________________________________________________________________________
# up14 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp23_2[0][0]
# __________________________________________________________________________________________________
# conv24_1 (Conv2D)               (None, 120, 120, 16) 9232        merge24[0][0]
# __________________________________________________________________________________________________
# merge14 (Concatenate)           (None, 240, 240, 32) 0           up14[0][0]
#                                                                  dp11_2[0][0]
#                                                                  dp12_2[0][0]
#                                                                  dp13_2[0][0]
# __________________________________________________________________________________________________
# dp24_1 (Dropout)                (None, 120, 120, 16) 0           conv24_1[0][0]
# __________________________________________________________________________________________________
# conv14_1 (Conv2D)               (None, 240, 240, 8)  2312        merge14[0][0]
# __________________________________________________________________________________________________
# conv24_2 (Conv2D)               (None, 120, 120, 16) 2320        dp24_1[0][0]
# __________________________________________________________________________________________________
# dp14_1 (Dropout)                (None, 240, 240, 8)  0           conv14_1[0][0]
# __________________________________________________________________________________________________
# dp24_2 (Dropout)                (None, 120, 120, 16) 0           conv24_2[0][0]
# __________________________________________________________________________________________________
# conv14_2 (Conv2D)               (None, 240, 240, 8)  584         dp14_1[0][0]
# __________________________________________________________________________________________________
# up15 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp24_2[0][0]
# __________________________________________________________________________________________________
# dp14_2 (Dropout)                (None, 240, 240, 8)  0           conv14_2[0][0]
# __________________________________________________________________________________________________
# merge15 (Concatenate)           (None, 240, 240, 40) 0           up15[0][0]
#                                                                  dp11_2[0][0]
#                                                                  dp12_2[0][0]
#                                                                  dp13_2[0][0]
#                                                                  dp14_2[0][0]
# __________________________________________________________________________________________________
# conv15_1 (Conv2D)               (None, 240, 240, 8)  2888        merge15[0][0]
# __________________________________________________________________________________________________
# dp15_1 (Dropout)                (None, 240, 240, 8)  0           conv15_1[0][0]
# __________________________________________________________________________________________________
# conv15_2 (Conv2D)               (None, 240, 240, 8)  584         dp15_1[0][0]
# __________________________________________________________________________________________________
# dp15_2 (Dropout)                (None, 240, 240, 8)  0           conv15_2[0][0]
# __________________________________________________________________________________________________
# output_4 (Conv2D)               (None, 240, 240, 4)  36          dp15_2[0][0]
# ==================================================================================================
# Total params: 566,172
# Trainable params: 566,172
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:75: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("ma..., outputs=[<tf.Tenso...)`

# %%
import os
import cv2
import numpy as np

# %%
# Function to convert image from greyscale to one hot (i.e. 4 channels)
def convertToOneHot(image):
    num_classes = 4
    shape = image.shape[:2]+(num_classes,)
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c]==0:
          encoded_image[r][c][0] = 1
        elif image[r][c]==85:
          encoded_image[r][c][1] = 1
        elif image[r][c]==170:
          encoded_image[r][c][2] = 1
        else:
          encoded_image[r][c][3] = 1
    return encoded_image

# %%
# Function to convert back from one hot image to greyscale
def convertFromOneHot(image):
    shape = image.shape[:2]
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c][0] == 1:
          encoded_image[r][c] = 0
        elif image[r][c][1] == 1:
          encoded_image[r][c] = 85
        elif image[r][c][2] == 1:
          encoded_image[r][c] = 170
        else:
          encoded_image[r][c] = 255
    return encoded_image

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/4 Class ER"

# Train set patients: 230 263 239 242 
TrainX_1 = np.load(PATH + '/ER IHC 239 Images.npy')
TrainY_1 = np.load(PATH + '/ER IHC 239 Masks.npy')
TrainX_2 = np.load(PATH + '/ER IHC 263 Images.npy')
TrainY_2 = np.load(PATH + '/ER IHC 263 Masks.npy')
TrainX_3 = np.load(PATH + '/ER IHC 242 Images.npy')
TrainY_3 = np.load(PATH + '/ER IHC 242 Masks.npy')
TrainX_4 = np.load(PATH + '/ER IHC 230 Images.npy')
TrainY_4 = np.load(PATH + '/ER IHC 230 Masks.npy')

# Test set patients: 221 246 232
TestX_1 = np.load(PATH + '/ER IHC 221 Images.npy')
TestY_1 = np.load(PATH + '/ER IHC 221 Masks.npy')
TestX_2 = np.load(PATH + '/ER IHC 246 Images.npy')
TestY_2 = np.load(PATH + '/ER IHC 246 Masks.npy')
TestX_3 = np.load(PATH + '/ER IHC 232 Images.npy')
TestY_3 = np.load(PATH + '/ER IHC 232 Masks.npy')

# %%
np.unique(TestY_3)
# Out:
# array([  0.,  85., 170., 255.])

# %%
TrainX = np.concatenate((TrainX_1, TrainX_2, TrainX_3, TrainX_4), axis=0)
TrainGroundTruth = np.concatenate((TrainY_1, TrainY_2, TrainY_3, TrainY_4), axis=0)
TrainY = []

for img in TrainGroundTruth:
  encoded_img = convertToOneHot(img)
  TrainY.append(encoded_img)

TrainY = np.asarray(TrainY)

TestX = np.concatenate((TestX_1, TestX_2, TestX_3), axis=0)
TestGroundTruth = np.concatenate((TestY_1, TestY_2, TestY_3), axis=0)
TestY = []

for img in TestGroundTruth:
  encoded_img = convertToOneHot(img)
  TestY.append(encoded_img)

TestY = np.asarray(TestY)

ValidX = TrainX[1800:, : ]
ValidY = TrainY[1800:, : ]

TrainX = TrainX[0:1800, : ]
TrainY = TrainY[0:1800, : ]

print(TrainX.shape)
print(TrainY.shape)
print(TestX.shape)
print(TestY.shape)
print(ValidX.shape)
print(ValidY.shape)
np.unique(TestY)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 4)
# (1440, 240, 240, 3)
# (1440, 240, 240, 4)
# (120, 240, 240, 3)
# (120, 240, 240, 4)
# array([0, 1], dtype=uint8)

# %%
TrainX = np.reshape(TrainX,(-1,240, 240,3))
TrainY = np.reshape(TrainY,(-1,240, 240,4))

TrainX = TrainX.astype('float32')/255

TestX = np.reshape(TestX,(-1,240, 240,3))
TestY = np.reshape(TestY,(-1,240, 240,4))

TestX = TestX.astype('float32')/255

ValidX = np.reshape(ValidX,(-1,240, 240,3))
ValidY = np.reshape(ValidY,(-1,240, 240,4))

ValidX = ValidX.astype('float32')/255

# %%
print(TrainX.shape)
print(TrainY.shape)

print(TestX.shape)
print(TestY.shape)

print(ValidX.shape)
print(ValidY.shape)

np.unique(TestY)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 4)
# (1440, 240, 240, 3)
# (1440, 240, 240, 4)
# (120, 240, 240, 3)
# (120, 240, 240, 4)
# array([0, 1], dtype=uint8)

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
import math
from keras.callbacks import EarlyStopping,ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='auto', verbose=1, patience=30)
mc = ModelCheckpoint('Checkpoint.h5', monitor='val_loss', mode='auto', verbose=1, save_best_only=True)

# %%
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def combined_loss(y_true, y_pred):
  return (1*K.categorical_crossentropy(y_true, y_pred))+(0.5*tversky_loss(y_true, y_pred))

def loss(y_true, y_pred):
  return (1*K.categorical_crossentropy(y_true, y_pred))

# %%
optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=True)

# %%
model.compile(loss= combined_loss, optimizer=optimizer, metrics=[dice_coef,'accuracy',tversky_loss, loss, combined_loss])

# %%
TrainY.shape
# Out:
# (1800, 240, 240, 4)

# %%
num_epoch = 100;
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER"
history = model.fit(TrainX, TrainY, epochs=num_epoch, validation_data=(ValidX, ValidY), shuffle=True,batch_size=16,callbacks=[es,mc])
model.save(MODELS_PATH + '/NestedUNET_ER_20_03_21_CombinedLoss.h5')
# Out:
# Train on 1800 samples, validate on 120 samples
# Epoch 1/100
# 1800/1800 [==============================] - 23s 13ms/step - loss: 2.8382 - dice_coef: 0.7410 - acc: 0.7656 - tversky_loss: 2.6711 - loss_1: 1.3355 - combined_loss: 2.6710 - val_loss: 1.7417 - val_dice_coef: 0.9869 - val_acc: 0.9879 - val_tversky_loss: 2.9637 - val_loss_1: 0.1099 - val_combined_loss: 1.5918
#
# Epoch 00001: val_loss improved from inf to 1.74168, saving model to Checkpoint.h5
# Epoch 2/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.7724 - dice_coef: 0.8447 - acc: 0.8726 - tversky_loss: 2.3740 - loss_1: 0.4508 - combined_loss: 1.6378 - val_loss: 1.7291 - val_dice_coef: 0.9884 - val_acc: 0.9883 - val_tversky_loss: 2.9617 - val_loss_1: 0.1281 - val_combined_loss: 1.6089
#
# Epoch 00002: val_loss improved from 1.74168 to 1.72913, saving model to Checkpoint.h5
# Epoch 3/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.6188 - dice_coef: 0.8624 - acc: 0.8930 - tversky_loss: 2.2734 - loss_1: 0.3732 - combined_loss: 1.5099 - val_loss: 1.6827 - val_dice_coef: 0.9877 - val_acc: 0.9877 - val_tversky_loss: 2.9509 - val_loss_1: 0.1090 - val_combined_loss: 1.5844
#
# Epoch 00003: val_loss improved from 1.72913 to 1.68274, saving model to Checkpoint.h5
# Epoch 4/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.5366 - dice_coef: 0.8688 - acc: 0.9006 - tversky_loss: 2.2054 - loss_1: 0.3439 - combined_loss: 1.4466 - val_loss: 1.6029 - val_dice_coef: 0.9889 - val_acc: 0.9887 - val_tversky_loss: 2.8318 - val_loss_1: 0.1045 - val_combined_loss: 1.5204
#
# Epoch 00004: val_loss improved from 1.68274 to 1.60291, saving model to Checkpoint.h5
# Epoch 5/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.4574 - dice_coef: 0.8772 - acc: 0.9085 - tversky_loss: 2.0921 - loss_1: 0.3341 - combined_loss: 1.3802 - val_loss: 1.5506 - val_dice_coef: 0.9881 - val_acc: 0.9878 - val_tversky_loss: 2.8275 - val_loss_1: 0.0644 - val_combined_loss: 1.4781
#
# Epoch 00005: val_loss improved from 1.60291 to 1.55056, saving model to Checkpoint.h5
# Epoch 6/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.3999 - dice_coef: 0.8833 - acc: 0.9147 - tversky_loss: 2.0169 - loss_1: 0.3229 - combined_loss: 1.3314 - val_loss: 1.5574 - val_dice_coef: 0.9675 - val_acc: 0.9773 - val_tversky_loss: 2.8419 - val_loss_1: 0.0718 - val_combined_loss: 1.4927
#
# Epoch 00006: val_loss did not improve from 1.55056
# Epoch 7/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.3735 - dice_coef: 0.8856 - acc: 0.9169 - tversky_loss: 1.9919 - loss_1: 0.3155 - combined_loss: 1.3115 - val_loss: 1.5193 - val_dice_coef: 0.9800 - val_acc: 0.9851 - val_tversky_loss: 2.8235 - val_loss_1: 0.0484 - val_combined_loss: 1.4602
#
# Epoch 00007: val_loss improved from 1.55056 to 1.51929, saving model to Checkpoint.h5
# Epoch 8/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.3614 - dice_coef: 0.8866 - acc: 0.9177 - tversky_loss: 1.9848 - loss_1: 0.3116 - combined_loss: 1.3040 - val_loss: 1.5406 - val_dice_coef: 0.9840 - val_acc: 0.9879 - val_tversky_loss: 2.8800 - val_loss_1: 0.0457 - val_combined_loss: 1.4857
#
# Epoch 00008: val_loss did not improve from 1.51929
# Epoch 9/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.3470 - dice_coef: 0.8875 - acc: 0.9183 - tversky_loss: 1.9801 - loss_1: 0.3043 - combined_loss: 1.2943 - val_loss: 1.7676 - val_dice_coef: 0.8630 - val_acc: 0.9501 - val_tversky_loss: 3.0032 - val_loss_1: 0.2152 - val_combined_loss: 1.7168
#
# Epoch 00009: val_loss did not improve from 1.51929
# Epoch 10/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.3199 - dice_coef: 0.8898 - acc: 0.9198 - tversky_loss: 1.9472 - loss_1: 0.2969 - combined_loss: 1.2705 - val_loss: 1.6234 - val_dice_coef: 0.9292 - val_acc: 0.9724 - val_tversky_loss: 2.9329 - val_loss_1: 0.1089 - val_combined_loss: 1.5753
#
# Epoch 00010: val_loss did not improve from 1.51929
# Epoch 11/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.3069 - dice_coef: 0.8908 - acc: 0.9210 - tversky_loss: 1.9364 - loss_1: 0.2916 - combined_loss: 1.2598 - val_loss: 1.9237 - val_dice_coef: 0.7873 - val_acc: 0.9140 - val_tversky_loss: 3.0700 - val_loss_1: 0.3423 - val_combined_loss: 1.8773
#
# Epoch 00011: val_loss did not improve from 1.51929
# Epoch 12/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2967 - dice_coef: 0.8925 - acc: 0.9217 - tversky_loss: 1.9292 - loss_1: 0.2865 - combined_loss: 1.2511 - val_loss: 1.7271 - val_dice_coef: 0.8706 - val_acc: 0.9607 - val_tversky_loss: 2.9977 - val_loss_1: 0.1834 - val_combined_loss: 1.6822
#
# Epoch 00012: val_loss did not improve from 1.51929
# Epoch 13/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2868 - dice_coef: 0.8932 - acc: 0.9225 - tversky_loss: 1.9188 - loss_1: 0.2837 - combined_loss: 1.2431 - val_loss: 1.8724 - val_dice_coef: 0.7961 - val_acc: 0.9375 - val_tversky_loss: 3.0650 - val_loss_1: 0.2968 - val_combined_loss: 1.8293
#
# Epoch 00013: val_loss did not improve from 1.51929
# Epoch 14/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2787 - dice_coef: 0.8942 - acc: 0.9226 - tversky_loss: 1.9077 - loss_1: 0.2824 - combined_loss: 1.2362 - val_loss: 1.7414 - val_dice_coef: 0.8567 - val_acc: 0.9656 - val_tversky_loss: 3.0166 - val_loss_1: 0.1913 - val_combined_loss: 1.6996
#
# Epoch 00014: val_loss did not improve from 1.51929
# Epoch 15/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2659 - dice_coef: 0.8948 - acc: 0.9234 - tversky_loss: 1.8920 - loss_1: 0.2786 - combined_loss: 1.2246 - val_loss: 2.3678 - val_dice_coef: 0.6321 - val_acc: 0.7647 - val_tversky_loss: 3.1954 - val_loss_1: 0.7287 - val_combined_loss: 2.3264
#
# Epoch 00015: val_loss did not improve from 1.51929
# Epoch 16/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2667 - dice_coef: 0.8951 - acc: 0.9233 - tversky_loss: 1.8958 - loss_1: 0.2784 - combined_loss: 1.2263 - val_loss: 1.7561 - val_dice_coef: 0.8441 - val_acc: 0.9750 - val_tversky_loss: 3.0312 - val_loss_1: 0.2012 - val_combined_loss: 1.7167
#
# Epoch 00016: val_loss did not improve from 1.51929
# Epoch 17/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2553 - dice_coef: 0.8955 - acc: 0.9233 - tversky_loss: 1.8844 - loss_1: 0.2743 - combined_loss: 1.2165 - val_loss: 1.9108 - val_dice_coef: 0.7609 - val_acc: 0.9479 - val_tversky_loss: 3.0973 - val_loss_1: 0.3235 - val_combined_loss: 1.8721
#
# Epoch 00017: val_loss did not improve from 1.51929
# Epoch 18/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2472 - dice_coef: 0.8969 - acc: 0.9243 - tversky_loss: 1.8802 - loss_1: 0.2687 - combined_loss: 1.2087 - val_loss: 1.9960 - val_dice_coef: 0.7191 - val_acc: 0.9271 - val_tversky_loss: 3.1265 - val_loss_1: 0.3941 - val_combined_loss: 1.9574
#
# Epoch 00018: val_loss did not improve from 1.51929
# Epoch 19/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2604 - dice_coef: 0.8962 - acc: 0.9236 - tversky_loss: 1.9009 - loss_1: 0.2711 - combined_loss: 1.2215 - val_loss: 1.6780 - val_dice_coef: 0.8862 - val_acc: 0.9837 - val_tversky_loss: 3.0034 - val_loss_1: 0.1375 - val_combined_loss: 1.6392
#
# Epoch 00019: val_loss did not improve from 1.51929
# Epoch 20/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2460 - dice_coef: 0.8974 - acc: 0.9245 - tversky_loss: 1.8835 - loss_1: 0.2663 - combined_loss: 1.2081 - val_loss: 1.8183 - val_dice_coef: 0.8080 - val_acc: 0.9672 - val_tversky_loss: 3.0605 - val_loss_1: 0.2507 - val_combined_loss: 1.7809
#
# Epoch 00020: val_loss did not improve from 1.51929
# Epoch 21/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2361 - dice_coef: 0.8984 - acc: 0.9251 - tversky_loss: 1.8661 - loss_1: 0.2662 - combined_loss: 1.1992 - val_loss: 1.9083 - val_dice_coef: 0.7605 - val_acc: 0.9463 - val_tversky_loss: 3.0952 - val_loss_1: 0.3244 - val_combined_loss: 1.8720
#
# Epoch 00021: val_loss did not improve from 1.51929
# Epoch 22/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2435 - dice_coef: 0.8982 - acc: 0.9246 - tversky_loss: 1.8700 - loss_1: 0.2719 - combined_loss: 1.2069 - val_loss: 1.7948 - val_dice_coef: 0.8186 - val_acc: 0.9775 - val_tversky_loss: 3.0584 - val_loss_1: 0.2293 - val_combined_loss: 1.7585
#
# Epoch 00022: val_loss did not improve from 1.51929
# Epoch 23/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2338 - dice_coef: 0.8986 - acc: 0.9251 - tversky_loss: 1.8602 - loss_1: 0.2675 - combined_loss: 1.1976 - val_loss: 1.6977 - val_dice_coef: 0.8747 - val_acc: 0.9786 - val_tversky_loss: 3.0099 - val_loss_1: 0.1567 - val_combined_loss: 1.6616
#
# Epoch 00023: val_loss did not improve from 1.51929
# Epoch 24/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2364 - dice_coef: 0.8990 - acc: 0.9249 - tversky_loss: 1.8665 - loss_1: 0.2675 - combined_loss: 1.2008 - val_loss: 2.1128 - val_dice_coef: 0.6511 - val_acc: 0.9249 - val_tversky_loss: 3.1824 - val_loss_1: 0.4861 - val_combined_loss: 2.0773
#
# Epoch 00024: val_loss did not improve from 1.51929
# Epoch 25/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2301 - dice_coef: 0.9003 - acc: 0.9253 - tversky_loss: 1.8584 - loss_1: 0.2656 - combined_loss: 1.1948 - val_loss: 1.9807 - val_dice_coef: 0.7146 - val_acc: 0.9585 - val_tversky_loss: 3.1358 - val_loss_1: 0.3774 - val_combined_loss: 1.9453
#
# Epoch 00025: val_loss did not improve from 1.51929
# Epoch 26/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2299 - dice_coef: 0.8998 - acc: 0.9249 - tversky_loss: 1.8592 - loss_1: 0.2655 - combined_loss: 1.1951 - val_loss: 2.8452 - val_dice_coef: 0.4104 - val_acc: 0.5260 - val_tversky_loss: 3.3990 - val_loss_1: 1.1114 - val_combined_loss: 2.8109
#
# Epoch 00026: val_loss did not improve from 1.51929
# Epoch 27/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2205 - dice_coef: 0.9007 - acc: 0.9258 - tversky_loss: 1.8487 - loss_1: 0.2622 - combined_loss: 1.1865 - val_loss: 3.5682 - val_dice_coef: 0.2736 - val_acc: 0.3136 - val_tversky_loss: 3.5564 - val_loss_1: 1.7561 - val_combined_loss: 3.5343
#
# Epoch 00027: val_loss did not improve from 1.51929
# Epoch 28/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2279 - dice_coef: 0.8998 - acc: 0.9248 - tversky_loss: 1.8518 - loss_1: 0.2681 - combined_loss: 1.1941 - val_loss: 1.8669 - val_dice_coef: 0.7732 - val_acc: 0.9722 - val_tversky_loss: 3.0885 - val_loss_1: 0.2889 - val_combined_loss: 1.8331
#
# Epoch 00028: val_loss did not improve from 1.51929
# Epoch 29/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2141 - dice_coef: 0.9017 - acc: 0.9261 - tversky_loss: 1.8316 - loss_1: 0.2642 - combined_loss: 1.1800 - val_loss: 2.5561 - val_dice_coef: 0.4835 - val_acc: 0.6549 - val_tversky_loss: 3.3291 - val_loss_1: 0.8574 - val_combined_loss: 2.5220
#
# Epoch 00029: val_loss did not improve from 1.51929
# Epoch 30/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.2254 - dice_coef: 0.9004 - acc: 0.9247 - tversky_loss: 1.8461 - loss_1: 0.2685 - combined_loss: 1.1915 - val_loss: 2.3803 - val_dice_coef: 0.5752 - val_acc: 0.6975 - val_tversky_loss: 3.2490 - val_loss_1: 0.7220 - val_combined_loss: 2.3465
#
# Epoch 00030: val_loss did not improve from 1.51929
# Epoch 31/100
# 1800/1800 [==============================] - 17s 10ms/step - loss: 1.2246 - dice_coef: 0.9007 - acc: 0.9245 - tversky_loss: 1.8351 - loss_1: 0.2732 - combined_loss: 1.1907 - val_loss: 2.5193 - val_dice_coef: 0.5157 - val_acc: 0.6589 - val_tversky_loss: 3.2998 - val_loss_1: 0.8356 - val_combined_loss: 2.4855
#
# Epoch 00031: val_loss did not improve from 1.51929
# Epoch 32/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.2211 - dice_coef: 0.9008 - acc: 0.9244 - tversky_loss: 1.8341 - loss_1: 0.2702 - combined_loss: 1.1873 - val_loss: 2.4859 - val_dice_coef: 0.5408 - val_acc: 0.6672 - val_tversky_loss: 3.2875 - val_loss_1: 0.8083 - val_combined_loss: 2.4521
#
# Epoch 00032: val_loss did not improve from 1.51929
# Epoch 33/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.2126 - dice_coef: 0.9019 - acc: 0.9249 - tversky_loss: 1.8165 - loss_1: 0.2704 - combined_loss: 1.1787 - val_loss: 3.5168 - val_dice_coef: 0.2665 - val_acc: 0.2712 - val_tversky_loss: 3.5684 - val_loss_1: 1.6986 - val_combined_loss: 3.4828
#
# Epoch 00033: val_loss did not improve from 1.51929
# Epoch 34/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.2193 - dice_coef: 0.9023 - acc: 0.9254 - tversky_loss: 1.8264 - loss_1: 0.2720 - combined_loss: 1.1852 - val_loss: 1.9475 - val_dice_coef: 0.7307 - val_acc: 0.9586 - val_tversky_loss: 3.1199 - val_loss_1: 0.3533 - val_combined_loss: 1.9133
#
# Epoch 00034: val_loss did not improve from 1.51929
# Epoch 35/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.2086 - dice_coef: 0.9021 - acc: 0.9244 - tversky_loss: 1.8069 - loss_1: 0.2706 - combined_loss: 1.1740 - val_loss: 2.4891 - val_dice_coef: 0.5164 - val_acc: 0.6738 - val_tversky_loss: 3.3014 - val_loss_1: 0.8037 - val_combined_loss: 2.4544
#
# Epoch 00035: val_loss did not improve from 1.51929
# Epoch 36/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.2262 - dice_coef: 0.9004 - acc: 0.9233 - tversky_loss: 1.8232 - loss_1: 0.2796 - combined_loss: 1.1912 - val_loss: 1.5562 - val_dice_coef: 0.9633 - val_acc: 0.9854 - val_tversky_loss: 2.8976 - val_loss_1: 0.0721 - val_combined_loss: 1.5209
#
# Epoch 00036: val_loss did not improve from 1.51929
# Epoch 37/100
# 1800/1800 [==============================] - 17s 9ms/step - loss: 1.2084 - dice_coef: 0.9024 - acc: 0.9248 - tversky_loss: 1.7997 - loss_1: 0.2733 - combined_loss: 1.1731 - val_loss: 2.3833 - val_dice_coef: 0.5967 - val_acc: 0.6186 - val_tversky_loss: 3.2272 - val_loss_1: 0.7346 - val_combined_loss: 2.3482
#
# Epoch 00037: val_loss did not improve from 1.51929
# Epoch 00037: early stopping

# %%
train_loss = history.history['loss']
train_acc = history.history['acc']
val_loss = history.history['val_loss']
val_acc = history.history['val_acc']
xc=range(len(train_loss))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_loss)
plt.plot(xc, val_loss)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(['train','val'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_acc)
plt.plot(xc, val_acc)
plt.xlabel("Epoch")
plt.ylabel("Acc")
plt.legend(['train','val'])

# %%
# MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models"
# model = keras.models.load_model(MODELS_PATH+'/UNET_ER_20_03_03_v5.h5',custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

# %%
# Function to find the most probable class of an image pixel by pixel
def ClassFinder(img):
  result = np.zeros(img.shape, dtype=np.uint8)
  for r in range(len(img)):
    for c in range(len(img[0])):
      idx = np.argmax(img[r][c])
      result[r][c][idx]=1
      
  return result

# %%
train_result = model.predict(TrainX, batch_size=16)
print(np.shape(train_result))
Train_predict = [ ]
for img in train_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_predict.append(encoded_img)

Predicted_images = np.asarray(Train_predict)
print(Predicted_images.shape)
np.unique(Predicted_images)
# dice = dc(train_result, TrainY)
# pre  = precision(train_result,TrainY)
# re   = recall(train_result,TrainY)
# print('Train dc: '  + str(dice))
# print('Train pre: ' + str(pre))
# print('Train re: '  + str(re))
# Out:
# (1800, 240, 240, 4)
# (1800, 240, 240)
# array([  0,  85, 170, 255], dtype=uint8)

# %%
test_result = model.predict(TestX, batch_size=16)
print(np.shape(test_result))

Test_predict = [ ]
for img in test_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_predict.append(encoded_img)

Predicted_images_test = np.asarray(Test_predict)
print(Predicted_images_test.shape)
np.unique(Predicted_images_test)
# dice = dc(test_result, TestY)
# pre  = precision(test_result,TestY)
# re   = recall(test_result,TestY)
# print('Test dc: '  + str(dice))
# print('Test pre: ' + str(pre))
# print('Test re: '  + str(re))
# Out:
# (1440, 240, 240, 4)
# (1440, 240, 240)
# array([  0,  85, 170, 255], dtype=uint8)

# %%
from sklearn.metrics import confusion_matrix
def get_confusion_matrix(Actual, Predicted):
  ActualY = np.reshape(Actual,(-1, Actual.shape[3]))
  PredY = np.reshape(Predicted,(-1, Predicted.shape[3]))
  matrix = confusion_matrix(ActualY.argmax(axis = 1), PredY.argmax(axis = 1))
  return matrix

def get_precision(confusion_matrix):
  precision = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 0)
  nan_indices = np.isnan(precision)
  precision[nan_indices] = 0
  return precision

def get_recall(confusion_matrix):
  recall = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 1)
  nan_indices = np.isnan(recall)
  recall[nan_indices] = 0
  return recall

# %%
test_matrix = get_confusion_matrix(TestY, test_result)
train_matrix = get_confusion_matrix(TrainY, train_result)
print(test_matrix)
print(train_matrix)
# TestY.shape[3]
# test_result.shape
# Out:
# [[65463590 10274497   826457     1716]
#  [  201222   236628   223979        0]
#  [  427358   313272  1958685      146]
#  [  161857    66402  2712254    75937]]
# [[60578343 22527739  5042890   815828]
#  [  265537   284446   801567    23403]
#  [  421744   249522  2425890  1250806]
#  [  509946   132968  3254126  5095245]]

# %%
np.unique(Predicted_images_test)
# Out:
# array([  0,  85, 170, 255], dtype=uint8)

# %%
test_precision = get_precision(test_matrix)
print('Test Precision')
print(test_precision)
test_recall = get_recall(test_matrix)
print('Test Recall')
print(test_recall)
train_precision = get_precision(train_matrix)
print('Train Precision')
print(train_precision)
train_recall = get_recall(train_matrix)
print('Train Recall')
print(train_recall)
# Out:
# Test Precision
# [0.9880696  0.02172733 0.34234515 0.97606653]
# Test Recall
# [0.85499266 0.35753646 0.72558374 0.02517429]
# Train Precision
# [0.98061973 0.01226342 0.210499   0.70912248]
# Train Recall
# [0.68092485 0.20687689 0.55793726 0.56662406]

# %%
# weight_matrix = np.zeros((3,1))
# weight_matrix[0] = 0.6
# weight_matrix[1] = 0.2
# weight_matrix[2] = 0.2
# print(weight_matrix.shape)

# %%
weight_matrix = np.zeros((4,1))
weight_matrix[0] = 1/3
weight_matrix[1] = 1/3
weight_matrix[2] = 1/3
weight_matrix[3] = 1/3
print(weight_matrix.shape)
# Out:
# (4, 1)

# %%
def get_overall_precision(precision, weights):
  final_precision = np.dot(precision,weights)
  return final_precision

def get_overall_recall(recall, weights):
  final_recall = np.dot(recall ,weights)
  return final_recall

# %%
final_test_precision  = get_overall_precision(test_precision, weight_matrix)
final_test_recall     = get_overall_recall(test_recall, weight_matrix)
final_train_precision = get_overall_precision(train_precision, weight_matrix)
final_train_recall    = get_overall_recall(train_recall, weight_matrix)
print('Final Test Precision')
print(final_test_precision)
print('Final Test Recall')
print(final_test_recall)
print('Final Train Precision')
print(final_train_precision)
print('Final Train Recall')
print(final_train_recall)
# Out:
# Final Test Precision
# [0.77606954]
# Final Test Recall
# [0.65442905]
# Final Train Precision
# [0.63750154]
# Final Train Recall
# [0.67078768]

# %%
from scipy.stats import hmean

def dice_coefficient(precision, recall):
  return hmean(np.asarray([precision , recall]))

# %%
test_dice_coeff = dice_coefficient(final_test_precision, final_test_recall)
print('Test Dice coeff')
print(test_dice_coeff)

train_dice_coeff = dice_coefficient(final_train_precision, final_train_recall)
print('Train Dice coeff')
print(train_dice_coeff)
# Out:
# Test Dice coeff
# [0.71007753]
# Train Dice coeff
# [0.65372117]

# %%
copy1  = np.copy(TestX [250])
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
copy3 = np.reshape(copy2,(240, 240,3))
Img = cv2.cvtColor(copy3,cv2.COLOR_BGR2RGB)

Mask = TestGroundTruth[250]

Predicted_Mask = Predicted_images_test[250] 

plt.subplot(131).imshow(Img)
plt.subplot(132).imshow(Mask,'gray')
plt.subplot(133).imshow(Predicted_Mask,'gray')

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask):
  num = mask.shape[0]/480
  for id in range(int(num)):
    temp = []
    for i in range(id, id+10):
      idx = i * 48
      final_output = mask[idx:idx+48]
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save("/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/Combined_Loss/ER1 Patient " + str(id), final_output)

# %%
# saving predicted outputs as numpy arrays for test images
saveNumpyOutput(Predicted_images)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 20   # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]

Mask_input = TestY[id:id+48]
Test_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Test_Actual)
print(Mask_input.shape)

final_output = Predicted_images_test[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 4)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0.  85. 170. 255.]

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 14  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]

Mask_input = TrainY[id:id+48]
Train_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Train_Actual)
print(Mask_input.shape)

final_output = Predicted_images[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 4)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0.  85. 170. 255.]
