# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from keras.layers import Activation,Conv2D,MaxPooling2D,UpSampling2D,Dense,BatchNormalization,Input,Reshape,multiply,add,Dropout,AveragePooling2D,GlobalAveragePooling2D,concatenate
from keras.layers.convolutional import Conv2DTranspose
from keras.models import Model														  
import keras.backend as K
from keras.regularizers import l2
from keras.engine import Layer,InputSpec
from keras.utils import conv_utils
from keras.layers import Activation,Conv2D,MaxPooling2D,UpSampling2D,Dense,BatchNormalization,Input,Reshape,multiply,add,Dropout,AveragePooling2D,GlobalAveragePooling2D,concatenate
from keras.layers.convolutional import Conv2DTranspose
from keras.models import Model														  
import keras.backend as K
from keras.regularizers import l2
from keras.engine import Layer,InputSpec
from keras.utils import conv_utils
# !pip install medpy
from keras.layers import *
from keras.models import Sequential
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from medpy.metric import dc, precision, recall
import keras
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Collecting medpy
#   Downloading https://files.pythonhosted.org/packages/3b/70/c1fd5dd60242eee81774696ea7ba4caafac2bad8f028bba94b1af83777d7/MedPy-0.4.0.tar.gz (151kB)
#      |████████████████████████████████| 153kB 3.4MB/s
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.17.5)
# Collecting SimpleITK>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/f8/d8/53338c34f71020725ffb3557846c80af96c29c03bc883551a2565aa68a7c/SimpleITK-1.2.4-cp36-cp36m-manylinux1_x86_64.whl (42.5MB)
#      |████████████████████████████████| 42.5MB 71kB/s
# Building wheels for collected packages: medpy
#   Building wheel for medpy (setup.py) ... done
#   Created wheel for medpy: filename=MedPy-0.4.0-cp36-cp36m-linux_x86_64.whl size=753434 sha256=251c3d16cd25416b6a609065c7140cc6edf3928109ba05d18c4cc438d8469553
#   Stored in directory: /root/.cache/pip/wheels/8c/c9/9c/2c6281c7a72b9fb1570862a4f028af7ce38405008354fbf870
# Successfully built medpy
# Installing collected packages: SimpleITK, medpy
# Successfully installed SimpleITK-1.2.4 medpy-0.4.0

# %%
def BN_ReLU_Conv(inputs, n_filters, filter_size=3, dropout_p=0.2):

    '''Apply successivly BatchNormalization, ReLu nonlinearity, Convolution and Dropout (if dropout_p > 0)''' 
    l = BatchNormalization()(inputs)
    l = Activation('relu')(l)
    l = Conv2D(n_filters, filter_size, padding='same', kernel_initializer='he_uniform')(l)
    if dropout_p != 0.0:
      l = Dropout(dropout_p)(l)
    return l


def TransitionDown(inputs, n_filters, dropout_p=0.2):

  """ Apply first a BN_ReLu_conv layer with filter size = 1, and a max pooling with a factor 2  """
  l = BN_ReLU_Conv(inputs, n_filters, filter_size=1, dropout_p=dropout_p)
  l = MaxPooling2D((2,2))(l)
  return l

def TransitionUp(skip_connection, block_to_upsample, n_filters_keep):

    '''Performs upsampling on block_to_upsample by a factor 2 and concatenates it with the skip_connection'''

    #Upsample and concatenate with skip connection
    l = Conv2DTranspose(n_filters_keep, kernel_size=3, strides=2, padding='same', kernel_initializer='he_uniform')(block_to_upsample)
    l = concatenate([l, skip_connection], axis=-1)
    return l


def SoftmaxLayer(inputs, n_classes):
    """
    Performs 1x1 convolution followed by softmax nonlinearity
    The output will have the shape (batch_size  * n_rows * n_cols, n_classes)
    """
    l = Conv2D(n_classes, kernel_size=1, padding='same', kernel_initializer='he_uniform')(inputs)
#    l = Reshape((-1, n_classes))(l)
    l = Activation('softmax')(l)#or softmax for multi-class

    return l

# %%
def Tiramisu(

        input_shape=(240,240,3),

        n_classes = 3,

        n_filters_first_conv = 48,

        n_pool = 3,

        growth_rate = 16 ,

        n_layers_per_block =  [5 , 5, 5 , 5, 5 , 5 ,5 ],

        dropout_p = 0.2

        ):

    if type(n_layers_per_block) == list:

            print(len(n_layers_per_block))

    elif type(n_layers_per_block) == int:

            n_layers_per_block = [n_layers_per_block] * (2 * n_pool + 1)

    else:

        raise ValueError

        

#####################

# First Convolution #

#####################        

    inputs = Input(shape=input_shape)

    stack = Conv2D(filters=n_filters_first_conv, kernel_size=3, padding='same', kernel_initializer='he_uniform')(inputs)

    n_filters = n_filters_first_conv



#####################

# Downsampling path #

#####################     

    skip_connection_list = []

    

    for i in range(n_pool):
        print("i")
        print(i)

        for j in range(n_layers_per_block[i]):
            print(j)
            l = BN_ReLU_Conv(stack, growth_rate, dropout_p=dropout_p)

            stack = concatenate([stack, l])

            n_filters += growth_rate

        

        skip_connection_list.append(stack)        

        stack = TransitionDown(stack, n_filters, dropout_p)

    skip_connection_list = skip_connection_list[::-1]



    

#####################

#    Bottleneck     #

#####################     

    block_to_upsample=[]

    

    for j in range(n_layers_per_block[n_pool]):

        l = BN_ReLU_Conv(stack, growth_rate, dropout_p=dropout_p)

        block_to_upsample.append(l)

        stack = concatenate([stack,l])

    block_to_upsample = concatenate(block_to_upsample)



   

#####################

#  Upsampling path  #

#####################

    for i in range(n_pool):

        n_filters_keep = growth_rate * n_layers_per_block[n_pool + i ]

        stack = TransitionUp(skip_connection_list[i], block_to_upsample, n_filters_keep)

        

        block_to_upsample = []

        for j in range(n_layers_per_block[ n_pool + i + 1 ]):

            l = BN_ReLU_Conv(stack, growth_rate, dropout_p=dropout_p)

            block_to_upsample.append(l)

            stack = concatenate([stack, l])

        block_to_upsample = concatenate(block_to_upsample)



#####################

#  Softmax          #

#####################

    output = SoftmaxLayer(stack, n_classes)            

    model=Model(inputs = inputs, outputs = output)    

    model.summary()

    

    return model

# %%
model = Tiramisu()
# Out:
# 7
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# i
# 0
# 0
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 1
# 2
# 3
# 4
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# i
# 1
# 0
# 1
# 2
# 3
# 4
# i
# 2
# 0
# 1
# 2
# 3
# 4
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 240, 240, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 240, 240, 48) 1344        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 240, 240, 48) 192         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 240, 240, 48) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 240, 240, 16) 6928        activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 240, 240, 16) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 240, 240, 64) 0           conv2d_1[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 240, 240, 64) 256         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 240, 240, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 240, 240, 16) 9232        activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 240, 240, 16) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 240, 240, 80) 0           concatenate_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 240, 240, 80) 320         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 240, 240, 80) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 240, 240, 16) 11536       activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 240, 240, 16) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 240, 240, 96) 0           concatenate_2[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 240, 240, 96) 384         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 240, 240, 96) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 240, 240, 16) 13840       activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 240, 240, 16) 0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 240, 240, 112 0           concatenate_3[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 240, 240, 112 448         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 240, 240, 112 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 240, 240, 16) 16144       activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 240, 240, 16) 0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 240, 240, 128 0           concatenate_4[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 240, 240, 128 512         concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 240, 240, 128 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 240, 240, 128 16512       activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 240, 240, 128 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 120, 120, 128 0           dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 120, 120, 128 512         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 120, 120, 128 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 120, 120, 16) 18448       activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 120, 120, 16) 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 120, 120, 144 0           max_pooling2d_1[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 120, 120, 144 576         concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 120, 120, 144 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 120, 120, 16) 20752       activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 120, 120, 16) 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 120, 120, 160 0           concatenate_6[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 120, 120, 160 640         concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 120, 120, 160 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 120, 120, 16) 23056       activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 120, 120, 16) 0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 120, 120, 176 0           concatenate_7[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 120, 120, 176 704         concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 120, 120, 176 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 120, 120, 16) 25360       activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 120, 120, 16) 0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 120, 120, 192 0           concatenate_8[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 120, 120, 192 768         concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 120, 120, 192 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 120, 120, 16) 27664       activation_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 120, 120, 16) 0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 120, 120, 208 0           concatenate_9[0][0]
#                                                                  dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 120, 120, 208 832         concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 120, 120, 208 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 120, 120, 208 43472       activation_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 120, 120, 208 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 60, 60, 208)  0           dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 60, 60, 208)  832         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 60, 60, 208)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 60, 60, 16)   29968       activation_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 60, 60, 16)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 60, 60, 224)  0           max_pooling2d_2[0][0]
#                                                                  dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 60, 60, 224)  896         concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 60, 60, 224)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 60, 60, 16)   32272       activation_14[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 60, 60, 16)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 60, 60, 240)  0           concatenate_11[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 60, 60, 240)  960         concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 60, 60, 240)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 60, 60, 16)   34576       activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 60, 60, 16)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 60, 60, 256)  0           concatenate_12[0][0]
#                                                                  dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 60, 60, 256)  1024        concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 60, 60, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 60, 60, 16)   36880       activation_16[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 60, 60, 16)   0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 60, 60, 272)  0           concatenate_13[0][0]
#                                                                  dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 60, 60, 272)  1088        concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 60, 60, 272)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 60, 60, 16)   39184       activation_17[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 60, 60, 16)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 60, 60, 288)  0           concatenate_14[0][0]
#                                                                  dropout_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 60, 60, 288)  1152        concatenate_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 60, 60, 288)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 60, 60, 288)  83232       activation_18[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 60, 60, 288)  0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 30, 30, 288)  0           dropout_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 30, 30, 288)  1152        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 30, 30, 288)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 30, 30, 16)   41488       activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 30, 30, 16)   0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 30, 30, 304)  0           max_pooling2d_3[0][0]
#                                                                  dropout_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 30, 30, 304)  1216        concatenate_16[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 30, 30, 304)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 30, 30, 16)   43792       activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 30, 30, 16)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 30, 30, 320)  0           concatenate_16[0][0]
#                                                                  dropout_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 30, 30, 320)  1280        concatenate_17[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 30, 30, 320)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 30, 30, 16)   46096       activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 30, 30, 16)   0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 30, 30, 336)  0           concatenate_17[0][0]
#                                                                  dropout_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 30, 30, 336)  1344        concatenate_18[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 30, 30, 336)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 30, 30, 16)   48400       activation_22[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 30, 30, 16)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 30, 30, 352)  0           concatenate_18[0][0]
#                                                                  dropout_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 30, 30, 352)  1408        concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 30, 30, 352)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 30, 30, 16)   50704       activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 30, 30, 16)   0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 30, 30, 80)   0           dropout_19[0][0]
#                                                                  dropout_20[0][0]
#                                                                  dropout_21[0][0]
#                                                                  dropout_22[0][0]
#                                                                  dropout_23[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 60, 60, 80)   57680       concatenate_21[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 60, 60, 368)  0           conv2d_transpose_1[0][0]
#                                                                  concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 60, 60, 368)  1472        concatenate_22[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 60, 60, 368)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 60, 60, 16)   53008       activation_24[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 60, 60, 16)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 60, 60, 384)  0           concatenate_22[0][0]
#                                                                  dropout_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 60, 60, 384)  1536        concatenate_23[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 60, 60, 384)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 60, 60, 16)   55312       activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 60, 60, 16)   0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 60, 60, 400)  0           concatenate_23[0][0]
#                                                                  dropout_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 60, 60, 400)  1600        concatenate_24[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 60, 60, 400)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 60, 60, 16)   57616       activation_26[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 60, 60, 16)   0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 60, 60, 416)  0           concatenate_24[0][0]
#                                                                  dropout_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 60, 60, 416)  1664        concatenate_25[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 60, 60, 416)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 60, 60, 16)   59920       activation_27[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 60, 60, 16)   0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 60, 60, 432)  0           concatenate_25[0][0]
#                                                                  dropout_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 60, 60, 432)  1728        concatenate_26[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 60, 60, 432)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 60, 60, 16)   62224       activation_28[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 60, 60, 16)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 60, 60, 80)   0           dropout_24[0][0]
#                                                                  dropout_25[0][0]
#                                                                  dropout_26[0][0]
#                                                                  dropout_27[0][0]
#                                                                  dropout_28[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 120, 120, 80) 57680       concatenate_28[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 120, 120, 288 0           conv2d_transpose_2[0][0]
#                                                                  concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 120, 120, 288 1152        concatenate_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 120, 120, 288 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 120, 120, 16) 41488       activation_29[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 120, 120, 16) 0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 120, 120, 304 0           concatenate_29[0][0]
#                                                                  dropout_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 120, 120, 304 1216        concatenate_30[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 120, 120, 304 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 120, 120, 16) 43792       activation_30[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 120, 120, 16) 0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 120, 120, 320 0           concatenate_30[0][0]
#                                                                  dropout_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 120, 120, 320 1280        concatenate_31[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 120, 120, 320 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 120, 120, 16) 46096       activation_31[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 120, 120, 16) 0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 120, 120, 336 0           concatenate_31[0][0]
#                                                                  dropout_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 120, 120, 336 1344        concatenate_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 120, 120, 336 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 120, 120, 16) 48400       activation_32[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 120, 120, 16) 0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 120, 120, 352 0           concatenate_32[0][0]
#                                                                  dropout_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 120, 120, 352 1408        concatenate_33[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 120, 120, 352 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 120, 120, 16) 50704       activation_33[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 120, 120, 16) 0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 120, 120, 80) 0           dropout_29[0][0]
#                                                                  dropout_30[0][0]
#                                                                  dropout_31[0][0]
#                                                                  dropout_32[0][0]
#                                                                  dropout_33[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 240, 240, 80) 57680       concatenate_35[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 240, 240, 208 0           conv2d_transpose_3[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 240, 240, 208 832         concatenate_36[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 240, 240, 208 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 240, 240, 16) 29968       activation_34[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 240, 240, 16) 0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 240, 240, 224 0           concatenate_36[0][0]
#                                                                  dropout_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 240, 240, 224 896         concatenate_37[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 240, 240, 224 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 240, 240, 16) 32272       activation_35[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 240, 240, 16) 0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 240, 240, 240 0           concatenate_37[0][0]
#                                                                  dropout_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 240, 240, 240 960         concatenate_38[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 240, 240, 240 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 240, 240, 16) 34576       activation_36[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 240, 240, 16) 0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 240, 240, 256 0           concatenate_38[0][0]
#                                                                  dropout_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 240, 240, 256 1024        concatenate_39[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 240, 240, 256 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 240, 240, 16) 36880       activation_37[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 240, 240, 16) 0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 240, 240, 272 0           concatenate_39[0][0]
#                                                                  dropout_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 240, 240, 272 1088        concatenate_40[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 240, 240, 272 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 240, 240, 16) 39184       activation_38[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 240, 240, 16) 0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# concatenate_41 (Concatenate)    (None, 240, 240, 288 0           concatenate_40[0][0]
#                                                                  dropout_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 240, 240, 3)  867         concatenate_41[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 240, 240, 3)  0           conv2d_40[0][0]
# ==================================================================================================
# Total params: 1,623,923
# Trainable params: 1,605,075
# Non-trainable params: 18,848
# __________________________________________________________________________________________________

# %%
import os
import cv2
import numpy as np

# %%
# Function to convert image from greyscale to one hot (i.e. 3 channels)
def convertToOneHot(image):
    num_classes = 3
    shape = image.shape[:2]+(num_classes,)
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c]==0:
          encoded_image[r][c][0] = 1
        elif image[r][c]==128:
          encoded_image[r][c][1] = 1
        else:
          encoded_image[r][c][2] = 1
    return encoded_image

# %%
# Function to convert back from one hot image to greyscale
def convertFromOneHot(image):
    shape = image.shape[:2]
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c][0] == 1:
          encoded_image[r][c] = 0
        elif image[r][c][1] == 1:
          encoded_image[r][c] = 128
        else:
          encoded_image[r][c] = 255
    return encoded_image

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/3 Class"

# Train set patients: 230 232 239 242 
TrainX_1 = np.load(PATH + '/ER IHC 239 Images.npy')
TrainY_1 = np.load(PATH + '/ER IHC 239 Masks.npy')
TrainX_2 = np.load(PATH + '/ER IHC 232 Images.npy')
TrainY_2 = np.load(PATH + '/ER IHC 232 Masks.npy')
TrainX_3 = np.load(PATH + '/ER IHC 242 Images.npy')
TrainY_3 = np.load(PATH + '/ER IHC 242 Masks.npy')
TrainX_4 = np.load(PATH + '/ER IHC 230 Images.npy')
TrainY_4 = np.load(PATH + '/ER IHC 230 Masks.npy')

# Test set patients: 221 246 263
TestX_1 = np.load(PATH + '/ER IHC 221 Images.npy')
TestY_1 = np.load(PATH + '/ER IHC 221 Masks.npy')
TestX_2 = np.load(PATH + '/ER IHC 246 Images.npy')
TestY_2 = np.load(PATH + '/ER IHC 246 Masks.npy')
TestX_3 = np.load(PATH + '/ER IHC 263 Images.npy')
TestY_3 = np.load(PATH + '/ER IHC 263 Masks.npy')

# %%
np.unique(TestY_3)
# Out:
# array([  0., 128., 255.])

# %%
TrainX = np.concatenate((TrainX_1, TrainX_2, TrainX_3, TrainX_4), axis=0)
TrainGroundTruth = np.concatenate((TrainY_1, TrainY_2, TrainY_3, TrainY_4), axis=0)
TrainY = []

for img in TrainGroundTruth:
  encoded_img = convertToOneHot(img)
  TrainY.append(encoded_img)

TrainY = np.asarray(TrainY)

TestX = np.concatenate((TestX_1, TestX_2, TestX_3), axis=0)
TestGroundTruth = np.concatenate((TestY_1, TestY_2, TestY_3), axis=0)
TestY = []

for img in TestGroundTruth:
  encoded_img = convertToOneHot(img)
  TestY.append(encoded_img)

TestY = np.asarray(TestY)

ValidX = TrainX[1800:, : ]
ValidY = TrainY[1800:, : ]

TrainX = TrainX[0:1800, : ]
TrainY = TrainY[0:1800, : ]

print(TrainX.shape)
print(TrainY.shape)
print(TestX.shape)
print(TestY.shape)
print(ValidX.shape)
print(ValidY.shape)
np.unique(TestY)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 3)
# (1440, 240, 240, 3)
# (1440, 240, 240, 3)
# (120, 240, 240, 3)
# (120, 240, 240, 3)
# array([0, 1], dtype=uint8)

# %%
TrainX = np.reshape(TrainX,(-1,240, 240,3))
TrainY = np.reshape(TrainY,(-1,240, 240,3))

TrainX = TrainX.astype('float32')/255

TestX = np.reshape(TestX,(-1,240, 240,3))
TestY = np.reshape(TestY,(-1,240, 240,3))

TestX = TestX.astype('float32')/255

ValidX = np.reshape(ValidX,(-1,240, 240,3))
ValidY = np.reshape(ValidY,(-1,240, 240,3))

ValidX = ValidX.astype('float32')/255

# %%
print(TrainX.shape)
print(TrainY.shape)

print(TestX.shape)
print(TestY.shape)

print(ValidX.shape)
print(ValidY.shape)

np.unique(TestY)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 3)
# (1440, 240, 240, 3)
# (1440, 240, 240, 3)
# (120, 240, 240, 3)
# (120, 240, 240, 3)
# array([0, 1], dtype=uint8)

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
import math
from keras.callbacks import EarlyStopping,ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
mc = ModelCheckpoint('Checkpoint.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def combined_loss(y_true, y_pred):
  return (1*K.categorical_crossentropy(y_true, y_pred))+(1*tversky_loss(y_true, y_pred))

# %%
optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=True)

# %%
model.compile(loss=combined_loss, optimizer=optimizer, metrics=[dice_coef,'accuracy',tversky_loss])

# %%
num_epoch = 100;
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models"
history = model.fit(TrainX, TrainY, epochs=num_epoch, validation_data=(ValidX, ValidY), shuffle=True,batch_size=4,callbacks=[es,mc])
model.save(MODELS_PATH + '/UNET_ER_20_03_16.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 1800 samples, validate on 120 samples
# Epoch 1/100
# 1800/1800 [==============================] - 584s 324ms/step - loss: 1.4315 - dice_coef: 0.9095 - acc: 0.9183 - tversky_loss: 1.1115 - val_loss: 1.9826 - val_dice_coef: 0.9875 - val_acc: 0.9883 - val_tversky_loss: 1.9247
#
# Epoch 00001: val_loss improved from inf to 1.98260, saving model to Checkpoint.h5
# Epoch 2/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 1.2949 - dice_coef: 0.9163 - acc: 0.9247 - tversky_loss: 1.0486 - val_loss: 2.0496 - val_dice_coef: 0.9882 - val_acc: 0.9883 - val_tversky_loss: 1.9758
#
# Epoch 00002: val_loss did not improve from 1.98260
# Epoch 3/100
# 1800/1800 [==============================] - 551s 306ms/step - loss: 1.2505 - dice_coef: 0.9199 - acc: 0.9279 - tversky_loss: 1.0126 - val_loss: 1.9047 - val_dice_coef: 0.9878 - val_acc: 0.9890 - val_tversky_loss: 1.8605
#
# Epoch 00003: val_loss improved from 1.98260 to 1.90470, saving model to Checkpoint.h5
# Epoch 4/100
# 1800/1800 [==============================] - 552s 306ms/step - loss: 1.2326 - dice_coef: 0.9215 - acc: 0.9296 - tversky_loss: 1.0006 - val_loss: 1.8411 - val_dice_coef: 0.9880 - val_acc: 0.9901 - val_tversky_loss: 1.8039
#
# Epoch 00004: val_loss improved from 1.90470 to 1.84106, saving model to Checkpoint.h5
# Epoch 5/100
# 1800/1800 [==============================] - 551s 306ms/step - loss: 1.1845 - dice_coef: 0.9240 - acc: 0.9315 - tversky_loss: 0.9541 - val_loss: 1.8557 - val_dice_coef: 0.9881 - val_acc: 0.9899 - val_tversky_loss: 1.8175
#
# Epoch 00005: val_loss did not improve from 1.84106
# Epoch 6/100
# 1800/1800 [==============================] - 552s 306ms/step - loss: 1.1206 - dice_coef: 0.9305 - acc: 0.9376 - tversky_loss: 0.8997 - val_loss: 1.7550 - val_dice_coef: 0.9866 - val_acc: 0.9909 - val_tversky_loss: 1.7202
#
# Epoch 00006: val_loss improved from 1.84106 to 1.75504, saving model to Checkpoint.h5
# Epoch 7/100
# 1800/1800 [==============================] - 551s 306ms/step - loss: 1.0669 - dice_coef: 0.9331 - acc: 0.9397 - tversky_loss: 0.8535 - val_loss: 1.7320 - val_dice_coef: 0.9828 - val_acc: 0.9875 - val_tversky_loss: 1.6933
#
# Epoch 00007: val_loss improved from 1.75504 to 1.73201, saving model to Checkpoint.h5
# Epoch 8/100
# 1800/1800 [==============================] - 550s 306ms/step - loss: 1.0421 - dice_coef: 0.9346 - acc: 0.9412 - tversky_loss: 0.8357 - val_loss: 1.9531 - val_dice_coef: 0.9897 - val_acc: 0.9899 - val_tversky_loss: 1.8818
#
# Epoch 00008: val_loss did not improve from 1.73201
# Epoch 9/100
# 1800/1800 [==============================] - 551s 306ms/step - loss: 1.0273 - dice_coef: 0.9351 - acc: 0.9413 - tversky_loss: 0.8264 - val_loss: 1.7709 - val_dice_coef: 0.9800 - val_acc: 0.9883 - val_tversky_loss: 1.7319
#
# Epoch 00009: val_loss did not improve from 1.73201
# Epoch 10/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 1.0125 - dice_coef: 0.9355 - acc: 0.9417 - tversky_loss: 0.8093 - val_loss: 1.8025 - val_dice_coef: 0.9888 - val_acc: 0.9905 - val_tversky_loss: 1.7639
#
# Epoch 00010: val_loss did not improve from 1.73201
# Epoch 11/100
# 1800/1800 [==============================] - 551s 306ms/step - loss: 0.9975 - dice_coef: 0.9369 - acc: 0.9431 - tversky_loss: 0.8033 - val_loss: 1.8790 - val_dice_coef: 0.9898 - val_acc: 0.9903 - val_tversky_loss: 1.8229
#
# Epoch 00011: val_loss did not improve from 1.73201
# Epoch 12/100
# 1800/1800 [==============================] - 551s 306ms/step - loss: 0.9836 - dice_coef: 0.9375 - acc: 0.9435 - tversky_loss: 0.7913 - val_loss: 1.8016 - val_dice_coef: 0.9870 - val_acc: 0.9908 - val_tversky_loss: 1.7571
#
# Epoch 00012: val_loss did not improve from 1.73201
# Epoch 13/100
# 1800/1800 [==============================] - 551s 306ms/step - loss: 0.9981 - dice_coef: 0.9377 - acc: 0.9437 - tversky_loss: 0.8034 - val_loss: 2.0066 - val_dice_coef: 0.9887 - val_acc: 0.9892 - val_tversky_loss: 1.9413
#
# Epoch 00013: val_loss did not improve from 1.73201
# Epoch 14/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.9583 - dice_coef: 0.9386 - acc: 0.9444 - tversky_loss: 0.7685 - val_loss: 1.8189 - val_dice_coef: 0.9892 - val_acc: 0.9908 - val_tversky_loss: 1.7734
#
# Epoch 00014: val_loss did not improve from 1.73201
# Epoch 15/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.9578 - dice_coef: 0.9395 - acc: 0.9454 - tversky_loss: 0.7712 - val_loss: 1.8249 - val_dice_coef: 0.9683 - val_acc: 0.9829 - val_tversky_loss: 1.7703
#
# Epoch 00015: val_loss did not improve from 1.73201
# Epoch 16/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.9673 - dice_coef: 0.9393 - acc: 0.9450 - tversky_loss: 0.7795 - val_loss: 1.8909 - val_dice_coef: 0.9894 - val_acc: 0.9902 - val_tversky_loss: 1.8376
#
# Epoch 00016: val_loss did not improve from 1.73201
# Epoch 17/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.9542 - dice_coef: 0.9408 - acc: 0.9464 - tversky_loss: 0.7726 - val_loss: 1.8104 - val_dice_coef: 0.9898 - val_acc: 0.9905 - val_tversky_loss: 1.7666
#
# Epoch 00017: val_loss did not improve from 1.73201
# Epoch 18/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.9626 - dice_coef: 0.9399 - acc: 0.9456 - tversky_loss: 0.7769 - val_loss: 1.8959 - val_dice_coef: 0.9897 - val_acc: 0.9902 - val_tversky_loss: 1.8416
#
# Epoch 00018: val_loss did not improve from 1.73201
# Epoch 19/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.9400 - dice_coef: 0.9396 - acc: 0.9454 - tversky_loss: 0.7557 - val_loss: 1.8049 - val_dice_coef: 0.9896 - val_acc: 0.9906 - val_tversky_loss: 1.7595
#
# Epoch 00019: val_loss did not improve from 1.73201
# Epoch 20/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.9477 - dice_coef: 0.9397 - acc: 0.9454 - tversky_loss: 0.7671 - val_loss: 2.0136 - val_dice_coef: 0.9884 - val_acc: 0.9892 - val_tversky_loss: 1.9352
#
# Epoch 00020: val_loss did not improve from 1.73201
# Epoch 21/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.9529 - dice_coef: 0.9400 - acc: 0.9458 - tversky_loss: 0.7691 - val_loss: 2.0179 - val_dice_coef: 0.9887 - val_acc: 0.9894 - val_tversky_loss: 1.9419
#
# Epoch 00021: val_loss did not improve from 1.73201
# Epoch 22/100
# 1800/1800 [==============================] - 553s 307ms/step - loss: 0.9671 - dice_coef: 0.9402 - acc: 0.9459 - tversky_loss: 0.7819 - val_loss: 1.9970 - val_dice_coef: 0.9889 - val_acc: 0.9892 - val_tversky_loss: 1.9375
#
# Epoch 00022: val_loss did not improve from 1.73201
# Epoch 23/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.9365 - dice_coef: 0.9402 - acc: 0.9457 - tversky_loss: 0.7540 - val_loss: 2.0336 - val_dice_coef: 0.9315 - val_acc: 0.9575 - val_tversky_loss: 1.9136
#
# Epoch 00023: val_loss did not improve from 1.73201
# Epoch 24/100
# 1800/1800 [==============================] - 552s 306ms/step - loss: 0.9258 - dice_coef: 0.9410 - acc: 0.9466 - tversky_loss: 0.7456 - val_loss: 1.8934 - val_dice_coef: 0.9835 - val_acc: 0.9899 - val_tversky_loss: 1.8517
#
# Epoch 00024: val_loss did not improve from 1.73201
# Epoch 25/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.9104 - dice_coef: 0.9414 - acc: 0.9468 - tversky_loss: 0.7322 - val_loss: 1.9613 - val_dice_coef: 0.9478 - val_acc: 0.9724 - val_tversky_loss: 1.8771
#
# Epoch 00025: val_loss did not improve from 1.73201
# Epoch 26/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.9166 - dice_coef: 0.9410 - acc: 0.9466 - tversky_loss: 0.7388 - val_loss: 1.8763 - val_dice_coef: 0.9895 - val_acc: 0.9903 - val_tversky_loss: 1.8298
#
# Epoch 00026: val_loss did not improve from 1.73201
# Epoch 27/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.9255 - dice_coef: 0.9422 - acc: 0.9477 - tversky_loss: 0.7520 - val_loss: 1.9195 - val_dice_coef: 0.9891 - val_acc: 0.9900 - val_tversky_loss: 1.8598
#
# Epoch 00027: val_loss did not improve from 1.73201
# Epoch 28/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.9291 - dice_coef: 0.9421 - acc: 0.9475 - tversky_loss: 0.7543 - val_loss: 1.8895 - val_dice_coef: 0.9892 - val_acc: 0.9899 - val_tversky_loss: 1.8384
#
# Epoch 00028: val_loss did not improve from 1.73201
# Epoch 29/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.9078 - dice_coef: 0.9423 - acc: 0.9476 - tversky_loss: 0.7319 - val_loss: 1.9185 - val_dice_coef: 0.9880 - val_acc: 0.9894 - val_tversky_loss: 1.8786
#
# Epoch 00029: val_loss did not improve from 1.73201
# Epoch 30/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.9154 - dice_coef: 0.9424 - acc: 0.9476 - tversky_loss: 0.7396 - val_loss: 1.8753 - val_dice_coef: 0.9867 - val_acc: 0.9904 - val_tversky_loss: 1.8228
#
# Epoch 00030: val_loss did not improve from 1.73201
# Epoch 31/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.9346 - dice_coef: 0.9418 - acc: 0.9474 - tversky_loss: 0.7600 - val_loss: 1.9342 - val_dice_coef: 0.9864 - val_acc: 0.9890 - val_tversky_loss: 1.8847
#
# Epoch 00031: val_loss did not improve from 1.73201
# Epoch 32/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.8841 - dice_coef: 0.9430 - acc: 0.9483 - tversky_loss: 0.7094 - val_loss: 1.8241 - val_dice_coef: 0.9777 - val_acc: 0.9896 - val_tversky_loss: 1.7766
#
# Epoch 00032: val_loss did not improve from 1.73201
# Epoch 33/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.9157 - dice_coef: 0.9432 - acc: 0.9484 - tversky_loss: 0.7434 - val_loss: 1.9589 - val_dice_coef: 0.9871 - val_acc: 0.9892 - val_tversky_loss: 1.9079
#
# Epoch 00033: val_loss did not improve from 1.73201
# Epoch 34/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.9257 - dice_coef: 0.9426 - acc: 0.9479 - tversky_loss: 0.7539 - val_loss: 1.8091 - val_dice_coef: 0.9829 - val_acc: 0.9895 - val_tversky_loss: 1.7653
#
# Epoch 00034: val_loss did not improve from 1.73201
# Epoch 35/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.8976 - dice_coef: 0.9432 - acc: 0.9482 - tversky_loss: 0.7231 - val_loss: 1.8206 - val_dice_coef: 0.9843 - val_acc: 0.9899 - val_tversky_loss: 1.7815
#
# Epoch 00035: val_loss did not improve from 1.73201
# Epoch 36/100
# 1800/1800 [==============================] - 552s 307ms/step - loss: 0.8939 - dice_coef: 0.9433 - acc: 0.9486 - tversky_loss: 0.7198 - val_loss: 2.0133 - val_dice_coef: 0.9889 - val_acc: 0.9892 - val_tversky_loss: 1.9390
#
# Epoch 00036: val_loss did not improve from 1.73201
# Epoch 37/100
# 1800/1800 [==============================] - 550s 306ms/step - loss: 0.8712 - dice_coef: 0.9444 - acc: 0.9493 - tversky_loss: 0.7019 - val_loss: 1.9228 - val_dice_coef: 0.9886 - val_acc: 0.9900 - val_tversky_loss: 1.8696
#
# Epoch 00037: val_loss did not improve from 1.73201
# Epoch 00037: early stopping

# %%
train_loss = history.history['loss']
train_acc = history.history['acc']
val_loss = history.history['val_loss']
val_acc = history.history['val_acc']
xc=range(len(train_loss))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_loss)
plt.plot(xc, val_loss)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(['train','val'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_acc)
plt.plot(xc, val_acc)
plt.xlabel("Epoch")
plt.ylabel("Acc")
plt.legend(['train','val'])

# %%
# MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models"
# model = keras.models.load_model(MODELS_PATH+'/UNET_ER_20_03_03_v5.h5',custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

# %%
# Function to find the most probable class of an image pixel by pixel
def ClassFinder(img):
  result = np.zeros(img.shape, dtype=np.uint8)
  for r in range(len(img)):
    for c in range(len(img[0])):
      idx = np.argmax(img[r][c])
      result[r][c][idx]=1
      
  return result

# %%
train_result = model.predict(TrainX, batch_size=4)
print(np.shape(train_result))
Train_predict = [ ]
for img in train_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_predict.append(encoded_img)

Predicted_images = np.asarray(Train_predict)
print(Predicted_images.shape)
np.unique(Predicted_images)
# dice = dc(train_result, TrainY)
# pre  = precision(train_result,TrainY)
# re   = recall(train_result,TrainY)
# print('Train dc: '  + str(dice))
# print('Train pre: ' + str(pre))
# print('Train re: '  + str(re))
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240)
# array([  0, 128, 255], dtype=uint8)

# %%
test_result = model.predict(TestX, batch_size=4)
print(np.shape(test_result))

Test_predict = [ ]
for img in test_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_predict.append(encoded_img)

Predicted_images_test = np.asarray(Test_predict)
print(Predicted_images_test.shape)
np.unique(Predicted_images_test)
# dice = dc(test_result, TestY)
# pre  = precision(test_result,TestY)
# re   = recall(test_result,TestY)
# print('Test dc: '  + str(dice))
# print('Test pre: ' + str(pre))
# print('Test re: '  + str(re))
# Out:
# (1440, 240, 240, 3)
# (1440, 240, 240)
# array([  0, 128, 255], dtype=uint8)

# %%
from sklearn.metrics import confusion_matrix
def get_confusion_matrix(Actual, Predicted):
  ActualY = np.reshape(Actual,(-1, Actual.shape[3]))
  PredY = np.reshape(Predicted,(-1, Predicted.shape[3]))
  matrix = confusion_matrix(ActualY.argmax(axis = 1), PredY.argmax(axis = 1))
  return matrix

def get_precision(confusion_matrix):
  precision = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 0)
  nan_indices = np.isnan(precision)
  precision[nan_indices] = 0
  return precision

def get_recall(confusion_matrix):
  recall = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 1)
  nan_indices = np.isnan(recall)
  recall[nan_indices] = 0
  return recall

# %%
test_matrix = get_confusion_matrix(TestY, test_result)
train_matrix = get_confusion_matrix(TrainY, train_result)
print(test_matrix)
print(train_matrix)
# TestY.shape[3]
# test_result.shape
# Out:
# [[72811063  2670867]
#  [ 2284542  5177528]]
# [[88692759  1356371]
#  [ 2509531 11121339]]

# %%
np.unique(Predicted_images_test)
# Out:
# array([  0, 255], dtype=uint8)

# %%
test_precision = get_precision(test_matrix)
print('Test Precision')
print(test_precision)
test_recall = get_recall(test_matrix)
print('Test Recall')
print(test_recall)
train_precision = get_precision(train_matrix)
print('Train Precision')
print(train_precision)
train_recall = get_recall(train_matrix)
print('Train Recall')
print(train_recall)
# Out:
# Test Precision
# [0.96957822 0.65969259]
# Test Recall
# [0.96461581 0.69384608]
# Train Precision
# [0.9724839  0.89129648]
# Train Recall
# [0.98493743 0.81589356]

# %%
# weight_matrix = np.zeros((3,1))
# weight_matrix[0] = 0.6
# weight_matrix[1] = 0.2
# weight_matrix[2] = 0.2
# print(weight_matrix.shape)
# Out:
# (3, 1)

# %%
weight_matrix = np.zeros((3,1))
weight_matrix[0] = 1/3
weight_matrix[1] = 1/3
weight_matrix[2] = 1/3
print(weight_matrix.shape)
# Out:
# (3, 1)

# %%
def get_overall_precision(precision, weights):
  final_precision = np.dot(precision,weights)
  return final_precision

def get_overall_recall(recall, weights):
  final_recall = np.dot(recall ,weights)
  return final_recall

# %%
final_test_precision  = get_overall_precision(test_precision, weight_matrix)
final_test_recall     = get_overall_recall(test_recall, weight_matrix)
final_train_precision = get_overall_precision(train_precision, weight_matrix)
final_train_recall    = get_overall_recall(train_recall, weight_matrix)
print('Final Test Precision')
print(final_test_precision)
print('Final Test Recall')
print(final_test_recall)
print('Final Train Precision')
print(final_train_precision)
print('Final Train Recall')
print(final_train_recall)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-c7c4d701bf12> in <module>()
# ----> 1 final_test_precision  = get_overall_precision(test_precision, weight_matrix)
#       2 final_test_recall     = get_overall_recall(test_recall, weight_matrix)
#       3 final_train_precision = get_overall_precision(train_precision, weight_matrix)
#       4 final_train_recall    = get_overall_recall(train_recall, weight_matrix)
#       5 print('Final Test Precision')
#
# <ipython-input-84-73fc12b69fc8> in get_overall_precision(precision, weights)
#       1 def get_overall_precision(precision, weights):
# ----> 2   final_precision = np.dot(precision,weights)
#       3   return final_precision
#       4
#       5 def get_overall_recall(recall, weights):
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (2,) and (3,1) not aligned: 2 (dim 0) != 3 (dim 0)

# %%
from scipy.stats import hmean

def dice_coefficient(precision, recall):
  return hmean(np.asarray([precision , recall]))

# %%
test_dice_coeff = dice_coefficient(final_test_precision, final_test_recall)
print('Test Dice coeff')
print(test_dice_coeff)

train_dice_coeff = dice_coefficient(final_train_precision, final_train_recall)
print('Train Dice coeff')
print(train_dice_coeff)

# %%
copy1  = np.copy(TestX [250])
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
copy3 = np.reshape(copy2,(240, 240,3))
Img = cv2.cvtColor(copy3,cv2.COLOR_BGR2RGB)

Mask = TestGroundTruth[250]

Predicted_Mask = Predicted_images_test[250] 

plt.subplot(131).imshow(Img)
plt.subplot(132).imshow(Mask,'gray')
plt.subplot(133).imshow(Predicted_Mask,'gray')

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask):
  num = mask.shape[0]/480
  for id in range(int(num)):
    temp = []
    for i in range(id, id+10):
      idx = i * 48
      final_output = mask[idx:idx+48]
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save("/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/Combined_Loss/ER1 Patient " + str(id), final_output)

# %%
# saving predicted outputs as numpy arrays for test images
saveNumpyOutput(Predicted_images)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 25   # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]

Mask_input = TestY[id:id+48]
Test_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Test_Actual)
print(Mask_input.shape)

final_output = Predicted_images_test[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 3)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0. 128. 255.]

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 14  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]

Mask_input = TrainY[id:id+48]
Train_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Train_Actual)
print(Mask_input.shape)

final_output = Predicted_images[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 3)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0. 128. 255.]
