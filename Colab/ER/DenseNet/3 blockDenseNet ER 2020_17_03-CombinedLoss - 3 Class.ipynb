# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from keras.layers import Activation,Conv2D,MaxPooling2D,UpSampling2D,Dense,BatchNormalization,Input,Reshape,multiply,add,Dropout,AveragePooling2D,GlobalAveragePooling2D,concatenate
from keras.layers.convolutional import Conv2DTranspose
from keras.models import Model														  
import keras.backend as K
from keras.regularizers import l2
from keras.engine import Layer,InputSpec
from keras.utils import conv_utils
from keras.layers import Activation,Conv2D,MaxPooling2D,UpSampling2D,Dense,BatchNormalization,Input,Reshape,multiply,add,Dropout,AveragePooling2D,GlobalAveragePooling2D,concatenate
from keras.layers.convolutional import Conv2DTranspose
from keras.models import Model														  
import keras.backend as K
from keras.regularizers import l2
from keras.engine import Layer,InputSpec
from keras.utils import conv_utils
# !pip install medpy
from keras.layers import *
from keras.models import Sequential
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from medpy.metric import dc, precision, recall
import keras
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Collecting medpy
#   Downloading https://files.pythonhosted.org/packages/3b/70/c1fd5dd60242eee81774696ea7ba4caafac2bad8f028bba94b1af83777d7/MedPy-0.4.0.tar.gz (151kB)
#      |████████████████████████████████| 153kB 2.8MB/s
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.18.1)
# Collecting SimpleITK>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/f8/d8/53338c34f71020725ffb3557846c80af96c29c03bc883551a2565aa68a7c/SimpleITK-1.2.4-cp36-cp36m-manylinux1_x86_64.whl (42.5MB)
#      |████████████████████████████████| 42.5MB 74kB/s
# Building wheels for collected packages: medpy
#   Building wheel for medpy (setup.py) ... done
#   Created wheel for medpy: filename=MedPy-0.4.0-cp36-cp36m-linux_x86_64.whl size=753440 sha256=447bc6af53b4d6e57fe100e475e40e595e0f03cf0a1c19eccea9e5c9589fc7bf
#   Stored in directory: /root/.cache/pip/wheels/8c/c9/9c/2c6281c7a72b9fb1570862a4f028af7ce38405008354fbf870
# Successfully built medpy
# Installing collected packages: SimpleITK, medpy
# Successfully installed SimpleITK-1.2.4 medpy-0.4.0

# %%
def BN_ReLU_Conv(inputs, n_filters, filter_size=3, dropout_p=0.2):

    '''Apply successivly BatchNormalization, ReLu nonlinearity, Convolution and Dropout (if dropout_p > 0)''' 
    l = BatchNormalization()(inputs)
    l = Activation('relu')(l)
    l = Conv2D(n_filters, filter_size, padding='same', kernel_initializer='he_uniform')(l)
    if dropout_p != 0.0:
      l = Dropout(dropout_p)(l)
    return l


def TransitionDown(inputs, n_filters, dropout_p=0.2):

  """ Apply first a BN_ReLu_conv layer with filter size = 1, and a max pooling with a factor 2  """
  l = BN_ReLU_Conv(inputs, n_filters, filter_size=1, dropout_p=dropout_p)
  l = MaxPooling2D((2,2))(l)
  return l

def TransitionUp(skip_connection, block_to_upsample, n_filters_keep):

    '''Performs upsampling on block_to_upsample by a factor 2 and concatenates it with the skip_connection'''

    #Upsample and concatenate with skip connection
    l = Conv2DTranspose(n_filters_keep, kernel_size=3, strides=2, padding='same', kernel_initializer='he_uniform')(block_to_upsample)
    l = concatenate([l, skip_connection], axis=-1)
    return l


def SoftmaxLayer(inputs, n_classes):
    """
    Performs 1x1 convolution followed by softmax nonlinearity
    The output will have the shape (batch_size  * n_rows * n_cols, n_classes)
    """
    l = Conv2D(n_classes, kernel_size=1, padding='same', kernel_initializer='he_uniform')(inputs)
#    l = Reshape((-1, n_classes))(l)
    l = Activation('softmax')(l)#or softmax for multi-class

    return l

# %%
def Tiramisu(

        input_shape=(240,240,3),

        n_classes = 3,

        n_filters_first_conv = 48,

        n_pool = 3,

        growth_rate = 16 ,

        n_layers_per_block =  [3 , 3, 3 , 3, 3 , 3 , 3],

        dropout_p = 0.2

        ):

    if type(n_layers_per_block) == list:

            print(len(n_layers_per_block))

    elif type(n_layers_per_block) == int:

            n_layers_per_block = [n_layers_per_block] * (2 * n_pool + 1)

    else:

        raise ValueError

        

#####################

# First Convolution #

#####################        

    inputs = Input(shape=input_shape)

    stack = Conv2D(filters=n_filters_first_conv, kernel_size=3, padding='same', kernel_initializer='he_uniform')(inputs)

    n_filters = n_filters_first_conv



#####################

# Downsampling path #

#####################     

    skip_connection_list = []

    

    for i in range(n_pool):
        print("i")
        print(i)

        for j in range(n_layers_per_block[i]):
            print(j)
            l = BN_ReLU_Conv(stack, growth_rate, dropout_p=dropout_p)

            stack = concatenate([stack, l])

            n_filters += growth_rate

        

        skip_connection_list.append(stack)        

        stack = TransitionDown(stack, n_filters, dropout_p)

    skip_connection_list = skip_connection_list[::-1]



    

#####################

#    Bottleneck     #

#####################     

    block_to_upsample=[]

    

    for j in range(n_layers_per_block[n_pool]):

        l = BN_ReLU_Conv(stack, growth_rate, dropout_p=dropout_p)

        block_to_upsample.append(l)

        stack = concatenate([stack,l])

    block_to_upsample = concatenate(block_to_upsample)



   

#####################

#  Upsampling path  #

#####################

    for i in range(n_pool):

        n_filters_keep = growth_rate * n_layers_per_block[n_pool + i ]

        stack = TransitionUp(skip_connection_list[i], block_to_upsample, n_filters_keep)

        

        block_to_upsample = []

        for j in range(n_layers_per_block[ n_pool + i + 1 ]):

            l = BN_ReLU_Conv(stack, growth_rate, dropout_p=dropout_p)

            block_to_upsample.append(l)

            stack = concatenate([stack, l])

        block_to_upsample = concatenate(block_to_upsample)



#####################

#  Softmax          #

#####################

    output = SoftmaxLayer(stack, n_classes)            

    model=Model(inputs = inputs, outputs = output)    

    model.summary()

    

    return model

# %%
model = Tiramisu()
# Out:
# 7
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# i
# 0
# 0
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 1
# 2
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# i
# 1
# 0
# 1
# 2
# i
# 2
# 0
# 1
# 2
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 240, 240, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 240, 240, 48) 1344        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 240, 240, 48) 192         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 240, 240, 48) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 240, 240, 16) 6928        activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 240, 240, 16) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 240, 240, 64) 0           conv2d_1[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 240, 240, 64) 256         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 240, 240, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 240, 240, 16) 9232        activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 240, 240, 16) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 240, 240, 80) 0           concatenate_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 240, 240, 80) 320         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 240, 240, 80) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 240, 240, 16) 11536       activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 240, 240, 16) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 240, 240, 96) 0           concatenate_2[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 240, 240, 96) 384         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 240, 240, 96) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 240, 240, 96) 9312        activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 240, 240, 96) 0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 120, 120, 96) 0           dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 120, 120, 96) 384         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 120, 120, 96) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 120, 120, 16) 13840       activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 120, 120, 16) 0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 120, 120, 112 0           max_pooling2d_1[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 120, 120, 112 448         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 120, 120, 112 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 120, 120, 16) 16144       activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 120, 120, 16) 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 120, 120, 128 0           concatenate_4[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 120, 120, 128 512         concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 120, 120, 128 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 120, 120, 16) 18448       activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 120, 120, 16) 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 120, 120, 144 0           concatenate_5[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 120, 120, 144 576         concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 120, 120, 144 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 120, 120, 144 20880       activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 120, 120, 144 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 60, 60, 144)  0           dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 60, 60, 144)  576         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 60, 60, 144)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 60, 60, 16)   20752       activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 60, 60, 16)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 60, 60, 160)  0           max_pooling2d_2[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 60, 60, 160)  640         concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 60, 60, 160)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 60, 60, 16)   23056       activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 60, 60, 16)   0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 60, 60, 176)  0           concatenate_7[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 60, 60, 176)  704         concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 60, 60, 176)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 60, 60, 16)   25360       activation_11[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 60, 60, 16)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 60, 60, 192)  0           concatenate_8[0][0]
#                                                                  dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 60, 60, 192)  768         concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 60, 60, 192)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 60, 60, 192)  37056       activation_12[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 60, 60, 192)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 30, 30, 192)  0           dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 30, 30, 192)  768         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 30, 30, 192)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 30, 30, 16)   27664       activation_13[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 30, 30, 16)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 30, 30, 208)  0           max_pooling2d_3[0][0]
#                                                                  dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 30, 30, 208)  832         concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 30, 30, 208)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 30, 30, 16)   29968       activation_14[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 30, 30, 16)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 30, 30, 224)  0           concatenate_10[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 30, 30, 224)  896         concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 30, 30, 224)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 30, 30, 16)   32272       activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 30, 30, 16)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 30, 30, 48)   0           dropout_13[0][0]
#                                                                  dropout_14[0][0]
#                                                                  dropout_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 60, 60, 48)   20784       concatenate_13[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 60, 60, 240)  0           conv2d_transpose_1[0][0]
#                                                                  concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 60, 60, 240)  960         concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 60, 60, 240)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 60, 60, 16)   34576       activation_16[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 60, 60, 16)   0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 60, 60, 256)  0           concatenate_14[0][0]
#                                                                  dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 60, 60, 256)  1024        concatenate_15[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 60, 60, 256)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 60, 60, 16)   36880       activation_17[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 60, 60, 16)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 60, 60, 272)  0           concatenate_15[0][0]
#                                                                  dropout_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 60, 60, 272)  1088        concatenate_16[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 60, 60, 272)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 60, 60, 16)   39184       activation_18[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 60, 60, 16)   0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 60, 60, 48)   0           dropout_16[0][0]
#                                                                  dropout_17[0][0]
#                                                                  dropout_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 120, 120, 48) 20784       concatenate_18[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 120, 120, 192 0           conv2d_transpose_2[0][0]
#                                                                  concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 120, 120, 192 768         concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 120, 120, 192 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 120, 120, 16) 27664       activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 120, 120, 16) 0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 120, 120, 208 0           concatenate_19[0][0]
#                                                                  dropout_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 120, 120, 208 832         concatenate_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 120, 120, 208 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 120, 120, 16) 29968       activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 120, 120, 16) 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 120, 120, 224 0           concatenate_20[0][0]
#                                                                  dropout_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 120, 120, 224 896         concatenate_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 120, 120, 224 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 120, 120, 16) 32272       activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 120, 120, 16) 0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 120, 120, 48) 0           dropout_19[0][0]
#                                                                  dropout_20[0][0]
#                                                                  dropout_21[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 240, 240, 48) 20784       concatenate_23[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 240, 240, 144 0           conv2d_transpose_3[0][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 240, 240, 144 576         concatenate_24[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 240, 240, 144 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 240, 240, 16) 20752       activation_22[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 240, 240, 16) 0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 240, 240, 160 0           concatenate_24[0][0]
#                                                                  dropout_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 240, 240, 160 640         concatenate_25[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 240, 240, 160 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 240, 240, 16) 23056       activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 240, 240, 16) 0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 240, 240, 176 0           concatenate_25[0][0]
#                                                                  dropout_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 240, 240, 176 704         concatenate_26[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 240, 240, 176 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 240, 240, 16) 25360       activation_24[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 240, 240, 16) 0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 240, 240, 192 0           concatenate_26[0][0]
#                                                                  dropout_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 240, 240, 3)  579         concatenate_27[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 240, 240, 3)  0           conv2d_26[0][0]
# ==================================================================================================
# Total params: 652,179
# Trainable params: 644,307
# Non-trainable params: 7,872
# __________________________________________________________________________________________________

# %%
import os
import cv2
import numpy as np

# %%
# Function to convert image from greyscale to one hot (i.e. 3 channels)
def convertToOneHot(image):
    num_classes = 3
    shape = image.shape[:2]+(num_classes,)
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c]==0:
          encoded_image[r][c][0] = 1
        elif image[r][c]==128:
          encoded_image[r][c][1] = 1
        else:
          encoded_image[r][c][2] = 1
    return encoded_image

# %%
# Function to convert back from one hot image to greyscale
def convertFromOneHot(image):
    shape = image.shape[:2]
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c][0] == 1:
          encoded_image[r][c] = 0
        elif image[r][c][1] == 1:
          encoded_image[r][c] = 128
        else:
          encoded_image[r][c] = 255
    return encoded_image

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/3 Class"

# Train set patients: 230 263 239 242 
TrainX_1 = np.load(PATH + '/ER IHC 239 Images.npy')
TrainY_1 = np.load(PATH + '/ER IHC 239 Masks.npy')
TrainX_2 = np.load(PATH + '/ER IHC 263 Images.npy')
TrainY_2 = np.load(PATH + '/ER IHC 263 Masks.npy')
TrainX_3 = np.load(PATH + '/ER IHC 242 Images.npy')
TrainY_3 = np.load(PATH + '/ER IHC 242 Masks.npy')
TrainX_4 = np.load(PATH + '/ER IHC 230 Images.npy')
TrainY_4 = np.load(PATH + '/ER IHC 230 Masks.npy')

# Test set patients: 221 246 232
TestX_1 = np.load(PATH + '/ER IHC 221 Images.npy')
TestY_1 = np.load(PATH + '/ER IHC 221 Masks.npy')
TestX_2 = np.load(PATH + '/ER IHC 246 Images.npy')
TestY_2 = np.load(PATH + '/ER IHC 246 Masks.npy')
TestX_3 = np.load(PATH + '/ER IHC 232 Images.npy')
TestY_3 = np.load(PATH + '/ER IHC 232 Masks.npy')

# %%
np.unique(TestY_3)
# Out:
# array([  0., 128., 255.])

# %%
TrainX = np.concatenate((TrainX_1, TrainX_2, TrainX_3, TrainX_4), axis=0)
TrainGroundTruth = np.concatenate((TrainY_1, TrainY_2, TrainY_3, TrainY_4), axis=0)
TrainY = []

for img in TrainGroundTruth:
  encoded_img = convertToOneHot(img)
  TrainY.append(encoded_img)

TrainY = np.asarray(TrainY)

TestX = np.concatenate((TestX_1, TestX_2, TestX_3), axis=0)
TestGroundTruth = np.concatenate((TestY_1, TestY_2, TestY_3), axis=0)
TestY = []

for img in TestGroundTruth:
  encoded_img = convertToOneHot(img)
  TestY.append(encoded_img)

TestY = np.asarray(TestY)

ValidX = TrainX[1800:, : ]
ValidY = TrainY[1800:, : ]

TrainX = TrainX[0:1800, : ]
TrainY = TrainY[0:1800, : ]

print(TrainX.shape)
print(TrainY.shape)
print(TestX.shape)
print(TestY.shape)
print(ValidX.shape)
print(ValidY.shape)
np.unique(TestY)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 3)
# (1440, 240, 240, 3)
# (1440, 240, 240, 3)
# (120, 240, 240, 3)
# (120, 240, 240, 3)
# array([0, 1], dtype=uint8)

# %%
TrainX = np.reshape(TrainX,(-1,240, 240,3))
TrainY = np.reshape(TrainY,(-1,240, 240,3))

TrainX = TrainX.astype('float32')/255

TestX = np.reshape(TestX,(-1,240, 240,3))
TestY = np.reshape(TestY,(-1,240, 240,3))

TestX = TestX.astype('float32')/255

ValidX = np.reshape(ValidX,(-1,240, 240,3))
ValidY = np.reshape(ValidY,(-1,240, 240,3))

ValidX = ValidX.astype('float32')/255

# %%
print(TrainX.shape)
print(TrainY.shape)

print(TestX.shape)
print(TestY.shape)

print(ValidX.shape)
print(ValidY.shape)

np.unique(TestY)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 3)
# (1440, 240, 240, 3)
# (1440, 240, 240, 3)
# (120, 240, 240, 3)
# (120, 240, 240, 3)
# array([0, 1], dtype=uint8)

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
import math
from keras.callbacks import EarlyStopping,ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
mc = ModelCheckpoint('Checkpoint.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def combined_loss(y_true, y_pred):
  return (1*K.categorical_crossentropy(y_true, y_pred))+(1*tversky_loss(y_true, y_pred))

# %%
optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=True)

# %%
model.compile(loss=combined_loss, optimizer=optimizer, metrics=[dice_coef,'accuracy',tversky_loss])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
num_epoch = 100;
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models"
history = model.fit(TrainX, TrainY, epochs=num_epoch, validation_data=(ValidX, ValidY), shuffle=True,batch_size=8,callbacks=[es,mc])
model.save(MODELS_PATH + '/UNET_ER_20_03_17.h5')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 1800 samples, validate on 120 samples
# Epoch 1/100
# 1800/1800 [==============================] - 82s 45ms/step - loss: 1.3686 - dice_coef: 0.9004 - acc: 0.9083 - tversky_loss: 1.0388 - val_loss: 1.8273 - val_dice_coef: 0.9837 - val_acc: 0.9898 - val_tversky_loss: 1.7777
#
# Epoch 00001: val_loss improved from inf to 1.82730, saving model to Checkpoint.h5
# Epoch 2/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 1.1358 - dice_coef: 0.9193 - acc: 0.9266 - tversky_loss: 0.8655 - val_loss: 1.6894 - val_dice_coef: 0.9857 - val_acc: 0.9901 - val_tversky_loss: 1.6526
#
# Epoch 00002: val_loss improved from 1.82730 to 1.68943, saving model to Checkpoint.h5
# Epoch 3/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 1.1078 - dice_coef: 0.9202 - acc: 0.9277 - tversky_loss: 0.8512 - val_loss: 1.6555 - val_dice_coef: 0.9820 - val_acc: 0.9887 - val_tversky_loss: 1.6195
#
# Epoch 00003: val_loss improved from 1.68943 to 1.65551, saving model to Checkpoint.h5
# Epoch 4/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 1.0560 - dice_coef: 0.9231 - acc: 0.9304 - tversky_loss: 0.8116 - val_loss: 1.6851 - val_dice_coef: 0.9774 - val_acc: 0.9865 - val_tversky_loss: 1.6447
#
# Epoch 00004: val_loss did not improve from 1.65551
# Epoch 5/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 1.0638 - dice_coef: 0.9231 - acc: 0.9307 - tversky_loss: 0.8266 - val_loss: 1.6807 - val_dice_coef: 0.9791 - val_acc: 0.9885 - val_tversky_loss: 1.6447
#
# Epoch 00005: val_loss did not improve from 1.65551
# Epoch 6/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 1.0295 - dice_coef: 0.9248 - acc: 0.9321 - tversky_loss: 0.7977 - val_loss: 1.6601 - val_dice_coef: 0.9892 - val_acc: 0.9905 - val_tversky_loss: 1.6266
#
# Epoch 00006: val_loss did not improve from 1.65551
# Epoch 7/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 1.0222 - dice_coef: 0.9250 - acc: 0.9321 - tversky_loss: 0.7934 - val_loss: 1.6977 - val_dice_coef: 0.9771 - val_acc: 0.9875 - val_tversky_loss: 1.6603
#
# Epoch 00007: val_loss did not improve from 1.65551
# Epoch 8/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.9801 - dice_coef: 0.9273 - acc: 0.9344 - tversky_loss: 0.7572 - val_loss: 1.7050 - val_dice_coef: 0.9757 - val_acc: 0.9883 - val_tversky_loss: 1.6677
#
# Epoch 00008: val_loss did not improve from 1.65551
# Epoch 9/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.9949 - dice_coef: 0.9268 - acc: 0.9340 - tversky_loss: 0.7756 - val_loss: 1.7141 - val_dice_coef: 0.9739 - val_acc: 0.9883 - val_tversky_loss: 1.6745
#
# Epoch 00009: val_loss did not improve from 1.65551
# Epoch 10/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.9968 - dice_coef: 0.9268 - acc: 0.9338 - tversky_loss: 0.7758 - val_loss: 1.6771 - val_dice_coef: 0.9812 - val_acc: 0.9893 - val_tversky_loss: 1.6452
#
# Epoch 00010: val_loss did not improve from 1.65551
# Epoch 11/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.9528 - dice_coef: 0.9290 - acc: 0.9358 - tversky_loss: 0.7385 - val_loss: 1.9793 - val_dice_coef: 0.9145 - val_acc: 0.9602 - val_tversky_loss: 1.8606
#
# Epoch 00011: val_loss did not improve from 1.65551
# Epoch 12/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.9854 - dice_coef: 0.9278 - acc: 0.9346 - tversky_loss: 0.7651 - val_loss: 2.1208 - val_dice_coef: 0.8672 - val_acc: 0.9021 - val_tversky_loss: 1.9059
#
# Epoch 00012: val_loss did not improve from 1.65551
# Epoch 13/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.9512 - dice_coef: 0.9281 - acc: 0.9348 - tversky_loss: 0.7337 - val_loss: 1.8591 - val_dice_coef: 0.9402 - val_acc: 0.9736 - val_tversky_loss: 1.7724
#
# Epoch 00013: val_loss did not improve from 1.65551
# Epoch 14/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.9797 - dice_coef: 0.9284 - acc: 0.9352 - tversky_loss: 0.7665 - val_loss: 2.0398 - val_dice_coef: 0.8848 - val_acc: 0.9298 - val_tversky_loss: 1.8628
#
# Epoch 00014: val_loss did not improve from 1.65551
# Epoch 15/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.9699 - dice_coef: 0.9289 - acc: 0.9356 - tversky_loss: 0.7547 - val_loss: 2.2668 - val_dice_coef: 0.8232 - val_acc: 0.8650 - val_tversky_loss: 1.9852
#
# Epoch 00015: val_loss did not improve from 1.65551
# Epoch 16/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.9795 - dice_coef: 0.9277 - acc: 0.9346 - tversky_loss: 0.7637 - val_loss: 1.6612 - val_dice_coef: 0.9819 - val_acc: 0.9894 - val_tversky_loss: 1.6304
#
# Epoch 00016: val_loss did not improve from 1.65551
# Epoch 17/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.9554 - dice_coef: 0.9286 - acc: 0.9352 - tversky_loss: 0.7406 - val_loss: 1.6885 - val_dice_coef: 0.9890 - val_acc: 0.9905 - val_tversky_loss: 1.6553
#
# Epoch 00017: val_loss did not improve from 1.65551
# Epoch 18/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.9405 - dice_coef: 0.9300 - acc: 0.9365 - tversky_loss: 0.7299 - val_loss: 2.2233 - val_dice_coef: 0.8289 - val_acc: 0.8699 - val_tversky_loss: 1.9484
#
# Epoch 00018: val_loss did not improve from 1.65551
# Epoch 19/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.9510 - dice_coef: 0.9301 - acc: 0.9366 - tversky_loss: 0.7417 - val_loss: 1.9600 - val_dice_coef: 0.9177 - val_acc: 0.9464 - val_tversky_loss: 1.8280
#
# Epoch 00019: val_loss did not improve from 1.65551
# Epoch 20/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.9307 - dice_coef: 0.9305 - acc: 0.9369 - tversky_loss: 0.7196 - val_loss: 1.8985 - val_dice_coef: 0.9341 - val_acc: 0.9718 - val_tversky_loss: 1.8085
#
# Epoch 00020: val_loss did not improve from 1.65551
# Epoch 21/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.9264 - dice_coef: 0.9306 - acc: 0.9369 - tversky_loss: 0.7180 - val_loss: 1.7765 - val_dice_coef: 0.9672 - val_acc: 0.9873 - val_tversky_loss: 1.7312
#
# Epoch 00021: val_loss did not improve from 1.65551
# Epoch 22/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.9212 - dice_coef: 0.9307 - acc: 0.9372 - tversky_loss: 0.7153 - val_loss: 1.7786 - val_dice_coef: 0.9580 - val_acc: 0.9741 - val_tversky_loss: 1.7129
#
# Epoch 00022: val_loss did not improve from 1.65551
# Epoch 23/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.9357 - dice_coef: 0.9303 - acc: 0.9368 - tversky_loss: 0.7262 - val_loss: 1.8640 - val_dice_coef: 0.9431 - val_acc: 0.9783 - val_tversky_loss: 1.7884
#
# Epoch 00023: val_loss did not improve from 1.65551
# Epoch 24/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.9418 - dice_coef: 0.9304 - acc: 0.9369 - tversky_loss: 0.7302 - val_loss: 1.6641 - val_dice_coef: 0.9780 - val_acc: 0.9865 - val_tversky_loss: 1.6270
#
# Epoch 00024: val_loss did not improve from 1.65551
# Epoch 25/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.9275 - dice_coef: 0.9309 - acc: 0.9371 - tversky_loss: 0.7219 - val_loss: 1.7932 - val_dice_coef: 0.9590 - val_acc: 0.9832 - val_tversky_loss: 1.7381
#
# Epoch 00025: val_loss did not improve from 1.65551
# Epoch 26/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.9192 - dice_coef: 0.9318 - acc: 0.9382 - tversky_loss: 0.7133 - val_loss: 1.6193 - val_dice_coef: 0.9853 - val_acc: 0.9905 - val_tversky_loss: 1.5913
#
# Epoch 00026: val_loss improved from 1.65551 to 1.61926, saving model to Checkpoint.h5
# Epoch 27/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.9415 - dice_coef: 0.9303 - acc: 0.9366 - tversky_loss: 0.7367 - val_loss: 1.7408 - val_dice_coef: 0.9712 - val_acc: 0.9853 - val_tversky_loss: 1.6992
#
# Epoch 00027: val_loss did not improve from 1.61926
# Epoch 28/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.8998 - dice_coef: 0.9324 - acc: 0.9384 - tversky_loss: 0.6934 - val_loss: 1.6146 - val_dice_coef: 0.9872 - val_acc: 0.9899 - val_tversky_loss: 1.5862
#
# Epoch 00028: val_loss improved from 1.61926 to 1.61456, saving model to Checkpoint.h5
# Epoch 29/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.9168 - dice_coef: 0.9318 - acc: 0.9381 - tversky_loss: 0.7115 - val_loss: 1.9288 - val_dice_coef: 0.9193 - val_acc: 0.9469 - val_tversky_loss: 1.7926
#
# Epoch 00029: val_loss did not improve from 1.61456
# Epoch 30/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.9064 - dice_coef: 0.9315 - acc: 0.9378 - tversky_loss: 0.7017 - val_loss: 1.7456 - val_dice_coef: 0.9648 - val_acc: 0.9808 - val_tversky_loss: 1.6919
#
# Epoch 00030: val_loss did not improve from 1.61456
# Epoch 31/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.9299 - dice_coef: 0.9306 - acc: 0.9371 - tversky_loss: 0.7225 - val_loss: 1.6964 - val_dice_coef: 0.9732 - val_acc: 0.9875 - val_tversky_loss: 1.6550
#
# Epoch 00031: val_loss did not improve from 1.61456
# Epoch 32/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.9150 - dice_coef: 0.9321 - acc: 0.9384 - tversky_loss: 0.7097 - val_loss: 1.7374 - val_dice_coef: 0.9739 - val_acc: 0.9870 - val_tversky_loss: 1.6993
#
# Epoch 00032: val_loss did not improve from 1.61456
# Epoch 33/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.9237 - dice_coef: 0.9327 - acc: 0.9388 - tversky_loss: 0.7215 - val_loss: 1.8050 - val_dice_coef: 0.9584 - val_acc: 0.9798 - val_tversky_loss: 1.7463
#
# Epoch 00033: val_loss did not improve from 1.61456
# Epoch 34/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.8895 - dice_coef: 0.9323 - acc: 0.9384 - tversky_loss: 0.6882 - val_loss: 1.7640 - val_dice_coef: 0.9606 - val_acc: 0.9781 - val_tversky_loss: 1.7041
#
# Epoch 00034: val_loss did not improve from 1.61456
# Epoch 35/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.8925 - dice_coef: 0.9328 - acc: 0.9390 - tversky_loss: 0.6885 - val_loss: 1.7899 - val_dice_coef: 0.9617 - val_acc: 0.9838 - val_tversky_loss: 1.7373
#
# Epoch 00035: val_loss did not improve from 1.61456
# Epoch 36/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.9030 - dice_coef: 0.9325 - acc: 0.9388 - tversky_loss: 0.7024 - val_loss: 1.6917 - val_dice_coef: 0.9889 - val_acc: 0.9905 - val_tversky_loss: 1.6618
#
# Epoch 00036: val_loss did not improve from 1.61456
# Epoch 37/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.9074 - dice_coef: 0.9322 - acc: 0.9384 - tversky_loss: 0.7017 - val_loss: 1.7215 - val_dice_coef: 0.9653 - val_acc: 0.9712 - val_tversky_loss: 1.6507
#
# Epoch 00037: val_loss did not improve from 1.61456
# Epoch 38/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.8892 - dice_coef: 0.9333 - acc: 0.9395 - tversky_loss: 0.6898 - val_loss: 1.7554 - val_dice_coef: 0.9693 - val_acc: 0.9811 - val_tversky_loss: 1.7066
#
# Epoch 00038: val_loss did not improve from 1.61456
# Epoch 39/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.9091 - dice_coef: 0.9323 - acc: 0.9386 - tversky_loss: 0.7053 - val_loss: 1.6172 - val_dice_coef: 0.9883 - val_acc: 0.9903 - val_tversky_loss: 1.5881
#
# Epoch 00039: val_loss did not improve from 1.61456
# Epoch 40/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.8894 - dice_coef: 0.9334 - acc: 0.9395 - tversky_loss: 0.6898 - val_loss: 1.6941 - val_dice_coef: 0.9778 - val_acc: 0.9843 - val_tversky_loss: 1.6555
#
# Epoch 00040: val_loss did not improve from 1.61456
# Epoch 41/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.8782 - dice_coef: 0.9340 - acc: 0.9399 - tversky_loss: 0.6793 - val_loss: 1.6258 - val_dice_coef: 0.9847 - val_acc: 0.9876 - val_tversky_loss: 1.5932
#
# Epoch 00041: val_loss did not improve from 1.61456
# Epoch 42/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.9136 - dice_coef: 0.9327 - acc: 0.9391 - tversky_loss: 0.7133 - val_loss: 1.7055 - val_dice_coef: 0.9729 - val_acc: 0.9842 - val_tversky_loss: 1.6634
#
# Epoch 00042: val_loss did not improve from 1.61456
# Epoch 43/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.9008 - dice_coef: 0.9332 - acc: 0.9393 - tversky_loss: 0.6999 - val_loss: 1.6901 - val_dice_coef: 0.9727 - val_acc: 0.9812 - val_tversky_loss: 1.6433
#
# Epoch 00043: val_loss did not improve from 1.61456
# Epoch 44/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.8797 - dice_coef: 0.9331 - acc: 0.9391 - tversky_loss: 0.6763 - val_loss: 2.0483 - val_dice_coef: 0.8932 - val_acc: 0.9227 - val_tversky_loss: 1.8732
#
# Epoch 00044: val_loss did not improve from 1.61456
# Epoch 45/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.8625 - dice_coef: 0.9346 - acc: 0.9405 - tversky_loss: 0.6652 - val_loss: 1.6182 - val_dice_coef: 0.9800 - val_acc: 0.9824 - val_tversky_loss: 1.5742
#
# Epoch 00045: val_loss did not improve from 1.61456
# Epoch 46/100
# 1800/1800 [==============================] - 68s 38ms/step - loss: 0.8924 - dice_coef: 0.9340 - acc: 0.9399 - tversky_loss: 0.6943 - val_loss: 1.7749 - val_dice_coef: 0.9631 - val_acc: 0.9798 - val_tversky_loss: 1.7180
#
# Epoch 00046: val_loss did not improve from 1.61456
# Epoch 47/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.8696 - dice_coef: 0.9343 - acc: 0.9401 - tversky_loss: 0.6721 - val_loss: 1.8889 - val_dice_coef: 0.9365 - val_acc: 0.9536 - val_tversky_loss: 1.7700
#
# Epoch 00047: val_loss did not improve from 1.61456
# Epoch 48/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.8630 - dice_coef: 0.9343 - acc: 0.9403 - tversky_loss: 0.6655 - val_loss: 1.8328 - val_dice_coef: 0.9476 - val_acc: 0.9687 - val_tversky_loss: 1.7543
#
# Epoch 00048: val_loss did not improve from 1.61456
# Epoch 49/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.8858 - dice_coef: 0.9340 - acc: 0.9402 - tversky_loss: 0.6880 - val_loss: 1.7513 - val_dice_coef: 0.9700 - val_acc: 0.9823 - val_tversky_loss: 1.7043
#
# Epoch 00049: val_loss did not improve from 1.61456
# Epoch 50/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.8848 - dice_coef: 0.9343 - acc: 0.9403 - tversky_loss: 0.6873 - val_loss: 1.8306 - val_dice_coef: 0.9563 - val_acc: 0.9720 - val_tversky_loss: 1.7576
#
# Epoch 00050: val_loss did not improve from 1.61456
# Epoch 51/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.8773 - dice_coef: 0.9348 - acc: 0.9407 - tversky_loss: 0.6811 - val_loss: 1.6798 - val_dice_coef: 0.9826 - val_acc: 0.9858 - val_tversky_loss: 1.6395
#
# Epoch 00051: val_loss did not improve from 1.61456
# Epoch 52/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.8655 - dice_coef: 0.9352 - acc: 0.9411 - tversky_loss: 0.6707 - val_loss: 1.7623 - val_dice_coef: 0.9663 - val_acc: 0.9772 - val_tversky_loss: 1.7061
#
# Epoch 00052: val_loss did not improve from 1.61456
# Epoch 53/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.8750 - dice_coef: 0.9346 - acc: 0.9405 - tversky_loss: 0.6799 - val_loss: 1.7209 - val_dice_coef: 0.9663 - val_acc: 0.9720 - val_tversky_loss: 1.6528
#
# Epoch 00053: val_loss did not improve from 1.61456
# Epoch 54/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.8665 - dice_coef: 0.9353 - acc: 0.9412 - tversky_loss: 0.6719 - val_loss: 1.9197 - val_dice_coef: 0.9290 - val_acc: 0.9471 - val_tversky_loss: 1.8015
#
# Epoch 00054: val_loss did not improve from 1.61456
# Epoch 55/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.8527 - dice_coef: 0.9353 - acc: 0.9412 - tversky_loss: 0.6591 - val_loss: 1.9212 - val_dice_coef: 0.9256 - val_acc: 0.9364 - val_tversky_loss: 1.7769
#
# Epoch 00055: val_loss did not improve from 1.61456
# Epoch 56/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.8748 - dice_coef: 0.9354 - acc: 0.9412 - tversky_loss: 0.6776 - val_loss: 1.7794 - val_dice_coef: 0.9554 - val_acc: 0.9623 - val_tversky_loss: 1.6885
#
# Epoch 00056: val_loss did not improve from 1.61456
# Epoch 57/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.8801 - dice_coef: 0.9350 - acc: 0.9411 - tversky_loss: 0.6841 - val_loss: 1.6589 - val_dice_coef: 0.9839 - val_acc: 0.9861 - val_tversky_loss: 1.6214
#
# Epoch 00057: val_loss did not improve from 1.61456
# Epoch 58/100
# 1800/1800 [==============================] - 67s 37ms/step - loss: 0.8650 - dice_coef: 0.9354 - acc: 0.9413 - tversky_loss: 0.6700 - val_loss: 1.8925 - val_dice_coef: 0.9316 - val_acc: 0.9446 - val_tversky_loss: 1.7691
#
# Epoch 00058: val_loss did not improve from 1.61456
# Epoch 00058: early stopping

# %%
train_loss = history.history['loss']
train_acc = history.history['acc']
val_loss = history.history['val_loss']
val_acc = history.history['val_acc']
xc=range(len(train_loss))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_loss)
plt.plot(xc, val_loss)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(['train','val'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_acc)
plt.plot(xc, val_acc)
plt.xlabel("Epoch")
plt.ylabel("Acc")
plt.legend(['train','val'])

# %%
# MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models"
# model = keras.models.load_model(MODELS_PATH+'/UNET_ER_20_03_03_v5.h5',custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

# %%
# Function to find the most probable class of an image pixel by pixel
def ClassFinder(img):
  result = np.zeros(img.shape, dtype=np.uint8)
  for r in range(len(img)):
    for c in range(len(img[0])):
      idx = np.argmax(img[r][c])
      result[r][c][idx]=1
      
  return result

# %%
train_result = model.predict(TrainX, batch_size=8)
print(np.shape(train_result))
Train_predict = [ ]
for img in train_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_predict.append(encoded_img)

Predicted_images = np.asarray(Train_predict)
print(Predicted_images.shape)
np.unique(Predicted_images)
# dice = dc(train_result, TrainY)
# pre  = precision(train_result,TrainY)
# re   = recall(train_result,TrainY)
# print('Train dc: '  + str(dice))
# print('Train pre: ' + str(pre))
# print('Train re: '  + str(re))
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240)
# array([  0, 128, 255], dtype=uint8)

# %%
test_result = model.predict(TestX, batch_size=8)
print(np.shape(test_result))

Test_predict = [ ]
for img in test_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_predict.append(encoded_img)

Predicted_images_test = np.asarray(Test_predict)
print(Predicted_images_test.shape)
np.unique(Predicted_images_test)
# dice = dc(test_result, TestY)
# pre  = precision(test_result,TestY)
# re   = recall(test_result,TestY)
# print('Test dc: '  + str(dice))
# print('Test pre: ' + str(pre))
# print('Test re: '  + str(re))
# Out:
# (1440, 240, 240, 3)
# (1440, 240, 240)
# array([  0, 128, 255], dtype=uint8)

# %%
from sklearn.metrics import confusion_matrix
def get_confusion_matrix(Actual, Predicted):
  ActualY = np.reshape(Actual,(-1, Actual.shape[3]))
  PredY = np.reshape(Predicted,(-1, Predicted.shape[3]))
  matrix = confusion_matrix(ActualY.argmax(axis = 1), PredY.argmax(axis = 1))
  return matrix

def get_precision(confusion_matrix):
  precision = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 0)
  nan_indices = np.isnan(precision)
  precision[nan_indices] = 0
  return precision

def get_recall(confusion_matrix):
  recall = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 1)
  nan_indices = np.isnan(recall)
  recall[nan_indices] = 0
  return recall

# %%
test_matrix = get_confusion_matrix(TestY, test_result)
train_matrix = get_confusion_matrix(TrainY, train_result)
print(test_matrix)
print(train_matrix)
# TestY.shape[3]
# test_result.shape
# Out:
# [[75303197  1258719     4609]
#  [  587656  2772658      976]
#  [   94832  2905597    15756]]
# [[82513922  6410094    41397]
#  [  423909  5294812     4194]
#  [  227780  8507864   256028]]

# %%
np.unique(Predicted_images_test)
# Out:
# array([  0, 128, 255], dtype=uint8)

# %%
test_precision = get_precision(test_matrix)
print('Test Precision')
print(test_precision)
test_recall = get_recall(test_matrix)
print('Test Recall')
print(test_recall)
train_precision = get_precision(train_matrix)
print('Train Precision')
print(train_precision)
train_recall = get_recall(train_matrix)
print('Train Recall')
print(train_recall)
# Out:
# Test Precision
# [0.9910182  0.39969272 0.73829717]
# Test Recall
# [0.98350026 0.82487914 0.00522382]
# Train Precision
# [0.99216396 0.2619538  0.84884573]
# Train Recall
# [0.92748316 0.92519494 0.0284739 ]

# %%
# weight_matrix = np.zeros((3,1))
# weight_matrix[0] = 0.6
# weight_matrix[1] = 0.2
# weight_matrix[2] = 0.2
# print(weight_matrix.shape)
# Out:
# (3, 1)

# %%
weight_matrix = np.zeros((3,1))
weight_matrix[0] = 1/3
weight_matrix[1] = 1/3
weight_matrix[2] = 1/3
print(weight_matrix.shape)
# Out:
# (3, 1)

# %%
def get_overall_precision(precision, weights):
  final_precision = np.dot(precision,weights)
  return final_precision

def get_overall_recall(recall, weights):
  final_recall = np.dot(recall ,weights)
  return final_recall

# %%
final_test_precision  = get_overall_precision(test_precision, weight_matrix)
final_test_recall     = get_overall_recall(test_recall, weight_matrix)
final_train_precision = get_overall_precision(train_precision, weight_matrix)
final_train_recall    = get_overall_recall(train_recall, weight_matrix)
print('Final Test Precision')
print(final_test_precision)
print('Final Test Recall')
print(final_test_recall)
print('Final Train Precision')
print(final_train_precision)
print('Final Train Recall')
print(final_train_recall)
# Out:
# Final Test Precision
# [0.70966937]
# Final Test Recall
# [0.6045344]
# Final Train Precision
# [0.70098783]
# Final Train Recall
# [0.62705067]

# %%
from scipy.stats import hmean

def dice_coefficient(precision, recall):
  return hmean(np.asarray([precision , recall]))

# %%
test_dice_coeff = dice_coefficient(final_test_precision, final_test_recall)
print('Test Dice coeff')
print(test_dice_coeff)

train_dice_coeff = dice_coefficient(final_train_precision, final_train_recall)
print('Train Dice coeff')
print(train_dice_coeff)
# Out:
# Test Dice coeff
# [0.65289654]
# Train Dice coeff
# [0.66196106]

# %%
copy1  = np.copy(TestX [250])
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
copy3 = np.reshape(copy2,(240, 240,3))
Img = cv2.cvtColor(copy3,cv2.COLOR_BGR2RGB)

Mask = TestGroundTruth[250]

Predicted_Mask = Predicted_images_test[250] 

plt.subplot(131).imshow(Img)
plt.subplot(132).imshow(Mask,'gray')
plt.subplot(133).imshow(Predicted_Mask,'gray')

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask):
  num = mask.shape[0]/480
  for id in range(int(num)):
    temp = []
    for i in range(id, id+10):
      idx = i * 48
      final_output = mask[idx:idx+48]
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save("/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/Combined_Loss/ER1 Patient " + str(id), final_output)

# %%
# saving predicted outputs as numpy arrays for test images
saveNumpyOutput(Predicted_images)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 25   # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]

Mask_input = TestY[id:id+48]
Test_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Test_Actual)
print(Mask_input.shape)

final_output = Predicted_images_test[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 3)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0. 128. 255.]

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 14  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]

Mask_input = TrainY[id:id+48]
Train_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Train_Actual)
print(Mask_input.shape)

final_output = Predicted_images[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 3)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0. 128. 255.]
