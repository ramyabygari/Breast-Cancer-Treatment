# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from keras.layers import Activation,Conv2D,MaxPooling2D,UpSampling2D,Dense,BatchNormalization,Input,Reshape,multiply,add,Dropout,AveragePooling2D,GlobalAveragePooling2D,concatenate
from keras.layers.convolutional import Conv2DTranspose
from keras.models import Model														  
import keras.backend as K
from keras.regularizers import l2
from keras.engine import Layer,InputSpec
from keras.utils import conv_utils
from keras.layers import Activation,Conv2D,MaxPooling2D,UpSampling2D,Dense,BatchNormalization,Input,Reshape,multiply,add,Dropout,AveragePooling2D,GlobalAveragePooling2D,concatenate
from keras.layers.convolutional import Conv2DTranspose
from keras.models import Model														  
import keras.backend as K
from keras.regularizers import l2
from keras.engine import Layer,InputSpec
from keras.utils import conv_utils
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
def BN_ReLU_Conv(inputs, n_filters, filter_size=3, dropout_p=0.2):

    '''Apply successivly BatchNormalization, ReLu nonlinearity, Convolution and Dropout (if dropout_p > 0)''' 
    l = BatchNormalization()(inputs)
    l = Activation('relu')(l)
    l = Conv2D(n_filters, filter_size, padding='same', kernel_initializer='he_uniform')(l)
    if dropout_p != 0.0:
      l = Dropout(dropout_p)(l)
    return l


def TransitionDown(inputs, n_filters, dropout_p=0.2):

  """ Apply first a BN_ReLu_conv layer with filter size = 1, and a max pooling with a factor 2  """
  l = BN_ReLU_Conv(inputs, n_filters, filter_size=1, dropout_p=dropout_p)
  l = MaxPooling2D((2,2))(l)
  return l

def TransitionUp(skip_connection, block_to_upsample, n_filters_keep):

    '''Performs upsampling on block_to_upsample by a factor 2 and concatenates it with the skip_connection'''

    #Upsample and concatenate with skip connection
    l = Conv2DTranspose(n_filters_keep, kernel_size=3, strides=2, padding='same', kernel_initializer='he_uniform')(block_to_upsample)
    l = concatenate([l, skip_connection], axis=-1)
    return l


def SoftmaxLayer(inputs, n_classes):
    """
    Performs 1x1 convolution followed by softmax nonlinearity
    The output will have the shape (batch_size  * n_rows * n_cols, n_classes)
    """
    l = Conv2D(n_classes, kernel_size=1, padding='same', kernel_initializer='he_uniform')(inputs)
#    l = Reshape((-1, n_classes))(l)
    l = Activation('softmax')(l)#or softmax for multi-class

    return l

# %%
def Tiramisu(

        input_shape=(240,240,3),

        n_classes = 3,

        n_filters_first_conv = 48,

        n_pool = 4,

        growth_rate = 16 ,

        n_layers_per_block =  [3, 3, 3 , 3, 3, 3, 3, 3, 3 ],

        dropout_p = 0.2

        ):

    if type(n_layers_per_block) == list:

            print(len(n_layers_per_block))

    elif type(n_layers_per_block) == int:

            n_layers_per_block = [n_layers_per_block] * (2 * n_pool + 1)

    else:

        raise ValueError

        

#####################

# First Convolution #

#####################        

    inputs = Input(shape=input_shape)

    stack = Conv2D(filters=n_filters_first_conv, kernel_size=3, padding='same', kernel_initializer='he_uniform')(inputs)

    n_filters = n_filters_first_conv



#####################

# Downsampling path #

#####################     

    skip_connection_list = []

    

    for i in range(n_pool):
        print("i")
        print(i)

        for j in range(n_layers_per_block[i]):
            print(j)
            l = BN_ReLU_Conv(stack, growth_rate, dropout_p=dropout_p)

            stack = concatenate([stack, l])

            n_filters += growth_rate

        

        skip_connection_list.append(stack)        

        stack = TransitionDown(stack, n_filters, dropout_p)

    skip_connection_list = skip_connection_list[::-1]



    

#####################

#    Bottleneck     #

#####################     

    block_to_upsample=[]

    

    for j in range(n_layers_per_block[n_pool]):

        l = BN_ReLU_Conv(stack, growth_rate, dropout_p=dropout_p)

        block_to_upsample.append(l)

        stack = concatenate([stack,l])

    block_to_upsample = concatenate(block_to_upsample)



   

#####################

#  Upsampling path  #

#####################

    for i in range(n_pool):

        n_filters_keep = growth_rate * n_layers_per_block[n_pool + i ]

        stack = TransitionUp(skip_connection_list[i], block_to_upsample, n_filters_keep)

        

        block_to_upsample = []

        for j in range(n_layers_per_block[ n_pool + i + 1 ]):

            l = BN_ReLU_Conv(stack, growth_rate, dropout_p=dropout_p)

            block_to_upsample.append(l)

            stack = concatenate([stack, l])

        block_to_upsample = concatenate(block_to_upsample)



#####################

#  Softmax          #

#####################

    output = SoftmaxLayer(stack, n_classes)            

    model=Model(inputs = inputs, outputs = output)    

    model.summary()

    

    return model

# %%
model = Tiramisu()
# Out:
# 9
# i
# 0
# 0
# 1
# 2
# i
# 1
# 0
# 1
# 2
# i
# 2
# 0
# 1
# 2
# i
# 3
# 0
# 1
# 2
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 240, 240, 3)  0
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 240, 240, 48) 1344        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 240, 240, 48) 192         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 240, 240, 48) 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 240, 240, 16) 6928        activation_42[0][0]
# __________________________________________________________________________________________________
# dropout_41 (Dropout)            (None, 240, 240, 16) 0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# concatenate_46 (Concatenate)    (None, 240, 240, 64) 0           conv2d_43[0][0]
#                                                                  dropout_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 240, 240, 64) 256         concatenate_46[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 240, 240, 64) 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 240, 240, 16) 9232        activation_43[0][0]
# __________________________________________________________________________________________________
# dropout_42 (Dropout)            (None, 240, 240, 16) 0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# concatenate_47 (Concatenate)    (None, 240, 240, 80) 0           concatenate_46[0][0]
#                                                                  dropout_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 240, 240, 80) 320         concatenate_47[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 240, 240, 80) 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 240, 240, 16) 11536       activation_44[0][0]
# __________________________________________________________________________________________________
# dropout_43 (Dropout)            (None, 240, 240, 16) 0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# concatenate_48 (Concatenate)    (None, 240, 240, 96) 0           concatenate_47[0][0]
#                                                                  dropout_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 240, 240, 96) 384         concatenate_48[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 240, 240, 96) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 240, 240, 96) 9312        activation_45[0][0]
# __________________________________________________________________________________________________
# dropout_44 (Dropout)            (None, 240, 240, 96) 0           conv2d_47[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 120, 120, 96) 0           dropout_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 120, 120, 96) 384         max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 120, 120, 96) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 120, 120, 16) 13840       activation_46[0][0]
# __________________________________________________________________________________________________
# dropout_45 (Dropout)            (None, 120, 120, 16) 0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# concatenate_49 (Concatenate)    (None, 120, 120, 112 0           max_pooling2d_5[0][0]
#                                                                  dropout_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 120, 120, 112 448         concatenate_49[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 120, 120, 112 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 120, 120, 16) 16144       activation_47[0][0]
# __________________________________________________________________________________________________
# dropout_46 (Dropout)            (None, 120, 120, 16) 0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# concatenate_50 (Concatenate)    (None, 120, 120, 128 0           concatenate_49[0][0]
#                                                                  dropout_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 120, 120, 128 512         concatenate_50[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 120, 120, 128 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 120, 120, 16) 18448       activation_48[0][0]
# __________________________________________________________________________________________________
# dropout_47 (Dropout)            (None, 120, 120, 16) 0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_51 (Concatenate)    (None, 120, 120, 144 0           concatenate_50[0][0]
#                                                                  dropout_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 120, 120, 144 576         concatenate_51[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 120, 120, 144 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 120, 120, 144 20880       activation_49[0][0]
# __________________________________________________________________________________________________
# dropout_48 (Dropout)            (None, 120, 120, 144 0           conv2d_51[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 60, 60, 144)  0           dropout_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 60, 60, 144)  576         max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 60, 60, 144)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 60, 60, 16)   20752       activation_50[0][0]
# __________________________________________________________________________________________________
# dropout_49 (Dropout)            (None, 60, 60, 16)   0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# concatenate_52 (Concatenate)    (None, 60, 60, 160)  0           max_pooling2d_6[0][0]
#                                                                  dropout_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 60, 60, 160)  640         concatenate_52[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 60, 60, 160)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 60, 60, 16)   23056       activation_51[0][0]
# __________________________________________________________________________________________________
# dropout_50 (Dropout)            (None, 60, 60, 16)   0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# concatenate_53 (Concatenate)    (None, 60, 60, 176)  0           concatenate_52[0][0]
#                                                                  dropout_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 60, 60, 176)  704         concatenate_53[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 60, 60, 176)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 60, 60, 16)   25360       activation_52[0][0]
# __________________________________________________________________________________________________
# dropout_51 (Dropout)            (None, 60, 60, 16)   0           conv2d_54[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 60, 60, 192)  0           concatenate_53[0][0]
#                                                                  dropout_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 60, 60, 192)  768         concatenate_54[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 60, 60, 192)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 60, 60, 192)  37056       activation_53[0][0]
# __________________________________________________________________________________________________
# dropout_52 (Dropout)            (None, 60, 60, 192)  0           conv2d_55[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 30, 30, 192)  0           dropout_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 30, 30, 192)  768         max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 30, 30, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 30, 30, 16)   27664       activation_54[0][0]
# __________________________________________________________________________________________________
# dropout_53 (Dropout)            (None, 30, 30, 16)   0           conv2d_56[0][0]
# __________________________________________________________________________________________________
# concatenate_55 (Concatenate)    (None, 30, 30, 208)  0           max_pooling2d_7[0][0]
#                                                                  dropout_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 30, 30, 208)  832         concatenate_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 30, 30, 208)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 30, 30, 16)   29968       activation_55[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 30, 30, 16)   0           conv2d_57[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 30, 30, 224)  0           concatenate_55[0][0]
#                                                                  dropout_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 30, 30, 224)  896         concatenate_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 30, 30, 224)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 30, 30, 16)   32272       activation_56[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 30, 30, 16)   0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 30, 30, 240)  0           concatenate_56[0][0]
#                                                                  dropout_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 30, 30, 240)  960         concatenate_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 30, 30, 240)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 30, 30, 240)  57840       activation_57[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 30, 30, 240)  0           conv2d_59[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 15, 15, 240)  0           dropout_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 15, 15, 240)  960         max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 15, 15, 240)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 15, 15, 16)   34576       activation_58[0][0]
# __________________________________________________________________________________________________
# dropout_57 (Dropout)            (None, 15, 15, 16)   0           conv2d_60[0][0]
# __________________________________________________________________________________________________
# concatenate_58 (Concatenate)    (None, 15, 15, 256)  0           max_pooling2d_8[0][0]
#                                                                  dropout_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 15, 15, 256)  1024        concatenate_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 15, 15, 256)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 15, 15, 16)   36880       activation_59[0][0]
# __________________________________________________________________________________________________
# dropout_58 (Dropout)            (None, 15, 15, 16)   0           conv2d_61[0][0]
# __________________________________________________________________________________________________
# concatenate_59 (Concatenate)    (None, 15, 15, 272)  0           concatenate_58[0][0]
#                                                                  dropout_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 15, 15, 272)  1088        concatenate_59[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 15, 15, 272)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 15, 15, 16)   39184       activation_60[0][0]
# __________________________________________________________________________________________________
# dropout_59 (Dropout)            (None, 15, 15, 16)   0           conv2d_62[0][0]
# __________________________________________________________________________________________________
# concatenate_61 (Concatenate)    (None, 15, 15, 48)   0           dropout_57[0][0]
#                                                                  dropout_58[0][0]
#                                                                  dropout_59[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 30, 30, 48)   20784       concatenate_61[0][0]
# __________________________________________________________________________________________________
# concatenate_62 (Concatenate)    (None, 30, 30, 288)  0           conv2d_transpose_5[0][0]
#                                                                  concatenate_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 30, 30, 288)  1152        concatenate_62[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 30, 30, 288)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 30, 30, 16)   41488       activation_61[0][0]
# __________________________________________________________________________________________________
# dropout_60 (Dropout)            (None, 30, 30, 16)   0           conv2d_63[0][0]
# __________________________________________________________________________________________________
# concatenate_63 (Concatenate)    (None, 30, 30, 304)  0           concatenate_62[0][0]
#                                                                  dropout_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 30, 30, 304)  1216        concatenate_63[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 30, 30, 304)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 30, 30, 16)   43792       activation_62[0][0]
# __________________________________________________________________________________________________
# dropout_61 (Dropout)            (None, 30, 30, 16)   0           conv2d_64[0][0]
# __________________________________________________________________________________________________
# concatenate_64 (Concatenate)    (None, 30, 30, 320)  0           concatenate_63[0][0]
#                                                                  dropout_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 30, 30, 320)  1280        concatenate_64[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 30, 30, 320)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 30, 30, 16)   46096       activation_63[0][0]
# __________________________________________________________________________________________________
# dropout_62 (Dropout)            (None, 30, 30, 16)   0           conv2d_65[0][0]
# __________________________________________________________________________________________________
# concatenate_66 (Concatenate)    (None, 30, 30, 48)   0           dropout_60[0][0]
#                                                                  dropout_61[0][0]
#                                                                  dropout_62[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 60, 60, 48)   20784       concatenate_66[0][0]
# __________________________________________________________________________________________________
# concatenate_67 (Concatenate)    (None, 60, 60, 240)  0           conv2d_transpose_6[0][0]
#                                                                  concatenate_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 60, 60, 240)  960         concatenate_67[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 60, 60, 240)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 60, 60, 16)   34576       activation_64[0][0]
# __________________________________________________________________________________________________
# dropout_63 (Dropout)            (None, 60, 60, 16)   0           conv2d_66[0][0]
# __________________________________________________________________________________________________
# concatenate_68 (Concatenate)    (None, 60, 60, 256)  0           concatenate_67[0][0]
#                                                                  dropout_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 60, 60, 256)  1024        concatenate_68[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 60, 60, 256)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 60, 60, 16)   36880       activation_65[0][0]
# __________________________________________________________________________________________________
# dropout_64 (Dropout)            (None, 60, 60, 16)   0           conv2d_67[0][0]
# __________________________________________________________________________________________________
# concatenate_69 (Concatenate)    (None, 60, 60, 272)  0           concatenate_68[0][0]
#                                                                  dropout_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 60, 60, 272)  1088        concatenate_69[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 60, 60, 272)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 60, 60, 16)   39184       activation_66[0][0]
# __________________________________________________________________________________________________
# dropout_65 (Dropout)            (None, 60, 60, 16)   0           conv2d_68[0][0]
# __________________________________________________________________________________________________
# concatenate_71 (Concatenate)    (None, 60, 60, 48)   0           dropout_63[0][0]
#                                                                  dropout_64[0][0]
#                                                                  dropout_65[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 120, 120, 48) 20784       concatenate_71[0][0]
# __________________________________________________________________________________________________
# concatenate_72 (Concatenate)    (None, 120, 120, 192 0           conv2d_transpose_7[0][0]
#                                                                  concatenate_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 120, 120, 192 768         concatenate_72[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 120, 120, 192 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 120, 120, 16) 27664       activation_67[0][0]
# __________________________________________________________________________________________________
# dropout_66 (Dropout)            (None, 120, 120, 16) 0           conv2d_69[0][0]
# __________________________________________________________________________________________________
# concatenate_73 (Concatenate)    (None, 120, 120, 208 0           concatenate_72[0][0]
#                                                                  dropout_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 120, 120, 208 832         concatenate_73[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 120, 120, 208 0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 120, 120, 16) 29968       activation_68[0][0]
# __________________________________________________________________________________________________
# dropout_67 (Dropout)            (None, 120, 120, 16) 0           conv2d_70[0][0]
# __________________________________________________________________________________________________
# concatenate_74 (Concatenate)    (None, 120, 120, 224 0           concatenate_73[0][0]
#                                                                  dropout_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 120, 120, 224 896         concatenate_74[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 120, 120, 224 0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 120, 120, 16) 32272       activation_69[0][0]
# __________________________________________________________________________________________________
# dropout_68 (Dropout)            (None, 120, 120, 16) 0           conv2d_71[0][0]
# __________________________________________________________________________________________________
# concatenate_76 (Concatenate)    (None, 120, 120, 48) 0           dropout_66[0][0]
#                                                                  dropout_67[0][0]
#                                                                  dropout_68[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 240, 240, 48) 20784       concatenate_76[0][0]
# __________________________________________________________________________________________________
# concatenate_77 (Concatenate)    (None, 240, 240, 144 0           conv2d_transpose_8[0][0]
#                                                                  concatenate_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 240, 240, 144 576         concatenate_77[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 240, 240, 144 0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 240, 240, 16) 20752       activation_70[0][0]
# __________________________________________________________________________________________________
# dropout_69 (Dropout)            (None, 240, 240, 16) 0           conv2d_72[0][0]
# __________________________________________________________________________________________________
# concatenate_78 (Concatenate)    (None, 240, 240, 160 0           concatenate_77[0][0]
#                                                                  dropout_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 240, 240, 160 640         concatenate_78[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 240, 240, 160 0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 240, 240, 16) 23056       activation_71[0][0]
# __________________________________________________________________________________________________
# dropout_70 (Dropout)            (None, 240, 240, 16) 0           conv2d_73[0][0]
# __________________________________________________________________________________________________
# concatenate_79 (Concatenate)    (None, 240, 240, 176 0           concatenate_78[0][0]
#                                                                  dropout_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 240, 240, 176 704         concatenate_79[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 240, 240, 176 0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 240, 240, 16) 25360       activation_72[0][0]
# __________________________________________________________________________________________________
# dropout_71 (Dropout)            (None, 240, 240, 16) 0           conv2d_74[0][0]
# __________________________________________________________________________________________________
# concatenate_80 (Concatenate)    (None, 240, 240, 192 0           concatenate_79[0][0]
#                                                                  dropout_71[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 240, 240, 3)  579         concatenate_80[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 240, 240, 3)  0           conv2d_75[0][0]
# ==================================================================================================
# Total params: 980,499
# Trainable params: 968,787
# Non-trainable params: 11,712
# __________________________________________________________________________________________________

# %%
import os
import cv2
import numpy as np

# %%
# Function to convert image from greyscale to one hot (i.e. 3 channels)
def convertToOneHot(image):
    num_classes = 3
    shape = image.shape[:2]+(num_classes,)
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c]==0:
          encoded_image[r][c][0] = 1
        elif image[r][c]==128:
          encoded_image[r][c][1] = 1
        else:
          encoded_image[r][c][2] = 1
    return encoded_image

# %%
# Function to convert back from one hot image to greyscale
def convertFromOneHot(image):
    shape = image.shape[:2]
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c][0] == 1:
          encoded_image[r][c] = 0
        elif image[r][c][1] == 1:
          encoded_image[r][c] = 128
        else:
          encoded_image[r][c] = 255
    return encoded_image

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/3 Class"

# Train set patients: 230 232 239 242 
TrainX_1 = np.load(PATH + '/ER IHC 239 Images.npy')
TrainY_1 = np.load(PATH + '/ER IHC 239 Masks.npy')
TrainX_2 = np.load(PATH + '/ER IHC 263 Images.npy')
TrainY_2 = np.load(PATH + '/ER IHC 263 Masks.npy')
TrainX_3 = np.load(PATH + '/ER IHC 242 Images.npy')
TrainY_3 = np.load(PATH + '/ER IHC 242 Masks.npy')
TrainX_4 = np.load(PATH + '/ER IHC 230 Images.npy')
TrainY_4 = np.load(PATH + '/ER IHC 230 Masks.npy')

# Test set patients: 221 246 263
TestX_1 = np.load(PATH + '/ER IHC 221 Images.npy')
TestY_1 = np.load(PATH + '/ER IHC 221 Masks.npy')
TestX_2 = np.load(PATH + '/ER IHC 246 Images.npy')
TestY_2 = np.load(PATH + '/ER IHC 246 Masks.npy')
TestX_3 = np.load(PATH + '/ER IHC 232 Images.npy')
TestY_3 = np.load(PATH + '/ER IHC 232 Masks.npy')

# %%
TrainX_3.shape
# Out:
# (480, 240, 240, 3)

# %%
TrainX = np.concatenate((TrainX_1, TrainX_2, TrainX_3, TrainX_4), axis=0)
TrainGroundTruth = np.concatenate((TrainY_1, TrainY_2, TrainY_3, TrainY_4), axis=0)
TrainY = []

for img in TrainGroundTruth:
  encoded_img = convertToOneHot(img)
  TrainY.append(encoded_img)

TrainY = np.asarray(TrainY)

TestX = np.concatenate((TestX_1, TestX_2, TestX_3), axis=0)
TestGroundTruth = np.concatenate((TestY_1, TestY_2, TestY_3), axis=0)
TestY = []

for img in TestGroundTruth:
  encoded_img = convertToOneHot(img)
  TestY.append(encoded_img)

TestY = np.asarray(TestY)

ValidX = TrainX[1800:, : ]
ValidY = TrainY[1800:, : ]

TrainX = TrainX[0:1800, : ]
TrainY = TrainY[0:1800, : ]

print(TrainX.shape)
print(TrainY.shape)
print(TestX.shape)
print(TestY.shape)
print(ValidX.shape)
print(ValidY.shape)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 3)
# (1440, 240, 240, 3)
# (1440, 240, 240, 3)
# (120, 240, 240, 3)
# (120, 240, 240, 3)

# %%
TrainX = np.reshape(TrainX,(-1,240, 240,3))
TrainY = np.reshape(TrainY,(-1,240, 240,3))

TrainX = TrainX.astype('float32')/255

TestX = np.reshape(TestX,(-1,240, 240,3))
TestY = np.reshape(TestY,(-1,240, 240,3))

TestX = TestX.astype('float32')/255

ValidX = np.reshape(ValidX,(-1,240, 240,3))
ValidY = np.reshape(ValidY,(-1,240, 240,3))

ValidX = ValidX.astype('float32')/255

# %%
print(TrainX.shape)
print(TrainY.shape)
print(TestX.shape)
print(TestY.shape)

print(ValidX.shape)
print(ValidY.shape)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 3)
# (1440, 240, 240, 3)
# (1440, 240, 240, 3)
# (120, 240, 240, 3)
# (120, 240, 240, 3)

# %%
# !pip install medpy
from keras.layers import *
import keras
from keras.models import Sequential
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from medpy.metric import dc, precision, recall
from keras import Model
from keras.layers import (Input, Convolution2D, Activation, BatchNormalization,
                          merge, AveragePooling2D, GlobalAveragePooling2D,
                          Dense, Dropout)
from keras.regularizers import l2
# Out:
# Collecting medpy
#   Downloading https://files.pythonhosted.org/packages/3b/70/c1fd5dd60242eee81774696ea7ba4caafac2bad8f028bba94b1af83777d7/MedPy-0.4.0.tar.gz (151kB)
#      |████████████████████████████████| 153kB 2.7MB/s
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.18.1)
# Collecting SimpleITK>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/f8/d8/53338c34f71020725ffb3557846c80af96c29c03bc883551a2565aa68a7c/SimpleITK-1.2.4-cp36-cp36m-manylinux1_x86_64.whl (42.5MB)
#      |████████████████████████████████| 42.5MB 77kB/s
# Building wheels for collected packages: medpy
#   Building wheel for medpy (setup.py) ... done
#   Created wheel for medpy: filename=MedPy-0.4.0-cp36-cp36m-linux_x86_64.whl size=753429 sha256=d9d4db8130a32526ee46e8f5ca5ee96efb3084b30f040d7af81196d1dd74cd6d
#   Stored in directory: /root/.cache/pip/wheels/8c/c9/9c/2c6281c7a72b9fb1570862a4f028af7ce38405008354fbf870
# Successfully built medpy
# Installing collected packages: SimpleITK, medpy
# Successfully installed SimpleITK-1.2.4 medpy-0.4.0

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def combined_loss(y_true, y_pred):
  return (1*K.categorical_crossentropy(y_true, y_pred))+(0.5*tversky_loss(y_true, y_pred))

# %%
import math
from keras.callbacks import EarlyStopping,ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
mc = ModelCheckpoint('Checkpoint.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=True)

# %%
from keras import backend as K      
model.compile(loss=tversky_loss, optimizer=optimizer, metrics=[dice_coef,'accuracy',tversky_loss])

# %%
num_epoch = 100;
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models"
history = model.fit(TrainX, TrainY, epochs=num_epoch, validation_data=(ValidX, ValidY), shuffle=True,batch_size=8,callbacks=[es,mc])
model.save(MODELS_PATH + '/UNET_ER_20_03_19_4block.h5')
# Out:
# Train on 1800 samples, validate on 120 samples
# Epoch 1/100
# 1800/1800 [==============================] - 266s 148ms/step - loss: 0.9159 - dice_coef: 0.9120 - acc: 0.9134 - tversky_loss: 0.9159 - val_loss: 1.7506 - val_dice_coef: 0.9901 - val_acc: 0.9901 - val_tversky_loss: 1.7506
#
# Epoch 00001: val_loss improved from inf to 1.75062, saving model to Checkpoint.h5
# Epoch 2/100
# 1800/1800 [==============================] - 258s 143ms/step - loss: 0.7749 - dice_coef: 0.9265 - acc: 0.9266 - tversky_loss: 0.7749 - val_loss: 1.5269 - val_dice_coef: 0.9904 - val_acc: 0.9904 - val_tversky_loss: 1.5269
#
# Epoch 00002: val_loss improved from 1.75062 to 1.52694, saving model to Checkpoint.h5
# Epoch 3/100
# 1800/1800 [==============================] - 258s 143ms/step - loss: 0.7555 - dice_coef: 0.9274 - acc: 0.9275 - tversky_loss: 0.7555 - val_loss: 1.5268 - val_dice_coef: 0.9906 - val_acc: 0.9906 - val_tversky_loss: 1.5268
#
# Epoch 00003: val_loss improved from 1.52694 to 1.52679, saving model to Checkpoint.h5
# Epoch 4/100
# 1800/1800 [==============================] - 259s 144ms/step - loss: 0.7602 - dice_coef: 0.9293 - acc: 0.9293 - tversky_loss: 0.7602 - val_loss: 1.4967 - val_dice_coef: 0.9906 - val_acc: 0.9906 - val_tversky_loss: 1.4967
#
# Epoch 00004: val_loss improved from 1.52679 to 1.49668, saving model to Checkpoint.h5
# Epoch 5/100
# 1800/1800 [==============================] - 258s 144ms/step - loss: 0.7425 - dice_coef: 0.9292 - acc: 0.9292 - tversky_loss: 0.7425 - val_loss: 1.8554 - val_dice_coef: 0.8916 - val_acc: 0.8925 - val_tversky_loss: 1.8554
#
# Epoch 00005: val_loss did not improve from 1.49668
# Epoch 6/100
# 1800/1800 [==============================] - 258s 143ms/step - loss: 0.7162 - dice_coef: 0.9314 - acc: 0.9314 - tversky_loss: 0.7162 - val_loss: 1.5096 - val_dice_coef: 0.9907 - val_acc: 0.9907 - val_tversky_loss: 1.5096
#
# Epoch 00006: val_loss did not improve from 1.49668
# Epoch 7/100
# 1800/1800 [==============================] - 259s 144ms/step - loss: 0.7355 - dice_coef: 0.9307 - acc: 0.9307 - tversky_loss: 0.7355 - val_loss: 1.4724 - val_dice_coef: 0.9895 - val_acc: 0.9895 - val_tversky_loss: 1.4724
#
# Epoch 00007: val_loss improved from 1.49668 to 1.47237, saving model to Checkpoint.h5
# Epoch 8/100
# 1800/1800 [==============================] - 258s 144ms/step - loss: 0.7269 - dice_coef: 0.9322 - acc: 0.9322 - tversky_loss: 0.7269 - val_loss: 1.7405 - val_dice_coef: 0.9348 - val_acc: 0.9353 - val_tversky_loss: 1.7405
#
# Epoch 00008: val_loss did not improve from 1.47237
# Epoch 9/100
# 1800/1800 [==============================] - 258s 143ms/step - loss: 0.7010 - dice_coef: 0.9327 - acc: 0.9327 - tversky_loss: 0.7010 - val_loss: 1.6367 - val_dice_coef: 0.9645 - val_acc: 0.9648 - val_tversky_loss: 1.6367
#
# Epoch 00009: val_loss did not improve from 1.47237
# Epoch 10/100
# 1800/1800 [==============================] - 257s 143ms/step - loss: 0.7108 - dice_coef: 0.9319 - acc: 0.9319 - tversky_loss: 0.7108 - val_loss: 1.6152 - val_dice_coef: 0.9905 - val_acc: 0.9905 - val_tversky_loss: 1.6152
#
# Epoch 00010: val_loss did not improve from 1.47237
# Epoch 11/100
# 1800/1800 [==============================] - 257s 143ms/step - loss: 0.7008 - dice_coef: 0.9331 - acc: 0.9331 - tversky_loss: 0.7008 - val_loss: 1.5720 - val_dice_coef: 0.9910 - val_acc: 0.9910 - val_tversky_loss: 1.5720
#
# Epoch 00011: val_loss did not improve from 1.47237
# Epoch 12/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6995 - dice_coef: 0.9332 - acc: 0.9332 - tversky_loss: 0.6995 - val_loss: 1.6093 - val_dice_coef: 0.9721 - val_acc: 0.9722 - val_tversky_loss: 1.6093
#
# Epoch 00012: val_loss did not improve from 1.47237
# Epoch 13/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6977 - dice_coef: 0.9333 - acc: 0.9333 - tversky_loss: 0.6977 - val_loss: 1.4931 - val_dice_coef: 0.9893 - val_acc: 0.9893 - val_tversky_loss: 1.4931
#
# Epoch 00013: val_loss did not improve from 1.47237
# Epoch 14/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6990 - dice_coef: 0.9332 - acc: 0.9332 - tversky_loss: 0.6990 - val_loss: 1.4944 - val_dice_coef: 0.9895 - val_acc: 0.9895 - val_tversky_loss: 1.4944
#
# Epoch 00014: val_loss did not improve from 1.47237
# Epoch 15/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6877 - dice_coef: 0.9342 - acc: 0.9342 - tversky_loss: 0.6877 - val_loss: 1.7521 - val_dice_coef: 0.9232 - val_acc: 0.9234 - val_tversky_loss: 1.7521
#
# Epoch 00015: val_loss did not improve from 1.47237
# Epoch 16/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6864 - dice_coef: 0.9349 - acc: 0.9349 - tversky_loss: 0.6864 - val_loss: 2.2092 - val_dice_coef: 0.5911 - val_acc: 0.5911 - val_tversky_loss: 2.2092
#
# Epoch 00016: val_loss did not improve from 1.47237
# Epoch 17/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6896 - dice_coef: 0.9334 - acc: 0.9334 - tversky_loss: 0.6896 - val_loss: 1.4818 - val_dice_coef: 0.9881 - val_acc: 0.9881 - val_tversky_loss: 1.4818
#
# Epoch 00017: val_loss did not improve from 1.47237
# Epoch 18/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6902 - dice_coef: 0.9353 - acc: 0.9353 - tversky_loss: 0.6902 - val_loss: 1.5207 - val_dice_coef: 0.9907 - val_acc: 0.9907 - val_tversky_loss: 1.5207
#
# Epoch 00018: val_loss did not improve from 1.47237
# Epoch 19/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6910 - dice_coef: 0.9345 - acc: 0.9345 - tversky_loss: 0.6910 - val_loss: 1.5146 - val_dice_coef: 0.9848 - val_acc: 0.9848 - val_tversky_loss: 1.5146
#
# Epoch 00019: val_loss did not improve from 1.47237
# Epoch 20/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6657 - dice_coef: 0.9354 - acc: 0.9354 - tversky_loss: 0.6657 - val_loss: 1.5038 - val_dice_coef: 0.9872 - val_acc: 0.9872 - val_tversky_loss: 1.5038
#
# Epoch 00020: val_loss did not improve from 1.47237
# Epoch 21/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6955 - dice_coef: 0.9341 - acc: 0.9341 - tversky_loss: 0.6955 - val_loss: 1.5942 - val_dice_coef: 0.9727 - val_acc: 0.9728 - val_tversky_loss: 1.5942
#
# Epoch 00021: val_loss did not improve from 1.47237
# Epoch 22/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.7038 - dice_coef: 0.9339 - acc: 0.9339 - tversky_loss: 0.7038 - val_loss: 1.4913 - val_dice_coef: 0.9866 - val_acc: 0.9866 - val_tversky_loss: 1.4913
#
# Epoch 00022: val_loss did not improve from 1.47237
# Epoch 23/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.7095 - dice_coef: 0.9340 - acc: 0.9341 - tversky_loss: 0.7095 - val_loss: 1.8392 - val_dice_coef: 0.8670 - val_acc: 0.8671 - val_tversky_loss: 1.8392
#
# Epoch 00023: val_loss did not improve from 1.47237
# Epoch 24/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6776 - dice_coef: 0.9353 - acc: 0.9354 - tversky_loss: 0.6776 - val_loss: 1.6275 - val_dice_coef: 0.9675 - val_acc: 0.9676 - val_tversky_loss: 1.6275
#
# Epoch 00024: val_loss did not improve from 1.47237
# Epoch 25/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6786 - dice_coef: 0.9359 - acc: 0.9359 - tversky_loss: 0.6786 - val_loss: 1.8664 - val_dice_coef: 0.8665 - val_acc: 0.8667 - val_tversky_loss: 1.8664
#
# Epoch 00025: val_loss did not improve from 1.47237
# Epoch 26/100
# 1800/1800 [==============================] - 257s 143ms/step - loss: 0.6773 - dice_coef: 0.9348 - acc: 0.9348 - tversky_loss: 0.6773 - val_loss: 1.7295 - val_dice_coef: 0.9368 - val_acc: 0.9369 - val_tversky_loss: 1.7295
#
# Epoch 00026: val_loss did not improve from 1.47237
# Epoch 27/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6553 - dice_coef: 0.9358 - acc: 0.9358 - tversky_loss: 0.6553 - val_loss: 1.6565 - val_dice_coef: 0.9590 - val_acc: 0.9591 - val_tversky_loss: 1.6565
#
# Epoch 00027: val_loss did not improve from 1.47237
# Epoch 28/100
# 1800/1800 [==============================] - 255s 142ms/step - loss: 0.6699 - dice_coef: 0.9362 - acc: 0.9362 - tversky_loss: 0.6699 - val_loss: 1.4802 - val_dice_coef: 0.9892 - val_acc: 0.9892 - val_tversky_loss: 1.4802
#
# Epoch 00028: val_loss did not improve from 1.47237
# Epoch 29/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6848 - dice_coef: 0.9349 - acc: 0.9349 - tversky_loss: 0.6848 - val_loss: 2.1169 - val_dice_coef: 0.6757 - val_acc: 0.6757 - val_tversky_loss: 2.1169
#
# Epoch 00029: val_loss did not improve from 1.47237
# Epoch 30/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6895 - dice_coef: 0.9344 - acc: 0.9344 - tversky_loss: 0.6895 - val_loss: 1.5775 - val_dice_coef: 0.9749 - val_acc: 0.9749 - val_tversky_loss: 1.5775
#
# Epoch 00030: val_loss did not improve from 1.47237
# Epoch 31/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6844 - dice_coef: 0.9360 - acc: 0.9360 - tversky_loss: 0.6844 - val_loss: 1.4877 - val_dice_coef: 0.9878 - val_acc: 0.9878 - val_tversky_loss: 1.4877
#
# Epoch 00031: val_loss did not improve from 1.47237
# Epoch 32/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6931 - dice_coef: 0.9351 - acc: 0.9351 - tversky_loss: 0.6931 - val_loss: 1.4842 - val_dice_coef: 0.9870 - val_acc: 0.9870 - val_tversky_loss: 1.4842
#
# Epoch 00032: val_loss did not improve from 1.47237
# Epoch 33/100
# 1800/1800 [==============================] - 255s 142ms/step - loss: 0.6952 - dice_coef: 0.9359 - acc: 0.9359 - tversky_loss: 0.6952 - val_loss: 1.5641 - val_dice_coef: 0.9789 - val_acc: 0.9789 - val_tversky_loss: 1.5641
#
# Epoch 00033: val_loss did not improve from 1.47237
# Epoch 34/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6872 - dice_coef: 0.9352 - acc: 0.9352 - tversky_loss: 0.6872 - val_loss: 1.6249 - val_dice_coef: 0.9675 - val_acc: 0.9676 - val_tversky_loss: 1.6249
#
# Epoch 00034: val_loss did not improve from 1.47237
# Epoch 35/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6695 - dice_coef: 0.9358 - acc: 0.9358 - tversky_loss: 0.6695 - val_loss: 1.4936 - val_dice_coef: 0.9858 - val_acc: 0.9858 - val_tversky_loss: 1.4936
#
# Epoch 00035: val_loss did not improve from 1.47237
# Epoch 36/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6855 - dice_coef: 0.9363 - acc: 0.9363 - tversky_loss: 0.6855 - val_loss: 1.6381 - val_dice_coef: 0.9657 - val_acc: 0.9658 - val_tversky_loss: 1.6381
#
# Epoch 00036: val_loss did not improve from 1.47237
# Epoch 37/100
# 1800/1800 [==============================] - 256s 142ms/step - loss: 0.6635 - dice_coef: 0.9367 - acc: 0.9367 - tversky_loss: 0.6635 - val_loss: 1.6102 - val_dice_coef: 0.9704 - val_acc: 0.9704 - val_tversky_loss: 1.6102
#
# Epoch 00037: val_loss did not improve from 1.47237
# Epoch 00037: early stopping

# %%
# from keras.models import load_model
# MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models"
# model = load_model(MODELS_PATH + '/UNET_ER_20_03_17_4block.h5', custom_objects={'combined_loss': combined_loss, 'dice_coef': dice_coef, 'tversky_loss': tversky_loss})

# %%
train_loss = history.history['loss']
train_acc = history.history['acc']
val_loss = history.history['val_loss']
val_acc = history.history['val_acc']
xc=range(len(train_loss))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_loss)
plt.plot(xc, val_loss)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(['train','val'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_acc)
plt.plot(xc, val_acc)
plt.xlabel("Epoch")
plt.ylabel("Acc")
plt.legend(['train','val'])

# %%
# MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models"
# model = keras.models.load_model(MODELS_PATH+'/UNET_ER_20_03_03_v5.h5',custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

# %%
# Function to find the most probable class of an image pixel by pixel
def ClassFinder(img):
  result = np.zeros(img.shape, dtype=np.uint8)
  for r in range(len(img)):
    for c in range(len(img[0])):
      idx = np.argmax(img[r][c])
      result[r][c][idx]=1
      
  return result

# %%
train_result = model.predict(TrainX, batch_size=8)
print(np.shape(train_result))
Train_predict = [ ]
for img in train_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_predict.append(encoded_img)

Predicted_images = np.asarray(Train_predict)
print(Predicted_images.shape)
np.unique(Predicted_images)
# dice = dc(train_result, TrainY)
# pre  = precision(train_result,TrainY)
# re   = recall(train_result,TrainY)
# print('Train dc: '  + str(dice))
# print('Train pre: ' + str(pre))
# print('Train re: '  + str(re))
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240)
# array([  0, 128, 255], dtype=uint8)

# %%
test_result = model.predict(TestX, batch_size=8)
print(np.shape(test_result))

Test_predict = [ ]
for img in test_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_predict.append(encoded_img)

Predicted_images_test = np.asarray(Test_predict)
print(Predicted_images_test.shape)
np.unique(Predicted_images_test)
# dice = dc(test_result, TestY)
# pre  = precision(test_result,TestY)
# re   = recall(test_result,TestY)
# print('Test dc: '  + str(dice))
# print('Test pre: ' + str(pre))
# print('Test re: '  + str(re))
# Out:
# (1440, 240, 240, 3)
# (1440, 240, 240)
# array([  0, 128, 255], dtype=uint8)

# %%
from sklearn.metrics import confusion_matrix
def get_confusion_matrix(Actual, Predicted):
  ActualY = np.reshape(Actual,(-1, Actual.shape[3]))
  PredY = np.reshape(Predicted,(-1, Predicted.shape[3]))
  matrix = confusion_matrix(ActualY.argmax(axis = 1), PredY.argmax(axis = 1))
  return matrix

def get_precision(confusion_matrix):
  precision = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 0)
  nan_indices = np.isnan(precision)
  precision[nan_indices] = 0
  return precision

def get_recall(confusion_matrix):
  recall = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 1)
  nan_indices = np.isnan(recall)
  recall[nan_indices] = 0
  return recall

# %%
test_matrix = get_confusion_matrix(TestY, test_result)
train_matrix = get_confusion_matrix(TrainY, train_result)
print(test_matrix)
print(train_matrix)
# TestY.shape[3]
# test_result.shape
# Out:
# [[74600141  1962088     4296]
#  [  434467  2926769       54]
#  [   50269  2958425     7491]]
# [[80671897  8271100    22416]
#  [  276793  5445180      942]
#  [   95333  8691598   204741]]

# %%
np.unique(Predicted_images_test)
# Out:
# array([  0, 128, 255], dtype=uint8)

# %%
test_precision = get_precision(test_matrix)
print('Test Precision')
print(test_precision)
test_recall = get_recall(test_matrix)
print('Test Recall')
print(test_recall)
train_precision = get_precision(train_matrix)
print('Train Precision')
print(train_precision)
train_recall = get_recall(train_matrix)
print('Train Recall')
print(train_recall)
# Out:
# Test Precision
# [0.99354416 0.37296595 0.63263238]
# Test Recall
# [0.97431797 0.87072791 0.0024836 ]
# Train Precision
# [0.99540835 0.24300293 0.8975971 ]
# Train Recall
# [0.9067782  0.95146966 0.02277007]

# %%
# weight_matrix = np.zeros((3,1))
# weight_matrix[0] = 0.6
# weight_matrix[1] = 0.2
# weight_matrix[2] = 0.2
# print(weight_matrix.shape)

# %%
weight_matrix = np.zeros((3,1))
weight_matrix[0] = 1/3
weight_matrix[1] = 1/3
weight_matrix[2] = 1/3
print(weight_matrix.shape)
# Out:
# (3, 1)

# %%
def get_overall_precision(precision, weights):
  final_precision = np.dot(precision,weights)
  return final_precision

def get_overall_recall(recall, weights):
  final_recall = np.dot(recall ,weights)
  return final_recall

# %%
final_test_precision  = get_overall_precision(test_precision, weight_matrix)
final_test_recall     = get_overall_recall(test_recall, weight_matrix)
final_train_precision = get_overall_precision(train_precision, weight_matrix)
final_train_recall    = get_overall_recall(train_recall, weight_matrix)
print('Final Test Precision')
print(final_test_precision)
print('Final Test Recall')
print(final_test_recall)
print('Final Train Precision')
print(final_train_precision)
print('Final Train Recall')
print(final_train_recall)
# Out:
# Final Test Precision
# [0.66638083]
# Final Test Recall
# [0.61584316]
# Final Train Precision
# [0.71200279]
# Final Train Recall
# [0.62700598]

# %%
from scipy.stats import hmean

def dice_coefficient(precision, recall):
  return hmean(np.asarray([precision , recall]))

# %%
test_dice_coeff = dice_coefficient(final_test_precision, final_test_recall)
print('Test Dice coeff')
print(test_dice_coeff)

train_dice_coeff = dice_coefficient(final_train_precision, final_train_recall)
print('Train Dice coeff')
print(train_dice_coeff)
# Out:
# Test Dice coeff
# [0.64011605]
# Train Dice coeff
# [0.6668067]

# %%
copy1  = np.copy(TestX [250])
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
copy3 = np.reshape(copy2,(240, 240,3))
Img = cv2.cvtColor(copy3,cv2.COLOR_BGR2RGB)

Mask = TestGroundTruth[250]

Predicted_Mask = Predicted_images_test[250] 

plt.subplot(131).imshow(Img)
plt.subplot(132).imshow(Mask,'gray')
plt.subplot(133).imshow(Predicted_Mask,'gray')

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask):
  num = mask.shape[0]/480
  for id in range(int(num)):
    temp = []
    for i in range(id, id+10):
      idx = i * 48
      final_output = mask[idx:idx+48]
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save("/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/Combined_Loss/ER1 Patient " + str(id), final_output)

# %%
# saving predicted outputs as numpy arrays for test images
saveNumpyOutput(Predicted_images)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 15   # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]

Mask_input = TestY[id:id+48]
Test_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Test_Actual)
print(Mask_input.shape)

final_output = Predicted_images_test[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 3)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0. 128. 255.]

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 10  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]

Mask_input = TrainY[id:id+48]
Train_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Train_Actual)
print(Mask_input.shape)

final_output = Predicted_images[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 3)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0. 128. 255.]
