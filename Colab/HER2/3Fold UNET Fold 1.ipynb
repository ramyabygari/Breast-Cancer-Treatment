# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np

# %%
import math
import random
import keras
from keras.layers import *
from keras.models import Sequential
from keras import Model
from keras import backend as K  
from keras.regularizers import l2
from keras.callbacks import EarlyStopping,ModelCheckpoint

from sklearn import metrics
# Out:
# Using TensorFlow backend.

# %%
def get_conv_block(input_layer,nFilters,size):
    conv1 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(input_layer)
    bn1 = BatchNormalization()(conv1)
    conv2 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(bn1)
    bn2 = BatchNormalization()(conv2)
    return bn2

def get_deconv_block(input_layer,nFilters,size):
    conv1 = Conv2DTranspose(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(input_layer)
    bn1 = BatchNormalization()(conv1)
    conv2 = Conv2DTranspose(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(bn1)
    bn2 = BatchNormalization()(conv2)
    return bn2
    
def get_UNET(input_layer,nFilters): 

    block1 = get_conv_block(input_layer,nFilters,3)
    mp1 = MaxPooling2D(pool_size=(2, 2))(block1)
    dr1 = Dropout(0.1)(mp1)
   
    block2 = get_conv_block(dr1,nFilters*2,3)
    mp2 = MaxPooling2D(pool_size=(2, 2))(block2)
    dr2 = Dropout(0.1)(mp2)

    block3 = get_conv_block(dr2,nFilters*4,3)
    mp3 = MaxPooling2D(pool_size=(2, 2))(block3)
    dr3 = Dropout(0.1)(mp3)
       
    block4 = get_conv_block(dr3,nFilters*8,3)
    mp4 = MaxPooling2D(pool_size=(2, 2))(block4)
    dr4 = Dropout(0.1)(mp4)

    conv5 = Conv2D(nFilters*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(dr4)
    conv5 = Conv2D(nFilters*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(conv5)

    up1 = UpSampling2D(size=(2,2))(conv5)
    cat1 = concatenate([block4, up1])
    dr1 = Dropout(0.1)(cat1)
    block5 = get_deconv_block(dr1,nFilters*8,3)

    up2 = UpSampling2D(size=(2,2))(block5)
    cat2 = concatenate([block3, up2])
    dr2 = Dropout(0.1)(cat2)
    block6 = get_deconv_block(dr2,nFilters*4,3)
    
    up3 = UpSampling2D(size=(2,2))(block6)
    cat3 = concatenate([block2, up3])
    dr3 = Dropout(0.1)(cat3)
    block7 = get_deconv_block(dr3,nFilters*2,3)
    
    up4 = UpSampling2D(size=(2,2))(block7)
    cat4 = concatenate([block1, up4])
    dr4 = Dropout(0.1)(cat4)
    block8 = get_deconv_block(dr4,nFilters,3)

    conv10 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(block8)
    conv11 = Conv2D(3,(1,1), activation='softmax', padding = 'same',kernel_regularizer=l2(1e-4))(conv10)

    return conv11

def get_model(input_shape,nFilters):

    input_layer = Input(shape=input_shape)
    out = get_UNET(input_layer,nFilters)
    model = Model(input_layer,out)
    return model

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/HER2/"

# Loading the data patient wise
X1 = np.load(PATH + 'Sliced Images/IHC 221.npy')
Y1 = np.load(PATH + 'Sliced Ground Truth/IHC 221.npy')

X2 = np.load(PATH + 'Sliced Images/IHC 229.npy')
Y2 = np.load(PATH + 'Sliced Ground Truth/IHC 229.npy')

X3 = np.load(PATH + 'Sliced Images/IHC 232.npy')
Y3 = np.load(PATH + 'Sliced Ground Truth/IHC 232.npy')

X4 = np.load(PATH + 'Sliced Images/IHC 239.npy')
Y4 = np.load(PATH + 'Sliced Ground Truth/IHC 239.npy')

X5 = np.load(PATH + 'Sliced Images/IHC 242.npy')
Y5 = np.load(PATH + 'Sliced Ground Truth/IHC 242.npy')

X6 = np.load(PATH + 'Sliced Images/IHC 246.npy')
Y6 = np.load(PATH + 'Sliced Ground Truth/IHC 246.npy')

X7 = np.load(PATH + 'Sliced Images/IHC 252.npy')
Y7 = np.load(PATH + 'Sliced Ground Truth/IHC 252.npy')

X8 = np.load(PATH + 'Sliced Images/IHC 254.npy')
Y8 = np.load(PATH + 'Sliced Ground Truth/IHC 254.npy')

X9 = np.load(PATH + 'Sliced Images/IHC 263.npy')
Y9 = np.load(PATH + 'Sliced Ground Truth/IHC 263.npy')

# %%
X = [X1, X2, X3, X4, X5, X6, X7, X8, X9]
Y = [Y1, Y2, Y3, Y4, Y5, Y6, Y7, Y8, Y9]
patient_no = ['221','229','232','239','242','246','252','254','263']
size = [10,10,10,10,10,10,11,10,10]

# %%
fold_split = []

#test patient = 221, 229
fold_split.append(([2,3,4,5,6,7,8],[0,1]))

#test_patient = 239, 252
fold_split.append(([0,1,2,4,5,7,8],[3,6]))

#test_patient = 252,263
fold_split.append(([0,1,2,3,4,6,8],[5,7]))

# %%
def convertToLabels(data):
  data[data==128]=1
  data[data==255]=2

def convertFromLabels(data):
  data[data==1]=128
  data[data==2]=255

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
def tversky_loss_1(y_true, y_pred):
    alpha = 0.7
    beta  = 0.3
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
  
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def tversky_loss_2(y_true, y_pred):
    alpha = 0.3
    beta  = 0.7
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))

    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def focal_tversky_loss_1(y_true, y_pred, gamma=0.75):
    tversky_index = tversky_loss_1(y_true, y_pred)
    return K.pow((tversky_index), gamma)
  
def focal_tversky_loss_2(y_true, y_pred, gamma=0.75):
    tversky_index = tversky_loss_2(y_true, y_pred)
    return K.pow((tversky_index), gamma)

def combined_loss(y_true, y_pred):
  return (0.2*K.categorical_crossentropy(y_true, y_pred))+(0.8*focal_tversky_loss_1(y_true, y_pred)+(0.8*focal_tversky_loss_2(y_true, y_pred)))

# %%
batch_size = 8
def get_batch(batch_size, X_train, Y_train): 
    size_batch = batch_size
    last_index = len(X_train) - 1
    x_train = X_train
    y_train = Y_train 
    while True:
        batch_data = [[],[]]
        for i in range(0, size_batch):
            random_index = random.randint(0, last_index)
            batch_data[0].append(x_train[random_index])
            batch_data[1].append(y_train[random_index])

        yield (np.array(batch_data[0]), np.array(batch_data[1]))

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/"

fold=0

for train_index, test_index in fold_split:
  print("TRAIN:", train_index, "TEST:", test_index, "FOLD:", fold)
  if fold==0:
    fold = fold+1
    continue

  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  Train = list(zip(TrainX,TrainY))
  random.shuffle(Train)
  TrainX,TrainY = zip(*Train)
  TrainX = np.asarray(list(TrainX))
  TrainY = np.asarray(list(TrainY))

  Test = list(zip(TestX,TestY))
  random.shuffle(Test)
  TestX,TestY = zip(*Test)
  TestX = np.asarray(list(TestX))
  TestY = np.asarray(list(TestY))

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255
  convertToLabels(TrainY)
  TrainY = keras.utils.to_categorical(TrainY,num_classes=3,dtype='int16')
  convertToLabels(TestY)
  TestY = keras.utils.to_categorical(TestY,num_classes=3,dtype='int16')
  ValX = TrainX[(int)(0.8*TrainX.shape[0]):]
  ValY = TrainY[(int)(0.8*TrainY.shape[0]):]
  model = get_model((240,240,3),64)

  mc = ModelCheckpoint(MODELS_PATH + 'Checkpoint_1.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)
  optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=0.001, decay=0.0, amsgrad=True)

  model.compile(loss=combined_loss, optimizer= optimizer , metrics=[dice_coef,'accuracy']) 
  num_epoch = 100
  datagen = get_batch(batch_size, TrainX, TrainY)
  n_points = len(TrainX)
  print('-----------fold {}--------------'.format(fold))
  history = model.fit(datagen, validation_data = [ValX, ValY],
                  epochs=num_epoch,steps_per_epoch = math.ceil(n_points / batch_size), callbacks =[mc],  shuffle =True)
  model.save(MODELS_PATH + '/UNET_HER2_'+ str(fold) +'.h5')
  fold = fold + 1
# Out:
# TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1] FOLD: 0
# TRAIN: [0, 1, 2, 4, 5, 7, 8] TEST: [3, 6] FOLD: 1
# -----------fold 1--------------
# Epoch 1/100
# 420/420 [==============================] - 186s 443ms/step - loss: 3.2107 - dice_coef: 0.7904 - accuracy: 0.8631 - val_loss: 3.5457 - val_dice_coef: 0.7604 - val_accuracy: 0.8044
#
# Epoch 00001: val_loss improved from inf to 3.54573, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 2/100
# 420/420 [==============================] - 181s 431ms/step - loss: 2.7742 - dice_coef: 0.8327 - accuracy: 0.8831 - val_loss: 2.6676 - val_dice_coef: 0.8292 - val_accuracy: 0.8786
#
# Epoch 00002: val_loss improved from 3.54573 to 2.66763, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 3/100
# 420/420 [==============================] - 181s 431ms/step - loss: 2.4735 - dice_coef: 0.8533 - accuracy: 0.8861 - val_loss: 2.3579 - val_dice_coef: 0.8622 - val_accuracy: 0.8887
#
# Epoch 00003: val_loss improved from 2.66763 to 2.35789, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 4/100
# 420/420 [==============================] - 181s 432ms/step - loss: 2.2147 - dice_coef: 0.8652 - accuracy: 0.8884 - val_loss: 2.4793 - val_dice_coef: 0.8326 - val_accuracy: 0.8431
#
# Epoch 00004: val_loss did not improve from 2.35789
# Epoch 5/100
# 420/420 [==============================] - 181s 431ms/step - loss: 1.9850 - dice_coef: 0.8754 - accuracy: 0.8926 - val_loss: 2.3552 - val_dice_coef: 0.7619 - val_accuracy: 0.7765
#
# Epoch 00005: val_loss improved from 2.35789 to 2.35518, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 6/100
# 420/420 [==============================] - 181s 432ms/step - loss: 1.8565 - dice_coef: 0.8795 - accuracy: 0.8926 - val_loss: 1.8094 - val_dice_coef: 0.8774 - val_accuracy: 0.8874
#
# Epoch 00006: val_loss improved from 2.35518 to 1.80942, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 7/100
# 420/420 [==============================] - 181s 432ms/step - loss: 1.7008 - dice_coef: 0.8852 - accuracy: 0.8964 - val_loss: 1.8354 - val_dice_coef: 0.8691 - val_accuracy: 0.8786
#
# Epoch 00007: val_loss did not improve from 1.80942
# Epoch 8/100
# 420/420 [==============================] - 181s 431ms/step - loss: 1.5742 - dice_coef: 0.8879 - accuracy: 0.8979 - val_loss: 1.5997 - val_dice_coef: 0.8832 - val_accuracy: 0.8901
#
# Epoch 00008: val_loss improved from 1.80942 to 1.59973, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 9/100
# 420/420 [==============================] - 181s 431ms/step - loss: 1.4669 - dice_coef: 0.8928 - accuracy: 0.9017 - val_loss: 1.6484 - val_dice_coef: 0.8650 - val_accuracy: 0.8773
#
# Epoch 00009: val_loss did not improve from 1.59973
# Epoch 10/100
# 420/420 [==============================] - 181s 431ms/step - loss: 1.4045 - dice_coef: 0.8913 - accuracy: 0.8992 - val_loss: 1.4727 - val_dice_coef: 0.8842 - val_accuracy: 0.8910
#
# Epoch 00010: val_loss improved from 1.59973 to 1.47273, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 11/100
# 420/420 [==============================] - 181s 431ms/step - loss: 1.3129 - dice_coef: 0.8979 - accuracy: 0.9054 - val_loss: 1.4317 - val_dice_coef: 0.8860 - val_accuracy: 0.8915
#
# Epoch 00011: val_loss improved from 1.47273 to 1.43175, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 12/100
# 420/420 [==============================] - 181s 431ms/step - loss: 1.2717 - dice_coef: 0.8943 - accuracy: 0.9013 - val_loss: 1.2531 - val_dice_coef: 0.9004 - val_accuracy: 0.9083
#
# Epoch 00012: val_loss improved from 1.43175 to 1.25309, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 13/100
# 420/420 [==============================] - 181s 432ms/step - loss: 1.2262 - dice_coef: 0.8966 - accuracy: 0.9032 - val_loss: 1.3178 - val_dice_coef: 0.8881 - val_accuracy: 0.8938
#
# Epoch 00013: val_loss did not improve from 1.25309
# Epoch 14/100
# 420/420 [==============================] - 181s 431ms/step - loss: 1.1462 - dice_coef: 0.9016 - accuracy: 0.9080 - val_loss: 1.2975 - val_dice_coef: 0.8833 - val_accuracy: 0.8886
#
# Epoch 00014: val_loss did not improve from 1.25309
# Epoch 15/100
# 420/420 [==============================] - 181s 432ms/step - loss: 1.1352 - dice_coef: 0.8990 - accuracy: 0.9051 - val_loss: 1.2323 - val_dice_coef: 0.8827 - val_accuracy: 0.8868
#
# Epoch 00015: val_loss improved from 1.25309 to 1.23231, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 16/100
# 420/420 [==============================] - 181s 432ms/step - loss: 1.0964 - dice_coef: 0.9018 - accuracy: 0.9076 - val_loss: 1.2274 - val_dice_coef: 0.8749 - val_accuracy: 0.8795
#
# Epoch 00016: val_loss improved from 1.23231 to 1.22736, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 17/100
# 420/420 [==============================] - 181s 431ms/step - loss: 1.0444 - dice_coef: 0.9059 - accuracy: 0.9113 - val_loss: 1.0967 - val_dice_coef: 0.9013 - val_accuracy: 0.9072
#
# Epoch 00017: val_loss improved from 1.22736 to 1.09667, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 18/100
# 420/420 [==============================] - 181s 431ms/step - loss: 1.0325 - dice_coef: 0.9052 - accuracy: 0.9105 - val_loss: 1.0846 - val_dice_coef: 0.9018 - val_accuracy: 0.9056
#
# Epoch 00018: val_loss improved from 1.09667 to 1.08457, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 19/100
# 420/420 [==============================] - 181s 431ms/step - loss: 1.0019 - dice_coef: 0.9064 - accuracy: 0.9115 - val_loss: 1.0846 - val_dice_coef: 0.9021 - val_accuracy: 0.9058
#
# Epoch 00019: val_loss did not improve from 1.08457
# Epoch 20/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.9931 - dice_coef: 0.9068 - accuracy: 0.9119 - val_loss: 1.1754 - val_dice_coef: 0.8751 - val_accuracy: 0.8798
#
# Epoch 00020: val_loss did not improve from 1.08457
# Epoch 21/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.9884 - dice_coef: 0.9056 - accuracy: 0.9105 - val_loss: 1.2333 - val_dice_coef: 0.8549 - val_accuracy: 0.8583
#
# Epoch 00021: val_loss did not improve from 1.08457
# Epoch 22/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.9525 - dice_coef: 0.9087 - accuracy: 0.9135 - val_loss: 1.0931 - val_dice_coef: 0.8914 - val_accuracy: 0.8977
#
# Epoch 00022: val_loss did not improve from 1.08457
# Epoch 23/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.9675 - dice_coef: 0.9054 - accuracy: 0.9102 - val_loss: 1.0919 - val_dice_coef: 0.8935 - val_accuracy: 0.8960
#
# Epoch 00023: val_loss did not improve from 1.08457
# Epoch 24/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.9260 - dice_coef: 0.9108 - accuracy: 0.9154 - val_loss: 0.9435 - val_dice_coef: 0.9151 - val_accuracy: 0.9192
#
# Epoch 00024: val_loss improved from 1.08457 to 0.94350, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 25/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.9234 - dice_coef: 0.9113 - accuracy: 0.9157 - val_loss: 1.3143 - val_dice_coef: 0.8563 - val_accuracy: 0.8615
#
# Epoch 00025: val_loss did not improve from 0.94350
# Epoch 26/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.9263 - dice_coef: 0.9104 - accuracy: 0.9148 - val_loss: 0.9936 - val_dice_coef: 0.9020 - val_accuracy: 0.9048
#
# Epoch 00026: val_loss did not improve from 0.94350
# Epoch 27/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.8832 - dice_coef: 0.9139 - accuracy: 0.9181 - val_loss: 0.9751 - val_dice_coef: 0.9046 - val_accuracy: 0.9083
#
# Epoch 00027: val_loss did not improve from 0.94350
# Epoch 28/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.8954 - dice_coef: 0.9128 - accuracy: 0.9169 - val_loss: 1.1640 - val_dice_coef: 0.8872 - val_accuracy: 0.8914
#
# Epoch 00028: val_loss did not improve from 0.94350
# Epoch 29/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8693 - dice_coef: 0.9170 - accuracy: 0.9209 - val_loss: 0.9272 - val_dice_coef: 0.9105 - val_accuracy: 0.9147
#
# Epoch 00029: val_loss improved from 0.94350 to 0.92718, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 30/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8843 - dice_coef: 0.9132 - accuracy: 0.9172 - val_loss: 1.0972 - val_dice_coef: 0.8820 - val_accuracy: 0.8872
#
# Epoch 00030: val_loss did not improve from 0.92718
# Epoch 31/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8630 - dice_coef: 0.9170 - accuracy: 0.9208 - val_loss: 1.0588 - val_dice_coef: 0.8933 - val_accuracy: 0.8962
#
# Epoch 00031: val_loss did not improve from 0.92718
# Epoch 32/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8660 - dice_coef: 0.9154 - accuracy: 0.9191 - val_loss: 0.9283 - val_dice_coef: 0.9076 - val_accuracy: 0.9121
#
# Epoch 00032: val_loss did not improve from 0.92718
# Epoch 33/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8697 - dice_coef: 0.9152 - accuracy: 0.9190 - val_loss: 1.1712 - val_dice_coef: 0.8821 - val_accuracy: 0.8862
#
# Epoch 00033: val_loss did not improve from 0.92718
# Epoch 34/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8763 - dice_coef: 0.9143 - accuracy: 0.9180 - val_loss: 0.8756 - val_dice_coef: 0.9179 - val_accuracy: 0.9211
#
# Epoch 00034: val_loss improved from 0.92718 to 0.87563, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 35/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8340 - dice_coef: 0.9208 - accuracy: 0.9243 - val_loss: 1.2162 - val_dice_coef: 0.8880 - val_accuracy: 0.8895
#
# Epoch 00035: val_loss did not improve from 0.87563
# Epoch 36/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.8496 - dice_coef: 0.9175 - accuracy: 0.9212 - val_loss: 1.0559 - val_dice_coef: 0.8894 - val_accuracy: 0.8934
#
# Epoch 00036: val_loss did not improve from 0.87563
# Epoch 37/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.8453 - dice_coef: 0.9189 - accuracy: 0.9224 - val_loss: 0.9529 - val_dice_coef: 0.9110 - val_accuracy: 0.9136
#
# Epoch 00037: val_loss did not improve from 0.87563
# Epoch 38/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8414 - dice_coef: 0.9189 - accuracy: 0.9223 - val_loss: 0.9711 - val_dice_coef: 0.9081 - val_accuracy: 0.9103
#
# Epoch 00038: val_loss did not improve from 0.87563
# Epoch 39/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8530 - dice_coef: 0.9183 - accuracy: 0.9219 - val_loss: 1.0749 - val_dice_coef: 0.8894 - val_accuracy: 0.8928
#
# Epoch 00039: val_loss did not improve from 0.87563
# Epoch 40/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8178 - dice_coef: 0.9230 - accuracy: 0.9264 - val_loss: 1.1285 - val_dice_coef: 0.8926 - val_accuracy: 0.8939
#
# Epoch 00040: val_loss did not improve from 0.87563
# Epoch 41/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8456 - dice_coef: 0.9198 - accuracy: 0.9232 - val_loss: 1.1718 - val_dice_coef: 0.8879 - val_accuracy: 0.8897
#
# Epoch 00041: val_loss did not improve from 0.87563
# Epoch 42/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.8479 - dice_coef: 0.9185 - accuracy: 0.9220 - val_loss: 0.9972 - val_dice_coef: 0.9062 - val_accuracy: 0.9088
#
# Epoch 00042: val_loss did not improve from 0.87563
# Epoch 43/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8332 - dice_coef: 0.9216 - accuracy: 0.9249 - val_loss: 0.9317 - val_dice_coef: 0.9164 - val_accuracy: 0.9185
#
# Epoch 00043: val_loss did not improve from 0.87563
# Epoch 44/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8343 - dice_coef: 0.9212 - accuracy: 0.9245 - val_loss: 0.9879 - val_dice_coef: 0.8975 - val_accuracy: 0.9066
#
# Epoch 00044: val_loss did not improve from 0.87563
# Epoch 45/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8564 - dice_coef: 0.9173 - accuracy: 0.9207 - val_loss: 1.0563 - val_dice_coef: 0.8976 - val_accuracy: 0.8995
#
# Epoch 00045: val_loss did not improve from 0.87563
# Epoch 46/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8373 - dice_coef: 0.9222 - accuracy: 0.9254 - val_loss: 1.1196 - val_dice_coef: 0.8931 - val_accuracy: 0.8947
#
# Epoch 00046: val_loss did not improve from 0.87563
# Epoch 47/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8336 - dice_coef: 0.9220 - accuracy: 0.9252 - val_loss: 0.9955 - val_dice_coef: 0.9046 - val_accuracy: 0.9073
#
# Epoch 00047: val_loss did not improve from 0.87563
# Epoch 48/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8183 - dice_coef: 0.9243 - accuracy: 0.9273 - val_loss: 0.9785 - val_dice_coef: 0.9112 - val_accuracy: 0.9130
#
# Epoch 00048: val_loss did not improve from 0.87563
# Epoch 49/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8260 - dice_coef: 0.9238 - accuracy: 0.9269 - val_loss: 1.1223 - val_dice_coef: 0.8707 - val_accuracy: 0.8741
#
# Epoch 00049: val_loss did not improve from 0.87563
# Epoch 50/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8163 - dice_coef: 0.9250 - accuracy: 0.9280 - val_loss: 1.1987 - val_dice_coef: 0.8789 - val_accuracy: 0.8875
#
# Epoch 00050: val_loss did not improve from 0.87563
# Epoch 51/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.8273 - dice_coef: 0.9241 - accuracy: 0.9271 - val_loss: 1.0629 - val_dice_coef: 0.8975 - val_accuracy: 0.8998
#
# Epoch 00051: val_loss did not improve from 0.87563
# Epoch 52/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8346 - dice_coef: 0.9219 - accuracy: 0.9250 - val_loss: 0.9196 - val_dice_coef: 0.9138 - val_accuracy: 0.9168
#
# Epoch 00052: val_loss did not improve from 0.87563
# Epoch 53/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8275 - dice_coef: 0.9231 - accuracy: 0.9261 - val_loss: 1.1169 - val_dice_coef: 0.8935 - val_accuracy: 0.8954
#
# Epoch 00053: val_loss did not improve from 0.87563
# Epoch 54/100
# 420/420 [==============================] - 181s 432ms/step - loss: 0.8308 - dice_coef: 0.9244 - accuracy: 0.9274 - val_loss: 0.9840 - val_dice_coef: 0.9085 - val_accuracy: 0.9113
#
# Epoch 00054: val_loss did not improve from 0.87563
# Epoch 55/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.8399 - dice_coef: 0.9225 - accuracy: 0.9255 - val_loss: 1.1011 - val_dice_coef: 0.8943 - val_accuracy: 0.8966
#
# Epoch 00055: val_loss did not improve from 0.87563
# Epoch 56/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.8024 - dice_coef: 0.9268 - accuracy: 0.9297 - val_loss: 0.9992 - val_dice_coef: 0.9060 - val_accuracy: 0.9078
#
# Epoch 00056: val_loss did not improve from 0.87563
# Epoch 57/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8271 - dice_coef: 0.9258 - accuracy: 0.9286 - val_loss: 1.0507 - val_dice_coef: 0.8989 - val_accuracy: 0.9028
#
# Epoch 00057: val_loss did not improve from 0.87563
# Epoch 58/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8674 - dice_coef: 0.9215 - accuracy: 0.9245 - val_loss: 1.3672 - val_dice_coef: 0.8613 - val_accuracy: 0.8635
#
# Epoch 00058: val_loss did not improve from 0.87563
# Epoch 59/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8268 - dice_coef: 0.9274 - accuracy: 0.9302 - val_loss: 1.0082 - val_dice_coef: 0.9085 - val_accuracy: 0.9098
#
# Epoch 00059: val_loss did not improve from 0.87563
# Epoch 60/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8252 - dice_coef: 0.9265 - accuracy: 0.9293 - val_loss: 1.0188 - val_dice_coef: 0.8977 - val_accuracy: 0.9003
#
# Epoch 00060: val_loss did not improve from 0.87563
# Epoch 61/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8110 - dice_coef: 0.9290 - accuracy: 0.9317 - val_loss: 1.1771 - val_dice_coef: 0.8854 - val_accuracy: 0.8874
#
# Epoch 00061: val_loss did not improve from 0.87563
# Epoch 62/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8061 - dice_coef: 0.9297 - accuracy: 0.9324 - val_loss: 0.9347 - val_dice_coef: 0.9156 - val_accuracy: 0.9180
#
# Epoch 00062: val_loss did not improve from 0.87563
# Epoch 63/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8424 - dice_coef: 0.9262 - accuracy: 0.9290 - val_loss: 0.8847 - val_dice_coef: 0.9211 - val_accuracy: 0.9234
#
# Epoch 00063: val_loss did not improve from 0.87563
# Epoch 64/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8143 - dice_coef: 0.9290 - accuracy: 0.9317 - val_loss: 0.8467 - val_dice_coef: 0.9264 - val_accuracy: 0.9288
#
# Epoch 00064: val_loss improved from 0.87563 to 0.84670, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 65/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.7888 - dice_coef: 0.9321 - accuracy: 0.9348 - val_loss: 1.0202 - val_dice_coef: 0.9069 - val_accuracy: 0.9093
#
# Epoch 00065: val_loss did not improve from 0.84670
# Epoch 66/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8404 - dice_coef: 0.9293 - accuracy: 0.9319 - val_loss: 1.1419 - val_dice_coef: 0.8693 - val_accuracy: 0.8766
#
# Epoch 00066: val_loss did not improve from 0.84670
# Epoch 67/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8004 - dice_coef: 0.9318 - accuracy: 0.9345 - val_loss: 0.9017 - val_dice_coef: 0.9201 - val_accuracy: 0.9232
#
# Epoch 00067: val_loss did not improve from 0.84670
# Epoch 68/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8222 - dice_coef: 0.9295 - accuracy: 0.9322 - val_loss: 1.0850 - val_dice_coef: 0.8907 - val_accuracy: 0.8964
#
# Epoch 00068: val_loss did not improve from 0.84670
# Epoch 69/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8159 - dice_coef: 0.9314 - accuracy: 0.9340 - val_loss: 1.4541 - val_dice_coef: 0.8541 - val_accuracy: 0.8557
#
# Epoch 00069: val_loss did not improve from 0.84670
# Epoch 70/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8079 - dice_coef: 0.9316 - accuracy: 0.9341 - val_loss: 0.8917 - val_dice_coef: 0.9213 - val_accuracy: 0.9239
#
# Epoch 00070: val_loss did not improve from 0.84670
# Epoch 71/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8172 - dice_coef: 0.9307 - accuracy: 0.9333 - val_loss: 0.8868 - val_dice_coef: 0.9248 - val_accuracy: 0.9276
#
# Epoch 00071: val_loss did not improve from 0.84670
# Epoch 72/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.8317 - dice_coef: 0.9302 - accuracy: 0.9327 - val_loss: 0.9927 - val_dice_coef: 0.9131 - val_accuracy: 0.9146
#
# Epoch 00072: val_loss did not improve from 0.84670
# Epoch 73/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8192 - dice_coef: 0.9327 - accuracy: 0.9352 - val_loss: 0.9361 - val_dice_coef: 0.9152 - val_accuracy: 0.9168
#
# Epoch 00073: val_loss did not improve from 0.84670
# Epoch 74/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.7961 - dice_coef: 0.9338 - accuracy: 0.9363 - val_loss: 1.0844 - val_dice_coef: 0.9028 - val_accuracy: 0.9045
#
# Epoch 00074: val_loss did not improve from 0.84670
# Epoch 75/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8071 - dice_coef: 0.9342 - accuracy: 0.9366 - val_loss: 1.0241 - val_dice_coef: 0.8992 - val_accuracy: 0.9010
#
# Epoch 00075: val_loss did not improve from 0.84670
# Epoch 76/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8098 - dice_coef: 0.9341 - accuracy: 0.9365 - val_loss: 0.9477 - val_dice_coef: 0.9142 - val_accuracy: 0.9168
#
# Epoch 00076: val_loss did not improve from 0.84670
# Epoch 77/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8590 - dice_coef: 0.9293 - accuracy: 0.9319 - val_loss: 1.1754 - val_dice_coef: 0.8907 - val_accuracy: 0.8920
#
# Epoch 00077: val_loss did not improve from 0.84670
# Epoch 78/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8181 - dice_coef: 0.9335 - accuracy: 0.9360 - val_loss: 1.1436 - val_dice_coef: 0.8904 - val_accuracy: 0.8925
#
# Epoch 00078: val_loss did not improve from 0.84670
# Epoch 79/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8089 - dice_coef: 0.9362 - accuracy: 0.9385 - val_loss: 1.1230 - val_dice_coef: 0.9070 - val_accuracy: 0.9088
#
# Epoch 00079: val_loss did not improve from 0.84670
# Epoch 80/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8155 - dice_coef: 0.9333 - accuracy: 0.9357 - val_loss: 1.0789 - val_dice_coef: 0.9070 - val_accuracy: 0.9082
#
# Epoch 00080: val_loss did not improve from 0.84670
# Epoch 81/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8257 - dice_coef: 0.9331 - accuracy: 0.9355 - val_loss: 1.0707 - val_dice_coef: 0.8990 - val_accuracy: 0.9006
#
# Epoch 00081: val_loss did not improve from 0.84670
# Epoch 82/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8358 - dice_coef: 0.9336 - accuracy: 0.9360 - val_loss: 1.1158 - val_dice_coef: 0.9069 - val_accuracy: 0.9081
#
# Epoch 00082: val_loss did not improve from 0.84670
# Epoch 83/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8389 - dice_coef: 0.9332 - accuracy: 0.9356 - val_loss: 0.9979 - val_dice_coef: 0.9155 - val_accuracy: 0.9172
#
# Epoch 00083: val_loss did not improve from 0.84670
# Epoch 84/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8152 - dice_coef: 0.9360 - accuracy: 0.9383 - val_loss: 1.1128 - val_dice_coef: 0.9008 - val_accuracy: 0.9029
#
# Epoch 00084: val_loss did not improve from 0.84670
# Epoch 85/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8098 - dice_coef: 0.9371 - accuracy: 0.9394 - val_loss: 0.8939 - val_dice_coef: 0.9319 - val_accuracy: 0.9331
#
# Epoch 00085: val_loss did not improve from 0.84670
# Epoch 86/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8086 - dice_coef: 0.9380 - accuracy: 0.9402 - val_loss: 0.8632 - val_dice_coef: 0.9331 - val_accuracy: 0.9351
#
# Epoch 00086: val_loss did not improve from 0.84670
# Epoch 87/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8168 - dice_coef: 0.9360 - accuracy: 0.9383 - val_loss: 1.0177 - val_dice_coef: 0.9143 - val_accuracy: 0.9164
#
# Epoch 00087: val_loss did not improve from 0.84670
# Epoch 88/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8274 - dice_coef: 0.9364 - accuracy: 0.9387 - val_loss: 1.1014 - val_dice_coef: 0.9058 - val_accuracy: 0.9071
#
# Epoch 00088: val_loss did not improve from 0.84670
# Epoch 89/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8329 - dice_coef: 0.9352 - accuracy: 0.9376 - val_loss: 0.9202 - val_dice_coef: 0.9277 - val_accuracy: 0.9292
#
# Epoch 00089: val_loss did not improve from 0.84670
# Epoch 90/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8456 - dice_coef: 0.9337 - accuracy: 0.9361 - val_loss: 1.0386 - val_dice_coef: 0.9120 - val_accuracy: 0.9144
#
# Epoch 00090: val_loss did not improve from 0.84670
# Epoch 91/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8330 - dice_coef: 0.9360 - accuracy: 0.9384 - val_loss: 1.0505 - val_dice_coef: 0.9154 - val_accuracy: 0.9186
#
# Epoch 00091: val_loss did not improve from 0.84670
# Epoch 92/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8329 - dice_coef: 0.9365 - accuracy: 0.9387 - val_loss: 0.9988 - val_dice_coef: 0.9193 - val_accuracy: 0.9214
#
# Epoch 00092: val_loss did not improve from 0.84670
# Epoch 93/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8160 - dice_coef: 0.9401 - accuracy: 0.9423 - val_loss: 0.9308 - val_dice_coef: 0.9252 - val_accuracy: 0.9278
#
# Epoch 00093: val_loss did not improve from 0.84670
# Epoch 94/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8164 - dice_coef: 0.9400 - accuracy: 0.9421 - val_loss: 1.0260 - val_dice_coef: 0.9168 - val_accuracy: 0.9188
#
# Epoch 00094: val_loss did not improve from 0.84670
# Epoch 95/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8114 - dice_coef: 0.9402 - accuracy: 0.9424 - val_loss: 0.8809 - val_dice_coef: 0.9347 - val_accuracy: 0.9367
#
# Epoch 00095: val_loss did not improve from 0.84670
# Epoch 96/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8079 - dice_coef: 0.9414 - accuracy: 0.9435 - val_loss: 0.8788 - val_dice_coef: 0.9334 - val_accuracy: 0.9353
#
# Epoch 00096: val_loss did not improve from 0.84670
# Epoch 97/100
# 420/420 [==============================] - 181s 430ms/step - loss: 0.8193 - dice_coef: 0.9390 - accuracy: 0.9411 - val_loss: 1.0013 - val_dice_coef: 0.9179 - val_accuracy: 0.9203
#
# Epoch 00097: val_loss did not improve from 0.84670
# Epoch 98/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.8251 - dice_coef: 0.9400 - accuracy: 0.9422 - val_loss: 1.0086 - val_dice_coef: 0.9218 - val_accuracy: 0.9229
#
# Epoch 00098: val_loss did not improve from 0.84670
# Epoch 99/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.8293 - dice_coef: 0.9394 - accuracy: 0.9416 - val_loss: 0.8447 - val_dice_coef: 0.9392 - val_accuracy: 0.9409
#
# Epoch 00099: val_loss improved from 0.84670 to 0.84467, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 100/100
# 420/420 [==============================] - 181s 431ms/step - loss: 0.8176 - dice_coef: 0.9411 - accuracy: 0.9432 - val_loss: 0.9612 - val_dice_coef: 0.9255 - val_accuracy: 0.9271
#
# Epoch 00100: val_loss did not improve from 0.84467
# TRAIN: [0, 1, 2, 3, 4, 6, 8] TEST: [5, 7] FOLD: 2
# -----------fold 2--------------
# Epoch 1/100
# 426/426 [==============================] - 190s 445ms/step - loss: 3.1713 - dice_coef: 0.8009 - accuracy: 0.8588 - val_loss: 3.1664 - val_dice_coef: 0.8088 - val_accuracy: 0.8534
#
# Epoch 00001: val_loss improved from inf to 3.16640, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 2/100
# 426/426 [==============================] - 184s 432ms/step - loss: 2.7413 - dice_coef: 0.8387 - accuracy: 0.8812 - val_loss: 2.5255 - val_dice_coef: 0.8580 - val_accuracy: 0.8977
#
# Epoch 00002: val_loss improved from 3.16640 to 2.52547, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 3/100
# 426/426 [==============================] - 184s 432ms/step - loss: 2.4174 - dice_coef: 0.8591 - accuracy: 0.8869 - val_loss: 2.3146 - val_dice_coef: 0.8581 - val_accuracy: 0.8796
#
# Epoch 00003: val_loss improved from 2.52547 to 2.31465, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 4/100
# 426/426 [==============================] - 184s 431ms/step - loss: 2.1407 - dice_coef: 0.8735 - accuracy: 0.8940 - val_loss: 2.1094 - val_dice_coef: 0.8750 - val_accuracy: 0.8908
#
# Epoch 00004: val_loss improved from 2.31465 to 2.10937, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 5/100
# 426/426 [==============================] - 184s 431ms/step - loss: 1.9780 - dice_coef: 0.8759 - accuracy: 0.8911 - val_loss: 1.8604 - val_dice_coef: 0.8923 - val_accuracy: 0.9053
#
# Epoch 00005: val_loss improved from 2.10937 to 1.86045, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 6/100
# 426/426 [==============================] - 184s 431ms/step - loss: 1.7799 - dice_coef: 0.8860 - accuracy: 0.8984 - val_loss: 1.7634 - val_dice_coef: 0.8782 - val_accuracy: 0.8880
#
# Epoch 00006: val_loss improved from 1.86045 to 1.76339, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 7/100
# 426/426 [==============================] - 184s 431ms/step - loss: 1.6330 - dice_coef: 0.8919 - accuracy: 0.9024 - val_loss: 1.6570 - val_dice_coef: 0.8784 - val_accuracy: 0.8854
#
# Epoch 00007: val_loss improved from 1.76339 to 1.65704, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 8/100
# 426/426 [==============================] - 184s 431ms/step - loss: 1.5690 - dice_coef: 0.8875 - accuracy: 0.8968 - val_loss: 1.6003 - val_dice_coef: 0.8811 - val_accuracy: 0.8876
#
# Epoch 00008: val_loss improved from 1.65704 to 1.60032, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 9/100
# 426/426 [==============================] - 184s 431ms/step - loss: 1.4506 - dice_coef: 0.8931 - accuracy: 0.9016 - val_loss: 1.4272 - val_dice_coef: 0.8975 - val_accuracy: 0.9036
#
# Epoch 00009: val_loss improved from 1.60032 to 1.42718, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 10/100
# 426/426 [==============================] - 184s 431ms/step - loss: 1.3541 - dice_coef: 0.8949 - accuracy: 0.9025 - val_loss: 1.6479 - val_dice_coef: 0.8400 - val_accuracy: 0.8486
#
# Epoch 00010: val_loss did not improve from 1.42718
# Epoch 11/100
# 426/426 [==============================] - 184s 431ms/step - loss: 1.2815 - dice_coef: 0.8978 - accuracy: 0.9051 - val_loss: 1.3995 - val_dice_coef: 0.8815 - val_accuracy: 0.8898
#
# Epoch 00011: val_loss improved from 1.42718 to 1.39952, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 12/100
# 426/426 [==============================] - 184s 431ms/step - loss: 1.2300 - dice_coef: 0.8997 - accuracy: 0.9064 - val_loss: 1.2723 - val_dice_coef: 0.8921 - val_accuracy: 0.8971
#
# Epoch 00012: val_loss improved from 1.39952 to 1.27233, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 13/100
# 426/426 [==============================] - 184s 431ms/step - loss: 1.1692 - dice_coef: 0.9011 - accuracy: 0.9074 - val_loss: 1.3101 - val_dice_coef: 0.8844 - val_accuracy: 0.8907
#
# Epoch 00013: val_loss did not improve from 1.27233
# Epoch 14/100
# 426/426 [==============================] - 184s 431ms/step - loss: 1.1435 - dice_coef: 0.9008 - accuracy: 0.9068 - val_loss: 1.2607 - val_dice_coef: 0.8781 - val_accuracy: 0.8845
#
# Epoch 00014: val_loss improved from 1.27233 to 1.26066, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 15/100
# 426/426 [==============================] - 184s 431ms/step - loss: 1.1063 - dice_coef: 0.9018 - accuracy: 0.9076 - val_loss: 1.3860 - val_dice_coef: 0.8761 - val_accuracy: 0.8789
#
# Epoch 00015: val_loss did not improve from 1.26066
# Epoch 16/100
# 426/426 [==============================] - 184s 431ms/step - loss: 1.0596 - dice_coef: 0.9029 - accuracy: 0.9084 - val_loss: 1.2295 - val_dice_coef: 0.8747 - val_accuracy: 0.8782
#
# Epoch 00016: val_loss improved from 1.26066 to 1.22952, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 17/100
# 426/426 [==============================] - 184s 431ms/step - loss: 1.0717 - dice_coef: 0.8997 - accuracy: 0.9053 - val_loss: 1.1212 - val_dice_coef: 0.8801 - val_accuracy: 0.8859
#
# Epoch 00017: val_loss improved from 1.22952 to 1.12119, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 18/100
# 426/426 [==============================] - 184s 431ms/step - loss: 0.9876 - dice_coef: 0.9084 - accuracy: 0.9135 - val_loss: 1.0193 - val_dice_coef: 0.8996 - val_accuracy: 0.9038
#
# Epoch 00018: val_loss improved from 1.12119 to 1.01933, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint.h5
# Epoch 19/100
# 426/426 [==============================] - 184s 431ms/step - loss: 0.9907 - dice_coef: 0.9068 - accuracy: 0.9118 - val_loss: 1.2752 - val_dice_coef: 0.8399 - val_accuracy: 0.8460
#
# Epoch 00019: val_loss did not improve from 1.01933
# Epoch 20/100
# 372/426 [=========================>....] - ETA: 21s - loss: 0.9988 - dice_coef: 0.9042 - accuracy: 0.9092
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-539981cc23e2> in <module>()
#      45   print('-----------fold {}--------------'.format(fold))
#      46   history = model.fit(datagen, validation_data = [ValX, ValY],
# ---> 47                   epochs=num_epoch,steps_per_epoch = math.ceil(n_points / batch_size), callbacks =[mc],  shuffle =True)
#      48   model.save(MODELS_PATH + '/UNET_HER2_'+ str(fold) +'.h5')
#      49   fold = fold + 1
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1145                 use_multiprocessing=use_multiprocessing,
#    1146                 shuffle=shuffle,
# -> 1147                 initial_epoch=initial_epoch)
#    1148
#    1149         # Case 2: Symbolic tensors or Numpy array-like.
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     218                                             sample_weight=sample_weight,
#     219                                             class_weight=class_weight,
# --> 220                                             reset_metrics=False)
#     221
#     222                 outs = to_list(outs)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3790         value = math_ops.cast(value, tensor.dtype)
#    3791       converted_inputs.append(value)
# -> 3792     outputs = self._graph_fn(*converted_inputs)
#    3793
#    3794     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    1603       TypeError: For invalid positional/keyword argument combinations.
#    1604     """
# -> 1605     return self._call_impl(args, kwargs)
#    1606
#    1607   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1643       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1644           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1645     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1646
#    1647   def _filtered_call(self, args, kwargs):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask, Patient_array,Patient_length,title,folder):
  idx = 0
  for i in range(len(Patient_length)):
    temp = []
    for j in range(Patient_length[i]):
      final_output = mask[idx:idx+48]
      idx = idx + 48
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save(folder + title + Patient_array[i], final_output)

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/"
model_names = os.listdir(MODELS_PATH)
model_names.sort()
model_names.pop(0)
print(model_names)
# Out:
# ['LadderNet_HER2_0.h5', 'LadderNet_HER2_1.h5']

# %%
SAVE_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/HER2/3Fold UNET/"

# %%
# Axis 0 = Folds
# Axis 1 = Class (Membrane Nuclei Background)
# Axis 2 = Evaluation Technique (Precision, Recall, Dice coefficient)
pixEvaluationTrain = np.empty((0,3,3))
pixEvaluationTest = np.empty((0,3,3))
score = np.zeros((1,3,3))

# %%
fold = 0

for train_index, test_index in fold_split:
  print("FOLD:",fold,"\tTRAIN:", train_index, "TEST:", test_index)
  # Splitting Train and Test data
  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  train_no = [patient_no[i] for i in train_index]
  train_size = [size[i] for i in train_index]

  test_no = [patient_no[i] for i in test_index]
  test_size = [size[i] for i in test_index]

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255

  convertToLabels(TrainY)
  convertToLabels(TestY)

  # Loading corrosponding fold of model
  model = keras.models.load_model(MODELS_PATH + model_names[fold],custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

  # Predicting results using model
  trainResult = model.predict(TrainX, batch_size=8)
  testResult = model.predict(TestX,batch_size=8)

  trainResult = np.argmax(trainResult,axis=-1)
  testResult = np.argmax(testResult,axis=-1)

  # Obtaining pixel-wise results: Precision recall and dice coefficient
  # For TRAIN
  y_true = np.reshape(TrainY,(-1))
  y_pred = np.reshape(trainResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2],average=None,zero_division=1)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2],average=None,zero_division=1)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(3):
    score[0][i][0] = prec[2-i]
    score[0][i][1] = recall[2-i]
    score[0][i][2] = dice[2-i]

  pixEvaluationTrain = np.append(pixEvaluationTrain,score,axis=0)
 
  # For TEST
  y_true = np.reshape(TestY,(-1))
  y_pred = np.reshape(testResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2],average=None,zero_division=1)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2],average=None,zero_division=1)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(3):
    score[0][i][0] = prec[2-i]
    score[0][i][1] = recall[2-i]
    score[0][i][2] = dice[2-i]

  pixEvaluationTest = np.append(pixEvaluationTest,score,axis=0)

  # Converting predicted labels to required output format
  convertFromLabels(trainResult)
  convertFromLabels(testResult)

  # Saving numpy arrays
  path = os.path.join(SAVE_PATH,"Fold " + str(fold))
  os.mkdir(path)
  os.mkdir(path + '/Train')
  os.mkdir(path + '/Test')

  saveNumpyOutput(trainResult, train_no, train_size,"/Train/",path)
  saveNumpyOutput(testResult, test_no, test_size,"/Test/",path)

  fold +=1

# %%
print(pixEvaluationTrain.shape)
print(pixEvaluationTest.shape)
# Out:
# (2, 3, 3)
# (2, 3, 3)

# %%
print(pixEvaluationTest)
# Out:
# [[[0.97970822 0.86456187 0.91854048]
#   [0.74876641 0.54365218 0.62993289]
#   [0.86160267 0.94738236 0.90245874]]
#
#  [[0.96148832 0.99157845 0.97630159]
#   [0.78987302 0.70201292 0.74335584]
#   [0.93285643 0.94732193 0.94003353]]]

# %%
np.save(SAVE_PATH + "Pixel-wise Metrics Train.npy", pixEvaluationTrain)
np.save(SAVE_PATH + "Pixel-wise Metrics Test.npy", pixEvaluationTest)

# %% [markdown]
# # **DISPLAY**

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 48   # enter between 0- 50 since there are 5 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]
Mask_input = TestGT[id:id+48]
final_output = testResult[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 25  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]
Mask_input = TrainGT[id:id+48]
final_output = trainResult[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
