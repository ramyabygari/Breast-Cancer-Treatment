# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np

# %%
import math
import random
import keras
from keras.layers import *
from keras.models import Sequential
from keras import Model
from keras import backend as K  
from keras.regularizers import l2
from keras.callbacks import EarlyStopping,ModelCheckpoint

from sklearn import metrics
# Out:
# Using TensorFlow backend.

# %%
def get_conv_block(input_layer,nFilters,size):
    conv1 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(input_layer)
    bn1 = BatchNormalization()(conv1)
    conv2 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(bn1)
    bn2 = BatchNormalization()(conv2)
    return bn2

def get_deconv_block(input_layer,nFilters,size):
    conv1 = Conv2DTranspose(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(input_layer)
    bn1 = BatchNormalization()(conv1)
    conv2 = Conv2DTranspose(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(bn1)
    bn2 = BatchNormalization()(conv2)
    return bn2
    
def get_UNET(input_layer,nFilters): 

    block1 = get_conv_block(input_layer,nFilters,3)
    mp1 = MaxPooling2D(pool_size=(2, 2))(block1)
    dr1 = Dropout(0.1)(mp1)
   
    block2 = get_conv_block(dr1,nFilters*2,3)
    mp2 = MaxPooling2D(pool_size=(2, 2))(block2)
    dr2 = Dropout(0.1)(mp2)

    block3 = get_conv_block(dr2,nFilters*4,3)
    mp3 = MaxPooling2D(pool_size=(2, 2))(block3)
    dr3 = Dropout(0.1)(mp3)
       
    block4 = get_conv_block(dr3,nFilters*8,3)
    mp4 = MaxPooling2D(pool_size=(2, 2))(block4)
    dr4 = Dropout(0.1)(mp4)

    conv5 = Conv2D(nFilters*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(dr4)
    conv5 = Conv2D(nFilters*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(conv5)

    up1 = UpSampling2D(size=(2,2))(conv5)
    cat1 = concatenate([block4, up1])
    dr1 = Dropout(0.1)(cat1)
    block5 = get_deconv_block(dr1,nFilters*8,3)

    up2 = UpSampling2D(size=(2,2))(block5)
    cat2 = concatenate([block3, up2])
    dr2 = Dropout(0.1)(cat2)
    block6 = get_deconv_block(dr2,nFilters*4,3)
    
    up3 = UpSampling2D(size=(2,2))(block6)
    cat3 = concatenate([block2, up3])
    dr3 = Dropout(0.1)(cat3)
    block7 = get_deconv_block(dr3,nFilters*2,3)
    
    up4 = UpSampling2D(size=(2,2))(block7)
    cat4 = concatenate([block1, up4])
    dr4 = Dropout(0.1)(cat4)
    block8 = get_deconv_block(dr4,nFilters,3)

    conv10 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(block8)
    conv11 = Conv2D(3,(1,1), activation='softmax', padding = 'same',kernel_regularizer=l2(1e-4))(conv10)

    return conv11

def get_model(input_shape,nFilters):

    input_layer = Input(shape=input_shape)
    out = get_UNET(input_layer,nFilters)
    model = Model(input_layer,out)
    return model

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/HER2/"

# Loading the data patient wise
X1 = np.load(PATH + 'Sliced Images/IHC 221.npy')
Y1 = np.load(PATH + 'Sliced Ground Truth/IHC 221.npy')

X2 = np.load(PATH + 'Sliced Images/IHC 229.npy')
Y2 = np.load(PATH + 'Sliced Ground Truth/IHC 229.npy')

X3 = np.load(PATH + 'Sliced Images/IHC 232.npy')
Y3 = np.load(PATH + 'Sliced Ground Truth/IHC 232.npy')

X4 = np.load(PATH + 'Sliced Images/IHC 239.npy')
Y4 = np.load(PATH + 'Sliced Ground Truth/IHC 239.npy')

X5 = np.load(PATH + 'Sliced Images/IHC 242.npy')
Y5 = np.load(PATH + 'Sliced Ground Truth/IHC 242.npy')

X6 = np.load(PATH + 'Sliced Images/IHC 246.npy')
Y6 = np.load(PATH + 'Sliced Ground Truth/IHC 246.npy')

X7 = np.load(PATH + 'Sliced Images/IHC 252.npy')
Y7 = np.load(PATH + 'Sliced Ground Truth/IHC 252.npy')

X8 = np.load(PATH + 'Sliced Images/IHC 254.npy')
Y8 = np.load(PATH + 'Sliced Ground Truth/IHC 254.npy')

X9 = np.load(PATH + 'Sliced Images/IHC 263.npy')
Y9 = np.load(PATH + 'Sliced Ground Truth/IHC 263.npy')

# %%
X = [X1, X2, X3, X4, X5, X6, X7, X8, X9]
Y = [Y1, Y2, Y3, Y4, Y5, Y6, Y7, Y8, Y9]
patient_no = ['221','229','232','239','242','246','252','254','263']
size = [10,10,10,10,10,10,11,10,10]

# %%
fold_split = []

#test patient = 221, 229
fold_split.append(([2,3,4,5,6,7,8],[0,1]))

#test_patient = 239, 252
fold_split.append(([0,1,2,4,5,7,8],[3,6]))

#test_patient = 252,263
fold_split.append(([0,1,2,3,4,6,8],[5,7]))

# %%
def convertToLabels(data):
  data[data==128]=1
  data[data==255]=2

def convertFromLabels(data):
  data[data==1]=128
  data[data==2]=255

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
def tversky_loss_1(y_true, y_pred):
    alpha = 0.7
    beta  = 0.3
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
  
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def tversky_loss_2(y_true, y_pred):
    alpha = 0.3
    beta  = 0.7
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))

    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def focal_tversky_loss_1(y_true, y_pred, gamma=0.75):
    tversky_index = tversky_loss_1(y_true, y_pred)
    return K.pow((tversky_index), gamma)
  
def focal_tversky_loss_2(y_true, y_pred, gamma=0.75):
    tversky_index = tversky_loss_2(y_true, y_pred)
    return K.pow((tversky_index), gamma)

def combined_loss(y_true, y_pred):
  return (0.2*K.categorical_crossentropy(y_true, y_pred))+(0.8*focal_tversky_loss_1(y_true, y_pred)+(0.8*focal_tversky_loss_2(y_true, y_pred)))

# %%
batch_size = 8
def get_batch(batch_size, X_train, Y_train): 
    size_batch = batch_size
    last_index = len(X_train) - 1
    x_train = X_train
    y_train = Y_train 
    while True:
        batch_data = [[],[]]
        for i in range(0, size_batch):
            random_index = random.randint(0, last_index)
            batch_data[0].append(x_train[random_index])
            batch_data[1].append(y_train[random_index])

        yield (np.array(batch_data[0]), np.array(batch_data[1]))

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/"

fold=0

for train_index, test_index in fold_split:
  print("TRAIN:", train_index, "TEST:", test_index, "FOLD:", fold)
  if fold==0:
    fold = fold+1
    continue
  if fold==1:
    fold = fold+1
    continue

  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  Train = list(zip(TrainX,TrainY))
  random.shuffle(Train)
  TrainX,TrainY = zip(*Train)
  TrainX = np.asarray(list(TrainX))
  TrainY = np.asarray(list(TrainY))

  Test = list(zip(TestX,TestY))
  random.shuffle(Test)
  TestX,TestY = zip(*Test)
  TestX = np.asarray(list(TestX))
  TestY = np.asarray(list(TestY))

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255
  convertToLabels(TrainY)
  TrainY = keras.utils.to_categorical(TrainY,num_classes=3,dtype='int16')
  convertToLabels(TestY)
  TestY = keras.utils.to_categorical(TestY,num_classes=3,dtype='int16')
  ValX = TrainX[(int)(0.8*TrainX.shape[0]):]
  ValY = TrainY[(int)(0.8*TrainY.shape[0]):]
  model = get_model((240,240,3),64)

  mc = ModelCheckpoint(MODELS_PATH + 'Checkpoint_1.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)
  optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=0.001, decay=0.0, amsgrad=True)

  model.compile(loss=combined_loss, optimizer= optimizer , metrics=[dice_coef,'accuracy']) 
  num_epoch = 100
  datagen = get_batch(batch_size, TrainX, TrainY)
  n_points = len(TrainX)
  print('-----------fold {}--------------'.format(fold))
  history = model.fit(datagen, validation_data = [ValX, ValY],
                  epochs=num_epoch,steps_per_epoch = math.ceil(n_points / batch_size), callbacks =[mc],  shuffle =True)
  model.save(MODELS_PATH + '/UNET_HER2_'+ str(fold) +'.h5')
  fold = fold + 1
# Out:
# TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1] FOLD: 0
# TRAIN: [0, 1, 2, 4, 5, 7, 8] TEST: [3, 6] FOLD: 1
# TRAIN: [0, 1, 2, 3, 4, 6, 8] TEST: [5, 7] FOLD: 2
# -----------fold 2--------------
# Epoch 1/100
# 426/426 [==============================] - 197s 462ms/step - loss: 3.3441 - dice_coef: 0.7654 - accuracy: 0.8562 - val_loss: 3.2586 - val_dice_coef: 0.8040 - val_accuracy: 0.8603
#
# Epoch 00001: val_loss improved from inf to 3.25864, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 2/100
# 426/426 [==============================] - 184s 433ms/step - loss: 2.8293 - dice_coef: 0.8294 - accuracy: 0.8877 - val_loss: 2.7285 - val_dice_coef: 0.8328 - val_accuracy: 0.8799
#
# Epoch 00002: val_loss improved from 3.25864 to 2.72846, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 3/100
# 426/426 [==============================] - 184s 433ms/step - loss: 2.4887 - dice_coef: 0.8477 - accuracy: 0.8850 - val_loss: 2.4075 - val_dice_coef: 0.8520 - val_accuracy: 0.8850
#
# Epoch 00003: val_loss improved from 2.72846 to 2.40746, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 4/100
# 426/426 [==============================] - 184s 433ms/step - loss: 2.1840 - dice_coef: 0.8664 - accuracy: 0.8915 - val_loss: 2.0845 - val_dice_coef: 0.8749 - val_accuracy: 0.8964
#
# Epoch 00004: val_loss improved from 2.40746 to 2.08445, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 5/100
# 426/426 [==============================] - 184s 433ms/step - loss: 1.9889 - dice_coef: 0.8734 - accuracy: 0.8913 - val_loss: 1.8888 - val_dice_coef: 0.8885 - val_accuracy: 0.9046
#
# Epoch 00005: val_loss improved from 2.08445 to 1.88885, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 6/100
# 426/426 [==============================] - 184s 433ms/step - loss: 1.8148 - dice_coef: 0.8818 - accuracy: 0.8960 - val_loss: 1.6669 - val_dice_coef: 0.8962 - val_accuracy: 0.9083
#
# Epoch 00006: val_loss improved from 1.88885 to 1.66689, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 7/100
# 426/426 [==============================] - 184s 432ms/step - loss: 1.6872 - dice_coef: 0.8844 - accuracy: 0.8962 - val_loss: 1.5618 - val_dice_coef: 0.8983 - val_accuracy: 0.9093
#
# Epoch 00007: val_loss improved from 1.66689 to 1.56178, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 8/100
# 426/426 [==============================] - 184s 432ms/step - loss: 1.5540 - dice_coef: 0.8892 - accuracy: 0.8991 - val_loss: 1.5020 - val_dice_coef: 0.8922 - val_accuracy: 0.9037
#
# Epoch 00008: val_loss improved from 1.56178 to 1.50201, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 9/100
# 426/426 [==============================] - 184s 432ms/step - loss: 1.4454 - dice_coef: 0.8930 - accuracy: 0.9016 - val_loss: 1.4083 - val_dice_coef: 0.8932 - val_accuracy: 0.9014
#
# Epoch 00009: val_loss improved from 1.50201 to 1.40826, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 10/100
# 426/426 [==============================] - 184s 432ms/step - loss: 1.3683 - dice_coef: 0.8936 - accuracy: 0.9017 - val_loss: 1.5428 - val_dice_coef: 0.8653 - val_accuracy: 0.8738
#
# Epoch 00010: val_loss did not improve from 1.40826
# Epoch 11/100
# 426/426 [==============================] - 184s 432ms/step - loss: 1.2992 - dice_coef: 0.8966 - accuracy: 0.9039 - val_loss: 1.2951 - val_dice_coef: 0.8978 - val_accuracy: 0.9045
#
# Epoch 00011: val_loss improved from 1.40826 to 1.29511, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 12/100
# 426/426 [==============================] - 184s 432ms/step - loss: 1.2412 - dice_coef: 0.8980 - accuracy: 0.9048 - val_loss: 1.3286 - val_dice_coef: 0.8719 - val_accuracy: 0.8796
#
# Epoch 00012: val_loss did not improve from 1.29511
# Epoch 13/100
# 426/426 [==============================] - 184s 432ms/step - loss: 1.1817 - dice_coef: 0.8992 - accuracy: 0.9058 - val_loss: 1.2722 - val_dice_coef: 0.8878 - val_accuracy: 0.8920
#
# Epoch 00013: val_loss improved from 1.29511 to 1.27223, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 14/100
# 426/426 [==============================] - 184s 432ms/step - loss: 1.1151 - dice_coef: 0.9023 - accuracy: 0.9085 - val_loss: 1.1658 - val_dice_coef: 0.8956 - val_accuracy: 0.9000
#
# Epoch 00014: val_loss improved from 1.27223 to 1.16577, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 15/100
# 426/426 [==============================] - 184s 432ms/step - loss: 1.0862 - dice_coef: 0.9037 - accuracy: 0.9096 - val_loss: 1.1307 - val_dice_coef: 0.9002 - val_accuracy: 0.9079
#
# Epoch 00015: val_loss improved from 1.16577 to 1.13068, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 16/100
# 426/426 [==============================] - 184s 432ms/step - loss: 1.0404 - dice_coef: 0.9053 - accuracy: 0.9112 - val_loss: 0.9736 - val_dice_coef: 0.9169 - val_accuracy: 0.9215
#
# Epoch 00016: val_loss improved from 1.13068 to 0.97356, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 17/100
# 426/426 [==============================] - 184s 432ms/step - loss: 1.0248 - dice_coef: 0.9054 - accuracy: 0.9109 - val_loss: 1.0048 - val_dice_coef: 0.9074 - val_accuracy: 0.9128
#
# Epoch 00017: val_loss did not improve from 0.97356
# Epoch 18/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.9987 - dice_coef: 0.9061 - accuracy: 0.9116 - val_loss: 1.2073 - val_dice_coef: 0.8795 - val_accuracy: 0.8835
#
# Epoch 00018: val_loss did not improve from 0.97356
# Epoch 19/100
# 426/426 [==============================] - 184s 432ms/step - loss: 1.0065 - dice_coef: 0.9045 - accuracy: 0.9097 - val_loss: 1.1754 - val_dice_coef: 0.8871 - val_accuracy: 0.8908
#
# Epoch 00019: val_loss did not improve from 0.97356
# Epoch 20/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.9526 - dice_coef: 0.9079 - accuracy: 0.9129 - val_loss: 0.9085 - val_dice_coef: 0.9135 - val_accuracy: 0.9194
#
# Epoch 00020: val_loss improved from 0.97356 to 0.90850, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 21/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.9443 - dice_coef: 0.9092 - accuracy: 0.9141 - val_loss: 0.8814 - val_dice_coef: 0.9162 - val_accuracy: 0.9207
#
# Epoch 00021: val_loss improved from 0.90850 to 0.88143, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 22/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.9149 - dice_coef: 0.9110 - accuracy: 0.9157 - val_loss: 1.1066 - val_dice_coef: 0.8705 - val_accuracy: 0.8749
#
# Epoch 00022: val_loss did not improve from 0.88143
# Epoch 23/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.9171 - dice_coef: 0.9095 - accuracy: 0.9142 - val_loss: 1.9461 - val_dice_coef: 0.6358 - val_accuracy: 0.6345
#
# Epoch 00023: val_loss did not improve from 0.88143
# Epoch 24/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.9138 - dice_coef: 0.9083 - accuracy: 0.9130 - val_loss: 0.8764 - val_dice_coef: 0.9136 - val_accuracy: 0.9197
#
# Epoch 00024: val_loss improved from 0.88143 to 0.87642, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 25/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.9123 - dice_coef: 0.9096 - accuracy: 0.9142 - val_loss: 0.9161 - val_dice_coef: 0.9074 - val_accuracy: 0.9119
#
# Epoch 00025: val_loss did not improve from 0.87642
# Epoch 26/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8767 - dice_coef: 0.9125 - accuracy: 0.9170 - val_loss: 1.0532 - val_dice_coef: 0.8819 - val_accuracy: 0.8841
#
# Epoch 00026: val_loss did not improve from 0.87642
# Epoch 27/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8916 - dice_coef: 0.9096 - accuracy: 0.9141 - val_loss: 0.9215 - val_dice_coef: 0.9071 - val_accuracy: 0.9100
#
# Epoch 00027: val_loss did not improve from 0.87642
# Epoch 28/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8890 - dice_coef: 0.9092 - accuracy: 0.9136 - val_loss: 0.8493 - val_dice_coef: 0.9173 - val_accuracy: 0.9212
#
# Epoch 00028: val_loss improved from 0.87642 to 0.84929, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 29/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8568 - dice_coef: 0.9149 - accuracy: 0.9191 - val_loss: 0.8623 - val_dice_coef: 0.9154 - val_accuracy: 0.9191
#
# Epoch 00029: val_loss did not improve from 0.84929
# Epoch 30/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8335 - dice_coef: 0.9176 - accuracy: 0.9216 - val_loss: 0.9238 - val_dice_coef: 0.9071 - val_accuracy: 0.9108
#
# Epoch 00030: val_loss did not improve from 0.84929
# Epoch 31/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8256 - dice_coef: 0.9165 - accuracy: 0.9206 - val_loss: 1.2002 - val_dice_coef: 0.8659 - val_accuracy: 0.8673
#
# Epoch 00031: val_loss did not improve from 0.84929
# Epoch 32/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8369 - dice_coef: 0.9149 - accuracy: 0.9189 - val_loss: 0.9495 - val_dice_coef: 0.8921 - val_accuracy: 0.8945
#
# Epoch 00032: val_loss did not improve from 0.84929
# Epoch 33/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8483 - dice_coef: 0.9125 - accuracy: 0.9167 - val_loss: 0.9668 - val_dice_coef: 0.8941 - val_accuracy: 0.9016
#
# Epoch 00033: val_loss did not improve from 0.84929
# Epoch 34/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8486 - dice_coef: 0.9143 - accuracy: 0.9184 - val_loss: 1.1796 - val_dice_coef: 0.8715 - val_accuracy: 0.8727
#
# Epoch 00034: val_loss did not improve from 0.84929
# Epoch 35/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8300 - dice_coef: 0.9158 - accuracy: 0.9198 - val_loss: 0.8711 - val_dice_coef: 0.9101 - val_accuracy: 0.9126
#
# Epoch 00035: val_loss did not improve from 0.84929
# Epoch 36/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8224 - dice_coef: 0.9177 - accuracy: 0.9215 - val_loss: 0.9352 - val_dice_coef: 0.9045 - val_accuracy: 0.9071
#
# Epoch 00036: val_loss did not improve from 0.84929
# Epoch 37/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8219 - dice_coef: 0.9171 - accuracy: 0.9211 - val_loss: 0.8383 - val_dice_coef: 0.9194 - val_accuracy: 0.9231
#
# Epoch 00037: val_loss improved from 0.84929 to 0.83828, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 38/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8331 - dice_coef: 0.9158 - accuracy: 0.9196 - val_loss: 0.9108 - val_dice_coef: 0.9081 - val_accuracy: 0.9105
#
# Epoch 00038: val_loss did not improve from 0.83828
# Epoch 39/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8216 - dice_coef: 0.9178 - accuracy: 0.9216 - val_loss: 1.1152 - val_dice_coef: 0.8695 - val_accuracy: 0.8741
#
# Epoch 00039: val_loss did not improve from 0.83828
# Epoch 40/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8139 - dice_coef: 0.9179 - accuracy: 0.9218 - val_loss: 0.8864 - val_dice_coef: 0.9078 - val_accuracy: 0.9107
#
# Epoch 00040: val_loss did not improve from 0.83828
# Epoch 41/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8150 - dice_coef: 0.9189 - accuracy: 0.9226 - val_loss: 1.0101 - val_dice_coef: 0.8864 - val_accuracy: 0.8969
#
# Epoch 00041: val_loss did not improve from 0.83828
# Epoch 42/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8079 - dice_coef: 0.9192 - accuracy: 0.9229 - val_loss: 0.7567 - val_dice_coef: 0.9272 - val_accuracy: 0.9297
#
# Epoch 00042: val_loss improved from 0.83828 to 0.75673, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/Checkpoint_1.h5
# Epoch 43/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8037 - dice_coef: 0.9197 - accuracy: 0.9234 - val_loss: 0.8413 - val_dice_coef: 0.9161 - val_accuracy: 0.9185
#
# Epoch 00043: val_loss did not improve from 0.75673
# Epoch 44/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8161 - dice_coef: 0.9193 - accuracy: 0.9229 - val_loss: 0.9138 - val_dice_coef: 0.9023 - val_accuracy: 0.9062
#
# Epoch 00044: val_loss did not improve from 0.75673
# Epoch 45/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8166 - dice_coef: 0.9185 - accuracy: 0.9222 - val_loss: 0.8625 - val_dice_coef: 0.9152 - val_accuracy: 0.9188
#
# Epoch 00045: val_loss did not improve from 0.75673
# Epoch 46/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8019 - dice_coef: 0.9212 - accuracy: 0.9248 - val_loss: 0.7945 - val_dice_coef: 0.9217 - val_accuracy: 0.9249
#
# Epoch 00046: val_loss did not improve from 0.75673
# Epoch 47/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8093 - dice_coef: 0.9208 - accuracy: 0.9242 - val_loss: 0.7821 - val_dice_coef: 0.9271 - val_accuracy: 0.9302
#
# Epoch 00047: val_loss did not improve from 0.75673
# Epoch 48/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7998 - dice_coef: 0.9219 - accuracy: 0.9254 - val_loss: 0.8472 - val_dice_coef: 0.9149 - val_accuracy: 0.9191
#
# Epoch 00048: val_loss did not improve from 0.75673
# Epoch 49/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8268 - dice_coef: 0.9191 - accuracy: 0.9226 - val_loss: 1.0227 - val_dice_coef: 0.8912 - val_accuracy: 0.8924
#
# Epoch 00049: val_loss did not improve from 0.75673
# Epoch 50/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8312 - dice_coef: 0.9185 - accuracy: 0.9221 - val_loss: 0.8189 - val_dice_coef: 0.9239 - val_accuracy: 0.9263
#
# Epoch 00050: val_loss did not improve from 0.75673
# Epoch 51/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8056 - dice_coef: 0.9209 - accuracy: 0.9245 - val_loss: 0.8246 - val_dice_coef: 0.9223 - val_accuracy: 0.9258
#
# Epoch 00051: val_loss did not improve from 0.75673
# Epoch 52/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8147 - dice_coef: 0.9206 - accuracy: 0.9241 - val_loss: 0.9056 - val_dice_coef: 0.9123 - val_accuracy: 0.9136
#
# Epoch 00052: val_loss did not improve from 0.75673
# Epoch 53/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8272 - dice_coef: 0.9216 - accuracy: 0.9250 - val_loss: 0.8003 - val_dice_coef: 0.9235 - val_accuracy: 0.9257
#
# Epoch 00053: val_loss did not improve from 0.75673
# Epoch 54/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8024 - dice_coef: 0.9217 - accuracy: 0.9252 - val_loss: 0.8505 - val_dice_coef: 0.9195 - val_accuracy: 0.9225
#
# Epoch 00054: val_loss did not improve from 0.75673
# Epoch 55/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7894 - dice_coef: 0.9246 - accuracy: 0.9279 - val_loss: 0.8176 - val_dice_coef: 0.9219 - val_accuracy: 0.9259
#
# Epoch 00055: val_loss did not improve from 0.75673
# Epoch 56/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7976 - dice_coef: 0.9245 - accuracy: 0.9278 - val_loss: 0.9677 - val_dice_coef: 0.9045 - val_accuracy: 0.9064
#
# Epoch 00056: val_loss did not improve from 0.75673
# Epoch 57/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7985 - dice_coef: 0.9253 - accuracy: 0.9285 - val_loss: 0.7935 - val_dice_coef: 0.9257 - val_accuracy: 0.9286
#
# Epoch 00057: val_loss did not improve from 0.75673
# Epoch 58/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8050 - dice_coef: 0.9239 - accuracy: 0.9272 - val_loss: 0.8756 - val_dice_coef: 0.9185 - val_accuracy: 0.9224
#
# Epoch 00058: val_loss did not improve from 0.75673
# Epoch 59/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8102 - dice_coef: 0.9232 - accuracy: 0.9265 - val_loss: 0.7925 - val_dice_coef: 0.9274 - val_accuracy: 0.9296
#
# Epoch 00059: val_loss did not improve from 0.75673
# Epoch 60/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7992 - dice_coef: 0.9240 - accuracy: 0.9273 - val_loss: 0.8588 - val_dice_coef: 0.9150 - val_accuracy: 0.9216
#
# Epoch 00060: val_loss did not improve from 0.75673
# Epoch 61/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8015 - dice_coef: 0.9252 - accuracy: 0.9284 - val_loss: 0.8368 - val_dice_coef: 0.9243 - val_accuracy: 0.9275
#
# Epoch 00061: val_loss did not improve from 0.75673
# Epoch 62/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7909 - dice_coef: 0.9275 - accuracy: 0.9306 - val_loss: 1.3169 - val_dice_coef: 0.8439 - val_accuracy: 0.8458
#
# Epoch 00062: val_loss did not improve from 0.75673
# Epoch 63/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7991 - dice_coef: 0.9258 - accuracy: 0.9290 - val_loss: 1.0034 - val_dice_coef: 0.9064 - val_accuracy: 0.9078
#
# Epoch 00063: val_loss did not improve from 0.75673
# Epoch 64/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7885 - dice_coef: 0.9301 - accuracy: 0.9331 - val_loss: 0.9214 - val_dice_coef: 0.9072 - val_accuracy: 0.9094
#
# Epoch 00064: val_loss did not improve from 0.75673
# Epoch 65/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7795 - dice_coef: 0.9290 - accuracy: 0.9320 - val_loss: 0.7761 - val_dice_coef: 0.9321 - val_accuracy: 0.9349
#
# Epoch 00065: val_loss did not improve from 0.75673
# Epoch 66/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7859 - dice_coef: 0.9285 - accuracy: 0.9316 - val_loss: 0.9918 - val_dice_coef: 0.9047 - val_accuracy: 0.9057
#
# Epoch 00066: val_loss did not improve from 0.75673
# Epoch 67/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7655 - dice_coef: 0.9315 - accuracy: 0.9344 - val_loss: 0.8485 - val_dice_coef: 0.9242 - val_accuracy: 0.9272
#
# Epoch 00067: val_loss did not improve from 0.75673
# Epoch 68/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8030 - dice_coef: 0.9272 - accuracy: 0.9303 - val_loss: 1.0530 - val_dice_coef: 0.9008 - val_accuracy: 0.9025
#
# Epoch 00068: val_loss did not improve from 0.75673
# Epoch 69/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8214 - dice_coef: 0.9254 - accuracy: 0.9285 - val_loss: 0.8176 - val_dice_coef: 0.9260 - val_accuracy: 0.9279
#
# Epoch 00069: val_loss did not improve from 0.75673
# Epoch 70/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8092 - dice_coef: 0.9280 - accuracy: 0.9311 - val_loss: 0.8765 - val_dice_coef: 0.9237 - val_accuracy: 0.9255
#
# Epoch 00070: val_loss did not improve from 0.75673
# Epoch 71/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7956 - dice_coef: 0.9290 - accuracy: 0.9320 - val_loss: 0.9117 - val_dice_coef: 0.9118 - val_accuracy: 0.9165
#
# Epoch 00071: val_loss did not improve from 0.75673
# Epoch 72/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7884 - dice_coef: 0.9302 - accuracy: 0.9331 - val_loss: 0.9210 - val_dice_coef: 0.9192 - val_accuracy: 0.9210
#
# Epoch 00072: val_loss did not improve from 0.75673
# Epoch 73/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8024 - dice_coef: 0.9290 - accuracy: 0.9319 - val_loss: 0.7793 - val_dice_coef: 0.9320 - val_accuracy: 0.9360
#
# Epoch 00073: val_loss did not improve from 0.75673
# Epoch 74/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8105 - dice_coef: 0.9293 - accuracy: 0.9322 - val_loss: 0.9215 - val_dice_coef: 0.9215 - val_accuracy: 0.9242
#
# Epoch 00074: val_loss did not improve from 0.75673
# Epoch 75/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7891 - dice_coef: 0.9312 - accuracy: 0.9339 - val_loss: 0.8675 - val_dice_coef: 0.9238 - val_accuracy: 0.9257
#
# Epoch 00075: val_loss did not improve from 0.75673
# Epoch 76/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8072 - dice_coef: 0.9289 - accuracy: 0.9318 - val_loss: 0.9511 - val_dice_coef: 0.9136 - val_accuracy: 0.9161
#
# Epoch 00076: val_loss did not improve from 0.75673
# Epoch 77/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8157 - dice_coef: 0.9283 - accuracy: 0.9312 - val_loss: 0.8146 - val_dice_coef: 0.9318 - val_accuracy: 0.9333
#
# Epoch 00077: val_loss did not improve from 0.75673
# Epoch 78/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8049 - dice_coef: 0.9306 - accuracy: 0.9335 - val_loss: 0.9199 - val_dice_coef: 0.9205 - val_accuracy: 0.9229
#
# Epoch 00078: val_loss did not improve from 0.75673
# Epoch 79/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7851 - dice_coef: 0.9336 - accuracy: 0.9363 - val_loss: 0.8937 - val_dice_coef: 0.9211 - val_accuracy: 0.9233
#
# Epoch 00079: val_loss did not improve from 0.75673
# Epoch 80/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7866 - dice_coef: 0.9335 - accuracy: 0.9362 - val_loss: 0.8424 - val_dice_coef: 0.9271 - val_accuracy: 0.9300
#
# Epoch 00080: val_loss did not improve from 0.75673
# Epoch 81/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7928 - dice_coef: 0.9333 - accuracy: 0.9360 - val_loss: 0.8396 - val_dice_coef: 0.9255 - val_accuracy: 0.9283
#
# Epoch 00081: val_loss did not improve from 0.75673
# Epoch 82/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8135 - dice_coef: 0.9304 - accuracy: 0.9332 - val_loss: 0.7822 - val_dice_coef: 0.9340 - val_accuracy: 0.9373
#
# Epoch 00082: val_loss did not improve from 0.75673
# Epoch 83/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8044 - dice_coef: 0.9325 - accuracy: 0.9352 - val_loss: 0.7722 - val_dice_coef: 0.9370 - val_accuracy: 0.9395
#
# Epoch 00083: val_loss did not improve from 0.75673
# Epoch 84/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8131 - dice_coef: 0.9302 - accuracy: 0.9330 - val_loss: 0.9803 - val_dice_coef: 0.8996 - val_accuracy: 0.9055
#
# Epoch 00084: val_loss did not improve from 0.75673
# Epoch 85/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8096 - dice_coef: 0.9330 - accuracy: 0.9357 - val_loss: 0.9130 - val_dice_coef: 0.9229 - val_accuracy: 0.9255
#
# Epoch 00085: val_loss did not improve from 0.75673
# Epoch 86/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7914 - dice_coef: 0.9349 - accuracy: 0.9375 - val_loss: 0.9182 - val_dice_coef: 0.9206 - val_accuracy: 0.9217
#
# Epoch 00086: val_loss did not improve from 0.75673
# Epoch 87/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8094 - dice_coef: 0.9317 - accuracy: 0.9345 - val_loss: 0.8946 - val_dice_coef: 0.9206 - val_accuracy: 0.9225
#
# Epoch 00087: val_loss did not improve from 0.75673
# Epoch 88/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8163 - dice_coef: 0.9325 - accuracy: 0.9353 - val_loss: 0.7927 - val_dice_coef: 0.9357 - val_accuracy: 0.9373
#
# Epoch 00088: val_loss did not improve from 0.75673
# Epoch 89/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8139 - dice_coef: 0.9322 - accuracy: 0.9349 - val_loss: 0.8755 - val_dice_coef: 0.9236 - val_accuracy: 0.9293
#
# Epoch 00089: val_loss did not improve from 0.75673
# Epoch 90/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7960 - dice_coef: 0.9364 - accuracy: 0.9389 - val_loss: 0.9897 - val_dice_coef: 0.9023 - val_accuracy: 0.9041
#
# Epoch 00090: val_loss did not improve from 0.75673
# Epoch 91/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8236 - dice_coef: 0.9314 - accuracy: 0.9341 - val_loss: 0.8358 - val_dice_coef: 0.9329 - val_accuracy: 0.9344
#
# Epoch 00091: val_loss did not improve from 0.75673
# Epoch 92/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8127 - dice_coef: 0.9345 - accuracy: 0.9372 - val_loss: 0.7950 - val_dice_coef: 0.9362 - val_accuracy: 0.9382
#
# Epoch 00092: val_loss did not improve from 0.75673
# Epoch 93/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8220 - dice_coef: 0.9340 - accuracy: 0.9366 - val_loss: 0.8623 - val_dice_coef: 0.9247 - val_accuracy: 0.9268
#
# Epoch 00093: val_loss did not improve from 0.75673
# Epoch 94/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8136 - dice_coef: 0.9346 - accuracy: 0.9372 - val_loss: 0.8481 - val_dice_coef: 0.9295 - val_accuracy: 0.9314
#
# Epoch 00094: val_loss did not improve from 0.75673
# Epoch 95/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8266 - dice_coef: 0.9340 - accuracy: 0.9366 - val_loss: 0.8875 - val_dice_coef: 0.9249 - val_accuracy: 0.9261
#
# Epoch 00095: val_loss did not improve from 0.75673
# Epoch 96/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7808 - dice_coef: 0.9393 - accuracy: 0.9417 - val_loss: 1.1195 - val_dice_coef: 0.8876 - val_accuracy: 0.8916
#
# Epoch 00096: val_loss did not improve from 0.75673
# Epoch 97/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7776 - dice_coef: 0.9397 - accuracy: 0.9421 - val_loss: 0.8798 - val_dice_coef: 0.9284 - val_accuracy: 0.9308
#
# Epoch 00097: val_loss did not improve from 0.75673
# Epoch 98/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.7782 - dice_coef: 0.9397 - accuracy: 0.9421 - val_loss: 0.7899 - val_dice_coef: 0.9385 - val_accuracy: 0.9403
#
# Epoch 00098: val_loss did not improve from 0.75673
# Epoch 99/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8274 - dice_coef: 0.9326 - accuracy: 0.9353 - val_loss: 1.5140 - val_dice_coef: 0.7919 - val_accuracy: 0.7934
#
# Epoch 00099: val_loss did not improve from 0.75673
# Epoch 100/100
# 426/426 [==============================] - 184s 432ms/step - loss: 0.8069 - dice_coef: 0.9358 - accuracy: 0.9383 - val_loss: 0.8124 - val_dice_coef: 0.9389 - val_accuracy: 0.9404
#
# Epoch 00100: val_loss did not improve from 0.75673

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask, Patient_array,Patient_length,title,folder):
  idx = 0
  for i in range(len(Patient_length)):
    temp = []
    for j in range(Patient_length[i]):
      final_output = mask[idx:idx+48]
      idx = idx + 48
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save(folder + title + Patient_array[i], final_output)

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold UNET/"
model_names = os.listdir(MODELS_PATH)
model_names.sort()
print(model_names)
# Out:
# ['UNET_HER2_0.h5', 'UNET_HER2_1.h5', 'UNET_HER2_2.h5']

# %%
SAVE_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/HER2/3Fold UNET/"

# %%
# Axis 0 = Folds
# Axis 1 = Class (Membrane Nuclei Background)
# Axis 2 = Evaluation Technique (Precision, Recall, Dice coefficient)
pixEvaluationTrain = np.empty((0,3,3))
pixEvaluationTest = np.empty((0,3,3))
score = np.zeros((1,3,3))

# %%
fold = 0

for train_index, test_index in fold_split:
  print("FOLD:",fold,"\tTRAIN:", train_index, "TEST:", test_index)
  # Splitting Train and Test data
  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  train_no = [patient_no[i] for i in train_index]
  train_size = [size[i] for i in train_index]

  test_no = [patient_no[i] for i in test_index]
  test_size = [size[i] for i in test_index]

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255

  convertToLabels(TrainY)
  convertToLabels(TestY)

  # Loading corrosponding fold of model
  model = keras.models.load_model(MODELS_PATH + model_names[fold],custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

  # Predicting results using model
  trainResult = model.predict(TrainX, batch_size=8)
  testResult = model.predict(TestX,batch_size=8)

  trainResult = np.argmax(trainResult,axis=-1)
  testResult = np.argmax(testResult,axis=-1)

  # Obtaining pixel-wise results: Precision recall and dice coefficient
  # For TRAIN
  y_true = np.reshape(TrainY,(-1))
  y_pred = np.reshape(trainResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2],average=None,zero_division=1)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2],average=None,zero_division=1)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(3):
    score[0][i][0] = prec[2-i]
    score[0][i][1] = recall[2-i]
    score[0][i][2] = dice[2-i]

  pixEvaluationTrain = np.append(pixEvaluationTrain,score,axis=0)
 
  # For TEST
  y_true = np.reshape(TestY,(-1))
  y_pred = np.reshape(testResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2],average=None,zero_division=1)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2],average=None,zero_division=1)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(3):
    score[0][i][0] = prec[2-i]
    score[0][i][1] = recall[2-i]
    score[0][i][2] = dice[2-i]

  pixEvaluationTest = np.append(pixEvaluationTest,score,axis=0)

  # Converting predicted labels to required output format
  convertFromLabels(trainResult)
  convertFromLabels(testResult)

  # Saving numpy arrays
  # path = os.path.join(SAVE_PATH,"Fold " + str(fold))
  # os.mkdir(path)
  # os.mkdir(path + '/Train')
  # os.mkdir(path + '/Test')

  # saveNumpyOutput(trainResult, train_no, train_size,"/Train/",path)
  # saveNumpyOutput(testResult, test_no, test_size,"/Test/",path)

  fold +=1
# Out:
# FOLD: 0 	TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1]
# FOLD: 1 	TRAIN: [0, 1, 2, 4, 5, 7, 8] TEST: [3, 6]
# FOLD: 2 	TRAIN: [0, 1, 2, 3, 4, 6, 8] TEST: [5, 7]

# %%
print(pixEvaluationTrain.shape)
print(pixEvaluationTest.shape)
# Out:
# (3, 3, 3)
# (3, 3, 3)

# %%
print(pixEvaluationTest)
# Out:
# [[[0.99804466 0.60063941 0.74994799]
#   [0.65900931 0.81741978 0.72971638]
#   [0.87461964 0.88392902 0.87924969]]
#
#  [[0.98311851 0.98227376 0.98269595]
#   [0.78458881 0.82366481 0.80365209]
#   [0.9555774  0.94522831 0.95037468]]
#
#  [[0.91596392 0.99856553 0.95548282]
#   [0.54955104 0.85831044 0.67007359]
#   [0.97927991 0.86218388 0.91700891]]]

# %%
print(pixEvaluationTrain)
# Out:
# [[[0.99951664 0.86710823 0.92861626]
#   [0.72785128 0.82157459 0.77187832]
#   [0.91575251 0.91103297 0.91338665]]
#
#  [[0.97658024 0.9647141  0.9706109 ]
#   [0.89687874 0.79892849 0.8450748 ]
#   [0.93348971 0.96727714 0.95008313]]
#
#  [[0.94269676 0.98643006 0.96406769]
#   [0.91295336 0.8298376  0.86941354]
#   [0.94377647 0.96451147 0.95403132]]]

# %%
np.save(SAVE_PATH + "Pixel-wise Metrics Train.npy", pixEvaluationTrain)
np.save(SAVE_PATH + "Pixel-wise Metrics Test.npy", pixEvaluationTest)

# %% [markdown]
# # **DISPLAY**

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 48   # enter between 0- 50 since there are 5 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]
Mask_input = TestGT[id:id+48]
final_output = testResult[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 25  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]
Mask_input = TrainGT[id:id+48]
final_output = trainResult[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
