# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np

# %%
import math
import random
import keras
from keras.layers import *
from keras.models import Sequential
from keras import Model
from keras import backend as K  
from keras.regularizers import l2
from keras.callbacks import EarlyStopping,ModelCheckpoint

from sklearn import metrics
# Out:
# Using TensorFlow backend.

# %%
def get_conv_block(input_layer,nFilters,size):
    conv1 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(input_layer)
    bn1 = BatchNormalization()(conv1)
    conv2 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(bn1)
    bn2 = BatchNormalization()(conv2)
    return bn2

def get_deconv_block(input_layer,nFilters,size):
    conv1 = Conv2DTranspose(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(input_layer)
    bn1 = BatchNormalization()(conv1)
    conv2 = Conv2DTranspose(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(bn1)
    bn2 = BatchNormalization()(conv2)
    return bn2
    
def get_UNET(input_layer,nFilters,flag): 

    block1 = get_conv_block(input_layer[0],nFilters,3)
    mp1 = MaxPooling2D(pool_size=(2, 2))(block1)
    dr1 = Dropout(0.1)(mp1)
   
    if(flag==1):
      dr1 = concatenate([dr1,input_layer[1]])

    block2 = get_conv_block(dr1,nFilters*2,3)
    mp2 = MaxPooling2D(pool_size=(2, 2))(block2)
    dr2 = Dropout(0.1)(mp2)

    if(flag==1):
      dr2 = concatenate([dr2,input_layer[2]])
   
    block3 = get_conv_block(dr2,nFilters*4,3)
    mp3 = MaxPooling2D(pool_size=(2, 2))(block3)
    dr3 = Dropout(0.1)(mp3)

    if(flag==1):
      dr3 = concatenate([dr3,input_layer[3]])
       
    block4 = get_conv_block(dr3,nFilters*8,3)
    mp4 = MaxPooling2D(pool_size=(2, 2))(block4)
    dr4 = Dropout(0.1)(mp4)

    conv5 = Conv2D(nFilters*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(dr4)
    conv5 = Conv2D(nFilters*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(conv5)

    up1 = UpSampling2D(size=(2,2))(conv5)
    cat1 = concatenate([block4, up1, mp3])
    dr1 = Dropout(0.1)(cat1)
    block5 = get_deconv_block(dr1,nFilters*8,3)

    up2 = UpSampling2D(size=(2,2))(block5)
    b4_upsample = UpSampling2D(size=(2,2))(block4)
    cat2 = concatenate([block3, up2, b4_upsample, mp2])
    dr2 = Dropout(0.1)(cat2)
    block6 = get_deconv_block(dr2,nFilters*4,3)
    
    up3 = UpSampling2D(size=(2,2))(block6)
    b3_upsample = UpSampling2D(size=(2,2))(block3)
    cat3 = concatenate([block2, up3, mp1, b3_upsample])
    dr3 = Dropout(0.1)(cat3)
    block7 = get_deconv_block(dr3,nFilters*2,3)
    
    up4 = UpSampling2D(size=(2,2))(block7)
    b2_upsample = UpSampling2D(size=(2,2))(block2)
    cat4 = concatenate([block1, up4, b2_upsample])
    dr4 = Dropout(0.1)(cat4)
    block8 = get_deconv_block(dr4,nFilters,3)

    conv10 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(block8)
    conv11 = Conv2D(3,(1,1), activation='softmax', padding = 'same',kernel_regularizer=l2(1e-4))(conv10)

    return (conv11, block7, block6, block5)

def get_model(input_shape,nFilters1,nFilters2):

    input_layer = Input(shape=input_shape)
    out1,out2,out3,out4 = get_UNET([input_layer],nFilters1,0)

    out1,out2,out3,out4 = get_UNET([out1,out2,out3,out4],nFilters2,1)

    model = Model(input_layer,out1)
    return model

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/HER2/"

# Loading the data patient wise
X1 = np.load(PATH + 'Sliced Images/IHC 221.npy')
Y1 = np.load(PATH + 'Sliced Ground Truth/IHC 221.npy')

X2 = np.load(PATH + 'Sliced Images/IHC 229.npy')
Y2 = np.load(PATH + 'Sliced Ground Truth/IHC 229.npy')

X3 = np.load(PATH + 'Sliced Images/IHC 232.npy')
Y3 = np.load(PATH + 'Sliced Ground Truth/IHC 232.npy')

X4 = np.load(PATH + 'Sliced Images/IHC 239.npy')
Y4 = np.load(PATH + 'Sliced Ground Truth/IHC 239.npy')

X5 = np.load(PATH + 'Sliced Images/IHC 242.npy')
Y5 = np.load(PATH + 'Sliced Ground Truth/IHC 242.npy')

X6 = np.load(PATH + 'Sliced Images/IHC 246.npy')
Y6 = np.load(PATH + 'Sliced Ground Truth/IHC 246.npy')

X7 = np.load(PATH + 'Sliced Images/IHC 252.npy')
Y7 = np.load(PATH + 'Sliced Ground Truth/IHC 252.npy')

X8 = np.load(PATH + 'Sliced Images/IHC 254.npy')
Y8 = np.load(PATH + 'Sliced Ground Truth/IHC 254.npy')

X9 = np.load(PATH + 'Sliced Images/IHC 263.npy')
Y9 = np.load(PATH + 'Sliced Ground Truth/IHC 263.npy')

# %%
X = [X1, X2, X3, X4, X5, X6, X7, X8, X9]
Y = [Y1, Y2, Y3, Y4, Y5, Y6, Y7, Y8, Y9]
patient_no = ['221','229','232','239','242','246','252','254','263']
size = [10,10,10,10,10,10,11,10,10]

# %%
fold_split = []

#test patient = 221, 229
fold_split.append(([2,3,4,5,6,7,8],[0,1]))

#test_patient = 239, 252
fold_split.append(([0,1,2,4,5,7,8],[3,6]))

#test_patient = 252,263
fold_split.append(([0,1,2,3,4,6,8],[5,7]))

# %%
def convertToLabels(data):
  data[data==128]=1
  data[data==255]=2

def convertFromLabels(data):
  data[data==1]=128
  data[data==2]=255

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
def tversky_loss_1(y_true, y_pred):
    alpha = 0.7
    beta  = 0.3
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
  
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def tversky_loss_2(y_true, y_pred):
    alpha = 0.3
    beta  = 0.7
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))

    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def focal_tversky_loss_1(y_true, y_pred, gamma=0.75):
    tversky_index = tversky_loss_1(y_true, y_pred)
    return K.pow((tversky_index), gamma)
  
def focal_tversky_loss_2(y_true, y_pred, gamma=0.75):
    tversky_index = tversky_loss_2(y_true, y_pred)
    return K.pow((tversky_index), gamma)

def combined_loss(y_true, y_pred):
  return (0.2*K.categorical_crossentropy(y_true, y_pred))+(0.8*focal_tversky_loss_1(y_true, y_pred)+(0.8*focal_tversky_loss_2(y_true, y_pred)))

# %%
batch_size = 8
def get_batch(batch_size, X_train, Y_train): 
    size_batch = batch_size
    last_index = len(X_train) - 1
    x_train = X_train
    y_train = Y_train 
    while True:
        batch_data = [[],[]]
        for i in range(0, size_batch):
            random_index = random.randint(0, last_index)
            batch_data[0].append(x_train[random_index])
            batch_data[1].append(y_train[random_index])

        yield (np.array(batch_data[0]), np.array(batch_data[1]))

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet/"

fold=0

for train_index, test_index in fold_split:
  print("TRAIN:", train_index, "TEST:", test_index, "FOLD:", fold)
  if fold==0:
    fold = fold+1
    continue

  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  Train = list(zip(TrainX,TrainY))
  random.shuffle(Train)
  TrainX,TrainY = zip(*Train)
  TrainX = np.asarray(list(TrainX))
  TrainY = np.asarray(list(TrainY))

  Test = list(zip(TestX,TestY))
  random.shuffle(Test)
  TestX,TestY = zip(*Test)
  TestX = np.asarray(list(TestX))
  TestY = np.asarray(list(TestY))

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255
  convertToLabels(TrainY)
  TrainY = keras.utils.to_categorical(TrainY,num_classes=3,dtype='int16')
  convertToLabels(TestY)
  TestY = keras.utils.to_categorical(TestY,num_classes=3,dtype='int16')
  ValX = TrainX[(int)(0.8*TrainX.shape[0]):]
  ValY = TrainY[(int)(0.8*TrainY.shape[0]):]
  model = get_model((240,240,3),32,64)

  mc = ModelCheckpoint(MODELS_PATH + '/Checkpoint.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)
  optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=0.001, decay=0.0, amsgrad=True)

  model.compile(loss=combined_loss, optimizer= optimizer , metrics=[dice_coef,'accuracy']) 
  num_epoch = 100
  datagen = get_batch(batch_size, TrainX, TrainY)
  n_points = len(TrainX)
  print('-----------fold {}--------------'.format(fold))
  history = model.fit(datagen, validation_data = [ValX, ValY],
                  epochs=num_epoch,steps_per_epoch = math.ceil(n_points / batch_size), callbacks =[mc],  shuffle =True)
  model.save(MODELS_PATH + '/LadderNet_HER2_'+ str(fold) +'.h5')
  fold = fold + 1
# Out:
# TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1] FOLD: 0
# TRAIN: [0, 1, 2, 4, 5, 7, 8] TEST: [3, 6] FOLD: 1
# -----------fold 1--------------
# Epoch 1/100
# 420/420 [==============================] - 338s 804ms/step - loss: 4.7023 - dice_coef: 0.7348 - accuracy: 0.8062 - val_loss: 4.2652 - val_dice_coef: 0.8094 - val_accuracy: 0.8609
#
# Epoch 00001: val_loss improved from inf to 4.26519, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 2/100
# 420/420 [==============================] - 318s 757ms/step - loss: 3.8483 - dice_coef: 0.8279 - accuracy: 0.8802 - val_loss: 3.5981 - val_dice_coef: 0.8404 - val_accuracy: 0.8863
#
# Epoch 00002: val_loss improved from 4.26519 to 3.59806, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 3/100
# 420/420 [==============================] - 318s 757ms/step - loss: 3.3952 - dice_coef: 0.8488 - accuracy: 0.8838 - val_loss: 3.1828 - val_dice_coef: 0.8658 - val_accuracy: 0.8927
#
# Epoch 00003: val_loss improved from 3.59806 to 3.18276, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 4/100
# 420/420 [==============================] - 318s 757ms/step - loss: 3.0293 - dice_coef: 0.8625 - accuracy: 0.8863 - val_loss: 3.1592 - val_dice_coef: 0.7947 - val_accuracy: 0.8057
#
# Epoch 00004: val_loss improved from 3.18276 to 3.15920, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 5/100
# 420/420 [==============================] - 318s 757ms/step - loss: 2.6765 - dice_coef: 0.8769 - accuracy: 0.8942 - val_loss: 2.7048 - val_dice_coef: 0.8673 - val_accuracy: 0.8822
#
# Epoch 00005: val_loss improved from 3.15920 to 2.70477, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 6/100
# 420/420 [==============================] - 318s 757ms/step - loss: 2.4146 - dice_coef: 0.8810 - accuracy: 0.8944 - val_loss: 2.2249 - val_dice_coef: 0.8941 - val_accuracy: 0.9071
#
# Epoch 00006: val_loss improved from 2.70477 to 2.22488, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 7/100
# 420/420 [==============================] - 318s 757ms/step - loss: 2.2201 - dice_coef: 0.8826 - accuracy: 0.8931 - val_loss: 2.5239 - val_dice_coef: 0.8234 - val_accuracy: 0.8330
#
# Epoch 00007: val_loss did not improve from 2.22488
# Epoch 8/100
# 420/420 [==============================] - 318s 757ms/step - loss: 2.0267 - dice_coef: 0.8878 - accuracy: 0.8958 - val_loss: 1.8997 - val_dice_coef: 0.8999 - val_accuracy: 0.9062
#
# Epoch 00008: val_loss improved from 2.22488 to 1.89968, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 9/100
# 420/420 [==============================] - 318s 757ms/step - loss: 1.8259 - dice_coef: 0.8982 - accuracy: 0.9030 - val_loss: 1.7471 - val_dice_coef: 0.9011 - val_accuracy: 0.9039
#
# Epoch 00009: val_loss improved from 1.89968 to 1.74713, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 10/100
# 420/420 [==============================] - 318s 757ms/step - loss: 1.7304 - dice_coef: 0.8937 - accuracy: 0.8980 - val_loss: 1.7024 - val_dice_coef: 0.8929 - val_accuracy: 0.8973
#
# Epoch 00010: val_loss improved from 1.74713 to 1.70244, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 11/100
# 420/420 [==============================] - 318s 757ms/step - loss: 1.6105 - dice_coef: 0.8972 - accuracy: 0.9011 - val_loss: 2.1633 - val_dice_coef: 0.7832 - val_accuracy: 0.7984
#
# Epoch 00011: val_loss did not improve from 1.70244
# Epoch 12/100
# 420/420 [==============================] - 318s 757ms/step - loss: 1.4759 - dice_coef: 0.9029 - accuracy: 0.9064 - val_loss: 1.4261 - val_dice_coef: 0.9026 - val_accuracy: 0.9058
#
# Epoch 00012: val_loss improved from 1.70244 to 1.42610, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 13/100
# 420/420 [==============================] - 318s 757ms/step - loss: 1.4072 - dice_coef: 0.9029 - accuracy: 0.9064 - val_loss: 1.4583 - val_dice_coef: 0.8927 - val_accuracy: 0.8969
#
# Epoch 00013: val_loss did not improve from 1.42610
# Epoch 14/100
# 420/420 [==============================] - 318s 757ms/step - loss: 1.3710 - dice_coef: 0.9000 - accuracy: 0.9037 - val_loss: 1.2846 - val_dice_coef: 0.9041 - val_accuracy: 0.9080
#
# Epoch 00014: val_loss improved from 1.42610 to 1.28464, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 15/100
# 420/420 [==============================] - 318s 757ms/step - loss: 1.2950 - dice_coef: 0.9011 - accuracy: 0.9047 - val_loss: 1.4314 - val_dice_coef: 0.8908 - val_accuracy: 0.8929
#
# Epoch 00015: val_loss did not improve from 1.28464
# Epoch 16/100
# 420/420 [==============================] - 318s 757ms/step - loss: 1.2438 - dice_coef: 0.9032 - accuracy: 0.9067 - val_loss: 1.2177 - val_dice_coef: 0.9049 - val_accuracy: 0.9083
#
# Epoch 00016: val_loss improved from 1.28464 to 1.21772, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 17/100
# 420/420 [==============================] - 318s 757ms/step - loss: 1.1989 - dice_coef: 0.9034 - accuracy: 0.9070 - val_loss: 1.2829 - val_dice_coef: 0.8992 - val_accuracy: 0.9006
#
# Epoch 00017: val_loss did not improve from 1.21772
# Epoch 18/100
# 420/420 [==============================] - 318s 757ms/step - loss: 1.1406 - dice_coef: 0.9051 - accuracy: 0.9085 - val_loss: 1.3932 - val_dice_coef: 0.8635 - val_accuracy: 0.8690
#
# Epoch 00018: val_loss did not improve from 1.21772
# Epoch 19/100
# 420/420 [==============================] - 318s 757ms/step - loss: 1.0869 - dice_coef: 0.9090 - accuracy: 0.9122 - val_loss: 1.1964 - val_dice_coef: 0.8925 - val_accuracy: 0.8993
#
# Epoch 00019: val_loss improved from 1.21772 to 1.19643, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 20/100
# 420/420 [==============================] - 318s 757ms/step - loss: 1.0716 - dice_coef: 0.9091 - accuracy: 0.9124 - val_loss: 1.1266 - val_dice_coef: 0.9013 - val_accuracy: 0.9044
#
# Epoch 00020: val_loss improved from 1.19643 to 1.12661, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 21/100
# 420/420 [==============================] - 318s 757ms/step - loss: 1.0687 - dice_coef: 0.9044 - accuracy: 0.9079 - val_loss: 1.2493 - val_dice_coef: 0.8740 - val_accuracy: 0.8788
#
# Epoch 00021: val_loss did not improve from 1.12661
# Epoch 22/100
# 420/420 [==============================] - 318s 757ms/step - loss: 1.0271 - dice_coef: 0.9080 - accuracy: 0.9112 - val_loss: 1.4234 - val_dice_coef: 0.8645 - val_accuracy: 0.8674
#
# Epoch 00022: val_loss did not improve from 1.12661
# Epoch 23/100
# 420/420 [==============================] - 318s 757ms/step - loss: 1.0144 - dice_coef: 0.9064 - accuracy: 0.9096 - val_loss: 1.0128 - val_dice_coef: 0.9088 - val_accuracy: 0.9128
#
# Epoch 00023: val_loss improved from 1.12661 to 1.01279, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 24/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.9809 - dice_coef: 0.9089 - accuracy: 0.9121 - val_loss: 1.0740 - val_dice_coef: 0.8927 - val_accuracy: 0.8972
#
# Epoch 00024: val_loss did not improve from 1.01279
# Epoch 25/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.9662 - dice_coef: 0.9104 - accuracy: 0.9136 - val_loss: 0.9587 - val_dice_coef: 0.9155 - val_accuracy: 0.9177
#
# Epoch 00025: val_loss improved from 1.01279 to 0.95867, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 26/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.9656 - dice_coef: 0.9119 - accuracy: 0.9149 - val_loss: 1.1861 - val_dice_coef: 0.8875 - val_accuracy: 0.8896
#
# Epoch 00026: val_loss did not improve from 0.95867
# Epoch 27/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.9784 - dice_coef: 0.9039 - accuracy: 0.9074 - val_loss: 0.9198 - val_dice_coef: 0.9119 - val_accuracy: 0.9150
#
# Epoch 00027: val_loss improved from 0.95867 to 0.91976, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 28/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.9587 - dice_coef: 0.9066 - accuracy: 0.9099 - val_loss: 1.0037 - val_dice_coef: 0.8981 - val_accuracy: 0.9015
#
# Epoch 00028: val_loss did not improve from 0.91976
# Epoch 29/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.9200 - dice_coef: 0.9128 - accuracy: 0.9159 - val_loss: 1.0685 - val_dice_coef: 0.8936 - val_accuracy: 0.8965
#
# Epoch 00029: val_loss did not improve from 0.91976
# Epoch 30/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8962 - dice_coef: 0.9132 - accuracy: 0.9162 - val_loss: 1.0010 - val_dice_coef: 0.9049 - val_accuracy: 0.9070
#
# Epoch 00030: val_loss did not improve from 0.91976
# Epoch 31/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.9267 - dice_coef: 0.9086 - accuracy: 0.9118 - val_loss: 1.1314 - val_dice_coef: 0.8910 - val_accuracy: 0.8925
#
# Epoch 00031: val_loss did not improve from 0.91976
# Epoch 32/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.9562 - dice_coef: 0.9050 - accuracy: 0.9083 - val_loss: 1.4608 - val_dice_coef: 0.8168 - val_accuracy: 0.8228
#
# Epoch 00032: val_loss did not improve from 0.91976
# Epoch 33/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8976 - dice_coef: 0.9115 - accuracy: 0.9147 - val_loss: 0.9867 - val_dice_coef: 0.9073 - val_accuracy: 0.9087
#
# Epoch 00033: val_loss did not improve from 0.91976
# Epoch 34/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8729 - dice_coef: 0.9156 - accuracy: 0.9184 - val_loss: 0.9765 - val_dice_coef: 0.8986 - val_accuracy: 0.9020
#
# Epoch 00034: val_loss did not improve from 0.91976
# Epoch 35/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8905 - dice_coef: 0.9130 - accuracy: 0.9159 - val_loss: 1.0490 - val_dice_coef: 0.8981 - val_accuracy: 0.8997
#
# Epoch 00035: val_loss did not improve from 0.91976
# Epoch 36/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8977 - dice_coef: 0.9119 - accuracy: 0.9149 - val_loss: 1.0927 - val_dice_coef: 0.8868 - val_accuracy: 0.8920
#
# Epoch 00036: val_loss did not improve from 0.91976
# Epoch 37/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8913 - dice_coef: 0.9118 - accuracy: 0.9148 - val_loss: 0.9415 - val_dice_coef: 0.9117 - val_accuracy: 0.9141
#
# Epoch 00037: val_loss did not improve from 0.91976
# Epoch 38/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8588 - dice_coef: 0.9171 - accuracy: 0.9199 - val_loss: 1.1149 - val_dice_coef: 0.8807 - val_accuracy: 0.8856
#
# Epoch 00038: val_loss did not improve from 0.91976
# Epoch 39/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8874 - dice_coef: 0.9121 - accuracy: 0.9151 - val_loss: 1.0293 - val_dice_coef: 0.8847 - val_accuracy: 0.8870
#
# Epoch 00039: val_loss did not improve from 0.91976
# Epoch 40/100
# 420/420 [==============================] - 318s 756ms/step - loss: 0.8825 - dice_coef: 0.9125 - accuracy: 0.9155 - val_loss: 0.9371 - val_dice_coef: 0.9080 - val_accuracy: 0.9114
#
# Epoch 00040: val_loss did not improve from 0.91976
# Epoch 41/100
# 420/420 [==============================] - 318s 756ms/step - loss: 0.8734 - dice_coef: 0.9144 - accuracy: 0.9173 - val_loss: 0.9756 - val_dice_coef: 0.9059 - val_accuracy: 0.9077
#
# Epoch 00041: val_loss did not improve from 0.91976
# Epoch 42/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8881 - dice_coef: 0.9099 - accuracy: 0.9130 - val_loss: 0.8982 - val_dice_coef: 0.9098 - val_accuracy: 0.9131
#
# Epoch 00042: val_loss improved from 0.91976 to 0.89824, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 43/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8600 - dice_coef: 0.9137 - accuracy: 0.9168 - val_loss: 0.8574 - val_dice_coef: 0.9174 - val_accuracy: 0.9201
#
# Epoch 00043: val_loss improved from 0.89824 to 0.85740, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 44/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8662 - dice_coef: 0.9152 - accuracy: 0.9181 - val_loss: 0.8422 - val_dice_coef: 0.9205 - val_accuracy: 0.9224
#
# Epoch 00044: val_loss improved from 0.85740 to 0.84221, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 45/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8505 - dice_coef: 0.9162 - accuracy: 0.9191 - val_loss: 0.8796 - val_dice_coef: 0.9129 - val_accuracy: 0.9162
#
# Epoch 00045: val_loss did not improve from 0.84221
# Epoch 46/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8731 - dice_coef: 0.9126 - accuracy: 0.9157 - val_loss: 1.0132 - val_dice_coef: 0.8857 - val_accuracy: 0.8910
#
# Epoch 00046: val_loss did not improve from 0.84221
# Epoch 47/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8610 - dice_coef: 0.9152 - accuracy: 0.9181 - val_loss: 0.9055 - val_dice_coef: 0.9054 - val_accuracy: 0.9097
#
# Epoch 00047: val_loss did not improve from 0.84221
# Epoch 48/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8666 - dice_coef: 0.9129 - accuracy: 0.9159 - val_loss: 0.9384 - val_dice_coef: 0.9018 - val_accuracy: 0.9047
#
# Epoch 00048: val_loss did not improve from 0.84221
# Epoch 49/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8680 - dice_coef: 0.9132 - accuracy: 0.9162 - val_loss: 0.9928 - val_dice_coef: 0.8991 - val_accuracy: 0.9012
#
# Epoch 00049: val_loss did not improve from 0.84221
# Epoch 50/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8881 - dice_coef: 0.9102 - accuracy: 0.9133 - val_loss: 1.2959 - val_dice_coef: 0.8722 - val_accuracy: 0.8728
#
# Epoch 00050: val_loss did not improve from 0.84221
# Epoch 51/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.9072 - dice_coef: 0.9077 - accuracy: 0.9109 - val_loss: 1.1811 - val_dice_coef: 0.8693 - val_accuracy: 0.8713
#
# Epoch 00051: val_loss did not improve from 0.84221
# Epoch 52/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8788 - dice_coef: 0.9121 - accuracy: 0.9152 - val_loss: 0.8847 - val_dice_coef: 0.9148 - val_accuracy: 0.9177
#
# Epoch 00052: val_loss did not improve from 0.84221
# Epoch 53/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8664 - dice_coef: 0.9141 - accuracy: 0.9170 - val_loss: 0.8522 - val_dice_coef: 0.9178 - val_accuracy: 0.9200
#
# Epoch 00053: val_loss did not improve from 0.84221
# Epoch 54/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8489 - dice_coef: 0.9175 - accuracy: 0.9202 - val_loss: 0.8890 - val_dice_coef: 0.9132 - val_accuracy: 0.9166
#
# Epoch 00054: val_loss did not improve from 0.84221
# Epoch 55/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8323 - dice_coef: 0.9195 - accuracy: 0.9223 - val_loss: 0.8300 - val_dice_coef: 0.9197 - val_accuracy: 0.9221
#
# Epoch 00055: val_loss improved from 0.84221 to 0.83002, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 56/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8342 - dice_coef: 0.9172 - accuracy: 0.9201 - val_loss: 0.9544 - val_dice_coef: 0.9042 - val_accuracy: 0.9078
#
# Epoch 00056: val_loss did not improve from 0.83002
# Epoch 57/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8236 - dice_coef: 0.9199 - accuracy: 0.9226 - val_loss: 0.9287 - val_dice_coef: 0.9061 - val_accuracy: 0.9099
#
# Epoch 00057: val_loss did not improve from 0.83002
# Epoch 58/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8530 - dice_coef: 0.9166 - accuracy: 0.9194 - val_loss: 0.8783 - val_dice_coef: 0.9139 - val_accuracy: 0.9171
#
# Epoch 00058: val_loss did not improve from 0.83002
# Epoch 59/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8637 - dice_coef: 0.9138 - accuracy: 0.9167 - val_loss: 1.0252 - val_dice_coef: 0.8971 - val_accuracy: 0.8987
#
# Epoch 00059: val_loss did not improve from 0.83002
# Epoch 60/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8400 - dice_coef: 0.9179 - accuracy: 0.9207 - val_loss: 0.8003 - val_dice_coef: 0.9241 - val_accuracy: 0.9266
#
# Epoch 00060: val_loss improved from 0.83002 to 0.80034, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet//Checkpoint.h5
# Epoch 61/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8313 - dice_coef: 0.9184 - accuracy: 0.9212 - val_loss: 1.4478 - val_dice_coef: 0.8159 - val_accuracy: 0.8251
#
# Epoch 00061: val_loss did not improve from 0.80034
# Epoch 62/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8650 - dice_coef: 0.9148 - accuracy: 0.9178 - val_loss: 0.8847 - val_dice_coef: 0.9139 - val_accuracy: 0.9182
#
# Epoch 00062: val_loss did not improve from 0.80034
# Epoch 63/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8497 - dice_coef: 0.9178 - accuracy: 0.9207 - val_loss: 0.9476 - val_dice_coef: 0.9033 - val_accuracy: 0.9060
#
# Epoch 00063: val_loss did not improve from 0.80034
# Epoch 64/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8428 - dice_coef: 0.9188 - accuracy: 0.9216 - val_loss: 0.9026 - val_dice_coef: 0.9136 - val_accuracy: 0.9151
#
# Epoch 00064: val_loss did not improve from 0.80034
# Epoch 65/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8752 - dice_coef: 0.9130 - accuracy: 0.9159 - val_loss: 1.0447 - val_dice_coef: 0.8967 - val_accuracy: 0.8980
#
# Epoch 00065: val_loss did not improve from 0.80034
# Epoch 66/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8660 - dice_coef: 0.9134 - accuracy: 0.9163 - val_loss: 0.9149 - val_dice_coef: 0.9120 - val_accuracy: 0.9136
#
# Epoch 00066: val_loss did not improve from 0.80034
# Epoch 67/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8431 - dice_coef: 0.9188 - accuracy: 0.9217 - val_loss: 0.8392 - val_dice_coef: 0.9213 - val_accuracy: 0.9229
#
# Epoch 00067: val_loss did not improve from 0.80034
# Epoch 68/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8660 - dice_coef: 0.9132 - accuracy: 0.9161 - val_loss: 1.0244 - val_dice_coef: 0.8929 - val_accuracy: 0.8998
#
# Epoch 00068: val_loss did not improve from 0.80034
# Epoch 69/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8681 - dice_coef: 0.9162 - accuracy: 0.9191 - val_loss: 0.9789 - val_dice_coef: 0.8936 - val_accuracy: 0.8965
#
# Epoch 00069: val_loss did not improve from 0.80034
# Epoch 70/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8756 - dice_coef: 0.9143 - accuracy: 0.9171 - val_loss: 0.9181 - val_dice_coef: 0.9104 - val_accuracy: 0.9149
#
# Epoch 00070: val_loss did not improve from 0.80034
# Epoch 71/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8314 - dice_coef: 0.9205 - accuracy: 0.9232 - val_loss: 0.8277 - val_dice_coef: 0.9221 - val_accuracy: 0.9241
#
# Epoch 00071: val_loss did not improve from 0.80034
# Epoch 72/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8483 - dice_coef: 0.9177 - accuracy: 0.9205 - val_loss: 1.0756 - val_dice_coef: 0.8941 - val_accuracy: 0.8961
#
# Epoch 00072: val_loss did not improve from 0.80034
# Epoch 73/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8118 - dice_coef: 0.9221 - accuracy: 0.9248 - val_loss: 0.8131 - val_dice_coef: 0.9237 - val_accuracy: 0.9261
#
# Epoch 00073: val_loss did not improve from 0.80034
# Epoch 74/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8265 - dice_coef: 0.9209 - accuracy: 0.9236 - val_loss: 0.9629 - val_dice_coef: 0.9076 - val_accuracy: 0.9098
#
# Epoch 00074: val_loss did not improve from 0.80034
# Epoch 75/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8293 - dice_coef: 0.9203 - accuracy: 0.9231 - val_loss: 0.9366 - val_dice_coef: 0.9084 - val_accuracy: 0.9102
#
# Epoch 00075: val_loss did not improve from 0.80034
# Epoch 76/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8431 - dice_coef: 0.9191 - accuracy: 0.9217 - val_loss: 1.0693 - val_dice_coef: 0.8911 - val_accuracy: 0.8924
#
# Epoch 00076: val_loss did not improve from 0.80034
# Epoch 77/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8425 - dice_coef: 0.9184 - accuracy: 0.9212 - val_loss: 0.8089 - val_dice_coef: 0.9235 - val_accuracy: 0.9265
#
# Epoch 00077: val_loss did not improve from 0.80034
# Epoch 78/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8475 - dice_coef: 0.9173 - accuracy: 0.9202 - val_loss: 0.9470 - val_dice_coef: 0.9102 - val_accuracy: 0.9136
#
# Epoch 00078: val_loss did not improve from 0.80034
# Epoch 79/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8183 - dice_coef: 0.9217 - accuracy: 0.9243 - val_loss: 0.8377 - val_dice_coef: 0.9220 - val_accuracy: 0.9246
#
# Epoch 00079: val_loss did not improve from 0.80034
# Epoch 80/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8168 - dice_coef: 0.9210 - accuracy: 0.9237 - val_loss: 1.0594 - val_dice_coef: 0.8880 - val_accuracy: 0.8927
#
# Epoch 00080: val_loss did not improve from 0.80034
# Epoch 81/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8203 - dice_coef: 0.9209 - accuracy: 0.9236 - val_loss: 0.9896 - val_dice_coef: 0.9026 - val_accuracy: 0.9039
#
# Epoch 00081: val_loss did not improve from 0.80034
# Epoch 82/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8219 - dice_coef: 0.9218 - accuracy: 0.9244 - val_loss: 0.9038 - val_dice_coef: 0.9143 - val_accuracy: 0.9155
#
# Epoch 00082: val_loss did not improve from 0.80034
# Epoch 83/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8279 - dice_coef: 0.9207 - accuracy: 0.9233 - val_loss: 0.9354 - val_dice_coef: 0.9101 - val_accuracy: 0.9119
#
# Epoch 00083: val_loss did not improve from 0.80034
# Epoch 84/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8306 - dice_coef: 0.9210 - accuracy: 0.9236 - val_loss: 0.9475 - val_dice_coef: 0.9061 - val_accuracy: 0.9101
#
# Epoch 00084: val_loss did not improve from 0.80034
# Epoch 85/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8260 - dice_coef: 0.9217 - accuracy: 0.9243 - val_loss: 0.8699 - val_dice_coef: 0.9184 - val_accuracy: 0.9215
#
# Epoch 00085: val_loss did not improve from 0.80034
# Epoch 86/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8343 - dice_coef: 0.9212 - accuracy: 0.9238 - val_loss: 0.9656 - val_dice_coef: 0.8963 - val_accuracy: 0.9000
#
# Epoch 00086: val_loss did not improve from 0.80034
# Epoch 87/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8612 - dice_coef: 0.9138 - accuracy: 0.9167 - val_loss: 0.9865 - val_dice_coef: 0.8999 - val_accuracy: 0.9020
#
# Epoch 00087: val_loss did not improve from 0.80034
# Epoch 88/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8224 - dice_coef: 0.9222 - accuracy: 0.9248 - val_loss: 1.1146 - val_dice_coef: 0.8771 - val_accuracy: 0.8815
#
# Epoch 00088: val_loss did not improve from 0.80034
# Epoch 89/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8268 - dice_coef: 0.9205 - accuracy: 0.9232 - val_loss: 1.1708 - val_dice_coef: 0.8755 - val_accuracy: 0.8792
#
# Epoch 00089: val_loss did not improve from 0.80034
# Epoch 90/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8024 - dice_coef: 0.9242 - accuracy: 0.9267 - val_loss: 0.9195 - val_dice_coef: 0.9110 - val_accuracy: 0.9140
#
# Epoch 00090: val_loss did not improve from 0.80034
# Epoch 91/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8086 - dice_coef: 0.9226 - accuracy: 0.9252 - val_loss: 0.8195 - val_dice_coef: 0.9190 - val_accuracy: 0.9224
#
# Epoch 00091: val_loss did not improve from 0.80034
# Epoch 92/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8030 - dice_coef: 0.9233 - accuracy: 0.9259 - val_loss: 0.9466 - val_dice_coef: 0.9041 - val_accuracy: 0.9067
#
# Epoch 00092: val_loss did not improve from 0.80034
# Epoch 93/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8226 - dice_coef: 0.9227 - accuracy: 0.9253 - val_loss: 1.0570 - val_dice_coef: 0.8994 - val_accuracy: 0.9005
#
# Epoch 00093: val_loss did not improve from 0.80034
# Epoch 94/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8087 - dice_coef: 0.9229 - accuracy: 0.9254 - val_loss: 0.9415 - val_dice_coef: 0.9137 - val_accuracy: 0.9157
#
# Epoch 00094: val_loss did not improve from 0.80034
# Epoch 95/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8195 - dice_coef: 0.9223 - accuracy: 0.9249 - val_loss: 0.8288 - val_dice_coef: 0.9226 - val_accuracy: 0.9241
#
# Epoch 00095: val_loss did not improve from 0.80034
# Epoch 96/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8325 - dice_coef: 0.9219 - accuracy: 0.9245 - val_loss: 0.9283 - val_dice_coef: 0.9069 - val_accuracy: 0.9130
#
# Epoch 00096: val_loss did not improve from 0.80034
# Epoch 97/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8257 - dice_coef: 0.9213 - accuracy: 0.9240 - val_loss: 0.8640 - val_dice_coef: 0.9134 - val_accuracy: 0.9164
#
# Epoch 00097: val_loss did not improve from 0.80034
# Epoch 98/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8175 - dice_coef: 0.9225 - accuracy: 0.9251 - val_loss: 0.8451 - val_dice_coef: 0.9208 - val_accuracy: 0.9237
#
# Epoch 00098: val_loss did not improve from 0.80034
# Epoch 99/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8241 - dice_coef: 0.9217 - accuracy: 0.9243 - val_loss: 0.8308 - val_dice_coef: 0.9225 - val_accuracy: 0.9254
#
# Epoch 00099: val_loss did not improve from 0.80034
# Epoch 100/100
# 420/420 [==============================] - 318s 757ms/step - loss: 0.8109 - dice_coef: 0.9233 - accuracy: 0.9259 - val_loss: 0.8751 - val_dice_coef: 0.9164 - val_accuracy: 0.9195
#
# Epoch 00100: val_loss did not improve from 0.80034
# TRAIN: [0, 1, 2, 3, 4, 6, 8] TEST: [5, 7] FOLD: 2
# -----------fold 2--------------
# Epoch 1/100
# 413/426 [============================>.] - ETA: 9s - loss: 4.3836 - dice_coef: 0.7801 - accuracy: 0.8467
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-165e6792ad4a> in <module>()
#      45   print('-----------fold {}--------------'.format(fold))
#      46   history = model.fit(datagen, validation_data = [ValX, ValY],
# ---> 47                   epochs=num_epoch,steps_per_epoch = math.ceil(n_points / batch_size), callbacks =[mc],  shuffle =True)
#      48   model.save(MODELS_PATH + '/LadderNet_HER2_'+ str(fold) +'.h5')
#      49   fold = fold + 1
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1145                 use_multiprocessing=use_multiprocessing,
#    1146                 shuffle=shuffle,
# -> 1147                 initial_epoch=initial_epoch)
#    1148
#    1149         # Case 2: Symbolic tensors or Numpy array-like.
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     218                                             sample_weight=sample_weight,
#     219                                             class_weight=class_weight,
# --> 220                                             reset_metrics=False)
#     221
#     222                 outs = to_list(outs)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3790         value = math_ops.cast(value, tensor.dtype)
#    3791       converted_inputs.append(value)
# -> 3792     outputs = self._graph_fn(*converted_inputs)
#    3793
#    3794     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    1603       TypeError: For invalid positional/keyword argument combinations.
#    1604     """
# -> 1605     return self._call_impl(args, kwargs)
#    1606
#    1607   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1643       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1644           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1645     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1646
#    1647   def _filtered_call(self, args, kwargs):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask, Patient_array,Patient_length,title,folder):
  idx = 0
  for i in range(len(Patient_length)):
    temp = []
    for j in range(Patient_length[i]):
      final_output = mask[idx:idx+48]
      idx = idx + 48
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save(folder + title + Patient_array[i], final_output)

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet/"
model_names = os.listdir(MODELS_PATH)
print(model_names)
# Out:
# ['LadderNet_HER2_1.h5']

# %%
model = keras.models.load_model(MODELS_PATH + model_names[0],custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-27-6fb2a8840da5> in <module>()
# ----> 1 model = keras.models.load_model(MODELS_PATH + model_names[0],custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     581
#     582     if H5Dict.is_supported_type(filepath):
# --> 583         with H5Dict(filepath, mode='r') as h5dict:
#     584             model = _deserialize_model(h5dict, custom_objects, compile)
#     585     elif hasattr(filepath, 'write') and callable(filepath.write):
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/io_utils.py in __init__(self, path, mode)
#     189             self._is_file = False
#     190         elif isinstance(path, six.string_types) or _is_path_instance(path):
# --> 191             self.data = h5py.File(path, mode=mode)
#     192             self._is_file = True
#     193         elif isinstance(path, dict):
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (file read failed: time = Wed Jul 22 18:01:27 2020
# , filename = '/content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet/LadderNet_HER2_1.h5', file descriptor = 54, errno = 5, error message = 'Input/output error', buf = 0x7ffe55d7d320, total read size = 8, bytes this sub-read = 8, bytes actually read = 18446744073709551615, offset = 0)

# %%
SAVE_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/HER2/3Fold LadderNet/"

# %%
# Axis 0 = Folds
# Axis 1 = Class (Membrane Nuclei Background)
# Axis 2 = Evaluation Technique (Precision, Recall, Dice coefficient)
pixEvaluationTrain = np.empty((0,3,3))
pixEvaluationTest = np.empty((0,3,3))
score = np.zeros((1,3,3))

# %%
fold = 0

for train_index, test_index in fold_split:
  print("FOLD:",fold,"\tTRAIN:", train_index, "TEST:", test_index)
  # Splitting Train and Test data
  if(fold == 0):
    fold = fold+1
    continue
  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  train_no = [patient_no[i] for i in train_index]
  train_size = [size[i] for i in train_index]

  test_no = [patient_no[i] for i in test_index]
  test_size = [size[i] for i in test_index]

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255

  convertToLabels(TrainY)
  convertToLabels(TestY)

  # Loading corrosponding fold of model
  model = keras.models.load_model(MODELS_PATH + model_names[0],custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

  # Predicting results using model
  trainResult = model.predict(TrainX, batch_size=8)
  testResult = model.predict(TestX,batch_size=8)

  trainResult = np.argmax(trainResult,axis=-1)
  testResult = np.argmax(testResult,axis=-1)

  # Obtaining pixel-wise results: Precision recall and dice coefficient
  # For TRAIN
  y_true = np.reshape(TrainY,(-1))
  y_pred = np.reshape(trainResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2],average=None,zero_division=1)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2],average=None,zero_division=1)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(3):
    score[0][i][0] = prec[2-i]
    score[0][i][1] = recall[2-i]
    score[0][i][2] = dice[2-i]

  pixEvaluationTrain = np.append(pixEvaluationTrain,score,axis=0)
 
  # For TEST
  y_true = np.reshape(TestY,(-1))
  y_pred = np.reshape(testResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2],average=None,zero_division=1)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2],average=None,zero_division=1)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(3):
    score[0][i][0] = prec[2-i]
    score[0][i][1] = recall[2-i]
    score[0][i][2] = dice[2-i]

  pixEvaluationTest = np.append(pixEvaluationTest,score,axis=0)

  # Converting predicted labels to required output format
  convertFromLabels(trainResult)
  convertFromLabels(testResult)

  # Saving numpy arrays
  path = os.path.join(SAVE_PATH,"Fold " + str(fold))
  os.mkdir(path)
  os.mkdir(path + '/Train')
  os.mkdir(path + '/Test')

  saveNumpyOutput(trainResult, train_no, train_size,"/Train/",path)
  saveNumpyOutput(testResult, test_no, test_size,"/Test/",path)

  fold +=1
# Out:
# FOLD: 0 	TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1]
# FOLD: 1 	TRAIN: [0, 1, 2, 4, 5, 7, 8] TEST: [3, 6]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-26-a16b5e068280> in <module>()
#      26
#      27   # Loading corrosponding fold of model
# ---> 28   model = keras.models.load_model(MODELS_PATH + model_names[0],custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })
#      29
#      30   # Predicting results using model
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     581
#     582     if H5Dict.is_supported_type(filepath):
# --> 583         with H5Dict(filepath, mode='r') as h5dict:
#     584             model = _deserialize_model(h5dict, custom_objects, compile)
#     585     elif hasattr(filepath, 'write') and callable(filepath.write):
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/io_utils.py in __init__(self, path, mode)
#     189             self._is_file = False
#     190         elif isinstance(path, six.string_types) or _is_path_instance(path):
# --> 191             self.data = h5py.File(path, mode=mode)
#     192             self._is_file = True
#     193         elif isinstance(path, dict):
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (file read failed: time = Wed Jul 22 17:55:42 2020
# , filename = '/content/drive/My Drive/Breast Cancer Treatment/Models/HER2/3Fold LadderNet/LadderNet_HER2_1.h5', file descriptor = 54, errno = 5, error message = 'Input/output error', buf = 0x7ffe55d7d320, total read size = 8, bytes this sub-read = 8, bytes actually read = 18446744073709551615, offset = 0)

# %%
print(pixEvaluationTrain.shape)
print(pixEvaluationTest.shape)

# %%
print(pixEvaluationTest)

# %%
np.save(SAVE_PATH + "Pixel-wise Metrics Train.npy", pixEvaluationTrain)
np.save(SAVE_PATH + "Pixel-wise Metrics Test.npy", pixEvaluationTest)

# %% [markdown]
# # **DISPLAY**

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 48   # enter between 0- 50 since there are 5 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]
Mask_input = TestGT[id:id+48]
final_output = testResult[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 25  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]
Mask_input = TrainGT[id:id+48]
final_output = trainResult[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
