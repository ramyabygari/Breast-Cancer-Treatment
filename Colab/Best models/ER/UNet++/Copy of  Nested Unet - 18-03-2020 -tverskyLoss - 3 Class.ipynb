# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %tensorflow_version 1.x
import tensorflow
print(tensorflow.__version__)

# %%
from keras.layers import Activation,Conv2D,MaxPooling2D,UpSampling2D,Dense,BatchNormalization,Input,Reshape,multiply,add,Dropout,AveragePooling2D,GlobalAveragePooling2D,concatenate
from keras.layers.convolutional import Conv2DTranspose
from keras.models import Model														  
import keras.backend as K
from keras.regularizers import l2
from keras.engine import Layer,InputSpec
from keras.utils import conv_utils
from keras.layers import Activation,Conv2D,MaxPooling2D,UpSampling2D,Dense,BatchNormalization,Input,Reshape,multiply,add,Dropout,AveragePooling2D,GlobalAveragePooling2D,concatenate
from keras.layers.convolutional import Conv2DTranspose
from keras.models import Model														  
import keras.backend as K
from keras.regularizers import l2
from keras.engine import Layer,InputSpec
from keras.utils import conv_utils
# !pip install medpy
from keras.layers import *
from keras.models import Sequential
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from medpy.metric import dc, precision, recall
import keras
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Collecting medpy
#   Downloading https://files.pythonhosted.org/packages/3b/70/c1fd5dd60242eee81774696ea7ba4caafac2bad8f028bba94b1af83777d7/MedPy-0.4.0.tar.gz (151kB)
#      |████████████████████████████████| 153kB 7.1MB/s
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from medpy) (1.18.1)
# Collecting SimpleITK>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/f8/d8/53338c34f71020725ffb3557846c80af96c29c03bc883551a2565aa68a7c/SimpleITK-1.2.4-cp36-cp36m-manylinux1_x86_64.whl (42.5MB)
#      |████████████████████████████████| 42.5MB 72kB/s
# Building wheels for collected packages: medpy
#   Building wheel for medpy (setup.py) ... done
#   Created wheel for medpy: filename=MedPy-0.4.0-cp36-cp36m-linux_x86_64.whl size=753430 sha256=708a11ce838645fb412f591c7c8259948cfc05de1fa559ebad681eb2b3d41366
#   Stored in directory: /root/.cache/pip/wheels/8c/c9/9c/2c6281c7a72b9fb1570862a4f028af7ce38405008354fbf870
# Successfully built medpy
# Installing collected packages: SimpleITK, medpy
# Successfully installed SimpleITK-1.2.4 medpy-0.4.0

# %%
smooth = 1.
dropout_rate = 0.5
def standard_unit(input_tensor, stage, nb_filter, kernel_size=3):

    act = 'elu'

    x = Conv2D(nb_filter, (kernel_size, kernel_size), activation=act, name='conv'+stage+'_1', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(input_tensor)
    x = Dropout(dropout_rate, name='dp'+stage+'_1')(x)
    x = Conv2D(nb_filter, (kernel_size, kernel_size), activation=act, name='conv'+stage+'_2', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(x)
    x = Dropout(dropout_rate, name='dp'+stage+'_2')(x)

    return x

# %%
def Nest_Net(img_rows, img_cols, color_type=3, num_class=3, deep_supervision=False):

    nb_filter = [8,16,32,64,128]
    act = 'elu'
  
    bn_axis = 3
    
    
    img_input = Input(shape=(img_rows, img_cols, color_type), name='main_input')
    conv1_1 = standard_unit(img_input, stage='11', nb_filter=nb_filter[0])
    pool1 = MaxPooling2D((2, 2), strides=(2, 2), name='pool1')(conv1_1)

    conv2_1 = standard_unit(pool1, stage='21', nb_filter=nb_filter[1])
    pool2 = MaxPooling2D((2, 2), strides=(2, 2), name='pool2')(conv2_1)

    up1_2 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up12', padding='same')(conv2_1)
    conv1_2 = concatenate([up1_2, conv1_1], name='merge12', axis=bn_axis)
    conv1_2 = standard_unit(conv1_2, stage='12', nb_filter=nb_filter[0])

    conv3_1 = standard_unit(pool2, stage='31', nb_filter=nb_filter[2])
    pool3 = MaxPooling2D((2, 2), strides=(2, 2), name='pool3')(conv3_1)

    up2_2 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up22', padding='same')(conv3_1)
    conv2_2 = concatenate([up2_2, conv2_1], name='merge22', axis=bn_axis)
    conv2_2 = standard_unit(conv2_2, stage='22', nb_filter=nb_filter[1])

    up1_3 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up13', padding='same')(conv2_2)
    conv1_3 = concatenate([up1_3, conv1_1, conv1_2], name='merge13', axis=bn_axis)
    conv1_3 = standard_unit(conv1_3, stage='13', nb_filter=nb_filter[0])

    conv4_1 = standard_unit(pool3, stage='41', nb_filter=nb_filter[3])
    pool4 = MaxPooling2D((2, 2), strides=(2, 2), name='pool4')(conv4_1)

    up3_2 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up32', padding='same')(conv4_1)
    conv3_2 = concatenate([up3_2, conv3_1], name='merge32', axis=bn_axis)
    conv3_2 = standard_unit(conv3_2, stage='32', nb_filter=nb_filter[2])

    up2_3 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up23', padding='same')(conv3_2)
    conv2_3 = concatenate([up2_3, conv2_1, conv2_2], name='merge23', axis=bn_axis)
    conv2_3 = standard_unit(conv2_3, stage='23', nb_filter=nb_filter[1])

    up1_4 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up14', padding='same')(conv2_3)
    conv1_4 = concatenate([up1_4, conv1_1, conv1_2, conv1_3], name='merge14', axis=bn_axis)
    conv1_4 = standard_unit(conv1_4, stage='14', nb_filter=nb_filter[0])

    conv5_1 = standard_unit(pool4, stage='51', nb_filter=nb_filter[4])

    up4_2 = Conv2DTranspose(nb_filter[3], (2, 2), strides=(2, 2), name='up42', padding='same')(conv5_1)
    conv4_2 = concatenate([up4_2, conv4_1], name='merge42', axis=bn_axis)
    conv4_2 = standard_unit(conv4_2, stage='42', nb_filter=nb_filter[3])

    up3_3 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up33', padding='same')(conv4_2)
    conv3_3 = concatenate([up3_3, conv3_1, conv3_2], name='merge33', axis=bn_axis)
    conv3_3 = standard_unit(conv3_3, stage='33', nb_filter=nb_filter[2])

    up2_4 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up24', padding='same')(conv3_3)
    conv2_4 = concatenate([up2_4, conv2_1, conv2_2, conv2_3], name='merge24', axis=bn_axis)
    conv2_4 = standard_unit(conv2_4, stage='24', nb_filter=nb_filter[1])

    up1_5 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up15', padding='same')(conv2_4)
    conv1_5 = concatenate([up1_5, conv1_1, conv1_2, conv1_3, conv1_4], name='merge15', axis=bn_axis)
    conv1_5 = standard_unit(conv1_5, stage='15', nb_filter=nb_filter[0])

    nestnet_output_1 = Conv2D(num_class, (1, 1), activation='softmax', name='output_1', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_2)
    nestnet_output_2 = Conv2D(num_class, (1, 1), activation='softmax', name='output_2', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_3)
    nestnet_output_3 = Conv2D(num_class, (1, 1), activation='softmax', name='output_3', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_4)
    nestnet_output_4 = Conv2D(num_class, (1, 1), activation='softmax', name='output_4', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_5)

    if deep_supervision:
        model = Model(input=img_input, output=[nestnet_output_1,
                                               nestnet_output_2,
                                               nestnet_output_3,
                                               nestnet_output_4])
    else:
        model = Model(input=img_input, output=[nestnet_output_4])

    return model

# %%
model = Nest_Net(240,240,3)
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 240, 240, 3)  0
# __________________________________________________________________________________________________
# conv11_1 (Conv2D)               (None, 240, 240, 8)  224         main_input[0][0]
# __________________________________________________________________________________________________
# dp11_1 (Dropout)                (None, 240, 240, 8)  0           conv11_1[0][0]
# __________________________________________________________________________________________________
# conv11_2 (Conv2D)               (None, 240, 240, 8)  584         dp11_1[0][0]
# __________________________________________________________________________________________________
# dp11_2 (Dropout)                (None, 240, 240, 8)  0           conv11_2[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 120, 120, 8)  0           dp11_2[0][0]
# __________________________________________________________________________________________________
# conv21_1 (Conv2D)               (None, 120, 120, 16) 1168        pool1[0][0]
# __________________________________________________________________________________________________
# dp21_1 (Dropout)                (None, 120, 120, 16) 0           conv21_1[0][0]
# __________________________________________________________________________________________________
# conv21_2 (Conv2D)               (None, 120, 120, 16) 2320        dp21_1[0][0]
# __________________________________________________________________________________________________
# dp21_2 (Dropout)                (None, 120, 120, 16) 0           conv21_2[0][0]
# __________________________________________________________________________________________________
# pool2 (MaxPooling2D)            (None, 60, 60, 16)   0           dp21_2[0][0]
# __________________________________________________________________________________________________
# conv31_1 (Conv2D)               (None, 60, 60, 32)   4640        pool2[0][0]
# __________________________________________________________________________________________________
# dp31_1 (Dropout)                (None, 60, 60, 32)   0           conv31_1[0][0]
# __________________________________________________________________________________________________
# conv31_2 (Conv2D)               (None, 60, 60, 32)   9248        dp31_1[0][0]
# __________________________________________________________________________________________________
# dp31_2 (Dropout)                (None, 60, 60, 32)   0           conv31_2[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 30, 30, 32)   0           dp31_2[0][0]
# __________________________________________________________________________________________________
# conv41_1 (Conv2D)               (None, 30, 30, 64)   18496       pool3[0][0]
# __________________________________________________________________________________________________
# dp41_1 (Dropout)                (None, 30, 30, 64)   0           conv41_1[0][0]
# __________________________________________________________________________________________________
# conv41_2 (Conv2D)               (None, 30, 30, 64)   36928       dp41_1[0][0]
# __________________________________________________________________________________________________
# dp41_2 (Dropout)                (None, 30, 30, 64)   0           conv41_2[0][0]
# __________________________________________________________________________________________________
# pool4 (MaxPooling2D)            (None, 15, 15, 64)   0           dp41_2[0][0]
# __________________________________________________________________________________________________
# conv51_1 (Conv2D)               (None, 15, 15, 128)  73856       pool4[0][0]
# __________________________________________________________________________________________________
# dp51_1 (Dropout)                (None, 15, 15, 128)  0           conv51_1[0][0]
# __________________________________________________________________________________________________
# conv51_2 (Conv2D)               (None, 15, 15, 128)  147584      dp51_1[0][0]
# __________________________________________________________________________________________________
# dp51_2 (Dropout)                (None, 15, 15, 128)  0           conv51_2[0][0]
# __________________________________________________________________________________________________
# up42 (Conv2DTranspose)          (None, 30, 30, 64)   32832       dp51_2[0][0]
# __________________________________________________________________________________________________
# merge42 (Concatenate)           (None, 30, 30, 128)  0           up42[0][0]
#                                                                  dp41_2[0][0]
# __________________________________________________________________________________________________
# up32 (Conv2DTranspose)          (None, 60, 60, 32)   8224        dp41_2[0][0]
# __________________________________________________________________________________________________
# conv42_1 (Conv2D)               (None, 30, 30, 64)   73792       merge42[0][0]
# __________________________________________________________________________________________________
# merge32 (Concatenate)           (None, 60, 60, 64)   0           up32[0][0]
#                                                                  dp31_2[0][0]
# __________________________________________________________________________________________________
# up22 (Conv2DTranspose)          (None, 120, 120, 16) 2064        dp31_2[0][0]
# __________________________________________________________________________________________________
# dp42_1 (Dropout)                (None, 30, 30, 64)   0           conv42_1[0][0]
# __________________________________________________________________________________________________
# conv32_1 (Conv2D)               (None, 60, 60, 32)   18464       merge32[0][0]
# __________________________________________________________________________________________________
# merge22 (Concatenate)           (None, 120, 120, 32) 0           up22[0][0]
#                                                                  dp21_2[0][0]
# __________________________________________________________________________________________________
# up12 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp21_2[0][0]
# __________________________________________________________________________________________________
# conv42_2 (Conv2D)               (None, 30, 30, 64)   36928       dp42_1[0][0]
# __________________________________________________________________________________________________
# dp32_1 (Dropout)                (None, 60, 60, 32)   0           conv32_1[0][0]
# __________________________________________________________________________________________________
# conv22_1 (Conv2D)               (None, 120, 120, 16) 4624        merge22[0][0]
# __________________________________________________________________________________________________
# merge12 (Concatenate)           (None, 240, 240, 16) 0           up12[0][0]
#                                                                  dp11_2[0][0]
# __________________________________________________________________________________________________
# dp42_2 (Dropout)                (None, 30, 30, 64)   0           conv42_2[0][0]
# __________________________________________________________________________________________________
# conv32_2 (Conv2D)               (None, 60, 60, 32)   9248        dp32_1[0][0]
# __________________________________________________________________________________________________
# dp22_1 (Dropout)                (None, 120, 120, 16) 0           conv22_1[0][0]
# __________________________________________________________________________________________________
# conv12_1 (Conv2D)               (None, 240, 240, 8)  1160        merge12[0][0]
# __________________________________________________________________________________________________
# up33 (Conv2DTranspose)          (None, 60, 60, 32)   8224        dp42_2[0][0]
# __________________________________________________________________________________________________
# dp32_2 (Dropout)                (None, 60, 60, 32)   0           conv32_2[0][0]
# __________________________________________________________________________________________________
# conv22_2 (Conv2D)               (None, 120, 120, 16) 2320        dp22_1[0][0]
# __________________________________________________________________________________________________
# dp12_1 (Dropout)                (None, 240, 240, 8)  0           conv12_1[0][0]
# __________________________________________________________________________________________________
# merge33 (Concatenate)           (None, 60, 60, 96)   0           up33[0][0]
#                                                                  dp31_2[0][0]
#                                                                  dp32_2[0][0]
# __________________________________________________________________________________________________
# dp22_2 (Dropout)                (None, 120, 120, 16) 0           conv22_2[0][0]
# __________________________________________________________________________________________________
# up23 (Conv2DTranspose)          (None, 120, 120, 16) 2064        dp32_2[0][0]
# __________________________________________________________________________________________________
# conv12_2 (Conv2D)               (None, 240, 240, 8)  584         dp12_1[0][0]
# __________________________________________________________________________________________________
# conv33_1 (Conv2D)               (None, 60, 60, 32)   27680       merge33[0][0]
# __________________________________________________________________________________________________
# merge23 (Concatenate)           (None, 120, 120, 48) 0           up23[0][0]
#                                                                  dp21_2[0][0]
#                                                                  dp22_2[0][0]
# __________________________________________________________________________________________________
# dp12_2 (Dropout)                (None, 240, 240, 8)  0           conv12_2[0][0]
# __________________________________________________________________________________________________
# up13 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp22_2[0][0]
# __________________________________________________________________________________________________
# dp33_1 (Dropout)                (None, 60, 60, 32)   0           conv33_1[0][0]
# __________________________________________________________________________________________________
# conv23_1 (Conv2D)               (None, 120, 120, 16) 6928        merge23[0][0]
# __________________________________________________________________________________________________
# merge13 (Concatenate)           (None, 240, 240, 24) 0           up13[0][0]
#                                                                  dp11_2[0][0]
#                                                                  dp12_2[0][0]
# __________________________________________________________________________________________________
# conv33_2 (Conv2D)               (None, 60, 60, 32)   9248        dp33_1[0][0]
# __________________________________________________________________________________________________
# dp23_1 (Dropout)                (None, 120, 120, 16) 0           conv23_1[0][0]
# __________________________________________________________________________________________________
# conv13_1 (Conv2D)               (None, 240, 240, 8)  1736        merge13[0][0]
# __________________________________________________________________________________________________
# dp33_2 (Dropout)                (None, 60, 60, 32)   0           conv33_2[0][0]
# __________________________________________________________________________________________________
# conv23_2 (Conv2D)               (None, 120, 120, 16) 2320        dp23_1[0][0]
# __________________________________________________________________________________________________
# dp13_1 (Dropout)                (None, 240, 240, 8)  0           conv13_1[0][0]
# __________________________________________________________________________________________________
# up24 (Conv2DTranspose)          (None, 120, 120, 16) 2064        dp33_2[0][0]
# __________________________________________________________________________________________________
# dp23_2 (Dropout)                (None, 120, 120, 16) 0           conv23_2[0][0]
# __________________________________________________________________________________________________
# conv13_2 (Conv2D)               (None, 240, 240, 8)  584         dp13_1[0][0]
# __________________________________________________________________________________________________
# merge24 (Concatenate)           (None, 120, 120, 64) 0           up24[0][0]
#                                                                  dp21_2[0][0]
#                                                                  dp22_2[0][0]
#                                                                  dp23_2[0][0]
# __________________________________________________________________________________________________
# dp13_2 (Dropout)                (None, 240, 240, 8)  0           conv13_2[0][0]
# __________________________________________________________________________________________________
# up14 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp23_2[0][0]
# __________________________________________________________________________________________________
# conv24_1 (Conv2D)               (None, 120, 120, 16) 9232        merge24[0][0]
# __________________________________________________________________________________________________
# merge14 (Concatenate)           (None, 240, 240, 32) 0           up14[0][0]
#                                                                  dp11_2[0][0]
#                                                                  dp12_2[0][0]
#                                                                  dp13_2[0][0]
# __________________________________________________________________________________________________
# dp24_1 (Dropout)                (None, 120, 120, 16) 0           conv24_1[0][0]
# __________________________________________________________________________________________________
# conv14_1 (Conv2D)               (None, 240, 240, 8)  2312        merge14[0][0]
# __________________________________________________________________________________________________
# conv24_2 (Conv2D)               (None, 120, 120, 16) 2320        dp24_1[0][0]
# __________________________________________________________________________________________________
# dp14_1 (Dropout)                (None, 240, 240, 8)  0           conv14_1[0][0]
# __________________________________________________________________________________________________
# dp24_2 (Dropout)                (None, 120, 120, 16) 0           conv24_2[0][0]
# __________________________________________________________________________________________________
# conv14_2 (Conv2D)               (None, 240, 240, 8)  584         dp14_1[0][0]
# __________________________________________________________________________________________________
# up15 (Conv2DTranspose)          (None, 240, 240, 8)  520         dp24_2[0][0]
# __________________________________________________________________________________________________
# dp14_2 (Dropout)                (None, 240, 240, 8)  0           conv14_2[0][0]
# __________________________________________________________________________________________________
# merge15 (Concatenate)           (None, 240, 240, 40) 0           up15[0][0]
#                                                                  dp11_2[0][0]
#                                                                  dp12_2[0][0]
#                                                                  dp13_2[0][0]
#                                                                  dp14_2[0][0]
# __________________________________________________________________________________________________
# conv15_1 (Conv2D)               (None, 240, 240, 8)  2888        merge15[0][0]
# __________________________________________________________________________________________________
# dp15_1 (Dropout)                (None, 240, 240, 8)  0           conv15_1[0][0]
# __________________________________________________________________________________________________
# conv15_2 (Conv2D)               (None, 240, 240, 8)  584         dp15_1[0][0]
# __________________________________________________________________________________________________
# dp15_2 (Dropout)                (None, 240, 240, 8)  0           conv15_2[0][0]
# __________________________________________________________________________________________________
# output_4 (Conv2D)               (None, 240, 240, 3)  27          dp15_2[0][0]
# ==================================================================================================
# Total params: 566,163
# Trainable params: 566,163
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:75: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("ma..., outputs=[<tf.Tenso...)`

# %%
import os
import cv2
import numpy as np

# %%
# Function to convert image from greyscale to one hot (i.e. 3 channels)
def convertToOneHot(image):
    num_classes = 3
    shape = image.shape[:2]+(num_classes,)
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c]==0:
          encoded_image[r][c][0] = 1
        elif image[r][c]==128:
          encoded_image[r][c][1] = 1
        else:
          encoded_image[r][c][2] = 1
    return encoded_image

# %%
# Function to convert back from one hot image to greyscale
def convertFromOneHot(image):
    shape = image.shape[:2]
    encoded_image = np.zeros(shape, dtype=np.uint8)
    for r in range(len(image)):
      for c in range(len(image[0])):
        if image[r][c][0] == 1:
          encoded_image[r][c] = 0
        elif image[r][c][1] == 1:
          encoded_image[r][c] = 128
        else:
          encoded_image[r][c] = 255
    return encoded_image

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/3 Class"

# Train set patients: 230 263 239 242 
TrainX_1 = np.load(PATH + '/ER IHC 239 Images.npy')
TrainY_1 = np.load(PATH + '/ER IHC 239 Masks.npy')
TrainX_2 = np.load(PATH + '/ER IHC 263 Images.npy')
TrainY_2 = np.load(PATH + '/ER IHC 263 Masks.npy')
TrainX_3 = np.load(PATH + '/ER IHC 242 Images.npy')
TrainY_3 = np.load(PATH + '/ER IHC 242 Masks.npy')
TrainX_4 = np.load(PATH + '/ER IHC 230 Images.npy')
TrainY_4 = np.load(PATH + '/ER IHC 230 Masks.npy')

# Test set patients: 221 246 232
TestX_1 = np.load(PATH + '/ER IHC 221 Images.npy')
TestY_1 = np.load(PATH + '/ER IHC 221 Masks.npy')
TestX_2 = np.load(PATH + '/ER IHC 246 Images.npy')
TestY_2 = np.load(PATH + '/ER IHC 246 Masks.npy')
TestX_3 = np.load(PATH + '/ER IHC 232 Images.npy')
TestY_3 = np.load(PATH + '/ER IHC 232 Masks.npy')

# %%
np.unique(TestY_3)
# Out:
# array([  0., 128., 255.])

# %%
TrainX = np.concatenate((TrainX_1, TrainX_2, TrainX_3, TrainX_4), axis=0)
TrainGroundTruth = np.concatenate((TrainY_1, TrainY_2, TrainY_3, TrainY_4), axis=0)
TrainY = []

for img in TrainGroundTruth:
  encoded_img = convertToOneHot(img)
  TrainY.append(encoded_img)

TrainY = np.asarray(TrainY)

TestX = np.concatenate((TestX_1, TestX_2, TestX_3), axis=0)
TestGroundTruth = np.concatenate((TestY_1, TestY_2, TestY_3), axis=0)
TestY = []

for img in TestGroundTruth:
  encoded_img = convertToOneHot(img)
  TestY.append(encoded_img)

TestY = np.asarray(TestY)

ValidX = TrainX[1800:, : ]
ValidY = TrainY[1800:, : ]

TrainX = TrainX[0:1800, : ]
TrainY = TrainY[0:1800, : ]

print(TrainX.shape)
print(TrainY.shape)
print(TestX.shape)
print(TestY.shape)
print(ValidX.shape)
print(ValidY.shape)
np.unique(TestY)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 3)
# (1440, 240, 240, 3)
# (1440, 240, 240, 3)
# (120, 240, 240, 3)
# (120, 240, 240, 3)
# array([0, 1], dtype=uint8)

# %%
TrainX = np.reshape(TrainX,(-1,240, 240,3))
TrainY = np.reshape(TrainY,(-1,240, 240,3))

TrainX = TrainX.astype('float32')/255

TestX = np.reshape(TestX,(-1,240, 240,3))
TestY = np.reshape(TestY,(-1,240, 240,3))

TestX = TestX.astype('float32')/255

ValidX = np.reshape(ValidX,(-1,240, 240,3))
ValidY = np.reshape(ValidY,(-1,240, 240,3))

ValidX = ValidX.astype('float32')/255

# %%
print(TrainX.shape)
print(TrainY.shape)

print(TestX.shape)
print(TestY.shape)

print(ValidX.shape)
print(ValidY.shape)

np.unique(TestY)
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240, 3)
# (1440, 240, 240, 3)
# (1440, 240, 240, 3)
# (120, 240, 240, 3)
# (120, 240, 240, 3)
# array([0, 1], dtype=uint8)

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)
  
def dice_loss(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    score = (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)
    return 1 - score

# %%
import math
from keras.callbacks import EarlyStopping,ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
mc = ModelCheckpoint('Checkpoint.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
def tversky_loss(y_true, y_pred):
    alpha = 0.5
    beta  = 0.5
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def combined_loss(y_true, y_pred):
  return (1*K.categorical_crossentropy(y_true, y_pred))+(0.5*tversky_loss(y_true, y_pred))

def loss(y_true, y_pred):
  return (1*K.categorical_crossentropy(y_true, y_pred))

def dice_loss(dice_coeff):
  return 1-dice_loss

# %%
optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=0.0001, decay=0.0, amsgrad=True)

# %%
model.compile(loss=tversky_loss, optimizer=optimizer, metrics=[dice_coef,'accuracy',tversky_loss, loss, combined_loss])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
TrainY.shape
# Out:
# (1800, 240, 240, 3)

# %%
num_epoch = 100;
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models"
history = model.fit(TrainX, TrainY, epochs=num_epoch, validation_data=(ValidX, ValidY), shuffle=True,batch_size=16,callbacks=[es,mc])
model.save(MODELS_PATH + '/NestedUNET_ER_20_03_18_v2.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 1800 samples, validate on 120 samples
# Epoch 1/100
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 1800/1800 [==============================] - 77s 43ms/step - loss: 2.0149 - dice_coef: 0.6676 - acc: 0.7005 - tversky_loss: 1.8692 - loss_1: 2.9282 - combined_loss: 3.8628 - val_loss: 2.9447 - val_dice_coef: 0.0883 - val_acc: 0.0957 - val_tversky_loss: 2.8373 - val_loss_1: 11.2483 - val_combined_loss: 12.6670
#
# Epoch 00001: val_loss improved from inf to 2.94475, saving model to Checkpoint.h5
# Epoch 2/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 1.2094 - dice_coef: 0.8845 - acc: 0.9050 - tversky_loss: 1.1239 - loss_1: 0.9163 - combined_loss: 1.4782 - val_loss: 2.8892 - val_dice_coef: 0.0982 - val_acc: 0.0989 - val_tversky_loss: 2.8201 - val_loss_1: 14.1459 - val_combined_loss: 15.5559
#
# Epoch 00002: val_loss improved from 2.94475 to 2.88923, saving model to Checkpoint.h5
# Epoch 3/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.9771 - dice_coef: 0.9060 - acc: 0.9177 - tversky_loss: 0.9121 - loss_1: 0.9974 - combined_loss: 1.4535 - val_loss: 2.2415 - val_dice_coef: 0.6722 - val_acc: 0.6722 - val_tversky_loss: 2.1795 - val_loss_1: 5.0994 - val_combined_loss: 6.1892
#
# Epoch 00003: val_loss improved from 2.88923 to 2.24150, saving model to Checkpoint.h5
# Epoch 4/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.8961 - dice_coef: 0.9147 - acc: 0.9228 - tversky_loss: 0.8380 - loss_1: 0.9895 - combined_loss: 1.4085 - val_loss: 2.0714 - val_dice_coef: 0.7874 - val_acc: 0.7874 - val_tversky_loss: 2.0161 - val_loss_1: 3.2631 - val_combined_loss: 4.2712
#
# Epoch 00004: val_loss improved from 2.24150 to 2.07142, saving model to Checkpoint.h5
# Epoch 5/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.8624 - dice_coef: 0.9184 - acc: 0.9247 - tversky_loss: 0.8070 - loss_1: 0.9771 - combined_loss: 1.3806 - val_loss: 2.2404 - val_dice_coef: 0.6163 - val_acc: 0.6163 - val_tversky_loss: 2.1860 - val_loss_1: 5.9803 - val_combined_loss: 7.0733
#
# Epoch 00005: val_loss did not improve from 2.07142
# Epoch 6/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.8391 - dice_coef: 0.9207 - acc: 0.9259 - tversky_loss: 0.7855 - loss_1: 0.9792 - combined_loss: 1.3720 - val_loss: 2.7410 - val_dice_coef: 0.1793 - val_acc: 0.1793 - val_tversky_loss: 2.6883 - val_loss_1: 13.1999 - val_combined_loss: 14.5441
#
# Epoch 00006: val_loss did not improve from 2.07142
# Epoch 7/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.8232 - dice_coef: 0.9227 - acc: 0.9271 - tversky_loss: 0.7719 - loss_1: 0.9703 - combined_loss: 1.3562 - val_loss: 2.6299 - val_dice_coef: 0.2605 - val_acc: 0.2605 - val_tversky_loss: 2.5796 - val_loss_1: 11.8524 - val_combined_loss: 13.1422
#
# Epoch 00007: val_loss did not improve from 2.07142
# Epoch 8/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.8118 - dice_coef: 0.9234 - acc: 0.9272 - tversky_loss: 0.7602 - loss_1: 0.9750 - combined_loss: 1.3551 - val_loss: 2.1103 - val_dice_coef: 0.7439 - val_acc: 0.7439 - val_tversky_loss: 2.0573 - val_loss_1: 4.0096 - val_combined_loss: 5.0383
#
# Epoch 00008: val_loss did not improve from 2.07142
# Epoch 9/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.8198 - dice_coef: 0.9236 - acc: 0.9271 - tversky_loss: 0.7683 - loss_1: 0.9898 - combined_loss: 1.3739 - val_loss: 1.7740 - val_dice_coef: 0.9709 - val_acc: 0.9709 - val_tversky_loss: 1.7238 - val_loss_1: 0.4663 - val_combined_loss: 1.3283
#
# Epoch 00009: val_loss improved from 2.07142 to 1.77400, saving model to Checkpoint.h5
# Epoch 10/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.8267 - dice_coef: 0.9228 - acc: 0.9259 - tversky_loss: 0.7757 - loss_1: 1.0082 - combined_loss: 1.3960 - val_loss: 1.6571 - val_dice_coef: 0.9786 - val_acc: 0.9786 - val_tversky_loss: 1.6062 - val_loss_1: 0.3424 - val_combined_loss: 1.1455
#
# Epoch 00010: val_loss improved from 1.77400 to 1.65706, saving model to Checkpoint.h5
# Epoch 11/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.7943 - dice_coef: 0.9260 - acc: 0.9288 - tversky_loss: 0.7437 - loss_1: 0.9708 - combined_loss: 1.3427 - val_loss: 2.1794 - val_dice_coef: 0.6700 - val_acc: 0.6700 - val_tversky_loss: 2.1296 - val_loss_1: 5.2601 - val_combined_loss: 6.3249
#
# Epoch 00011: val_loss did not improve from 1.65706
# Epoch 12/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7839 - dice_coef: 0.9267 - acc: 0.9292 - tversky_loss: 0.7347 - loss_1: 0.9709 - combined_loss: 1.3383 - val_loss: 2.4039 - val_dice_coef: 0.4629 - val_acc: 0.4629 - val_tversky_loss: 2.3554 - val_loss_1: 8.6060 - val_combined_loss: 9.7837
#
# Epoch 00012: val_loss did not improve from 1.65706
# Epoch 13/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7987 - dice_coef: 0.9265 - acc: 0.9290 - tversky_loss: 0.7506 - loss_1: 0.9771 - combined_loss: 1.3523 - val_loss: 2.4370 - val_dice_coef: 0.4284 - val_acc: 0.4284 - val_tversky_loss: 2.3889 - val_loss_1: 9.1564 - val_combined_loss: 10.3509
#
# Epoch 00013: val_loss did not improve from 1.65706
# Epoch 14/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7746 - dice_coef: 0.9276 - acc: 0.9299 - tversky_loss: 0.7269 - loss_1: 0.9674 - combined_loss: 1.3309 - val_loss: 2.0137 - val_dice_coef: 0.7986 - val_acc: 0.7986 - val_tversky_loss: 1.9666 - val_loss_1: 3.2137 - val_combined_loss: 4.1970
#
# Epoch 00014: val_loss did not improve from 1.65706
# Epoch 15/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7793 - dice_coef: 0.9273 - acc: 0.9294 - tversky_loss: 0.7317 - loss_1: 0.9758 - combined_loss: 1.3416 - val_loss: 2.5086 - val_dice_coef: 0.3696 - val_acc: 0.3696 - val_tversky_loss: 2.4600 - val_loss_1: 10.0910 - val_combined_loss: 11.3209
#
# Epoch 00015: val_loss did not improve from 1.65706
# Epoch 16/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7723 - dice_coef: 0.9270 - acc: 0.9290 - tversky_loss: 0.7237 - loss_1: 0.9846 - combined_loss: 1.3464 - val_loss: 1.8961 - val_dice_coef: 0.8830 - val_acc: 0.8830 - val_tversky_loss: 1.8482 - val_loss_1: 1.8546 - val_combined_loss: 2.7787
#
# Epoch 00016: val_loss did not improve from 1.65706
# Epoch 17/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.7626 - dice_coef: 0.9284 - acc: 0.9305 - tversky_loss: 0.7142 - loss_1: 0.9679 - combined_loss: 1.3250 - val_loss: 2.3143 - val_dice_coef: 0.5454 - val_acc: 0.5454 - val_tversky_loss: 2.2651 - val_loss_1: 7.2679 - val_combined_loss: 8.4005
#
# Epoch 00017: val_loss did not improve from 1.65706
# Epoch 18/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7557 - dice_coef: 0.9286 - acc: 0.9305 - tversky_loss: 0.7061 - loss_1: 0.9701 - combined_loss: 1.3232 - val_loss: 1.8778 - val_dice_coef: 0.8965 - val_acc: 0.8965 - val_tversky_loss: 1.8284 - val_loss_1: 1.6343 - val_combined_loss: 2.5485
#
# Epoch 00018: val_loss did not improve from 1.65706
# Epoch 19/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7618 - dice_coef: 0.9294 - acc: 0.9312 - tversky_loss: 0.7131 - loss_1: 0.9621 - combined_loss: 1.3186 - val_loss: 2.1045 - val_dice_coef: 0.7191 - val_acc: 0.7191 - val_tversky_loss: 2.0554 - val_loss_1: 4.4599 - val_combined_loss: 5.4876
#
# Epoch 00019: val_loss did not improve from 1.65706
# Epoch 20/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7824 - dice_coef: 0.9270 - acc: 0.9286 - tversky_loss: 0.7324 - loss_1: 1.0014 - combined_loss: 1.3676 - val_loss: 1.4954 - val_dice_coef: 0.9873 - val_acc: 0.9873 - val_tversky_loss: 1.4448 - val_loss_1: 0.2022 - val_combined_loss: 0.9246
#
# Epoch 00020: val_loss improved from 1.65706 to 1.49539, saving model to Checkpoint.h5
# Epoch 21/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7983 - dice_coef: 0.9272 - acc: 0.9289 - tversky_loss: 0.7465 - loss_1: 0.9973 - combined_loss: 1.3706 - val_loss: 1.8058 - val_dice_coef: 0.9275 - val_acc: 0.9275 - val_tversky_loss: 1.7525 - val_loss_1: 1.1483 - val_combined_loss: 2.0245
#
# Epoch 00021: val_loss did not improve from 1.49539
# Epoch 22/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7673 - dice_coef: 0.9297 - acc: 0.9314 - tversky_loss: 0.7147 - loss_1: 0.9649 - combined_loss: 1.3222 - val_loss: 1.8955 - val_dice_coef: 0.8836 - val_acc: 0.8836 - val_tversky_loss: 1.8439 - val_loss_1: 1.8528 - val_combined_loss: 2.7747
#
# Epoch 00022: val_loss did not improve from 1.49539
# Epoch 23/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7823 - dice_coef: 0.9285 - acc: 0.9301 - tversky_loss: 0.7318 - loss_1: 0.9851 - combined_loss: 1.3510 - val_loss: 1.8253 - val_dice_coef: 0.9232 - val_acc: 0.9232 - val_tversky_loss: 1.7757 - val_loss_1: 1.2158 - val_combined_loss: 2.1036
#
# Epoch 00023: val_loss did not improve from 1.49539
# Epoch 24/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.7640 - dice_coef: 0.9289 - acc: 0.9305 - tversky_loss: 0.7148 - loss_1: 0.9796 - combined_loss: 1.3370 - val_loss: 1.6791 - val_dice_coef: 0.9616 - val_acc: 0.9616 - val_tversky_loss: 1.6307 - val_loss_1: 0.6059 - val_combined_loss: 1.4212
#
# Epoch 00024: val_loss did not improve from 1.49539
# Epoch 25/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.7411 - dice_coef: 0.9313 - acc: 0.9330 - tversky_loss: 0.6928 - loss_1: 0.9469 - combined_loss: 1.2933 - val_loss: 2.5778 - val_dice_coef: 0.3021 - val_acc: 0.3021 - val_tversky_loss: 2.5296 - val_loss_1: 11.2023 - val_combined_loss: 12.4671
#
# Epoch 00025: val_loss did not improve from 1.49539
# Epoch 26/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.7533 - dice_coef: 0.9293 - acc: 0.9309 - tversky_loss: 0.7054 - loss_1: 0.9741 - combined_loss: 1.3268 - val_loss: 1.6329 - val_dice_coef: 0.9731 - val_acc: 0.9731 - val_tversky_loss: 1.5851 - val_loss_1: 0.4232 - val_combined_loss: 1.2158
#
# Epoch 00026: val_loss did not improve from 1.49539
# Epoch 27/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7465 - dice_coef: 0.9301 - acc: 0.9316 - tversky_loss: 0.6990 - loss_1: 0.9677 - combined_loss: 1.3172 - val_loss: 1.7376 - val_dice_coef: 0.9550 - val_acc: 0.9550 - val_tversky_loss: 1.6903 - val_loss_1: 0.7138 - val_combined_loss: 1.5590
#
# Epoch 00027: val_loss did not improve from 1.49539
# Epoch 28/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.7326 - dice_coef: 0.9320 - acc: 0.9335 - tversky_loss: 0.6857 - loss_1: 0.9419 - combined_loss: 1.2848 - val_loss: 1.5349 - val_dice_coef: 0.9850 - val_acc: 0.9850 - val_tversky_loss: 1.4881 - val_loss_1: 0.2381 - val_combined_loss: 0.9822
#
# Epoch 00028: val_loss did not improve from 1.49539
# Epoch 29/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.7431 - dice_coef: 0.9299 - acc: 0.9314 - tversky_loss: 0.6963 - loss_1: 0.9719 - combined_loss: 1.3201 - val_loss: 1.6552 - val_dice_coef: 0.9744 - val_acc: 0.9744 - val_tversky_loss: 1.6085 - val_loss_1: 0.4064 - val_combined_loss: 1.2107
#
# Epoch 00029: val_loss did not improve from 1.49539
# Epoch 30/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7322 - dice_coef: 0.9310 - acc: 0.9326 - tversky_loss: 0.6855 - loss_1: 0.9580 - combined_loss: 1.3007 - val_loss: 1.5543 - val_dice_coef: 0.9845 - val_acc: 0.9845 - val_tversky_loss: 1.5078 - val_loss_1: 0.2432 - val_combined_loss: 0.9971
#
# Epoch 00030: val_loss did not improve from 1.49539
# Epoch 31/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7599 - dice_coef: 0.9299 - acc: 0.9314 - tversky_loss: 0.7130 - loss_1: 0.9766 - combined_loss: 1.3331 - val_loss: 1.5230 - val_dice_coef: 0.9873 - val_acc: 0.9873 - val_tversky_loss: 1.4760 - val_loss_1: 0.2012 - val_combined_loss: 0.9392
#
# Epoch 00031: val_loss did not improve from 1.49539
# Epoch 32/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.7332 - dice_coef: 0.9313 - acc: 0.9327 - tversky_loss: 0.6867 - loss_1: 0.9577 - combined_loss: 1.3010 - val_loss: 1.6969 - val_dice_coef: 0.9891 - val_acc: 0.9891 - val_tversky_loss: 1.6505 - val_loss_1: 0.1747 - val_combined_loss: 1.0000
#
# Epoch 00032: val_loss did not improve from 1.49539
# Epoch 33/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.7508 - dice_coef: 0.9304 - acc: 0.9319 - tversky_loss: 0.7046 - loss_1: 0.9720 - combined_loss: 1.3243 - val_loss: 1.6442 - val_dice_coef: 0.9722 - val_acc: 0.9722 - val_tversky_loss: 1.5980 - val_loss_1: 0.4367 - val_combined_loss: 1.2357
#
# Epoch 00033: val_loss did not improve from 1.49539
# Epoch 34/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7445 - dice_coef: 0.9305 - acc: 0.9322 - tversky_loss: 0.6979 - loss_1: 0.9696 - combined_loss: 1.3185 - val_loss: 1.4944 - val_dice_coef: 0.9886 - val_acc: 0.9886 - val_tversky_loss: 1.4473 - val_loss_1: 0.1806 - val_combined_loss: 0.9043
#
# Epoch 00034: val_loss improved from 1.49539 to 1.49439, saving model to Checkpoint.h5
# Epoch 35/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7510 - dice_coef: 0.9310 - acc: 0.9326 - tversky_loss: 0.7043 - loss_1: 0.9637 - combined_loss: 1.3158 - val_loss: 1.6267 - val_dice_coef: 0.9741 - val_acc: 0.9741 - val_tversky_loss: 1.5807 - val_loss_1: 0.4106 - val_combined_loss: 1.2010
#
# Epoch 00035: val_loss did not improve from 1.49439
# Epoch 36/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7344 - dice_coef: 0.9301 - acc: 0.9316 - tversky_loss: 0.6889 - loss_1: 0.9822 - combined_loss: 1.3266 - val_loss: 1.6622 - val_dice_coef: 0.9896 - val_acc: 0.9896 - val_tversky_loss: 1.6170 - val_loss_1: 0.1671 - val_combined_loss: 0.9755
#
# Epoch 00036: val_loss did not improve from 1.49439
# Epoch 37/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7738 - dice_coef: 0.9292 - acc: 0.9306 - tversky_loss: 0.7274 - loss_1: 0.9936 - combined_loss: 1.3573 - val_loss: 1.5279 - val_dice_coef: 0.9883 - val_acc: 0.9883 - val_tversky_loss: 1.4808 - val_loss_1: 0.1863 - val_combined_loss: 0.9267
#
# Epoch 00037: val_loss did not improve from 1.49439
# Epoch 38/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7801 - dice_coef: 0.9291 - acc: 0.9306 - tversky_loss: 0.7332 - loss_1: 0.9949 - combined_loss: 1.3615 - val_loss: 1.5622 - val_dice_coef: 0.9812 - val_acc: 0.9812 - val_tversky_loss: 1.5158 - val_loss_1: 0.2997 - val_combined_loss: 1.0576
#
# Epoch 00038: val_loss did not improve from 1.49439
# Epoch 39/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7361 - dice_coef: 0.9309 - acc: 0.9323 - tversky_loss: 0.6904 - loss_1: 0.9721 - combined_loss: 1.3173 - val_loss: 1.6667 - val_dice_coef: 0.9895 - val_acc: 0.9895 - val_tversky_loss: 1.6212 - val_loss_1: 0.1677 - val_combined_loss: 0.9783
#
# Epoch 00039: val_loss did not improve from 1.49439
# Epoch 40/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7599 - dice_coef: 0.9287 - acc: 0.9301 - tversky_loss: 0.7144 - loss_1: 1.0049 - combined_loss: 1.3621 - val_loss: 1.5669 - val_dice_coef: 0.9879 - val_acc: 0.9879 - val_tversky_loss: 1.5212 - val_loss_1: 0.1938 - val_combined_loss: 0.9544
#
# Epoch 00040: val_loss did not improve from 1.49439
# Epoch 41/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.7422 - dice_coef: 0.9309 - acc: 0.9323 - tversky_loss: 0.6968 - loss_1: 0.9735 - combined_loss: 1.3218 - val_loss: 1.5435 - val_dice_coef: 0.9886 - val_acc: 0.9886 - val_tversky_loss: 1.4984 - val_loss_1: 0.1826 - val_combined_loss: 0.9318
#
# Epoch 00041: val_loss did not improve from 1.49439
# Epoch 42/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.7137 - dice_coef: 0.9327 - acc: 0.9341 - tversky_loss: 0.6689 - loss_1: 0.9467 - combined_loss: 1.2812 - val_loss: 1.6254 - val_dice_coef: 0.9898 - val_acc: 0.9898 - val_tversky_loss: 1.5802 - val_loss_1: 0.1634 - val_combined_loss: 0.9535
#
# Epoch 00042: val_loss did not improve from 1.49439
# Epoch 43/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7278 - dice_coef: 0.9317 - acc: 0.9331 - tversky_loss: 0.6824 - loss_1: 0.9625 - combined_loss: 1.3037 - val_loss: 1.5588 - val_dice_coef: 0.9828 - val_acc: 0.9828 - val_tversky_loss: 1.5133 - val_loss_1: 0.2729 - val_combined_loss: 1.0296
#
# Epoch 00043: val_loss did not improve from 1.49439
# Epoch 44/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7318 - dice_coef: 0.9321 - acc: 0.9335 - tversky_loss: 0.6862 - loss_1: 0.9568 - combined_loss: 1.2999 - val_loss: 1.4998 - val_dice_coef: 0.9864 - val_acc: 0.9864 - val_tversky_loss: 1.4546 - val_loss_1: 0.2152 - val_combined_loss: 0.9424
#
# Epoch 00044: val_loss did not improve from 1.49439
# Epoch 45/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.7529 - dice_coef: 0.9305 - acc: 0.9319 - tversky_loss: 0.7080 - loss_1: 0.9819 - combined_loss: 1.3359 - val_loss: 1.8575 - val_dice_coef: 0.9161 - val_acc: 0.9161 - val_tversky_loss: 1.8125 - val_loss_1: 1.3331 - val_combined_loss: 2.2394
#
# Epoch 00045: val_loss did not improve from 1.49439
# Epoch 46/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.7517 - dice_coef: 0.9293 - acc: 0.9306 - tversky_loss: 0.7067 - loss_1: 0.9995 - combined_loss: 1.3528 - val_loss: 1.6709 - val_dice_coef: 0.9902 - val_acc: 0.9902 - val_tversky_loss: 1.6262 - val_loss_1: 0.1570 - val_combined_loss: 0.9701
#
# Epoch 00046: val_loss did not improve from 1.49439
# Epoch 47/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.7653 - dice_coef: 0.9300 - acc: 0.9313 - tversky_loss: 0.7207 - loss_1: 0.9894 - combined_loss: 1.3498 - val_loss: 1.5373 - val_dice_coef: 0.9901 - val_acc: 0.9901 - val_tversky_loss: 1.4931 - val_loss_1: 0.1585 - val_combined_loss: 0.9051
#
# Epoch 00047: val_loss did not improve from 1.49439
# Epoch 48/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7196 - dice_coef: 0.9321 - acc: 0.9334 - tversky_loss: 0.6757 - loss_1: 0.9608 - combined_loss: 1.2986 - val_loss: 1.6163 - val_dice_coef: 0.9893 - val_acc: 0.9893 - val_tversky_loss: 1.5725 - val_loss_1: 0.1715 - val_combined_loss: 0.9578
#
# Epoch 00048: val_loss did not improve from 1.49439
# Epoch 49/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7762 - dice_coef: 0.9275 - acc: 0.9287 - tversky_loss: 0.7326 - loss_1: 1.0335 - combined_loss: 1.3998 - val_loss: 1.5471 - val_dice_coef: 0.9867 - val_acc: 0.9867 - val_tversky_loss: 1.5036 - val_loss_1: 0.2114 - val_combined_loss: 0.9632
#
# Epoch 00049: val_loss did not improve from 1.49439
# Epoch 50/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7325 - dice_coef: 0.9326 - acc: 0.9338 - tversky_loss: 0.6892 - loss_1: 0.9518 - combined_loss: 1.2964 - val_loss: 1.6760 - val_dice_coef: 0.9895 - val_acc: 0.9895 - val_tversky_loss: 1.6329 - val_loss_1: 0.1687 - val_combined_loss: 0.9851
#
# Epoch 00050: val_loss did not improve from 1.49439
# Epoch 51/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7075 - dice_coef: 0.9334 - acc: 0.9346 - tversky_loss: 0.6646 - loss_1: 0.9423 - combined_loss: 1.2746 - val_loss: 1.5616 - val_dice_coef: 0.9873 - val_acc: 0.9873 - val_tversky_loss: 1.5184 - val_loss_1: 0.2013 - val_combined_loss: 0.9605
#
# Epoch 00051: val_loss did not improve from 1.49439
# Epoch 52/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7213 - dice_coef: 0.9317 - acc: 0.9329 - tversky_loss: 0.6777 - loss_1: 0.9666 - combined_loss: 1.3055 - val_loss: 1.5663 - val_dice_coef: 0.9866 - val_acc: 0.9866 - val_tversky_loss: 1.5220 - val_loss_1: 0.2122 - val_combined_loss: 0.9732
#
# Epoch 00052: val_loss did not improve from 1.49439
# Epoch 53/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7264 - dice_coef: 0.9327 - acc: 0.9339 - tversky_loss: 0.6824 - loss_1: 0.9537 - combined_loss: 1.2949 - val_loss: 1.6268 - val_dice_coef: 0.9864 - val_acc: 0.9864 - val_tversky_loss: 1.5826 - val_loss_1: 0.2162 - val_combined_loss: 1.0075
#
# Epoch 00053: val_loss did not improve from 1.49439
# Epoch 54/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7491 - dice_coef: 0.9308 - acc: 0.9319 - tversky_loss: 0.7049 - loss_1: 0.9812 - combined_loss: 1.3336 - val_loss: 1.5333 - val_dice_coef: 0.9886 - val_acc: 0.9886 - val_tversky_loss: 1.4890 - val_loss_1: 0.1815 - val_combined_loss: 0.9260
#
# Epoch 00054: val_loss did not improve from 1.49439
# Epoch 55/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7168 - dice_coef: 0.9329 - acc: 0.9341 - tversky_loss: 0.6723 - loss_1: 0.9495 - combined_loss: 1.2856 - val_loss: 1.5084 - val_dice_coef: 0.9885 - val_acc: 0.9885 - val_tversky_loss: 1.4638 - val_loss_1: 0.1820 - val_combined_loss: 0.9139
#
# Epoch 00055: val_loss did not improve from 1.49439
# Epoch 56/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7179 - dice_coef: 0.9334 - acc: 0.9345 - tversky_loss: 0.6733 - loss_1: 0.9437 - combined_loss: 1.2804 - val_loss: 1.5685 - val_dice_coef: 0.9896 - val_acc: 0.9896 - val_tversky_loss: 1.5242 - val_loss_1: 0.1656 - val_combined_loss: 0.9277
#
# Epoch 00056: val_loss did not improve from 1.49439
# Epoch 57/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7275 - dice_coef: 0.9320 - acc: 0.9331 - tversky_loss: 0.6834 - loss_1: 0.9655 - combined_loss: 1.3072 - val_loss: 1.6626 - val_dice_coef: 0.9682 - val_acc: 0.9682 - val_tversky_loss: 1.6187 - val_loss_1: 0.5019 - val_combined_loss: 1.3113
#
# Epoch 00057: val_loss did not improve from 1.49439
# Epoch 58/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7265 - dice_coef: 0.9316 - acc: 0.9327 - tversky_loss: 0.6829 - loss_1: 0.9741 - combined_loss: 1.3156 - val_loss: 1.5550 - val_dice_coef: 0.9846 - val_acc: 0.9846 - val_tversky_loss: 1.5116 - val_loss_1: 0.2429 - val_combined_loss: 0.9987
#
# Epoch 00058: val_loss did not improve from 1.49439
# Epoch 59/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.7323 - dice_coef: 0.9325 - acc: 0.9336 - tversky_loss: 0.6890 - loss_1: 0.9593 - combined_loss: 1.3038 - val_loss: 1.5071 - val_dice_coef: 0.9868 - val_acc: 0.9868 - val_tversky_loss: 1.4642 - val_loss_1: 0.2086 - val_combined_loss: 0.9406
#
# Epoch 00059: val_loss did not improve from 1.49439
# Epoch 60/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.7231 - dice_coef: 0.9324 - acc: 0.9335 - tversky_loss: 0.6806 - loss_1: 0.9596 - combined_loss: 1.2999 - val_loss: 1.6235 - val_dice_coef: 0.9894 - val_acc: 0.9894 - val_tversky_loss: 1.5811 - val_loss_1: 0.1702 - val_combined_loss: 0.9608
#
# Epoch 00060: val_loss did not improve from 1.49439
# Epoch 61/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.7181 - dice_coef: 0.9329 - acc: 0.9340 - tversky_loss: 0.6757 - loss_1: 0.9507 - combined_loss: 1.2886 - val_loss: 1.5419 - val_dice_coef: 0.9837 - val_acc: 0.9837 - val_tversky_loss: 1.4996 - val_loss_1: 0.2571 - val_combined_loss: 1.0069
#
# Epoch 00061: val_loss did not improve from 1.49439
# Epoch 62/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.6982 - dice_coef: 0.9337 - acc: 0.9348 - tversky_loss: 0.6559 - loss_1: 0.9427 - combined_loss: 1.2707 - val_loss: 1.5316 - val_dice_coef: 0.9857 - val_acc: 0.9857 - val_tversky_loss: 1.4892 - val_loss_1: 0.2258 - val_combined_loss: 0.9704
#
# Epoch 00062: val_loss did not improve from 1.49439
# Epoch 63/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.7202 - dice_coef: 0.9327 - acc: 0.9337 - tversky_loss: 0.6777 - loss_1: 0.9567 - combined_loss: 1.2955 - val_loss: 1.5473 - val_dice_coef: 0.9897 - val_acc: 0.9897 - val_tversky_loss: 1.5047 - val_loss_1: 0.1632 - val_combined_loss: 0.9155
#
# Epoch 00063: val_loss did not improve from 1.49439
# Epoch 64/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.7206 - dice_coef: 0.9331 - acc: 0.9341 - tversky_loss: 0.6781 - loss_1: 0.9506 - combined_loss: 1.2897 - val_loss: 1.5612 - val_dice_coef: 0.9814 - val_acc: 0.9814 - val_tversky_loss: 1.5184 - val_loss_1: 0.2914 - val_combined_loss: 1.0506
#
# Epoch 00064: val_loss did not improve from 1.49439
# Epoch 00064: early stopping

# %%
train_loss = history.history['loss']
train_acc = history.history['acc']
val_loss = history.history['val_loss']
val_acc = history.history['val_acc']
xc=range(len(train_loss))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_loss)
plt.plot(xc, val_loss)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(['train','val'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc, train_acc)
plt.plot(xc, val_acc)
plt.xlabel("Epoch")
plt.ylabel("Acc")
plt.legend(['train','val'])

# %%
# MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models"
# model = keras.models.load_model(MODELS_PATH+'/UNET_ER_20_03_03_v5.h5',custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

# %%
# Function to find the most probable class of an image pixel by pixel
def ClassFinder(img):
  result = np.zeros(img.shape, dtype=np.uint8)
  for r in range(len(img)):
    for c in range(len(img[0])):
      idx = np.argmax(img[r][c])
      result[r][c][idx]=1
      
  return result

# %%
train_result = model.predict(TrainX, batch_size=16)
print(np.shape(train_result))
Train_predict = [ ]
for img in train_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_predict.append(encoded_img)

Predicted_images = np.asarray(Train_predict)
print(Predicted_images.shape)
np.unique(Predicted_images)
# dice = dc(train_result, TrainY)
# pre  = precision(train_result,TrainY)
# re   = recall(train_result,TrainY)
# print('Train dc: '  + str(dice))
# print('Train pre: ' + str(pre))
# print('Train re: '  + str(re))
# Out:
# (1800, 240, 240, 3)
# (1800, 240, 240)
# array([  0, 128, 255], dtype=uint8)

# %%
test_result = model.predict(TestX, batch_size=16)
print(np.shape(test_result))

Test_predict = [ ]
for img in test_result:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_predict.append(encoded_img)

Predicted_images_test = np.asarray(Test_predict)
print(Predicted_images_test.shape)
np.unique(Predicted_images_test)
# dice = dc(test_result, TestY)
# pre  = precision(test_result,TestY)
# re   = recall(test_result,TestY)
# print('Test dc: '  + str(dice))
# print('Test pre: ' + str(pre))
# print('Test re: '  + str(re))
# Out:
# (1440, 240, 240, 3)
# (1440, 240, 240)
# array([  0, 128, 255], dtype=uint8)

# %%
from sklearn.metrics import confusion_matrix
def get_confusion_matrix(Actual, Predicted):
  ActualY = np.reshape(Actual,(-1, Actual.shape[3]))
  PredY = np.reshape(Predicted,(-1, Predicted.shape[3]))
  matrix = confusion_matrix(ActualY.argmax(axis = 1), PredY.argmax(axis = 1))
  return matrix

def get_precision(confusion_matrix):
  precision = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 0)
  nan_indices = np.isnan(precision)
  precision[nan_indices] = 0
  return precision

def get_recall(confusion_matrix):
  recall = np.diag(confusion_matrix) / np.sum(confusion_matrix, axis = 1)
  nan_indices = np.isnan(recall)
  recall[nan_indices] = 0
  return recall

# %%
test_matrix = get_confusion_matrix(TestY, test_result)
train_matrix = get_confusion_matrix(TrainY, train_result)
print(test_matrix)
print(train_matrix)
# TestY.shape[3]
# test_result.shape
# Out:
# [[74216221  1836503   513801]
#  [  229224  2503984   628082]
#  [   99445   336475  2580265]]
# [[67190034 16813321  4962058]
#  [  287044  2646248  2789623]
#  [  188108   324523  8479041]]

# %%
np.unique(Predicted_images_test)
# Out:
# array([  0, 128, 255], dtype=uint8)

# %%
test_precision = get_precision(test_matrix)
print('Test Precision')
print(test_precision)
test_recall = get_recall(test_matrix)
print('Test Recall')
print(test_recall)
train_precision = get_precision(train_matrix)
print('Train Precision')
print(train_precision)
train_recall = get_recall(train_matrix)
print('Train Recall')
print(train_recall)
# Out:
# Test Precision
# [0.99559099 0.53538686 0.69321935]
# Test Recall
# [0.96930377 0.74494733 0.85547306]
# Train Precision
# [0.9929779  0.13375635 0.52240689]
# Train Recall
# [0.7552377  0.46239513 0.94298825]

# %%
# weight_matrix = np.zeros((3,1))
# weight_matrix[0] = 0.6
# weight_matrix[1] = 0.2
# weight_matrix[2] = 0.2
# print(weight_matrix.shape)

# %%
weight_matrix = np.zeros((3,1))
weight_matrix[0] = 1/3
weight_matrix[1] = 1/3
weight_matrix[2] = 1/3
print(weight_matrix.shape)
# Out:
# (3, 1)

# %%
def get_overall_precision(precision, weights):
  final_precision = np.dot(precision,weights)
  return final_precision

def get_overall_recall(recall, weights):
  final_recall = np.dot(recall ,weights)
  return final_recall

# %%
final_test_precision  = get_overall_precision(test_precision, weight_matrix)
final_test_recall     = get_overall_recall(test_recall, weight_matrix)
final_train_precision = get_overall_precision(train_precision, weight_matrix)
final_train_recall    = get_overall_recall(train_recall, weight_matrix)
print('Final Test Precision')
print(final_test_precision)
print('Final Test Recall')
print(final_test_recall)
print('Final Train Precision')
print(final_train_precision)
print('Final Train Recall')
print(final_train_recall)
# Out:
# Final Test Precision
# [0.74139907]
# Final Test Recall
# [0.85657472]
# Final Train Precision
# [0.54971371]
# Final Train Recall
# [0.72020702]

# %%
from scipy.stats import hmean

def dice_coefficient(precision, recall):
  return hmean(np.asarray([precision , recall]))

# %%
test_dice_coeff = dice_coefficient(final_test_precision, final_test_recall)
print('Test Dice coeff')
print(test_dice_coeff)

train_dice_coeff = dice_coefficient(final_train_precision, final_train_recall)
print('Train Dice coeff')
print(train_dice_coeff)
# Out:
# Test Dice coeff
# [0.79483619]
# Train Dice coeff
# [0.62351557]

# %%
copy1  = np.copy(TestX [250])
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
copy3 = np.reshape(copy2,(240, 240,3))
Img = cv2.cvtColor(copy3,cv2.COLOR_BGR2RGB)

Mask = TestGroundTruth[250]

Predicted_Mask = Predicted_images_test[250] 

plt.subplot(131).imshow(Img)
plt.subplot(132).imshow(Mask,'gray')
plt.subplot(133).imshow(Predicted_Mask,'gray')

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask):
  num = mask.shape[0]/480
  for id in range(int(num)):
    temp = []
    for i in range(id, id+10):
      idx = i * 48
      final_output = mask[idx:idx+48]
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save("/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/Combined_Loss/ER1 Patient " + str(id), final_output)

# %%
# saving predicted outputs as numpy arrays for test images
saveNumpyOutput(Predicted_images)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 23   # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]

Mask_input = TestY[id:id+48]
Test_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Test_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Test_Actual)
print(Mask_input.shape)

final_output = Predicted_images_test[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 3)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0. 128. 255.]

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 19  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]

Mask_input = TrainY[id:id+48]
Train_Actual = [ ]
for img in Mask_input:
  img = ClassFinder(img)
  encoded_img = convertFromOneHot(img)
  Train_Actual.append(encoded_img)
  
print(Mask_input.shape)
Mask_input = np.asarray(Train_Actual)
print(Mask_input.shape)

final_output = Predicted_images[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
# Out:
# (48, 240, 240, 3)
# (48, 240, 240)
# (1440, 1920, 3)
# (1440, 1920)
# (1440, 1920)
# [  0. 128. 255.]
