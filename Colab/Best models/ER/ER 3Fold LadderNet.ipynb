# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import cv2
import numpy as np
# !pip install -U keras
# !pip install tensorflow-gpu==2.1.0rc0
# Out:
# Requirement already up-to-date: keras in /usr/local/lib/python3.6/dist-packages (2.3.1)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras) (1.0.8)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)
# Requirement already satisfied, skipping upgrade: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.4.1)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras) (1.12.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.18.5)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.10.0)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras) (1.1.2)
# Requirement already satisfied: tensorflow-gpu==2.1.0rc0 in /usr/local/lib/python3.6/dist-packages (2.1.0rc0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (3.10.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.2.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.0.8)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.8.1)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.2.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.29.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (3.2.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.1.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.18.5)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.12.1)
# Requirement already satisfied: tensorflow-estimator<2.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (2.0.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.12.0)
# Requirement already satisfied: tensorboard<2.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (2.0.2)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.34.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.9.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorflow-gpu==2.1.0rc0) (47.1.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==2.1.0rc0) (2.10.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.2.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.7.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.6.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.3.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2020.4.5.1)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.1)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.2.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.4.8)

# %%
import math
import random
import keras
from keras.layers import *
from keras.models import Sequential
from keras import Model
from keras import backend as K  
from keras.regularizers import l2
from keras.callbacks import EarlyStopping,ModelCheckpoint

from sklearn.model_selection import LeaveOneOut
from sklearn import metrics
# Out:
# Using TensorFlow backend.

# %%
def get_conv_block(input_layer,nFilters,size):
    conv1 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(input_layer)
    bn1 = BatchNormalization()(conv1)
    conv2 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(bn1)
    bn2 = BatchNormalization()(conv2)
    return bn2
    
def get_UNET(input_layer,nFilters,flag): 

    block1 = get_conv_block(input_layer[0],nFilters,3)
    mp1 = MaxPooling2D(pool_size=(2, 2))(block1)
    dr1 = Dropout(0.1)(mp1)
   
    if(flag==1):
      dr1 = concatenate([dr1,input_layer[1]])

    block2 = get_conv_block(dr1,nFilters*2,3)
    mp2 = MaxPooling2D(pool_size=(2, 2))(block2)
    dr2 = Dropout(0.1)(mp2)

    if(flag==1):
      dr2 = concatenate([dr2,input_layer[2]])
   
    block3 = get_conv_block(dr2,nFilters*4,3)
    mp3 = MaxPooling2D(pool_size=(2, 2))(block3)
    dr3 = Dropout(0.1)(mp3)

    if(flag==1):
      dr3 = concatenate([dr3,input_layer[3]])
       
    block4 = get_conv_block(dr3,nFilters*8,3)
    mp4 = MaxPooling2D(pool_size=(2, 2))(block4)
    dr4 = Dropout(0.1)(mp4)

    conv5 = Conv2D(nFilters*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(dr4)
    conv5 = Conv2D(nFilters*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(conv5)

    up1 = Conv2DTranspose(nFilters*8,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(conv5)
    cat1 = concatenate([block4, up1, mp3])
    dr1 = Dropout(0.1)(cat1)
    block5 = get_conv_block(dr1,nFilters*8,3)

    up2 = Conv2DTranspose(nFilters*4,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block5)
    b4_upsample = Conv2DTranspose(nFilters*4,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block4)
    cat2 = concatenate([block3, up2, b4_upsample, mp2])
    dr2 = Dropout(0.1)(cat2)
    block6 = get_conv_block(dr2,nFilters*4,3)
    
    up3 = Conv2DTranspose(nFilters*2,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block6)
    b3_upsample = Conv2DTranspose(nFilters*2,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block3)
    cat3 = concatenate([block2, up3, mp1, b3_upsample])
    dr3 = Dropout(0.1)(cat3)
    block7 = get_conv_block(dr3,nFilters*2,3)
    
    up4 = Conv2DTranspose(nFilters,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block7)
    b2_upsample = Conv2DTranspose(nFilters,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block2)
    cat4 = concatenate([block1, up4, b2_upsample])
    dr4 = Dropout(0.1)(cat4)
    block8 = get_conv_block(dr4,nFilters,3)

    conv10 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(block8)
    conv11 = Conv2D(4,(1,1), activation='softmax', padding = 'same',kernel_regularizer=l2(1e-4))(conv10)

    return (conv11, block7, block6, block5)

def get_model(input_shape,nFilters1,nFilters2):

    input_layer = Input(shape=input_shape)
    out1,out2,out3,out4 = get_UNET([input_layer],nFilters1,0)

    out1,out2,out3,out4 = get_UNET([out1,out2,out3,out4],nFilters2,1)

    model = Model(input_layer,out1)
    return model

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/4 Class ER"

# Loading the data patient wise
X1 = np.load(PATH + '/ER IHC 230 Images.npy')
Y1 = np.load(PATH + '/ER IHC 230 Masks.npy')

X2 = np.load(PATH + '/ER IHC 232 Images.npy')
Y2 = np.load(PATH + '/ER IHC 232 Masks.npy')

X3 = np.load(PATH + '/ER IHC 242 Images.npy')
Y3 = np.load(PATH + '/ER IHC 242 Masks.npy')

X4 = np.load(PATH + '/ER IHC 263 Images.npy')
Y4 = np.load(PATH + '/ER IHC 263 Masks.npy')

X5 = np.load(PATH + '/ER IHC 221 Images.npy')
Y5 = np.load(PATH + '/ER IHC 221 Masks.npy')

X6 = np.load(PATH + '/ER IHC 229 Images.npy')
Y6 = np.load(PATH + '/ER IHC 229 Masks.npy')

X7 = np.load(PATH + '/ER IHC 239 Images.npy')
Y7 = np.load(PATH + '/ER IHC 239 Masks.npy')

X8 = np.load(PATH + '/ER IHC 246 Images.npy')
Y8 = np.load(PATH + '/ER IHC 246 Masks.npy')

X9 = np.load(PATH + '/ER IHC 252 Images.npy')
Y9 = np.load(PATH + '/ER IHC 252 Masks.npy')

# %%
X = [X1, X2, X3, X4, X5, X6, X7, X8, X9]
Y = [Y1, Y2, Y3, Y4, Y5, Y6, Y7, Y8, Y9]
patient_no = ['230','232','242','263','221','229','239','246','252']
size = [10,10,10,10,10,10,10,10,10]

# %%
fold_split = []

#test patient = 230, 232 
fold_split.append(([2,3,4,5,6,7,8],[0,1]))

#test_patient = 239, 242
fold_split.append(([0,1,3,4,5,7,8],[2,6]))

#test_patient = 252,263
fold_split.append(([0,1,2,4,5,6,7],[3,8]))

# %%
def convertToLabels(data):
  data[data==85]=1
  data[data==170]=2
  data[data==255]=3

def convertFromLabels(data):
  data[data==1]=85
  data[data==2]=170
  data[data==3]=255

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
def tversky_loss_1(y_true, y_pred):
    alpha = 0.7
    beta  = 0.3
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
  
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    # 
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def tversky_loss_2(y_true, y_pred):
    alpha = 0.3
    beta  = 0.7
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    # 
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def focal_tversky_loss_1(y_true, y_pred, gamma=0.75):
    tversky_index = tversky_loss_1(y_true, y_pred)
    return K.pow((tversky_index), gamma)
  
def focal_tversky_loss_2(y_true, y_pred, gamma=0.75):
    tversky_index = tversky_loss_2(y_true, y_pred)
    return K.pow((tversky_index), gamma)

def combined_loss(y_true, y_pred):
  return (0.2*K.categorical_crossentropy(y_true, y_pred))+(0.8*focal_tversky_loss_1(y_true, y_pred)+(0.8*focal_tversky_loss_2(y_true, y_pred)))

# %%
batch_size = 8
def get_batch(batch_size, X_train, Y_train): 
    size_batch = batch_size
    last_index = len(X_train) - 1
    x_train = X_train
    y_train = Y_train 
    while True:
        batch_data = [[],[]]
        for i in range(0, size_batch):
            random_index = random.randint(0, last_index)
            batch_data[0].append(x_train[random_index])
            batch_data[1].append(y_train[random_index])

        yield (np.array(batch_data[0]), np.array(batch_data[1]))

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER/3Fold LadderNet"

fold=0

for train_index, test_index in fold_split:
  print("TRAIN:", train_index, "TEST:", test_index)
  
  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  Train = list(zip(TrainX,TrainY))
  random.shuffle(Train)
  TrainX,TrainY = zip(*Train)
  TrainX = np.asarray(list(TrainX))
  TrainY = np.asarray(list(TrainY))

  Test = list(zip(TestX,TestY))
  random.shuffle(Test)
  TestX,TestY = zip(*Test)
  TestX = np.asarray(list(TestX))
  TestY = np.asarray(list(TestY))

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255
  convertToLabels(TrainY)
  TrainY = keras.utils.to_categorical(TrainY,num_classes=4,dtype='int16')
  convertToLabels(TestY)
  TestY = keras.utils.to_categorical(TestY,num_classes=4,dtype='int16')
  ValX = TrainX[(int)(0.8*TrainX.shape[0]):]
  ValY = TrainY[(int)(0.8*TrainY.shape[0]):]
  model = get_model((240,240,3),32,64)

  #es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
  mc = ModelCheckpoint('Checkpoint.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

  optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=0.001, decay=0.0, amsgrad=True)

  model.compile(loss=combined_loss, optimizer= optimizer , metrics=[dice_coef,'accuracy']) 
  num_epoch = 100
  datagen = get_batch(batch_size, TrainX, TrainY)
  n_points = len(TrainX)
  print('-----------fold {}--------------'.format(fold))
  history = model.fit(datagen, validation_data = [ValX, ValY],
                  epochs=num_epoch,steps_per_epoch = math.ceil(n_points / batch_size), callbacks =[mc],  shuffle =True)
  model.save(MODELS_PATH + '/FoC_TVCombined_LadderNet_ER_v2_3'+ str(fold) +'.h5')
  fold = fold + 1
# Out:
# TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1]
# -----------fold 0--------------
# Epoch 1/100
# 210/210 [==============================] - 180s 859ms/step - loss: 5.3113 - dice_coef: 0.3022 - accuracy: 0.8241 - val_loss: 5.3400 - val_dice_coef: 0.3266 - val_accuracy: 0.9233
#
# Epoch 00001: val_loss improved from inf to 5.33995, saving model to Checkpoint.h5
# Epoch 2/100
# 210/210 [==============================] - 168s 802ms/step - loss: 5.0585 - dice_coef: 0.3958 - accuracy: 0.9531 - val_loss: 4.9682 - val_dice_coef: 0.4404 - val_accuracy: 0.9408
#
# Epoch 00002: val_loss improved from 5.33995 to 4.96822, saving model to Checkpoint.h5
# Epoch 3/100
# 210/210 [==============================] - 169s 802ms/step - loss: 4.8091 - dice_coef: 0.4921 - accuracy: 0.9552 - val_loss: 4.6748 - val_dice_coef: 0.5467 - val_accuracy: 0.9431
#
# Epoch 00003: val_loss improved from 4.96822 to 4.67478, saving model to Checkpoint.h5
# Epoch 4/100
# 210/210 [==============================] - 168s 802ms/step - loss: 3.8786 - dice_coef: 0.8581 - accuracy: 0.9581 - val_loss: 3.7979 - val_dice_coef: 0.9526 - val_accuracy: 0.9552
#
# Epoch 00004: val_loss improved from 4.67478 to 3.79785, saving model to Checkpoint.h5
# Epoch 5/100
# 210/210 [==============================] - 168s 802ms/step - loss: 3.5493 - dice_coef: 0.9555 - accuracy: 0.9589 - val_loss: 4.2116 - val_dice_coef: 0.9295 - val_accuracy: 0.9306
#
# Epoch 00005: val_loss did not improve from 3.79785
# Epoch 6/100
# 210/210 [==============================] - 168s 802ms/step - loss: 3.4123 - dice_coef: 0.9563 - accuracy: 0.9593 - val_loss: 3.6240 - val_dice_coef: 0.9387 - val_accuracy: 0.9455
#
# Epoch 00006: val_loss improved from 3.79785 to 3.62402, saving model to Checkpoint.h5
# Epoch 7/100
# 210/210 [==============================] - 168s 802ms/step - loss: 3.3583 - dice_coef: 0.9581 - accuracy: 0.9608 - val_loss: 3.4133 - val_dice_coef: 0.9624 - val_accuracy: 0.9635
#
# Epoch 00007: val_loss improved from 3.62402 to 3.41328, saving model to Checkpoint.h5
# Epoch 8/100
# 210/210 [==============================] - 168s 802ms/step - loss: 3.2919 - dice_coef: 0.9598 - accuracy: 0.9622 - val_loss: 3.2100 - val_dice_coef: 0.9559 - val_accuracy: 0.9589
#
# Epoch 00008: val_loss improved from 3.41328 to 3.21004, saving model to Checkpoint.h5
# Epoch 9/100
# 210/210 [==============================] - 168s 802ms/step - loss: 3.1695 - dice_coef: 0.9611 - accuracy: 0.9637 - val_loss: 3.3167 - val_dice_coef: 0.9608 - val_accuracy: 0.9616
#
# Epoch 00009: val_loss did not improve from 3.21004
# Epoch 10/100
# 210/210 [==============================] - 168s 802ms/step - loss: 3.1360 - dice_coef: 0.9582 - accuracy: 0.9610 - val_loss: 3.1088 - val_dice_coef: 0.9637 - val_accuracy: 0.9648
#
# Epoch 00010: val_loss improved from 3.21004 to 3.10880, saving model to Checkpoint.h5
# Epoch 11/100
# 210/210 [==============================] - 168s 802ms/step - loss: 3.0631 - dice_coef: 0.9602 - accuracy: 0.9629 - val_loss: 3.1165 - val_dice_coef: 0.9586 - val_accuracy: 0.9628
#
# Epoch 00011: val_loss did not improve from 3.10880
# Epoch 12/100
# 210/210 [==============================] - 169s 803ms/step - loss: 3.0555 - dice_coef: 0.9589 - accuracy: 0.9621 - val_loss: 3.0147 - val_dice_coef: 0.9619 - val_accuracy: 0.9636
#
# Epoch 00012: val_loss improved from 3.10880 to 3.01474, saving model to Checkpoint.h5
# Epoch 13/100
# 210/210 [==============================] - 168s 802ms/step - loss: 3.0242 - dice_coef: 0.9578 - accuracy: 0.9573 - val_loss: 2.9142 - val_dice_coef: 0.9557 - val_accuracy: 0.9535
#
# Epoch 00013: val_loss improved from 3.01474 to 2.91419, saving model to Checkpoint.h5
# Epoch 14/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.9500 - dice_coef: 0.9592 - accuracy: 0.9588 - val_loss: 2.8760 - val_dice_coef: 0.9603 - val_accuracy: 0.9603
#
# Epoch 00014: val_loss improved from 2.91419 to 2.87601, saving model to Checkpoint.h5
# Epoch 15/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.8664 - dice_coef: 0.9604 - accuracy: 0.9599 - val_loss: 2.9928 - val_dice_coef: 0.9464 - val_accuracy: 0.9447
#
# Epoch 00015: val_loss did not improve from 2.87601
# Epoch 16/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.8648 - dice_coef: 0.9577 - accuracy: 0.9573 - val_loss: 2.9037 - val_dice_coef: 0.9431 - val_accuracy: 0.9399
#
# Epoch 00016: val_loss did not improve from 2.87601
# Epoch 17/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.7947 - dice_coef: 0.9584 - accuracy: 0.9585 - val_loss: 2.8302 - val_dice_coef: 0.9607 - val_accuracy: 0.9609
#
# Epoch 00017: val_loss improved from 2.87601 to 2.83023, saving model to Checkpoint.h5
# Epoch 18/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.8288 - dice_coef: 0.9565 - accuracy: 0.9566 - val_loss: 2.8914 - val_dice_coef: 0.9592 - val_accuracy: 0.9594
#
# Epoch 00018: val_loss did not improve from 2.83023
# Epoch 19/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.7378 - dice_coef: 0.9573 - accuracy: 0.9572 - val_loss: 3.0179 - val_dice_coef: 0.9583 - val_accuracy: 0.9588
#
# Epoch 00019: val_loss did not improve from 2.83023
# Epoch 20/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.7413 - dice_coef: 0.9557 - accuracy: 0.9558 - val_loss: 2.8621 - val_dice_coef: 0.9510 - val_accuracy: 0.9506
#
# Epoch 00020: val_loss did not improve from 2.83023
# Epoch 21/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.7240 - dice_coef: 0.9588 - accuracy: 0.9589 - val_loss: 2.7069 - val_dice_coef: 0.9628 - val_accuracy: 0.9633
#
# Epoch 00021: val_loss improved from 2.83023 to 2.70695, saving model to Checkpoint.h5
# Epoch 22/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.6210 - dice_coef: 0.9577 - accuracy: 0.9581 - val_loss: 2.7036 - val_dice_coef: 0.9587 - val_accuracy: 0.9593
#
# Epoch 00022: val_loss improved from 2.70695 to 2.70360, saving model to Checkpoint.h5
# Epoch 23/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.6689 - dice_coef: 0.9593 - accuracy: 0.9597 - val_loss: 2.6321 - val_dice_coef: 0.9472 - val_accuracy: 0.9469
#
# Epoch 00023: val_loss improved from 2.70360 to 2.63212, saving model to Checkpoint.h5
# Epoch 24/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.6147 - dice_coef: 0.9596 - accuracy: 0.9599 - val_loss: 2.5185 - val_dice_coef: 0.9623 - val_accuracy: 0.9632
#
# Epoch 00024: val_loss improved from 2.63212 to 2.51854, saving model to Checkpoint.h5
# Epoch 25/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.5847 - dice_coef: 0.9590 - accuracy: 0.9592 - val_loss: 2.5797 - val_dice_coef: 0.9544 - val_accuracy: 0.9549
#
# Epoch 00025: val_loss did not improve from 2.51854
# Epoch 26/100
# 210/210 [==============================] - 168s 801ms/step - loss: 2.5449 - dice_coef: 0.9628 - accuracy: 0.9632 - val_loss: 2.4413 - val_dice_coef: 0.9645 - val_accuracy: 0.9649
#
# Epoch 00026: val_loss improved from 2.51854 to 2.44128, saving model to Checkpoint.h5
# Epoch 27/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.5636 - dice_coef: 0.9604 - accuracy: 0.9609 - val_loss: 2.6387 - val_dice_coef: 0.9604 - val_accuracy: 0.9609
#
# Epoch 00027: val_loss did not improve from 2.44128
# Epoch 28/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.5070 - dice_coef: 0.9592 - accuracy: 0.9596 - val_loss: 2.6379 - val_dice_coef: 0.9648 - val_accuracy: 0.9654
#
# Epoch 00028: val_loss did not improve from 2.44128
# Epoch 29/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.5581 - dice_coef: 0.9619 - accuracy: 0.9624 - val_loss: 2.5646 - val_dice_coef: 0.9600 - val_accuracy: 0.9609
#
# Epoch 00029: val_loss did not improve from 2.44128
# Epoch 30/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.4691 - dice_coef: 0.9579 - accuracy: 0.9583 - val_loss: 2.4585 - val_dice_coef: 0.9607 - val_accuracy: 0.9614
#
# Epoch 00030: val_loss did not improve from 2.44128
# Epoch 31/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.4450 - dice_coef: 0.9588 - accuracy: 0.9593 - val_loss: 2.3868 - val_dice_coef: 0.9630 - val_accuracy: 0.9634
#
# Epoch 00031: val_loss improved from 2.44128 to 2.38682, saving model to Checkpoint.h5
# Epoch 32/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.5257 - dice_coef: 0.9613 - accuracy: 0.9618 - val_loss: 2.4845 - val_dice_coef: 0.9611 - val_accuracy: 0.9617
#
# Epoch 00032: val_loss did not improve from 2.38682
# Epoch 33/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3956 - dice_coef: 0.9630 - accuracy: 0.9635 - val_loss: 2.5664 - val_dice_coef: 0.9618 - val_accuracy: 0.9621
#
# Epoch 00033: val_loss did not improve from 2.38682
# Epoch 34/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.4890 - dice_coef: 0.9580 - accuracy: 0.9584 - val_loss: 2.3798 - val_dice_coef: 0.9622 - val_accuracy: 0.9625
#
# Epoch 00034: val_loss improved from 2.38682 to 2.37975, saving model to Checkpoint.h5
# Epoch 35/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3616 - dice_coef: 0.9584 - accuracy: 0.9590 - val_loss: 2.3377 - val_dice_coef: 0.9624 - val_accuracy: 0.9629
#
# Epoch 00035: val_loss improved from 2.37975 to 2.33775, saving model to Checkpoint.h5
# Epoch 36/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.4481 - dice_coef: 0.9626 - accuracy: 0.9631 - val_loss: 2.5272 - val_dice_coef: 0.9526 - val_accuracy: 0.9531
#
# Epoch 00036: val_loss did not improve from 2.33775
# Epoch 37/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3918 - dice_coef: 0.9595 - accuracy: 0.9600 - val_loss: 2.4084 - val_dice_coef: 0.9596 - val_accuracy: 0.9602
#
# Epoch 00037: val_loss did not improve from 2.33775
# Epoch 38/100
# 210/210 [==============================] - 169s 802ms/step - loss: 2.3710 - dice_coef: 0.9594 - accuracy: 0.9600 - val_loss: 2.5384 - val_dice_coef: 0.9636 - val_accuracy: 0.9639
#
# Epoch 00038: val_loss did not improve from 2.33775
# Epoch 39/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3428 - dice_coef: 0.9651 - accuracy: 0.9656 - val_loss: 2.5223 - val_dice_coef: 0.9636 - val_accuracy: 0.9639
#
# Epoch 00039: val_loss did not improve from 2.33775
# Epoch 40/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.4233 - dice_coef: 0.9614 - accuracy: 0.9619 - val_loss: 2.2904 - val_dice_coef: 0.9605 - val_accuracy: 0.9610
#
# Epoch 00040: val_loss improved from 2.33775 to 2.29037, saving model to Checkpoint.h5
# Epoch 41/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3607 - dice_coef: 0.9608 - accuracy: 0.9613 - val_loss: 2.2911 - val_dice_coef: 0.9651 - val_accuracy: 0.9656
#
# Epoch 00041: val_loss did not improve from 2.29037
# Epoch 42/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.4119 - dice_coef: 0.9604 - accuracy: 0.9610 - val_loss: 2.3709 - val_dice_coef: 0.9641 - val_accuracy: 0.9645
#
# Epoch 00042: val_loss did not improve from 2.29037
# Epoch 43/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3360 - dice_coef: 0.9610 - accuracy: 0.9616 - val_loss: 2.2784 - val_dice_coef: 0.9642 - val_accuracy: 0.9649
#
# Epoch 00043: val_loss improved from 2.29037 to 2.27840, saving model to Checkpoint.h5
# Epoch 44/100
# 210/210 [==============================] - 169s 803ms/step - loss: 2.3994 - dice_coef: 0.9626 - accuracy: 0.9631 - val_loss: 2.3609 - val_dice_coef: 0.9635 - val_accuracy: 0.9638
#
# Epoch 00044: val_loss did not improve from 2.27840
# Epoch 45/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2979 - dice_coef: 0.9611 - accuracy: 0.9617 - val_loss: 2.2902 - val_dice_coef: 0.9606 - val_accuracy: 0.9611
#
# Epoch 00045: val_loss did not improve from 2.27840
# Epoch 46/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3307 - dice_coef: 0.9614 - accuracy: 0.9619 - val_loss: 2.3496 - val_dice_coef: 0.9621 - val_accuracy: 0.9623
#
# Epoch 00046: val_loss did not improve from 2.27840
# Epoch 47/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3527 - dice_coef: 0.9622 - accuracy: 0.9628 - val_loss: 2.2155 - val_dice_coef: 0.9650 - val_accuracy: 0.9654
#
# Epoch 00047: val_loss improved from 2.27840 to 2.21555, saving model to Checkpoint.h5
# Epoch 48/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3488 - dice_coef: 0.9638 - accuracy: 0.9643 - val_loss: 2.2755 - val_dice_coef: 0.9649 - val_accuracy: 0.9654
#
# Epoch 00048: val_loss did not improve from 2.21555
# Epoch 49/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3265 - dice_coef: 0.9606 - accuracy: 0.9612 - val_loss: 2.3628 - val_dice_coef: 0.9599 - val_accuracy: 0.9610
#
# Epoch 00049: val_loss did not improve from 2.21555
# Epoch 50/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3072 - dice_coef: 0.9638 - accuracy: 0.9643 - val_loss: 2.2159 - val_dice_coef: 0.9630 - val_accuracy: 0.9634
#
# Epoch 00050: val_loss did not improve from 2.21555
# Epoch 51/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3074 - dice_coef: 0.9607 - accuracy: 0.9613 - val_loss: 2.3653 - val_dice_coef: 0.9593 - val_accuracy: 0.9598
#
# Epoch 00051: val_loss did not improve from 2.21555
# Epoch 52/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3110 - dice_coef: 0.9590 - accuracy: 0.9597 - val_loss: 2.4805 - val_dice_coef: 0.9595 - val_accuracy: 0.9600
#
# Epoch 00052: val_loss did not improve from 2.21555
# Epoch 53/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3657 - dice_coef: 0.9611 - accuracy: 0.9616 - val_loss: 2.2632 - val_dice_coef: 0.9608 - val_accuracy: 0.9612
#
# Epoch 00053: val_loss did not improve from 2.21555
# Epoch 54/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3885 - dice_coef: 0.9618 - accuracy: 0.9622 - val_loss: 2.1842 - val_dice_coef: 0.9628 - val_accuracy: 0.9635
#
# Epoch 00054: val_loss improved from 2.21555 to 2.18419, saving model to Checkpoint.h5
# Epoch 55/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2926 - dice_coef: 0.9610 - accuracy: 0.9616 - val_loss: 2.2242 - val_dice_coef: 0.9659 - val_accuracy: 0.9664
#
# Epoch 00055: val_loss did not improve from 2.18419
# Epoch 56/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2705 - dice_coef: 0.9605 - accuracy: 0.9611 - val_loss: 2.2893 - val_dice_coef: 0.9608 - val_accuracy: 0.9617
#
# Epoch 00056: val_loss did not improve from 2.18419
# Epoch 57/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2157 - dice_coef: 0.9618 - accuracy: 0.9624 - val_loss: 2.1649 - val_dice_coef: 0.9658 - val_accuracy: 0.9664
#
# Epoch 00057: val_loss improved from 2.18419 to 2.16486, saving model to Checkpoint.h5
# Epoch 58/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2648 - dice_coef: 0.9618 - accuracy: 0.9624 - val_loss: 2.2578 - val_dice_coef: 0.9588 - val_accuracy: 0.9608
#
# Epoch 00058: val_loss did not improve from 2.16486
# Epoch 59/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2438 - dice_coef: 0.9614 - accuracy: 0.9620 - val_loss: 2.2319 - val_dice_coef: 0.9670 - val_accuracy: 0.9675
#
# Epoch 00059: val_loss did not improve from 2.16486
# Epoch 60/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2474 - dice_coef: 0.9620 - accuracy: 0.9625 - val_loss: 2.2020 - val_dice_coef: 0.9641 - val_accuracy: 0.9646
#
# Epoch 00060: val_loss did not improve from 2.16486
# Epoch 61/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2535 - dice_coef: 0.9631 - accuracy: 0.9636 - val_loss: 2.7035 - val_dice_coef: 0.9601 - val_accuracy: 0.9605
#
# Epoch 00061: val_loss did not improve from 2.16486
# Epoch 62/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2433 - dice_coef: 0.9633 - accuracy: 0.9639 - val_loss: 2.4814 - val_dice_coef: 0.9594 - val_accuracy: 0.9602
#
# Epoch 00062: val_loss did not improve from 2.16486
# Epoch 63/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2824 - dice_coef: 0.9581 - accuracy: 0.9587 - val_loss: 2.4381 - val_dice_coef: 0.9577 - val_accuracy: 0.9581
#
# Epoch 00063: val_loss did not improve from 2.16486
# Epoch 64/100
# 210/210 [==============================] - 169s 802ms/step - loss: 2.2893 - dice_coef: 0.9587 - accuracy: 0.9593 - val_loss: 2.2604 - val_dice_coef: 0.9589 - val_accuracy: 0.9595
#
# Epoch 00064: val_loss did not improve from 2.16486
# Epoch 65/100
# 210/210 [==============================] - 169s 802ms/step - loss: 2.2620 - dice_coef: 0.9617 - accuracy: 0.9623 - val_loss: 2.1436 - val_dice_coef: 0.9645 - val_accuracy: 0.9651
#
# Epoch 00065: val_loss improved from 2.16486 to 2.14361, saving model to Checkpoint.h5
# Epoch 66/100
# 210/210 [==============================] - 169s 803ms/step - loss: 2.2693 - dice_coef: 0.9640 - accuracy: 0.9645 - val_loss: 2.1748 - val_dice_coef: 0.9662 - val_accuracy: 0.9668
#
# Epoch 00066: val_loss did not improve from 2.14361
# Epoch 67/100
# 210/210 [==============================] - 169s 803ms/step - loss: 2.2689 - dice_coef: 0.9607 - accuracy: 0.9613 - val_loss: 2.1936 - val_dice_coef: 0.9644 - val_accuracy: 0.9649
#
# Epoch 00067: val_loss did not improve from 2.14361
# Epoch 68/100
# 210/210 [==============================] - 169s 803ms/step - loss: 2.2789 - dice_coef: 0.9609 - accuracy: 0.9615 - val_loss: 2.2501 - val_dice_coef: 0.9623 - val_accuracy: 0.9628
#
# Epoch 00068: val_loss did not improve from 2.14361
# Epoch 69/100
# 210/210 [==============================] - 169s 803ms/step - loss: 2.2542 - dice_coef: 0.9607 - accuracy: 0.9613 - val_loss: 2.2817 - val_dice_coef: 0.9540 - val_accuracy: 0.9544
#
# Epoch 00069: val_loss did not improve from 2.14361
# Epoch 70/100
# 210/210 [==============================] - 169s 802ms/step - loss: 2.2697 - dice_coef: 0.9612 - accuracy: 0.9618 - val_loss: 2.3290 - val_dice_coef: 0.9582 - val_accuracy: 0.9589
#
# Epoch 00070: val_loss did not improve from 2.14361
# Epoch 71/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2928 - dice_coef: 0.9626 - accuracy: 0.9632 - val_loss: 2.1874 - val_dice_coef: 0.9647 - val_accuracy: 0.9653
#
# Epoch 00071: val_loss did not improve from 2.14361
# Epoch 72/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3054 - dice_coef: 0.9596 - accuracy: 0.9602 - val_loss: 2.3181 - val_dice_coef: 0.9576 - val_accuracy: 0.9582
#
# Epoch 00072: val_loss did not improve from 2.14361
# Epoch 73/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2526 - dice_coef: 0.9607 - accuracy: 0.9614 - val_loss: 2.3404 - val_dice_coef: 0.9634 - val_accuracy: 0.9638
#
# Epoch 00073: val_loss did not improve from 2.14361
# Epoch 74/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2955 - dice_coef: 0.9623 - accuracy: 0.9629 - val_loss: 2.1611 - val_dice_coef: 0.9624 - val_accuracy: 0.9628
#
# Epoch 00074: val_loss did not improve from 2.14361
# Epoch 75/100
# 210/210 [==============================] - 169s 802ms/step - loss: 2.2317 - dice_coef: 0.9627 - accuracy: 0.9632 - val_loss: 2.1244 - val_dice_coef: 0.9653 - val_accuracy: 0.9659
#
# Epoch 00075: val_loss improved from 2.14361 to 2.12443, saving model to Checkpoint.h5
# Epoch 76/100
# 210/210 [==============================] - 169s 803ms/step - loss: 2.2707 - dice_coef: 0.9603 - accuracy: 0.9610 - val_loss: 2.3130 - val_dice_coef: 0.9639 - val_accuracy: 0.9644
#
# Epoch 00076: val_loss did not improve from 2.12443
# Epoch 77/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2828 - dice_coef: 0.9596 - accuracy: 0.9603 - val_loss: 2.4385 - val_dice_coef: 0.9574 - val_accuracy: 0.9580
#
# Epoch 00077: val_loss did not improve from 2.12443
# Epoch 78/100
# 210/210 [==============================] - 169s 803ms/step - loss: 2.2318 - dice_coef: 0.9624 - accuracy: 0.9630 - val_loss: 2.2113 - val_dice_coef: 0.9651 - val_accuracy: 0.9654
#
# Epoch 00078: val_loss did not improve from 2.12443
# Epoch 79/100
# 210/210 [==============================] - 169s 803ms/step - loss: 2.2783 - dice_coef: 0.9608 - accuracy: 0.9614 - val_loss: 2.2984 - val_dice_coef: 0.9646 - val_accuracy: 0.9652
#
# Epoch 00079: val_loss did not improve from 2.12443
# Epoch 80/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3241 - dice_coef: 0.9579 - accuracy: 0.9585 - val_loss: 2.4546 - val_dice_coef: 0.9430 - val_accuracy: 0.9436
#
# Epoch 00080: val_loss did not improve from 2.12443
# Epoch 81/100
# 210/210 [==============================] - 169s 803ms/step - loss: 2.2672 - dice_coef: 0.9588 - accuracy: 0.9594 - val_loss: 2.2249 - val_dice_coef: 0.9649 - val_accuracy: 0.9652
#
# Epoch 00081: val_loss did not improve from 2.12443
# Epoch 82/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3113 - dice_coef: 0.9605 - accuracy: 0.9612 - val_loss: 2.4127 - val_dice_coef: 0.9624 - val_accuracy: 0.9629
#
# Epoch 00082: val_loss did not improve from 2.12443
# Epoch 83/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.3686 - dice_coef: 0.9634 - accuracy: 0.9639 - val_loss: 2.2317 - val_dice_coef: 0.9643 - val_accuracy: 0.9649
#
# Epoch 00083: val_loss did not improve from 2.12443
# Epoch 84/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2385 - dice_coef: 0.9636 - accuracy: 0.9643 - val_loss: 2.2202 - val_dice_coef: 0.9608 - val_accuracy: 0.9615
#
# Epoch 00084: val_loss did not improve from 2.12443
# Epoch 85/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2522 - dice_coef: 0.9619 - accuracy: 0.9626 - val_loss: 2.2518 - val_dice_coef: 0.9593 - val_accuracy: 0.9618
#
# Epoch 00085: val_loss did not improve from 2.12443
# Epoch 86/100
# 210/210 [==============================] - 169s 802ms/step - loss: 2.2241 - dice_coef: 0.9624 - accuracy: 0.9630 - val_loss: 2.2372 - val_dice_coef: 0.9642 - val_accuracy: 0.9649
#
# Epoch 00086: val_loss did not improve from 2.12443
# Epoch 87/100
# 210/210 [==============================] - 169s 803ms/step - loss: 2.2878 - dice_coef: 0.9599 - accuracy: 0.9606 - val_loss: 2.3187 - val_dice_coef: 0.9618 - val_accuracy: 0.9633
#
# Epoch 00087: val_loss did not improve from 2.12443
# Epoch 88/100
# 210/210 [==============================] - 169s 802ms/step - loss: 2.2176 - dice_coef: 0.9617 - accuracy: 0.9624 - val_loss: 2.1636 - val_dice_coef: 0.9668 - val_accuracy: 0.9672
#
# Epoch 00088: val_loss did not improve from 2.12443
# Epoch 89/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2158 - dice_coef: 0.9631 - accuracy: 0.9636 - val_loss: 2.1844 - val_dice_coef: 0.9650 - val_accuracy: 0.9654
#
# Epoch 00089: val_loss did not improve from 2.12443
# Epoch 90/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2185 - dice_coef: 0.9631 - accuracy: 0.9637 - val_loss: 2.1914 - val_dice_coef: 0.9658 - val_accuracy: 0.9665
#
# Epoch 00090: val_loss did not improve from 2.12443
# Epoch 91/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2593 - dice_coef: 0.9614 - accuracy: 0.9619 - val_loss: 2.2337 - val_dice_coef: 0.9583 - val_accuracy: 0.9588
#
# Epoch 00091: val_loss did not improve from 2.12443
# Epoch 92/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2954 - dice_coef: 0.9639 - accuracy: 0.9644 - val_loss: 2.1716 - val_dice_coef: 0.9641 - val_accuracy: 0.9644
#
# Epoch 00092: val_loss did not improve from 2.12443
# Epoch 93/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2519 - dice_coef: 0.9638 - accuracy: 0.9643 - val_loss: 2.1359 - val_dice_coef: 0.9681 - val_accuracy: 0.9685
#
# Epoch 00093: val_loss did not improve from 2.12443
# Epoch 94/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2666 - dice_coef: 0.9644 - accuracy: 0.9649 - val_loss: 2.5905 - val_dice_coef: 0.9632 - val_accuracy: 0.9637
#
# Epoch 00094: val_loss did not improve from 2.12443
# Epoch 95/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2938 - dice_coef: 0.9634 - accuracy: 0.9639 - val_loss: 2.1975 - val_dice_coef: 0.9626 - val_accuracy: 0.9632
#
# Epoch 00095: val_loss did not improve from 2.12443
# Epoch 96/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2365 - dice_coef: 0.9598 - accuracy: 0.9606 - val_loss: 2.1080 - val_dice_coef: 0.9647 - val_accuracy: 0.9651
#
# Epoch 00096: val_loss improved from 2.12443 to 2.10797, saving model to Checkpoint.h5
# Epoch 97/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2288 - dice_coef: 0.9620 - accuracy: 0.9626 - val_loss: 2.1084 - val_dice_coef: 0.9667 - val_accuracy: 0.9671
#
# Epoch 00097: val_loss did not improve from 2.10797
# Epoch 98/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2083 - dice_coef: 0.9617 - accuracy: 0.9624 - val_loss: 2.1850 - val_dice_coef: 0.9657 - val_accuracy: 0.9661
#
# Epoch 00098: val_loss did not improve from 2.10797
# Epoch 99/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2497 - dice_coef: 0.9627 - accuracy: 0.9633 - val_loss: 2.2092 - val_dice_coef: 0.9664 - val_accuracy: 0.9669
#
# Epoch 00099: val_loss did not improve from 2.10797
# Epoch 100/100
# 210/210 [==============================] - 168s 802ms/step - loss: 2.2608 - dice_coef: 0.9627 - accuracy: 0.9633 - val_loss: 2.3160 - val_dice_coef: 0.9639 - val_accuracy: 0.9645
#
# Epoch 00100: val_loss did not improve from 2.10797

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask, Patient_array,Patient_length,title,folder):
  idx = 0
  for i in range(len(Patient_length)):
    temp = []
    for j in range(Patient_length[i]):
      final_output = mask[idx:idx+48]
      idx = idx + 48
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save(folder + title + Patient_array[i], final_output)

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/4 Class/ER/3Fold LadderNet/"
model_names = os.listdir(MODELS_PATH)
print(model_names)
# Out:
# ['LadderNet_ER_v2_0.h5', 'LadderNet_ER_v2_1.h5', 'LadderNet_ER_v2_2.h5', 'FoC_TVCombined_LadderNet_ER_v2_30.h5']

# %%
SAVE_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/ER/3Fold LadderNet/"

# %%
# Axis 0 = Folds
# Axis 1 = Class (Strong Intermediate,Weak,Background)
# Axis 2 = Evaluation Technique (Precision, Recall, Dice coefficient)
pixEvaluationTrain = np.empty((0,4,3))
pixEvaluationTest = np.empty((0,4,3))
score = np.zeros((1,4,3))

# %%
fold = 0

for train_index, test_index in fold_split:
  print("FOLD:",fold,"\tTRAIN:", train_index, "TEST:", test_index)
  # Splitting Train and Test data
  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  train_no = [patient_no[i] for i in train_index]
  train_size = [size[i] for i in train_index]

  test_no = [patient_no[i] for i in test_index]
  test_size = [size[i] for i in test_index]

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255

  convertToLabels(TrainY)
  convertToLabels(TestY)

  # TrainY = keras.utils.to_categorical(TrainY,num_classes=4,dtype='int16')
  # TestY = keras.utils.to_categorical(TestY,num_classes=4,dtype='int16')
  
  # Loading corrosponding fold of model
  model = keras.models.load_model(MODELS_PATH + 'FoC_TVCombined_LadderNet_ER_v2_30.h5',custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

  # Predicting results using model
  trainResult = model.predict(TrainX, batch_size=8)
  testResult = model.predict(TestX,batch_size=8)

  trainResult = np.argmax(trainResult,axis=-1)
  testResult = np.argmax(testResult,axis=-1)

  # trainOneHot = keras.utils.to_categorical(trainResult,num_classes=4,dtype='int16')
  # testOneHot = keras.utils.to_categorical(testResult,num_classes=4,dtype='int16')

  # Obtaining pixel-wise results: Precision recall and dice coefficient
  # For TRAIN
  y_true = np.reshape(TrainY,(-1))
  y_pred = np.reshape(trainResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(4):
    score[0][i][0] = prec[3-i]
    score[0][i][1] = recall[3-i]
    score[0][i][2] = dice[3-i]

  pixEvaluationTrain = np.append(pixEvaluationTrain,score,axis=0)
 
  # For TEST
  y_true = np.reshape(TestY,(-1))
  y_pred = np.reshape(testResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2,3],average=None,zero_division=1)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(4):
    score[0][i][0] = prec[3-i]
    score[0][i][1] = recall[3-i]
    score[0][i][2] = dice[3-i]

  pixEvaluationTest = np.append(pixEvaluationTest,score,axis=0)

  # Converting predicted labels to required output format
  # convertFromLabels(trainResult)
  # convertFromLabels(testResult)

  # # Saving numpy arrays
  # path = os.path.join(SAVE_PATH,"Fold " + str(fold))
  # os.mkdir(path)
  # os.mkdir(path + '/Train')
  # os.mkdir(path + '/Test')

  # saveNumpyOutput(trainResult, train_no, train_size,"/Train/",path)
  # saveNumpyOutput(testResult, test_no, test_size,"/Test/",path)

  fold +=1
# Out:
# FOLD: 0 	TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1]

# %%
print(pixEvaluationTrain.shape)
print(pixEvaluationTest.shape)
print(pixEvaluationTest)
# Out:
# (1, 4, 3)
# (1, 4, 3)
# [[[0.88057365 0.38439159 0.53516902]
#   [0.44256609 0.71980221 0.5481224 ]
#   [0.46586629 0.1725451  0.25182178]
#   [0.97250802 0.98358452 0.97801491]]]

# %%
np.save(SAVE_PATH + "Pixel-wise Metrics Train.npy", pixEvaluationTrain)
np.save(SAVE_PATH + "Pixel-wise Metrics Test.npy", pixEvaluationTest)

# %% [markdown]
# # **DISPLAY**

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 48   # enter between 0- 50 since there are 5 patients with 10 images each

id = id * 48
final_input = TestX[id:id+48]
Mask_input = TestGT[id:id+48]
final_output = testResult[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


plt.figure(figsize=(20,20))
id = 25  # enter between 0- 40 since there are 4 patients with 10 images each

id = id * 48
final_input = TrainX[id:id+48]
Mask_input = TrainGT[id:id+48]
final_output = trainResult[id:id+48]

final_input = stitchImagePatches(final_input)
Mask_input =  stitchMaskPatches(Mask_input)
final_output = stitchMaskPatches(final_output)

print(final_input.shape)
print(final_output.shape)
print(Mask_input.shape)

print(np.unique(final_output))
copy1  = np.copy(final_input)
copy2 = copy1.astype('float32')*255
copy2 = copy2.astype('uint8')
final_input = np.reshape(copy2,(1440, 1920,3))
final_input = cv2.cvtColor(final_input,cv2.COLOR_BGR2RGB)

plt.subplot(131).imshow(final_input)
plt.subplot(132).imshow(Mask_input,'gray')
plt.subplot(133).imshow(final_output,'gray')
