# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
# !pip install -U keras
# !pip install tensorflow-gpu==2.1.0rc0
# Out:
# Requirement already up-to-date: keras in /usr/local/lib/python3.6/dist-packages (2.3.1)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras) (1.12.0)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras) (1.1.2)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.18.5)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras) (1.0.8)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.10.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.4.1)
# Collecting tensorflow-gpu==2.1.0rc0
#   Downloading https://files.pythonhosted.org/packages/f3/24/f94a1b8f779471f53b814a96c5109994ccf65b0103b771ff208c8a937d37/tensorflow_gpu-2.1.0rc0-cp36-cp36m-manylinux2010_x86_64.whl (402.3MB)
#      |████████████████████████████████| 402.3MB 33kB/s
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.2.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.29.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.18.5)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.12.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.8.1)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.1.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.34.2)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.1.2)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (3.10.0)
# Collecting tensorboard<2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/76/54/99b9d5d52d5cb732f099baaaf7740403e83fe6b0cedde940fabd2b13d75a/tensorboard-2.0.2-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 32.5MB/s
# Collecting tensorflow-estimator<2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/fc/08/8b927337b7019c374719145d1dceba21a8bb909b93b1ad6f8fb7d22c1ca1/tensorflow_estimator-2.0.1-py2.py3-none-any.whl (449kB)
#      |████████████████████████████████| 450kB 37.4MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (1.12.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (3.2.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.1.0rc0) (0.9.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==2.1.0rc0) (2.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorflow-gpu==2.1.0rc0) (47.1.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.4.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.7.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.2.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.0.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.3.0)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (4.0)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.2.8)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.6.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.1.0rc0) (3.1.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=7b1a234c8a38678254f629f3a06b16b59df4178b692f0a8eb2236462c5d791d4
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 2.2.0 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.2.0 has requirement tensorboard<2.3.0,>=2.2.0, but you'll have tensorboard 2.0.2 which is incompatible.
# ERROR: tensorflow 2.2.0 has requirement tensorflow-estimator<2.3.0,>=2.2.0, but you'll have tensorflow-estimator 2.0.1 which is incompatible.
# ERROR: tensorflow-probability 0.10.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# Installing collected packages: gast, tensorboard, tensorflow-estimator, tensorflow-gpu
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
# Successfully installed gast-0.2.2 tensorboard-2.0.2 tensorflow-estimator-2.0.1 tensorflow-gpu-2.1.0rc0

# %%
import math
import random
import keras
from keras.layers import *
from keras.models import Sequential
from keras import Model
from keras import backend as K  
from keras.regularizers import l2
from keras.callbacks import EarlyStopping,ModelCheckpoint

from sklearn.model_selection import LeaveOneOut
from sklearn import metrics
# Out:
# Using TensorFlow backend.

# %%
def get_conv_block(input_layer,nFilters,size):
    conv1 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(input_layer)
    bn1 = BatchNormalization()(conv1)
    conv2 = Conv2D(nFilters, size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(bn1)
    bn2 = BatchNormalization()(conv2)
    return bn2
    
def get_UNET(input_layer,nFilters,flag): 

    block1 = get_conv_block(input_layer[0],nFilters,3)
    mp1 = MaxPooling2D(pool_size=(2, 2))(block1)
    dr1 = Dropout(0.1)(mp1)
   
    if(flag==1):
      dr1 = concatenate([dr1,input_layer[1]])

    block2 = get_conv_block(dr1,nFilters*2,3)
    mp2 = MaxPooling2D(pool_size=(2, 2))(block2)
    dr2 = Dropout(0.1)(mp2)

    if(flag==1):
      dr2 = concatenate([dr2,input_layer[2]])
   
    block3 = get_conv_block(dr2,nFilters*4,3)
    mp3 = MaxPooling2D(pool_size=(2, 2))(block3)
    dr3 = Dropout(0.1)(mp3)

    if(flag==1):
      dr3 = concatenate([dr3,input_layer[3]])
       
    block4 = get_conv_block(dr3,nFilters*8,3)
    mp4 = MaxPooling2D(pool_size=(2, 2))(block4)
    dr4 = Dropout(0.1)(mp4)

    conv5 = Conv2D(nFilters*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(dr4)
    conv5 = Conv2D(nFilters*16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(conv5)

    up1 = Conv2DTranspose(nFilters*8,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(conv5)
    cat1 = concatenate([block4, up1, mp3])
    dr1 = Dropout(0.1)(cat1)
    block5 = get_conv_block(dr1,nFilters*8,3)

    up2 = Conv2DTranspose(nFilters*4,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block5)
    b4_upsample = Conv2DTranspose(nFilters*4,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block4)
    cat2 = concatenate([block3, up2, b4_upsample, mp2])
    dr2 = Dropout(0.1)(cat2)
    block6 = get_conv_block(dr2,nFilters*4,3)
    
    up3 = Conv2DTranspose(nFilters*2,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block6)
    b3_upsample = Conv2DTranspose(nFilters*2,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block3)
    cat3 = concatenate([block2, up3, mp1, b3_upsample])
    dr3 = Dropout(0.1)(cat3)
    block7 = get_conv_block(dr3,nFilters*2,3)
    
    up4 = Conv2DTranspose(nFilters,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block7)
    b2_upsample = Conv2DTranspose(nFilters,(3,3),strides =(2,2),activation='relu',padding='same',kernel_initializer = 'he_normal')(block2)
    cat4 = concatenate([block1, up4, b2_upsample])
    dr4 = Dropout(0.1)(cat4)
    block8 = get_conv_block(dr4,nFilters,3)

    conv10 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',kernel_regularizer=l2(1e-4))(block8)
    conv11 = Conv2D(3,(1,1), activation='softmax', padding = 'same',kernel_regularizer=l2(1e-4))(conv10)

    return (conv11, block7, block6, block5)

def get_model(input_shape,nFilters1,nFilters2):

    input_layer = Input(shape=input_shape)
    out1,out2,out3,out4 = get_UNET([input_layer],nFilters1,0)

    out1,out2,out3,out4 = get_UNET([out1,out2,out3,out4],nFilters2,1)

    model = Model(input_layer,out1)
    return model

# %%
PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Ki67"


X1  = np.load(PATH + '/Ki67 IHC 230 Images.npy')
Y1  = np.load(PATH + '/Ki67 IHC 230 Masks.npy')

X2  = np.load(PATH + '/Ki67 IHC 232 Images.npy')
Y2  = np.load(PATH + '/Ki67 IHC 232 Masks.npy')

X3  = np.load(PATH + '/Ki67 IHC 242 Images.npy')
Y3  = np.load(PATH + '/Ki67 IHC 242 Masks.npy')

X4  = np.load(PATH + '/Ki67 IHC 263 Images.npy')
Y4  = np.load(PATH + '/Ki67 IHC 263 Masks.npy')

X5 = np.load(PATH + '/Ki67 IHC 221 Images.npy')
Y5 = np.load(PATH + '/Ki67 IHC 221 Masks.npy')

X6 = np.load(PATH + '/Ki67 IHC 229 Images.npy')
Y6 = np.load(PATH + '/Ki67 IHC 229 Masks.npy')

X7 = np.load(PATH + '/Ki67 IHC 239 Images.npy')
Y7 = np.load(PATH + '/Ki67 IHC 239 Masks.npy')

X8 = np.load(PATH + '/Ki67 IHC 246 Images.npy')
Y8 = np.load(PATH + '/Ki67 IHC 246 Masks.npy')

X9 = np.load(PATH + '/Ki67 IHC 252 Images.npy')
Y9 = np.load(PATH + '/Ki67 IHC 252 Masks.npy')

# %%
print(X1.shape[0]/48)
print(X2.shape[0]/48)
print(X3.shape[0]/48)
print(X4.shape[0]/48)
print(X5.shape[0]/48)
print(X6.shape[0]/48)
print(X7.shape[0]/48)
print(X8.shape[0]/48)
print(X9.shape[0]/48)
# Out:
# 10.0
# 10.0
# 11.0
# 11.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0

# %%
X = [X1, X2, X3, X4, X5, X6, X7, X8, X9]
Y = [Y1, Y2, Y3, Y4, Y5, Y6, Y7, Y8, Y9]
patient_no = ['230','232','242','263','221','229','239','246','252']
size = [10,10,11,11,10,10,10,10,10]

# %%
fold_split = []

#test patient = 230, 232 
fold_split.append(([2,3,4,5,6,7,8],[0,1]))

#test_patient = 239, 242
fold_split.append(([0,1,3,4,5,7,8],[2,6]))

#test_patient = 252,263
fold_split.append(([0,1,2,4,5,6,7],[3,8]))

# %%
def convertToLabels(data):
  data[data==128]=1
  data[data==255]=2

def convertFromLabels(data):
  data[data==1]=128
  data[data==2]=255

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

# %%
def tversky_loss_1(y_true, y_pred):
    alpha = 0.7
    beta  = 0.3
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
  
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    # 
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def tversky_loss_2(y_true, y_pred):
    alpha = 0.3
    beta  = 0.7
    
    ones = K.ones(K.shape(y_true))
    p0 = y_pred      # proba that voxels are class i
    p1 = ones-y_pred # proba that voxels are not class i
    g0 = y_true
    g1 = ones-y_true
    
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    # 
    T = K.sum(num/den) # when summing over classes, T has dynamic range [0 Ncl]
    
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def focal_tversky_loss_1(y_true, y_pred, gamma=0.75):
    tversky_index = tversky_loss_1(y_true, y_pred)
    return K.pow((tversky_index), gamma)
  
def focal_tversky_loss_2(y_true, y_pred, gamma=0.75):
    tversky_index = tversky_loss_2(y_true, y_pred)
    return K.pow((tversky_index), gamma)

def combined_loss(y_true, y_pred):
  return (0.2*K.categorical_crossentropy(y_true, y_pred))+(0.8*focal_tversky_loss_1(y_true, y_pred)+(0.8*focal_tversky_loss_2(y_true, y_pred)))

# %%
from keras.callbacks import EarlyStopping,ModelCheckpoint

# %%
optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=0.001, decay=0.0, amsgrad=True)

# %%
batch_size = 8
def get_batch(batch_size, X_train, Y_train): 
    size_batch = batch_size
    last_index = len(X_train) - 1
    x_train = X_train
    y_train = Y_train 
    while True:
        batch_data = [[],[]]
        for i in range(0, size_batch):
            random_index = random.randint(0, last_index)
            batch_data[0].append(x_train[random_index])
            batch_data[1].append(y_train[random_index])

        yield (np.array(batch_data[0]), np.array(batch_data[1]))

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL"

fold = 1

for train_index, test_index in fold_split:
  print("TRAIN:", train_index, "TEST:", test_index)
  if(test_index[0]==0):
    continue
  
  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  # Train = list(zip(TrainX,TrainY))
  # random.shuffle(Train)
  # TrainX,TrainY = zip(*Train)
  # TrainX = np.asarray(list(TrainX))
  # TrainY = np.asarray(list(TrainY))

  # Test = list(zip(TestX,TestY))
  # random.shuffle(Test)
  # TestX,TestY = zip(*Test)
  # TestX = np.asarray(list(TestX))
  # TestY = np.asarray(list(TestY))

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255
  convertToLabels(TrainY)
  TrainY = keras.utils.to_categorical(TrainY,num_classes=3,dtype='int16')
  convertToLabels(TestY)
  TestY = keras.utils.to_categorical(TestY,num_classes=3,dtype='int16')
  ValX = TrainX[(int)(0.8*TrainX.shape[0]):]
  ValY = TrainY[(int)(0.8*TrainY.shape[0]):]
  model = get_model((240,240,3),32,64)

  
  mc = ModelCheckpoint(MODELS_PATH +'/Checkpoint '+str(fold) +'.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

  optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=0.001, decay=0.0, amsgrad=True)

  model.compile(loss=combined_loss, optimizer= optimizer , metrics=[dice_coef,'accuracy']) 
  num_epoch = 100
  datagen = get_batch(batch_size, TrainX, TrainY)
  n_points = len(TrainX)
  print('-----------fold {}--------------'.format(fold))
  history = model.fit(datagen, validation_data = [ValX, ValY],
                  epochs=num_epoch,steps_per_epoch = math.ceil(n_points / batch_size), callbacks =[mc],  shuffle =True)
  model.save(MODELS_PATH + '/Ki67 '+ str(fold) +'.h5')
  fold = fold + 1
# Out:
# TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1]
# TRAIN: [0, 1, 3, 4, 5, 7, 8] TEST: [2, 6]
# -----------fold 1--------------
# Epoch 1/100
# 426/426 [==============================] - 337s 792ms/step - loss: 3.4651 - dice_coef: 0.8147 - accuracy: 0.8567 - val_loss: 3.0097 - val_dice_coef: 0.8864 - val_accuracy: 0.9069
#
# Epoch 00001: val_loss improved from inf to 3.00970, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 2/100
# 426/426 [==============================] - 315s 740ms/step - loss: 2.9025 - dice_coef: 0.8658 - accuracy: 0.8952 - val_loss: 2.7280 - val_dice_coef: 0.9038 - val_accuracy: 0.9248
#
# Epoch 00002: val_loss improved from 3.00970 to 2.72800, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 3/100
# 426/426 [==============================] - 315s 740ms/step - loss: 2.5195 - dice_coef: 0.8918 - accuracy: 0.9018 - val_loss: 2.4094 - val_dice_coef: 0.9204 - val_accuracy: 0.9214
#
# Epoch 00003: val_loss improved from 2.72800 to 2.40936, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 4/100
# 426/426 [==============================] - 315s 740ms/step - loss: 2.2513 - dice_coef: 0.9062 - accuracy: 0.9091 - val_loss: 4.4008 - val_dice_coef: 0.2360 - val_accuracy: 0.2314
#
# Epoch 00004: val_loss did not improve from 2.40936
# Epoch 5/100
# 426/426 [==============================] - 315s 740ms/step - loss: 2.0639 - dice_coef: 0.9091 - accuracy: 0.9118 - val_loss: 2.0344 - val_dice_coef: 0.9272 - val_accuracy: 0.9284
#
# Epoch 00005: val_loss improved from 2.40936 to 2.03436, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 6/100
# 426/426 [==============================] - 315s 739ms/step - loss: 1.9064 - dice_coef: 0.9121 - accuracy: 0.9147 - val_loss: 1.8301 - val_dice_coef: 0.9264 - val_accuracy: 0.9294
#
# Epoch 00006: val_loss improved from 2.03436 to 1.83008, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 7/100
# 426/426 [==============================] - 315s 740ms/step - loss: 1.7578 - dice_coef: 0.9153 - accuracy: 0.9177 - val_loss: 1.9935 - val_dice_coef: 0.8733 - val_accuracy: 0.8758
#
# Epoch 00007: val_loss did not improve from 1.83008
# Epoch 8/100
# 426/426 [==============================] - 315s 739ms/step - loss: 1.6543 - dice_coef: 0.9179 - accuracy: 0.9203 - val_loss: 1.6787 - val_dice_coef: 0.9249 - val_accuracy: 0.9270
#
# Epoch 00008: val_loss improved from 1.83008 to 1.67872, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 9/100
# 426/426 [==============================] - 315s 739ms/step - loss: 1.5435 - dice_coef: 0.9205 - accuracy: 0.9228 - val_loss: 1.6341 - val_dice_coef: 0.9260 - val_accuracy: 0.9286
#
# Epoch 00009: val_loss improved from 1.67872 to 1.63409, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 10/100
# 426/426 [==============================] - 315s 739ms/step - loss: 1.4883 - dice_coef: 0.9177 - accuracy: 0.9202 - val_loss: 1.8980 - val_dice_coef: 0.9050 - val_accuracy: 0.9063
#
# Epoch 00010: val_loss did not improve from 1.63409
# Epoch 11/100
# 426/426 [==============================] - 315s 739ms/step - loss: 1.3701 - dice_coef: 0.9228 - accuracy: 0.9250 - val_loss: 1.3604 - val_dice_coef: 0.9299 - val_accuracy: 0.9323
#
# Epoch 00011: val_loss improved from 1.63409 to 1.36041, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 12/100
# 426/426 [==============================] - 315s 739ms/step - loss: 1.3277 - dice_coef: 0.9213 - accuracy: 0.9237 - val_loss: 1.3756 - val_dice_coef: 0.9325 - val_accuracy: 0.9343
#
# Epoch 00012: val_loss did not improve from 1.36041
# Epoch 13/100
# 426/426 [==============================] - 315s 740ms/step - loss: 1.2640 - dice_coef: 0.9233 - accuracy: 0.9255 - val_loss: 1.4955 - val_dice_coef: 0.8951 - val_accuracy: 0.9009
#
# Epoch 00013: val_loss did not improve from 1.36041
# Epoch 14/100
# 426/426 [==============================] - 315s 739ms/step - loss: 1.2353 - dice_coef: 0.9219 - accuracy: 0.9243 - val_loss: 1.3478 - val_dice_coef: 0.9240 - val_accuracy: 0.9274
#
# Epoch 00014: val_loss improved from 1.36041 to 1.34783, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 15/100
# 426/426 [==============================] - 315s 739ms/step - loss: 1.1787 - dice_coef: 0.9255 - accuracy: 0.9277 - val_loss: 1.3568 - val_dice_coef: 0.9228 - val_accuracy: 0.9252
#
# Epoch 00015: val_loss did not improve from 1.34783
# Epoch 16/100
# 426/426 [==============================] - 315s 739ms/step - loss: 1.1776 - dice_coef: 0.9227 - accuracy: 0.9249 - val_loss: 1.3416 - val_dice_coef: 0.9118 - val_accuracy: 0.9147
#
# Epoch 00016: val_loss improved from 1.34783 to 1.34164, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 17/100
# 426/426 [==============================] - 315s 739ms/step - loss: 1.1534 - dice_coef: 0.9218 - accuracy: 0.9240 - val_loss: 1.2301 - val_dice_coef: 0.9269 - val_accuracy: 0.9289
#
# Epoch 00017: val_loss improved from 1.34164 to 1.23006, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 18/100
# 426/426 [==============================] - 315s 738ms/step - loss: 1.1095 - dice_coef: 0.9248 - accuracy: 0.9270 - val_loss: 1.0891 - val_dice_coef: 0.9377 - val_accuracy: 0.9398
#
# Epoch 00018: val_loss improved from 1.23006 to 1.08915, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 19/100
# 426/426 [==============================] - 315s 738ms/step - loss: 1.0631 - dice_coef: 0.9278 - accuracy: 0.9298 - val_loss: 1.1198 - val_dice_coef: 0.9303 - val_accuracy: 0.9321
#
# Epoch 00019: val_loss did not improve from 1.08915
# Epoch 20/100
# 426/426 [==============================] - 315s 738ms/step - loss: 1.0511 - dice_coef: 0.9267 - accuracy: 0.9288 - val_loss: 1.3550 - val_dice_coef: 0.9224 - val_accuracy: 0.9233
#
# Epoch 00020: val_loss did not improve from 1.08915
# Epoch 21/100
# 426/426 [==============================] - 314s 738ms/step - loss: 1.0406 - dice_coef: 0.9269 - accuracy: 0.9289 - val_loss: 1.2358 - val_dice_coef: 0.9265 - val_accuracy: 0.9283
#
# Epoch 00021: val_loss did not improve from 1.08915
# Epoch 22/100
# 426/426 [==============================] - 315s 738ms/step - loss: 1.0111 - dice_coef: 0.9292 - accuracy: 0.9312 - val_loss: 1.2558 - val_dice_coef: 0.8935 - val_accuracy: 0.8963
#
# Epoch 00022: val_loss did not improve from 1.08915
# Epoch 23/100
# 426/426 [==============================] - 315s 739ms/step - loss: 1.0140 - dice_coef: 0.9283 - accuracy: 0.9303 - val_loss: 1.2279 - val_dice_coef: 0.9252 - val_accuracy: 0.9264
#
# Epoch 00023: val_loss did not improve from 1.08915
# Epoch 24/100
# 426/426 [==============================] - 315s 739ms/step - loss: 1.0119 - dice_coef: 0.9268 - accuracy: 0.9288 - val_loss: 1.8344 - val_dice_coef: 0.8852 - val_accuracy: 0.8860
#
# Epoch 00024: val_loss did not improve from 1.08915
# Epoch 25/100
# 426/426 [==============================] - 315s 739ms/step - loss: 1.0109 - dice_coef: 0.9261 - accuracy: 0.9282 - val_loss: 1.2543 - val_dice_coef: 0.9233 - val_accuracy: 0.9243
#
# Epoch 00025: val_loss did not improve from 1.08915
# Epoch 26/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9786 - dice_coef: 0.9281 - accuracy: 0.9302 - val_loss: 1.2182 - val_dice_coef: 0.8999 - val_accuracy: 0.9048
#
# Epoch 00026: val_loss did not improve from 1.08915
# Epoch 27/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9852 - dice_coef: 0.9283 - accuracy: 0.9304 - val_loss: 1.1164 - val_dice_coef: 0.9247 - val_accuracy: 0.9282
#
# Epoch 00027: val_loss did not improve from 1.08915
# Epoch 28/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9814 - dice_coef: 0.9275 - accuracy: 0.9296 - val_loss: 1.1313 - val_dice_coef: 0.9322 - val_accuracy: 0.9336
#
# Epoch 00028: val_loss did not improve from 1.08915
# Epoch 29/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9685 - dice_coef: 0.9309 - accuracy: 0.9329 - val_loss: 1.0857 - val_dice_coef: 0.9194 - val_accuracy: 0.9216
#
# Epoch 00029: val_loss improved from 1.08915 to 1.08571, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 30/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9604 - dice_coef: 0.9297 - accuracy: 0.9317 - val_loss: 1.0910 - val_dice_coef: 0.9312 - val_accuracy: 0.9330
#
# Epoch 00030: val_loss did not improve from 1.08571
# Epoch 31/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9718 - dice_coef: 0.9276 - accuracy: 0.9296 - val_loss: 1.4424 - val_dice_coef: 0.8751 - val_accuracy: 0.8771
#
# Epoch 00031: val_loss did not improve from 1.08571
# Epoch 32/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9542 - dice_coef: 0.9304 - accuracy: 0.9324 - val_loss: 1.7363 - val_dice_coef: 0.8906 - val_accuracy: 0.8918
#
# Epoch 00032: val_loss did not improve from 1.08571
# Epoch 33/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9654 - dice_coef: 0.9293 - accuracy: 0.9313 - val_loss: 1.0520 - val_dice_coef: 0.9368 - val_accuracy: 0.9385
#
# Epoch 00033: val_loss improved from 1.08571 to 1.05198, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 34/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9568 - dice_coef: 0.9305 - accuracy: 0.9324 - val_loss: 1.9227 - val_dice_coef: 0.6921 - val_accuracy: 0.6932
#
# Epoch 00034: val_loss did not improve from 1.05198
# Epoch 35/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9522 - dice_coef: 0.9302 - accuracy: 0.9321 - val_loss: 1.5881 - val_dice_coef: 0.8976 - val_accuracy: 0.8989
#
# Epoch 00035: val_loss did not improve from 1.05198
# Epoch 36/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9438 - dice_coef: 0.9316 - accuracy: 0.9335 - val_loss: 1.0646 - val_dice_coef: 0.9345 - val_accuracy: 0.9366
#
# Epoch 00036: val_loss did not improve from 1.05198
# Epoch 37/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9667 - dice_coef: 0.9291 - accuracy: 0.9311 - val_loss: 1.3981 - val_dice_coef: 0.8629 - val_accuracy: 0.8670
#
# Epoch 00037: val_loss did not improve from 1.05198
# Epoch 38/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9466 - dice_coef: 0.9299 - accuracy: 0.9320 - val_loss: 1.0241 - val_dice_coef: 0.9375 - val_accuracy: 0.9396
#
# Epoch 00038: val_loss improved from 1.05198 to 1.02412, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 39/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9623 - dice_coef: 0.9301 - accuracy: 0.9320 - val_loss: 1.0127 - val_dice_coef: 0.9397 - val_accuracy: 0.9413
#
# Epoch 00039: val_loss improved from 1.02412 to 1.01273, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 40/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9646 - dice_coef: 0.9304 - accuracy: 0.9324 - val_loss: 1.1314 - val_dice_coef: 0.9165 - val_accuracy: 0.9199
#
# Epoch 00040: val_loss did not improve from 1.01273
# Epoch 41/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9490 - dice_coef: 0.9307 - accuracy: 0.9326 - val_loss: 0.9902 - val_dice_coef: 0.9400 - val_accuracy: 0.9414
#
# Epoch 00041: val_loss improved from 1.01273 to 0.99022, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 42/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9388 - dice_coef: 0.9327 - accuracy: 0.9346 - val_loss: 1.0407 - val_dice_coef: 0.9391 - val_accuracy: 0.9404
#
# Epoch 00042: val_loss did not improve from 0.99022
# Epoch 43/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9408 - dice_coef: 0.9337 - accuracy: 0.9355 - val_loss: 1.0618 - val_dice_coef: 0.9232 - val_accuracy: 0.9262
#
# Epoch 00043: val_loss did not improve from 0.99022
# Epoch 44/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9405 - dice_coef: 0.9316 - accuracy: 0.9335 - val_loss: 1.0458 - val_dice_coef: 0.9377 - val_accuracy: 0.9389
#
# Epoch 00044: val_loss did not improve from 0.99022
# Epoch 45/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9568 - dice_coef: 0.9305 - accuracy: 0.9325 - val_loss: 1.0202 - val_dice_coef: 0.9347 - val_accuracy: 0.9362
#
# Epoch 00045: val_loss did not improve from 0.99022
# Epoch 46/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9291 - dice_coef: 0.9333 - accuracy: 0.9352 - val_loss: 1.0161 - val_dice_coef: 0.9395 - val_accuracy: 0.9414
#
# Epoch 00046: val_loss did not improve from 0.99022
# Epoch 47/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9480 - dice_coef: 0.9329 - accuracy: 0.9347 - val_loss: 0.9694 - val_dice_coef: 0.9380 - val_accuracy: 0.9403
#
# Epoch 00047: val_loss improved from 0.99022 to 0.96940, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 48/100
# 426/426 [==============================] - 314s 738ms/step - loss: 0.9460 - dice_coef: 0.9331 - accuracy: 0.9349 - val_loss: 1.0586 - val_dice_coef: 0.9366 - val_accuracy: 0.9380
#
# Epoch 00048: val_loss did not improve from 0.96940
# Epoch 49/100
# 426/426 [==============================] - 314s 738ms/step - loss: 0.9620 - dice_coef: 0.9313 - accuracy: 0.9332 - val_loss: 1.1426 - val_dice_coef: 0.9136 - val_accuracy: 0.9164
#
# Epoch 00049: val_loss did not improve from 0.96940
# Epoch 50/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9477 - dice_coef: 0.9329 - accuracy: 0.9348 - val_loss: 0.9474 - val_dice_coef: 0.9464 - val_accuracy: 0.9479
#
# Epoch 00050: val_loss improved from 0.96940 to 0.94738, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 51/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9534 - dice_coef: 0.9327 - accuracy: 0.9345 - val_loss: 1.8212 - val_dice_coef: 0.8684 - val_accuracy: 0.8724
#
# Epoch 00051: val_loss did not improve from 0.94738
# Epoch 52/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9481 - dice_coef: 0.9324 - accuracy: 0.9343 - val_loss: 0.9631 - val_dice_coef: 0.9441 - val_accuracy: 0.9455
#
# Epoch 00052: val_loss did not improve from 0.94738
# Epoch 53/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9676 - dice_coef: 0.9319 - accuracy: 0.9337 - val_loss: 1.1330 - val_dice_coef: 0.9293 - val_accuracy: 0.9335
#
# Epoch 00053: val_loss did not improve from 0.94738
# Epoch 54/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9446 - dice_coef: 0.9332 - accuracy: 0.9351 - val_loss: 2.3963 - val_dice_coef: 0.6451 - val_accuracy: 0.6456
#
# Epoch 00054: val_loss did not improve from 0.94738
# Epoch 55/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9326 - dice_coef: 0.9350 - accuracy: 0.9368 - val_loss: 1.1285 - val_dice_coef: 0.9239 - val_accuracy: 0.9259
#
# Epoch 00055: val_loss did not improve from 0.94738
# Epoch 56/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9381 - dice_coef: 0.9360 - accuracy: 0.9378 - val_loss: 1.0608 - val_dice_coef: 0.9329 - val_accuracy: 0.9352
#
# Epoch 00056: val_loss did not improve from 0.94738
# Epoch 57/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9395 - dice_coef: 0.9343 - accuracy: 0.9361 - val_loss: 1.2815 - val_dice_coef: 0.8782 - val_accuracy: 0.8800
#
# Epoch 00057: val_loss did not improve from 0.94738
# Epoch 58/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9319 - dice_coef: 0.9353 - accuracy: 0.9371 - val_loss: 1.8842 - val_dice_coef: 0.8068 - val_accuracy: 0.8136
#
# Epoch 00058: val_loss did not improve from 0.94738
# Epoch 59/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9419 - dice_coef: 0.9358 - accuracy: 0.9375 - val_loss: 1.0931 - val_dice_coef: 0.9299 - val_accuracy: 0.9315
#
# Epoch 00059: val_loss did not improve from 0.94738
# Epoch 60/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9586 - dice_coef: 0.9337 - accuracy: 0.9355 - val_loss: 1.0122 - val_dice_coef: 0.9404 - val_accuracy: 0.9422
#
# Epoch 00060: val_loss did not improve from 0.94738
# Epoch 61/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9628 - dice_coef: 0.9333 - accuracy: 0.9351 - val_loss: 1.7058 - val_dice_coef: 0.8945 - val_accuracy: 0.8953
#
# Epoch 00061: val_loss did not improve from 0.94738
# Epoch 62/100
# 426/426 [==============================] - 314s 738ms/step - loss: 0.9517 - dice_coef: 0.9344 - accuracy: 0.9362 - val_loss: 2.4752 - val_dice_coef: 0.5437 - val_accuracy: 0.5436
#
# Epoch 00062: val_loss did not improve from 0.94738
# Epoch 63/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9486 - dice_coef: 0.9343 - accuracy: 0.9361 - val_loss: 1.0069 - val_dice_coef: 0.9366 - val_accuracy: 0.9395
#
# Epoch 00063: val_loss did not improve from 0.94738
# Epoch 64/100
# 426/426 [==============================] - 314s 738ms/step - loss: 0.9418 - dice_coef: 0.9356 - accuracy: 0.9373 - val_loss: 1.1595 - val_dice_coef: 0.9313 - val_accuracy: 0.9328
#
# Epoch 00064: val_loss did not improve from 0.94738
# Epoch 65/100
# 426/426 [==============================] - 314s 738ms/step - loss: 0.9792 - dice_coef: 0.9336 - accuracy: 0.9354 - val_loss: 1.2214 - val_dice_coef: 0.9282 - val_accuracy: 0.9295
#
# Epoch 00065: val_loss did not improve from 0.94738
# Epoch 66/100
# 426/426 [==============================] - 314s 738ms/step - loss: 0.9696 - dice_coef: 0.9352 - accuracy: 0.9370 - val_loss: 1.0840 - val_dice_coef: 0.9397 - val_accuracy: 0.9410
#
# Epoch 00066: val_loss did not improve from 0.94738
# Epoch 67/100
# 426/426 [==============================] - 314s 738ms/step - loss: 0.9748 - dice_coef: 0.9359 - accuracy: 0.9376 - val_loss: 1.0585 - val_dice_coef: 0.9400 - val_accuracy: 0.9417
#
# Epoch 00067: val_loss did not improve from 0.94738
# Epoch 68/100
# 426/426 [==============================] - 314s 738ms/step - loss: 0.9469 - dice_coef: 0.9373 - accuracy: 0.9391 - val_loss: 0.9839 - val_dice_coef: 0.9457 - val_accuracy: 0.9477
#
# Epoch 00068: val_loss did not improve from 0.94738
# Epoch 69/100
# 426/426 [==============================] - 314s 738ms/step - loss: 0.9575 - dice_coef: 0.9352 - accuracy: 0.9370 - val_loss: 0.9635 - val_dice_coef: 0.9466 - val_accuracy: 0.9485
#
# Epoch 00069: val_loss did not improve from 0.94738
# Epoch 70/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9679 - dice_coef: 0.9342 - accuracy: 0.9361 - val_loss: 1.0508 - val_dice_coef: 0.9425 - val_accuracy: 0.9437
#
# Epoch 00070: val_loss did not improve from 0.94738
# Epoch 71/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9682 - dice_coef: 0.9355 - accuracy: 0.9372 - val_loss: 1.1462 - val_dice_coef: 0.9156 - val_accuracy: 0.9175
#
# Epoch 00071: val_loss did not improve from 0.94738
# Epoch 72/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9768 - dice_coef: 0.9342 - accuracy: 0.9360 - val_loss: 1.1522 - val_dice_coef: 0.9220 - val_accuracy: 0.9245
#
# Epoch 00072: val_loss did not improve from 0.94738
# Epoch 73/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9548 - dice_coef: 0.9374 - accuracy: 0.9391 - val_loss: 1.1185 - val_dice_coef: 0.9371 - val_accuracy: 0.9386
#
# Epoch 00073: val_loss did not improve from 0.94738
# Epoch 74/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9896 - dice_coef: 0.9331 - accuracy: 0.9349 - val_loss: 1.2195 - val_dice_coef: 0.9125 - val_accuracy: 0.9145
#
# Epoch 00074: val_loss did not improve from 0.94738
# Epoch 75/100
# 426/426 [==============================] - 314s 738ms/step - loss: 0.9698 - dice_coef: 0.9361 - accuracy: 0.9379 - val_loss: 1.6391 - val_dice_coef: 0.7962 - val_accuracy: 0.7988
#
# Epoch 00075: val_loss did not improve from 0.94738
# Epoch 76/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9685 - dice_coef: 0.9366 - accuracy: 0.9383 - val_loss: 0.9887 - val_dice_coef: 0.9476 - val_accuracy: 0.9490
#
# Epoch 00076: val_loss did not improve from 0.94738
# Epoch 77/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9551 - dice_coef: 0.9372 - accuracy: 0.9390 - val_loss: 0.9627 - val_dice_coef: 0.9493 - val_accuracy: 0.9505
#
# Epoch 00077: val_loss did not improve from 0.94738
# Epoch 78/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9506 - dice_coef: 0.9384 - accuracy: 0.9401 - val_loss: 2.0627 - val_dice_coef: 0.6606 - val_accuracy: 0.6655
#
# Epoch 00078: val_loss did not improve from 0.94738
# Epoch 79/100
# 426/426 [==============================] - 314s 738ms/step - loss: 0.9428 - dice_coef: 0.9382 - accuracy: 0.9399 - val_loss: 1.1071 - val_dice_coef: 0.9381 - val_accuracy: 0.9391
#
# Epoch 00079: val_loss did not improve from 0.94738
# Epoch 80/100
# 426/426 [==============================] - 314s 738ms/step - loss: 0.9720 - dice_coef: 0.9375 - accuracy: 0.9392 - val_loss: 0.9677 - val_dice_coef: 0.9478 - val_accuracy: 0.9490
#
# Epoch 00080: val_loss did not improve from 0.94738
# Epoch 81/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9601 - dice_coef: 0.9384 - accuracy: 0.9400 - val_loss: 1.2881 - val_dice_coef: 0.9070 - val_accuracy: 0.9108
#
# Epoch 00081: val_loss did not improve from 0.94738
# Epoch 82/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9843 - dice_coef: 0.9372 - accuracy: 0.9389 - val_loss: 1.0993 - val_dice_coef: 0.9344 - val_accuracy: 0.9375
#
# Epoch 00082: val_loss did not improve from 0.94738
# Epoch 83/100
# 426/426 [==============================] - 314s 738ms/step - loss: 1.0019 - dice_coef: 0.9353 - accuracy: 0.9371 - val_loss: 2.8075 - val_dice_coef: 0.5110 - val_accuracy: 0.5076
#
# Epoch 00083: val_loss did not improve from 0.94738
# Epoch 84/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9703 - dice_coef: 0.9390 - accuracy: 0.9407 - val_loss: 1.0470 - val_dice_coef: 0.9433 - val_accuracy: 0.9446
#
# Epoch 00084: val_loss did not improve from 0.94738
# Epoch 85/100
# 426/426 [==============================] - 314s 738ms/step - loss: 0.9493 - dice_coef: 0.9397 - accuracy: 0.9413 - val_loss: 1.3661 - val_dice_coef: 0.9198 - val_accuracy: 0.9214
#
# Epoch 00085: val_loss did not improve from 0.94738
# Epoch 86/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9523 - dice_coef: 0.9398 - accuracy: 0.9413 - val_loss: 1.3233 - val_dice_coef: 0.8984 - val_accuracy: 0.9011
#
# Epoch 00086: val_loss did not improve from 0.94738
# Epoch 87/100
# 426/426 [==============================] - 314s 738ms/step - loss: 0.9467 - dice_coef: 0.9395 - accuracy: 0.9411 - val_loss: 1.1742 - val_dice_coef: 0.9148 - val_accuracy: 0.9194
#
# Epoch 00087: val_loss did not improve from 0.94738
# Epoch 88/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9455 - dice_coef: 0.9395 - accuracy: 0.9411 - val_loss: 1.2337 - val_dice_coef: 0.9299 - val_accuracy: 0.9312
#
# Epoch 00088: val_loss did not improve from 0.94738
# Epoch 89/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9745 - dice_coef: 0.9387 - accuracy: 0.9403 - val_loss: 1.1263 - val_dice_coef: 0.9390 - val_accuracy: 0.9402
#
# Epoch 00089: val_loss did not improve from 0.94738
# Epoch 90/100
# 426/426 [==============================] - 314s 738ms/step - loss: 1.0092 - dice_coef: 0.9358 - accuracy: 0.9376 - val_loss: 1.4233 - val_dice_coef: 0.8853 - val_accuracy: 0.8879
#
# Epoch 00090: val_loss did not improve from 0.94738
# Epoch 91/100
# 426/426 [==============================] - 314s 738ms/step - loss: 0.9634 - dice_coef: 0.9383 - accuracy: 0.9400 - val_loss: 0.9948 - val_dice_coef: 0.9494 - val_accuracy: 0.9505
#
# Epoch 00091: val_loss did not improve from 0.94738
# Epoch 92/100
# 426/426 [==============================] - 314s 738ms/step - loss: 0.9741 - dice_coef: 0.9381 - accuracy: 0.9398 - val_loss: 1.3573 - val_dice_coef: 0.9128 - val_accuracy: 0.9158
#
# Epoch 00092: val_loss did not improve from 0.94738
# Epoch 93/100
# 426/426 [==============================] - 315s 738ms/step - loss: 0.9868 - dice_coef: 0.9379 - accuracy: 0.9396 - val_loss: 1.2564 - val_dice_coef: 0.9029 - val_accuracy: 0.9053
#
# Epoch 00093: val_loss did not improve from 0.94738
# Epoch 94/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9568 - dice_coef: 0.9402 - accuracy: 0.9418 - val_loss: 0.9352 - val_dice_coef: 0.9523 - val_accuracy: 0.9535
#
# Epoch 00094: val_loss improved from 0.94738 to 0.93524, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 1.h5
# Epoch 95/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9609 - dice_coef: 0.9396 - accuracy: 0.9412 - val_loss: 1.4754 - val_dice_coef: 0.8409 - val_accuracy: 0.8442
#
# Epoch 00095: val_loss did not improve from 0.93524
# Epoch 96/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9682 - dice_coef: 0.9403 - accuracy: 0.9419 - val_loss: 0.9565 - val_dice_coef: 0.9513 - val_accuracy: 0.9528
#
# Epoch 00096: val_loss did not improve from 0.93524
# Epoch 97/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9532 - dice_coef: 0.9413 - accuracy: 0.9428 - val_loss: 1.0883 - val_dice_coef: 0.9404 - val_accuracy: 0.9420
#
# Epoch 00097: val_loss did not improve from 0.93524
# Epoch 98/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9731 - dice_coef: 0.9398 - accuracy: 0.9414 - val_loss: 1.0000 - val_dice_coef: 0.9478 - val_accuracy: 0.9492
#
# Epoch 00098: val_loss did not improve from 0.93524
# Epoch 99/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9790 - dice_coef: 0.9390 - accuracy: 0.9406 - val_loss: 1.6688 - val_dice_coef: 0.7701 - val_accuracy: 0.7722
#
# Epoch 00099: val_loss did not improve from 0.93524
# Epoch 100/100
# 426/426 [==============================] - 315s 739ms/step - loss: 0.9602 - dice_coef: 0.9413 - accuracy: 0.9428 - val_loss: 0.9674 - val_dice_coef: 0.9509 - val_accuracy: 0.9520
#
# Epoch 00100: val_loss did not improve from 0.93524
# TRAIN: [0, 1, 2, 4, 5, 6, 7] TEST: [3, 8]
# -----------fold 2--------------
# Epoch 1/100
# 426/426 [==============================] - 327s 768ms/step - loss: 3.4594 - dice_coef: 0.8098 - accuracy: 0.8676 - val_loss: 3.5416 - val_dice_coef: 0.7697 - val_accuracy: 0.7963
#
# Epoch 00001: val_loss improved from inf to 3.54161, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 2.h5
# Epoch 2/100
# 426/426 [==============================] - 315s 739ms/step - loss: 3.0132 - dice_coef: 0.8514 - accuracy: 0.8908 - val_loss: 3.0711 - val_dice_coef: 0.8672 - val_accuracy: 0.8806
#
# Epoch 00002: val_loss improved from 3.54161 to 3.07115, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 2.h5
# Epoch 3/100
# 426/426 [==============================] - 315s 738ms/step - loss: 2.6478 - dice_coef: 0.8733 - accuracy: 0.8989 - val_loss: 2.5728 - val_dice_coef: 0.8916 - val_accuracy: 0.9058
#
# Epoch 00003: val_loss improved from 3.07115 to 2.57280, saving model to /content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Checkpoint 2.h5
# Epoch 4/100
#  65/426 [===>..........................] - ETA: 4:11 - loss: 2.4627 - dice_coef: 0.8809 - accuracy: 0.9018

# %%
def stitchMaskPatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240] = pieces[k]
      k = k + 1
  return reconstructed_img


def stitchImagePatches(pieces):
  k = 0
  reconstructed_img = np.ones([1440,1920,3])
  for r in range(6):
    row = r * 240
    for c in range(8):
      col = c * 240
      reconstructed_img[row:row+240,col:col+240,:] = pieces[k]
      k = k + 1
  return reconstructed_img

# %%
def saveNumpyOutput(mask, Patient_array,Patient_length,title,folder):
  idx = 0
  for i in range(len(Patient_length)):
    temp = []
    for j in range(Patient_length[i]):
      final_output = mask[idx:idx+48]
      idx = idx + 48
      final_output = stitchMaskPatches(final_output)
      temp.append(final_output)
    final_output = np.asarray(temp)
    np.save(folder + title + Patient_array[i], final_output)

# %%
MODELS_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Models/Ki67/Combined FTL/Ki67/"
model_names = os.listdir(MODELS_PATH)
print(model_names)
# Out:
# ['Ki67 0.h5', 'Ki67 2.h5', 'Ki67 1.h5']

# %%
# !ls "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/Ki67/3Fold LadderNet/"

# %%
SAVE_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/Ki67/3Fold LadderNet/"

# %%
# Axis 0 = Folds
# Axis 1 = Class (Backround, Immunopositive,Immunongative)
# Axis 2 = Evaluation Technique (Precision, Recall, Dice coefficient)
pixEvaluationTrain = np.empty((0,3,3))
pixEvaluationTest = np.empty((0,3,3))
score = np.zeros((1,3,3))
print(pixEvaluationTrain.shape)
print(pixEvaluationTest.shape)
print(score.shape)
# Out:
# (0, 3, 3)
# (0, 3, 3)
# (1, 3, 3)

# %%
fold = 0

for train_index, test_index in fold_split:
  print("FOLD:",fold,"\tTRAIN:", train_index, "TEST:", test_index)
  # Splitting Train and Test data
  TrainX =  np.concatenate(np.array([X[i] for i in train_index]))
  TrainY =  np.concatenate(np.array([Y[i] for i in train_index]))
  TestX  =  np.concatenate(np.array([X[i] for i in test_index]))
  TestY  =  np.concatenate(np.array([Y[i] for i in test_index]))

  train_no = [patient_no[i] for i in train_index]
  train_size = [size[i] for i in train_index]

  test_no = [patient_no[i] for i in test_index]
  test_size = [size[i] for i in test_index]

  TrainX = TrainX.astype('float32')/255
  TestX = TestX.astype('float32')/255

  convertToLabels(TrainY)
  convertToLabels(TestY)
  
  # Loading corrosponding fold of model
  model = keras.models.load_model(MODELS_PATH + model_names[fold],custom_objects={ 'combined_loss': combined_loss, 'dice_coef': dice_coef })

  # Predicting results using model
  trainResult = model.predict(TrainX, batch_size=8)
  testResult = model.predict(TestX,batch_size=8)

  trainResult = np.argmax(trainResult,axis=-1)
  testResult = np.argmax(testResult,axis=-1)

  # Obtaining pixel-wise results: Precision recall and dice coefficient
  # For TRAIN
  y_true = np.reshape(TrainY,(-1))
  y_pred = np.reshape(trainResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2],average=None,zero_division=1)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2],average=None,zero_division=1)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(3):
    score[0][i][0] = prec[i]
    score[0][i][1] = recall[i]
    score[0][i][2] = dice[i]

  pixEvaluationTrain = np.append(pixEvaluationTrain,score,axis=0)
 
  # For TEST
  y_true = np.reshape(TestY,(-1))
  y_pred = np.reshape(testResult,(-1))

  prec   = metrics.precision_score(y_true,y_pred,labels=[0,1,2],average=None,zero_division=1)
  recall = metrics.recall_score(y_true,y_pred,labels=[0,1,2],average=None,zero_division=1)
  dice = 2*prec*recall/(prec+recall)

  # Precision Recall Dice for each class
  for i in range(3):
    score[0][i][0] = prec[i]
    score[0][i][1] = recall[i]
    score[0][i][2] = dice[i]

  pixEvaluationTest = np.append(pixEvaluationTest,score,axis=0)

  # Converting predicted labels to required output format
  convertFromLabels(trainResult)
  convertFromLabels(testResult)

  # Saving numpy arrays
  path = os.path.join(SAVE_PATH,"Fold " + str(fold))
  os.mkdir(path)
  os.mkdir(path + '/Train')
  os.mkdir(path + '/Test')

  saveNumpyOutput(trainResult, train_no, train_size,"/Train/",path)
  saveNumpyOutput(testResult, test_no, test_size,"/Test/",path)

  fold +=1
# Out:
# FOLD: 0 	TRAIN: [2, 3, 4, 5, 6, 7, 8] TEST: [0, 1]
# FOLD: 1 	TRAIN: [0, 1, 3, 4, 5, 7, 8] TEST: [2, 6]
# FOLD: 2 	TRAIN: [0, 1, 2, 4, 5, 6, 7] TEST: [3, 8]

# %%
print(pixEvaluationTrain.shape)
print(pixEvaluationTest.shape)
# Out:
# (3, 3, 3)
# (3, 3, 3)

# %%
print(pixEvaluationTrain)
print(pixEvaluationTest)
# Out:
# [[[0.95641807 0.96895467 0.96264555]
#   [0.87621463 0.84015425 0.85780563]
#   [0.90193241 0.85918155 0.88003809]]
#
#  [[0.96066248 0.95611437 0.95838303]
#   [0.84079263 0.81778287 0.82912814]
#   [0.83002941 0.91519765 0.8705354 ]]
#
#  [[0.95917451 0.94034877 0.94966835]
#   [0.84399573 0.83333489 0.83863143]
#   [0.80203726 0.92782235 0.86035663]]]
# [[[0.92102706 0.94215554 0.9314715 ]
#   [0.76701276 0.759829   0.76340398]
#   [0.8997609  0.72169501 0.80095049]]
#
#  [[0.95538981 0.94267552 0.94899008]
#   [0.8781907  0.84241862 0.8599328 ]
#   [0.82729668 0.9183455  0.87044664]]
#
#  [[0.97887958 0.96260159 0.97067234]
#   [0.81981352 0.89424264 0.85541212]
#   [0.89160806 0.91548014 0.90338642]]]

# %%
np.save(SAVE_PATH + "Pixel-wise Metrics Train.npy", pixEvaluationTrain)
np.save(SAVE_PATH + "Pixel-wise Metrics Test.npy", pixEvaluationTest)

# %%
LOAD_PATH = "/content/drive/My Drive/Breast Cancer Treatment/Numpy Arrays/Predicted Output/Ki67/KFold LadderNet/"
trainMetrics = np.load(LOAD_PATH + "Pixel-wise Metrics Train.npy")
testMetrics  = np.load(LOAD_PATH + "Pixel-wise Metrics Test.npy")
print(trainMetrics.shape)
print(testMetrics.shape)
# Out:
# (9, 3, 3)
# (9, 3, 3)

# %%
#For pixel-wise background is included and for object-wise background is not included
numClasses = 3
avgTrainMetrics  = np.zeros([numClasses, 3])
avgTestMetrics   = np.zeros([numClasses, 3])

def calculateMetrics(AvgMetrics, ValidationMetrics):
  for patientNum in range(ValidationMetrics.shape[0]):
    for row in range(numClasses):
      for col in range(3):
        AvgMetrics[row][col] += ValidationMetrics[patientNum][row][col]
  AvgMetrics = np.divide(AvgMetrics,ValidationMetrics.shape[0] )
  return AvgMetrics


avgTrainMetrics = calculateMetrics(avgTrainMetrics, trainMetrics)
print('TRAIN :')
print(avgTrainMetrics)

avgTestMetrics = calculateMetrics(avgTestMetrics, testMetrics)
print('TEST :')
print(avgTestMetrics)
# Out:
# TRAIN :
# [[0.9558469  0.957932   0.95671614]
#  [0.8550969  0.81991115 0.83443751]
#  [0.86590669 0.89296803 0.87713484]]
# TEST :
# [[0.93093541 0.93941124 0.93411226]
#  [0.79153604 0.66190771 0.68281195]
#  [0.83019238 0.82337968 0.82415122]]
